# %% [markdown]
# # Bogota 2

# %%
import pandas as pd 

df2_phase5 = pd.read_csv("../data/Absolute Score Bogota2 Phase5.csv")
df2_phase5
# Out:
#          Project                Hack       Student  \
# 0   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 1   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 2        bdvegat  Bogota-Hack-2-2017       bdvegat
# 3        bdvegat  Bogota-Hack-2-2017       bdvegat
# 4     Phoenixest  Bogota-Hack-2-2017    Phoenixest
# ..           ...                 ...           ...
# 73      oserasoa  Bogota-Hack-2-2017      oserasoa
# 74      lsfinite  Bogota-Hack-2-2017      lsfinite
# 75      lsfinite  Bogota-Hack-2-2017      lsfinite
# 76     xdanielsb  Bogota-Hack-2-2017     xdanielsb
# 77     xdanielsb  Bogota-Hack-2-2017     xdanielsb
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# ...

# %%
df2_novelty_phase5 = df2_phase5[df2_phase5['User Requirement'] != "- - -"]
df2_novelty_phase5
# Out:
#             Project                Hack          Student  \
# 0      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 2           bdvegat  Bogota-Hack-2-2017          bdvegat
# 4        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 6          HashNick  Bogota-Hack-2-2017         HashNick
# 8           ccvacad  Bogota-Hack-2-2017          ccvacad
# 10     jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 12  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 14         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 17      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 19       crarojasca  Bogota-Hack-2-2017       crarojasca
# 21           sagilm  Bogota-Hack-2-2017           sagilm
# 23         idrojasf  Bogota-Hack-2-2017         idrojasf
# 25     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 27        fabianr23  Bogota-Hack-2-2017        fabianr23
# 29       jhriverasa  Bogota-Hack-2-2017       jhriverasa
# ...

# %%
df2_final_novelty_phase5 = df2_novelty_phase5[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df2_tech_phase5 = df2_phase5[df2_phase5['Tech Score'] != "- - -"]
df2_tech_phase5
# Out:
#             Project                Hack          Student  \
# 1      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 3           bdvegat  Bogota-Hack-2-2017          bdvegat
# 5        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 7          HashNick  Bogota-Hack-2-2017         HashNick
# 9           ccvacad  Bogota-Hack-2-2017          ccvacad
# 11     jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 13  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 15         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 16      CSebasGomez  Bogota-Hack-2-2017      CSebasGomez
# 18      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 20       crarojasca  Bogota-Hack-2-2017       crarojasca
# 22           sagilm  Bogota-Hack-2-2017           sagilm
# 24         idrojasf  Bogota-Hack-2-2017         idrojasf
# 26     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 28        fabianr23  Bogota-Hack-2-2017        fabianr23
# ...

# %%
df2_tech_phase5[['Student', 'Tech Score']]
# Out:
#             Student Tech Score
# 1      jusherrerama         75
# 3           bdvegat       62.5
# 5        Phoenixest         25
# 7          HashNick       37.5
# 9           ccvacad       87.5
# 11       joaortizro       87.5
# 13  juasmartinezbel       87.5
# 15         mdbelloc         75
# 16      CSebasGomez          0
# 18      diegocruz10       37.5
# 20       crarojasca          0
# 22           sagilm       62.5
# 24         idrojasf         75
# 26     raulramirezp        100
# 28        fabianr23        100
# 30       jhriverasa        100
# 31      jhcardenasa          0
# 33       jhonsd1996         75
# 35       JuanitoAli       62.5
# 37       Davsatu313       87.5
# 39   cesarochoa2006       87.5
# 41        jjmuesesq         75
# 43     jucjimenezmo        100
# 45           kancas         75
# 47          Gantiva         75
# 49       Dandarprox        100
# 51       debeltranc         75
# 53        ykchautai         75
# 55        ligibrial       87.5
# ...

# %%
df2_final_tech_phase5 = df2_tech_phase5[['Student', 'Tech Score']]
df2_final_tech_phase5
# Out:
#             Student Tech Score
# 1      jusherrerama         75
# 3           bdvegat       62.5
# 5        Phoenixest         25
# 7          HashNick       37.5
# 9           ccvacad       87.5
# 11       joaortizro       87.5
# 13  juasmartinezbel       87.5
# 15         mdbelloc         75
# 16      CSebasGomez          0
# 18      diegocruz10       37.5
# 20       crarojasca          0
# 22           sagilm       62.5
# 24         idrojasf         75
# 26     raulramirezp        100
# 28        fabianr23        100
# 30       jhriverasa        100
# 31      jhcardenasa          0
# 33       jhonsd1996         75
# 35       JuanitoAli       62.5
# 37       Davsatu313       87.5
# 39   cesarochoa2006       87.5
# 41        jjmuesesq         75
# 43     jucjimenezmo        100
# 45           kancas         75
# 47          Gantiva         75
# 49       Dandarprox        100
# 51       debeltranc         75
# 53        ykchautai         75
# 55        ligibrial       87.5
# ...

# %%
df2_phase5 = pd.merge(df2_final_novelty_phase5, df2_final_tech_phase5, on='Student', how = 'outer')
df2_phase5
# Out:
#             Student User Requirement Info Viz Score Novelty Score Tech Score
# 0      jusherrerama               20             25             0         75
# 1           bdvegat               20             25             0       62.5
# 2        Phoenixest                0             25            25         25
# 3          HashNick               40             50            25       37.5
# 4           ccvacad               80          66.67            80       87.5
# 5        joaortizro              100             50          87.5       87.5
# 6   juasmartinezbel              100             75            75       87.5
# 7          mdbelloc                0           37.5            25         75
# 8       diegocruz10               20          45.83            25       37.5
# 9        crarojasca               20             25             0          0
# 10           sagilm               20          33.33          62.5       62.5
# ...

# %%
bogota2 = pd.read_csv('../data/total2-phase5.csv')
bogota2
# Out:
#             Student  Unnamed: 1  Unnamed: 2  Total Score  Unnamed: 4  \
# 0         xdanielsb         NaN         NaN       357.50         NaN
# 1           Gantiva         NaN         NaN       345.83         NaN
# 2          leguzman         NaN         NaN       339.17         NaN
# 3   juasmartinezbel         NaN         NaN       337.50         NaN
# 4    cesarochoa2006         NaN         NaN       326.67         NaN
# 5         fabianr23         NaN         NaN       325.83         NaN
# 6        joaortizro         NaN         NaN       325.00         NaN
# 7        Davsatu313         NaN         NaN       322.71         NaN
# 8        jhriverasa         NaN         NaN       318.33         NaN
# 9           ccvacad         NaN         NaN       314.17         NaN
# 10           Yelis3         NaN         NaN       309.17         NaN
# 11       kmendezp96         NaN         NaN       304.79         NaN
# 12       Dandarprox         NaN         NaN       275.83         NaN
# ...

# %%
bogota2 = bogota2[['Student', 'Total Score']]
bogota2
# Out:
#             Student  Total Score
# 0         xdanielsb       357.50
# 1           Gantiva       345.83
# 2          leguzman       339.17
# 3   juasmartinezbel       337.50
# 4    cesarochoa2006       326.67
# 5         fabianr23       325.83
# 6        joaortizro       325.00
# 7        Davsatu313       322.71
# 8        jhriverasa       318.33
# 9           ccvacad       314.17
# 10           Yelis3       309.17
# 11       kmendezp96       304.79
# 12       Dandarprox       275.83
# 13     raulramirezp       272.50
# 14       JuanitoAli       265.83
# 15        begarzonf       227.50
# 16      JulianaNino       224.17
# 17        ykchautai       211.67
# 18     jucjimenezmo       187.50
# 19           kancas       182.50
# 20           sagilm       178.33
# 21       jhonsd1996       174.17
# 22         idrojasf       170.00
# 23     luealfonsoru       158.33
# 24         oserasoa       154.17
# 25         HashNick       152.50
# 26        ligibrial       145.83
# ...

# %%
df2_phase5 = pd.merge(df2_phase5, bogota2, on='Student', how = 'outer')
df2_phase5
# Out:
#             Student User Requirement Info Viz Score Novelty Score Tech Score  \
# 0      jusherrerama               20             25             0         75
# 1           bdvegat               20             25             0       62.5
# 2        Phoenixest                0             25            25         25
# 3          HashNick               40             50            25       37.5
# 4           ccvacad               80          66.67            80       87.5
# 5        joaortizro              100             50          87.5       87.5
# 6   juasmartinezbel              100             75            75       87.5
# 7          mdbelloc                0           37.5            25         75
# 8       diegocruz10               20          45.83            25       37.5
# 9        crarojasca               20             25             0          0
# 10           sagilm               20          33.33          62.5       62.5
# ...

# %%
df2_phase5.insert (1, "Group", 2)
df2_phase5 = df2_phase5.fillna(0)
df2_phase5
# Out:
#             Student  Group User Requirement Info Viz Score Novelty Score  \
# 0      jusherrerama      2               20             25             0
# 1           bdvegat      2               20             25             0
# 2        Phoenixest      2                0             25            25
# 3          HashNick      2               40             50            25
# 4           ccvacad      2               80          66.67            80
# 5        joaortizro      2              100             50          87.5
# 6   juasmartinezbel      2              100             75            75
# 7          mdbelloc      2                0           37.5            25
# 8       diegocruz10      2               20          45.83            25
# 9        crarojasca      2               20             25             0
# 10           sagilm      2               20          33.33          62.5
# 11         idrojasf      2               20             50            25
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase5',
        'Info Viz Score': 'infovis-phase5',
        'Novelty Score': 'novelty-phase5', 
        'Tech Score': 'tech-phase5', 
        'Total Score': 'total-phase5'}
  
# call rename () method
df2_phase5.rename(columns=dict,
          inplace=True)

df2_phase5
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
import pandas as pd 

df2_phase4 = pd.read_csv("../data/Absolute Score Bogota2 Phase 4.csv")
df2_phase4
# Out:
#          Project                Hack       Student  \
# 0   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 1   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 2        bdvegat  Bogota-Hack-2-2017       bdvegat
# 3        bdvegat  Bogota-Hack-2-2017       bdvegat
# 4     Phoenixest  Bogota-Hack-2-2017    Phoenixest
# ..           ...                 ...           ...
# 69  luealfonsoru  Bogota-Hack-2-2017  luealfonsoru
# 70      oserasoa  Bogota-Hack-2-2017      oserasoa
# 71      oserasoa  Bogota-Hack-2-2017      oserasoa
# 72     xdanielsb  Bogota-Hack-2-2017     xdanielsb
# 73     xdanielsb  Bogota-Hack-2-2017     xdanielsb
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# ...

# %%
import pandas as pd 

df1_phase4 = pd.read_csv("../data/Absolute Score Bogota2 Phase 4.csv")
df1_phase4
# Out:
#          Project                Hack       Student  \
# 0   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 1   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 2        bdvegat  Bogota-Hack-2-2017       bdvegat
# 3        bdvegat  Bogota-Hack-2-2017       bdvegat
# 4     Phoenixest  Bogota-Hack-2-2017    Phoenixest
# ..           ...                 ...           ...
# 69  luealfonsoru  Bogota-Hack-2-2017  luealfonsoru
# 70      oserasoa  Bogota-Hack-2-2017      oserasoa
# 71      oserasoa  Bogota-Hack-2-2017      oserasoa
# 72     xdanielsb  Bogota-Hack-2-2017     xdanielsb
# 73     xdanielsb  Bogota-Hack-2-2017     xdanielsb
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# ...

# %%
df2_novelty_phase4 = df2_phase4[df2_phase4['User Requirement'] != "- - -"]
df2_novelty_phase4
# Out:
#             Project                Hack          Student  \
# 0      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 2           bdvegat  Bogota-Hack-2-2017          bdvegat
# 4        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 6          HashNick  Bogota-Hack-2-2017         HashNick
# 8      jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 10  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 12         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 14      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 16       crarojasca  Bogota-Hack-2-2017       crarojasca
# 18           sagilm  Bogota-Hack-2-2017           sagilm
# 20         idrojasf  Bogota-Hack-2-2017         idrojasf
# 23     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 25        fabianr23  Bogota-Hack-2-2017        fabianr23
# 27       jhriverasa  Bogota-Hack-2-2017       jhriverasa
# 30       jhonsd1996  Bogota-Hack-2-2017       jhonsd1996
# ...

# %%
df2_final_novelty_phase4 = df2_novelty_phase4[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df2_tech_phase4 = df2_phase4[df2_phase4['Tech Score'] != "- - -"]
df2_tech_phase4
# Out:
#             Project                Hack          Student  \
# 1      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 3           bdvegat  Bogota-Hack-2-2017          bdvegat
# 5        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 7          HashNick  Bogota-Hack-2-2017         HashNick
# 9      jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 11  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 13         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 15      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 17       crarojasca  Bogota-Hack-2-2017       crarojasca
# 19           sagilm  Bogota-Hack-2-2017           sagilm
# 21         idrojasf  Bogota-Hack-2-2017         idrojasf
# 22     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 24        tres-iqus  Bogota-Hack-2-2017        tres-iqus
# 26        fabianr23  Bogota-Hack-2-2017        fabianr23
# 28       jhriverasa  Bogota-Hack-2-2017       jhriverasa
# ...

# %%
df2_tech_phase4[['Student', 'Tech Score']]
# Out:
#             Student Tech Score
# 1      jusherrerama       62.5
# 3           bdvegat         50
# 5        Phoenixest         25
# 7          HashNick       37.5
# 9        joaortizro       87.5
# 11  juasmartinezbel         75
# 13         mdbelloc         75
# 15      diegocruz10       37.5
# 17       crarojasca          0
# 19           sagilm         50
# 21         idrojasf         75
# 22     raulramirezp         75
# 24        tres-iqus          0
# 26        fabianr23        100
# 28       jhriverasa         75
# 29      jhcardenasa          0
# 31       jhonsd1996         75
# 33       JuanitoAli       62.5
# 35       Davsatu313       87.5
# 37   cesarochoa2006       87.5
# 39        jjmuesesq       62.5
# 41     jucjimenezmo         75
# 43           kancas       62.5
# 45          Gantiva       62.5
# 47       Dandarprox         75
# 49       debeltranc         50
# 50        ykchautai         75
# 53        ligibrial       62.5
# 55       davidrh195       62.5
# ...

# %%
df2_final_tech_phase4 = df2_tech_phase4[['Student', 'Tech Score']]
df2_final_tech_phase4
# Out:
#             Student Tech Score
# 1      jusherrerama       62.5
# 3           bdvegat         50
# 5        Phoenixest         25
# 7          HashNick       37.5
# 9        joaortizro       87.5
# 11  juasmartinezbel         75
# 13         mdbelloc         75
# 15      diegocruz10       37.5
# 17       crarojasca          0
# 19           sagilm         50
# 21         idrojasf         75
# 22     raulramirezp         75
# 24        tres-iqus          0
# 26        fabianr23        100
# 28       jhriverasa         75
# 29      jhcardenasa          0
# 31       jhonsd1996         75
# 33       JuanitoAli       62.5
# 35       Davsatu313       87.5
# 37   cesarochoa2006       87.5
# 39        jjmuesesq       62.5
# 41     jucjimenezmo         75
# 43           kancas       62.5
# 45          Gantiva       62.5
# 47       Dandarprox         75
# 49       debeltranc         50
# 50        ykchautai         75
# 53        ligibrial       62.5
# 55       davidrh195       62.5
# ...

# %%
df2_tech_phase45 = pd.merge(df2_phase5, df2_final_tech_phase4, on='Student', how = 'outer')
df2_tech_phase45
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
df2_phase45 = pd.merge(df2_tech_phase45, df2_final_novelty_phase4, on='Student', how = 'outer')
df2_phase45
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
total2_phase4 = pd.read_csv("../data/total2-phase4.csv")
total2_phase4 = total2_phase4.loc[:, ~total2_phase4.columns.str.contains('^Unnamed')]
total2_phase4
# Out:
#             Student  Total Score
# 0         fabianr23       358.33
# 1        jhriverasa       333.33
# 2        JuanitoAli       325.00
# 3   juasmartinezbel       320.83
# 4        Davsatu313       300.83
# 5          leguzman       290.00
# 6    cesarochoa2006       283.96
# 7        joaortizro       280.00
# 8           Gantiva       237.50
# 9            Yelis3       234.17
# 10        begarzonf       215.00
# 11       Dandarprox       213.33
# 12           kancas       206.67
# 13       kmendezp96       206.67
# 14     jucjimenezmo       203.33
# 15        ykchautai       199.17
# 16       jhonsd1996       157.50
# 17         idrojasf       153.33
# 18           sagilm       150.00
# 19     raulramirezp       148.33
# 20     luealfonsoru       137.50
# 21         HashNick       131.67
# 22         mdbelloc       129.17
# 23      JulianaNino       124.17
# 24         luegilca       116.67
# 25         oserasoa       115.83
# 26        ligibrial       108.33
# ...

# %%
df2_total_phase45 = pd.merge(df2_phase45, total2_phase4, on='Student', how = 'outer')
df2_total_phase45
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase4',
        'Info Viz Score': 'infovis-phase4',
        'Novelty Score': 'novelty-phase4', 
        'Tech Score': 'tech-phase4', 
        'Total Score': 'total-phase4'}
  
# call rename () method
df2_total_phase45.rename(columns=dict,
          inplace=True)

df2_total_phase45
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
import pandas as pd 

df2_phase3 = pd.read_csv("../data/Absolute Score Bogota2 Phase3.csv")
df2_phase3
# Out:
#          Project                Hack       Student  \
# 0   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 1   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 2        bdvegat  Bogota-Hack-2-2017       bdvegat
# 3        bdvegat  Bogota-Hack-2-2017       bdvegat
# 4     Phoenixest  Bogota-Hack-2-2017    Phoenixest
# ..           ...                 ...           ...
# 71      oserasoa  Bogota-Hack-2-2017      oserasoa
# 72      lsfinite  Bogota-Hack-2-2017      lsfinite
# 73      lsfinite  Bogota-Hack-2-2017      lsfinite
# 74     xdanielsb  Bogota-Hack-2-2017     xdanielsb
# 75     xdanielsb  Bogota-Hack-2-2017     xdanielsb
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# ...

# %%
df2_novelty_phase3 = df2_phase3[df2_phase3['User Requirement'] != "- - -"]
df2_novelty_phase3
# Out:
#             Project                Hack          Student  \
# 0      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 2           bdvegat  Bogota-Hack-2-2017          bdvegat
# 4        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 6          HashNick  Bogota-Hack-2-2017         HashNick
# 8      jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 10  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 12         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 14      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 16       crarojasca  Bogota-Hack-2-2017       crarojasca
# 18           sagilm  Bogota-Hack-2-2017           sagilm
# 20         idrojasf  Bogota-Hack-2-2017         idrojasf
# 22     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 25        fabianr23  Bogota-Hack-2-2017        fabianr23
# 27       jhriverasa  Bogota-Hack-2-2017       jhriverasa
# 30       jhonsd1996  Bogota-Hack-2-2017       jhonsd1996
# ...

# %%
df2_final_novelty_phase3 = df2_novelty_phase3[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df2_tech_phase3 = df2_phase3[df2_phase3['Tech Score'] != "- - -"]
df2_tech_phase3
# Out:
#             Project                Hack          Student  \
# 1      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 3           bdvegat  Bogota-Hack-2-2017          bdvegat
# 5        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 7          HashNick  Bogota-Hack-2-2017         HashNick
# 9      jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 11  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 13         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 15      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 17       crarojasca  Bogota-Hack-2-2017       crarojasca
# 19           sagilm  Bogota-Hack-2-2017           sagilm
# 21         idrojasf  Bogota-Hack-2-2017         idrojasf
# 23     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 24        tres-iqus  Bogota-Hack-2-2017        tres-iqus
# 26        fabianr23  Bogota-Hack-2-2017        fabianr23
# 28       jhriverasa  Bogota-Hack-2-2017       jhriverasa
# ...

# %%
df2_tech_phase3[['Student', 'Tech Score']]
# Out:
#             Student Tech Score
# 1      jusherrerama       62.5
# 3           bdvegat         50
# 5        Phoenixest         25
# 7          HashNick       37.5
# 9        joaortizro       87.5
# 11  juasmartinezbel         75
# 13         mdbelloc         75
# 15      diegocruz10       37.5
# 17       crarojasca          0
# 19           sagilm         50
# 21         idrojasf       37.5
# 23     raulramirezp         75
# 24        tres-iqus          0
# 26        fabianr23        100
# 28       jhriverasa       87.5
# 29      jhcardenasa          0
# 31       jhonsd1996         75
# 33       JuanitoAli       62.5
# 35       Davsatu313       87.5
# 37   cesarochoa2006       87.5
# 39        jjmuesesq         50
# 41     jucjimenezmo         47
# 43           kancas       62.5
# 45          Gantiva       62.5
# 47       Dandarprox       62.5
# 49       debeltranc         50
# 51        ykchautai         75
# 53        ligibrial       62.5
# 55       davidrh195       62.5
# ...

# %%
df2_final_tech_phase3 = df2_tech_phase3[['Student', 'Tech Score']]
df2_final_tech_phase3
# Out:
#             Student Tech Score
# 1      jusherrerama       62.5
# 3           bdvegat         50
# 5        Phoenixest         25
# 7          HashNick       37.5
# 9        joaortizro       87.5
# 11  juasmartinezbel         75
# 13         mdbelloc         75
# 15      diegocruz10       37.5
# 17       crarojasca          0
# 19           sagilm         50
# 21         idrojasf       37.5
# 23     raulramirezp         75
# 24        tres-iqus          0
# 26        fabianr23        100
# 28       jhriverasa       87.5
# 29      jhcardenasa          0
# 31       jhonsd1996         75
# 33       JuanitoAli       62.5
# 35       Davsatu313       87.5
# 37   cesarochoa2006       87.5
# 39        jjmuesesq         50
# 41     jucjimenezmo         47
# 43           kancas       62.5
# 45          Gantiva       62.5
# 47       Dandarprox       62.5
# 49       debeltranc         50
# 51        ykchautai         75
# 53        ligibrial       62.5
# 55       davidrh195       62.5
# ...

# %%
df2_tech_phase345 = pd.merge(df2_total_phase45, df2_final_tech_phase3, on='Student', how = 'outer')
df2_tech_phase345 = df2_tech_phase345.loc[:, ~df2_tech_phase345.columns.str.contains('^Unnamed')]
df2_tech_phase345
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
df2_phase3 = pd.merge(df2_tech_phase345, df2_final_novelty_phase3, on='Student', how = 'outer')
df2_phase3
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
total2_phase3 = pd.read_csv("../data/total2-phase3.csv")
total2_phase3 = total2_phase3.loc[:, ~total2_phase3.columns.str.contains('^Unnamed')]
total2_phase3
# Out:
#             Student  Total Score
# 0         fabianr23       358.33
# 1        Davsatu313       320.83
# 2        jhriverasa       312.50
# 3        joaortizro       305.00
# 4   juasmartinezbel       293.33
# 5    cesarochoa2006       276.67
# 6            Yelis3       268.33
# 7        JuanitoAli       255.00
# 8        kmendezp96       235.83
# 9            kancas       230.83
# 10          Gantiva       229.17
# 11     raulramirezp       223.33
# 12        ykchautai       195.00
# 13        begarzonf       174.17
# 14         idrojasf       155.83
# 15       jhonsd1996       153.33
# 16         leguzman       150.00
# 17           sagilm       145.83
# 18     luealfonsoru       145.83
# 19       Dandarprox       135.83
# 20         mdbelloc       133.33
# 21      JulianaNino       124.17
# 22         oserasoa       124.17
# 23        ligibrial       120.83
# 24         luegilca       120.83
# 25     jusherrerama       120.00
# 26      diegocruz10       111.67
# ...

# %%
df2_total_phase3 = pd.merge(df2_phase3, total2_phase3, on='Student', how = 'outer')
df2_total_phase3
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase3',
        'Info Viz Score': 'infovis-phase3',
        'Novelty Score': 'novelty-phase3', 
        'Tech Score': 'tech-phase3', 
        'Total Score': 'total-phase3'}
  
# call rename () method
df2_total_phase3.rename(columns=dict,
          inplace=True)

df2_total_phase3
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
import pandas as pd

df2_phase2 = pd.read_csv("../data/Absolute Score Bogota2 Phase 2.csv")
df2_phase2
# Out:
#          Project                Hack       Student  \
# 0   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 1   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 2        bdvegat  Bogota-Hack-2-2017       bdvegat
# 3        bdvegat  Bogota-Hack-2-2017       bdvegat
# 4     Phoenixest  Bogota-Hack-2-2017    Phoenixest
# ..           ...                 ...           ...
# 72      oserasoa  Bogota-Hack-2-2017      oserasoa
# 73      lsfinite  Bogota-Hack-2-2017      lsfinite
# 74      lsfinite  Bogota-Hack-2-2017      lsfinite
# 75     xdanielsb  Bogota-Hack-2-2017     xdanielsb
# 76     xdanielsb  Bogota-Hack-2-2017     xdanielsb
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# ...

# %%
df2_novelty_phase2 = df2_phase2[df2_phase2['User Requirement'] != "- - -"]
df2_novelty_phase2
# Out:
#             Project                Hack          Student  \
# 0      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 2           bdvegat  Bogota-Hack-2-2017          bdvegat
# 4        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 6          HashNick  Bogota-Hack-2-2017         HashNick
# 9      jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 11  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 13         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 16      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 18       crarojasca  Bogota-Hack-2-2017       crarojasca
# 20           sagilm  Bogota-Hack-2-2017           sagilm
# 22         idrojasf  Bogota-Hack-2-2017         idrojasf
# 24     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 27        fabianr23  Bogota-Hack-2-2017        fabianr23
# 29       jhriverasa  Bogota-Hack-2-2017       jhriverasa
# 33       JuanitoAli  Bogota-Hack-2-2017       JuanitoAli
# ...

# %%
df2_final_novelty_phase2 = df2_novelty_phase2[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df2_tech_phase2 = df2_phase2[df2_phase2['Tech Score'] != "- - -"]
df2_tech_phase2
# Out:
#             Project                Hack          Student  \
# 1      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 3           bdvegat  Bogota-Hack-2-2017          bdvegat
# 5        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 7          HashNick  Bogota-Hack-2-2017         HashNick
# 8           ccvacad  Bogota-Hack-2-2017          ccvacad
# 10     jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 12  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 14         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 15      CSebasGomez  Bogota-Hack-2-2017      CSebasGomez
# 17      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 19       crarojasca  Bogota-Hack-2-2017       crarojasca
# 21           sagilm  Bogota-Hack-2-2017           sagilm
# 23         idrojasf  Bogota-Hack-2-2017         idrojasf
# 25     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 26        tres-iqus  Bogota-Hack-2-2017        tres-iqus
# ...

# %%
df2_tech_phase2[['Student', 'Tech Score']]
# Out:
#             Student Tech Score
# 1      jusherrerama       62.5
# 3           bdvegat         50
# 5        Phoenixest       37.5
# 7          HashNick         50
# 8           ccvacad       12.5
# 10       joaortizro       87.5
# 12  juasmartinezbel         75
# 14         mdbelloc         75
# 15      CSebasGomez       12.5
# 17      diegocruz10         50
# 19       crarojasca       12.5
# 21           sagilm       37.5
# 23         idrojasf       37.5
# 25     raulramirezp         75
# 26        tres-iqus       12.5
# 28        fabianr23        100
# 30       jhriverasa       87.5
# 31      jhcardenasa       12.5
# 32       jhonsd1996         75
# 34       JuanitoAli       62.5
# 36       Davsatu313       87.5
# 38   cesarochoa2006       62.5
# 40        jjmuesesq         50
# 42     jucjimenezmo         50
# 44           kancas       62.5
# 46          Gantiva         75
# 48       Dandarprox       62.5
# 50       debeltranc         50
# 52        ykchautai       62.5
# ...

# %%
df2_final_tech_phase2 = df2_tech_phase2[['Student', 'Tech Score']]
df2_final_tech_phase2
# Out:
#             Student Tech Score
# 1      jusherrerama       62.5
# 3           bdvegat         50
# 5        Phoenixest       37.5
# 7          HashNick         50
# 8           ccvacad       12.5
# 10       joaortizro       87.5
# 12  juasmartinezbel         75
# 14         mdbelloc         75
# 15      CSebasGomez       12.5
# 17      diegocruz10         50
# 19       crarojasca       12.5
# 21           sagilm       37.5
# 23         idrojasf       37.5
# 25     raulramirezp         75
# 26        tres-iqus       12.5
# 28        fabianr23        100
# 30       jhriverasa       87.5
# 31      jhcardenasa       12.5
# 32       jhonsd1996         75
# 34       JuanitoAli       62.5
# 36       Davsatu313       87.5
# 38   cesarochoa2006       62.5
# 40        jjmuesesq         50
# 42     jucjimenezmo         50
# 44           kancas       62.5
# 46          Gantiva         75
# 48       Dandarprox       62.5
# 50       debeltranc         50
# 52        ykchautai       62.5
# ...

# %%
df2_tech_phase2345 = pd.merge(df2_total_phase3, df2_final_tech_phase2, on='Student', how = 'outer')
df2_tech_phase2345 = df2_tech_phase2345.loc[:, ~df2_tech_phase2345.columns.str.contains('^Unnamed')]
df2_tech_phase2345
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
df2_phase2 = pd.merge(df2_tech_phase2345, df2_final_novelty_phase2, on='Student', how = 'outer')
df2_phase2
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
total2_phase2 = pd.read_csv("../data/total2-phase2.csv")
total2_phase2 = total2_phase2.loc[:, ~total2_phase2.columns.str.contains('^Unnamed')]
total2_phase2
# Out:
#             Student  Total Score
# 0         fabianr23       330.00
# 1   juasmartinezbel       296.67
# 2        JuanitoAli       284.17
# 3        joaortizro       268.33
# 4    cesarochoa2006       255.83
# 5          leguzman       244.17
# 6            kancas       243.33
# 7        Davsatu313       236.67
# 8        jhriverasa       224.17
# 9      raulramirezp       219.17
# 10           Yelis3       211.67
# 11       kmendezp96       210.83
# 12        jjmuesesq       186.67
# 13         idrojasf       168.33
# 14     jusherrerama       161.67
# 15     luealfonsoru       137.50
# 16       Dandarprox       135.83
# 17          Gantiva       133.33
# 18      diegocruz10       128.33
# 19         mdbelloc       125.00
# 20        ykchautai       120.00
# 21       davidrh195       120.00
# 22         luegilca       112.50
# 23       Phoenixest       111.67
# 24         HashNick       108.33
# 25        ligibrial       108.33
# 26        begarzonf       107.50
# ...

# %%
df2_total_phase2 = pd.merge(df2_phase2, total2_phase2, on='Student', how = 'outer')
df2_total_phase2
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase2',
        'Info Viz Score': 'infovis-phase2',
        'Novelty Score': 'novelty-phase2', 
        'Tech Score': 'tech-phase2', 
        'Total Score': 'total-phase2'}
  
# call rename () method
df2_total_phase2.rename(columns=dict,
          inplace=True)

df2_total_phase2
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase2',
        'Info Viz Score': 'infovis-phase2',
        'Novelty Score': 'novelty-phase2', 
        'Tech Score': 'tech-phase2', 
        'Total Score': 'total-phase2'}
  
# call rename () method
df2_total_phase2.rename(columns=dict,
          inplace=True)

df2_total_phase2
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
import pandas as pd 

df2_phase1 = pd.read_csv("../data/Absolute Score Bogota2 Phase1.csv")
df2_phase1
# Out:
#          Project                Hack       Student  \
# 0   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 1   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 2        bdvegat  Bogota-Hack-2-2017       bdvegat
# 3        bdvegat  Bogota-Hack-2-2017       bdvegat
# 4     Phoenixest  Bogota-Hack-2-2017    Phoenixest
# ..           ...                 ...           ...
# 74      oserasoa  Bogota-Hack-2-2017      oserasoa
# 75      lsfinite  Bogota-Hack-2-2017      lsfinite
# 76      lsfinite  Bogota-Hack-2-2017      lsfinite
# 77     xdanielsb  Bogota-Hack-2-2017     xdanielsb
# 78     xdanielsb  Bogota-Hack-2-2017     xdanielsb
#
#                             Grader Name                         Grader Email  \
# 0   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 1     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 2                         tech grader 1              ironhacktech1@gmail.com
# ...

# %%
df2_novelty_phase1 = df2_phase1[df2_phase1['User Requirement'] != "- - -"]
df2_novelty_phase1
# Out:
#             Project                Hack          Student  \
# 1      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 3           bdvegat  Bogota-Hack-2-2017          bdvegat
# 5        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 8           ccvacad  Bogota-Hack-2-2017          ccvacad
# 10     jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 11  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 14         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 16      CSebasGomez  Bogota-Hack-2-2017      CSebasGomez
# 17      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 20       crarojasca  Bogota-Hack-2-2017       crarojasca
# 22           sagilm  Bogota-Hack-2-2017           sagilm
# 23         idrojasf  Bogota-Hack-2-2017         idrojasf
# 26     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 28        tres-iqus  Bogota-Hack-2-2017        tres-iqus
# 29        fabianr23  Bogota-Hack-2-2017        fabianr23
# ...

# %%
df2_final_novelty_phase1 = df2_novelty_phase1[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df2_tech_phase1 = df2_phase1[df2_phase1['Tech Score'] != "- - -"]
df2_tech_phase1
# Out:
#             Project                Hack          Student  \
# 0      jusherrerama  Bogota-Hack-2-2017     jusherrerama
# 2           bdvegat  Bogota-Hack-2-2017          bdvegat
# 4        Phoenixest  Bogota-Hack-2-2017       Phoenixest
# 6          HashNick  Bogota-Hack-2-2017         HashNick
# 7           ccvacad  Bogota-Hack-2-2017          ccvacad
# 9      jscontrerasp  Bogota-Hack-2-2017       joaortizro
# 12  juasmartinezbel  Bogota-Hack-2-2017  juasmartinezbel
# 13         mdbelloc  Bogota-Hack-2-2017         mdbelloc
# 15      CSebasGomez  Bogota-Hack-2-2017      CSebasGomez
# 18      diegocruz10  Bogota-Hack-2-2017      diegocruz10
# 19       crarojasca  Bogota-Hack-2-2017       crarojasca
# 21           sagilm  Bogota-Hack-2-2017           sagilm
# 24         idrojasf  Bogota-Hack-2-2017         idrojasf
# 25     raulramirezp  Bogota-Hack-2-2017     raulramirezp
# 27        tres-iqus  Bogota-Hack-2-2017        tres-iqus
# ...

# %%
df2_tech_phase1[['Student', 'Tech Score']]
# Out:
#             Student Tech Score
# 0      jusherrerama         25
# 2           bdvegat          0
# 4        Phoenixest          0
# 6          HashNick          0
# 7           ccvacad          0
# 9        joaortizro       62.5
# 12  juasmartinezbel         75
# 13         mdbelloc       37.5
# 15      CSebasGomez          0
# 18      diegocruz10         25
# 19       crarojasca          0
# 21           sagilm         25
# 24         idrojasf       62.5
# 25     raulramirezp          0
# 27        tres-iqus          0
# 30        fabianr23         50
# 31       jhriverasa         50
# 33      jhcardenasa          0
# 35       jhonsd1996         50
# 36       JuanitoAli         75
# 39       Davsatu313       62.5
# 40   cesarochoa2006       37.5
# 42        jjmuesesq       37.5
# 44     jucjimenezmo       12.5
# 45           kancas       37.5
# 49          Gantiva         50
# 50       Dandarprox       12.5
# 53       debeltranc         75
# 54        ykchautai         50
# ...

# %%
df2_final_tech_phase1 = df2_tech_phase1[['Student', 'Tech Score']]
df2_final_tech_phase1
# Out:
#             Student Tech Score
# 0      jusherrerama         25
# 2           bdvegat          0
# 4        Phoenixest          0
# 6          HashNick          0
# 7           ccvacad          0
# 9        joaortizro       62.5
# 12  juasmartinezbel         75
# 13         mdbelloc       37.5
# 15      CSebasGomez          0
# 18      diegocruz10         25
# 19       crarojasca          0
# 21           sagilm         25
# 24         idrojasf       62.5
# 25     raulramirezp          0
# 27        tres-iqus          0
# 30        fabianr23         50
# 31       jhriverasa         50
# 33      jhcardenasa          0
# 35       jhonsd1996         50
# 36       JuanitoAli         75
# 39       Davsatu313       62.5
# 40   cesarochoa2006       37.5
# 42        jjmuesesq       37.5
# 44     jucjimenezmo       12.5
# 45           kancas       37.5
# 49          Gantiva         50
# 50       Dandarprox       12.5
# 53       debeltranc         75
# 54        ykchautai         50
# ...

# %%
df2_tech_phase12345 = pd.merge(df2_total_phase2, df2_final_tech_phase1, on='Student', how = 'outer')
df2_tech_phase12345 = df2_tech_phase12345.loc[:, ~df2_tech_phase12345.columns.str.contains('^Unnamed')]
df2_tech_phase12345
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
df2_phase1 = pd.merge(df2_tech_phase12345, df2_final_novelty_phase1, on='Student', how = 'outer')
df2_phase1
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
total2_phase1 = pd.read_csv("../data/total2-phase1.csv")
total2_phase1 = total2_phase1.loc[:, ~total2_phase1.columns.str.contains('^Unnamed')]
total2_phase1
# Out:
#             Student  Total Score
# 0         xdanielsb       260.00
# 1   juasmartinezbel       251.67
# 2            Yelis3       231.67
# 3          idrojasf       207.50
# 4        Davsatu313       207.50
# 5         fabianr23       205.00
# 6        kmendezp96       185.83
# 7        debeltranc       162.50
# 8         ykchautai       161.67
# 9         begarzonf       157.50
# 10     luealfonsoru       154.17
# 11         leguzman       153.33
# 12       jhriverasa       142.92
# 13        ligibrial       133.33
# 14         luegilca       129.17
# 15          Gantiva       115.83
# 16       joaortizro       107.50
# 17       Dandarprox       105.42
# 18       JuanitoAli       100.00
# 19       jhonsd1996       100.00
# 20         mdbelloc        91.67
# 21      diegocruz10        90.83
# 22   cesarochoa2006        86.67
# 23     jusherrerama        82.50
# 24        jjmuesesq        82.50
# 25       Phoenixest        74.17
# 26         lsfinite        62.50
# ...

# %%
df2_total_phase1 = pd.merge(df2_phase1, total2_phase1, on='Student', how = 'outer')
df2_total_phase1
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase1',
        'Info Viz Score': 'infovis-phase1',
        'Novelty Score': 'novelty-phase1', 
        'Tech Score': 'tech-phase1', 
        'Total Score': 'total-phase1'}
  
# call rename () method
df2_total_phase1.rename(columns=dict,
          inplace=True)

df2_total_phase1
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
df2_total_phase1.fillna(0)
# Out:
#             Student  Group user-requirement-phase5 infovis-phase5  \
# 0      jusherrerama      2                      20             25
# 1           bdvegat      2                      20             25
# 2        Phoenixest      2                       0             25
# 3          HashNick      2                      40             50
# 4           ccvacad      2                      80          66.67
# 5        joaortizro      2                     100             50
# 6   juasmartinezbel      2                     100             75
# 7          mdbelloc      2                       0           37.5
# 8       diegocruz10      2                      20          45.83
# 9        crarojasca      2                      20             25
# 10           sagilm      2                      20          33.33
# 11         idrojasf      2                      20             50
# 12     raulramirezp      2                      60          45.83
# ...

# %%
df2_total_phase1.fillna(0)
df2_total_phase1.to_csv('Bogota-2-Scores.csv')
