# %% [markdown]
# # Bogota 0 Phase 5

# %%
import pandas as pd 

df0_phase5 = pd.read_csv("../data/Absolute Score Bogota0 Phase 5.csv")
df0_phase5
# Out:
#          Project                Hack       Student  \
# 0      fffeelipe  Bogota-Hack-0-2017     fffeelipe
# 1      fffeelipe  Bogota-Hack-0-2017     fffeelipe
# 2      mnguzmanc  Bogota-Hack-0-2017     mnguzmanc
# 3      mnguzmanc  Bogota-Hack-0-2017     mnguzmanc
# 4         annipi  Bogota-Hack-0-2017        annipi
# ..           ...                 ...           ...
# 65  lfvalderrama  Bogota-Hack-0-2017  lfvalderrama
# 66     bsgarciac  Bogota-Hack-0-2017     bsgarciac
# 67     bsgarciac  Bogota-Hack-0-2017     bsgarciac
# 68        gabi04  Bogota-Hack-0-2017        gabi04
# 69        gabi04  Bogota-Hack-0-2017        gabi04
#
#                             Grader Name                         Grader Email  \
# 0                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# 1   purdueironhack+techjudge1@gmail.com  purdueironhack+techjudge1@gmail.com
# 2     purdueironhack+uxjudge7@gmail.com    purdueironhack+uxjudge7@gmail.com
# ...

# %%
df0_novelty_phase5 = df0_phase5[df0_phase5['User Requirement'] != "- - -"]
df0_novelty_phase5
# Out:
#            Project                Hack         Student  \
# 0        fffeelipe  Bogota-Hack-0-2017       fffeelipe
# 2        mnguzmanc  Bogota-Hack-0-2017       mnguzmanc
# 5       jmcuestasb  Bogota-Hack-0-2017      jmcuestasb
# 7       katherinsb  Bogota-Hack-0-2017      katherinsb
# 9     jjrodriguezn  Bogota-Hack-0-2017    jjrodriguezn
# 11           DglyP  Bogota-Hack-0-2017           DglyP
# 16          cap182  Bogota-Hack-0-2017          cap182
# 20     annumunozme  Bogota-Hack-0-2017     annumumozme
# 21     Judgarciani  Bogota-Hack-0-2017     Judgarciani
# 23       sacastroc  Bogota-Hack-0-2017       sacastroc
# 25       pcberriop  Bogota-Hack-0-2017       pcberriop
# 27     hsmartineza  Bogota-Hack-0-2017     hsmartineza
# 29        Moimolcp  Bogota-Hack-0-2017        Moimolcp
# 31     CamiloRueda  Bogota-Hack-0-2017     CamiloRueda
# 33       juanescai  Bogota-Hack-0-2017       juanescai
# 35      JoseMolano  Bogota-Hack-0-2017      JoseMolano
# ...

# %%
df0_final_novelty_phase5 = df0_novelty_phase5[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df0_tech_phase5 = df0_phase5[df0_phase5['Tech Score'] != "- - -"]
df0_tech_phase5
# Out:
#            Project                Hack         Student  \
# 1        fffeelipe  Bogota-Hack-0-2017       fffeelipe
# 3        mnguzmanc  Bogota-Hack-0-2017       mnguzmanc
# 4           annipi  Bogota-Hack-0-2017          annipi
# 6       jmcuestasb  Bogota-Hack-0-2017      jmcuestasb
# 8       katherinsb  Bogota-Hack-0-2017      katherinsb
# 10    jjrodriguezn  Bogota-Hack-0-2017    jjrodriguezn
# 12           DglyP  Bogota-Hack-0-2017           DglyP
# 13       jdsolanos  Bogota-Hack-0-2017       jdsolanos
# 14        jcneivaa  Bogota-Hack-0-2017        jcneivaa
# 15       fmbernalb  Bogota-Hack-0-2017       fmbernalb
# 17          cap182  Bogota-Hack-0-2017          cap182
# 18         MogGy94  Bogota-Hack-0-2017         MogGy94
# 19     annumunozme  Bogota-Hack-0-2017     annumumozme
# 22     Judgarciani  Bogota-Hack-0-2017     Judgarciani
# 24       sacastroc  Bogota-Hack-0-2017       sacastroc
# 26       pcberriop  Bogota-Hack-0-2017       pcberriop
# ...

# %%
df0_tech_phase5[['Student', 'Tech Score']]
# Out:
#            Student Tech Score
# 1        fffeelipe        100
# 3        mnguzmanc       87.5
# 4           annipi          0
# 6       jmcuestasb         75
# 8       katherinsb       62.5
# 10    jjrodriguezn         50
# 12           DglyP        100
# 13       jdsolanos          0
# 14        jcneivaa          0
# 15       fmbernalb          0
# 17          cap182          0
# 18         MogGy94          0
# 19     annumumozme        100
# 22     Judgarciani        100
# 24       sacastroc       87.5
# 26       pcberriop         75
# 28     hsmartineza         75
# 30        Moimolcp         75
# 32     CamiloRueda         25
# 34       juanescai          0
# 36      JoseMolano         75
# 38   maikellPardoA         25
# 40      NicolasZon       37.5
# 42       camilo654         75
# 44  CristianLozano       37.5
# 46       jdsuarezj         75
# 47       odprietoh          0
# 49       pipemax85       62.5
# 51     juandavidro         50
# 53  UNhcrodriguezl         75
# ...

# %%
df0_tech_phase5[~df0_tech_phase5['Student'].str.contains('Ironhack')]
# Out:
#            Project                Hack         Student  \
# 1        fffeelipe  Bogota-Hack-0-2017       fffeelipe
# 3        mnguzmanc  Bogota-Hack-0-2017       mnguzmanc
# 4           annipi  Bogota-Hack-0-2017          annipi
# 6       jmcuestasb  Bogota-Hack-0-2017      jmcuestasb
# 8       katherinsb  Bogota-Hack-0-2017      katherinsb
# 10    jjrodriguezn  Bogota-Hack-0-2017    jjrodriguezn
# 12           DglyP  Bogota-Hack-0-2017           DglyP
# 13       jdsolanos  Bogota-Hack-0-2017       jdsolanos
# 14        jcneivaa  Bogota-Hack-0-2017        jcneivaa
# 15       fmbernalb  Bogota-Hack-0-2017       fmbernalb
# 17          cap182  Bogota-Hack-0-2017          cap182
# 18         MogGy94  Bogota-Hack-0-2017         MogGy94
# 19     annumunozme  Bogota-Hack-0-2017     annumumozme
# 22     Judgarciani  Bogota-Hack-0-2017     Judgarciani
# 24       sacastroc  Bogota-Hack-0-2017       sacastroc
# 26       pcberriop  Bogota-Hack-0-2017       pcberriop
# ...

# %%
df0_final_tech_phase5 = df0_tech_phase5[['Student', 'Tech Score']]
df0_final_tech_phase5
# Out:
#            Student Tech Score
# 1        fffeelipe        100
# 3        mnguzmanc       87.5
# 4           annipi          0
# 6       jmcuestasb         75
# 8       katherinsb       62.5
# 10    jjrodriguezn         50
# 12           DglyP        100
# 13       jdsolanos          0
# 14        jcneivaa          0
# 15       fmbernalb          0
# 17          cap182          0
# 18         MogGy94          0
# 19     annumumozme        100
# 22     Judgarciani        100
# 24       sacastroc       87.5
# 26       pcberriop         75
# 28     hsmartineza         75
# 30        Moimolcp         75
# 32     CamiloRueda         25
# 34       juanescai          0
# 36      JoseMolano         75
# 38   maikellPardoA         25
# 40      NicolasZon       37.5
# 42       camilo654         75
# 44  CristianLozano       37.5
# 46       jdsuarezj         75
# 47       odprietoh          0
# 49       pipemax85       62.5
# 51     juandavidro         50
# 53  UNhcrodriguezl         75
# ...

# %%
bogota0 = pd.read_csv('../data/bogota-0.csv')
bogota0
# Out:
#            Student  Unnamed: 1  Unnamed: 2  Total Score  Unnamed: 4  \
# 0     lfvalderrama         NaN         NaN       352.92         NaN
# 1      Judgarciani         NaN         NaN       325.00         NaN
# 2        bsgarciac         NaN         NaN       320.83         NaN
# 3         Moimolcp         NaN         NaN       304.17         NaN
# 4        mnguzmanc         NaN         NaN       290.00         NaN
# 5       JoseMolano         NaN         NaN       276.67         NaN
# 6        jdsuarezj         NaN         NaN       272.50         NaN
# 7       capinillab         NaN         NaN       264.17         NaN
# 8   UNhcrodriguezl         NaN         NaN       263.33         NaN
# 9     jjrodriguezn         NaN         NaN       255.83         NaN
# 10      jmcuestasb         NaN         NaN       254.17         NaN
# 11     annumumozme         NaN         NaN       237.50         NaN
# 12       sacastroc         NaN         NaN       226.25         NaN
# ...

# %%
df0_final_tech_phase5 = pd.merge(bogota0, df0_final_tech_phase5, on='Student', how = 'outer')
df0_final_tech_phase5 = df0_final_tech_phase5.loc[:, ~df0_final_tech_phase5.columns.str.contains('^Unnamed')]
df0_final_tech_phase5
# Out:
#            Student  Total Score Tech Score
# 0     lfvalderrama       352.92        100
# 1      Judgarciani       325.00        100
# 2        bsgarciac       320.83        100
# 3         Moimolcp       304.17         75
# 4        mnguzmanc       290.00       87.5
# 5       JoseMolano       276.67         75
# 6        jdsuarezj       272.50         75
# 7       capinillab       264.17         75
# 8   UNhcrodriguezl       263.33         75
# 9     jjrodriguezn       255.83         50
# 10      jmcuestasb       254.17         75
# 11     annumumozme       237.50        100
# 12       sacastroc       226.25       87.5
# 13     camilo13152       222.50         75
# 14    leavendanoro       206.67         75
# 15       fffeelipe       199.17        100
# 16       camilo654       199.17         75
# 17           DglyP       195.00        100
# 18       pcberriop       195.00         75
# 19      cdcordobaa       190.83         75
# 20     hsmartineza       180.83         75
# ...

# %%
df0_phase5 = pd.merge(df0_final_novelty_phase5, df0_final_tech_phase5, on='Student', how = 'outer')
df0_phase5
# Out:
#            Student User Requirement Info Viz Score Novelty Score  Total Score  \
# 0        fffeelipe               20          29.17            50       199.17
# 1        mnguzmanc               60             75          67.5       290.00
# 2       jmcuestasb              100          54.17            25       254.17
# 3       katherinsb               20           37.5         16.67       136.67
# 4     jjrodriguezn               60          58.33          87.5       255.83
# 5            DglyP               20             25            50       195.00
# 6           cap182               20          29.17             0        49.17
# 7      annumumozme               40           37.5            60       237.50
# 8      Judgarciani              100          58.33         66.67       325.00
# 9        sacastroc               20             50         68.75       226.25
# 10       pcberriop               20           37.5          62.5       195.00
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase5',
        'Info Viz Score': 'infovis-phase5',
        'Novelty Score': 'novelty-phase5', 
        'Tech Score': 'tech-phase5', 
        'Total Score': 'total-phase5'}
  
# call rename () method
df0_phase5.rename(columns=dict,
          inplace=True)

df0_phase5
# Out:
#            Student user-requirement-phase5 infovis-phase5 novelty-phase5  \
# 0        fffeelipe                      20          29.17             50
# 1        mnguzmanc                      60             75           67.5
# 2       jmcuestasb                     100          54.17             25
# 3       katherinsb                      20           37.5          16.67
# 4     jjrodriguezn                      60          58.33           87.5
# 5            DglyP                      20             25             50
# 6           cap182                      20          29.17              0
# 7      annumumozme                      40           37.5             60
# 8      Judgarciani                     100          58.33          66.67
# 9        sacastroc                      20             50          68.75
# 10       pcberriop                      20           37.5           62.5
# 11     hsmartineza                      20          33.33           52.5
# ...

# %%
df0_phase5.insert (1, "Group", 0)
df0_phase5 = df0_phase5.fillna(0)
df0_phase5
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...

# %%
import pandas as pd 

df0_phase4 = pd.read_csv("../data/Absolute Score Bogota0 Phase 4.csv")
df0_phase4
# Out:
#          Project                Hack       Student  \
# 0      fffeelipe  Bogota-Hack-0-2017     fffeelipe
# 1      fffeelipe  Bogota-Hack-0-2017     fffeelipe
# 2      mnguzmanc  Bogota-Hack-0-2017     mnguzmanc
# 3      mnguzmanc  Bogota-Hack-0-2017     mnguzmanc
# 4     jmcuestasb  Bogota-Hack-0-2017    jmcuestasb
# ..           ...                 ...           ...
# 64  lfvalderrama  Bogota-Hack-0-2017  lfvalderrama
# 65     bsgarciac  Bogota-Hack-0-2017     bsgarciac
# 66     bsgarciac  Bogota-Hack-0-2017     bsgarciac
# 67        gabi04  Bogota-Hack-0-2017        gabi04
# 68        gabi04  Bogota-Hack-0-2017        gabi04
#
#                             Grader Name                         Grader Email  \
# 0                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# 1   purdueironhack+techjudge1@gmail.com  purdueironhack+techjudge1@gmail.com
# 2     purdueironhack+uxjudge7@gmail.com    purdueironhack+uxjudge7@gmail.com
# ...

# %%
df0_novelty_phase4 = df0_phase4[df0_phase4['User Requirement'] != "- - -"]
df0_novelty_phase4
# Out:
#            Project                Hack         Student  \
# 0        fffeelipe  Bogota-Hack-0-2017       fffeelipe
# 2        mnguzmanc  Bogota-Hack-0-2017       mnguzmanc
# 4       jmcuestasb  Bogota-Hack-0-2017      jmcuestasb
# 6       katherinsb  Bogota-Hack-0-2017      katherinsb
# 8     jjrodriguezn  Bogota-Hack-0-2017    jjrodriguezn
# 10           DglyP  Bogota-Hack-0-2017           DglyP
# 15          cap182  Bogota-Hack-0-2017          cap182
# 19     annumunozme  Bogota-Hack-0-2017     annumumozme
# 20     Judgarciani  Bogota-Hack-0-2017     Judgarciani
# 22       sacastroc  Bogota-Hack-0-2017       sacastroc
# 24       pcberriop  Bogota-Hack-0-2017       pcberriop
# 26     hsmartineza  Bogota-Hack-0-2017     hsmartineza
# 29        Moimolcp  Bogota-Hack-0-2017        Moimolcp
# 31     CamiloRueda  Bogota-Hack-0-2017     CamiloRueda
# 33       juanescai  Bogota-Hack-0-2017       juanescai
# 35      JoseMolano  Bogota-Hack-0-2017      JoseMolano
# ...

# %%
df0_final_novelty_phase4 = df0_novelty_phase4[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df0_tech_phase4 = df0_phase4[df0_phase4['Tech Score'] != "- - -"]
df0_tech_phase4
# Out:
#            Project                Hack         Student  \
# 1        fffeelipe  Bogota-Hack-0-2017       fffeelipe
# 3        mnguzmanc  Bogota-Hack-0-2017       mnguzmanc
# 5       jmcuestasb  Bogota-Hack-0-2017      jmcuestasb
# 7       katherinsb  Bogota-Hack-0-2017      katherinsb
# 9     jjrodriguezn  Bogota-Hack-0-2017    jjrodriguezn
# 11           DglyP  Bogota-Hack-0-2017           DglyP
# 12       jdsolanos  Bogota-Hack-0-2017       jdsolanos
# 13        jcneivaa  Bogota-Hack-0-2017        jcneivaa
# 14       fmbernalb  Bogota-Hack-0-2017       fmbernalb
# 16          cap182  Bogota-Hack-0-2017          cap182
# 17         MogGy94  Bogota-Hack-0-2017         MogGy94
# 18     annumunozme  Bogota-Hack-0-2017     annumumozme
# 21     Judgarciani  Bogota-Hack-0-2017     Judgarciani
# 23       sacastroc  Bogota-Hack-0-2017       sacastroc
# 25       pcberriop  Bogota-Hack-0-2017       pcberriop
# 27     hsmartineza  Bogota-Hack-0-2017     hsmartineza
# ...

# %%
df0_tech_phase4[['Student', 'Tech Score']]
# Out:
#            Student Tech Score
# 1        fffeelipe        100
# 3        mnguzmanc       87.5
# 5       jmcuestasb       62.5
# 7       katherinsb       37.5
# 9     jjrodriguezn       37.5
# 11           DglyP       87.5
# 12       jdsolanos          0
# 13        jcneivaa          0
# 14       fmbernalb          0
# 16          cap182          0
# 17         MogGy94          0
# 18     annumumozme         75
# 21     Judgarciani         75
# 23       sacastroc       87.5
# 25       pcberriop         50
# 27     hsmartineza       62.5
# 28       yocuervoc          0
# 30        Moimolcp       62.5
# 32     CamiloRueda         25
# 34       juanescai          0
# 36      JoseMolano       87.5
# 37   maikellPardoA         25
# 39      NicolasZon       37.5
# 41       camilo654         75
# 43  CristianLozano       37.5
# 45       jdsuarezj         75
# 46       odprietoh          0
# 47       pipemax85         50
# 50     juandavidro       37.5
# 52  UNhcrodriguezl         75
# ...

# %%
df0_final_tech_phase4 = df0_tech_phase4[['Student', 'Tech Score']]
df0_final_tech_phase4
# Out:
#            Student Tech Score
# 1        fffeelipe        100
# 3        mnguzmanc       87.5
# 5       jmcuestasb       62.5
# 7       katherinsb       37.5
# 9     jjrodriguezn       37.5
# 11           DglyP       87.5
# 12       jdsolanos          0
# 13        jcneivaa          0
# 14       fmbernalb          0
# 16          cap182          0
# 17         MogGy94          0
# 18     annumumozme         75
# 21     Judgarciani         75
# 23       sacastroc       87.5
# 25       pcberriop         50
# 27     hsmartineza       62.5
# 28       yocuervoc          0
# 30        Moimolcp       62.5
# 32     CamiloRueda         25
# 34       juanescai          0
# 36      JoseMolano       87.5
# 37   maikellPardoA         25
# 39      NicolasZon       37.5
# 41       camilo654         75
# 43  CristianLozano       37.5
# 45       jdsuarezj         75
# 46       odprietoh          0
# 47       pipemax85         50
# 50     juandavidro       37.5
# 52  UNhcrodriguezl         75
# ...

# %%
df0_tech_phase45 = pd.merge(df0_phase5, df0_final_tech_phase4, on='Student', how = 'outer')
df0_tech_phase45
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...

# %%
df0_phase45 = pd.merge(df0_tech_phase45, df0_final_novelty_phase4, on='Student', how = 'outer')
df0_phase45
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...

# %%
total0_phase4 = pd.read_csv("../data/total0-phase4.csv")
total0_phase4 = total0_phase4.loc[:, ~total0_phase4.columns.str.contains('^Unnamed')]
total0_phase4
# Out:
#            Student  Total Score
# 0        bsgarciac       313.33
# 1        jdsuarezj       276.67
# 2       capinillab       251.67
# 3        mnguzmanc       245.00
# 4        camilo654       243.33
# 5      camilo13152       243.33
# 6      Judgarciani       242.50
# 7       jmcuestasb       220.83
# 8        sacastroc       220.00
# 9       JoseMolano       216.67
# 10  UNhcrodriguezl       215.83
# 11    lfvalderrama       207.50
# 12       fffeelipe       192.92
# 13      cdcordobaa       190.83
# 14     hsmartineza       176.25
# 15       pcberriop       165.83
# 16           DglyP       162.50
# 17  CristianLozano       147.50
# 18    jjrodriguezn       131.67
# 19      katherinsb       128.33
# 20    leavendanoro       125.00
# 21        Moimolcp       120.83
# 22     juandavidro       111.67
# 23       pipemax85       103.33
# 24      Januguerab        99.17
# 25      NicolasZon        87.50
# 26          gabi04        74.17
# 27     CamiloRueda        70.00
# ...

# %%
df0_total_phase45 = pd.merge(df0_phase45, total0_phase4, on='Student', how = 'outer')
df0_total_phase45
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase4',
        'Info Viz Score': 'infovis-phase4',
        'Novelty Score': 'novelty-phase4', 
        'Tech Score': 'tech-phase4', 
        'Total Score': 'total-phase4'}
  
# call rename () method
df0_total_phase45.rename(columns=dict,
          inplace=True)

df0_total_phase45
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...

# %%
import pandas as pd 

df0_phase3 = pd.read_csv("../data/Absolute Score Bogota0 Phase 3.csv")
df0_phase3
# Out:
#          Project                Hack       Student  \
# 0      fffeelipe  Bogota-Hack-0-2017     fffeelipe
# 1      fffeelipe  Bogota-Hack-0-2017     fffeelipe
# 2      mnguzmanc  Bogota-Hack-0-2017     mnguzmanc
# 3      mnguzmanc  Bogota-Hack-0-2017     mnguzmanc
# 4         annipi  Bogota-Hack-0-2017        annipi
# ..           ...                 ...           ...
# 65  lfvalderrama  Bogota-Hack-0-2017  lfvalderrama
# 66     bsgarciac  Bogota-Hack-0-2017     bsgarciac
# 67     bsgarciac  Bogota-Hack-0-2017     bsgarciac
# 68        gabi04  Bogota-Hack-0-2017        gabi04
# 69        gabi04  Bogota-Hack-0-2017        gabi04
#
#                             Grader Name                         Grader Email  \
# 0                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# 1   purdueironhack+techjudge1@gmail.com  purdueironhack+techjudge1@gmail.com
# 2     purdueironhack+uxjudge7@gmail.com    purdueironhack+uxjudge7@gmail.com
# ...

# %%
df0_novelty_phase3 = df0_phase3[df0_phase3['User Requirement'] != "- - -"]
df0_novelty_phase3
# Out:
#            Project                Hack         Student  \
# 0        fffeelipe  Bogota-Hack-0-2017       fffeelipe
# 2        mnguzmanc  Bogota-Hack-0-2017       mnguzmanc
# 5       jmcuestasb  Bogota-Hack-0-2017      jmcuestasb
# 8     jjrodriguezn  Bogota-Hack-0-2017    jjrodriguezn
# 10           DglyP  Bogota-Hack-0-2017           DglyP
# 15          cap182  Bogota-Hack-0-2017          cap182
# 19     annumunozme  Bogota-Hack-0-2017     annumumozme
# 20     Judgarciani  Bogota-Hack-0-2017     Judgarciani
# 22       sacastroc  Bogota-Hack-0-2017       sacastroc
# 24       pcberriop  Bogota-Hack-0-2017       pcberriop
# 26     hsmartineza  Bogota-Hack-0-2017     hsmartineza
# 29        Moimolcp  Bogota-Hack-0-2017        Moimolcp
# 31     CamiloRueda  Bogota-Hack-0-2017     CamiloRueda
# 33       juanescai  Bogota-Hack-0-2017       juanescai
# 35      JoseMolano  Bogota-Hack-0-2017      JoseMolano
# 37   maikellPardoA  Bogota-Hack-0-2017   maikellPardoA
# ...

# %%
df0_final_novelty_phase3 = df0_novelty_phase3[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df0_tech_phase3 = df0_phase3[df0_phase3['Tech Score'] != "- - -"]
df0_tech_phase3
# Out:
#            Project                Hack         Student  \
# 1        fffeelipe  Bogota-Hack-0-2017       fffeelipe
# 3        mnguzmanc  Bogota-Hack-0-2017       mnguzmanc
# 4           annipi  Bogota-Hack-0-2017          annipi
# 6       jmcuestasb  Bogota-Hack-0-2017      jmcuestasb
# 7       katherinsb  Bogota-Hack-0-2017      katherinsb
# 9     jjrodriguezn  Bogota-Hack-0-2017    jjrodriguezn
# 11           DglyP  Bogota-Hack-0-2017           DglyP
# 12       jdsolanos  Bogota-Hack-0-2017       jdsolanos
# 13        jcneivaa  Bogota-Hack-0-2017        jcneivaa
# 14       fmbernalb  Bogota-Hack-0-2017       fmbernalb
# 16          cap182  Bogota-Hack-0-2017          cap182
# 17         MogGy94  Bogota-Hack-0-2017         MogGy94
# 18     annumunozme  Bogota-Hack-0-2017     annumumozme
# 21     Judgarciani  Bogota-Hack-0-2017     Judgarciani
# 23       sacastroc  Bogota-Hack-0-2017       sacastroc
# 25       pcberriop  Bogota-Hack-0-2017       pcberriop
# ...

# %%
df0_tech_phase3[['Student', 'Tech Score']]
# Out:
#            Student Tech Score
# 1        fffeelipe         75
# 3        mnguzmanc        100
# 4           annipi          0
# 6       jmcuestasb       62.5
# 7       katherinsb          0
# 9     jjrodriguezn       37.5
# 11           DglyP         50
# 12       jdsolanos          0
# 13        jcneivaa          0
# 14       fmbernalb          0
# 16          cap182          0
# 17         MogGy94          0
# 18     annumumozme       62.5
# 21     Judgarciani       62.5
# 23       sacastroc        100
# 25       pcberriop         50
# 27     hsmartineza         50
# 28       yocuervoc          0
# 30        Moimolcp       62.5
# 32     CamiloRueda         25
# 34       juanescai          0
# 36      JoseMolano       87.5
# 38   maikellPardoA         25
# 40      NicolasZon       37.5
# 42       camilo654         50
# 44  CristianLozano       37.5
# 46       jdsuarezj         75
# 47       odprietoh          0
# 49       pipemax85         50
# 51     juandavidro       37.5
# ...

# %%
df0_final_tech_phase3 = df0_tech_phase3[['Student', 'Tech Score']]
df0_final_tech_phase3
# Out:
#            Student Tech Score
# 1        fffeelipe         75
# 3        mnguzmanc        100
# 4           annipi          0
# 6       jmcuestasb       62.5
# 7       katherinsb          0
# 9     jjrodriguezn       37.5
# 11           DglyP         50
# 12       jdsolanos          0
# 13        jcneivaa          0
# 14       fmbernalb          0
# 16          cap182          0
# 17         MogGy94          0
# 18     annumumozme       62.5
# 21     Judgarciani       62.5
# 23       sacastroc        100
# 25       pcberriop         50
# 27     hsmartineza         50
# 28       yocuervoc          0
# 30        Moimolcp       62.5
# 32     CamiloRueda         25
# 34       juanescai          0
# 36      JoseMolano       87.5
# 38   maikellPardoA         25
# 40      NicolasZon       37.5
# 42       camilo654         50
# 44  CristianLozano       37.5
# 46       jdsuarezj         75
# 47       odprietoh          0
# 49       pipemax85         50
# 51     juandavidro       37.5
# ...

# %%
df0_tech_phase345 = pd.merge(df0_total_phase45, df0_final_tech_phase3, on='Student', how = 'outer')
df0_tech_phase345 = df0_tech_phase345.loc[:, ~df0_tech_phase345.columns.str.contains('^Unnamed')]
df0_tech_phase345
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...

# %%
df0_phase3 = pd.merge(df0_tech_phase345, df0_final_novelty_phase3, on='Student', how = 'outer')
df0_phase3
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...

# %%
total0_phase3 = pd.read_csv("../data/total0-phase3.csv")
total0_phase3 = total0_phase3.loc[:, ~total0_phase3.columns.str.contains('^Unnamed')]
total0_phase3
# Out:
#            Student  Total Score
# 0        jdsuarezj       293.33
# 1       JoseMolano       289.17
# 2        bsgarciac       272.50
# 3     lfvalderrama       250.42
# 4        mnguzmanc       236.67
# 5      hsmartineza       230.83
# 6       capinillab       226.67
# 7      Judgarciani       221.67
# 8      camilo13152       218.33
# 9        sacastroc       215.83
# 10  UNhcrodriguezl       190.83
# 11      cdcordobaa       190.83
# 12     juandavidro       175.83
# 13       fffeelipe       172.50
# 14        Moimolcp       170.00
# 15       pcberriop       165.83
# 16       camilo654       161.67
# 17           DglyP       140.00
# 18      jmcuestasb       132.50
# 19    leavendanoro       112.50
# 20    jjrodriguezn       103.33
# 21       pipemax85       103.33
# 22      Januguerab        99.17
# 23      NicolasZon        87.50
# 24  CristianLozano        86.67
# 25   maikellPardoA        83.33
# 26          gabi04        74.17
# 27       juanescai        61.67
# ...

# %%
df0_total_phase3 = pd.merge(df0_phase3, total0_phase3, on='Student', how = 'outer')
df0_total_phase3
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase3',
        'Info Viz Score': 'infovis-phase3',
        'Novelty Score': 'novelty-phase3', 
        'Tech Score': 'tech-phase3', 
        'Total Score': 'total-phase3'}
  
# call rename () method
df0_total_phase3.rename(columns=dict,
          inplace=True)

df0_total_phase3
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        fffeelipe      0                      20          29.17
# 1        mnguzmanc      0                      60             75
# 2       jmcuestasb      0                     100          54.17
# 3       katherinsb      0                      20           37.5
# 4     jjrodriguezn      0                      60          58.33
# 5            DglyP      0                      20             25
# 6           cap182      0                      20          29.17
# 7      annumumozme      0                      40           37.5
# 8      Judgarciani      0                     100          58.33
# 9        sacastroc      0                      20             50
# 10       pcberriop      0                      20           37.5
# 11     hsmartineza      0                      20          33.33
# 12        Moimolcp      0                     100           62.5
# ...
