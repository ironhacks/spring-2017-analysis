# %%
import pandas as pd


df = pd.read_csv('pre-survey.csv')
df
# Out:
#             StartDate           EndDate      Status       IPAddress  Progress  \
# 0    31/01/2017 10:27  31/01/2017 10:30  IP Address   79.113.30.240       100
# 1    02/02/2017 10:13  02/02/2017 10:14  IP Address   79.113.17.219       100
# 2    04/02/2017 21:06  04/02/2017 21:08  IP Address  213.233.84.222       100
# 3     06/02/2017 0:45   06/02/2017 0:55  IP Address  98.226.144.140       100
# 4    08/02/2017 22:08  08/02/2017 22:10  IP Address  128.210.107.73       100
# ..                ...               ...         ...             ...       ...
# 225  14/04/2017 11:42  14/04/2017 11:43  IP Address  128.210.106.57       100
# 226  14/04/2017 11:45  14/04/2017 11:47  IP Address  128.210.106.57       100
# 227  14/04/2017 22:29  14/04/2017 22:31  IP Address  50.100.240.252       100
# 228  17/04/2017 21:38  17/04/2017 21:55  IP Address   190.156.15.34       100
# 229   26/04/2017 9:59  26/04/2017 10:28  IP Address    170.238.64.4       100
#
#      Duration (in seconds)  Finished      RecordedDate         ResponseId  \
# 0                      179      True  31/01/2017 10:30  R_2B9UmcRqC3K1exx
# 1                       95      True  02/02/2017 10:14  R_ehdVXMehOMMche9
# 2                      106      True  04/02/2017 21:08  R_110dynGvJLLAoTi
# 3                      615      True   06/02/2017 0:55  R_3Jl2OxPSP4uOMHd
# 4                      102      True  08/02/2017 22:10  R_1FQxjH4qlLXGZBK
# ..                     ...       ...               ...                ...
# 225                     80      True  14/04/2017 11:43  R_3sz7gRMw2GBzcdT
# 226                     75      True  14/04/2017 11:47  R_UZbp1luN5lJPDm9
# 227                    133      True  14/04/2017 22:31  R_1MRHD4ivzMfimrM
# 228                   1001      True  17/04/2017 21:55  R_1mXfaS86upbVd2K
# 229                   1739      True  26/04/2017 10:28  R_2SlgBdU4E6drL4F
#
#      RecipientLastName  ...     Q12   Q13   Q14  \
# 0                  NaN  ...  1000.0  45.0  40.0
# 1                  NaN  ...    43.0  32.0  42.0
# 2                  NaN  ...    23.0  12.0  24.0
# 3                  NaN  ...    34.0   3.0   3.0
# 4                  NaN  ...   100.0   2.0   3.0
# ..                 ...  ...     ...   ...   ...
# 225                NaN  ...     1.0   1.0   1.0
# 226                NaN  ...     1.0   1.0   1.0
# 227                NaN  ...    23.0  11.0  11.0
# 228                NaN  ...     0.0   5.0   2.0
# 229                NaN  ...     1.0   3.0  15.0
#
#                                                    Q24  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 225  Ingeniería de software I, Group 1, Yury Niño, ...
# 226  Ingeniería de software II, Group 2, Camilo Del...
# 227  Ingeniería de software I, Group 1, Yury Niño, ...
# 228                                                NaN
# 229                                                NaN
#
#                     Q24_8_TEXT     Q17                     Q18 Q18_7_TEXT  \
# 0                          NaN    Male   Prefer not to respond        NaN
# 1                          NaN    Male   Prefer not to respond        NaN
# 2                          NaN    Male   Prefer not to respond        NaN
# 3                          NaN  Female  Asian/Pacific Islander        NaN
# 4                          NaN  Female             Multiracial        NaN
# ..                         ...     ...                     ...        ...
# 225                        NaN    Male  Asian/Pacific Islander        NaN
# 226                        NaN    Male             Multiracial        NaN
# 227                        NaN    Male  Asian/Pacific Islander        NaN
# 228                     Platzi    Male         Hispanic/Latino        NaN
# 229  arquitectura de software     Male         Hispanic/Latino        NaN
#
#                         email                   user_id
# 0                         NaN  5890c8f7da461a3bcfa445e9
# 1       bizauionica@gmail.com  589368ab148a3e3e849fbebb
# 2       bizauionica@gmail.com  5896a49d39b6f00011141359
# 3    priyankjjain61@gmail.com  5898298d72553400114e43ef
# 4      jialincheoh9@gmail.com  589bf962dbd3ea00113c7bb5
# ..                        ...                       ...
# 225    jialincheoh9@gmail.com  58f109faf09e6300114e1a86
# 226     jialin327@hotmail.com  58f10ad1f09e6300114e1a87
# 227       rakib1987@gmail.com  58f1a1b83b443369d10708da
# 228     alexwebpuro@gmail.com  58f58a4ffa60660011a1679b
# 229        rmelos@unal.edu.co  5900c3d8369b080011ce0ddc
#
# [230 rows x 69 columns]

# %%
df = df.dropna(axis=0, subset=['email'])
df
# Out:
#             StartDate           EndDate      Status       IPAddress  Progress  \
# 1    02/02/2017 10:13  02/02/2017 10:14  IP Address   79.113.17.219       100
# 2    04/02/2017 21:06  04/02/2017 21:08  IP Address  213.233.84.222       100
# 3     06/02/2017 0:45   06/02/2017 0:55  IP Address  98.226.144.140       100
# 4    08/02/2017 22:08  08/02/2017 22:10  IP Address  128.210.107.73       100
# 5     11/02/2017 6:01   11/02/2017 6:03  IP Address  128.210.107.73       100
# ..                ...               ...         ...             ...       ...
# 225  14/04/2017 11:42  14/04/2017 11:43  IP Address  128.210.106.57       100
# 226  14/04/2017 11:45  14/04/2017 11:47  IP Address  128.210.106.57       100
# 227  14/04/2017 22:29  14/04/2017 22:31  IP Address  50.100.240.252       100
# 228  17/04/2017 21:38  17/04/2017 21:55  IP Address   190.156.15.34       100
# 229   26/04/2017 9:59  26/04/2017 10:28  IP Address    170.238.64.4       100
#
#      Duration (in seconds)  Finished      RecordedDate         ResponseId  \
# 1                       95      True  02/02/2017 10:14  R_ehdVXMehOMMche9
# 2                      106      True  04/02/2017 21:08  R_110dynGvJLLAoTi
# 3                      615      True   06/02/2017 0:55  R_3Jl2OxPSP4uOMHd
# 4                      102      True  08/02/2017 22:10  R_1FQxjH4qlLXGZBK
# 5                      157      True   11/02/2017 6:03  R_3P4rlhBLqmgCchT
# ..                     ...       ...               ...                ...
# 225                     80      True  14/04/2017 11:43  R_3sz7gRMw2GBzcdT
# 226                     75      True  14/04/2017 11:47  R_UZbp1luN5lJPDm9
# 227                    133      True  14/04/2017 22:31  R_1MRHD4ivzMfimrM
# 228                   1001      True  17/04/2017 21:55  R_1mXfaS86upbVd2K
# 229                   1739      True  26/04/2017 10:28  R_2SlgBdU4E6drL4F
#
#      RecipientLastName  ...    Q12   Q13   Q14  \
# 1                  NaN  ...   43.0  32.0  42.0
# 2                  NaN  ...   23.0  12.0  24.0
# 3                  NaN  ...   34.0   3.0   3.0
# 4                  NaN  ...  100.0   2.0   3.0
# 5                  NaN  ...  100.0  60.0  20.0
# ..                 ...  ...    ...   ...   ...
# 225                NaN  ...    1.0   1.0   1.0
# 226                NaN  ...    1.0   1.0   1.0
# 227                NaN  ...   23.0  11.0  11.0
# 228                NaN  ...    0.0   5.0   2.0
# 229                NaN  ...    1.0   3.0  15.0
#
#                                                    Q24  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# ..                                                 ...
# 225  Ingeniería de software I, Group 1, Yury Niño, ...
# 226  Ingeniería de software II, Group 2, Camilo Del...
# 227  Ingeniería de software I, Group 1, Yury Niño, ...
# 228                                                NaN
# 229                                                NaN
#
#                     Q24_8_TEXT     Q17                     Q18 Q18_7_TEXT  \
# 1                          NaN    Male   Prefer not to respond        NaN
# 2                          NaN    Male   Prefer not to respond        NaN
# 3                          NaN  Female  Asian/Pacific Islander        NaN
# 4                          NaN  Female             Multiracial        NaN
# 5                          NaN    Male             Multiracial        NaN
# ..                         ...     ...                     ...        ...
# 225                        NaN    Male  Asian/Pacific Islander        NaN
# 226                        NaN    Male             Multiracial        NaN
# 227                        NaN    Male  Asian/Pacific Islander        NaN
# 228                     Platzi    Male         Hispanic/Latino        NaN
# 229  arquitectura de software     Male         Hispanic/Latino        NaN
#
#                         email                   user_id
# 1       bizauionica@gmail.com  589368ab148a3e3e849fbebb
# 2       bizauionica@gmail.com  5896a49d39b6f00011141359
# 3    priyankjjain61@gmail.com  5898298d72553400114e43ef
# 4      jialincheoh9@gmail.com  589bf962dbd3ea00113c7bb5
# 5         uxjudges1@gmail.com  589f0b18a8508b001180880d
# ..                        ...                       ...
# 225    jialincheoh9@gmail.com  58f109faf09e6300114e1a86
# 226     jialin327@hotmail.com  58f10ad1f09e6300114e1a87
# 227       rakib1987@gmail.com  58f1a1b83b443369d10708da
# 228     alexwebpuro@gmail.com  58f58a4ffa60660011a1679b
# 229        rmelos@unal.edu.co  5900c3d8369b080011ce0ddc
#
# [189 rows x 69 columns]

# %%
df = df[(df.email != 'bizauionica@gmail.com') & (df.email != 'jialincheoh9@gmail.com')
       & (df.email != 'rakib1987@gmail.com') & (df.email != 'priyankjjain61@gmail.com')
        & (df.email != 'jialin327@hotmail.com') & (df.email != 'ironhacktech1@gmail.com')
        & (df.email != 'uxjudges@gmail.com') & (df.email != 'uxjudges1@gmail.com') 
        & (df.email != 'uxjudges3@gmail.com') & (df.email != 'uxjudges2@gmail.com') 
        & (df.email != 'opendigital@purdue.edu') & (df.email != 'uxjudges2@gmail.com') 
        & (df.email != 'uxjudges2@gmail.com') & (df.email != 'jadejade1023@gmail.com') 
        & (df.email != 'ironhacktech2@gmail.com')
       
       ]

df
# Out:
#             StartDate           EndDate      Status       IPAddress  Progress  \
# 25    06/03/2017 8:26   06/03/2017 8:34  IP Address  168.176.239.33       100
# 26    06/03/2017 8:30   06/03/2017 8:40  IP Address   168.176.55.16       100
# 27    06/03/2017 8:31   06/03/2017 8:41  IP Address   168.176.55.16       100
# 29    06/03/2017 8:38   06/03/2017 8:44  IP Address  168.176.239.35       100
# 30    06/03/2017 8:29   06/03/2017 8:48  IP Address  168.176.239.31       100
# ..                ...               ...         ...             ...       ...
# 220  28/03/2017 11:26  28/03/2017 11:36  IP Address   168.176.40.31       100
# 221  28/03/2017 13:16  28/03/2017 13:21  IP Address  168.176.239.33       100
# 222  29/03/2017 13:30  29/03/2017 13:38  IP Address   167.249.41.42       100
# 228  17/04/2017 21:38  17/04/2017 21:55  IP Address   190.156.15.34       100
# 229   26/04/2017 9:59  26/04/2017 10:28  IP Address    170.238.64.4       100
#
#      Duration (in seconds)  Finished      RecordedDate         ResponseId  \
# 25                     485      True   06/03/2017 8:34  R_3OcZPtSkKpMblc7
# 26                     598      True   06/03/2017 8:40  R_1FkULXg7YtL44L8
# 27                     557      True   06/03/2017 8:41  R_O9co0FmiBLBhGPD
# 29                     370      True   06/03/2017 8:44  R_rcDEw6vttWC7RIJ
# 30                    1161      True   06/03/2017 8:48  R_21By0Q1fsmmJ9S0
# ..                     ...       ...               ...                ...
# 220                    590      True  28/03/2017 11:36  R_uq2HQNlBXceXRE5
# 221                    344      True  28/03/2017 13:21  R_siKDpkNJ0IBgtkR
# 222                    466      True  29/03/2017 13:38  R_3DndUpbl7cem6XD
# 228                   1001      True  17/04/2017 21:55  R_1mXfaS86upbVd2K
# 229                   1739      True  26/04/2017 10:28  R_2SlgBdU4E6drL4F
#
#      RecipientLastName  ...   Q12   Q13   Q14  \
# 25                 NaN  ...   0.0   0.0   3.0
# 26                 NaN  ...   0.0   5.0   3.0
# 27                 NaN  ...   0.0   8.0   5.0
# 29                 NaN  ...   0.0   0.0   2.0
# 30                 NaN  ...   3.0  20.0   5.0
# ..                 ...  ...   ...   ...   ...
# 220                NaN  ...   0.5  25.0   4.0
# 221                NaN  ...   2.0  30.0   2.0
# 222                NaN  ...  10.0   0.0   4.0
# 228                NaN  ...   0.0   5.0   2.0
# 229                NaN  ...   1.0   3.0  15.0
#
#                                                    Q24  \
# 25   Ingeniería de software II, Group 2, Camilo Del...
# 26   Ingeniería de software I, Group 2, Jairo Apont...
# 27   Ingeniería de software II, Group 1, Camilo Del...
# 29   Ingeniería de software I, Group 2, Jairo Apont...
# 30   Ingeniería de software II, Group 2, Camilo Del...
# ..                                                 ...
# 220  Ingeniería de software II, Group 2, Camilo Del...
# 221  Ingeniería de software II, Group 2, Camilo Del...
# 222                                                NaN
# 228                                                NaN
# 229                                                NaN
#
#                     Q24_8_TEXT     Q17                    Q18 Q18_7_TEXT  \
# 25                         NaN    Male  Prefer not to respond        NaN
# 26                         NaN    Male        Hispanic/Latino        NaN
# 27                         NaN    Male        Hispanic/Latino        NaN
# 29                         NaN    Male        Hispanic/Latino        NaN
# 30                         NaN  Female        Hispanic/Latino        NaN
# ..                         ...     ...                    ...        ...
# 220                        NaN    Male        Hispanic/Latino        NaN
# 221                        NaN    Male                  White        NaN
# 222      Pensamiento Sistemico    Male        Hispanic/Latino        NaN
# 228                     Platzi    Male        Hispanic/Latino        NaN
# 229  arquitectura de software     Male        Hispanic/Latino        NaN
#
#                            email                   user_id
# 25       afguerreroa@unal.edu.co  58bd7fb8d7334500119d3e04
# 26       hsmartineza@unal.edu.co  58bd80b2d7334500119d3e0a
# 27       anfmorenoso@unal.edu.co  58bd80e0d7334500119d3e0b
# 29          kancas.gia@gmail.com  58bd8272d7334500119d3e0e
# 30    lau.angelica39@hotmail.com  58bd805cd7334500119d3e07
# ..                           ...                       ...
# 220         ofnanezn@unal.edu.co  58da9cd90fdf9900115ccb04
# 221          dspavap@unal.edu.co  58dab6796765db00110343d6
# 222  castellanos1458@hotmail.com  58dc0b6fc1bdc400119a4161
# 228        alexwebpuro@gmail.com  58f58a4ffa60660011a1679b
# 229           rmelos@unal.edu.co  5900c3d8369b080011ce0ddc
#
# [165 rows x 69 columns]

# %%
df.to_csv('final.csv')

# %%
df['email']
# Out:
# 25         afguerreroa@unal.edu.co
# 26         hsmartineza@unal.edu.co
# 27         anfmorenoso@unal.edu.co
# 29            kancas.gia@gmail.com
# 30      lau.angelica39@hotmail.com
#                   ...
# 220           ofnanezn@unal.edu.co
# 221            dspavap@unal.edu.co
# 222    castellanos1458@hotmail.com
# 228          alexwebpuro@gmail.com
# 229             rmelos@unal.edu.co
# Name: email, Length: 165, dtype: object

# %%
df1 = pd.read_csv('email-hack_id.csv')
df1
# Out:
#                            email  hack_id
# 0            uxjudges2@gmail.com        0
# 1        jonatanparrat@gmail.com        1
# 2          leguzmana@unal.edu.co        2
# 3        afguerreroa@unal.edu.co        3
# 4        hsmartineza@unal.edu.co        0
# ..                           ...      ...
# 161         gsuarezc@unal.edu.co        0
# 162      cdsanabriar@unal.edu.co        1
# 163     jucjimenezmo@unal.edu.co        2
# 164         ofnanezn@unal.edu.co        3
# 165  castellanos1458@hotmail.com        1
#
# [166 rows x 2 columns]

# %%
merged = pd.merge(df, df1, left_on="email", right_on="email", how="inner")
merged
# Out:
#             StartDate           EndDate      Status       IPAddress  Progress  \
# 0     06/03/2017 8:26   06/03/2017 8:34  IP Address  168.176.239.33       100
# 1     06/03/2017 8:30   06/03/2017 8:40  IP Address   168.176.55.16       100
# 2     06/03/2017 8:31   06/03/2017 8:41  IP Address   168.176.55.16       100
# 3     06/03/2017 8:38   06/03/2017 8:44  IP Address  168.176.239.35       100
# 4     06/03/2017 8:29   06/03/2017 8:48  IP Address  168.176.239.31       100
# ..                ...               ...         ...             ...       ...
# 158  27/03/2017 17:30  27/03/2017 17:41  IP Address  168.176.239.31       100
# 159  27/03/2017 20:34  27/03/2017 20:40  IP Address    186.30.91.89       100
# 160  28/03/2017 11:26  28/03/2017 11:36  IP Address   168.176.40.31       100
# 161  28/03/2017 13:16  28/03/2017 13:21  IP Address  168.176.239.33       100
# 162  29/03/2017 13:30  29/03/2017 13:38  IP Address   167.249.41.42       100
#
#      Duration (in seconds)  Finished      RecordedDate         ResponseId  \
# 0                      485      True   06/03/2017 8:34  R_3OcZPtSkKpMblc7
# 1                      598      True   06/03/2017 8:40  R_1FkULXg7YtL44L8
# 2                      557      True   06/03/2017 8:41  R_O9co0FmiBLBhGPD
# 3                      370      True   06/03/2017 8:44  R_rcDEw6vttWC7RIJ
# 4                     1161      True   06/03/2017 8:48  R_21By0Q1fsmmJ9S0
# ..                     ...       ...               ...                ...
# 158                    658      True  27/03/2017 17:41  R_307S4UKIjHXlMLN
# 159                    373      True  27/03/2017 20:40  R_6nHGYps3o52ucNP
# 160                    590      True  28/03/2017 11:36  R_uq2HQNlBXceXRE5
# 161                    344      True  28/03/2017 13:21  R_siKDpkNJ0IBgtkR
# 162                    466      True  29/03/2017 13:38  R_3DndUpbl7cem6XD
#
#      RecipientLastName  ...   Q13  Q14  \
# 0                  NaN  ...   0.0  3.0
# 1                  NaN  ...   5.0  3.0
# 2                  NaN  ...   8.0  5.0
# 3                  NaN  ...   0.0  2.0
# 4                  NaN  ...  20.0  5.0
# ..                 ...  ...   ...  ...
# 158                NaN  ...   8.0  3.0
# 159                NaN  ...   0.0  2.0
# 160                NaN  ...  25.0  4.0
# 161                NaN  ...  30.0  2.0
# 162                NaN  ...   0.0  4.0
#
#                                                    Q24             Q24_8_TEXT  \
# 0    Ingeniería de software II, Group 2, Camilo Del...                    NaN
# 1    Ingeniería de software I, Group 2, Jairo Apont...                    NaN
# 2    Ingeniería de software II, Group 1, Camilo Del...                    NaN
# 3    Ingeniería de software I, Group 2, Jairo Apont...                    NaN
# 4    Ingeniería de software II, Group 2, Camilo Del...                    NaN
# ..                                                 ...                    ...
# 158  Ingeniería de software I, Group 2, Jairo Apont...                    NaN
# 159  Ingeniería de software II, Group 1, Camilo Del...                    NaN
# 160  Ingeniería de software II, Group 2, Camilo Del...                    NaN
# 161  Ingeniería de software II, Group 2, Camilo Del...                    NaN
# 162                                                NaN  Pensamiento Sistemico
#
#         Q17                    Q18 Q18_7_TEXT                        email  \
# 0      Male  Prefer not to respond        NaN      afguerreroa@unal.edu.co
# 1      Male        Hispanic/Latino        NaN      hsmartineza@unal.edu.co
# 2      Male        Hispanic/Latino        NaN      anfmorenoso@unal.edu.co
# 3      Male        Hispanic/Latino        NaN         kancas.gia@gmail.com
# 4    Female        Hispanic/Latino        NaN   lau.angelica39@hotmail.com
# ..      ...                    ...        ...                          ...
# 158    Male        Hispanic/Latino        NaN      cdsanabriar@unal.edu.co
# 159    Male        Hispanic/Latino        NaN     jucjimenezmo@unal.edu.co
# 160    Male        Hispanic/Latino        NaN         ofnanezn@unal.edu.co
# 161    Male                  White        NaN          dspavap@unal.edu.co
# 162    Male        Hispanic/Latino        NaN  castellanos1458@hotmail.com
#
#                       user_id hack_id
# 0    58bd7fb8d7334500119d3e04       3
# 1    58bd80b2d7334500119d3e0a       0
# 2    58bd80e0d7334500119d3e0b       1
# 3    58bd8272d7334500119d3e0e       2
# 4    58bd805cd7334500119d3e07       3
# ..                        ...     ...
# 158  58d9a0b20fdf9900115cca2e       1
# 159  58d9cbad0fdf9900115cca76       2
# 160  58da9cd90fdf9900115ccb04       3
# 161  58dab6796765db00110343d6       0
# 162  58dc0b6fc1bdc400119a4161       1
#
# [163 rows x 70 columns]

# %%
merged.to_csv('cleaned.csv')
