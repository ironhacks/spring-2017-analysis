# %%
import pandas as pd


df = pd.read_csv('pre-survey.csv')
df
# Out:
#                     StartDate                 EndDate                 Status  \
# 0                  Start Date                End Date          Response Type
# 1    {"ImportId":"startDate"}  {"ImportId":"endDate"}  {"ImportId":"status"}
# 2         2017-01-31 10:27:29     2017-01-31 10:30:29             IP Address
# 3         2017-02-02 10:13:20     2017-02-02 10:14:55             IP Address
# 4         2017-02-04 21:06:28     2017-02-04 21:08:14             IP Address
# ..                        ...                     ...                    ...
# 227       2017-04-14 11:42:19     2017-04-14 11:43:39             IP Address
# 228       2017-04-14 11:45:54     2017-04-14 11:47:10             IP Address
# 229       2017-04-14 22:29:44     2017-04-14 22:31:58             IP Address
# 230       2017-04-17 21:38:55     2017-04-17 21:55:37             IP Address
# 231       2017-04-26 09:59:21     2017-04-26 10:28:20             IP Address
#
# ...

# %%
df = df.dropna(axis=0, subset=['email'])
df
# Out:
#                     StartDate                 EndDate                 Status  \
# 0                  Start Date                End Date          Response Type
# 1    {"ImportId":"startDate"}  {"ImportId":"endDate"}  {"ImportId":"status"}
# 3         2017-02-02 10:13:20     2017-02-02 10:14:55             IP Address
# 4         2017-02-04 21:06:28     2017-02-04 21:08:14             IP Address
# 5         2017-02-06 00:45:23     2017-02-06 00:55:38             IP Address
# ..                        ...                     ...                    ...
# 227       2017-04-14 11:42:19     2017-04-14 11:43:39             IP Address
# 228       2017-04-14 11:45:54     2017-04-14 11:47:10             IP Address
# 229       2017-04-14 22:29:44     2017-04-14 22:31:58             IP Address
# 230       2017-04-17 21:38:55     2017-04-17 21:55:37             IP Address
# 231       2017-04-26 09:59:21     2017-04-26 10:28:20             IP Address
#
# ...
