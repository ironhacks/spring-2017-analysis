# %%
from scipy import stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st 
import networkx as nx

# %%
# Fall 2017 
# honors0 - Full Transparency 
# unal0- No Transparency
# unal1 - Solution Transparency 
# unal2 - Full Transparency

# %%
df1 = pd.read_csv("all_score_total.csv")

# %%
df_new2 = df1.loc[df1['hack id'] == 'unal0']
print(len(df_new2))
df_new2 = df1.loc[df1['hack id'] == 'unal1']
print(len(df_new2))
df_new2 = df1.loc[df1['hack id'] == 'unal2']
print(len(df_new2))
df_new2 = df1.loc[df1['hack id'] == 'honors0']
print(len(df_new2))
# Out:
# 27
# 27
# 27
# 27

# %%
df1['total_diff1'] = df1['total_raw2'] - df1['total_raw1']
df1['total_diff2'] = df1['total_raw3'] - df1['total_raw2']
df1['total_diff3'] = df1['total_raw4'] - df1['total_raw3']
df1['total_diff4'] = df1['total_raw'] - df1['total_raw4']

# %%
df1['total_norm_diff1'] = df1['total_norm2'] - df1['total_norm1']
df1['total_norm_diff2'] = df1['total_norm3'] - df1['total_norm2']
df1['total_norm_diff3'] = df1['total_norm4'] - df1['total_norm3']
df1['total_norm_diff4'] = df1['total_norm'] - df1['total_norm4']

# %%
df1
# Out:
#             username  hack id                                      repo name  \
# 0          mdecloedt  honors0        IH-Project-2017-mdecloedt_webapp_phase5
# 1      Jordan-Loeser  honors0    IH-Project-2017-Jordan-Loeser_webapp_phase5
# 2    LukasMMarinovic  honors0  IH-Project-2017-LukasMMarinovic_webapp_phase5
# 3        whipplem123  honors0      IH-Project-2017-whipplem123_webapp_phase5
# 4             SionHu  honors0           IH-Project-2017-SionHu_webapp_phase5
# ..               ...      ...                                            ...
# 103     RafaelCruz15    unal2     IH-Project-2017-RafaelCruz15_webapp_phase5
# 104         gimg1859    unal2         IH-Project-2017-gimg1859_webapp_phase5
# 105      jannMorenoJ    unal2      IH-Project-2017-jannMorenoJ_webapp_phase5
# 106       dahrojasca    unal2       IH-Project-2017-dahrojasca_webapp_phase5
# 107      FredyRosero    unal2      IH-Project-2017-FredyRosero_webapp_phase5
#
#                          time  climate dataset  extra dataset used  \
# 0    Wed Nov 22 08:30:39 2017                1                   2
# 1    Wed Nov 22 08:30:39 2017                1                   2
# 2    Wed Nov 22 08:30:39 2017                1                   1
# 3    Wed Nov 22 08:30:39 2017                0                   1
# 4    Wed Nov 22 08:30:39 2017                0                   0
# ..                        ...              ...                 ...
# 103  Wed Nov 22 08:30:40 2017                0                   0
# 104  Wed Nov 22 08:30:40 2017                0                   0
# 105  Wed Nov 22 08:30:40 2017                0                   0
# 106  Wed Nov 22 08:30:40 2017                0                   0
# 107  Wed Nov 22 08:30:40 2017                1                   1
#
#                                     extra dataset list  google api  location  \
# 0    Required Weather API, Zillow Home Value Search...           1         1
# 1    Required Weather API, Zillow Home Value Search...           1         1
# 2                               Required Weather API,            1         0
# 3                    Zillow Home Value Searching API,            1         1
# 4                                                  NaN           0         0
# ..                                                 ...         ...       ...
# 103                                                NaN           0         0
# 104                                                NaN           0         0
# 105                                                NaN           0         0
# 106                                                NaN           1         1
# 107                             Required Weather API,            1         1
#
#      using JS  ...  total_norm1  total_norm_per1  total_diff1  total_diff2  \
# 0           1  ...   179.420290           59.26%            9            7
# 1           1  ...   194.392041           85.19%           12            0
# 2           1  ...   175.584075           55.56%            2            3
# 3           1  ...   158.695652           37.04%            2            4
# 4           1  ...   158.550725           33.33%           -3            0
# ..        ...  ...          ...              ...          ...          ...
# 103         1  ...   192.638681           74.07%            2           -9
# 104         1  ...   126.666667            0.00%            0            0
# 105         1  ...   170.000000           55.56%            8          -12
# 106         1  ...   146.875000           40.74%           -2            1
# 107         1  ...   166.772575           51.85%            5           -9
#
#      total_diff3 total_diff4  total_norm_diff1  total_norm_diff2  \
# 0              2           1      3.122034e+01      5.542580e+01
# 1              2           0      3.124902e+01      8.360502e+00
# 2              0           2      1.651996e+01      5.755117e-01
# 3              3           0      1.613155e+01      3.952062e+01
# 4              0           0     -3.188406e+01      3.000000e-07
# ..           ...         ...               ...               ...
# 103            0           0      2.148749e+01     -8.745951e+01
# 104            0           0     -3.000000e-07      3.000000e-07
# 105            0           0      3.697585e+01     -8.030918e+01
# 106           -1           5     -2.020833e+01      9.619347e+00
# 107           13           1      4.496274e+01     -8.506865e+01
#
#      total_norm_diff3  total_norm_diff4
# 0        6.064101e+00          9.318117
# 1        1.747345e+01        -16.766262
# 2        3.951444e-01         17.403568
# 3       -1.910750e+00          0.178616
# 4       -3.000000e-07          0.000000
# ..                ...               ...
# 103     -3.000000e-07          0.000000
# 104     -3.000000e-07          0.000000
# 105     -3.000000e-07          0.000000
# 106     -9.619347e+00         45.750565
# 107      1.198551e+02        -15.350471
#
# [108 rows x 72 columns]

# %%
G_cool = pd.read_csv('Scores and Project Clicks Fall 2017.csv')
G_df = G_cool[G_cool['clicker_username'] != 'RCODI']
G_df
# Out:
#       click_date click_time  time_open         event_type  \
# 75       10/9/17    8:07 PM        NaN  click-project-url
# 76       10/9/17    8:07 PM        NaN          show-code
# 77       10/9/17    8:07 PM        NaN          open-file
# 78       10/9/17    8:07 PM        NaN          show-view
# 79       10/9/17    8:07 PM        NaN          show-view
# ...          ...        ...        ...                ...
# 21942   11/22/17    9:31 AM        NaN          open-file
# 21943   11/22/17    9:31 AM        NaN          open-file
# 21944   11/22/17    9:32 AM     61.085  view-project-time
# 21945   11/22/17   11:43 AM        NaN          show-view
# 21946   11/22/17   11:44 AM     44.924  view-project-time
#
#                                                      url   file_path   phase  \
# 75     http://www.ironhacks.com/view-project/f09deadf...         NaN  phase1
# 76     /users/aldiazve/projects/ironhackstutorial/edi...         NaN  phase1
# 77     http://www.ironhacks.com/users/aldiazve/projec...  index.html  phase1
# 78     /users/aldiazve/projects/ironhackstutorial/pre...         NaN  phase1
# 79     /users/aldiazve/projects/ironhackstutorial/pre...         NaN  phase1
# ...                                                  ...         ...     ...
# 21942  http://www.ironhacks.com/users/Anvido/projects...      map.js  phase5
# 21943  http://www.ironhacks.com/users/Anvido/projects...   moreNy.js  phase5
# 21944               /users/Anvido/projects/webapp_phase4         NaN  phase5
# 21945  /users/cglaitong/projects/webapp_phase4/previe...         NaN  phase5
# 21946            /users/cglaitong/projects/webapp_phase4         NaN  phase5
#
#       hacker_username           hacker_email clicker_username  \
# 75           aldiazve   aldiazve@unal.edu.co        uxjudges3
# 76           aldiazve   aldiazve@unal.edu.co        uxjudges3
# 77           aldiazve   aldiazve@unal.edu.co        uxjudges3
# 78           aldiazve   aldiazve@unal.edu.co        uxjudges3
# 79           aldiazve   aldiazve@unal.edu.co        uxjudges3
# ...               ...                    ...              ...
# 21942          Anvido  andrezo0896@gmail.com       pahigueraf
# 21943          Anvido  andrezo0896@gmail.com       pahigueraf
# 21944          Anvido  andrezo0896@gmail.com       pahigueraf
# 21945       cglaitong  cglaitong@unal.edu.co    davideperdomo
# 21946       cglaitong  cglaitong@unal.edu.co    davideperdomo
#
#                   clicker_email
# 75          uxjudges3@gmail.com
# 76          uxjudges3@gmail.com
# 77          uxjudges3@gmail.com
# 78          uxjudges3@gmail.com
# 79          uxjudges3@gmail.com
# ...                         ...
# 21942    pahigueraf@unal.edu.co
# 21943    pahigueraf@unal.edu.co
# 21944    pahigueraf@unal.edu.co
# 21945  daeperdomocr@unal.edu.co
# 21946  daeperdomocr@unal.edu.co
#
# [19927 rows x 11 columns]

# %% [markdown]
# # Phase 5

# %%
phase5 = G_df.loc[G_df['phase'] == 'phase5']
phase5
# Out:
#       click_date click_time  time_open         event_type  \
# 17401   11/18/17   11:16 PM        NaN  click-project-url
# 17402   11/18/17   11:16 PM      2.309  view-project-time
# 17403   11/18/17   11:17 PM        NaN  click-project-url
# 17404   11/18/17   11:17 PM        NaN          show-view
# 17405   11/18/17   11:17 PM     34.639  view-project-time
# ...          ...        ...        ...                ...
# 21942   11/22/17    9:31 AM        NaN          open-file
# 21943   11/22/17    9:31 AM        NaN          open-file
# 21944   11/22/17    9:32 AM     61.085  view-project-time
# 21945   11/22/17   11:43 AM        NaN          show-view
# 21946   11/22/17   11:44 AM     44.924  view-project-time
#
#                                                      url  file_path   phase  \
# 17401  http://www.ironhacks.com/view-project/f09deadf...        NaN  phase5
# 17402            /users/snugghash/projects/webapp_phase4        NaN  phase5
# 17403  http://www.ironhacks.com/view-project/f09deadf...        NaN  phase5
# 17404  /users/hihms/projects/webapp_phase4/preview/in...        NaN  phase5
# 17405                /users/hihms/projects/webapp_phase4        NaN  phase5
# ...                                                  ...        ...     ...
# 21942  http://www.ironhacks.com/users/Anvido/projects...     map.js  phase5
# 21943  http://www.ironhacks.com/users/Anvido/projects...  moreNy.js  phase5
# 21944               /users/Anvido/projects/webapp_phase4        NaN  phase5
# 21945  /users/cglaitong/projects/webapp_phase4/previe...        NaN  phase5
# 21946            /users/cglaitong/projects/webapp_phase4        NaN  phase5
#
#       hacker_username                        hacker_email clicker_username  \
# 17401       snugghash  snugghash@users.noreply.github.com       jmamaril25
# 17402       snugghash  snugghash@users.noreply.github.com       jmamaril25
# 17403           hihms                 hwang123@purdue.edu      viswapurdue
# 17404           hihms                 hwang123@purdue.edu      viswapurdue
# 17405           hihms                 hwang123@purdue.edu      viswapurdue
# ...               ...                                 ...              ...
# 21942          Anvido               andrezo0896@gmail.com       pahigueraf
# 21943          Anvido               andrezo0896@gmail.com       pahigueraf
# 21944          Anvido               andrezo0896@gmail.com       pahigueraf
# 21945       cglaitong               cglaitong@unal.edu.co    davideperdomo
# 21946       cglaitong               cglaitong@unal.edu.co    davideperdomo
#
#                   clicker_email
# 17401      jmamaril25@gmail.com
# 17402      jmamaril25@gmail.com
# 17403        balajiv@purdue.edu
# 17404        balajiv@purdue.edu
# 17405        balajiv@purdue.edu
# ...                         ...
# 21942    pahigueraf@unal.edu.co
# 21943    pahigueraf@unal.edu.co
# 21944    pahigueraf@unal.edu.co
# 21945  daeperdomocr@unal.edu.co
# 21946  daeperdomocr@unal.edu.co
#
# [4158 rows x 11 columns]

# %% [markdown]
# # Honors0

# %%
df_new = df1.loc[df1['hack id'] == 'honors0']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase5.loc[phase5.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 17401   11/18/17   11:16 PM        NaN  click-project-url
# 17402   11/18/17   11:16 PM      2.309  view-project-time
# 17403   11/18/17   11:17 PM        NaN  click-project-url
# 17404   11/18/17   11:17 PM        NaN          show-view
# 17405   11/18/17   11:17 PM     34.639  view-project-time
# ...          ...        ...        ...                ...
# 21892   11/21/17   11:42 PM        NaN          open-file
# 21893   11/21/17   11:42 PM    884.747  view-project-time
# 21894   11/21/17   11:42 PM   1158.562  view-project-time
# 21918   11/21/17   11:54 PM        NaN          open-file
# 21919   11/21/17   11:55 PM  19828.927  view-project-time
#
#                                                      url  file_path   phase  \
# 17401  http://www.ironhacks.com/view-project/f09deadf...        NaN  phase5
# 17402            /users/snugghash/projects/webapp_phase4        NaN  phase5
# 17403  http://www.ironhacks.com/view-project/f09deadf...        NaN  phase5
# 17404  /users/hihms/projects/webapp_phase4/preview/in...        NaN  phase5
# 17405                /users/hihms/projects/webapp_phase4        NaN  phase5
# ...                                                  ...        ...     ...
# 21892  http://www.ironhacks.com/users/jmamaril25/proj...   index.js  phase5
# 21893           /users/jmamaril25/projects/webapp_phase4        NaN  phase5
# 21894           /users/jmamaril25/projects/webapp_phase4        NaN  phase5
# 21918  http://www.ironhacks.com/users/jmamaril25/proj...  README.md  phase5
# 21919           /users/jmamaril25/projects/webapp_phase4        NaN  phase5
#
#       hacker_username                        hacker_email clicker_username  \
# 17401       snugghash  snugghash@users.noreply.github.com       jmamaril25
# 17402       snugghash  snugghash@users.noreply.github.com       jmamaril25
# 17403           hihms                 hwang123@purdue.edu      viswapurdue
# 17404           hihms                 hwang123@purdue.edu      viswapurdue
# 17405           hihms                 hwang123@purdue.edu      viswapurdue
# ...               ...                                 ...              ...
# 21892      jmamaril25                jmamaril25@gmail.com           bzin22
# 21893      jmamaril25                jmamaril25@gmail.com    Jordan-Loeser
# 21894      jmamaril25                jmamaril25@gmail.com    Jordan-Loeser
# 21918      jmamaril25                jmamaril25@gmail.com           bzin22
# 21919      jmamaril25                jmamaril25@gmail.com           bzin22
#
#               clicker_email
# 17401  jmamaril25@gmail.com
# 17402  jmamaril25@gmail.com
# 17403    balajiv@purdue.edu
# 17404    balajiv@purdue.edu
# 17405    balajiv@purdue.edu
# ...                     ...
# 21892   bryanzin7@gmail.com
# 21893    jordlo@comcast.net
# 21894    jordlo@comcast.net
# 21918   bryanzin7@gmail.com
# 21919   bryanzin7@gmail.com
#
# [2134 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#               index  click_times
# 0        jmamaril25          335
# 1       viswapurdue          189
# 2           gshowal           78
# 3              ko68          245
# 4            AkaGar          140
# 5           matson3           30
# 6         mdecloedt          355
# 7   LukasMMarinovic          122
# 8          nbraunec           72
# 9            bzin22          143
# 10    Jordan-Loeser           67
# 11       CampbellC2           70
# 12          ecottle            3
# 13      littlex2015           39
# 14      whipplem123            7
# 15          shivans           23
# 16      noah-curran          122
# 17          zhao744           50
# 18          lennwgs           20
# 19        GeoffYart           24

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff4'])
print(df_cool)
# Out:
#               index  click_times  match
# 0        jmamaril25          335      5
# 1       viswapurdue          189      2
# 2           gshowal           78      8
# 3              ko68          245      5
# 4            AkaGar          140      5
# 5           matson3           30      3
# 6         mdecloedt          355      1
# 7   LukasMMarinovic          122      2
# 8          nbraunec           72    -23
# 9            bzin22          143     15
# 10    Jordan-Loeser           67      0
# 11       CampbellC2           70     12
# 12          ecottle            3      0
# 13      littlex2015           39      1
# 14      whipplem123            7      0
# 15          shivans           23      0
# 16      noah-curran          122      1
# 17          zhao744           50     -2
# 18          lennwgs           20      0
# 19        GeoffYart           24     -1

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 4-5 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: honors0 - Full Transparency')
# Out:
# Text(0.5, 1.0, 'Group: honors0 - Full Transparency')

# %% [markdown]
# # UNAL1

# %%
df_new = df1.loc[df1['hack id'] == 'unal1']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase5.loc[phase5.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 17619   11/18/17   11:44 PM        NaN          show-code
# 17620   11/18/17   11:44 PM        NaN          open-file
# 17621   11/18/17   11:44 PM        NaN          open-file
# 17626   11/18/17   11:45 PM     54.293  view-project-time
# 17629   11/18/17   11:45 PM        NaN          show-view
# ...          ...        ...        ...                ...
# 21924   11/22/17   12:02 AM        NaN          show-view
# 21925   11/22/17   12:02 AM     18.140  view-project-time
# 21926   11/22/17   12:17 AM  10583.896  view-project-time
# 21945   11/22/17   11:43 AM        NaN          show-view
# 21946   11/22/17   11:44 AM     44.924  view-project-time
#
#                                                      url   file_path   phase  \
# 17619  /users/jaleonro/projects/webapp_phase4/edit?re...         NaN  phase5
# 17620  http://www.ironhacks.com/users/jaleonro/projec...  index.html  phase5
# 17621  http://www.ironhacks.com/users/jaleonro/projec...    index.js  phase5
# 17626             /users/jaleonro/projects/webapp_phase4         NaN  phase5
# 17629  /users/garayf/projects/webapp_phase4/preview/i...         NaN  phase5
# ...                                                  ...         ...     ...
# 21924  /users/Juankmilo97/projects/webapp_phase4/prev...         NaN  phase5
# 21925          /users/Juankmilo97/projects/webapp_phase4         NaN  phase5
# 21926        /users/evilcucaracha/projects/webapp_phase4         NaN  phase5
# 21945  /users/cglaitong/projects/webapp_phase4/previe...         NaN  phase5
# 21946            /users/cglaitong/projects/webapp_phase4         NaN  phase5
#
#       hacker_username               hacker_email clicker_username  \
# 17619        jaleonro       jaleonro@unal.edu.co    davideperdomo
# 17620        jaleonro       jaleonro@unal.edu.co    davideperdomo
# 17621        jaleonro       jaleonro@unal.edu.co    davideperdomo
# 17626        jaleonro       jaleonro@unal.edu.co    davideperdomo
# 17629          garayf       edgarayf@unal.edu.co    davideperdomo
# ...               ...                        ...              ...
# 21924     Juankmilo97  juancaropu123@outlook.com    davideperdomo
# 21925     Juankmilo97  juancaropu123@outlook.com    davideperdomo
# 21926   evilcucaracha     rcbuelvasv@unal.edu.co        jdsolanos
# 21945       cglaitong      cglaitong@unal.edu.co    davideperdomo
# 21946       cglaitong      cglaitong@unal.edu.co    davideperdomo
#
#                   clicker_email
# 17619  daeperdomocr@unal.edu.co
# 17620  daeperdomocr@unal.edu.co
# 17621  daeperdomocr@unal.edu.co
# 17626  daeperdomocr@unal.edu.co
# 17629  daeperdomocr@unal.edu.co
# ...                         ...
# 21924  daeperdomocr@unal.edu.co
# 21925  daeperdomocr@unal.edu.co
# 21926     jdsolanos@unal.edu.co
# 21945  daeperdomocr@unal.edu.co
# 21946  daeperdomocr@unal.edu.co
#
# [848 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#               index  click_times
# 0     davideperdomo           98
# 1          ayperezc           10
# 2    BrandonAvilanR           92
# 3         jdsolanos           54
# 4    sebcamacho1703           65
# 5         cglaitong           33
# 6        Biopeligro          354
# 7        DaniCastel           85
# 8  JamerMejiaGarcia           57

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff4'])
print(df_cool)
# Out:
#               index  click_times  match
# 0     davideperdomo           98      7
# 1          ayperezc           10    -17
# 2    BrandonAvilanR           92      0
# 3         jdsolanos           54      2
# 4    sebcamacho1703           65     20
# 5         cglaitong           33     -4
# 6        Biopeligro          354      0
# 7        DaniCastel           85     15
# 8  JamerMejiaGarcia           57      0

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 4-5 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: unal1 - Solution Transparency')
# Out:
# Text(0.5, 1.0, 'Group: unal1 - Solution Transparency')

# %% [markdown]
# # UNAL2

# %%
df_new = df1.loc[df1['hack id'] == 'unal2']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase5.loc[phase5.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 17622   11/18/17   11:44 PM    185.277  view-project-time
# 17623   11/18/17   11:44 PM        NaN  click-project-url
# 17624   11/18/17   11:45 PM        NaN          show-code
# 17625   11/18/17   11:45 PM        NaN          open-file
# 17627   11/18/17   11:45 PM     12.317  view-project-time
# ...          ...        ...        ...                ...
# 21940   11/22/17    9:31 AM        NaN          open-file
# 21941   11/22/17    9:31 AM        NaN          open-file
# 21942   11/22/17    9:31 AM        NaN          open-file
# 21943   11/22/17    9:31 AM        NaN          open-file
# 21944   11/22/17    9:32 AM     61.085  view-project-time
#
#                                                      url   file_path   phase  \
# 17622            /users/jsalcinar/projects/webapp_phase4         NaN  phase5
# 17623  http://www.ironhacks.com/view-project/f09deadf...         NaN  phase5
# 17624  /users/jdgaitanf/projects/webapp_phase4/edit?r...         NaN  phase5
# 17625  http://www.ironhacks.com/users/jdgaitanf/proje...  index.html  phase5
# 17627            /users/jdgaitanf/projects/webapp_phase4         NaN  phase5
# ...                                                  ...         ...     ...
# 21940  http://www.ironhacks.com/users/Anvido/projects...      map.js  phase5
# 21941  http://www.ironhacks.com/users/Anvido/projects...   moreNy.js  phase5
# 21942  http://www.ironhacks.com/users/Anvido/projects...      map.js  phase5
# 21943  http://www.ironhacks.com/users/Anvido/projects...   moreNy.js  phase5
# 21944               /users/Anvido/projects/webapp_phase4         NaN  phase5
#
#       hacker_username           hacker_email clicker_username  \
# 17622       jsalcinar  jsalcinar@unal.edu.co       pahigueraf
# 17623       jdgaitanf  jdgaitanf@unal.edu.co       pahigueraf
# 17624       jdgaitanf  jdgaitanf@unal.edu.co       pahigueraf
# 17625       jdgaitanf  jdgaitanf@unal.edu.co       pahigueraf
# 17627       jdgaitanf  jdgaitanf@unal.edu.co       pahigueraf
# ...               ...                    ...              ...
# 21940          Anvido  andrezo0896@gmail.com       pahigueraf
# 21941          Anvido  andrezo0896@gmail.com       pahigueraf
# 21942          Anvido  andrezo0896@gmail.com       pahigueraf
# 21943          Anvido  andrezo0896@gmail.com       pahigueraf
# 21944          Anvido  andrezo0896@gmail.com       pahigueraf
#
#                 clicker_email
# 17622  pahigueraf@unal.edu.co
# 17623  pahigueraf@unal.edu.co
# 17624  pahigueraf@unal.edu.co
# 17625  pahigueraf@unal.edu.co
# 17627  pahigueraf@unal.edu.co
# ...                       ...
# 21940  pahigueraf@unal.edu.co
# 21941  pahigueraf@unal.edu.co
# 21942  pahigueraf@unal.edu.co
# 21943  pahigueraf@unal.edu.co
# 21944  pahigueraf@unal.edu.co
#
# [1141 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#                index  click_times
# 0         pahigueraf          103
# 1             Anvido           23
# 2      trickyjuggler           19
# 3   diefrodriguezcha          267
# 4       RafaelCruz15          207
# 5        GabrielUnal           23
# 6            bsdiaza           95
# 7        adcorredorm           58
# 8         csalfonsol          107
# 9          serbatero           84
# 10         federgolo           57
# 11     Jufcardenasmo           56
# 12          casc3798           42

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff4'])
print(df_cool)
# Out:
#                index  click_times  match
# 0         pahigueraf          103      6
# 1             Anvido           23     13
# 2      trickyjuggler           19     16
# 3   diefrodriguezcha          267     10
# 4       RafaelCruz15          207      0
# 5        GabrielUnal           23     -4
# 6            bsdiaza           95      0
# 7        adcorredorm           58     18
# 8         csalfonsol          107     12
# 9          serbatero           84      1
# 10         federgolo           57      7
# 11     Jufcardenasmo           56      0
# 12          casc3798           42     25

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 4-5 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: unal2 - Full Transparency')
# Out:
# Text(0.5, 1.0, 'Group: unal2 - Full Transparency')

# %% [markdown]
# # Phase 4

# %%
phase4 = G_df.loc[G_df['phase'] == 'phase4']
phase4
# Out:
#       click_date click_time  time_open         event_type  \
# 13059   11/13/17   11:38 PM        NaN        score-click
# 13060   11/13/17   11:38 PM        NaN        score-click
# 13061   11/13/17   11:38 PM        NaN        score-click
# 13062   11/13/17   11:38 PM        NaN        score-click
# 13063   11/13/17   11:38 PM        NaN  click-project-url
# ...          ...        ...        ...                ...
# 17746   11/18/17   11:57 PM        NaN          open-file
# 17747   11/18/17   11:57 PM     21.248  view-project-time
# 17748   11/18/17   11:57 PM        NaN        score-click
# 17749   11/18/17   11:57 PM        NaN  click-project-url
# 17750   11/18/17   11:57 PM        NaN          show-view
#
#                                                      url file_path   phase  \
# 13059                                                NaN       NaN  phase4
# 13060                                                NaN       NaN  phase4
# 13061                                                NaN       NaN  phase4
# 13062                                                NaN       NaN  phase4
# 13063  http://www.ironhacks.com/view-project/f09deadf...       NaN  phase4
# ...                                                  ...       ...     ...
# 17746  http://www.ironhacks.com/users/GeoffYart/proje...  index.js  phase4
# 17747            /users/GeoffYart/projects/webapp_phase4       NaN  phase4
# 17748                                                NaN       NaN  phase4
# 17749  http://www.ironhacks.com/view-project/f09deadf...       NaN  phase4
# 17750  /users/Jordan-Loeser/projects/webapp_phase4/pr...       NaN  phase4
#
#       hacker_username              hacker_email clicker_username  \
# 13059   trickyjuggler    ejjimenezc@unal.edu.co    ironhacktech2
# 13060       serbatero    sisanchezp@unal.edu.co    ironhacktech2
# 13061     StevenEsmar  stespinosama@unal.edu.co    ironhacktech2
# 13062      pahigueraf    pahigueraf@unal.edu.co    ironhacktech2
# 13063      pahigueraf    pahigueraf@unal.edu.co    ironhacktech2
# ...               ...                       ...              ...
# 17746       GeoffYart    nathanfei123@gmail.com       jmamaril25
# 17747       GeoffYart    nathanfei123@gmail.com       jmamaril25
# 17748   Jordan-Loeser        jordlo@comcast.net       jmamaril25
# 17749   Jordan-Loeser        jordlo@comcast.net       jmamaril25
# 17750   Jordan-Loeser        jordlo@comcast.net       jmamaril25
#
#                  clicker_email
# 13059  ironhacktech2@gmail.com
# 13060  ironhacktech2@gmail.com
# 13061  ironhacktech2@gmail.com
# 13062  ironhacktech2@gmail.com
# 13063  ironhacktech2@gmail.com
# ...                        ...
# 17746     jmamaril25@gmail.com
# 17747     jmamaril25@gmail.com
# 17748     jmamaril25@gmail.com
# 17749     jmamaril25@gmail.com
# 17750     jmamaril25@gmail.com
#
# [4352 rows x 11 columns]

# %% [markdown]
# # Honors0

# %%
df_new = df1.loc[df1['hack id'] == 'honors0']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase4.loc[phase4.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 13076   11/13/17   11:39 PM        NaN  click-project-url
# 13077   11/13/17   11:39 PM        NaN          show-view
# 13078   11/13/17   11:39 PM        NaN          show-view
# 13079   11/13/17   11:39 PM      7.351  view-project-time
# 13081   11/13/17   11:39 PM        NaN  click-project-url
# ...          ...        ...        ...                ...
# 17746   11/18/17   11:57 PM        NaN          open-file
# 17747   11/18/17   11:57 PM     21.248  view-project-time
# 17748   11/18/17   11:57 PM        NaN        score-click
# 17749   11/18/17   11:57 PM        NaN  click-project-url
# 17750   11/18/17   11:57 PM        NaN          show-view
#
#                                                      url file_path   phase  \
# 13076  http://www.ironhacks.com/view-project/f09deadf...       NaN  phase4
# 13077  /users/nbraunec/projects/webapp_phase3/preview...       NaN  phase4
# 13078  /users/nbraunec/projects/webapp_phase3/preview...       NaN  phase4
# 13079             /users/nbraunec/projects/webapp_phase3       NaN  phase4
# 13081  http://www.ironhacks.com/view-project/f09deadf...       NaN  phase4
# ...                                                  ...       ...     ...
# 17746  http://www.ironhacks.com/users/GeoffYart/proje...  index.js  phase4
# 17747            /users/GeoffYart/projects/webapp_phase4       NaN  phase4
# 17748                                                NaN       NaN  phase4
# 17749  http://www.ironhacks.com/view-project/f09deadf...       NaN  phase4
# 17750  /users/Jordan-Loeser/projects/webapp_phase4/pr...       NaN  phase4
#
#       hacker_username               hacker_email clicker_username  \
# 13076        nbraunec  noah.braunecker@gmail.com             ko68
# 13077        nbraunec  noah.braunecker@gmail.com             ko68
# 13078        nbraunec  noah.braunecker@gmail.com             ko68
# 13079        nbraunec  noah.braunecker@gmail.com             ko68
# 13081   Jordan-Loeser         jordlo@comcast.net             ko68
# ...               ...                        ...              ...
# 17746       GeoffYart     nathanfei123@gmail.com       jmamaril25
# 17747       GeoffYart     nathanfei123@gmail.com       jmamaril25
# 17748   Jordan-Loeser         jordlo@comcast.net       jmamaril25
# 17749   Jordan-Loeser         jordlo@comcast.net       jmamaril25
# 17750   Jordan-Loeser         jordlo@comcast.net       jmamaril25
#
#               clicker_email
# 13076       ko68@purdue.edu
# 13077       ko68@purdue.edu
# 13078       ko68@purdue.edu
# 13079       ko68@purdue.edu
# 13081       ko68@purdue.edu
# ...                     ...
# 17746  jmamaril25@gmail.com
# 17747  jmamaril25@gmail.com
# 17748  jmamaril25@gmail.com
# 17749  jmamaril25@gmail.com
# 17750  jmamaril25@gmail.com
#
# [2391 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#             index  click_times
# 0            ko68          187
# 1          bzin22           97
# 2      jmamaril25          262
# 3     viswapurdue          239
# 4         zhao744          221
# 5         matson3           99
# 6       mdecloedt          349
# 7         gshowal          167
# 8        nbraunec           57
# 9     littlex2015          194
# 10  Jordan-Loeser           83
# 11      GeoffYart           52
# 12         AkaGar           28
# 13    whipplem123          105
# 14        ecottle          186
# 15    noah-curran           10
# 16        lennwgs            3
# 17     CampbellC2           52

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff3'])
print(df_cool)
# Out:
#             index  click_times  match
# 0            ko68          187      0
# 1          bzin22           97      2
# 2      jmamaril25          262     11
# 3     viswapurdue          239     13
# 4         zhao744          221      0
# 5         matson3           99     -3
# 6       mdecloedt          349      2
# 7         gshowal          167     -1
# 8        nbraunec           57      7
# 9     littlex2015          194      6
# 10  Jordan-Loeser           83      2
# 11      GeoffYart           52     18
# 12         AkaGar           28      0
# 13    whipplem123          105      3
# 14        ecottle          186      0
# 15    noah-curran           10      3
# 16        lennwgs            3      0
# 17     CampbellC2           52     -2

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 3-4 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: honors0 - Full Transparency')
# Out:
# Text(0.5, 1.0, 'Group: honors0 - Full Transparency')

# %%
df_new = df1.loc[df1['hack id'] == 'unal1']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase4.loc[phase4.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 13122   11/13/17   11:47 PM        NaN          show-view
# 13123   11/13/17   11:49 PM     67.781  view-project-time
# 13124   11/13/17   11:49 PM        NaN          show-view
# 13125   11/13/17   11:50 PM        NaN          show-view
# 13126   11/13/17   11:50 PM     88.703  view-project-time
# ...          ...        ...        ...                ...
# 17692   11/18/17   11:49 PM        NaN          show-view
# 17698   11/18/17   11:49 PM     14.275  view-project-time
# 17699   11/18/17   11:49 PM        NaN          show-view
# 17700   11/18/17   11:49 PM      2.925  view-project-time
# 17702   11/18/17   11:49 PM        NaN          show-view
#
#                                                      url file_path   phase  \
# 13122  /users/alejosaur/projects/webapp_phase3/previe...       NaN  phase4
# 13123            /users/alejosaur/projects/webapp_phase3       NaN  phase4
# 13124  /users/BrandonAvilanR/projects/webapp_phase3/p...       NaN  phase4
# 13125  /users/cglaitong/projects/webapp_phase3/previe...       NaN  phase4
# 13126       /users/BrandonAvilanR/projects/webapp_phase3       NaN  phase4
# ...                                                  ...       ...     ...
# 17692  /users/jdsolanos/projects/webapp_phase4/previe...       NaN  phase4
# 17698            /users/jdsolanos/projects/webapp_phase4       NaN  phase4
# 17699  /users/gahormigag/projects/webapp_phase4/previ...       NaN  phase4
# 17700           /users/gahormigag/projects/webapp_phase4       NaN  phase4
# 17702  /users/alejosaur/projects/webapp_phase4/previe...       NaN  phase4
#
#       hacker_username              hacker_email clicker_username  \
# 13122       alejosaur  asantamariap@unal.edu.co    davideperdomo
# 13123       alejosaur  asantamariap@unal.edu.co    davideperdomo
# 13124  BrandonAvilanR     bsavilanr@unal.edu.co    davideperdomo
# 13125       cglaitong     cglaitong@unal.edu.co    davideperdomo
# 13126  BrandonAvilanR     bsavilanr@unal.edu.co    davideperdomo
# ...               ...                       ...              ...
# 17692       jdsolanos     jdsolanos@unal.edu.co    davideperdomo
# 17698       jdsolanos     jdsolanos@unal.edu.co    davideperdomo
# 17699      gahormigag    gahormigag@unal.edu.co    davideperdomo
# 17700      gahormigag    gahormigag@unal.edu.co    davideperdomo
# 17702       alejosaur  asantamariap@unal.edu.co    davideperdomo
#
#                   clicker_email
# 13122  daeperdomocr@unal.edu.co
# 13123  daeperdomocr@unal.edu.co
# 13124  daeperdomocr@unal.edu.co
# 13125  daeperdomocr@unal.edu.co
# 13126  daeperdomocr@unal.edu.co
# ...                         ...
# 17692  daeperdomocr@unal.edu.co
# 17698  daeperdomocr@unal.edu.co
# 17699  daeperdomocr@unal.edu.co
# 17700  daeperdomocr@unal.edu.co
# 17702  daeperdomocr@unal.edu.co
#
# [779 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#             index  click_times
# 0   davideperdomo          109
# 1  BrandonAvilanR          269
# 2      DaniCastel           24
# 3        ayperezc          176
# 4  sebcamacho1703           68
# 5       cglaitong           90
# 6       jdsolanos           22
# 7       nikolasto           21

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff3'])
print(df_cool)
# Out:
#             index  click_times  match
# 0   davideperdomo          109     11
# 1  BrandonAvilanR          269    -24
# 2      DaniCastel           24      4
# 3        ayperezc          176      4
# 4  sebcamacho1703           68     -4
# 5       cglaitong           90     10
# 6       jdsolanos           22      0
# 7       nikolasto           21     -5

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 3-4 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: unal1 - Solution Transparency')
# Out:
# Text(0.5, 1.0, 'Group: unal1 - Solution Transparency')

# %%
df_new = df1.loc[df1['hack id'] == 'unal2']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase4.loc[phase4.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 13101   11/13/17   11:42 PM        NaN        score-click
# 13102   11/13/17   11:43 PM        NaN        score-click
# 13108   11/13/17   11:43 PM        NaN        score-click
# 13109   11/13/17   11:43 PM        NaN        score-click
# 13111   11/13/17   11:43 PM        NaN  click-project-url
# ...          ...        ...        ...                ...
# 17729   11/18/17   11:53 PM        NaN  click-project-url
# 17730   11/18/17   11:53 PM        NaN          show-code
# 17731   11/18/17   11:53 PM        NaN          open-file
# 17732   11/18/17   11:53 PM        NaN          open-file
# 17733   11/18/17   11:56 PM    157.674  view-project-time
#
#                                                      url   file_path   phase  \
# 13101                                                NaN         NaN  phase4
# 13102                                                NaN         NaN  phase4
# 13108                                                NaN         NaN  phase4
# 13109                                                NaN         NaN  phase4
# 13111  http://www.ironhacks.com/view-project/f09deadf...         NaN  phase4
# ...                                                  ...         ...     ...
# 17729  http://www.ironhacks.com/view-project/f09deadf...         NaN  phase4
# 17730  /users/diefrodriguezcha/projects/webapp_phase4...         NaN  phase4
# 17731  http://www.ironhacks.com/users/diefrodriguezch...  index.html  phase4
# 17732  http://www.ironhacks.com/users/diefrodriguezch...    index.js  phase4
# 17733     /users/diefrodriguezcha/projects/webapp_phase4         NaN  phase4
#
#         hacker_username                  hacker_email clicker_username  \
# 13101        pahigueraf        pahigueraf@unal.edu.co       pahigueraf
# 13102          casc3798      caasanchezcr@unal.edu.co       pahigueraf
# 13108            Anvido         andrezo0896@gmail.com       pahigueraf
# 13109     trickyjuggler        ejjimenezc@unal.edu.co       pahigueraf
# 13111            Anvido         andrezo0896@gmail.com       pahigueraf
# ...                 ...                           ...              ...
# 17729  diefrodriguezcha  diefrodriguezcha@unal.edu.co       pahigueraf
# 17730  diefrodriguezcha  diefrodriguezcha@unal.edu.co       pahigueraf
# 17731  diefrodriguezcha  diefrodriguezcha@unal.edu.co       pahigueraf
# 17732  diefrodriguezcha  diefrodriguezcha@unal.edu.co       pahigueraf
# 17733  diefrodriguezcha  diefrodriguezcha@unal.edu.co       pahigueraf
#
#                 clicker_email
# 13101  pahigueraf@unal.edu.co
# 13102  pahigueraf@unal.edu.co
# 13108  pahigueraf@unal.edu.co
# 13109  pahigueraf@unal.edu.co
# 13111  pahigueraf@unal.edu.co
# ...                       ...
# 17729  pahigueraf@unal.edu.co
# 17730  pahigueraf@unal.edu.co
# 17731  pahigueraf@unal.edu.co
# 17732  pahigueraf@unal.edu.co
# 17733  pahigueraf@unal.edu.co
#
# [1164 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#                index  click_times
# 0         pahigueraf          489
# 1      trickyjuggler           39
# 2             Anvido          119
# 3   diefrodriguezcha           99
# 4        adcorredorm           32
# 5         anferoar96           67
# 6         dahrojasca          103
# 7          federgolo           17
# 8       DaveValencia           82
# 9        GabrielUnal           71
# 10         serbatero           35
# 11        csalfonsol           11

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff3'])
print(df_cool)
# Out:
#                index  click_times  match
# 0         pahigueraf          489      1
# 1      trickyjuggler           39      4
# 2             Anvido          119     11
# 3   diefrodriguezcha           99     51
# 4        adcorredorm           32      0
# 5         anferoar96           67      0
# 6         dahrojasca          103     -1
# 7          federgolo           17      7
# 8       DaveValencia           82      0
# 9        GabrielUnal           71      4
# 10         serbatero           35      4
# 11        csalfonsol           11     -2

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 3-4 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: unal2 - Full Transparency')
# Out:
# Text(0.5, 1.0, 'Group: unal2 - Full Transparency')

# %% [markdown]
# # Phase 3

# %%
phase3 = G_df.loc[G_df['phase'] == 'phase3']
phase3
# Out:
#       click_date click_time  time_open         event_type  \
# 668     10/30/17    6:42 AM        NaN  click-project-url
# 669     10/30/17    6:42 AM        NaN          show-code
# 670     10/30/17    6:42 AM        NaN          open-file
# 671     10/30/17    6:42 AM        NaN          show-view
# 672     10/30/17    6:42 AM      3.301  view-project-time
# ...          ...        ...        ...                ...
# 13037   11/13/17   11:09 PM     25.994  view-project-time
# 13038   11/13/17   11:32 PM        NaN        score-click
# 13043   11/13/17   11:34 PM    668.685  view-project-time
# 13044   11/13/17   11:34 PM    668.587  view-project-time
# 13045   11/13/17   11:34 PM    668.786  view-project-time
#
#                                                      url   file_path   phase  \
# 668    http://www.ironhacks.com/view-project/f09deadf...         NaN  phase3
# 669    /users/dcastanedar/projects/webapp_phase3/edit...         NaN  phase3
# 670    http://www.ironhacks.com/users/dcastanedar/pro...  index.html  phase3
# 671    /users/dcastanedar/projects/webapp_phase3/prev...         NaN  phase3
# 672            /users/dcastanedar/projects/webapp_phase3         NaN  phase3
# ...                                                  ...         ...     ...
# 13037           /users/jmamaril25/projects/webapp_phase2         NaN  phase3
# 13038                                                NaN         NaN  phase3
# 13043             /users/ayperezc/projects/webapp_phase2         NaN  phase3
# 13044       /users/BrandonAvilanR/projects/webapp_phase2         NaN  phase3
# 13045             /users/jaleonro/projects/webapp_phase2         NaN  phase3
#
#       hacker_username             hacker_email clicker_username  \
# 668       dcastanedar  dcastanedar@unal.edu.co    ironhacktech2
# 669       dcastanedar  dcastanedar@unal.edu.co    ironhacktech2
# 670       dcastanedar  dcastanedar@unal.edu.co    ironhacktech2
# 671       dcastanedar  dcastanedar@unal.edu.co    ironhacktech2
# 672       dcastanedar  dcastanedar@unal.edu.co    ironhacktech2
# ...               ...                      ...              ...
# 13037      jmamaril25     jmamaril25@gmail.com       jmamaril25
# 13038      pahigueraf   pahigueraf@unal.edu.co       pahigueraf
# 13043        ayperezc     ayperezc@unal.edu.co         ayperezc
# 13044  BrandonAvilanR    bsavilanr@unal.edu.co         ayperezc
# 13045        jaleonro     jaleonro@unal.edu.co         ayperezc
#
#                  clicker_email
# 668    ironhacktech2@gmail.com
# 669    ironhacktech2@gmail.com
# 670    ironhacktech2@gmail.com
# 671    ironhacktech2@gmail.com
# 672    ironhacktech2@gmail.com
# ...                        ...
# 13037     jmamaril25@gmail.com
# 13038   pahigueraf@unal.edu.co
# 13043     ayperezc@unal.edu.co
# 13044     ayperezc@unal.edu.co
# 13045     ayperezc@unal.edu.co
#
# [1038 rows x 11 columns]

# %%
df_new = df1.loc[df1['hack id'] == 'honors0']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase3.loc[phase3.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 11739   11/11/17    3:30 PM   7038.921  view-project-time
# 11782   11/11/17    3:47 PM        NaN  click-project-url
# 11784   11/11/17    3:47 PM        NaN          show-code
# 11785   11/11/17    3:47 PM        NaN          open-file
# 11786   11/11/17    3:48 PM        NaN          show-view
# ...          ...        ...        ...                ...
# 13033   11/13/17   11:09 PM        NaN          show-code
# 13034   11/13/17   11:09 PM        NaN          open-file
# 13035   11/13/17   11:09 PM        NaN          open-file
# 13036   11/13/17   11:09 PM        NaN          open-file
# 13037   11/13/17   11:09 PM     25.994  view-project-time
#
#                                                      url   file_path   phase  \
# 11739           /users/CampbellC2/projects/webapp_phase2         NaN  phase3
# 11782  http://www.ironhacks.com/view-project/f09deadf...         NaN  phase3
# 11784  /users/Jordan-Loeser/projects/webapp_phase2/ed...         NaN  phase3
# 11785  http://www.ironhacks.com/users/Jordan-Loeser/p...  index.html  phase3
# 11786  /users/Jordan-Loeser/projects/webapp_phase2/pr...         NaN  phase3
# ...                                                  ...         ...     ...
# 13033  /users/jmamaril25/projects/webapp_phase2/edit?...         NaN  phase3
# 13034  http://www.ironhacks.com/users/jmamaril25/proj...  index.html  phase3
# 13035  http://www.ironhacks.com/users/jmamaril25/proj...    index.js  phase3
# 13036  http://www.ironhacks.com/users/jmamaril25/proj...   style.css  phase3
# 13037           /users/jmamaril25/projects/webapp_phase2         NaN  phase3
#
#       hacker_username          hacker_email clicker_username  \
# 11739      CampbellC2   campb341@purdue.edu        mdecloedt
# 11782   Jordan-Loeser    jordlo@comcast.net  LukasMMarinovic
# 11784   Jordan-Loeser    jordlo@comcast.net  LukasMMarinovic
# 11785   Jordan-Loeser    jordlo@comcast.net  LukasMMarinovic
# 11786   Jordan-Loeser    jordlo@comcast.net  LukasMMarinovic
# ...               ...                   ...              ...
# 13033      jmamaril25  jmamaril25@gmail.com       jmamaril25
# 13034      jmamaril25  jmamaril25@gmail.com       jmamaril25
# 13035      jmamaril25  jmamaril25@gmail.com       jmamaril25
# 13036      jmamaril25  jmamaril25@gmail.com       jmamaril25
# 13037      jmamaril25  jmamaril25@gmail.com       jmamaril25
#
#               clicker_email
# 11739   mdecloed@purdue.edu
# 11782     lukas@agramer.com
# 11784     lukas@agramer.com
# 11785     lukas@agramer.com
# 11786     lukas@agramer.com
# ...                     ...
# 13033  jmamaril25@gmail.com
# 13034  jmamaril25@gmail.com
# 13035  jmamaril25@gmail.com
# 13036  jmamaril25@gmail.com
# 13037  jmamaril25@gmail.com
#
# [612 rows x 11 columns]

# %% [markdown]
# # Honors0

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#               index  click_times
# 0         mdecloedt           19
# 1   LukasMMarinovic           27
# 2            bzin22           42
# 3       viswapurdue          199
# 4           zhao744           76
# 5              ko68            9
# 6           matson3           48
# 7            AkaGar           73
# 8           gshowal           38
# 9       noah-curran           22
# 10        GeoffYart            8
# 11         nbraunec           13
# 12       jmamaril25           38

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff2'])
print(df_cool)
# Out:
#               index  click_times  match
# 0         mdecloedt           19      7
# 1   LukasMMarinovic           27      3
# 2            bzin22           42     12
# 3       viswapurdue          199     -9
# 4           zhao744           76      0
# 5              ko68            9      0
# 6           matson3           48      6
# 7            AkaGar           73      5
# 8           gshowal           38     13
# 9       noah-curran           22      0
# 10        GeoffYart            8      0
# 11         nbraunec           13     16
# 12       jmamaril25           38     -1

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 2-3 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: honors0 - Full Transparency')
# Out:
# Text(0.5, 1.0, 'Group: honors0 - Full Transparency')

# %% [markdown]
# # Unal1

# %%
df_new = df1.loc[df1['hack id'] == 'unal1']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase3.loc[phase3.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 12182   11/11/17    6:29 PM        NaN          show-view
# 12183   11/11/17    6:29 PM     17.345  view-project-time
# 12376   11/11/17    9:01 PM        NaN  click-project-url
# 12377   11/11/17    9:01 PM        NaN          show-view
# 12504   11/11/17   10:47 PM   6337.629  view-project-time
# ...          ...        ...        ...                ...
# 12894   11/13/17    9:58 PM   3334.658  view-project-time
# 12895   11/13/17    9:58 PM   3361.015  view-project-time
# 13043   11/13/17   11:34 PM    668.685  view-project-time
# 13044   11/13/17   11:34 PM    668.587  view-project-time
# 13045   11/13/17   11:34 PM    668.786  view-project-time
#
#                                                      url file_path   phase  \
# 12182  /users/ayperezc/projects/webapp_phase2/preview...       NaN  phase3
# 12183             /users/ayperezc/projects/webapp_phase2       NaN  phase3
# 12376  http://www.ironhacks.com/view-project/f09deadf...       NaN  phase3
# 12377  /users/alejosaur/projects/webapp_phase2/previe...       NaN  phase3
# 12504            /users/alejosaur/projects/webapp_phase2       NaN  phase3
# ...                                                  ...       ...     ...
# 12894       /users/BrandonAvilanR/projects/webapp_phase2       NaN  phase3
# 12895             /users/jaleonro/projects/webapp_phase2       NaN  phase3
# 13043             /users/ayperezc/projects/webapp_phase2       NaN  phase3
# 13044       /users/BrandonAvilanR/projects/webapp_phase2       NaN  phase3
# 13045             /users/jaleonro/projects/webapp_phase2       NaN  phase3
#
#       hacker_username              hacker_email clicker_username  \
# 12182        ayperezc      ayperezc@unal.edu.co        nikolasto
# 12183        ayperezc      ayperezc@unal.edu.co        nikolasto
# 12376       alejosaur  asantamariap@unal.edu.co    davideperdomo
# 12377       alejosaur  asantamariap@unal.edu.co    davideperdomo
# 12504       alejosaur  asantamariap@unal.edu.co    davideperdomo
# ...               ...                       ...              ...
# 12894  BrandonAvilanR     bsavilanr@unal.edu.co         ayperezc
# 12895        jaleonro      jaleonro@unal.edu.co         ayperezc
# 13043        ayperezc      ayperezc@unal.edu.co         ayperezc
# 13044  BrandonAvilanR     bsavilanr@unal.edu.co         ayperezc
# 13045        jaleonro      jaleonro@unal.edu.co         ayperezc
#
#                    clicker_email
# 12182  nikolasto2094@hotmail.com
# 12183  nikolasto2094@hotmail.com
# 12376   daeperdomocr@unal.edu.co
# 12377   daeperdomocr@unal.edu.co
# 12504   daeperdomocr@unal.edu.co
# ...                          ...
# 12894       ayperezc@unal.edu.co
# 12895       ayperezc@unal.edu.co
# 13043       ayperezc@unal.edu.co
# 13044       ayperezc@unal.edu.co
# 13045       ayperezc@unal.edu.co
#
# [111 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#             index  click_times
# 0       nikolasto            2
# 1   davideperdomo            7
# 2          garayf           21
# 3        ayperezc           72
# 4  BrandonAvilanR            9

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff2'])
print(df_cool)
# Out:
#             index  click_times  match
# 0       nikolasto            2      1
# 1   davideperdomo            7     17
# 2          garayf           21      6
# 3        ayperezc           72     12
# 4  BrandonAvilanR            9     14

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 2-3 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: unal1 - Solution Transparency')
# Out:
# Text(0.5, 1.0, 'Group: unal1 - Solution Transparency')

# %%
df_new = df1.loc[df1['hack id'] == 'unal2']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase3.loc[phase3.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 11740   11/11/17    3:38 PM        NaN        score-click
# 11741   11/11/17    3:38 PM        NaN  click-project-url
# 11742   11/11/17    3:38 PM        NaN        score-click
# 11743   11/11/17    3:38 PM        NaN        score-click
# 11744   11/11/17    3:38 PM        NaN        score-click
# ...          ...        ...        ...                ...
# 12900   11/13/17   10:56 PM        NaN        score-click
# 12914   11/13/17   11:02 PM        NaN        score-click
# 12915   11/13/17   11:03 PM        NaN        score-click
# 12916   11/13/17   11:03 PM        NaN        score-click
# 13038   11/13/17   11:32 PM        NaN        score-click
#
#                                                      url file_path   phase  \
# 11740                                                NaN       NaN  phase3
# 11741  http://www.ironhacks.com/view-project/f09deadf...       NaN  phase3
# 11742                                                NaN       NaN  phase3
# 11743                                                NaN       NaN  phase3
# 11744                                                NaN       NaN  phase3
# ...                                                  ...       ...     ...
# 12900                                                NaN       NaN  phase3
# 12914                                                NaN       NaN  phase3
# 12915                                                NaN       NaN  phase3
# 12916                                                NaN       NaN  phase3
# 13038                                                NaN       NaN  phase3
#
#       hacker_username               hacker_email clicker_username  \
# 11740      pahigueraf     pahigueraf@unal.edu.co     RafaelCruz15
# 11741      pahigueraf     pahigueraf@unal.edu.co     RafaelCruz15
# 11742       serbatero     sisanchezp@unal.edu.co     RafaelCruz15
# 11743   Jufcardenasmo  jufcardenasmo@unal.edu.co     RafaelCruz15
# 11744    RafaelCruz15        ercruzr@unal.edu.co     RafaelCruz15
# ...               ...                        ...              ...
# 12900          Anvido      andrezo0896@gmail.com       anferoar96
# 12914       jdgaitanf      jdgaitanf@unal.edu.co       anferoar96
# 12915   ironhacktech2    ironhacktech2@gmail.com       anferoar96
# 12916      anferoar96       afromana@unal.edu.co       anferoar96
# 13038      pahigueraf     pahigueraf@unal.edu.co       pahigueraf
#
#                 clicker_email
# 11740     ercruzr@unal.edu.co
# 11741     ercruzr@unal.edu.co
# 11742     ercruzr@unal.edu.co
# 11743     ercruzr@unal.edu.co
# 11744     ercruzr@unal.edu.co
# ...                       ...
# 12900    afromana@unal.edu.co
# 12914    afromana@unal.edu.co
# 12915    afromana@unal.edu.co
# 12916    afromana@unal.edu.co
# 13038  pahigueraf@unal.edu.co
#
# [268 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#            index  click_times
# 0   RafaelCruz15           79
# 1     csalfonsol           17
# 2     anferoar96            6
# 3      serbatero           31
# 4    GabrielUnal           15
# 5     dahrojasca           28
# 6       gimg1859           27
# 7      jdgaitanf           35
# 8         Anvido            6
# 9      federgolo           17
# 10   FredyRosero            6
# 11    pahigueraf            1

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff2'])
print(df_cool)
# Out:
#            index  click_times  match
# 0   RafaelCruz15           79     -9
# 1     csalfonsol           17     -3
# 2     anferoar96            6      4
# 3      serbatero           31     -2
# 4    GabrielUnal           15      0
# 5     dahrojasca           28      1
# 6       gimg1859           27      0
# 7      jdgaitanf           35      4
# 8         Anvido            6      5
# 9      federgolo           17      3
# 10   FredyRosero            6     -9
# 11    pahigueraf            1     21

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 2-3 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: unal2 - Full Transparency')
# Out:
# Text(0.5, 1.0, 'Group: unal2 - Full Transparency')

# %% [markdown]
# # Phase 2

# %%
phase2 = G_df.loc[G_df['phase'] == 'phase2']
phase2
# Out:
#       click_date click_time  time_open         event_type  \
# 5775     11/6/17   12:00 PM        NaN        score-click
# 5778     11/6/17   12:00 PM        NaN  click-project-url
# 5780     11/6/17   12:00 PM        NaN          show-view
# 5781     11/6/17   12:00 PM        NaN          show-code
# 5782     11/6/17   12:00 PM        NaN          open-file
# ...          ...        ...        ...                ...
# 11734   11/11/17    3:15 PM        NaN          open-file
# 11735   11/11/17    3:15 PM        NaN          open-file
# 11736   11/11/17    3:15 PM        NaN          open-file
# 11737   11/11/17    3:15 PM        NaN          open-file
# 11738   11/11/17    3:15 PM        NaN          open-file
#
#                                                      url   file_path   phase  \
# 5775                                                 NaN         NaN  phase2
# 5778   http://www.ironhacks.com/view-project/f09deadf...         NaN  phase2
# 5780   /users/Jordan-Loeser/projects/webapp_phase1/pr...         NaN  phase2
# 5781   /users/Jordan-Loeser/projects/webapp_phase1/ed...         NaN  phase2
# 5782   http://www.ironhacks.com/users/Jordan-Loeser/p...  index.html  phase2
# ...                                                  ...         ...     ...
# 11734  http://www.ironhacks.com/users/Anvido/projects...     info.js  phase2
# 11735  http://www.ironhacks.com/users/Anvido/projects...     info.js  phase2
# 11736  http://www.ironhacks.com/users/Anvido/projects...      map.js  phase2
# 11737  http://www.ironhacks.com/users/Anvido/projects...     info.js  phase2
# 11738  http://www.ironhacks.com/users/Anvido/projects...      map.js  phase2
#
#       hacker_username           hacker_email clicker_username  \
# 5775    Jordan-Loeser     jordlo@comcast.net          zhao744
# 5778    Jordan-Loeser     jordlo@comcast.net          zhao744
# 5780    Jordan-Loeser     jordlo@comcast.net          zhao744
# 5781    Jordan-Loeser     jordlo@comcast.net          zhao744
# 5782    Jordan-Loeser     jordlo@comcast.net          zhao744
# ...               ...                    ...              ...
# 11734          Anvido  andrezo0896@gmail.com       anferoar96
# 11735          Anvido  andrezo0896@gmail.com       anferoar96
# 11736          Anvido  andrezo0896@gmail.com       anferoar96
# 11737          Anvido  andrezo0896@gmail.com       anferoar96
# 11738          Anvido  andrezo0896@gmail.com       anferoar96
#
#               clicker_email
# 5775     zhao744@purdue.edu
# 5778     zhao744@purdue.edu
# 5780     zhao744@purdue.edu
# 5781     zhao744@purdue.edu
# 5782     zhao744@purdue.edu
# ...                     ...
# 11734  afromana@unal.edu.co
# 11735  afromana@unal.edu.co
# 11736  afromana@unal.edu.co
# 11737  afromana@unal.edu.co
# 11738  afromana@unal.edu.co
#
# [3283 rows x 11 columns]

# %% [markdown]
# # Honors 0

# %%
df_new = df1.loc[df1['hack id'] == 'honors0']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase2.loc[phase2.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 5775     11/6/17   12:00 PM        NaN        score-click
# 5778     11/6/17   12:00 PM        NaN  click-project-url
# 5780     11/6/17   12:00 PM        NaN          show-view
# 5781     11/6/17   12:00 PM        NaN          show-code
# 5782     11/6/17   12:00 PM        NaN          open-file
# ...          ...        ...        ...                ...
# 11722   11/11/17    2:55 PM      4.432  view-project-time
# 11723   11/11/17    2:57 PM        NaN          show-view
# 11724   11/11/17    2:57 PM        NaN          show-code
# 11725   11/11/17    2:57 PM        NaN          open-file
# 11726   11/11/17    2:57 PM        NaN          open-file
#
#                                                      url   file_path   phase  \
# 5775                                                 NaN         NaN  phase2
# 5778   http://www.ironhacks.com/view-project/f09deadf...         NaN  phase2
# 5780   /users/Jordan-Loeser/projects/webapp_phase1/pr...         NaN  phase2
# 5781   /users/Jordan-Loeser/projects/webapp_phase1/ed...         NaN  phase2
# 5782   http://www.ironhacks.com/users/Jordan-Loeser/p...  index.html  phase2
# ...                                                  ...         ...     ...
# 11722        /users/Jordan-Loeser/projects/webapp_phase2         NaN  phase2
# 11723  /users/jmamaril25/projects/webapp_phase2/previ...         NaN  phase2
# 11724  /users/jmamaril25/projects/webapp_phase2/edit?...         NaN  phase2
# 11725  http://www.ironhacks.com/users/jmamaril25/proj...  index.html  phase2
# 11726  http://www.ironhacks.com/users/jmamaril25/proj...    index.js  phase2
#
#       hacker_username          hacker_email clicker_username  \
# 5775    Jordan-Loeser    jordlo@comcast.net          zhao744
# 5778    Jordan-Loeser    jordlo@comcast.net          zhao744
# 5780    Jordan-Loeser    jordlo@comcast.net          zhao744
# 5781    Jordan-Loeser    jordlo@comcast.net          zhao744
# 5782    Jordan-Loeser    jordlo@comcast.net          zhao744
# ...               ...                   ...              ...
# 11722   Jordan-Loeser    jordlo@comcast.net    Jordan-Loeser
# 11723      jmamaril25  jmamaril25@gmail.com           bzin22
# 11724      jmamaril25  jmamaril25@gmail.com           bzin22
# 11725      jmamaril25  jmamaril25@gmail.com           bzin22
# 11726      jmamaril25  jmamaril25@gmail.com           bzin22
#
#              clicker_email
# 5775    zhao744@purdue.edu
# 5778    zhao744@purdue.edu
# 5780    zhao744@purdue.edu
# 5781    zhao744@purdue.edu
# 5782    zhao744@purdue.edu
# ...                    ...
# 11722   jordlo@comcast.net
# 11723  bryanzin7@gmail.com
# 11724  bryanzin7@gmail.com
# 11725  bryanzin7@gmail.com
# 11726  bryanzin7@gmail.com
#
# [1538 rows x 11 columns]

# %% [markdown]
# # Honors0

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#             index  click_times
# 0         zhao744           92
# 1          bzin22           70
# 2      jmamaril25           83
# 3         gshowal          114
# 4      CampbellC2            2
# 5       mdecloedt          509
# 6     viswapurdue          106
# 7     littlex2015           62
# 8        nbraunec          145
# 9            ko68           94
# 10        matson3          131
# 11      GeoffYart           62
# 12        ecottle           25
# 13        lennwgs            8
# 14  Jordan-Loeser           30
# 15    whipplem123            5

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff1'])
print(df_cool)
# Out:
#             index  click_times  match
# 0         zhao744           92     10
# 1          bzin22           70      4
# 2      jmamaril25           83     16
# 3         gshowal          114      0
# 4      CampbellC2            2      4
# 5       mdecloedt          509      9
# 6     viswapurdue          106      3
# 7     littlex2015           62      5
# 8        nbraunec          145     -1
# 9            ko68           94      5
# 10        matson3          131      2
# 11      GeoffYart           62      8
# 12        ecottle           25      3
# 13        lennwgs            8      0
# 14  Jordan-Loeser           30     12
# 15    whipplem123            5      2

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 1-2 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: honors0 - Full Transparency')
# Out:
# Text(0.5, 1.0, 'Group: honors0 - Full Transparency')

# %% [markdown]
# # UNAL 1

# %%
df_new = df1.loc[df1['hack id'] == 'unal1']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase2.loc[phase2.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 8897     11/8/17   11:24 PM        NaN          show-view
# 8898     11/8/17   11:24 PM     10.786  view-project-time
# 8899     11/8/17   11:24 PM        NaN          show-view
# 8900     11/8/17   11:25 PM     20.970  view-project-time
# 8929     11/8/17   11:33 PM        NaN  click-project-url
# ...          ...        ...        ...                ...
# 11612   11/11/17    1:21 PM      4.277  view-project-time
# 11613   11/11/17    1:21 PM        NaN  click-project-url
# 11614   11/11/17    1:21 PM        NaN          show-view
# 11618   11/11/17    1:21 PM     23.488  view-project-time
# 11619   11/11/17    1:21 PM    242.778  view-project-time
#
#                                                      url file_path   phase  \
# 8897   /users/davideperdomo/projects/webapp_phase2/pr...       NaN  phase2
# 8898         /users/davideperdomo/projects/webapp_phase2       NaN  phase2
# 8899   /users/evilcucaracha/projects/webapp_phase2/pr...       NaN  phase2
# 8900         /users/evilcucaracha/projects/webapp_phase2       NaN  phase2
# 8929   http://www.ironhacks.com/view-project/f09deadf...       NaN  phase2
# ...                                                  ...       ...     ...
# 11612            /users/alejosaur/projects/webapp_phase2       NaN  phase2
# 11613  http://www.ironhacks.com/view-project/f09deadf...       NaN  phase2
# 11614  /users/BrandonAvilanR/projects/webapp_phase2/p...       NaN  phase2
# 11618       /users/BrandonAvilanR/projects/webapp_phase2       NaN  phase2
# 11619             /users/xFortich/projects/webapp_phase2       NaN  phase2
#
#       hacker_username              hacker_email clicker_username  \
# 8897    davideperdomo  daeperdomocr@unal.edu.co    davideperdomo
# 8898    davideperdomo  daeperdomocr@unal.edu.co    davideperdomo
# 8899    evilcucaracha    rcbuelvasv@unal.edu.co    davideperdomo
# 8900    evilcucaracha    rcbuelvasv@unal.edu.co    davideperdomo
# 8929        uxjudges3       uxjudges3@gmail.com    davideperdomo
# ...               ...                       ...              ...
# 11612       alejosaur  asantamariap@unal.edu.co   BrandonAvilanR
# 11613  BrandonAvilanR     bsavilanr@unal.edu.co   BrandonAvilanR
# 11614  BrandonAvilanR     bsavilanr@unal.edu.co   BrandonAvilanR
# 11618  BrandonAvilanR     bsavilanr@unal.edu.co   BrandonAvilanR
# 11619        xFortich     ajsuarezf@unal.edu.co   BrandonAvilanR
#
#                   clicker_email
# 8897   daeperdomocr@unal.edu.co
# 8898   daeperdomocr@unal.edu.co
# 8899   daeperdomocr@unal.edu.co
# 8900   daeperdomocr@unal.edu.co
# 8929   daeperdomocr@unal.edu.co
# ...                         ...
# 11612     bsavilanr@unal.edu.co
# 11613     bsavilanr@unal.edu.co
# 11614     bsavilanr@unal.edu.co
# 11618     bsavilanr@unal.edu.co
# 11619     bsavilanr@unal.edu.co
#
# [335 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#             index  click_times
# 0   davideperdomo          161
# 1      DaniCastel           33
# 2        xFortich           29
# 3  BrandonAvilanR           28
# 4       alejosaur           15
# 5       Saariasba           12
# 6        ayperezc           46
# 7   evilcucaracha            3
# 8  DavidsMartinez            8

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff1'])
print(df_cool)
# Out:
#             index  click_times  match
# 0   davideperdomo          161      2
# 1      DaniCastel           33      0
# 2        xFortich           29      8
# 3  BrandonAvilanR           28      5
# 4       alejosaur           15     26
# 5       Saariasba           12     -1
# 6        ayperezc           46      1
# 7   evilcucaracha            3      7
# 8  DavidsMartinez            8      0

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 1-2 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: unal1 - Solution Transparency')
# Out:
# Text(0.5, 1.0, 'Group: unal1 - Solution Transparency')

# %% [markdown]
# # UNAL 2

# %%
df_new = df1.loc[df1['hack id'] == 'unal2']
#print(df_new['username'].tolist())
#print(df_new)
df_revised = phase2.loc[phase2.clicker_username.isin(df_new['username'])]
df_revised
# Out:
#       click_date click_time  time_open         event_type  \
# 8444     11/8/17   10:47 PM        NaN  click-project-url
# 8446     11/8/17   10:47 PM        NaN          show-view
# 8452     11/8/17   10:47 PM     20.401  view-project-time
# 8454     11/8/17   10:47 PM        NaN  click-project-url
# 8455     11/8/17   10:47 PM        NaN          show-view
# ...          ...        ...        ...                ...
# 11734   11/11/17    3:15 PM        NaN          open-file
# 11735   11/11/17    3:15 PM        NaN          open-file
# 11736   11/11/17    3:15 PM        NaN          open-file
# 11737   11/11/17    3:15 PM        NaN          open-file
# 11738   11/11/17    3:15 PM        NaN          open-file
#
#                                                      url file_path   phase  \
# 8444   http://www.ironhacks.com/view-project/f09deadf...       NaN  phase2
# 8446   /users/jdgaitanf/projects/webapp_phase2/previe...       NaN  phase2
# 8452             /users/jdgaitanf/projects/webapp_phase2       NaN  phase2
# 8454   http://www.ironhacks.com/view-project/f09deadf...       NaN  phase2
# 8455   /users/buendiagon/projects/webapp_phase2/previ...       NaN  phase2
# ...                                                  ...       ...     ...
# 11734  http://www.ironhacks.com/users/Anvido/projects...   info.js  phase2
# 11735  http://www.ironhacks.com/users/Anvido/projects...   info.js  phase2
# 11736  http://www.ironhacks.com/users/Anvido/projects...    map.js  phase2
# 11737  http://www.ironhacks.com/users/Anvido/projects...   info.js  phase2
# 11738  http://www.ironhacks.com/users/Anvido/projects...    map.js  phase2
#
#       hacker_username                hacker_email clicker_username  \
# 8444        jdgaitanf       jdgaitanf@unal.edu.co       pahigueraf
# 8446        jdgaitanf       jdgaitanf@unal.edu.co       pahigueraf
# 8452        jdgaitanf       jdgaitanf@unal.edu.co       pahigueraf
# 8454       buendiagon  daagonzalezbue@unal.edu.co       pahigueraf
# 8455       buendiagon  daagonzalezbue@unal.edu.co       pahigueraf
# ...               ...                         ...              ...
# 11734          Anvido       andrezo0896@gmail.com       anferoar96
# 11735          Anvido       andrezo0896@gmail.com       anferoar96
# 11736          Anvido       andrezo0896@gmail.com       anferoar96
# 11737          Anvido       andrezo0896@gmail.com       anferoar96
# 11738          Anvido       andrezo0896@gmail.com       anferoar96
#
#                 clicker_email
# 8444   pahigueraf@unal.edu.co
# 8446   pahigueraf@unal.edu.co
# 8452   pahigueraf@unal.edu.co
# 8454   pahigueraf@unal.edu.co
# 8455   pahigueraf@unal.edu.co
# ...                       ...
# 11734    afromana@unal.edu.co
# 11735    afromana@unal.edu.co
# 11736    afromana@unal.edu.co
# 11737    afromana@unal.edu.co
# 11738    afromana@unal.edu.co
#
# [1200 rows x 11 columns]

# %%
G5 = nx.from_pandas_edgelist(df_revised, 'hacker_username', 'clicker_username')

matching = df_revised['clicker_username'].tolist()
count = 0

wordfreq = {}
for raw_word in matching:
    if raw_word not in wordfreq:
        wordfreq[raw_word] = 0 
    wordfreq[raw_word] += 1


df_result = pd.DataFrame.from_dict(wordfreq, orient='index')
df_cool = df_result.reset_index().melt('index',value_name='click_times').drop('variable', axis=1)
print(df_cool)
# Out:
#                index  click_times
# 0         pahigueraf          214
# 1          serbatero          121
# 2             Anvido           58
# 3         anferoar96          115
# 4          jdgaitanf           19
# 5      trickyjuggler          193
# 6        adcorredorm           35
# 7          jsalcinar          141
# 8         csalfonsol          226
# 9      Jufcardenasmo            4
# 10      RafaelCruz15           50
# 11  diefrodriguezcha           24

# %%
df_cool['match'] = df_cool['index'].map(df_new.set_index('username')['total_diff1'])
print(df_cool)
# Out:
#                index  click_times  match
# 0         pahigueraf          214      6
# 1          serbatero          121      0
# 2             Anvido           58      6
# 3         anferoar96          115      3
# 4          jdgaitanf           19      4
# 5      trickyjuggler          193     15
# 6        adcorredorm           35      8
# 7          jsalcinar          141      2
# 8         csalfonsol          226      3
# 9      Jufcardenasmo            4      2
# 10      RafaelCruz15           50      2
# 11  diefrodriguezcha           24     -3

# %%
plt.plot(df_cool['match'], df_cool['click_times'], 'o')
m, b = np.polyfit(df_cool['match'], df_cool['click_times'], 1)
plt.plot(df_cool['match'], m*df_cool['match'] + b)
plt.xlabel('Phase 1-2 Total Raw Improvement Score')
plt.ylabel('Number of Clicks Performed')
plt.title('Group: unal2 - Full Transparency')
# Out:
# Text(0.5, 1.0, 'Group: unal2 - Full Transparency')
