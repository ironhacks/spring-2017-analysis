# %% [markdown]
# # Bogota 1

# %%
import pandas as pd 

df1_phase5 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/Absolute Score Bogota1 Phase5.csv")
df1_phase5
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# ..             ...                 ...             ...
# 73      daandradec  Bogota-Hack-1-2017      daandradec
# 74        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 75        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 76  joahernandezca  Bogota-Hack-1-2017  joahernandezca
# 77  joahernandezca  Bogota-Hack-1-2017  joahernandezca
#
#                             Grader Name                         Grader Email  \
# 0                              uxjudge5    purdueironhack+uxjudge5@gmail.com
# 1   purdueironhack+techjudge1@gmail.com  purdueironhack+techjudge1@gmail.com
# ...

# %%
df1_novelty_phase5 = df1_phase5[df1_phase5['User Requirement'] != "- - -"]
df1_novelty_phase5
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 6   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 8      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 10       helmeraac  Bogota-Hack-1-2017       helmeraac
# 12      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 14      falperezgo  Bogota-Hack-1-2017      falperezgo
# 16       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 19      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 21          oeroaq  Bogota-Hack-1-2017          oeroaq
# 23         gcantem  Bogota-Hack-1-2017         gcantem
# 25     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 27      jonatan360  Bogota-Hack-1-2017      jonatan360
# 29  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# 31    stevenbustos  Bogota-Hack-1-2017    stevenbustos
# ...

# %%
df1_final_novelty_phase5 = df1_novelty_phase5[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df1_tech_phase5 = df1_phase5[df1_phase5['Tech Score'] != "- - -"]
df1_tech_phase5
# Out:
#            Project                Hack         Student  \
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 5        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 7   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 9      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 11       helmeraac  Bogota-Hack-1-2017       helmeraac
# 13      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 15      falperezgo  Bogota-Hack-1-2017      falperezgo
# 17       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 18         ItsNavi  Bogota-Hack-1-2017         ItsNavi
# 20      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 22          oeroaq  Bogota-Hack-1-2017          oeroaq
# 24         gcantem  Bogota-Hack-1-2017         gcantem
# 26     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 28      jonatan360  Bogota-Hack-1-2017      jonatan360
# 30  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# ...

# %%
df1_tech_phase5[['Student', 'Tech Score']]
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 3     adamantwharf       62.5
# 5        bdcajicam         75
# 7   andfsanchezlem          0
# 9      dfhincapiem       37.5
# 11       helmeraac       62.5
# 13      dasalgadob         50
# 15      falperezgo        100
# 17       djguzmanc         75
# 18         ItsNavi          0
# 20      gsuarezc04         25
# 22          oeroaq       87.5
# 24         gcantem         25
# 26     Semoralesga         50
# 28      jonatan360        100
# 30  jesusfchavarro        100
# 32    stevenbustos         75
# 34  jufcontrerasco         75
# 36      dsbarrerag       87.5
# 38       wolfstain       87.5
# 39         Zeugmax          0
# 40     kastellanos          0
# 41    JairVillalba         75
# 43      miaborjaac       87.5
# 45   ivdgonzalezco         75
# 47    maikellPardo          0
# 49    Christian7sr         75
# 51      jsnarvaezb       87.5
# 53   gfalbarracinr         75
# 55        aldiazve       87.5
# ...

# %%
df1_final_tech_phase5 = df1_tech_phase5[['Student', 'Tech Score']]
df1_final_tech_phase5
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 3     adamantwharf       62.5
# 5        bdcajicam         75
# 7   andfsanchezlem          0
# 9      dfhincapiem       37.5
# 11       helmeraac       62.5
# 13      dasalgadob         50
# 15      falperezgo        100
# 17       djguzmanc         75
# 18         ItsNavi          0
# 20      gsuarezc04         25
# 22          oeroaq       87.5
# 24         gcantem         25
# 26     Semoralesga         50
# 28      jonatan360        100
# 30  jesusfchavarro        100
# 32    stevenbustos         75
# 34  jufcontrerasco         75
# 36      dsbarrerag       87.5
# 38       wolfstain       87.5
# 39         Zeugmax          0
# 40     kastellanos          0
# 41    JairVillalba         75
# 43      miaborjaac       87.5
# 45   ivdgonzalezco         75
# 47    maikellPardo          0
# 49    Christian7sr         75
# 51      jsnarvaezb       87.5
# 53   gfalbarracinr         75
# 55        aldiazve       87.5
# ...

# %%
df1_phase5 = pd.merge(df1_final_novelty_phase5, df1_final_tech_phase5, on='Student', how = 'outer')
df1_phase5
# Out:
#            Student User Requirement Info Viz Score Novelty Score Tech Score
# 0        gasierram               40           62.5            25       62.5
# 1     adamantwharf               20             25             0       62.5
# 2        bdcajicam               40          29.17          62.5         75
# 3   andfsanchezlem               20             25             0          0
# 4      dfhincapiem               20             25            25       37.5
# 5        helmeraac                0             25             0       62.5
# 6       dasalgadob                0             25            25         50
# 7       falperezgo               20          45.83          62.5        100
# 8        djguzmanc               80          79.17           100         75
# 9       gsuarezc04                0             25             0         25
# 10          oeroaq              100           87.5          82.5       87.5
# ...

# %%
bogota1 = pd.read_csv('../data/total1-phase5.csv')
bogota1
# Out:
#            Student  Unnamed: 1  Unnamed: 2  Total Score  Unnamed: 4  \
# 0           oeroaq         NaN         NaN       357.50         NaN
# 1       jonatan360         NaN         NaN       352.50         NaN
# 2   jesusfchavarro         NaN         NaN       345.00         NaN
# 3       daandradec         NaN         NaN       336.67         NaN
# 4        djguzmanc         NaN         NaN       334.17         NaN
# 5        jsviveroj         NaN         NaN       331.67         NaN
# 6       dsbarrerag         NaN         NaN       330.00         NaN
# 7       miaborjaac         NaN         NaN       323.33         NaN
# 8   diegoaguevarar         NaN         NaN       317.50         NaN
# 9    ivdgonzalezco         NaN         NaN       312.50         NaN
# 10     jiapulidoar         NaN         NaN       310.00         NaN
# 11         gcantem         NaN         NaN       283.33         NaN
# 12  jufcontrerasco         NaN         NaN       264.17         NaN
# ...

# %%
bogota1 = bogota1[['Student', 'Total Score']]
bogota1
# Out:
#            Student  Total Score
# 0           oeroaq       357.50
# 1       jonatan360       352.50
# 2   jesusfchavarro       345.00
# 3       daandradec       336.67
# 4        djguzmanc       334.17
# 5        jsviveroj       331.67
# 6       dsbarrerag       330.00
# 7       miaborjaac       323.33
# 8   diegoaguevarar       317.50
# 9    ivdgonzalezco       312.50
# 10     jiapulidoar       310.00
# 11         gcantem       283.33
# 12  jufcontrerasco       264.17
# 13        jcrubioa       246.25
# 14      fevargasmo       240.00
# 15        aldiazve       236.67
# 16      falperezgo       228.33
# 17     anfmorenoso       217.50
# 18      jsnarvaezb       211.67
# 19       bdcajicam       206.67
# 20    stevenbustos       198.33
# 21       wolfstain       197.08
# 22     nabautistal       195.00
# 23       gasierram       190.00
# 24     Semoralesga       165.83
# 25  joahernandezca       161.67
# 26    Christian7sr       124.17
# 27      jmhurtadoc       120.83
# ...

# %%
df1_phase5 = pd.merge(df1_phase5, bogota1, on='Student', how = 'outer')
df1_phase5
# Out:
#            Student User Requirement Info Viz Score Novelty Score Tech Score  \
# 0        gasierram               40           62.5            25       62.5
# 1     adamantwharf               20             25             0       62.5
# 2        bdcajicam               40          29.17          62.5         75
# 3   andfsanchezlem               20             25             0          0
# 4      dfhincapiem               20             25            25       37.5
# 5        helmeraac                0             25             0       62.5
# 6       dasalgadob                0             25            25         50
# 7       falperezgo               20          45.83          62.5        100
# 8        djguzmanc               80          79.17           100         75
# 9       gsuarezc04                0             25             0         25
# 10          oeroaq              100           87.5          82.5       87.5
# ...

# %%
df1_phase5.insert (1, "Group", 1)
df1_phase5 = df1_phase5.fillna(0)
df1_phase5
# Out:
#            Student  Group User Requirement Info Viz Score Novelty Score  \
# 0        gasierram      1               40           62.5            25
# 1     adamantwharf      1               20             25             0
# 2        bdcajicam      1               40          29.17          62.5
# 3   andfsanchezlem      1               20             25             0
# 4      dfhincapiem      1               20             25            25
# 5        helmeraac      1                0             25             0
# 6       dasalgadob      1                0             25            25
# 7       falperezgo      1               20          45.83          62.5
# 8        djguzmanc      1               80          79.17           100
# 9       gsuarezc04      1                0             25             0
# 10          oeroaq      1              100           87.5          82.5
# 11         gcantem      1              100          70.83          87.5
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase5',
        'Info Viz Score': 'infovis-phase5',
        'Novelty Score': 'novelty-phase5', 
        'Tech Score': 'tech-phase5', 
        'Total Score': 'total-phase5'}
  
# call rename () method
df1_phase5.rename(columns=dict,
          inplace=True)

df1_phase5
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
import pandas as pd 

df1_phase4 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/AbsoluteScore Bogota1 Phase4.csv")
df1_phase4
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# ..             ...                 ...             ...
# 72      daandradec  Bogota-Hack-1-2017      daandradec
# 73        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 74        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 75  joahernandezca  Bogota-Hack-1-2017  joahernandezca
# 76  joahernandezca  Bogota-Hack-1-2017  joahernandezca
#
#                             Grader Name                         Grader Email  \
# 0                              uxjudge5    purdueironhack+uxjudge5@gmail.com
# 1   purdueironhack+techjudge1@gmail.com  purdueironhack+techjudge1@gmail.com
# ...

# %%
df1_novelty_phase4 = df1_phase4[df1_phase4['User Requirement'] != "- - -"]
df1_novelty_phase4
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 6   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 8      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 10       helmeraac  Bogota-Hack-1-2017       helmeraac
# 12      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 14      falperezgo  Bogota-Hack-1-2017      falperezgo
# 16       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 19      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 21          oeroaq  Bogota-Hack-1-2017          oeroaq
# 23         gcantem  Bogota-Hack-1-2017         gcantem
# 25     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 27      jonatan360  Bogota-Hack-1-2017      jonatan360
# 29  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# 32    stevenbustos  Bogota-Hack-1-2017    stevenbustos
# ...

# %%
df1_final_novelty_phase4 = df1_novelty_phase4[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df1_tech_phase4 = df1_phase4[df1_phase4['Tech Score'] != "- - -"]
df1_tech_phase4
# Out:
#            Project                Hack         Student  \
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 5        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 7   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 9      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 11       helmeraac  Bogota-Hack-1-2017       helmeraac
# 13      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 15      falperezgo  Bogota-Hack-1-2017      falperezgo
# 17       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 18         ItsNavi  Bogota-Hack-1-2017         ItsNavi
# 20      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 22          oeroaq  Bogota-Hack-1-2017          oeroaq
# 24         gcantem  Bogota-Hack-1-2017         gcantem
# 26     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 28      jonatan360  Bogota-Hack-1-2017      jonatan360
# 30  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# ...

# %%
df1_tech_phase4[['Student', 'Tech Score']]
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 3     adamantwharf         50
# 5        bdcajicam       62.5
# 7   andfsanchezlem          0
# 9      dfhincapiem       37.5
# 11       helmeraac       37.5
# 13      dasalgadob         50
# 15      falperezgo        100
# 17       djguzmanc       62.5
# 18         ItsNavi          0
# 20      gsuarezc04         25
# 22          oeroaq         75
# 24         gcantem        100
# 26     Semoralesga       62.5
# 28      jonatan360        100
# 30  jesusfchavarro         75
# 31    stevenbustos       62.5
# 34  jufcontrerasco         75
# 36      dsbarrerag       87.5
# 38       wolfstain       87.5
# 39         Zeugmax          0
# 40     kastellanos          0
# 41    JairVillalba       62.5
# 43      miaborjaac         75
# 45   ivdgonzalezco         75
# 47    maikellPardo         25
# 49    Christian7sr         75
# 51      jsnarvaezb         75
# 52   gfalbarracinr         50
# 54        aldiazve       87.5
# ...

# %%
df1_final_tech_phase4 = df1_tech_phase4[['Student', 'Tech Score']]
df1_final_tech_phase4
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 3     adamantwharf         50
# 5        bdcajicam       62.5
# 7   andfsanchezlem          0
# 9      dfhincapiem       37.5
# 11       helmeraac       37.5
# 13      dasalgadob         50
# 15      falperezgo        100
# 17       djguzmanc       62.5
# 18         ItsNavi          0
# 20      gsuarezc04         25
# 22          oeroaq         75
# 24         gcantem        100
# 26     Semoralesga       62.5
# 28      jonatan360        100
# 30  jesusfchavarro         75
# 31    stevenbustos       62.5
# 34  jufcontrerasco         75
# 36      dsbarrerag       87.5
# 38       wolfstain       87.5
# 39         Zeugmax          0
# 40     kastellanos          0
# 41    JairVillalba       62.5
# 43      miaborjaac         75
# 45   ivdgonzalezco         75
# 47    maikellPardo         25
# 49    Christian7sr         75
# 51      jsnarvaezb         75
# 52   gfalbarracinr         50
# 54        aldiazve       87.5
# ...

# %%
df1_tech_phase45 = pd.merge(df1_phase5, df1_final_tech_phase4, on='Student', how = 'outer')
df1_tech_phase45
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
df1_phase45 = pd.merge(df1_tech_phase45, df1_final_novelty_phase4, on='Student', how = 'outer')
df1_phase45
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
total1_phase4 = pd.read_csv("../data/total1-phase4.csv")
total1_phase4 = total1_phase4.loc[:, ~total1_phase4.columns.str.contains('^Unnamed')]
total1_phase4
# Out:
#            Student  Total Score
# 0           oeroaq       350.00
# 1       jonatan360       343.33
# 2   jesusfchavarro       333.33
# 3       daandradec       318.75
# 4   diegoaguevarar       312.50
# 5       miaborjaac       301.67
# 6        djguzmanc       292.29
# 7       dsbarrerag       285.00
# 8        jsviveroj       280.83
# 9       falperezgo       277.50
# 10     jiapulidoar       277.50
# 11         gcantem       264.17
# 12        aldiazve       260.00
# 13      fevargasmo       248.33
# 14      jsnarvaezb       244.17
# 15      dasalgadob       225.00
# 16        jcrubioa       215.83
# 17       wolfstain       203.33
# 18     Semoralesga       178.33
# 19     anfmorenoso       178.33
# 20       bdcajicam       174.17
# 21   ivdgonzalezco       165.00
# 22  jufcontrerasco       161.67
# 23       gasierram       160.83
# 24  joahernandezca       132.50
# 25    Christian7sr       124.17
# 26      jmhurtadoc       116.67
# 27    stevenbustos       115.83
# ...

# %%
df1_total_phase45 = pd.merge(df1_phase45, total1_phase4, on='Student', how = 'outer')
df1_total_phase45
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase4',
        'Info Viz Score': 'infovis-phase4',
        'Novelty Score': 'novelty-phase4', 
        'Tech Score': 'tech-phase4', 
        'Total Score': 'total-phase4'}
  
# call rename () method
df1_total_phase45.rename(columns=dict,
          inplace=True)

df1_total_phase45
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
import pandas as pd 

df1_phase3 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/Absolute Score Bogota1 Phase3.csv")
df1_phase3
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# ..             ...                 ...             ...
# 73      daandradec  Bogota-Hack-1-2017      daandradec
# 74        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 75        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 76  joahernandezca  Bogota-Hack-1-2017  joahernandezca
# 77  joahernandezca  Bogota-Hack-1-2017  joahernandezca
#
#                             Grader Name                         Grader Email  \
# 0                              uxjudge5    purdueironhack+uxjudge5@gmail.com
# 1   purdueironhack+techjudge1@gmail.com  purdueironhack+techjudge1@gmail.com
# ...

# %%
df1_novelty_phase3 = df1_phase3[df1_phase3['User Requirement'] != "- - -"]
df1_novelty_phase3
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 6   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 8      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 10       helmeraac  Bogota-Hack-1-2017       helmeraac
# 12      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 14      falperezgo  Bogota-Hack-1-2017      falperezgo
# 16       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 19      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 21          oeroaq  Bogota-Hack-1-2017          oeroaq
# 23         gcantem  Bogota-Hack-1-2017         gcantem
# 25     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 27      jonatan360  Bogota-Hack-1-2017      jonatan360
# 29  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# 31    stevenbustos  Bogota-Hack-1-2017    stevenbustos
# ...

# %%
df1_final_novelty_phase3 = df1_novelty_phase3[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df1_tech_phase3 = df1_phase3[df1_phase3['Tech Score'] != "- - -"]
df1_tech_phase3
# Out:
#            Project                Hack         Student  \
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 5        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 7   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 9      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 11       helmeraac  Bogota-Hack-1-2017       helmeraac
# 13      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 15      falperezgo  Bogota-Hack-1-2017      falperezgo
# 17       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 18         ItsNavi  Bogota-Hack-1-2017         ItsNavi
# 20      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 22          oeroaq  Bogota-Hack-1-2017          oeroaq
# 24         gcantem  Bogota-Hack-1-2017         gcantem
# 26     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 28      jonatan360  Bogota-Hack-1-2017      jonatan360
# 30  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# ...

# %%
df1_tech_phase3[['Student', 'Tech Score']]
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 3     adamantwharf         50
# 5        bdcajicam         50
# 7   andfsanchezlem          0
# 9      dfhincapiem       37.5
# 11       helmeraac         25
# 13      dasalgadob         50
# 15      falperezgo        100
# 17       djguzmanc       62.5
# 18         ItsNavi          0
# 20      gsuarezc04         25
# 22          oeroaq         75
# 24         gcantem       62.5
# 26     Semoralesga       62.5
# 28      jonatan360        100
# 30  jesusfchavarro         75
# 32    stevenbustos         50
# 34  jufcontrerasco         50
# 36      dsbarrerag         75
# 38       wolfstain       87.5
# 39         Zeugmax          0
# 40     kastellanos          0
# 41    JairVillalba       62.5
# 43      miaborjaac         75
# 45   ivdgonzalezco         75
# 47    maikellPardo          0
# 49    Christian7sr         75
# 51      jsnarvaezb       62.5
# 53   gfalbarracinr         50
# 55        aldiazve         75
# ...

# %%
df1_final_tech_phase3 = df1_tech_phase3[['Student', 'Tech Score']]
df1_final_tech_phase3
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 3     adamantwharf         50
# 5        bdcajicam         50
# 7   andfsanchezlem          0
# 9      dfhincapiem       37.5
# 11       helmeraac         25
# 13      dasalgadob         50
# 15      falperezgo        100
# 17       djguzmanc       62.5
# 18         ItsNavi          0
# 20      gsuarezc04         25
# 22          oeroaq         75
# 24         gcantem       62.5
# 26     Semoralesga       62.5
# 28      jonatan360        100
# 30  jesusfchavarro         75
# 32    stevenbustos         50
# 34  jufcontrerasco         50
# 36      dsbarrerag         75
# 38       wolfstain       87.5
# 39         Zeugmax          0
# 40     kastellanos          0
# 41    JairVillalba       62.5
# 43      miaborjaac         75
# 45   ivdgonzalezco         75
# 47    maikellPardo          0
# 49    Christian7sr         75
# 51      jsnarvaezb       62.5
# 53   gfalbarracinr         50
# 55        aldiazve         75
# ...

# %%
df1_tech_phase345 = pd.merge(df1_total_phase45, df1_final_tech_phase3, on='Student', how = 'outer')
df1_tech_phase345 = df1_tech_phase345.loc[:, ~df1_tech_phase345.columns.str.contains('^Unnamed')]
df1_tech_phase345
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
df1_phase3 = pd.merge(df1_tech_phase345, df1_final_novelty_phase3, on='Student', how = 'outer')
df1_phase3
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
total1_phase3 = pd.read_csv("../data/total1-phase3.csv")
total1_phase3 = total1_phase3.loc[:, ~total1_phase3.columns.str.contains('^Unnamed')]
total1_phase3
# Out:
#            Student  Total Score
# 0   jesusfchavarro       345.83
# 1       falperezgo       338.33
# 2       jonatan360       332.92
# 3       dsbarrerag       325.00
# 4   diegoaguevarar       325.00
# 5           oeroaq       320.83
# 6       fevargasmo       313.33
# 7        djguzmanc       305.00
# 8       miaborjaac       300.83
# 9        jsviveroj       293.33
# 10     jiapulidoar       281.67
# 11      daandradec       240.83
# 12        aldiazve       229.58
# 13      jsnarvaezb       228.33
# 14         gcantem       226.67
# 15        jcrubioa       205.42
# 16       wolfstain       195.00
# 17     Semoralesga       178.33
# 18       bdcajicam       157.50
# 19       gasierram       132.50
# 20  jufcontrerasco       128.33
# 21   ivdgonzalezco       124.17
# 22    Christian7sr       124.17
# 23      jmhurtadoc       120.83
# 24     anfmorenoso       115.83
# 25  joahernandezca       108.33
# 26     dfhincapiem       107.50
# 27    stevenbustos       103.33
# ...

# %%
df1_total_phase3 = pd.merge(df1_phase3, total1_phase3, on='Student', how = 'outer')
df1_total_phase3
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase3',
        'Info Viz Score': 'infovis-phase3',
        'Novelty Score': 'novelty-phase3', 
        'Tech Score': 'tech-phase3', 
        'Total Score': 'total-phase3'}
  
# call rename () method
df1_total_phase3.rename(columns=dict,
          inplace=True)

df1_total_phase3
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
import pandas as pd

df1_phase2 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/AbsoluteScore Bogota1 Phase2.csv")
df1_phase2
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# ..             ...                 ...             ...
# 73      daandradec  Bogota-Hack-1-2017      daandradec
# 74        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 75        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 76  joahernandezca  Bogota-Hack-1-2017  joahernandezca
# 77  joahernandezca  Bogota-Hack-1-2017  joahernandezca
#
#                             Grader Name                         Grader Email  \
# 0                              uxjudge5    purdueironhack+uxjudge5@gmail.com
# 1   purdueironhack+techjudge1@gmail.com  purdueironhack+techjudge1@gmail.com
# ...

# %%
df1_novelty_phase2 = df1_phase2[df1_phase2['User Requirement'] != "- - -"]
df1_novelty_phase2
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 6   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 8      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 10       helmeraac  Bogota-Hack-1-2017       helmeraac
# 12      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 14      falperezgo  Bogota-Hack-1-2017      falperezgo
# 16       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 19      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 21          oeroaq  Bogota-Hack-1-2017          oeroaq
# 23         gcantem  Bogota-Hack-1-2017         gcantem
# 25     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 27      jonatan360  Bogota-Hack-1-2017      jonatan360
# 29  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# 31    stevenbustos  Bogota-Hack-1-2017    stevenbustos
# ...

# %%
df1_final_novelty_phase2 = df1_novelty_phase2[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df1_tech_phase2 = df1_phase2[df1_phase2['Tech Score'] != "- - -"]
df1_tech_phase2
# Out:
#            Project                Hack         Student  \
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 5        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 7   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 9      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 11       helmeraac  Bogota-Hack-1-2017       helmeraac
# 13      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 15      falperezgo  Bogota-Hack-1-2017      falperezgo
# 17       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 18         ItsNavi  Bogota-Hack-1-2017         ItsNavi
# 20      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 22          oeroaq  Bogota-Hack-1-2017          oeroaq
# 24         gcantem  Bogota-Hack-1-2017         gcantem
# 26     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 28      jonatan360  Bogota-Hack-1-2017      jonatan360
# 30  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# ...

# %%
df1_tech_phase2[['Student', 'Tech Score']]
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 2     adamantwharf         50
# 5        bdcajicam         50
# 7   andfsanchezlem       12.5
# 9      dfhincapiem         50
# 11       helmeraac       37.5
# 13      dasalgadob         50
# 15      falperezgo        100
# 17       djguzmanc       62.5
# 18         ItsNavi       12.5
# 20      gsuarezc04       37.5
# 22          oeroaq         75
# 24         gcantem       62.5
# 26     Semoralesga         75
# 28      jonatan360       87.5
# 30  jesusfchavarro         75
# 32    stevenbustos         50
# 34  jufcontrerasco         50
# 36      dsbarrerag         75
# 38       wolfstain         75
# 39         Zeugmax       12.5
# 40     kastellanos          0
# 41    JairVillalba       62.5
# 43      miaborjaac       62.5
# 45   ivdgonzalezco         75
# 47    maikellPardo       12.5
# 49    Christian7sr       62.5
# 51      jsnarvaezb       62.5
# 53   gfalbarracinr       37.5
# 55        aldiazve         75
# ...

# %%
df1_final_tech_phase2 = df1_tech_phase2[['Student', 'Tech Score']]
df1_final_tech_phase2
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 2     adamantwharf         50
# 5        bdcajicam         50
# 7   andfsanchezlem       12.5
# 9      dfhincapiem         50
# 11       helmeraac       37.5
# 13      dasalgadob         50
# 15      falperezgo        100
# 17       djguzmanc       62.5
# 18         ItsNavi       12.5
# 20      gsuarezc04       37.5
# 22          oeroaq         75
# 24         gcantem       62.5
# 26     Semoralesga         75
# 28      jonatan360       87.5
# 30  jesusfchavarro         75
# 32    stevenbustos         50
# 34  jufcontrerasco         50
# 36      dsbarrerag         75
# 38       wolfstain         75
# 39         Zeugmax       12.5
# 40     kastellanos          0
# 41    JairVillalba       62.5
# 43      miaborjaac       62.5
# 45   ivdgonzalezco         75
# 47    maikellPardo       12.5
# 49    Christian7sr       62.5
# 51      jsnarvaezb       62.5
# 53   gfalbarracinr       37.5
# 55        aldiazve         75
# ...

# %%
df1_tech_phase2345 = pd.merge(df1_total_phase3, df1_final_tech_phase2, on='Student', how = 'outer')
df1_tech_phase2345 = df1_tech_phase2345.loc[:, ~df1_tech_phase2345.columns.str.contains('^Unnamed')]
df1_tech_phase2345
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
df1_phase2 = pd.merge(df1_tech_phase2345, df1_final_novelty_phase2, on='Student', how = 'outer')
df1_phase2
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
total1_phase2 = pd.read_csv("../data/total1-phase2.csv")
total1_phase2 = total1_phase2.loc[:, ~total1_phase2.columns.str.contains('^Unnamed')]
total1_phase2
# Out:
#            Student  Total Score
# 0       dsbarrerag       333.33
# 1       falperezgo       330.00
# 2       daandradec       313.33
# 3   jesusfchavarro       289.17
# 4           oeroaq       288.33
# 5        djguzmanc       266.25
# 6      jiapulidoar       256.67
# 7          gcantem       251.67
# 8       jonatan360       227.50
# 9   diegoaguevarar       219.17
# 10        aldiazve       210.83
# 11      jsnarvaezb       207.50
# 12     Semoralesga       190.83
# 13       wolfstain       190.83
# 14        jcrubioa       187.50
# 15       jsviveroj       153.33
# 16       helmeraac       150.00
# 17       gasierram       140.83
# 18      gsuarezc04       133.33
# 19      fevargasmo       129.17
# 20     dfhincapiem       128.33
# 21   ivdgonzalezco       128.33
# 22      miaborjaac       115.83
# 23     anfmorenoso       115.83
# 24    Christian7sr       111.67
# 25  jufcontrerasco       108.33
# 26    stevenbustos       103.33
# 27     nabautistal        99.17
# ...

# %%
df1_total_phase2 = pd.merge(df1_phase2, total1_phase2, on='Student', how = 'outer')
df1_total_phase2
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase2',
        'Info Viz Score': 'infovis-phase2',
        'Novelty Score': 'novelty-phase2', 
        'Tech Score': 'tech-phase2', 
        'Total Score': 'total-phase2'}
  
# call rename () method
df1_total_phase2.rename(columns=dict,
          inplace=True)

df1_total_phase2
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
import pandas as pd 

df1_phase1 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/Absolute Score Bogota1 Phase1.csv")
df1_phase1
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# ..             ...                 ...             ...
# 71      daandradec  Bogota-Hack-1-2017      daandradec
# 72        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 73        jcrubioa  Bogota-Hack-1-2017        jcrubioa
# 74  joahernandezca  Bogota-Hack-1-2017  joahernandezca
# 75  joahernandezca  Bogota-Hack-1-2017  joahernandezca
#
#                             Grader Name                         Grader Email  \
# 0                              uxjudge5    purdueironhack+uxjudge5@gmail.com
# 1   purdueironhack+techjudge1@gmail.com  purdueironhack+techjudge1@gmail.com
# ...

# %%
df1_novelty_phase1 = df1_phase1[df1_phase1['User Requirement'] != "- - -"]
df1_novelty_phase1
# Out:
#            Project                Hack         Student  \
# 0        gasierram  Bogota-Hack-1-2017       gasierram
# 3     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 5        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 7   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 10       helmeraac  Bogota-Hack-1-2017       helmeraac
# 12      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 13      falperezgo  Bogota-Hack-1-2017      falperezgo
# 15       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 20          oeroaq  Bogota-Hack-1-2017          oeroaq
# 22         gcantem  Bogota-Hack-1-2017         gcantem
# 24     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 26      jonatan360  Bogota-Hack-1-2017      jonatan360
# 28  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# 30    stevenbustos  Bogota-Hack-1-2017    stevenbustos
# 32  jufcontrerasco  Bogota-Hack-1-2017  jufcontrerasco
# 33      dsbarrerag  Bogota-Hack-1-2017      dsbarrerag
# ...

# %%
df1_final_novelty_phase1 = df1_novelty_phase1[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df1_tech_phase1 = df1_phase1[df1_phase1['Tech Score'] != "- - -"]
df1_tech_phase1
# Out:
#            Project                Hack         Student  \
# 1        gasierram  Bogota-Hack-1-2017       gasierram
# 2     adamantwharf  Bogota-Hack-1-2017    adamantwharf
# 4        bdcajicam  Bogota-Hack-1-2017       bdcajicam
# 6   andfsanchezlem  Bogota-Hack-1-2017  andfsanchezlem
# 8      dfhincapiem  Bogota-Hack-1-2017     dfhincapiem
# 9        helmeraac  Bogota-Hack-1-2017       helmeraac
# 11      dasalgadob  Bogota-Hack-1-2017      dasalgadob
# 14      falperezgo  Bogota-Hack-1-2017      falperezgo
# 16       djguzmanc  Bogota-Hack-1-2017       djguzmanc
# 17         ItsNavi  Bogota-Hack-1-2017         ItsNavi
# 18      gsuarezc04  Bogota-Hack-1-2017      gsuarezc04
# 19          oeroaq  Bogota-Hack-1-2017          oeroaq
# 21         gcantem  Bogota-Hack-1-2017         gcantem
# 23     Semoralesga  Bogota-Hack-1-2017     Semoralesga
# 25      jonatan360  Bogota-Hack-1-2017      jonatan360
# 27  jesusfchavarro  Bogota-Hack-1-2017  jesusfchavarro
# ...

# %%
df1_tech_phase1[['Student', 'Tech Score']]
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 2     adamantwharf       37.5
# 4        bdcajicam         25
# 6   andfsanchezlem         25
# 8      dfhincapiem          0
# 9        helmeraac         25
# 11      dasalgadob         50
# 14      falperezgo         75
# 16       djguzmanc       62.5
# 17         ItsNavi          0
# 18      gsuarezc04          0
# 19          oeroaq       37.5
# 21         gcantem       62.5
# 23     Semoralesga       12.5
# 25      jonatan360        100
# 27  jesusfchavarro        100
# 29    stevenbustos       12.5
# 31  jufcontrerasco          0
# 34      dsbarrerag         50
# 35       wolfstain         25
# 37         Zeugmax          0
# 39     kastellanos          0
# 40    JairVillalba       62.5
# 41      miaborjaac       62.5
# 43   ivdgonzalezco          0
# 44    maikellPardo       37.5
# 46    Christian7sr         25
# 48      jsnarvaezb         50
# 50   gfalbarracinr       12.5
# 52        aldiazve       37.5
# ...

# %%
df1_final_tech_phase1 = df1_tech_phase1[['Student', 'Tech Score']]
df1_final_tech_phase1
# Out:
#            Student Tech Score
# 1        gasierram       62.5
# 2     adamantwharf       37.5
# 4        bdcajicam         25
# 6   andfsanchezlem         25
# 8      dfhincapiem          0
# 9        helmeraac         25
# 11      dasalgadob         50
# 14      falperezgo         75
# 16       djguzmanc       62.5
# 17         ItsNavi          0
# 18      gsuarezc04          0
# 19          oeroaq       37.5
# 21         gcantem       62.5
# 23     Semoralesga       12.5
# 25      jonatan360        100
# 27  jesusfchavarro        100
# 29    stevenbustos       12.5
# 31  jufcontrerasco          0
# 34      dsbarrerag         50
# 35       wolfstain         25
# 37         Zeugmax          0
# 39     kastellanos          0
# 40    JairVillalba       62.5
# 41      miaborjaac       62.5
# 43   ivdgonzalezco          0
# 44    maikellPardo       37.5
# 46    Christian7sr         25
# 48      jsnarvaezb         50
# 50   gfalbarracinr       12.5
# 52        aldiazve       37.5
# ...

# %%
df1_tech_phase12345 = pd.merge(df1_total_phase2, df1_final_tech_phase1, on='Student', how = 'outer')
df1_tech_phase12345 = df1_tech_phase12345.loc[:, ~df1_tech_phase12345.columns.str.contains('^Unnamed')]
df1_tech_phase12345
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
df1_phase1 = pd.merge(df1_tech_phase12345, df1_final_novelty_phase1, on='Student', how = 'outer')
df1_phase1
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
total1_phase1 = pd.read_csv("../data/total1-phase1.csv")
total1_phase1 = total1_phase1.loc[:, ~total1_phase1.columns.str.contains('^Unnamed')]
total1_phase1
# Out:
#            Student  Total Score
# 0          gcantem       329.17
# 1       jonatan360       285.83
# 2        djguzmanc       280.83
# 3       falperezgo       256.67
# 4   jesusfchavarro       248.33
# 5           oeroaq       230.83
# 6       dsbarrerag       225.83
# 7      jiapulidoar       219.17
# 8        gasierram       195.00
# 9       jsnarvaezb       174.17
# 10      fevargasmo       165.00
# 11      jmhurtadoc       162.50
# 12  joahernandezca       150.00
# 13      daandradec       137.50
# 14        jcrubioa       136.67
# 15    stevenbustos       132.50
# 16      miaborjaac       120.00
# 17        aldiazve       120.00
# 18       jsviveroj       103.33
# 19      dasalgadob       100.00
# 20     anfmorenoso        97.50
# 21  jufcontrerasco        91.67
# 22    maikellPardo        87.50
# 23  diegoaguevarar        87.50
# 24    adamantwharf        82.50
# 25       wolfstain        74.17
# 26    Christian7sr        74.17
# 27  andfsanchezlem        70.00
# ...

# %%
df1_total_phase1 = pd.merge(df1_phase1, total1_phase1, on='Student', how = 'outer')
df1_total_phase1
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase1',
        'Info Viz Score': 'infovis-phase1',
        'Novelty Score': 'novelty-phase1', 
        'Tech Score': 'tech-phase1', 
        'Total Score': 'total-phase1'}
  
# call rename () method
df1_total_phase1.rename(columns=dict,
          inplace=True)

df1_total_phase1
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
df1_total_phase1.fillna(0)
# Out:
#            Student  Group user-requirement-phase5 infovis-phase5  \
# 0        gasierram      1                      40           62.5
# 1     adamantwharf      1                      20             25
# 2        bdcajicam      1                      40          29.17
# 3   andfsanchezlem      1                      20             25
# 4      dfhincapiem      1                      20             25
# 5        helmeraac      1                       0             25
# 6       dasalgadob      1                       0             25
# 7       falperezgo      1                      20          45.83
# 8        djguzmanc      1                      80          79.17
# 9       gsuarezc04      1                       0             25
# 10          oeroaq      1                     100           87.5
# 11         gcantem      1                     100          70.83
# 12     Semoralesga      1                      20          33.33
# ...

# %%
df1_total_phase1.fillna(0)
df1_total_phase1.to_csv('Bogota-1-Scores.csv')
