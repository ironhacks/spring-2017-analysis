# %%
import pandas as pd


df = pd.read_csv('pre-survey.csv')
df
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    179      True  31/01/2017 10:30
# 1         100                     95      True  02/02/2017 10:14
# 2         100                    106      True  04/02/2017 21:08
# 3         100                    615      True   06/02/2017 0:55
# 4         100                    102      True  08/02/2017 22:10
# ..        ...                    ...       ...               ...
# 225       100                     80      True  14/04/2017 11:43
# 226       100                     75      True  14/04/2017 11:47
# 227       100                    133      True  14/04/2017 22:31
# 228       100                   1001      True  17/04/2017 21:55
# 229       100                   1739      True  26/04/2017 10:28
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 0    R_2B9UmcRqC3K1exx                NaN         47.066696
# 1    R_ehdVXMehOMMche9                NaN         46.666702
# ...

# %%
df = df.dropna(axis=0, subset=['email'])
df
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 1         100                     95      True  02/02/2017 10:14
# 2         100                    106      True  04/02/2017 21:08
# 3         100                    615      True   06/02/2017 0:55
# 4         100                    102      True  08/02/2017 22:10
# 5         100                    157      True   11/02/2017 6:03
# ..        ...                    ...       ...               ...
# 225       100                     80      True  14/04/2017 11:43
# 226       100                     75      True  14/04/2017 11:47
# 227       100                    133      True  14/04/2017 22:31
# 228       100                   1001      True  17/04/2017 21:55
# 229       100                   1739      True  26/04/2017 10:28
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 1    R_ehdVXMehOMMche9                NaN         46.666702
# 2    R_110dynGvJLLAoTi                NaN         46.000000
# ...

# %%
df = df[(df.email != 'bizauionica@gmail.com') & (df.email != 'jialincheoh9@gmail.com')
       & (df.email != 'rakib1987@gmail.com') & (df.email != 'priyankjjain61@gmail.com')
        & (df.email != 'jialin327@hotmail.com') & (df.email != 'ironhacktech1@gmail.com')
        & (df.email != 'uxjudges@gmail.com') & (df.email != 'uxjudges1@gmail.com') 
        & (df.email != 'uxjudges3@gmail.com') & (df.email != 'uxjudges2@gmail.com') 
        & (df.email != 'opendigital@purdue.edu') & (df.email != 'uxjudges2@gmail.com') 
        & (df.email != 'uxjudges2@gmail.com') & (df.email != 'jadejade1023@gmail.com') 
        & (df.email != 'ironhacktech2@gmail.com')
       
       ]

df
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 25        100                    485      True   06/03/2017 8:34
# 26        100                    598      True   06/03/2017 8:40
# 27        100                    557      True   06/03/2017 8:41
# 29        100                    370      True   06/03/2017 8:44
# 30        100                   1161      True   06/03/2017 8:48
# ..        ...                    ...       ...               ...
# 220       100                    590      True  28/03/2017 11:36
# 221       100                    344      True  28/03/2017 13:21
# 222       100                    466      True  29/03/2017 13:38
# 228       100                   1001      True  17/04/2017 21:55
# 229       100                   1739      True  26/04/2017 10:28
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 25   R_3OcZPtSkKpMblc7                NaN          4.649200
# 26   R_1FkULXg7YtL44L8                NaN          4.649200
# ...

# %%
df.to_csv('final.csv')

# %%
df['email']
# Out:
# 25         afguerreroa@unal.edu.co
# 26         hsmartineza@unal.edu.co
# 27         anfmorenoso@unal.edu.co
# 29            kancas.gia@gmail.com
# 30      lau.angelica39@hotmail.com
#                   ...
# 220           ofnanezn@unal.edu.co
# 221            dspavap@unal.edu.co
# 222    castellanos1458@hotmail.com
# 228          alexwebpuro@gmail.com
# 229             rmelos@unal.edu.co
# Name: email, Length: 165, dtype: object

# %%
df1 = pd.read_csv('email-hack_id.csv')
df1
# Out:
#          username                        email  hack_id
# 0       uxjudges2          uxjudges2@gmail.com        0
# 1      jonatan360      jonatanparrat@gmail.com        1
# 2        leguzman        leguzmana@unal.edu.co        2
# 3       AFelipeGA      afguerreroa@unal.edu.co        3
# 4     hsmartineza      hsmartineza@unal.edu.co        0
# ..            ...                          ...      ...
# 161        gabi04         gsuarezc@unal.edu.co        0
# 162  Christian7sr      cdsanabriar@unal.edu.co        1
# 163  jucjimenezmo     jucjimenezmo@unal.edu.co        2
# 164      ofnanezn         ofnanezn@unal.edu.co        3
# 165   kastellanos  castellanos1458@hotmail.com        1
#
# [166 rows x 3 columns]

# %%
merged = pd.merge(df, df1, left_on="email", right_on="email", how="inner")
merged
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    485      True   06/03/2017 8:34
# 1         100                    598      True   06/03/2017 8:40
# 2         100                    557      True   06/03/2017 8:41
# 3         100                    370      True   06/03/2017 8:44
# 4         100                   1161      True   06/03/2017 8:48
# ..        ...                    ...       ...               ...
# 158       100                    658      True  27/03/2017 17:41
# 159       100                    373      True  27/03/2017 20:40
# 160       100                    590      True  28/03/2017 11:36
# 161       100                    344      True  28/03/2017 13:21
# 162       100                    466      True  29/03/2017 13:38
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 0    R_3OcZPtSkKpMblc7                NaN            4.6492
# 1    R_1FkULXg7YtL44L8                NaN            4.6492
# ...

# %%
merged_q2 = merged.replace(['Not at all Important','Very Unimportant',
                                              'Somewhat Unimportant', 'Neither Important nor Unimportant', 
                                              'Somewhat Important', 'Very Important', 'Extremely Important'], [0, 1, 2, 3, 4, 5, 6])
merged_q2
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    485      True   06/03/2017 8:34
# 1         100                    598      True   06/03/2017 8:40
# 2         100                    557      True   06/03/2017 8:41
# 3         100                    370      True   06/03/2017 8:44
# 4         100                   1161      True   06/03/2017 8:48
# ..        ...                    ...       ...               ...
# 158       100                    658      True  27/03/2017 17:41
# 159       100                    373      True  27/03/2017 20:40
# 160       100                    590      True  28/03/2017 11:36
# 161       100                    344      True  28/03/2017 13:21
# 162       100                    466      True  29/03/2017 13:38
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 0    R_3OcZPtSkKpMblc7                NaN            4.6492
# 1    R_1FkULXg7YtL44L8                NaN            4.6492
# ...

# %%
merged_q2.to_csv('merged-final.csv')

# %%
merged_q3 = merged_q2.replace(['Not at all like me','Not like me',
                                              'Not much like me', 'Neutral', 
                                              'Somewhat like me', 'Like me', 'Just like me'], [0, 1, 2, 3, 4, 5, 6])
merged_q3
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    485      True   06/03/2017 8:34
# 1         100                    598      True   06/03/2017 8:40
# 2         100                    557      True   06/03/2017 8:41
# 3         100                    370      True   06/03/2017 8:44
# 4         100                   1161      True   06/03/2017 8:48
# ..        ...                    ...       ...               ...
# 158       100                    658      True  27/03/2017 17:41
# 159       100                    373      True  27/03/2017 20:40
# 160       100                    590      True  28/03/2017 11:36
# 161       100                    344      True  28/03/2017 13:21
# 162       100                    466      True  29/03/2017 13:38
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 0    R_3OcZPtSkKpMblc7                NaN            4.6492
# 1    R_1FkULXg7YtL44L8                NaN            4.6492
# ...

# %%
merged_q3.to_csv('merged.csv')

# %%
merged_q4 = merged_q3.replace(['Strongly Disagree','Disagree',
                                              'Somewhat Disagree', 'Neither Agree nor Disagree', 
                                              'Somewhat Agree', 'Agree', 'Strongly Agree'], [0, 1, 2, 3, 4, 5, 6])
merged_q4
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    485      True   06/03/2017 8:34
# 1         100                    598      True   06/03/2017 8:40
# 2         100                    557      True   06/03/2017 8:41
# 3         100                    370      True   06/03/2017 8:44
# 4         100                   1161      True   06/03/2017 8:48
# ..        ...                    ...       ...               ...
# 158       100                    658      True  27/03/2017 17:41
# 159       100                    373      True  27/03/2017 20:40
# 160       100                    590      True  28/03/2017 11:36
# 161       100                    344      True  28/03/2017 13:21
# 162       100                    466      True  29/03/2017 13:38
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 0    R_3OcZPtSkKpMblc7                NaN            4.6492
# 1    R_1FkULXg7YtL44L8                NaN            4.6492
# ...

# %%
merged_q4.to_csv('merged.csv')

# %%
merged_q8 = merged_q4.replace(['Very Bad','Bad',
                                              'Poor', 'Neither Good nor Bad', 
                                              'Fair', 'Good', 'Very Good'], [0, 1, 2, 3, 4, 5, 6])
merged_q8
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    485      True   06/03/2017 8:34
# 1         100                    598      True   06/03/2017 8:40
# 2         100                    557      True   06/03/2017 8:41
# 3         100                    370      True   06/03/2017 8:44
# 4         100                   1161      True   06/03/2017 8:48
# ..        ...                    ...       ...               ...
# 158       100                    658      True  27/03/2017 17:41
# 159       100                    373      True  27/03/2017 20:40
# 160       100                    590      True  28/03/2017 11:36
# 161       100                    344      True  28/03/2017 13:21
# 162       100                    466      True  29/03/2017 13:38
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 0    R_3OcZPtSkKpMblc7                NaN            4.6492
# 1    R_1FkULXg7YtL44L8                NaN            4.6492
# ...

# %%
merged_q8.to_csv('merged.csv')

# %%
merged_q9 = merged_q8.replace(['Yes','No'], [0, 1])
merged_q9
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    485      True   06/03/2017 8:34
# 1         100                    598      True   06/03/2017 8:40
# 2         100                    557      True   06/03/2017 8:41
# 3         100                    370      True   06/03/2017 8:44
# 4         100                   1161      True   06/03/2017 8:48
# ..        ...                    ...       ...               ...
# 158       100                    658      True  27/03/2017 17:41
# 159       100                    373      True  27/03/2017 20:40
# 160       100                    590      True  28/03/2017 11:36
# 161       100                    344      True  28/03/2017 13:21
# 162       100                    466      True  29/03/2017 13:38
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 0    R_3OcZPtSkKpMblc7                NaN            4.6492
# 1    R_1FkULXg7YtL44L8                NaN            4.6492
# ...

# %%
merged_q10 = merged_q9.replace(['bottom of the class','Below Average', 'Average', 'Top 10', 'Top 3'], [0, 1, 2, 3, 4])
merged_q10
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    485      True   06/03/2017 8:34
# 1         100                    598      True   06/03/2017 8:40
# 2         100                    557      True   06/03/2017 8:41
# 3         100                    370      True   06/03/2017 8:44
# 4         100                   1161      True   06/03/2017 8:48
# ..        ...                    ...       ...               ...
# 158       100                    658      True  27/03/2017 17:41
# 159       100                    373      True  27/03/2017 20:40
# 160       100                    590      True  28/03/2017 11:36
# 161       100                    344      True  28/03/2017 13:21
# 162       100                    466      True  29/03/2017 13:38
#
#             ResponseId  RecipientLastName  LocationLatitude  \
# 0    R_3OcZPtSkKpMblc7                NaN            4.6492
# 1    R_1FkULXg7YtL44L8                NaN            4.6492
# ...

# %%
merged_q10.to_csv('merged_final.csv')

# %%
df3 = merged.loc[merged['hack_id'] == 3]
df3
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 0         100                    485      True   06/03/2017 8:34
# 4         100                   1161      True   06/03/2017 8:48
# 8         100                   1102      True   06/03/2017 9:22
# 12        100                    836      True   06/03/2017 9:45
# 16        100                    816      True  06/03/2017 10:31
# 20        100                    523      True  06/03/2017 12:41
# 24        100                   3644      True  06/03/2017 13:18
# 28        100                    881      True  06/03/2017 13:31
# 34        100                   4336      True  06/03/2017 13:44
# 36        100                    933      True  06/03/2017 14:37
# 41        100                    388      True  06/03/2017 15:59
# 44        100                    718      True  06/03/2017 16:32
# 48        100                    638      True  06/03/2017 17:06
# ...

# %%
df2 = merged.loc[merged['hack_id'] == 2]
df2
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 3         100                    370      True   06/03/2017 8:44
# 7         100                    709      True   06/03/2017 9:16
# 11        100                    590      True   06/03/2017 9:43
# 15        100                   2041      True  06/03/2017 10:15
# 19        100                    511      True  06/03/2017 12:38
# 23        100                   3824      True  06/03/2017 13:14
# 27        100                    662      True  06/03/2017 13:30
# 31        100                   1775      True  06/03/2017 13:38
# 40        100                   1224      True  06/03/2017 15:51
# 43        100                   1042      True  06/03/2017 16:27
# 47        100                    605      True  06/03/2017 17:03
# 51        100                   2675      True  06/03/2017 17:30
# 52        100                   1218      True  06/03/2017 17:46
# ...

# %%
df1 = merged.loc[merged['hack_id'] == 1]
df1
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 2         100                    557      True   06/03/2017 8:41
# 6         100                    555      True   06/03/2017 9:15
# 10        100                   1411      True   06/03/2017 9:33
# 14        100                   1305      True  06/03/2017 10:07
# 18        100                    910      True  06/03/2017 12:09
# 22        100                   3718      True  06/03/2017 13:14
# 26        100                    747      True  06/03/2017 13:27
# 30        100                    611      True  06/03/2017 13:35
# 32        100                   1303      True  06/03/2017 13:44
# 33        100                    418      True  06/03/2017 13:52
# 37        100                   2131      True  06/03/2017 14:39
# 39        100                    345      True  06/03/2017 14:47
# 42        100                   1197      True  06/03/2017 16:23
# ...

# %%
df0 = merged.loc[merged['hack_id'] == 0]
df0
# Out:
#      Progress  Duration (in seconds)  Finished      RecordedDate  \
# 1         100                    598      True   06/03/2017 8:40
# 5         100                   1304      True   06/03/2017 8:49
# 9         100                    572      True   06/03/2017 9:26
# 13        100                    763      True  06/03/2017 10:02
# 17        100                   1835      True  06/03/2017 11:08
# 21        100                    860      True  06/03/2017 12:54
# 25        100                   3133      True  06/03/2017 13:21
# 29        100                    829      True  06/03/2017 13:31
# 35        100                   5559      True  06/03/2017 13:45
# 38        100                    885      True  06/03/2017 14:40
# 45        100                   5171      True  06/03/2017 16:55
# 49        100                   1027      True  06/03/2017 17:15
# 54        100                    558      True  06/03/2017 18:01
# ...
