# %%
import pandas as pd

info = pd.read_csv("loc-win.csv")
info
# Out:
#                                      commit-id             name  \
# 0     e174fca993401473e33731f57f7354a77cf66a11        AFelipeGA
# 1     30c53931ba6ccfea0034b927985f4b8fe354d6db  Felipe Guerrero
# 2     f076dd4c77551c783165326817834e05d4c05740  Felipe Guerrero
# 3     d811a1832b23c6d8560ab3f4942fb34fd5c15ae9  Felipe Guerrero
# 4     540c77dae0e8ce6d4a985bfb1d47fe634bc664ba        AFelipeGA
# ...                                        ...              ...
# 1651  b5103d9a1334f16901cf500ef4ce00ad4293f380   Yessica Chauta
# 1652  49275b5057187fcd3e00c3fe35f846badb991ab6   Yessica Chauta
# 1653  a0f1e06b64e8568e65208e17d4ee2777768fda0b   Yessica Chauta
# 1654  b641122a34f2db327b3cf0c07e04f9c49b5cf9ac   Yessica Chauta
# 1655  e679da444041a15c2c7ed367f8254e0539f8e245   Yessica Chauta
#
#                         email              date
# 0     afguerreroa@unal.edu.co  05/04/2017 23:38
# 1     afguerreroa@unal.edu.co   06/04/2017 4:37
# 2     afguerreroa@unal.edu.co  05/04/2017 23:34
# ...

# %%
import pandas as pd

loc = pd.read_csv("loc-final.csv")
filled = loc.fillna(0)
filled
# Out:
#                                      commit-id  files  additions  deletions
# 0     e174fca993401473e33731f57f7354a77cf66a11    1.0        2.0       11.0
# 1     30c53931ba6ccfea0034b927985f4b8fe354d6db   43.0    23533.0        0.0
# 2     f076dd4c77551c783165326817834e05d4c05740    0.0        0.0        0.0
# 3     d811a1832b23c6d8560ab3f4942fb34fd5c15ae9   30.0        0.0     1351.0
# 4     540c77dae0e8ce6d4a985bfb1d47fe634bc664ba    1.0       24.0        7.0
# ...                                        ...    ...        ...        ...
# 2206  a0f1e06b64e8568e65208e17d4ee2777768fda0b    2.0      106.0       13.0
# 2207  b641122a34f2db327b3cf0c07e04f9c49b5cf9ac    1.0       46.0        1.0
# 2208  e679da444041a15c2c7ed367f8254e0539f8e245    8.0      101.0        2.0
# 2209  fe8fa265a378051ef805e4cbfb12d9df2540225f    1.0        3.0        0.0
# 2210  fe8fa265a378051ef805e4cbfb12d9df2540225f    1.0        3.0        0.0
#
# [2211 rows x 4 columns]

# %%
result = pd.merge(info, filled[['commit-id', 'files', 'additions', 'deletions']], on='commit-id', how='right')
filled_result = result.fillna(0)
final_result = filled_result[filled_result.name != 0]
final_result
# Out:
#                                      commit-id             name  \
# 0     e174fca993401473e33731f57f7354a77cf66a11        AFelipeGA
# 1     30c53931ba6ccfea0034b927985f4b8fe354d6db  Felipe Guerrero
# 2     f076dd4c77551c783165326817834e05d4c05740  Felipe Guerrero
# 3     d811a1832b23c6d8560ab3f4942fb34fd5c15ae9  Felipe Guerrero
# 4     540c77dae0e8ce6d4a985bfb1d47fe634bc664ba        AFelipeGA
# ...                                        ...              ...
# 2204  b5103d9a1334f16901cf500ef4ce00ad4293f380   Yessica Chauta
# 2205  49275b5057187fcd3e00c3fe35f846badb991ab6   Yessica Chauta
# 2206  a0f1e06b64e8568e65208e17d4ee2777768fda0b   Yessica Chauta
# 2207  b641122a34f2db327b3cf0c07e04f9c49b5cf9ac   Yessica Chauta
# 2208  e679da444041a15c2c7ed367f8254e0539f8e245   Yessica Chauta
#
#                         email              date  files  additions  deletions
# 0     afguerreroa@unal.edu.co  05/04/2017 23:38    1.0        2.0       11.0
# ...

# %%
score = pd.read_csv("../scores/spring-2017-analysis/overall_score_click_result.csv")
score = score.rename(columns={'Student': 'name'})
score
# Out:
#      Unnamed: 0                name  Group  user-requirement-phase5  \
# 0             0           fffeelipe    0.0                     20.0
# 1             1           mnguzmanc    0.0                     60.0
# 2             2          jmcuestasb    0.0                    100.0
# 3             3          katherinsb    0.0                     20.0
# 4             4        jjrodriguezn    0.0                     60.0
# ..          ...                 ...    ...                      ...
# 159         159       jumcorredorro    3.0                    100.0
# 160         160          feartheGru    3.0                      0.0
# 161         161        Danielsv9207    3.0                      0.0
# 162         162  JhonEmmanuelTorres    3.0                      0.0
# 163         163          janoguerab    0.0                      0.0
#
#      infovis-phase5  novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
result = pd.merge(final_result, score[['name', 'Group']], on='name', how='left')
result.to_csv('result_name.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig,ax = plt.subplots()
sns.set_theme(style="whitegrid")
sns.lineplot(data=final_result, hue='name', x='date', y='additions')
sns.set(rc = {'figure.figsize':(100,5)})
#fig.set_figheight(10)
ax.set(ylim=(0, 500))
ax.set(xlim=(0, 210))
plt.legend(bbox_to_anchor=(2, 2), loc=2, borderaxespad=0.)
plt.show()

# %%
import pandas as pd

commit = pd.read_csv("commit-data.csv")
commit
# Out:
#       Unnamed: 0                                 commit-id             name  \
# 0              0  e174fca993401473e33731f57f7354a77cf66a11        AFelipeGA
# 1              1  30c53931ba6ccfea0034b927985f4b8fe354d6db  Felipe Guerrero
# 2              2  d811a1832b23c6d8560ab3f4942fb34fd5c15ae9  Felipe Guerrero
# 3              3  540c77dae0e8ce6d4a985bfb1d47fe634bc664ba        AFelipeGA
# 4              4  0a0bde5bb5780ea5fb7e55fcaf358a93c95523c6  Felipe Guerrero
# ...          ...                                       ...              ...
# 1573        1578  b5103d9a1334f16901cf500ef4ce00ad4293f380   Yessica Chauta
# 1574        1579  49275b5057187fcd3e00c3fe35f846badb991ab6   Yessica Chauta
# 1575        1580  a0f1e06b64e8568e65208e17d4ee2777768fda0b   Yessica Chauta
# 1576        1581  b641122a34f2db327b3cf0c07e04f9c49b5cf9ac   Yessica Chauta
# 1577        1582  e679da444041a15c2c7ed367f8254e0539f8e245   Yessica Chauta
#
# ...

# %%
group3 = commit.loc[commit['Group'] == 3]
group3
# Out:
#       Unnamed: 0                                 commit-id             name  \
# 0              0  e174fca993401473e33731f57f7354a77cf66a11        AFelipeGA
# 1              1  30c53931ba6ccfea0034b927985f4b8fe354d6db  Felipe Guerrero
# 2              2  d811a1832b23c6d8560ab3f4942fb34fd5c15ae9  Felipe Guerrero
# 3              3  540c77dae0e8ce6d4a985bfb1d47fe634bc664ba        AFelipeGA
# 4              4  0a0bde5bb5780ea5fb7e55fcaf358a93c95523c6  Felipe Guerrero
# ...          ...                                       ...              ...
# 1522        1527  6328c2a70b293694de6d4d1d30c3c2a8e63c4ab1    wapiravaguens
# 1523        1528  4ad0ede573fc16b1ddd0a9941638e1d5be7035fd    Wilson Tellez
# 1524        1529  6f4a9c6b0bcef03d6845f4e9892a96d759958ddc    Wilson Tellez
# 1525        1530  8bb020eba6993600201d53f551454899887a239d    Wilson Tellez
# 1526        1531  2027032879122e57e18a5d6b75520de36a4d8862    Wilson Tellez
#
# ...

# %%
group2 = commit.loc[commit['Group'] == 2]
group2
# Out:
#       Unnamed: 0                                 commit-id              name  \
# 32            33  fe398879d1f9b66eb87b74223f3268fa46410f4e        Dandarprox
# 33            34  97bc1a4c877e3f2b7b70ba017f2bc436653bf098        Dandarprox
# 34            35  bc8fff688b112a326bb7ed2a26d212d933f62fec  Daniel Rodriguez
# 35            36  a38ac54f742556860d20998fd484588a5ad31ce2  Daniel Rodriguez
# 36            37  62283a91c389c5867376a263d27f8521f9fe3524        Dandarprox
# ...          ...                                       ...               ...
# 1573        1578  b5103d9a1334f16901cf500ef4ce00ad4293f380    Yessica Chauta
# 1574        1579  49275b5057187fcd3e00c3fe35f846badb991ab6    Yessica Chauta
# 1575        1580  a0f1e06b64e8568e65208e17d4ee2777768fda0b    Yessica Chauta
# 1576        1581  b641122a34f2db327b3cf0c07e04f9c49b5cf9ac    Yessica Chauta
# 1577        1582  e679da444041a15c2c7ed367f8254e0539f8e245    Yessica Chauta
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig,ax = plt.subplots()
sns.set_theme(style="whitegrid")
sns.lineplot(data=group3, hue='name', x='date', y='additions')
sns.set(rc = {'figure.figsize':(100,5)})
#fig.set_figheight(10)
ax.set(ylim=(0, 500))
ax.set(xlim=(0, 210))
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig,ax = plt.subplots()
sns.set_theme(style="whitegrid")
sns.lineplot(data=group2, hue='name', x='date', y='additions')
sns.set(rc = {'figure.figsize':(100,5)})
#fig.set_figheight(10)
ax.set(ylim=(0, 500))
ax.set(xlim=(0, 210))
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.show()
