# %%
import pandas as pd 

df3_phase5 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/AbsoluteScore Bogota3 Phase5.csv")
df3_phase5
# Out:
#           Project                Hack        Student  \
# 0       lemartinp  Bogota-Hack-3-2017      lemartinp
# 1       lemartinp  Bogota-Hack-3-2017      lemartinp
# 2       juligarji  Bogota-Hack-3-2017      juligarji
# 3       juligarji  Bogota-Hack-3-2017      juligarji
# 4       nfmorenog  Bogota-Hack-3-2017      nfmorenog
# ..            ...                 ...            ...
# 74      lizzyt10h  Bogota-Hack-3-2017      lizzyt10h
# 75     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 76     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 77  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
# 78  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# ...

# %%
df3_novelty_phase5 = df3_phase5[df3_phase5['User Requirement'] != "- - -"]
df3_novelty_phase5
# Out:
#             Project                Hack          Student  \
# 0         lemartinp  Bogota-Hack-3-2017        lemartinp
# 2         juligarji  Bogota-Hack-3-2017        juligarji
# 4         nfmorenog  Bogota-Hack-3-2017        nfmorenog
# 6         AFelipeGA  Bogota-Hack-3-2017        AFelipeGA
# 8        mballeng91  Bogota-Hack-3-2017       mballeng91
# 10         dduartec  Bogota-Hack-3-2017         dduartec
# 12        srmedinac  Bogota-Hack-3-2017        srmedinac
# 14     wilson911013  Bogota-Hack-3-2017     wilson911013
# 16    wapiravaguens  Bogota-Hack-3-2017    wapiravaguens
# 18         davidh17  Bogota-Hack-3-2017         davidh17
# 20   DianaNavarrete  Bogota-Hack-3-2017   DianaNavarrete
# 22        jdmonroyg  Bogota-Hack-3-2017        jdmonroyg
# 25        jorge52an  Bogota-Hack-3-2017        jorge52an
# 27  jscastelblancoh  Bogota-Hack-3-2017  jscastelblancoh
# 29       juclopezso  Bogota-Hack-3-2017       juclopezso
# ...

# %%
df3_final_novelty_phase5 = df3_novelty_phase5[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df3_tech_phase5 = df3_phase5[df3_phase5['Tech Score'] != "- - -"]
df3_tech_phase5
# Out:
#                Project                Hack             Student  \
# 1            lemartinp  Bogota-Hack-3-2017           lemartinp
# 3            juligarji  Bogota-Hack-3-2017           juligarji
# 5            nfmorenog  Bogota-Hack-3-2017           nfmorenog
# 7            AFelipeGA  Bogota-Hack-3-2017           AFelipeGA
# 9           mballeng91  Bogota-Hack-3-2017          mballeng91
# 11            dduartec  Bogota-Hack-3-2017            dduartec
# 13           srmedinac  Bogota-Hack-3-2017           srmedinac
# 15        wilson911013  Bogota-Hack-3-2017        wilson911013
# 17       wapiravaguens  Bogota-Hack-3-2017       wapiravaguens
# 19            davidh17  Bogota-Hack-3-2017            davidh17
# 21      DianaNavarrete  Bogota-Hack-3-2017      DianaNavarrete
# 23           jdmonroyg  Bogota-Hack-3-2017           jdmonroyg
# 24          feartheGru  Bogota-Hack-3-2017          feartheGru
# 26           jorge52an  Bogota-Hack-3-2017           jorge52an
# ...

# %%
df3_tech_phase5[['Student', 'Tech Score']]
# Out:
#                Student Tech Score
# 1            lemartinp       87.5
# 3            juligarji       87.5
# 5            nfmorenog         75
# 7            AFelipeGA       87.5
# 9           mballeng91       62.5
# 11            dduartec       87.5
# 13           srmedinac         75
# 15        wilson911013         50
# 17       wapiravaguens        100
# 19            davidh17       87.5
# 21      DianaNavarrete       37.5
# 23           jdmonroyg         25
# 24          feartheGru          0
# 26           jorge52an        100
# 28     jscastelblancoh         75
# 30          juclopezso       87.5
# 32           afforeroc       62.5
# 33        Danielsv9207          0
# 34  JhonEmmanuelTorres          0
# 36         dagofonseca       87.5
# 38         lacardenasv        100
# 40         oacastillol         75
# 42          ncampuzano       87.5
# 44            adriel62       87.5
# 46            capinzor        100
# 48            ofnanezn         75
# ...

# %%
df3_final_tech_phase5 = df3_tech_phase5[['Student', 'Tech Score']]
df3_final_tech_phase5
# Out:
#                Student Tech Score
# 1            lemartinp       87.5
# 3            juligarji       87.5
# 5            nfmorenog         75
# 7            AFelipeGA       87.5
# 9           mballeng91       62.5
# 11            dduartec       87.5
# 13           srmedinac         75
# 15        wilson911013         50
# 17       wapiravaguens        100
# 19            davidh17       87.5
# 21      DianaNavarrete       37.5
# 23           jdmonroyg         25
# 24          feartheGru          0
# 26           jorge52an        100
# 28     jscastelblancoh         75
# 30          juclopezso       87.5
# 32           afforeroc       62.5
# 33        Danielsv9207          0
# 34  JhonEmmanuelTorres          0
# 36         dagofonseca       87.5
# 38         lacardenasv        100
# 40         oacastillol         75
# 42          ncampuzano       87.5
# 44            adriel62       87.5
# 46            capinzor        100
# 48            ofnanezn         75
# ...

# %%
df3_phase5 = pd.merge(df3_final_novelty_phase5, df3_final_tech_phase5, on='Student', how = 'outer')
df3_phase5
# Out:
#                Student User Requirement Info Viz Score Novelty Score  \
# 0            lemartinp              100          54.17          87.5
# 1            juligarji              100             75          92.5
# 2            nfmorenog                0           37.5            15
# 3            AFelipeGA               40           37.5         56.25
# 4           mballeng91                0             25            25
# 5             dduartec               80          83.33            95
# 6            srmedinac               20          33.33             0
# 7         wilson911013                0             25             0
# 8        wapiravaguens               80             75          72.5
# 9             davidh17               20          45.83         56.25
# 10      DianaNavarrete               20           62.5            25
# 11           jdmonroyg                0             25            25
# 12           jorge52an              100             50            60
# ...

# %%
bogota3 = pd.read_csv('../data/total3-phase5.csv')
bogota3
# Out:
#                Student  Unnamed: 1  Unnamed: 2  Total Score  Unnamed: 4  \
# 0           NicolasPrr         NaN         NaN       360.83         NaN
# 1      jscastelblancoh         NaN         NaN       358.33         NaN
# 2            juligarji         NaN         NaN       355.00         NaN
# 3          lacardenasv         NaN         NaN       350.00         NaN
# 4           jmalvarezd         NaN         NaN       348.75         NaN
# 5             dduartec         NaN         NaN       345.83         NaN
# 6           lgmoralesa         NaN         NaN       345.83         NaN
# 7            lemartinp         NaN         NaN       329.17         NaN
# 8        wapiravaguens         NaN         NaN       327.50         NaN
# 9        jumcorredorro         NaN         NaN       325.00         NaN
# 10           jorge52an         NaN         NaN       310.00         NaN
# 11            adriel62         NaN         NaN       301.67         NaN
# ...

# %%
bogota3 = bogota3[['Student', 'Total Score']]
bogota3
# Out:
#                Student  Total Score
# 0           NicolasPrr       360.83
# 1      jscastelblancoh       358.33
# 2            juligarji       355.00
# 3          lacardenasv       350.00
# 4           jmalvarezd       348.75
# 5             dduartec       345.83
# 6           lgmoralesa       345.83
# 7            lemartinp       329.17
# 8        wapiravaguens       327.50
# 9        jumcorredorro       325.00
# 10           jorge52an       310.00
# 11            adriel62       301.67
# 12         kgbayala528       298.75
# 13             DavidQP       284.17
# 14          juclopezso       278.75
# 15         afceballosr       270.83
# 16           lizzyt10h       255.42
# 17         oacastillol       235.00
# 18         dagofonseca       231.67
# 19           AFelipeGA       221.25
# 20            davidh17       209.58
# 21             sarizag       209.58
# 22          ncampuzano       203.33
# 23            capinzor       203.33
# 24            ofnanezn       198.33
# ...

# %%
df3_phase5 = pd.merge(df3_phase5, bogota3, on='Student', how = 'outer')
df3_phase5
# Out:
#                Student User Requirement Info Viz Score Novelty Score  \
# 0            lemartinp              100          54.17          87.5
# 1            juligarji              100             75          92.5
# 2            nfmorenog                0           37.5            15
# 3            AFelipeGA               40           37.5         56.25
# 4           mballeng91                0             25            25
# 5             dduartec               80          83.33            95
# 6            srmedinac               20          33.33             0
# 7         wilson911013                0             25             0
# 8        wapiravaguens               80             75          72.5
# 9             davidh17               20          45.83         56.25
# 10      DianaNavarrete               20           62.5            25
# 11           jdmonroyg                0             25            25
# 12           jorge52an              100             50            60
# ...

# %%
df3_phase5.insert (1, "Group", 3)
df3_phase5 = df3_phase5.fillna(0)
df3_phase5
# Out:
#                Student  Group User Requirement Info Viz Score Novelty Score  \
# 0            lemartinp      3              100          54.17          87.5
# 1            juligarji      3              100             75          92.5
# 2            nfmorenog      3                0           37.5            15
# 3            AFelipeGA      3               40           37.5         56.25
# 4           mballeng91      3                0             25            25
# 5             dduartec      3               80          83.33            95
# 6            srmedinac      3               20          33.33             0
# 7         wilson911013      3                0             25             0
# 8        wapiravaguens      3               80             75          72.5
# 9             davidh17      3               20          45.83         56.25
# 10      DianaNavarrete      3               20           62.5            25
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase5',
        'Info Viz Score': 'infovis-phase5',
        'Novelty Score': 'novelty-phase5', 
        'Tech Score': 'tech-phase5', 
        'Total Score': 'total-phase5'}
  
# call rename () method
df3_phase5.rename(columns=dict,
          inplace=True)

df3_phase5
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
import pandas as pd 

df3_phase4 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/Absolute Score Bogota2 Phase 4.csv")
df3_phase4
# Out:
#          Project                Hack       Student  \
# 0   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 1   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 2        bdvegat  Bogota-Hack-2-2017       bdvegat
# 3        bdvegat  Bogota-Hack-2-2017       bdvegat
# 4     Phoenixest  Bogota-Hack-2-2017    Phoenixest
# ..           ...                 ...           ...
# 69  luealfonsoru  Bogota-Hack-2-2017  luealfonsoru
# 70      oserasoa  Bogota-Hack-2-2017      oserasoa
# 71      oserasoa  Bogota-Hack-2-2017      oserasoa
# 72     xdanielsb  Bogota-Hack-2-2017     xdanielsb
# 73     xdanielsb  Bogota-Hack-2-2017     xdanielsb
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2                              uxjudge4    purdueironhack+uxjudge4@gmail.com
# ...

# %%
import pandas as pd 

df3_phase4 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/AbsoluteScore Bogota3 Phase4.csv")
df3_phase4
# Out:
#           Project                Hack        Student  \
# 0       lemartinp  Bogota-Hack-3-2017      lemartinp
# 1       lemartinp  Bogota-Hack-3-2017      lemartinp
# 2       juligarji  Bogota-Hack-3-2017      juligarji
# 3       juligarji  Bogota-Hack-3-2017      juligarji
# 4       nfmorenog  Bogota-Hack-3-2017      nfmorenog
# ..            ...                 ...            ...
# 73      lizzyt10h  Bogota-Hack-3-2017      lizzyt10h
# 74     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 75     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 76  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
# 77  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# ...

# %%
df3_novelty_phase4 = df3_phase4[df3_phase4['User Requirement'] != "- - -"]
df3_novelty_phase4
# Out:
#             Project                Hack          Student  \
# 0         lemartinp  Bogota-Hack-3-2017        lemartinp
# 2         juligarji  Bogota-Hack-3-2017        juligarji
# 4         nfmorenog  Bogota-Hack-3-2017        nfmorenog
# 6         AFelipeGA  Bogota-Hack-3-2017        AFelipeGA
# 8        mballeng91  Bogota-Hack-3-2017       mballeng91
# 10         dduartec  Bogota-Hack-3-2017         dduartec
# 13        srmedinac  Bogota-Hack-3-2017        srmedinac
# 14     wilson911013  Bogota-Hack-3-2017     wilson911013
# 17    wapiravaguens  Bogota-Hack-3-2017    wapiravaguens
# 18         davidh17  Bogota-Hack-3-2017         davidh17
# 20   DianaNavarrete  Bogota-Hack-3-2017   DianaNavarrete
# 24        jorge52an  Bogota-Hack-3-2017        jorge52an
# 26  jscastelblancoh  Bogota-Hack-3-2017  jscastelblancoh
# 28       juclopezso  Bogota-Hack-3-2017       juclopezso
# 30        afforeroc  Bogota-Hack-3-2017        afforeroc
# ...

# %%
df3_final_novelty_phase4 = df3_novelty_phase4[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df3_tech_phase4 = df3_phase4[df3_phase4['Tech Score'] != "- - -"]
df3_tech_phase4
# Out:
#                Project                Hack             Student  \
# 1            lemartinp  Bogota-Hack-3-2017           lemartinp
# 3            juligarji  Bogota-Hack-3-2017           juligarji
# 5            nfmorenog  Bogota-Hack-3-2017           nfmorenog
# 7            AFelipeGA  Bogota-Hack-3-2017           AFelipeGA
# 9           mballeng91  Bogota-Hack-3-2017          mballeng91
# 11            dduartec  Bogota-Hack-3-2017            dduartec
# 12           srmedinac  Bogota-Hack-3-2017           srmedinac
# 15        wilson911013  Bogota-Hack-3-2017        wilson911013
# 16       wapiravaguens  Bogota-Hack-3-2017       wapiravaguens
# 19            davidh17  Bogota-Hack-3-2017            davidh17
# 21      DianaNavarrete  Bogota-Hack-3-2017      DianaNavarrete
# 22           jdmonroyg  Bogota-Hack-3-2017           jdmonroyg
# 23          feartheGru  Bogota-Hack-3-2017          feartheGru
# 25           jorge52an  Bogota-Hack-3-2017           jorge52an
# ...

# %%
df3_tech_phase4[['Student', 'Tech Score']]
# Out:
#                Student Tech Score
# 1            lemartinp       87.5
# 3            juligarji        100
# 5            nfmorenog         75
# 7            AFelipeGA         75
# 9           mballeng91       62.5
# 11            dduartec       87.5
# 12           srmedinac       62.5
# 15        wilson911013       37.5
# 16       wapiravaguens       62.5
# 19            davidh17         75
# 21      DianaNavarrete       37.5
# 22           jdmonroyg          0
# 23          feartheGru          0
# 25           jorge52an         75
# 27     jscastelblancoh         75
# 29          juclopezso       62.5
# 31           afforeroc         50
# 32        Danielsv9207          0
# 33  JhonEmmanuelTorres          0
# 35         dagofonseca       87.5
# 37         lacardenasv       87.5
# 39         oacastillol       62.5
# 41          ncampuzano       62.5
# 43            adriel62       87.5
# 45            capinzor       87.5
# 47            ofnanezn         50
# ...

# %%
df3_final_tech_phase4 = df3_tech_phase4[['Student', 'Tech Score']]
df3_final_tech_phase4
# Out:
#                Student Tech Score
# 1            lemartinp       87.5
# 3            juligarji        100
# 5            nfmorenog         75
# 7            AFelipeGA         75
# 9           mballeng91       62.5
# 11            dduartec       87.5
# 12           srmedinac       62.5
# 15        wilson911013       37.5
# 16       wapiravaguens       62.5
# 19            davidh17         75
# 21      DianaNavarrete       37.5
# 22           jdmonroyg          0
# 23          feartheGru          0
# 25           jorge52an         75
# 27     jscastelblancoh         75
# 29          juclopezso       62.5
# 31           afforeroc         50
# 32        Danielsv9207          0
# 33  JhonEmmanuelTorres          0
# 35         dagofonseca       87.5
# 37         lacardenasv       87.5
# 39         oacastillol       62.5
# 41          ncampuzano       62.5
# 43            adriel62       87.5
# 45            capinzor       87.5
# 47            ofnanezn         50
# ...

# %%
df3_tech_phase45 = pd.merge(df3_phase5, df3_final_tech_phase4, on='Student', how = 'outer')
df3_tech_phase45
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
df3_phase45 = pd.merge(df3_tech_phase45, df3_final_novelty_phase4, on='Student', how = 'outer')
df3_phase45
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
total3_phase4 = pd.read_csv("../data/total3-phase4.csv")
total3_phase4 = total3_phase4.loc[:, ~total3_phase4.columns.str.contains('^Unnamed')]
total3_phase4
# Out:
#                Student  Total Score
# 0            juligarji       358.33
# 1           lgmoralesa       337.50
# 2      jscastelblancoh       316.67
# 3        jumcorredorro       305.00
# 4            lemartinp       300.83
# 5              DavidQP       271.67
# 6          dagofonseca       265.00
# 7          afceballosr       265.00
# 8          lacardenasv       260.00
# 9            jorge52an       243.33
# 10         kgbayala528       243.33
# 11          jmalvarezd       218.33
# 12       wapiravaguens       217.50
# 13            adriel62       210.83
# 14            capinzor       195.00
# 15             sarizag       190.83
# 16          ronaldsg20       165.83
# 17           AFelipeGA       152.50
# 18          juclopezso       151.67
# 19           macuestap       149.17
# 20           lizzyt10h       145.83
# 21          ncampuzano       145.00
# 22            ofnanezn       128.33
# 23           nfmorenog       120.83
# 24         oacastillol       120.83
# ...

# %%
df3_total_phase45 = pd.merge(df3_phase45, total3_phase4, on='Student', how = 'outer')
df3_total_phase45
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase4',
        'Info Viz Score': 'infovis-phase4',
        'Novelty Score': 'novelty-phase4', 
        'Tech Score': 'tech-phase4', 
        'Total Score': 'total-phase4'}
  
# call rename () method
df3_total_phase45.rename(columns=dict,
          inplace=True)

df3_total_phase45
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
import pandas as pd 

df3_phase3 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/AbsoluteScore Bogota3 Phase3.csv")
df3_phase3
# Out:
#           Project                Hack        Student  \
# 0       lemartinp  Bogota-Hack-3-2017      lemartinp
# 1       lemartinp  Bogota-Hack-3-2017      lemartinp
# 2       juligarji  Bogota-Hack-3-2017      juligarji
# 3       juligarji  Bogota-Hack-3-2017      juligarji
# 4       nfmorenog  Bogota-Hack-3-2017      nfmorenog
# ..            ...                 ...            ...
# 73      lizzyt10h  Bogota-Hack-3-2017      lizzyt10h
# 74     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 75     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 76  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
# 77  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# ...

# %%
df3_novelty_phase3 = df3_phase3[df3_phase3['User Requirement'] != "- - -"]
df3_novelty_phase3
# Out:
#             Project                Hack          Student  \
# 0         lemartinp  Bogota-Hack-3-2017        lemartinp
# 2         juligarji  Bogota-Hack-3-2017        juligarji
# 4         nfmorenog  Bogota-Hack-3-2017        nfmorenog
# 6         AFelipeGA  Bogota-Hack-3-2017        AFelipeGA
# 8        mballeng91  Bogota-Hack-3-2017       mballeng91
# 10         dduartec  Bogota-Hack-3-2017         dduartec
# 12        srmedinac  Bogota-Hack-3-2017        srmedinac
# 14     wilson911013  Bogota-Hack-3-2017     wilson911013
# 16    wapiravaguens  Bogota-Hack-3-2017    wapiravaguens
# 18         davidh17  Bogota-Hack-3-2017         davidh17
# 20   DianaNavarrete  Bogota-Hack-3-2017   DianaNavarrete
# 24        jorge52an  Bogota-Hack-3-2017        jorge52an
# 26  jscastelblancoh  Bogota-Hack-3-2017  jscastelblancoh
# 28       juclopezso  Bogota-Hack-3-2017       juclopezso
# 30        afforeroc  Bogota-Hack-3-2017        afforeroc
# ...

# %%
df3_final_novelty_phase3 = df3_novelty_phase3[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df3_tech_phase3 = df3_phase3[df3_phase3['Tech Score'] != "- - -"]
df3_tech_phase3
# Out:
#                Project                Hack             Student  \
# 1            lemartinp  Bogota-Hack-3-2017           lemartinp
# 3            juligarji  Bogota-Hack-3-2017           juligarji
# 5            nfmorenog  Bogota-Hack-3-2017           nfmorenog
# 7            AFelipeGA  Bogota-Hack-3-2017           AFelipeGA
# 9           mballeng91  Bogota-Hack-3-2017          mballeng91
# 11            dduartec  Bogota-Hack-3-2017            dduartec
# 13           srmedinac  Bogota-Hack-3-2017           srmedinac
# 15        wilson911013  Bogota-Hack-3-2017        wilson911013
# 17       wapiravaguens  Bogota-Hack-3-2017       wapiravaguens
# 19            davidh17  Bogota-Hack-3-2017            davidh17
# 21      DianaNavarrete  Bogota-Hack-3-2017      DianaNavarrete
# 22           jdmonroyg  Bogota-Hack-3-2017           jdmonroyg
# 23          feartheGru  Bogota-Hack-3-2017          feartheGru
# 25           jorge52an  Bogota-Hack-3-2017           jorge52an
# ...

# %%
df3_tech_phase3[['Student', 'Tech Score']]
# Out:
#                Student Tech Score
# 1            lemartinp       62.5
# 3            juligarji       87.5
# 5            nfmorenog         75
# 7            AFelipeGA         75
# 9           mballeng91         50
# 11            dduartec       87.5
# 13           srmedinac       62.5
# 15        wilson911013       37.5
# 17       wapiravaguens       62.5
# 19            davidh17       62.5
# 21      DianaNavarrete       37.5
# 22           jdmonroyg          0
# 23          feartheGru          0
# 25           jorge52an         75
# 27     jscastelblancoh         75
# 29          juclopezso       62.5
# 31           afforeroc         50
# 32        Danielsv9207          0
# 33  JhonEmmanuelTorres          0
# 35         dagofonseca         50
# 37         lacardenasv       87.5
# 39         oacastillol       62.5
# 41          ncampuzano       62.5
# 43            adriel62         75
# 45            capinzor        100
# 47            ofnanezn         50
# ...

# %%
df3_final_tech_phase3 = df3_tech_phase3[['Student', 'Tech Score']]
df3_final_tech_phase3
# Out:
#                Student Tech Score
# 1            lemartinp       62.5
# 3            juligarji       87.5
# 5            nfmorenog         75
# 7            AFelipeGA         75
# 9           mballeng91         50
# 11            dduartec       87.5
# 13           srmedinac       62.5
# 15        wilson911013       37.5
# 17       wapiravaguens       62.5
# 19            davidh17       62.5
# 21      DianaNavarrete       37.5
# 22           jdmonroyg          0
# 23          feartheGru          0
# 25           jorge52an         75
# 27     jscastelblancoh         75
# 29          juclopezso       62.5
# 31           afforeroc         50
# 32        Danielsv9207          0
# 33  JhonEmmanuelTorres          0
# 35         dagofonseca         50
# 37         lacardenasv       87.5
# 39         oacastillol       62.5
# 41          ncampuzano       62.5
# 43            adriel62         75
# 45            capinzor        100
# 47            ofnanezn         50
# ...

# %%
df3_tech_phase345 = pd.merge(df3_total_phase45, df3_final_tech_phase3, on='Student', how = 'outer')
df3_tech_phase345 = df3_tech_phase345.loc[:, ~df3_tech_phase345.columns.str.contains('^Unnamed')]
df3_tech_phase345
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
df3_phase3 = pd.merge(df3_tech_phase345, df3_final_novelty_phase3, on='Student', how = 'outer')
df3_phase3
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
total3_phase3 = pd.read_csv("../data/total3-phase3.csv")
total3_phase3 = total3_phase3.loc[:, ~total3_phase3.columns.str.contains('^Unnamed')]
total3_phase3
# Out:
#                Student  Total Score
# 0        jumcorredorro       330.00
# 1           lgmoralesa       310.00
# 2             dduartec       305.00
# 3           jmalvarezd       275.00
# 4          lacardenasv       264.17
# 5          kgbayala528       251.67
# 6      jscastelblancoh       230.83
# 7          dagofonseca       227.50
# 8             davidh17       220.83
# 9             capinzor       207.50
# 10           juligarji       203.33
# 11       wapiravaguens       192.50
# 12            adriel62       190.83
# 13           jorge52an       162.50
# 14          ronaldsg20       157.50
# 15           AFelipeGA       152.50
# 16            ofnanezn       148.33
# 17      DianaNavarrete       147.50
# 18           lizzyt10h       145.83
# 19           macuestap       145.00
# 20           lemartinp       136.67
# 21           nfmorenog       133.33
# 22             sarizag       128.33
# 23             DavidQP       124.17
# 24         oacastillol       120.83
# ...

# %%
df3_total_phase3 = pd.merge(df3_phase3, total3_phase3, on='Student', how = 'outer')
df3_total_phase3
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase3',
        'Info Viz Score': 'infovis-phase3',
        'Novelty Score': 'novelty-phase3', 
        'Tech Score': 'tech-phase3', 
        'Total Score': 'total-phase3'}
  
# call rename () method
df3_total_phase3.rename(columns=dict,
          inplace=True)

df3_total_phase3
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
import pandas as pd

df3_phase2 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/AbsoluteScore Bogota3 Phase2.csv")
df3_phase2
# Out:
#           Project                Hack        Student  \
# 0       lemartinp  Bogota-Hack-3-2017      lemartinp
# 1       lemartinp  Bogota-Hack-3-2017      lemartinp
# 2       juligarji  Bogota-Hack-3-2017      juligarji
# 3       juligarji  Bogota-Hack-3-2017      juligarji
# 4       nfmorenog  Bogota-Hack-3-2017      nfmorenog
# ..            ...                 ...            ...
# 73      lizzyt10h  Bogota-Hack-3-2017      lizzyt10h
# 74     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 75     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 76  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
# 77  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
#
#                             Grader Name                         Grader Email  \
# 0     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 1   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 2     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# ...

# %%
df3_novelty_phase2 = df3_phase2[df3_phase2['User Requirement'] != "- - -"]
df3_novelty_phase2
# Out:
#             Project                Hack          Student  \
# 0         lemartinp  Bogota-Hack-3-2017        lemartinp
# 2         juligarji  Bogota-Hack-3-2017        juligarji
# 4         nfmorenog  Bogota-Hack-3-2017        nfmorenog
# 6         AFelipeGA  Bogota-Hack-3-2017        AFelipeGA
# 8        mballeng91  Bogota-Hack-3-2017       mballeng91
# 10         dduartec  Bogota-Hack-3-2017         dduartec
# 12        srmedinac  Bogota-Hack-3-2017        srmedinac
# 14     wilson911013  Bogota-Hack-3-2017     wilson911013
# 16    wapiravaguens  Bogota-Hack-3-2017    wapiravaguens
# 18         davidh17  Bogota-Hack-3-2017         davidh17
# 20   DianaNavarrete  Bogota-Hack-3-2017   DianaNavarrete
# 24        jorge52an  Bogota-Hack-3-2017        jorge52an
# 26  jscastelblancoh  Bogota-Hack-3-2017  jscastelblancoh
# 28       juclopezso  Bogota-Hack-3-2017       juclopezso
# 30        afforeroc  Bogota-Hack-3-2017        afforeroc
# ...

# %%
df3_final_novelty_phase2 = df3_novelty_phase2[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df3_tech_phase2 = df3_phase2[df3_phase2['Tech Score'] != "- - -"]
df3_tech_phase2
# Out:
#                Project                Hack             Student  \
# 1            lemartinp  Bogota-Hack-3-2017           lemartinp
# 3            juligarji  Bogota-Hack-3-2017           juligarji
# 5            nfmorenog  Bogota-Hack-3-2017           nfmorenog
# 7            AFelipeGA  Bogota-Hack-3-2017           AFelipeGA
# 9           mballeng91  Bogota-Hack-3-2017          mballeng91
# 11            dduartec  Bogota-Hack-3-2017            dduartec
# 13           srmedinac  Bogota-Hack-3-2017           srmedinac
# 15        wilson911013  Bogota-Hack-3-2017        wilson911013
# 17       wapiravaguens  Bogota-Hack-3-2017       wapiravaguens
# 19            davidh17  Bogota-Hack-3-2017            davidh17
# 21      DianaNavarrete  Bogota-Hack-3-2017      DianaNavarrete
# 22           jdmonroyg  Bogota-Hack-3-2017           jdmonroyg
# 23          feartheGru  Bogota-Hack-3-2017          feartheGru
# 25           jorge52an  Bogota-Hack-3-2017           jorge52an
# ...

# %%
df3_tech_phase2[['Student', 'Tech Score']]
# Out:
#                Student Tech Score
# 1            lemartinp       62.5
# 3            juligarji       87.5
# 5            nfmorenog         75
# 7            AFelipeGA         75
# 9           mballeng91         50
# 11            dduartec       87.5
# 13           srmedinac       62.5
# 15        wilson911013       37.5
# 17       wapiravaguens       62.5
# 19            davidh17       62.5
# 21      DianaNavarrete         50
# 22           jdmonroyg       12.5
# 23          feartheGru       12.5
# 25           jorge52an         75
# 27     jscastelblancoh         75
# 29          juclopezso       62.5
# 31           afforeroc         50
# 32        Danielsv9207       12.5
# 33  JhonEmmanuelTorres       12.5
# 35         dagofonseca         50
# 37         lacardenasv       62.5
# 39         oacastillol       62.5
# 41          ncampuzano         50
# 43            adriel62       87.5
# 45            capinzor         75
# 47            ofnanezn         50
# ...

# %%
df3_final_tech_phase2 = df3_tech_phase2[['Student', 'Tech Score']]
df3_final_tech_phase2
# Out:
#                Student Tech Score
# 1            lemartinp       62.5
# 3            juligarji       87.5
# 5            nfmorenog         75
# 7            AFelipeGA         75
# 9           mballeng91         50
# 11            dduartec       87.5
# 13           srmedinac       62.5
# 15        wilson911013       37.5
# 17       wapiravaguens       62.5
# 19            davidh17       62.5
# 21      DianaNavarrete         50
# 22           jdmonroyg       12.5
# 23          feartheGru       12.5
# 25           jorge52an         75
# 27     jscastelblancoh         75
# 29          juclopezso       62.5
# 31           afforeroc         50
# 32        Danielsv9207       12.5
# 33  JhonEmmanuelTorres       12.5
# 35         dagofonseca         50
# 37         lacardenasv       62.5
# 39         oacastillol       62.5
# 41          ncampuzano         50
# 43            adriel62       87.5
# 45            capinzor         75
# 47            ofnanezn         50
# ...

# %%
df3_tech_phase2345 = pd.merge(df3_total_phase3, df3_final_tech_phase2, on='Student', how = 'outer')
df3_tech_phase2345 = df3_tech_phase2345.loc[:, ~df3_tech_phase2345.columns.str.contains('^Unnamed')]
df3_tech_phase2345
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
df3_phase2 = pd.merge(df3_tech_phase2345, df3_final_novelty_phase2, on='Student', how = 'outer')
df3_phase2
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
total3_phase2 = pd.read_csv("../data/total3-phase2.csv")
total3_phase2 = total3_phase2.loc[:, ~total3_phase2.columns.str.contains('^Unnamed')]
total3_phase2
# Out:
#                Student  Total Score
# 0             dduartec       333.33
# 1        jumcorredorro       309.17
# 2           lgmoralesa       268.33
# 3      jscastelblancoh       264.17
# 4          lacardenasv       264.17
# 5             davidh17       245.83
# 6            juligarji       242.08
# 7             adriel62       203.33
# 8           jmalvarezd       198.33
# 9        wapiravaguens       192.50
# 10         dagofonseca       190.00
# 11           jorge52an       187.50
# 12          ronaldsg20       161.67
# 13           AFelipeGA       152.50
# 14           macuestap       145.00
# 15             sarizag       140.83
# 16           nfmorenog       133.33
# 17            ofnanezn       132.50
# 18           lemartinp       131.67
# 19      DianaNavarrete       128.33
# 20          ncampuzano       124.17
# 21         kgbayala528       123.33
# 22            capinzor       120.00
# 23             DavidQP       120.00
# 24         oacastillol       116.67
# ...

# %%
df3_total_phase2 = pd.merge(df3_phase2, total3_phase2, on='Student', how = 'outer')
df3_total_phase2
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase2',
        'Info Viz Score': 'infovis-phase2',
        'Novelty Score': 'novelty-phase2', 
        'Tech Score': 'tech-phase2', 
        'Total Score': 'total-phase2'}
  
# call rename () method
df3_total_phase2.rename(columns=dict,
          inplace=True)

df3_total_phase2
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase2',
        'Info Viz Score': 'infovis-phase2',
        'Novelty Score': 'novelty-phase2', 
        'Tech Score': 'tech-phase2', 
        'Total Score': 'total-phase2'}
  
# call rename () method
df3_total_phase2.rename(columns=dict,
          inplace=True)

df3_total_phase2
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
import pandas as pd 

df2_phase1 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/Absolute Score Bogota2 Phase1.csv")
df2_phase1
# Out:
#          Project                Hack       Student  \
# 0   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 1   jusherrerama  Bogota-Hack-2-2017  jusherrerama
# 2        bdvegat  Bogota-Hack-2-2017       bdvegat
# 3        bdvegat  Bogota-Hack-2-2017       bdvegat
# 4     Phoenixest  Bogota-Hack-2-2017    Phoenixest
# ..           ...                 ...           ...
# 73      oserasoa  Bogota-Hack-2-2017      oserasoa
# 74      lsfinite  Bogota-Hack-2-2017      lsfinite
# 75      lsfinite  Bogota-Hack-2-2017      lsfinite
# 76     xdanielsb  Bogota-Hack-2-2017     xdanielsb
# 77     xdanielsb  Bogota-Hack-2-2017     xdanielsb
#
#                             Grader Name                         Grader Email  \
# 0   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 1     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 2                         tech grader 1              ironhacktech1@gmail.com
# ...

# %%
import pandas as pd 

df3_phase1 = pd.read_csv("../../../../../Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/raw-data/AbsoluteScore Bogota3 Phase1.csv")
df3_phase1
# Out:
#           Project                Hack        Student  \
# 0       lemartinp  Bogota-Hack-3-2017      lemartinp
# 1       lemartinp  Bogota-Hack-3-2017      lemartinp
# 2       juligarji  Bogota-Hack-3-2017      juligarji
# 3       juligarji  Bogota-Hack-3-2017      juligarji
# 4       nfmorenog  Bogota-Hack-3-2017      nfmorenog
# ..            ...                 ...            ...
# 71      lizzyt10h  Bogota-Hack-3-2017      lizzyt10h
# 72     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 73     NicolasPrr  Bogota-Hack-3-2017     NicolasPrr
# 74  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
# 75  jumcorredorro  Bogota-Hack-3-2017  jumcorredorro
#
#                             Grader Name                         Grader Email  \
# 0   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# 1     purdueironhack+uxjudge6@gmail.com    purdueironhack+uxjudge6@gmail.com
# 2   purdueironhack+techjudge2@gmail.com  purdueironhack+techjudge2@gmail.com
# ...

# %%
df3_novelty_phase1 = df3_phase1[df3_phase1['User Requirement'] != "- - -"]
df3_novelty_phase1
# Out:
#             Project                Hack          Student  \
# 1         lemartinp  Bogota-Hack-3-2017        lemartinp
# 3         juligarji  Bogota-Hack-3-2017        juligarji
# 5         nfmorenog  Bogota-Hack-3-2017        nfmorenog
# 7         AFelipeGA  Bogota-Hack-3-2017        AFelipeGA
# 9        mballeng91  Bogota-Hack-3-2017       mballeng91
# 10         dduartec  Bogota-Hack-3-2017         dduartec
# 12        srmedinac  Bogota-Hack-3-2017        srmedinac
# 14     wilson911013  Bogota-Hack-3-2017     wilson911013
# 16    wapiravaguens  Bogota-Hack-3-2017    wapiravaguens
# 18         davidh17  Bogota-Hack-3-2017         davidh17
# 20   DianaNavarrete  Bogota-Hack-3-2017   DianaNavarrete
# 24        jorge52an  Bogota-Hack-3-2017        jorge52an
# 26  jscastelblancoh  Bogota-Hack-3-2017  jscastelblancoh
# 28       juclopezso  Bogota-Hack-3-2017       juclopezso
# 30        afforeroc  Bogota-Hack-3-2017        afforeroc
# ...

# %%
df3_final_novelty_phase1 = df3_novelty_phase1[['Student', 'User Requirement', 'Info Viz Score', 'Novelty Score']]

# %%
df3_tech_phase1 = df3_phase1[df3_phase1['Tech Score'] != "- - -"]
df3_tech_phase1
# Out:
#                Project                Hack             Student  \
# 0            lemartinp  Bogota-Hack-3-2017           lemartinp
# 2            juligarji  Bogota-Hack-3-2017           juligarji
# 4            nfmorenog  Bogota-Hack-3-2017           nfmorenog
# 6            AFelipeGA  Bogota-Hack-3-2017           AFelipeGA
# 8           mballeng91  Bogota-Hack-3-2017          mballeng91
# 11           srmedinac  Bogota-Hack-3-2017           srmedinac
# 13        wilson911013  Bogota-Hack-3-2017        wilson911013
# 15       wapiravaguens  Bogota-Hack-3-2017       wapiravaguens
# 17            davidh17  Bogota-Hack-3-2017            davidh17
# 19      DianaNavarrete  Bogota-Hack-3-2017      DianaNavarrete
# 21           jdmonroyg  Bogota-Hack-3-2017           jdmonroyg
# 22          feartheGru  Bogota-Hack-3-2017          feartheGru
# 23           jorge52an  Bogota-Hack-3-2017           jorge52an
# 25     jscastelblancoh  Bogota-Hack-3-2017     jscastelblancoh
# ...

# %%
df3_tech_phase1[['Student', 'Tech Score']]
# Out:
#                Student Tech Score
# 0            lemartinp         25
# 2            juligarji         50
# 4            nfmorenog         50
# 6            AFelipeGA       12.5
# 8           mballeng91          0
# 11           srmedinac         25
# 13        wilson911013       12.5
# 15       wapiravaguens       62.5
# 17            davidh17       37.5
# 19      DianaNavarrete       37.5
# 21           jdmonroyg          0
# 22          feartheGru       12.5
# 23           jorge52an         50
# 25     jscastelblancoh         50
# 27          juclopezso         25
# 29           afforeroc       12.5
# 31        Danielsv9207         50
# 32  JhonEmmanuelTorres          0
# 33         dagofonseca       12.5
# 35         lacardenasv       62.5
# 38          ncampuzano          0
# 40            adriel62         25
# 42            capinzor         25
# 44            ofnanezn       12.5
# 46           macuestap        100
# 48              spenas         50
# ...

# %%
df3_final_tech_phase1 = df3_tech_phase1[['Student', 'Tech Score']]
df3_final_tech_phase1
# Out:
#                Student Tech Score
# 0            lemartinp         25
# 2            juligarji         50
# 4            nfmorenog         50
# 6            AFelipeGA       12.5
# 8           mballeng91          0
# 11           srmedinac         25
# 13        wilson911013       12.5
# 15       wapiravaguens       62.5
# 17            davidh17       37.5
# 19      DianaNavarrete       37.5
# 21           jdmonroyg          0
# 22          feartheGru       12.5
# 23           jorge52an         50
# 25     jscastelblancoh         50
# 27          juclopezso         25
# 29           afforeroc       12.5
# 31        Danielsv9207         50
# 32  JhonEmmanuelTorres          0
# 33         dagofonseca       12.5
# 35         lacardenasv       62.5
# 38          ncampuzano          0
# 40            adriel62         25
# 42            capinzor         25
# 44            ofnanezn       12.5
# 46           macuestap        100
# 48              spenas         50
# ...

# %%
df3_tech_phase12345 = pd.merge(df3_total_phase2, df3_final_tech_phase1, on='Student', how = 'outer')
df3_tech_phase12345 = df3_tech_phase12345.loc[:, ~df3_tech_phase12345.columns.str.contains('^Unnamed')]
df3_tech_phase12345
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
df3_phase1 = pd.merge(df3_tech_phase12345, df3_final_novelty_phase1, on='Student', how = 'outer')
df3_phase1
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
total3_phase1 = pd.read_csv("../data/total3-phase1.csv")
total3_phase1 = total3_phase1.loc[:, ~total3_phase1.columns.str.contains('^Unnamed')]
total3_phase1
# Out:
#                Student  Total Score
# 0           jmalvarezd       329.17
# 1        wapiravaguens       239.17
# 2      jscastelblancoh       201.67
# 3          lacardenasv       186.67
# 4        jumcorredorro       185.83
# 5           ronaldsg20       182.50
# 6            macuestap       168.75
# 7            juligarji       161.67
# 8             davidh17       155.83
# 9            lizzyt10h       154.17
# 10          lgmoralesa       136.67
# 11              spenas       128.33
# 12         afceballosr       120.00
# 13          NicolasPrr       112.50
# 14             DavidQP       111.67
# 15            capinzor       107.50
# 16         kgbayala528       107.50
# 17             sarizag       107.50
# 18           nfmorenog       104.17
# 19            adriel62       103.33
# 20      DianaNavarrete       100.00
# 21           jorge52an        99.17
# 22           smarquezo        99.17
# 23          ncampuzano        91.67
# 24         oacastillol        91.67
# ...

# %%
df3_total_phase1 = pd.merge(df3_phase1, total3_phase1, on='Student', how = 'outer')
df3_total_phase1
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
dict = {'User Requirement': 'user-requirement-phase1',
        'Info Viz Score': 'infovis-phase1',
        'Novelty Score': 'novelty-phase1', 
        'Tech Score': 'tech-phase1', 
        'Total Score': 'total-phase1'}
  
# call rename () method
df3_total_phase1.rename(columns=dict,
          inplace=True)

df3_total_phase1
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
df3_total_phase1.fillna(0)
# Out:
#                Student  Group user-requirement-phase5 infovis-phase5  \
# 0            lemartinp      3                     100          54.17
# 1            juligarji      3                     100             75
# 2            nfmorenog      3                       0           37.5
# 3            AFelipeGA      3                      40           37.5
# 4           mballeng91      3                       0             25
# 5             dduartec      3                      80          83.33
# 6            srmedinac      3                      20          33.33
# 7         wilson911013      3                       0             25
# 8        wapiravaguens      3                      80             75
# 9             davidh17      3                      20          45.83
# 10      DianaNavarrete      3                      20           62.5
# 11           jdmonroyg      3                       0             25
# 12           jorge52an      3                     100             50
# ...

# %%
df3_total_phase1.fillna(0)
df3_total_phase1.to_csv('Bogota-3-Scores.csv')
