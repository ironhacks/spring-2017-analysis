# %% [markdown]
# # Phase 1 ---- D3 Components

# %%
import pandas as pd


df1 = pd.read_csv("./data/Phase-1-Output.csv") 
df1
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              0            d3-collection_Maps_.map
# 3              1                   d3-fetch___.json
# 4              2            d3-collection_Sets_.set
# ...          ...                                ...
# 1603           0  d3-selection_Selecting_.selectAll
# 1604           1            d3-collection_Sets_.set
# 1605           2     d3-selection_Selecting_.select
# 1606           3      d3-selection_Selecting_.style
# 1607           4     d3-selection_Modifying_.create
#
#                         username_folder_name  js_loc_in_each_js
# 0        2017-Purdue-UNAL-IronHack-nfmorenog              846.0
# 1        2017-Purdue-UNAL-IronHack-nfmorenog              846.0
# 2     2017-Purdue-UNAL-IronHack-lfvalderrama             1855.0
# 3     2017-Purdue-UNAL-IronHack-lfvalderrama             1855.0
# ...

# %%
df1['username'] = df1['username_folder_name'].apply(lambda row: row.split('-')[-1])
df1
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              0            d3-collection_Maps_.map
# 3              1                   d3-fetch___.json
# 4              2            d3-collection_Sets_.set
# ...          ...                                ...
# 1603           0  d3-selection_Selecting_.selectAll
# 1604           1            d3-collection_Sets_.set
# 1605           2     d3-selection_Selecting_.select
# 1606           3      d3-selection_Selecting_.style
# 1607           4     d3-selection_Modifying_.create
#
#                         username_folder_name  js_loc_in_each_js      username
# 0        2017-Purdue-UNAL-IronHack-nfmorenog              846.0     nfmorenog
# 1        2017-Purdue-UNAL-IronHack-nfmorenog              846.0     nfmorenog
# 2     2017-Purdue-UNAL-IronHack-lfvalderrama             1855.0  lfvalderrama
# ...

# %% [markdown]
# # Phase 2 --- D3 Components

# %%
df2 = pd.read_csv("./data/Phase-2-Output.csv") 
df2
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              2            d3-collection_Sets_.set
# 3              0            d3-dispatch___.dispatch
# 4              1           d3-array_Statistics_.min
# ...          ...                                ...
# 4734           0  d3-selection_Selecting_.selectAll
# 4735           1            d3-collection_Sets_.set
# 4736           2     d3-selection_Selecting_.select
# 4737           3      d3-selection_Selecting_.style
# 4738           4     d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             4369.0
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             4369.0
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             4369.0
# 3     2017-Purdue-UNAL-IronHack-falperezgo           148390.0
# ...

# %%
df2['username'] = df2['username_folder_name'].apply(lambda row: row.split('-')[-1])
df2
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              2            d3-collection_Sets_.set
# 3              0            d3-dispatch___.dispatch
# 4              1           d3-array_Statistics_.min
# ...          ...                                ...
# 4734           0  d3-selection_Selecting_.selectAll
# 4735           1            d3-collection_Sets_.set
# 4736           2     d3-selection_Selecting_.select
# 4737           3      d3-selection_Selecting_.style
# 4738           4     d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js    username
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             4369.0   nfmorenog
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             4369.0   nfmorenog
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             4369.0   nfmorenog
# ...

# %% [markdown]
# # Phase 3 --- D3 Components

# %%
df3 = pd.read_csv("./data/Phase-3-Output.csv") 
df3
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              2            d3-collection_Sets_.set
# 3              0            d3-dispatch___.dispatch
# 4              1           d3-array_Statistics_.min
# ...          ...                                ...
# 4877           0  d3-selection_Selecting_.selectAll
# 4878           1            d3-collection_Sets_.set
# 4879           2     d3-selection_Selecting_.select
# 4880           3      d3-selection_Selecting_.style
# 4881           4     d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0
# 3     2017-Purdue-UNAL-IronHack-falperezgo           148390.0
# ...

# %%
df3['username'] = df3['username_folder_name'].apply(lambda row: row.split('-')[-1])
df3
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              2            d3-collection_Sets_.set
# 3              0            d3-dispatch___.dispatch
# 4              1           d3-array_Statistics_.min
# ...          ...                                ...
# 4877           0  d3-selection_Selecting_.selectAll
# 4878           1            d3-collection_Sets_.set
# 4879           2     d3-selection_Selecting_.select
# 4880           3      d3-selection_Selecting_.style
# 4881           4     d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js    username
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0   nfmorenog
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0   nfmorenog
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0   nfmorenog
# ...

# %% [markdown]
# # Phase 4 --- D3 Components

# %%
df4 = pd.read_csv("./data/Phase-4-Output.csv") 
df4
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              2            d3-collection_Sets_.set
# 3              0            d3-collection_Maps_.map
# 4              1       d3-selection_Handling_.event
# ...          ...                                ...
# 4942           0  d3-selection_Selecting_.selectAll
# 4943           1            d3-collection_Sets_.set
# 4944           2     d3-selection_Selecting_.select
# 4945           3      d3-selection_Selecting_.style
# 4946           4     d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0
# 3     2017-Purdue-UNAL-IronHack-falperezgo             7309.0
# ...

# %%
df4['username'] = df4['username_folder_name'].apply(lambda row: row.split('-')[-1])
df4
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              2            d3-collection_Sets_.set
# 3              0            d3-collection_Maps_.map
# 4              1       d3-selection_Handling_.event
# ...          ...                                ...
# 4942           0  d3-selection_Selecting_.selectAll
# 4943           1            d3-collection_Sets_.set
# 4944           2     d3-selection_Selecting_.select
# 4945           3      d3-selection_Selecting_.style
# 4946           4     d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js    username
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# ...

# %% [markdown]
# # Phase 5  - - -   D3 Components

# %%
df5 = pd.read_csv("./data/Phase-5-Output.csv") 
df5
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              2            d3-collection_Sets_.set
# 3              0            d3-collection_Maps_.map
# 4              1       d3-selection_Handling_.event
# ...          ...                                ...
# 4973           0  d3-selection_Selecting_.selectAll
# 4974           1            d3-collection_Sets_.set
# 4975           2     d3-selection_Selecting_.select
# 4976           3      d3-selection_Selecting_.style
# 4977           4     d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0
# 3     2017-Purdue-UNAL-IronHack-falperezgo            13466.0
# ...

# %%
df5['username'] = df5['username_folder_name'].apply(lambda row: row.split('-')[-1])

# %%
df5
# Out:
#       Unnamed: 0                         components  \
# 0              0            d3-collection_Maps_.map
# 1              1                   d3-fetch___.json
# 2              2            d3-collection_Sets_.set
# 3              0            d3-collection_Maps_.map
# 4              1       d3-selection_Handling_.event
# ...          ...                                ...
# 4973           0  d3-selection_Selecting_.selectAll
# 4974           1            d3-collection_Sets_.set
# 4975           2     d3-selection_Selecting_.select
# 4976           3      d3-selection_Selecting_.style
# 4977           4     d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js    username
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# ...

# %% [markdown]
# # Deletions Phase 1 - 5

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

deletion_12 = dataframe_difference(df1, df2, which='left_only')
deletion_12['username'] = deletion_12['username_folder_name'].apply(lambda row: row.split('-')[-1])
deletion_12

# %% [markdown]
# # Additions Phase 1 - 5

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

addition_12 = dataframe_difference(df1, df2, which='right_only')
addition_12['username'] = addition_12['username_folder_name'].apply(lambda row: row.split('-')[-1])
addition_12

# %% [markdown]
# # Deletions Phase 1 - 2

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

deletion_12 = dataframe_difference(df1, df2, which='left_only')
deletion_12['username'] = deletion_12['username_folder_name'].apply(lambda row: row.split('-')[-1])
deletion_12
# Out:
#     Unnamed: 0                     components  \
# 0            0        d3-collection_Maps_.map
# 1            1               d3-fetch___.json
# 2            0        d3-collection_Maps_.map
# 3            1               d3-fetch___.json
# 4            2        d3-collection_Sets_.set
# 9            0        d3-collection_Maps_.map
# 58           0        d3-collection_Maps_.map
# 59           1               d3-fetch___.text
# 60           2        d3-collection_Sets_.set
# 61           3                d3-drag___.drag
# 62           0        d3-collection_Maps_.map
# 63           1        d3-collection_Sets_.set
# 64           0               d3-fetch___.json
# 66           0        d3-collection_Maps_.map
# 67           1   d3-selection_Handling_.event
# 68           2               d3-fetch___.json
# 69           3        d3-collection_Sets_.set
# 74           0        d3-collection_Maps_.map
# 75           1   d3-selection_Handling_.event
# ...

# %% [markdown]
# # Additions Phase 1 - 2

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

addition_12 = dataframe_difference(df1, df2, which='right_only')
addition_12['username'] = addition_12['username_folder_name'].apply(lambda row: row.split('-')[-1])
addition_12
# Out:
#       Unnamed: 0                      components  \
# 1664           0         d3-collection_Maps_.map
# 1665           1                d3-fetch___.json
# 1666           2         d3-collection_Sets_.set
# 1667           0         d3-dispatch___.dispatch
# 1668           1        d3-array_Statistics_.min
# ...          ...                             ...
# 4814           0                d3-fetch___.json
# 4815           0       d3-selection_Local_.local
# 4816           1         d3-collection_Sets_.set
# 4817           0  d3-selection_Modifying_.create
# 4818           1          d3-shape_Stacks_.stack
#
#                        username_folder_name  js_loc_in_each_js     username  \
# 1664    2017-Purdue-UNAL-IronHack-nfmorenog             4369.0    nfmorenog
# 1665    2017-Purdue-UNAL-IronHack-nfmorenog             4369.0    nfmorenog
# 1666    2017-Purdue-UNAL-IronHack-nfmorenog             4369.0    nfmorenog
# ...

# %% [markdown]
# # Deletions Phase 2 - 3

# %%
def dataframe_difference(df2, df3, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

deletion_23 = dataframe_difference(df2, df3, which='left_only')
deletion_23['username'] = deletion_23['username_folder_name'].apply(lambda row: row.split('-')[-1])
deletion_23
# Out:
#     Unnamed: 0                     components  \
# 0            0        d3-collection_Maps_.map
# 1            1               d3-fetch___.json
# 2            0        d3-collection_Maps_.map
# 3            1               d3-fetch___.json
# 4            2        d3-collection_Sets_.set
# 9            0        d3-collection_Maps_.map
# 58           0        d3-collection_Maps_.map
# 59           1               d3-fetch___.text
# 60           2        d3-collection_Sets_.set
# 61           3                d3-drag___.drag
# 62           0        d3-collection_Maps_.map
# 63           1        d3-collection_Sets_.set
# 64           0               d3-fetch___.json
# 66           0        d3-collection_Maps_.map
# 67           1   d3-selection_Handling_.event
# 68           2               d3-fetch___.json
# 69           3        d3-collection_Sets_.set
# 74           0        d3-collection_Maps_.map
# 75           1   d3-selection_Handling_.event
# ...

# %% [markdown]
# # Additions Phase 2 - 3

# %%
def dataframe_difference(df2, df3, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

addition_23 = dataframe_difference(df2, df3, which='right_only')
addition_23['username'] = addition_23['username_folder_name'].apply(lambda row: row.split('-')[-1])
addition_23
# Out:
#       Unnamed: 0                      components  \
# 1664           0         d3-collection_Maps_.map
# 1665           1                d3-fetch___.json
# 1666           2         d3-collection_Sets_.set
# 1667           0         d3-dispatch___.dispatch
# 1668           1        d3-array_Statistics_.min
# ...          ...                             ...
# 4814           0                d3-fetch___.json
# 4815           0       d3-selection_Local_.local
# 4816           1         d3-collection_Sets_.set
# 4817           0  d3-selection_Modifying_.create
# 4818           1          d3-shape_Stacks_.stack
#
#                        username_folder_name  js_loc_in_each_js     username  \
# 1664    2017-Purdue-UNAL-IronHack-nfmorenog             4369.0    nfmorenog
# 1665    2017-Purdue-UNAL-IronHack-nfmorenog             4369.0    nfmorenog
# 1666    2017-Purdue-UNAL-IronHack-nfmorenog             4369.0    nfmorenog
# ...

# %% [markdown]
# # Deletions Phase 3 - 4

# %%
def dataframe_difference(df3, df4, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df3.merge(
        df4,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

deletion_34 = dataframe_difference(df3, df4, which='left_only')
deletion_34['username'] = deletion_34['username_folder_name'].apply(lambda row: row.split('-')[-1])
deletion_34
# Out:
#       Unnamed: 0                      components  \
# 0              0         d3-collection_Maps_.map
# 1              1                d3-fetch___.json
# 2              2         d3-collection_Sets_.set
# 148            0         d3-collection_Maps_.map
# 149            1    d3-selection_Handling_.event
# ...          ...                             ...
# 367            6               d3-color___.color
# 4473           0         d3-collection_Sets_.set
# 4474           1                d3-fetch___.text
# 4475           0         d3-collection_Maps_.map
# 4476           1  d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js    username  \
# 0      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0   nfmorenog
# 1      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0   nfmorenog
# 2      2017-Purdue-UNAL-IronHack-nfmorenog             4372.0   nfmorenog
# 148    2017-Purdue-UNAL-IronHack-xdanielsb             3213.0   xdanielsb
# ...

# %% [markdown]
# # Additions Phase 3 - 4

# %%
def dataframe_difference(df3, df4, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df3.merge(
        df4,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

addition_34 = dataframe_difference(df3, df4, which='right_only')
addition_34['username'] = addition_34['username_folder_name'].apply(lambda row: row.split('-')[-1])
addition_34
# Out:
#       Unnamed: 0                      components  \
# 6034           0         d3-collection_Maps_.map
# 6035           1                d3-fetch___.json
# 6036           2         d3-collection_Sets_.set
# 6037           0         d3-collection_Maps_.map
# 6038           1    d3-selection_Handling_.event
# ...          ...                             ...
# 6176           0                d3-fetch___.json
# 6177           0         d3-collection_Sets_.set
# 6178           1                d3-fetch___.text
# 6179           0         d3-collection_Maps_.map
# 6180           1  d3-selection_Modifying_.create
#
#                       username_folder_name  js_loc_in_each_js    username  \
# 6034   2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# 6035   2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# 6036   2017-Purdue-UNAL-IronHack-nfmorenog             5857.0   nfmorenog
# 6037  2017-Purdue-UNAL-IronHack-falperezgo             7309.0  falperezgo
# ...

# %% [markdown]
# # Deletions Phase 4 - 5

# %%
def dataframe_difference(df4, df5, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df4.merge(
        df5,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

deletion_45 = dataframe_difference(df4, df5, which='left_only')
deletion_45['username'] = deletion_45['username_folder_name'].apply(lambda row: row.split('-')[-1])
deletion_45
# Out:
#       Unnamed: 0                      components  \
# 3              0         d3-collection_Maps_.map
# 4              1    d3-selection_Handling_.event
# 5              2                d3-fetch___.json
# 6              3         d3-collection_Sets_.set
# 62             0         d3-collection_Sets_.set
# ...          ...                             ...
# 4537           0                d3-fetch___.json
# 4538           0         d3-collection_Sets_.set
# 4539           1                d3-fetch___.text
# 4540           0         d3-collection_Maps_.map
# 4541           1  d3-selection_Modifying_.create
#
#                         username_folder_name  js_loc_in_each_js      username  \
# 3       2017-Purdue-UNAL-IronHack-falperezgo             7309.0    falperezgo
# 4       2017-Purdue-UNAL-IronHack-falperezgo             7309.0    falperezgo
# 5       2017-Purdue-UNAL-IronHack-falperezgo             7309.0    falperezgo
# ...

# %% [markdown]
# # Additions Phase 4 - 5

# %%
def dataframe_difference(df4, df5, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df4.merge(
        df5,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    diff_df.to_csv('data/diff.csv')
    return diff_df

addition_45 = dataframe_difference(df4, df5, which='right_only')
addition_45['username'] = addition_45['username_folder_name'].apply(lambda row: row.split('-')[-1])
addition_45
# Out:
#       Unnamed: 0                      components  \
# 6099           0         d3-collection_Maps_.map
# 6100           1    d3-selection_Handling_.event
# 6101           2                d3-fetch___.json
# 6102           3         d3-collection_Sets_.set
# 6103           0        d3-array_Statistics_.sum
# ...          ...                             ...
# 6203           1         d3-collection_Sets_.set
# 6204           2                d3-fetch___.text
# 6205           0         d3-collection_Maps_.map
# 6206           1  d3-selection_Modifying_.create
# 6207           2         d3-collection_Sets_.set
#
#                       username_folder_name  js_loc_in_each_js    username  \
# 6099  2017-Purdue-UNAL-IronHack-falperezgo            13466.0  falperezgo
# 6100  2017-Purdue-UNAL-IronHack-falperezgo            13466.0  falperezgo
# 6101  2017-Purdue-UNAL-IronHack-falperezgo            13466.0  falperezgo
# 6102  2017-Purdue-UNAL-IronHack-falperezgo            13466.0  falperezgo
# ...
