# %%
import pandas as pd
df = pd.read_csv('data.txt', sep="|", names=['data'])

df = pd.DataFrame({'user': df.data.iloc[::2].to_numpy(),
                   'fruits': df.data.iloc[1::2].to_numpy()})

# %%
df
# Out:
#                                                   user  \
# 0                     2017-Purdue-UNAL-IronHack-cap182
# 1                  2017-Purdue-UNAL-IronHack-nfmorenog
# 2                 2017-Purdue-UNAL-IronHack-falperezgo
# 3               2017-Purdue-UNAL-IronHack-lfvalderrama
# 4                  2017-Purdue-UNAL-IronHack-xdanielsb
# ..                                                 ...
# 685  ['www.ncdc.noaa.gov/cdo-web/api/v2', 'data.cit...
# 686     ['data.cityofchicago.org/api/views/s6ha-ppgi']
# 687                                                 []
# 688                                                 []
# 689  ['data.cityofchicago.org/resource', 'data.city...
#
#                                                 fruits
# 0                                                   []
# 1    ['data.cityofchicago.org/api/views/ijzp-q8t2',...
# 2       ['data.cityofchicago.org/api/views/s6ha-ppgi']
# 3       ['data.cityofchicago.org/api/views/z8bn-74gv']
# ...

# %%
df = pd.read_csv('data.txt', sep="|", names=['data'])

df[df['data'].str.startswith('2017')]
# Out:
#                                         data
# 0           2017-Purdue-UNAL-IronHack-cap182
# 2        2017-Purdue-UNAL-IronHack-nfmorenog
# 4       2017-Purdue-UNAL-IronHack-falperezgo
# 6     2017-Purdue-UNAL-IronHack-lfvalderrama
# 8        2017-Purdue-UNAL-IronHack-xdanielsb
# ...                                      ...
# 1369     2017-Purdue-UNAL-IronHack-mnguzmanc
# 1371   2017-Purdue-UNAL-IronHack-Semoralesga
# 1373   2017-Purdue-UNAL-IronHack-jhcardenasa
# 1375        2017-Purdue-UNAL-IronHack-crigar
# 1377     2017-Purdue-UNAL-IronHack-AFelipeGA
#
# [660 rows x 1 columns]

# %%
df[df['data'].str.startswith('2017')]
# Out:
#                                         data
# 0           2017-Purdue-UNAL-IronHack-cap182
# 2        2017-Purdue-UNAL-IronHack-nfmorenog
# 4       2017-Purdue-UNAL-IronHack-falperezgo
# 6     2017-Purdue-UNAL-IronHack-lfvalderrama
# 8        2017-Purdue-UNAL-IronHack-xdanielsb
# ...                                      ...
# 1369     2017-Purdue-UNAL-IronHack-mnguzmanc
# 1371   2017-Purdue-UNAL-IronHack-Semoralesga
# 1373   2017-Purdue-UNAL-IronHack-jhcardenasa
# 1375        2017-Purdue-UNAL-IronHack-crigar
# 1377     2017-Purdue-UNAL-IronHack-AFelipeGA
#
# [660 rows x 1 columns]

# %%
file  = open("data.txt", "r")
lists = []
for line in file.readlines():
  lst = line.replace("[", "").replace("]","").replace("\"","").replace("\n","").split(", ")
  lists.append(lst)
print(len(lists))
# Out:
# 1380

# %%
lists
# Out:
# [['2017-Purdue-UNAL-IronHack-cap182'],
#  [''],
#  ['2017-Purdue-UNAL-IronHack-nfmorenog'],
#  ["'data.cityofchicago.org/api/views/ijzp-q8t2'",
#   "'data.cityofchicago.org/resource'"],
#  ['2017-Purdue-UNAL-IronHack-falperezgo'],
#  ["'data.cityofchicago.org/api/views/s6ha-ppgi'"],
#  ['2017-Purdue-UNAL-IronHack-lfvalderrama'],
#  ["'data.cityofchicago.org/api/views/z8bn-74gv'"],
#  ['2017-Purdue-UNAL-IronHack-xdanielsb'],
#  ["'www.ncdc.noaa.gov/cdo-web/api/v2'",
#   "'data.cityofchicago.org/resource'",
#   "'data.cityofchicago.org/resource/uahe-iimk'"],
#  ['2017-Purdue-UNAL-IronHack-ykchautai'],
#  [''],
#  ['2017-Purdue-UNAL-IronHack-oeroaq'],
#  ["'data.cityofchicago.org/api/views/s6ha-ppgi'"],
#  ['2017-Purdue-UNAL-IronHack-Danielsv9207'],
#  [''],
#  ['2017-Purdue-UNAL-IronHack-janoguerab'],
#  [''],
#  ['2017-Purdue-UNAL-IronHack-nabautistal'],
#  [''],
#  ['2017-Purdue-UNAL-IronHack-dsbarrerag'],
#  [''],
#  ['2017-Purdue-UNAL-IronHack-Christian7sr'],
#  [''],
# ...

# %%
df = pd.read_csv("data.txt")
df

# %%
df['DataFrame Column'].dtypes
