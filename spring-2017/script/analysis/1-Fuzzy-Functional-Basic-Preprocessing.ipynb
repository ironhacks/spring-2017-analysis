# %% [markdown]
# ## Functional Preprocessing with Output from Fuzzy Logic
#
# > Preprocessing is done considering the output from the ironhub where the fuzzy logic output is obtained.

# %%
# retrive variables stored in other Jupyter notebooks

# %store -r overall_loc_scores_final
# %store -r overall_loc_scores

import numpy as np
import pandas as pd
import ast

# %%
phase1_functions = pd.read_csv('data-from-ironhub/p1_output.txt', header=None, sep='\0', names=['functions'], converters={ 'functions' : ast.literal_eval })
phase1_functions
# Out:
#                                              functions
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [materialize.min.css, material.min.js, .min.js...
# 3    [jquery.min.js, style.css, init.js, X.containe...
# 4    [bootstrap.min.css, theme.min.css, aos.css, co...
# ..                                                 ...
# 160  [style.css, maps.js, z.document.getElementById...
# 161  [style.css, scripto.js, z.document.getElementB...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [eslint.org, t.module.exports, RULES.md, .vue,...
#
# [165 rows x 1 columns]

# %%
phase1_functions['unique'] = phase1_functions['functions'].apply(pd.unique)
phase1_functions['unique']
# Out:
# 0                                                     []
# 1      [FirstLook.css, bootstrap.min.css, jquery.min....
# 2      [materialize.min.css, material.min.js, .min.js...
# 3      [jquery.min.js, style.css, init.js, X.containe...
# 4      [bootstrap.min.css, theme.min.css, aos.css, co...
#                              ...
# 160    [style.css, maps.js, z.document.getElementById...
# 161    [style.css, scripto.js, z.document.getElementB...
# 162                                                   []
# 163    [z.document.getElementById, google.maps.Map, g...
# 164    [eslint.org, t.module.exports, RULES.md, .vue,...
# Name: unique, Length: 165, dtype: object

# %%
phase1_functions['len_unique'] = phase1_functions['unique'].str.len()
phase1_functions['len_functions'] = phase1_functions['functions'].str.len()
phase1_functions
# Out:
#                                              functions  \
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [materialize.min.css, material.min.js, .min.js...
# 3    [jquery.min.js, style.css, init.js, X.containe...
# 4    [bootstrap.min.css, theme.min.css, aos.css, co...
# ..                                                 ...
# 160  [style.css, maps.js, z.document.getElementById...
# 161  [style.css, scripto.js, z.document.getElementB...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [eslint.org, t.module.exports, RULES.md, .vue,...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          15
# 2    [materialize.min.css, material.min.js, .min.js...          20
# 3    [jquery.min.js, style.css, init.js, X.containe...          29
# 4    [bootstrap.min.css, theme.min.css, aos.css, co...         163
# ..                                                 ...         ...
# 160  [style.css, maps.js, z.document.getElementById...           5
# 161  [style.css, scripto.js, z.document.getElementB...           5
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [eslint.org, t.module.exports, RULES.md, .vue,...         110
#
#      len_functions
# 0                0
# 1               16
# 2               21
# 3               29
# 4              165
# ..             ...
# 160              5
# 161              5
# 162              0
# 163              4
# 164            113
#
# [165 rows x 4 columns]

# %%
phase2_functions = pd.read_csv('data-from-ironhub/p2_output.txt', header=None, sep='\0', names=['functions'], converters={ 'functions' : ast.literal_eval })
phase2_functions
# Out:
#                                              functions
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [materialize.css, materialize.js, material.min...
# 3    [jquery.min.js, style.css, init.js, test.js, X...
# 4    [.ajax, Z.done, nconsole.log, .fail, data.city...
# ..                                                 ...
# 160  [house.ico, style.css, maps.js, Chicago.jpg, z...
# 161  [style.css, .js, scripto.js, .ready, k.click, ...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [materialize.min.css, style.css, awesome.min.c...
#
# [165 rows x 1 columns]

# %%
phase2_functions['unique'] = phase2_functions['functions'].apply(pd.unique)
phase2_functions['unique']
# Out:
# 0                                                     []
# 1      [FirstLook.css, bootstrap.min.css, jquery.min....
# 2      [materialize.css, materialize.js, material.min...
# 3      [jquery.min.js, style.css, init.js, test.js, X...
# 4      [.ajax, Z.done, nconsole.log, .fail, data.city...
#                              ...
# 160    [house.ico, style.css, maps.js, Chicago.jpg, z...
# 161    [style.css, .js, scripto.js, .ready, k.click, ...
# 162                                                   []
# 163    [z.document.getElementById, google.maps.Map, g...
# 164    [materialize.min.css, style.css, awesome.min.c...
# Name: unique, Length: 165, dtype: object

# %%
phase2_functions['len_unique'] = phase2_functions['unique'].str.len()
phase2_functions['len_functions'] = phase2_functions['functions'].str.len()
phase2_functions
# Out:
#                                              functions  \
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [materialize.css, materialize.js, material.min...
# 3    [jquery.min.js, style.css, init.js, test.js, X...
# 4    [.ajax, Z.done, nconsole.log, .fail, data.city...
# ..                                                 ...
# 160  [house.ico, style.css, maps.js, Chicago.jpg, z...
# 161  [style.css, .js, scripto.js, .ready, k.click, ...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [materialize.min.css, style.css, awesome.min.c...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          42
# 2    [materialize.css, materialize.js, material.min...        1799
# 3    [jquery.min.js, style.css, init.js, test.js, X...          40
# 4    [.ajax, Z.done, nconsole.log, .fail, data.city...         182
# ..                                                 ...         ...
# 160  [house.ico, style.css, maps.js, Chicago.jpg, z...          25
# 161  [style.css, .js, scripto.js, .ready, k.click, ...        2011
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [materialize.min.css, style.css, awesome.min.c...        1907
#
#      len_functions
# 0                0
# 1               43
# 2             1944
# 3               40
# 4              185
# ..             ...
# 160             25
# 161           2257
# 162              0
# 163              4
# 164           2059
#
# [165 rows x 4 columns]

# %%
phase3_functions = pd.read_csv('data-from-ironhub/p3_output.txt', header=None, sep='\0', names=['functions'], converters={ 'functions' : ast.literal_eval })
phase3_functions
# Out:
#                                              functions
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [materialize.css, materialize.js, material.min...
# 3    [jquery.min.js, style.css, init.js, handler.js...
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# ..                                                 ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...
# 161  [style.css, .js, scripto.js, .ready, k.click, ...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [materialize.min.css, style.css, awesome.min.c...
#
# [165 rows x 1 columns]

# %%
phase3_functions.to_csv('phase3.txt')

# %%
phase3_functions['unique'] = phase3_functions['functions'].apply(pd.unique)
phase3_functions['unique']
# Out:
# 0                                                     []
# 1      [FirstLook.css, bootstrap.min.css, jquery.min....
# 2      [materialize.css, materialize.js, material.min...
# 3      [jquery.min.js, style.css, init.js, handler.js...
# 4      [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
#                              ...
# 160    [house.ico, style.css, .css, main.js, maps.js,...
# 161    [style.css, .js, scripto.js, .ready, k.click, ...
# 162                                                   []
# 163    [z.document.getElementById, google.maps.Map, g...
# 164    [materialize.min.css, style.css, awesome.min.c...
# Name: unique, Length: 165, dtype: object

# %%
phase3_functions['len_unique'] = phase3_functions['unique'].str.len()
phase3_functions['len_functions'] = phase3_functions['functions'].str.len()
phase3_functions
# Out:
#                                              functions  \
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [materialize.css, materialize.js, material.min...
# 3    [jquery.min.js, style.css, init.js, handler.js...
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# ..                                                 ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...
# 161  [style.css, .js, scripto.js, .ready, k.click, ...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [materialize.min.css, style.css, awesome.min.c...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          51
# 2    [materialize.css, materialize.js, material.min...        1799
# 3    [jquery.min.js, style.css, init.js, handler.js...          59
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...         188
# ..                                                 ...         ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...        1742
# 161  [style.css, .js, scripto.js, .ready, k.click, ...        2011
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [materialize.min.css, style.css, awesome.min.c...        1907
#
#      len_functions
# 0                0
# 1               52
# 2             1944
# 3               59
# 4              193
# ..             ...
# 160           2273
# 161           2257
# 162              0
# 163              4
# 164           2059
#
# [165 rows x 4 columns]

# %%
phase4_functions = pd.read_csv('data-from-ironhub/p4_output.txt', header=None, sep='\0', names=['functions'], converters={ 'functions' : ast.literal_eval })
phase4_functions
# Out:
#                                              functions
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [.ajax, data.cityofchicago.org, rows.json, Z.d...
# 3    [up.net, shiv.js, main.css, .css, jquery.min.j...
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# ..                                                 ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...
# 161  [style.css, bootstrap.min.css, .js, scripto.js...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [materialize.min.css, style.css, awesome.min.c...
#
# [165 rows x 1 columns]

# %%
phase4_functions['unique'] = phase4_functions['functions'].apply(pd.unique)
phase4_functions['unique']
# Out:
# 0                                                     []
# 1      [FirstLook.css, bootstrap.min.css, jquery.min....
# 2      [.ajax, data.cityofchicago.org, rows.json, Z.d...
# 3      [up.net, shiv.js, main.css, .css, jquery.min.j...
# 4      [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
#                              ...
# 160    [house.ico, style.css, .css, main.js, maps.js,...
# 161    [style.css, bootstrap.min.css, .js, scripto.js...
# 162                                                   []
# 163    [z.document.getElementById, google.maps.Map, g...
# 164    [materialize.min.css, style.css, awesome.min.c...
# Name: unique, Length: 165, dtype: object

# %%
phase4_functions['len_unique'] = phase4_functions['unique'].str.len()
phase4_functions['len_functions'] = phase4_functions['functions'].str.len()
phase4_functions
# Out:
#                                              functions  \
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [.ajax, data.cityofchicago.org, rows.json, Z.d...
# 3    [up.net, shiv.js, main.css, .css, jquery.min.j...
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# ..                                                 ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...
# 161  [style.css, bootstrap.min.css, .js, scripto.js...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [materialize.min.css, style.css, awesome.min.c...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          51
# 2    [.ajax, data.cityofchicago.org, rows.json, Z.d...        1859
# 3    [up.net, shiv.js, main.css, .css, jquery.min.j...          62
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...         224
# ..                                                 ...         ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...        1760
# 161  [style.css, bootstrap.min.css, .js, scripto.js...          17
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [materialize.min.css, style.css, awesome.min.c...        1907
#
#      len_functions
# 0                0
# 1               52
# 2             2003
# 3               62
# 4              229
# ..             ...
# 160           2290
# 161             17
# 162              0
# 163              4
# 164           2059
#
# [165 rows x 4 columns]

# %%
phase5_functions = pd.read_csv('data-from-ironhub/p5_output.txt', header=None, sep='\0', names=['functions'], converters={ 'functions' : ast.literal_eval })
phase5_functions
# Out:
#                                              functions
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [.ajax, data.cityofchicago.org, rows.json, Z.d...
# 3    [up.net, shiv.js, main.css, .css, jquery.min.j...
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# ..                                                 ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...
# 161  [style.css, bootstrap.min.css, .js, scripto.js...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [materialize.min.css, style.css, awesome.min.c...
#
# [165 rows x 1 columns]

# %%
phase5_functions['unique'] = phase5_functions['functions'].apply(pd.unique)
phase5_functions['unique']
# Out:
# 0                                                     []
# 1      [FirstLook.css, bootstrap.min.css, jquery.min....
# 2      [.ajax, data.cityofchicago.org, rows.json, Z.d...
# 3      [up.net, shiv.js, main.css, .css, jquery.min.j...
# 4      [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
#                              ...
# 160    [house.ico, style.css, .css, main.js, maps.js,...
# 161    [style.css, bootstrap.min.css, .js, scripto.js...
# 162                                                   []
# 163    [z.document.getElementById, google.maps.Map, g...
# 164    [materialize.min.css, style.css, awesome.min.c...
# Name: unique, Length: 165, dtype: object

# %%
phase5_functions['len_unique'] = phase5_functions['unique'].str.len()
phase5_functions['len_functions'] = phase5_functions['functions'].str.len()
phase5_functions
# Out:
#                                              functions  \
# 0                                                   []
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....
# 2    [.ajax, data.cityofchicago.org, rows.json, Z.d...
# 3    [up.net, shiv.js, main.css, .css, jquery.min.j...
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# ..                                                 ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...
# 161  [style.css, bootstrap.min.css, .js, scripto.js...
# 162                                                 []
# 163  [z.document.getElementById, google.maps.Map, g...
# 164  [materialize.min.css, style.css, awesome.min.c...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          51
# 2    [.ajax, data.cityofchicago.org, rows.json, Z.d...        1865
# 3    [up.net, shiv.js, main.css, .css, jquery.min.j...          62
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...         440
# ..                                                 ...         ...
# 160  [house.ico, style.css, .css, main.js, maps.js,...        1766
# 161  [style.css, bootstrap.min.css, .js, scripto.js...          21
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [materialize.min.css, style.css, awesome.min.c...        1907
#
#      len_functions
# 0                0
# 1               52
# 2             2009
# 3               62
# 4              463
# ..             ...
# 160           2297
# 161             21
# 162              0
# 163              4
# 164           2059
#
# [165 rows x 4 columns]

# %%
import glob 
import pandas as pd

phase1_name = glob.glob("../../../../Library/CloudStorage/Box-Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/processed-data/bogota-functions-output/spring2017-goldironhack-phase1/*")  # get all .csv files from the working dir
assert isinstance(phase1_name, list)
phase1_name = pd.DataFrame(phase1_name, columns = ['username'])
components = phase1_name.username.str[1:].str.split('-', expand = True)
phase1_name['Student'] = components[11]
phase1_name_drop = phase1_name.drop(['username'], axis=1)
phase1_name_drop
# Out:
#           Student
# 0          cap182
# 1       nfmorenog
# 2      falperezgo
# 3    lfvalderrama
# 4       xdanielsb
# ..            ...
# 160     mnguzmanc
# 161   Semoralesga
# 162   jhcardenasa
# 163        crigar
# 164     AFelipeGA
#
# [165 rows x 1 columns]

# %%
import glob 
import pandas as pd

phase2_name = glob.glob("../../../../Library/CloudStorage/Box-Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/processed-data/bogota-functions-output/spring2017-goldironhack-phase2/*")  # get all .csv files from the working dir
assert isinstance(phase2_name, list)
phase2_name = pd.DataFrame(phase2_name, columns = ['username'])
components = phase2_name.username.str[1:].str.split('-', expand = True)
phase2_name['Student'] = components[11]
phase2_name_drop = phase2_name.drop(['username'], axis=1)
phase2_name_drop
# Out:
#           Student
# 0          cap182
# 1       nfmorenog
# 2      falperezgo
# 3    lfvalderrama
# 4       xdanielsb
# ..            ...
# 160     mnguzmanc
# 161   Semoralesga
# 162   jhcardenasa
# 163        crigar
# 164     AFelipeGA
#
# [165 rows x 1 columns]

# %%
import glob 
import pandas as pd

phase3_name = glob.glob("../../../../Library/CloudStorage/Box-Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/processed-data/bogota-functions-output/spring2017-goldironhack-phase3/*")  # get all .csv files from the working dir
assert isinstance(phase3_name, list)
phase3_name = pd.DataFrame(phase3_name, columns = ['username'])
components = phase3_name.username.str[1:].str.split('-', expand = True)
phase3_name['Student'] = components[11]
phase3_name_drop = phase3_name.drop(['username'], axis=1)
phase3_name_drop
# Out:
#           Student
# 0          cap182
# 1       nfmorenog
# 2      falperezgo
# 3    lfvalderrama
# 4       xdanielsb
# ..            ...
# 160     mnguzmanc
# 161   Semoralesga
# 162   jhcardenasa
# 163        crigar
# 164     AFelipeGA
#
# [165 rows x 1 columns]

# %%
import glob 
import pandas as pd

phase4_name = glob.glob("../../../../Library/CloudStorage/Box-Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/processed-data/bogota-functions-output/spring2017-goldironhack-phase4/*")  # get all .csv files from the working dir
assert isinstance(phase4_name, list)
phase4_name = pd.DataFrame(phase4_name, columns = ['username'])
components = phase4_name.username.str[1:].str.split('-', expand = True)
phase4_name['Student'] = components[11]
phase4_name_drop = phase4_name.drop(['username'], axis=1)
phase4_name_drop
# Out:
#           Student
# 0          cap182
# 1       nfmorenog
# 2      falperezgo
# 3    lfvalderrama
# 4       xdanielsb
# ..            ...
# 160     mnguzmanc
# 161   Semoralesga
# 162   jhcardenasa
# 163        crigar
# 164     AFelipeGA
#
# [165 rows x 1 columns]

# %%
import glob 
import pandas as pd

phase5_name = glob.glob("../../../../Library/CloudStorage/Box-Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/processed-data/bogota-functions-output/spring2017-goldironhack-phase5/*")  # get all .csv files from the working dir
assert isinstance(phase5_name, list)
phase5_name = pd.DataFrame(phase5_name, columns = ['username'])
components = phase5_name.username.str[1:].str.split('-', expand = True)
phase5_name['Student'] = components[11]
phase5_name_drop = phase5_name.drop(['username'], axis=1)
phase5_name_drop
# Out:
#           Student
# 0          cap182
# 1       nfmorenog
# 2      falperezgo
# 3    lfvalderrama
# 4       xdanielsb
# ..            ...
# 160     mnguzmanc
# 161   Semoralesga
# 162   jhcardenasa
# 163        crigar
# 164     AFelipeGA
#
# [165 rows x 1 columns]

# %% [markdown]
# ## Functions Dataframe for Phase 1

# %%
phase1 = pd.concat([phase1_name_drop, phase1_functions], axis=1)

phase1
# Out:
#           Student                                          functions  \
# 0          cap182                                                 []
# 1       nfmorenog  [FirstLook.css, bootstrap.min.css, jquery.min....
# 2      falperezgo  [materialize.min.css, material.min.js, .min.js...
# 3    lfvalderrama  [jquery.min.js, style.css, init.js, X.containe...
# 4       xdanielsb  [bootstrap.min.css, theme.min.css, aos.css, co...
# ..            ...                                                ...
# 160     mnguzmanc  [style.css, maps.js, z.document.getElementById...
# 161   Semoralesga  [style.css, scripto.js, z.document.getElementB...
# 162   jhcardenasa                                                 []
# 163        crigar  [z.document.getElementById, google.maps.Map, g...
# 164     AFelipeGA  [eslint.org, t.module.exports, RULES.md, .vue,...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          15
# 2    [materialize.min.css, material.min.js, .min.js...          20
# 3    [jquery.min.js, style.css, init.js, X.containe...          29
# 4    [bootstrap.min.css, theme.min.css, aos.css, co...         163
# ..                                                 ...         ...
# 160  [style.css, maps.js, z.document.getElementById...           5
# 161  [style.css, scripto.js, z.document.getElementB...           5
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [eslint.org, t.module.exports, RULES.md, .vue,...         110
#
#      len_functions
# 0                0
# 1               16
# 2               21
# 3               29
# 4              165
# ..             ...
# 160              5
# 161              5
# 162              0
# 163              4
# 164            113
#
# [165 rows x 5 columns]

# %% [markdown]
# ### phase 1 functions dataframe merge with overall dataframe to know the groups.

# %%
overall_phase1 = overall_loc_scores.merge(phase1[['Student','functions', 'unique', 'len_unique', 'len_functions']], on='Student', how='left')
overall_phase1['unique']
# Out:
# 0      [.ready, k.click, .mcheck, .on, .closest, p.li...
# 1      [style.css, maps.js, z.document.getElementById...
# 2                                                     []
# 3                                                     []
# 4                                                     []
#                              ...
# 159    [scripto.js, jquery.min.js, bootstrap.min.css,...
# 160                                                   []
# 161                                                   []
# 162                                                   []
# 163                                                  NaN
# Name: unique, Length: 164, dtype: object

# %% [markdown]
# ## Functions Dataframe for Phase 2

# %%
phase2 = pd.concat([phase2_name_drop, phase2_functions], axis=1)

phase2
# Out:
#           Student                                          functions  \
# 0          cap182                                                 []
# 1       nfmorenog  [FirstLook.css, bootstrap.min.css, jquery.min....
# 2      falperezgo  [materialize.css, materialize.js, material.min...
# 3    lfvalderrama  [jquery.min.js, style.css, init.js, test.js, X...
# 4       xdanielsb  [.ajax, Z.done, nconsole.log, .fail, data.city...
# ..            ...                                                ...
# 160     mnguzmanc  [house.ico, style.css, maps.js, Chicago.jpg, z...
# 161   Semoralesga  [style.css, .js, scripto.js, .ready, k.click, ...
# 162   jhcardenasa                                                 []
# 163        crigar  [z.document.getElementById, google.maps.Map, g...
# 164     AFelipeGA  [materialize.min.css, style.css, awesome.min.c...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          42
# 2    [materialize.css, materialize.js, material.min...        1799
# 3    [jquery.min.js, style.css, init.js, test.js, X...          40
# 4    [.ajax, Z.done, nconsole.log, .fail, data.city...         182
# ..                                                 ...         ...
# 160  [house.ico, style.css, maps.js, Chicago.jpg, z...          25
# 161  [style.css, .js, scripto.js, .ready, k.click, ...        2011
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [materialize.min.css, style.css, awesome.min.c...        1907
#
#      len_functions
# 0                0
# 1               43
# 2             1944
# 3               40
# 4              185
# ..             ...
# 160             25
# 161           2257
# 162              0
# 163              4
# 164           2059
#
# [165 rows x 5 columns]

# %% [markdown]
# ### phase 2 functions dataframe merge with overall dataframe to know the groups.

# %%
pd.set_option('display.max_rows', 500)
overall_phase2 = overall_loc_scores.merge(phase2[['Student','functions', 'unique', 'len_unique', 'len_functions']], on='Student', how='left')
overall_phase2
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# 5                 DglyP    0.0                     20.0           25.00
# 6                cap182    0.0                     20.0           29.17
# 7           annumumozme    0.0                     40.0           37.50
# 8           Judgarciani    0.0                    100.0           58.33
# 9             sacastroc    0.0                     20.0           50.00
# 10            pcberriop    0.0                     20.0           37.50
# 11          hsmartineza    0.0                     20.0           33.33
# 12             Moimolcp    0.0                    100.0           62.50
# 13          CamiloRueda    0.0                      0.0           29.17
# 14            juanescai    0.0                      0.0           25.00
# 15           JoseMolano    0.0                     60.0           66.67
# 16        maikellPardoA    0.0                      0.0           37.50
# 17           NicolasZon    0.0                      0.0           25.00
# 18            camilo654    0.0                     20.0           29.17
# 19       CristianLozano    0.0                     20.0           33.33
# 20            jdsuarezj    0.0                     60.0           50.00
# 21            pipemax85    0.0                     20.0           33.33
# 22          juandavidro    0.0                     20.0           58.33
# 23       UNhcrodriguezl    0.0                     80.0           33.33
# 24          camilo13152    0.0                     60.0           50.00
# 25         leavendanoro    0.0                     40.0           66.67
# 26           cdcordobaa    0.0                     20.0           33.33
# 27           capinillab    0.0                     60.0           54.17
# 28           janoguerab    0.0                     20.0           29.17
# 29         lfvalderrama    0.0                     80.0           66.67
# 30            bsgarciac    0.0                    100.0           70.83
# 31               gabi04    0.0                     20.0           29.17
# 32               annipi    0.0                      0.0            0.00
# 33            jdsolanos    0.0                      0.0            0.00
# 34             jcneivaa    0.0                      0.0            0.00
# 35            fmbernalb    0.0                      0.0            0.00
# 36              MogGy94    0.0                      0.0            0.00
# 37            yocuervoc    0.0                      0.0            0.00
# 38            odprietoh    0.0                      0.0            0.00
# 39            gasierram    1.0                     40.0           62.50
# 40         adamantwharf    1.0                     20.0           25.00
# 41            bdcajicam    1.0                     40.0           29.17
# 84            80.00        314.17         87.5          0.0
# 85            87.50        325.00         87.5         87.5
# 86            75.00        337.50         87.5         75.0
# 87            25.00        137.50         75.0         75.0
# 88            25.00        128.33         37.5         37.5
# 89             0.00         45.00          0.0          0.0
# 90            62.50        178.33         62.5         50.0
# 91            25.00        170.00         75.0         75.0
# 92            66.67        272.50        100.0         75.0
# 93            87.50        325.83        100.0        100.0
# 94            60.00        318.33        100.0         75.0
# 95            25.00        174.17         75.0         75.0
# 96            65.00        265.83         62.5         62.5
# 97            84.38        322.71         87.5         87.5
# 98            72.50        326.67         87.5         87.5
# 99             0.00        120.00         75.0         62.5
# 100           62.50        187.50        100.0         75.0
# 101           62.50        182.50         75.0         62.5
# 102          100.00        345.83         75.0         62.5
# 103           37.50        275.83        100.0         75.0
# 104           25.00        125.00         75.0         50.0
# 105           75.00        211.67         75.0         75.0
# 106           25.00        145.83         87.5         62.5
# 107            0.00         95.00         50.0         62.5
# 108           75.00        224.17         87.5         75.0
# 109            0.00        100.00         62.5         62.5
# 110           62.50        309.17        100.0         87.5
# 111           75.00        227.50         87.5         75.0
# 112           65.63        304.79        100.0         62.5
# 113          100.00        339.17        100.0        100.0
# 114           25.00        158.33         87.5         87.5
# 115           33.33        154.17         87.5         37.5
# 116           12.50        125.00         87.5          0.0
# 117           70.00        357.50        100.0         50.0
# 118            0.00          0.00          0.0          0.0
# 119            0.00          0.00          0.0          0.0
# 120            0.00          0.00          0.0          0.0
# 121            0.00          0.00          0.0          0.0
# 122           87.50        329.17         87.5         87.5
# 123           92.50        355.00         87.5        100.0
# 124           15.00        127.50         75.0         75.0
# 125           56.25        221.25         87.5         75.0
# 126           25.00        112.50         62.5         62.5
# 127           95.00        345.83         87.5         87.5
# 128            0.00        128.33         75.0         62.5
# 129            0.00         75.00         50.0         37.5
# 130           72.50        327.50        100.0         62.5
# 131           56.25        209.58         87.5         75.0
# 132           25.00        145.00         37.5         37.5
# 133           25.00         75.00         25.0          0.0
# 134           60.00        310.00        100.0         75.0
# 135          100.00        358.33         75.0         75.0
# 136           81.25        278.75         87.5         62.5
# 137           50.00        161.67         62.5         50.0
# 138           66.67        231.67         87.5         87.5
# 139           75.00        350.00        100.0         87.5
# 140           37.50        235.00         75.0         62.5
# 141           50.00        203.33         87.5         62.5
# 142           67.50        301.67         87.5         87.5
# 143           58.33        203.33        100.0         87.5
# 144           25.00        198.33         75.0         50.0
# 145           25.00        177.50         62.5         62.5
# 146            0.00        115.83         62.5         62.5
# 147           81.25        298.75         87.5         62.5
# 148           87.50        345.83         87.5         87.5
# 149           12.50        178.33        100.0        100.0
# 150           56.25        197.08         87.5         62.5
# 151           93.75        348.75        100.0         87.5
# 152           57.50        185.83         75.0         62.5
# 153           56.25        209.58        100.0         75.0
# 154            0.00         95.00         50.0         50.0
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
# 160            0.00          0.00          0.0          0.0
# 161            0.00          0.00          0.0          0.0
# 162            0.00          0.00          0.0          0.0
# 163             NaN           NaN          NaN          NaN
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...              104.0
# 5                        0.0           25.00  ...               21.5
# 6                       20.0           29.17  ...              -39.5
# 7                        0.0            0.00  ...                NaN
# 8                       80.0           87.50  ...              -19.5
# 9                       20.0           50.00  ...                0.0
# 10                      20.0           33.33  ...                2.5
# 11                      20.0           37.50  ...               -1.5
# 12                       0.0           33.33  ...                0.0
# 13                      20.0           25.00  ...                0.0
# 14                       0.0           25.00  ...                0.0
# 15                       0.0           58.33  ...              -20.5
# 16                       0.0            0.00  ...                0.0
# 17                       0.0           25.00  ...               -0.5
# 18                      60.0           33.33  ...                0.0
# 19                      60.0           50.00  ...                0.0
# 20                      60.0           66.67  ...              -48.0
# 21                      20.0           33.33  ...                2.0
# 22                      20.0           54.17  ...               66.0
# 23                      20.0           41.67  ...                0.0
# 24                      60.0           45.83  ...                0.0
# 25                       0.0           25.00  ...              -19.0
# 26                      20.0           33.33  ...                0.0
# 27                      60.0           54.17  ...                0.0
# 28                      20.0           29.17  ...                0.0
# 29                      20.0           50.00  ...               -2.0
# 30                      80.0           70.83  ...                9.5
# 31                      20.0           29.17  ...               -3.0
# 32                       0.0            0.00  ...                0.0
# 33                       0.0            0.00  ...               -7.5
# 34                       0.0            0.00  ...               -1.0
# 35                       0.0            0.00  ...                0.0
# 36                       0.0            0.00  ...                0.0
# 37                       0.0            0.00  ...                0.0
# 38                       0.0            0.00  ...                0.0
# 39                      40.0           58.33  ...                1.5
# 40                      20.0           25.00  ...                0.0
# 41                      20.0           29.17  ...                0.0
# 42                      20.0           25.00  ...                0.0
# 43                      20.0           50.00  ...                0.0
# 44                      20.0           29.17  ...                0.5
# 45                     100.0           75.00  ...                0.0
# 46                      40.0           62.50  ...             -124.0
# 47                      60.0           79.17  ...                0.0
# 48                       0.0           25.00  ...                0.0
# 49                     100.0           79.17  ...               10.5
# 50                      60.0           29.17  ...                1.5
# 51                      20.0           33.33  ...                0.0
# 52                      60.0           83.33  ...                8.0
# 53                     100.0           70.83  ...               -8.5
# 54                      20.0           33.33  ...              156.0
# 55                      20.0           41.67  ...                0.0
# 56                      60.0           62.50  ...               43.0
# 57                      20.0           33.33  ...                0.0
# 58                      80.0           66.67  ...              -11.0
# 59                      40.0           50.00  ...               -0.5
# 60                       0.0           25.00  ...                0.0
# 61                      20.0           29.17  ...                2.5
# 62                      40.0           54.17  ...                0.0
# 63                       0.0            0.00  ...               -1.0
# 64                      60.0           54.17  ...              -27.5
# 65                     100.0           75.00  ...                0.0
# 66                      40.0           58.33  ...               22.5
# 67                       0.0           29.17  ...                0.0
# 68                      20.0           33.33  ...               19.5
# 69                      20.0           33.33  ...                2.0
# 70                      20.0           25.00  ...                0.0
# 159               12.0                1.0                1.0
# 160                0.0                0.0                0.0
# 161                0.0                0.0                0.0
# 162                0.0                0.0                0.0
# 163                0.0                0.0                0.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 3                  0.0                0.0
# 4                  0.0               34.5
# 5                -31.0                0.0
# 6                  0.0               -1.5
# 7                  NaN                NaN
# 8                  1.0                1.0
# 9                  0.5                0.5
# 10                 3.0                0.5
# 11               -43.0                6.5
# 12               -11.5              -11.5
# 13                 0.0                0.0
# 14                 0.0                0.0
# 15                -9.0               25.0
# 16                 0.0                0.0
# 17                -0.5                0.0
# 18                16.5                3.0
# 19                 0.0                0.0
# 20                -6.5              201.5
# 21                 2.0                0.0
# 22               274.5              283.0
# 23                 0.0                0.0
# 24                 0.0                0.0
# 25                -2.0               38.5
# 26               -17.5               -8.0
# 27               -75.0              -22.5
# 28                 NaN                0.0
# 29                 2.5                1.5
# 30                 0.0               10.0
# 31                 0.0              -23.5
# 32                 0.0               26.0
# 33                 0.0               16.0
# 34                 0.0                0.0
# 35                 0.0                0.0
# 36                 0.0                0.0
# 37                 0.0                0.0
# 38                 0.0                0.0
# 39               -23.0               -5.5
# 40                 0.0               43.5
# 41                26.0                0.0
# 42               -21.0               16.5
# 43                 0.0              -18.5
# 44                 1.0               -9.5
# 45                 0.0               43.0
# 46                35.5                0.0
# 47              -404.0                0.0
# 48                 0.0                6.5
# 49              -121.0              -33.0
# 50                -6.5               21.0
# 51               -25.0              -16.5
# 52               -15.0               -2.0
# 53                -7.0                0.0
# 54               -34.0               76.5
# 55                 2.0               -5.5
# 56                49.5               31.5
# 57              -183.5             -134.5
# 58                19.5               10.0
# 59                -1.5              -70.5
# ...
# 148  [bootstrap.min.css, jquery.min.js, Javascript....
# 149  [google.maps.Map, z.document.getElementById, g...
# 150  [unal.edu.co, bootstrap.min.css, template.css,...
# 151  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 152  [page.php, google.maps.Map, z.document.getElem...
# 153  [js.org, .v, .min.js, style.css, jquery.min.js...
# 154  [style.css, main.js, z.document.getElementById...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, farmermarket.st...
# 157  [.js, jsInitMap.js, z.document.getElementById,...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [scripto.js, jquery.min.js, bootstrap.min.css,...
# 160                                                 []
# 161                                                 []
# 162                                                 []
# 163                                                NaN
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, .mcheck, .on, .closest, p.li...        29.0
# 1    [house.ico, style.css, maps.js, Chicago.jpg, z...        25.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      6404.0
# 3                                                   []         0.0
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...        19.0
# 5    [google.maps.Map, z.document.getElementById, g...        23.0
# 6                                                   []         0.0
# 7                                                  NaN         NaN
# 8    [bootstrap.min.css, jquery.min.js, Rent.js, Cr...        78.0
# 9    [js.org, .v, .min.js, collection.v, dispatch.v...        40.0
# 10   [google.maps.Map, z.document.getElementById, g...        41.0
# 11   [jquery.min.js, .js, info.js, Chicago.jpg, z.d...        35.0
# 12   [style.css, scripto.js, jquery.min.js, google....        39.0
# 13   [layout.css, shiv.js, z.document.getElementByI...        46.0
# 14                                                  []         0.0
# 15   [bootstrap.min.css, theme.min.css, jquery.min....        46.0
# 16   [z.document.getElementById, google.maps.Map, g...         4.0
# 17   [google.maps.LatLng, google.maps.mapTypeId.ROA...        12.0
# 18   [.ready, k.click, .ajax, data.cityofchicago.or...        18.0
# 19   [z.document.getElementById, google.maps.Map, g...         7.0
# 20   [google.maps.Map, z.document.getElementById, g...        41.0
# 21   [bootstrap.min.css, theme.min.css, jquery.min....        21.0
# 22   [bootstrap.min.css, theme.min.css, jquery.min....       122.0
# 23   [demos.css, bootstrap.min.css, select.min.css,...        77.0
# 24   [favicon.ico, fluidbox.min.css, main.css, goog...        14.0
# 25   [style.css, js.org, .v, .min.js, myArrayOfObje...        22.0
# 26   [bootstrap.min.css, main.css, .org, .js, maps....        32.0
# 27   [z.document.getElementById, google.maps.Map, g...        19.0
# 28   [js.org, .v, .min.js, z.document.getElementByI...        36.0
# 29   [jquery.min.js, style.css, init.js, test.js, X...        40.0
# 30   [document.getElementsByClassName, dx.length, B...        59.0
# 31   [google.maps.LatLng, google.maps.mapTypeId.ROA...        41.0
# 32                                                  []         0.0
# 33                                                  []         0.0
# 34                                                  []         0.0
# 35                                                  []         0.0
# 36                                                  []         0.0
# 37                                                  []         0.0
# 38                                                  []         0.0
# 39   [illinois.edu, favicon.ico, bootstrap.min.css,...        16.0
# 40   [z.document.getElementById, google.maps.Map, g...         3.0
# 41   [google.maps.Map, z.document.getElementById, g...         3.0
# 42                                                  []         0.0
# 43   [main.js, google.maps.Map, z.document.getEleme...         4.0
# 44   [style.css, jquery.min.js, scripto.js, integra...        15.0
# 45   [bootstrap.min.css, theme.min.css, jquery.min....         8.0
# 46   [materialize.css, materialize.js, material.min...      1799.0
# 47   [google.maps.LatLng, google.maps.Map, z.docume...        44.0
# 48   [google.maps.LatLng, google.maps.mapTypeId.ROA...        41.0
# 49   [style.css, bootstrap.css, jquery.js, Bootstra...       141.0
# 50   [bootstrap.min.css, theme.min.css, jquery.min....       109.0
# 51   [style.css, .js, scripto.js, .ready, k.click, ...      2011.0
# 52   [awesome.min.css, bootstrap.min.css, style.css...        86.0
# 53   [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      2283.0
# 54   [style.css, .jpg, google.maps.LatLng, google.m...         6.0
# 55   [body.css, favicon.ico, google.maps.Map, z.doc...        13.0
# 56   [.CSS, .custom.css, .css, awesome.min.css, jqu...        34.0
# 57   [bootstrap.min.css, maps.js, jquery.min.js, z....        38.0
# 58   [bootstrap.min.css, modifier.css, jquery.min.j...        90.0
# 59   [favicon.ico, bootstrap.min.css, awesome.css, ...       233.0
# 60                                                  []         0.0
# 61                             [estilos.css, icon.ico]         2.0
# 62   [bootstrap.min.css, jquery.min.js, style.css, ...        53.0
# 63   [bootstrap.min.css, blueberry.css, main.css, j...         9.0
# 64   [bootstrap.min.css, main.css, bundle.js, mapEx...     20706.0
# 65   [style.css, blocks.css, bootstrap.min.css, the...       132.0
# 66   [this.valueOf, this.name, z.document.getElemen...        25.0
# 67   [.controls, .pac, searchBox.js, bootstrap.min....       145.0
# 68   [estilos.css, map.PNG, unal.edu.co, bootstrap....        18.0
# 69   [z.document.getElementById, google.maps.Map, g...         3.0
# 70   [z.document.getElementById, google.maps.Map, g...         4.0
# 71   [t.module.exports, grunt.option, grunt.initCon...     71433.0
# 72   [bootstrap.min.css, freelancer.min.js, style.c...        38.0
# 73   [style.css, bootstrap.min.css, jquery.min.js, ...       108.0
# 74   [bootstrap.min.css, awesome.min.css, animate.c...       335.0
# 75   [z.document.getElementById, google.maps.Map, g...       118.0
# 76                                                  []         0.0
# 77                                                  []         0.0
# 78                                                 NaN         NaN
# 79   [fH.css, call.js, jquery.min.js, .js, this.jid...        23.0
# 80   [bootstrap.min.css, portfolio.css, awesome.min...        15.0
# 81   [cs.css, z.document.getElementById, google.map...         4.0
# 82   [a.active, z.document.getElementById, google.m...         4.0
# 83   [jquery.min.js, tutorial.js, bootstrap.min.css...        53.0
# 84                                                  []         0.0
# 85   [z.document.getElementById, google.maps.Map, b...        10.0
# 86   [bootstrap.min.css, jquery.min.js, .js, js.org...        97.0
# 87   [jquery.min.js, bootstrap.min.css, tutorial.cs...        53.0
# 88   [bootstrap.min.css, awesome.min.css, theme.min...        26.0
# 89                                                  []         0.0
# 90   [.css, buttons.css, google.maps.Map, z.documen...         5.0
# 91   [components.css, responsee.css, owl.carousel.j...       563.0
# 92   [up.net, main.css, bootstrap.min.css, jquery.m...       148.0
# 93   [estilos.css, funciones.js, jquery.min.js, .aj...        48.0
# 94   [style.css, jquery.min.js, .ready, k.click, .a...        23.0
# 95   [style.css, .Chicago, z.document.getElementByI...         5.0
# 96   [templates.asp, bootstrap.min.css, jquery.min....      2043.0
# 97   [Style.css, .min.js, js.org, .v, maps.js, clim...        57.0
# 98   [google.maps.DirectionsRenderer, z.document.ge...        64.0
# 99   [z.document.getElementById, google.maps.Map, g...         3.0
# 100  [home.css, search.css, navicon.jpg, logo.jpg, ...         9.0
# 101  [style.css, bootstrap.min.css, theme.min.css, ...        41.0
# 102  [latest.min.js, jquery.min.js, clear.js, foo.j...        37.0
# 103  [Bootstrap.js, bootstrap.css, style.css, table...        51.0
# 104  [runner.github.io, t.module.exports, config.se...        19.0
# 105  [tiry.cloudfront.net, foundation.min.css, styl...        15.0
# 106  [funciones.js, jquery.min.js, bootstrap.min.cs...      2013.0
# 107  [navicon.jpg, style.css, z.document.getElement...        17.0
# 108  [google.maps.Map, z.document.getElementById, g...        23.0
# 109  [bootstrap.min.css, .js, js.org, .v, .min.js, ...        32.0
# 110  [semantic.min.css, style.css, .min.js, bootstr...     31872.0
# 111  [reset.css, layout.css, style.css, jquery.fanc...       412.0
# 112  [js.org, .v, .min.js, bar.css, StyleSheet.css,...        67.0
# 113  [pxmlhttp.open, xmlhttp.setRequestHeader, xmlh...        59.0
# 114  [bootstrap.min.css, freelancer.css, .custom.cs...        83.0
# 115  [bootstrap.min.css, theme.min.css, jquery.min....        34.0
# 116  [.css, awesome.min.css, latest.min.js, room.js...      4521.0
# 117  [.ajax, Z.done, nconsole.log, .fail, data.city...       182.0
# 118                                                 []         0.0
# 119                                                 []         0.0
# 120                                                NaN         NaN
# 121  [google.maps.LatLng, google.maps.mapTypeId.ROA...        21.0
# 122  [google.maps.Map, z.document.getElementById, g...        14.0
# 123  [jquery.min.js, bootstrap.min.css, mainPage.cs...       129.0
# 124  [FirstLook.css, bootstrap.min.css, jquery.min....        42.0
# 125  [materialize.min.css, style.css, awesome.min.c...      1907.0
# 126  [.bin, e.g, protractor.conf.js, exports.config...     60918.0
# 127  [style.css, maps.js, weather.js, api.openweath...        39.0
# 128  [.create, package.json, pkg.title, pkg.version...        56.0
# 129  [t.module.exports, options.keyId, options.clie...       343.0
# 130  [.css, .js, js.org, .v, bootstrap.min.css, the...        59.0
# 131  [bootstrap.min.css, style.css, theme.min.css, ...        42.0
# 132  [.l, morado.jpg, a.active, google.maps.Map, z....         6.0
# 133                                                 []         0.0
# 134  [main.css, material.min.js, angular.min.js, an...        53.0
# 135  [bootstrap.min.css, theme.min.css, style.css, ...        33.0
# 136  [bootstrap.min.css, portfolio.css, awesome.min...         6.0
# 137  [bootstrap.min.css, uic.edu, .js, z.document.g...         6.0
# 138  [style.css, loadUpData.js, maps.js, google.map...        19.0
# 139  [awesome.min.css, bootstrap.min.css, materiali...        48.0
# 140  [bootstrap.min.css, theme.min.css, awesome.min...       111.0
# 141  [.ajax, data.cityofchicago.org, wj.json, Z.don...        44.0
# 142  [favicon.ico, bootstrap.min.css, .min.js, appl...        39.0
# 143  [bootstrap.min.css, estilos.css, maps.js, .min...        19.0
# 144  [.create, package.json, pkg.title, pkg.version...        67.0
# 145  [style.css, favicon.ico, bootstrap.min.css, th...        15.0
# 146  [bootstrap.min.css, mdb.min.css, demos.css, st...        22.0
# 147  [bootstrap.min.css, dashboard.css, style.css, ...        96.0
# 148  [bootstrap.min.css, jquery.min.js, Javascript....        42.0
# 149  [google.maps.Map, z.document.getElementById, g...     34443.0
# 150  [unal.edu.co, bootstrap.min.css, template.css,...        52.0
# 151  [jmalvarezd.js, bootstrap.min.css, jquery.min....        51.0
# 152  [page.php, google.maps.Map, z.document.getElem...         4.0
# 153  [js.org, .v, .min.js, style.css, jquery.min.js...        28.0
# 154  [style.css, main.js, z.document.getElementById...         5.0
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        31.0
# 156  [bootstrap.min.css, style.css, farmermarket.st...        38.0
# 157  [.js, jsInitMap.js, z.document.getElementById,...        13.0
# 158  [bootstrap.min.css, jquery.min.js, stylesLogin...        19.0
# 159  [scripto.js, jquery.min.js, bootstrap.min.css,...        38.0
# 160                                                 []         0.0
# 161                                                 []         0.0
# 162                                                 []         0.0
# 163                                                NaN         NaN
#
#      len_functions
# 0             30.0
# 1             25.0
# 2           7051.0
# 3              0.0
# 4             19.0
# 5             24.0
# 6              0.0
# 7              NaN
# 8             80.0
# 9             42.0
# 10            41.0
# 11            35.0
# 12            39.0
# 13            47.0
# 14             0.0
# 15            47.0
# 16             4.0
# 17            12.0
# 18            18.0
# 19             7.0
# 20            41.0
# 21            22.0
# 22           127.0
# 23            78.0
# 24            14.0
# 25            22.0
# 26            32.0
# 27            20.0
# 28            36.0
# 29            40.0
# 30            60.0
# 31            41.0
# 32             0.0
# 33             0.0
# 34             0.0
# 35             0.0
# 36             0.0
# 37             0.0
# 38             0.0
# 39            17.0
# 40             3.0
# 41             3.0
# 42             0.0
# 43             4.0
# 44            15.0
# 45             9.0
# 46          1944.0
# 47            45.0
# 48            41.0
# 49           151.0
# 50           113.0
# 51          2257.0
# 52            87.0
# 53          2882.0
# 54             6.0
# 55            13.0
# 56            34.0
# 57            39.0
# 58            91.0
# 59           246.0
# 60             0.0
# 61             2.0
# 62            53.0
# 63             9.0
# 64         23323.0
# 65           137.0
# 66            25.0
# 67           150.0
# 68            18.0
# 69             3.0
# 70             4.0
# 71         86211.0
# 72            40.0
# 73           109.0
# 74           345.0
# 75           123.0
# 76             0.0
# 77             0.0
# 78             NaN
# 79            23.0
# 80            16.0
# 81             4.0
# 82             5.0
# 83            53.0
# 84             0.0
# 85            11.0
# 86           102.0
# 87            53.0
# 88            27.0
# 89             0.0
# 90             5.0
# 91           595.0
# 92           153.0
# 93            48.0
# 94            24.0
# 95             5.0
# 96          2291.0
# 97            57.0
# 98            64.0
# 99             3.0
# 100            9.0
# 101           42.0
# 102           37.0
# 103           51.0
# 104           19.0
# 105           15.0
# 106         2259.0
# 107           17.0
# 108           25.0
# 109           33.0
# 110        36049.0
# 111          420.0
# 112           67.0
# 113           60.0
# 114           84.0
# 115           35.0
# 116         4842.0
# 117          185.0
# 118            0.0
# 119            0.0
# 120            NaN
# 121           22.0
# 122           15.0
# 123          134.0
# 124           43.0
# 125         2059.0
# 126        71867.0
# 127           39.0
# 128           57.0
# 129          359.0
# 130           63.0
# 131           43.0
# 132            7.0
# 133            0.0
# 134           55.0
# 135           34.0
# 136            6.0
# 137            7.0
# 138           19.0
# 139           49.0
# 140          113.0
# 141           45.0
# 142           40.0
# 143           20.0
# 144           69.0
# 145           16.0
# 146           22.0
# 147           96.0
# 148           43.0
# 149        39434.0
# 150           53.0
# 151           52.0
# 152            4.0
# 153           29.0
# 154            5.0
# 155           31.0
# 156           40.0
# 157           13.0
# 158           20.0
# 159           39.0
# 160            0.0
# 161            0.0
# 162            0.0
# 163            NaN
#
# [164 rows x 90 columns]

# %% [markdown]
# ## Functions Dataframe for Phase 3

# %%
phase3 = pd.concat([phase3_name_drop, phase3_functions], axis=1)

phase3
# Out:
#                 Student                                          functions  \
# 0                cap182                                                 []
# 1             nfmorenog  [FirstLook.css, bootstrap.min.css, jquery.min....
# 2            falperezgo  [materialize.css, materialize.js, material.min...
# 3          lfvalderrama  [jquery.min.js, style.css, init.js, handler.js...
# 4             xdanielsb  [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# 5             ykchautai  [tiry.cloudfront.net, foundation.min.css, styl...
# 6                oeroaq  [style.css, bootstrap.css, balloon.css, jquery...
# 7          Danielsv9207                                                 []
# 8            janoguerab  [js.org, .v, .min.js, z.document.getElementByI...
# 9           nabautistal  [z.document.getElementById, google.maps.Map, g...
# 10           dsbarrerag  [.CSS, .custom.css, .css, awesome.min.css, jqu...
# 11         Christian7sr  [estilos.css, icon.ico, Etxea.js, z.document.g...
# 12             Chranium  [style.css, main.js, z.document.getElementById...
# 13            srmedinac  [.create, package.json, pkg.title, pkg.version...
# 14         jucjimenezmo  [home.css, search.css, navicon.jpg, logo.jpg, ...
# 15          kgbayala528  [latest.min.js, jquery.min.js, bootstrap.min.c...
# 16            wolfstain  [up.net, main.css, .css, noscript.css, chicago...
# 17       DianaNavarrete  [.l, morado.jpg, a.active, a.active, google.ma...
# 18            bsgarciac  [document.getElementsByClassName, dx.length, B...
# 19          jiapulidoar  [t.module.exports, grunt.option, grunt.initCon...
# 20           ronaldsg20  [.ready, .ajax, nconsole.log, data.result, goo...
# 21            bdcajicam  [nearium.css, .js, nearium.js, google.maps.Map...
# 22       andfsanchezlem                                                 []
# 23               li2266                                                 []
# 24          JulianaNino  [google.maps.Map, z.document.getElementById, g...
# 25           jonatan360  [awesome.min.css, bootstrap.min.css, style.css...
# 26            camilo654  [.ready, k.click, .ajax, data.cityofchicago.or...
# 27         stevenbustos  [style.css, .jpg, google.maps.LatLng, google.m...
# 28         jscontrerasp  [latest.min.js, google.maps.LatLng, google.map...
# 29           gsuarezc04  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 30           jmalvarezd  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 31           katherinsb                                                 []
# 32               annipi                                                 []
# 33            fmbernalb                                                 []
# 34           mballeng91  [.bin, e.g, protractor.conf.js, exports.config...
# 35      jscastelblancoh  [bootstrap.min.css, theme.min.css, style.css, ...
# 36             capinzor  [bootstrap.min.css, estilos.css, .min.js, boot...
# 37            jdsuarezj  [google.maps.Map, z.document.getElementById, g...
# 38       jufcontrerasco  [body.css, favicon.ico, google.maps.Map, z.doc...
# 39           NicolasZon  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 40                 tres                                                 []
# 41          hsmartineza  [jquery.min.js, .js, maps.js, info.js, test.js...
# 42          dfhincapiem  [main.js, google.maps.Map, z.document.getEleme...
# 43            gasierram  [illinois.edu, favicon.ico, bootstrap.min.css,...
# 44           JuanitoAli  [bootstrap.css, .js, Bootstrap.js, google.maps...
# 45            fabianr23  [estilos.css, funciones.js, jquery.min.js, .aj...
# 46         leavendanoro  [style.css, js.org, .v, .min.js, scripto.js, z...
# 47              ccvacad                                                 []
# 48             jcneivaa                                                 []
# 49            yocuervoc                                                 []
# 50           JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....
# 51          CSebasGomez                                                 []
# 52          juandavidro  [style.css, scripto.js, bootstrap.min.css, sit...
# 53            jdsolanos                                                 []
# 54          afceballosr  [bootstrap.min.css, style.css, farmermarket.st...
# 55                DglyP  [google.maps.Map, z.document.getElementById, g...
# 56         jjrodriguezn  [google.maps.Map, z.document.getElementById, g...
# 57          CamiloRueda  [layout.css, shiv.js, z.document.getElementByI...
# 58             oserasoa  [bootstrap.min.css, theme.min.css, jquery.min....
# 59           joaortizro  [z.document.getElementById, google.maps.Map, b...
# 60             davidh17  [bootstrap.min.css, style.css, theme.min.css, ...
# 61         JairVillalba  [fH.css, call.js, jquery.min.js, .js, this.jid...
# 62           davidrh195  [navicon.jpg, style.css, z.document.getElement...
# 63           juclopezso  [bootstrap.min.css, portfolio.css, awesome.min...
# 64         raulramirezp  [up.net, main.css, bootstrap.min.css, jquery.m...
# 65          camilo13152  [mapController.js, favicon.ico, fluidbox.min.c...
# 66           kmendezp96  [js.org, .v, .min.js, bar.css, StyleSheet.css,...
# 67           miaborjaac  [bootstrap.min.css, modifier.css, jquery.min.j...
# 68             dduartec  [.js, style.css, superplaceholder.js, superpla...
# 69           crarojasca                                                 []
# 70       UNhcrodriguezl  [demos.css, bootstrap.min.css, select.min.css,...
# 71            pipemax85  [bootstrap.min.css, theme.min.css, jquery.min....
# 72        ivdgonzalezco  [favicon.ico, bootstrap.min.css, awesome.css, ...
# 73       jesusfchavarro  [gl.js, gl.css, .mapboxgl, mapboxgl.accessToke...
# 74         wilson911013  [t.module.exports, options.keyId, options.clie...
# 75   JhonEmmanuelTorres                                                 []
# 76            jjmuesesq  [z.document.getElementById, google.maps.Map, g...
# 77         adamantwharf  [z.document.getElementById, google.maps.Map, g...
# 78           NicolasPrr  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 79             luegilca  [bootstrap.min.css, .js, js.org, .v, .min.js, ...
# 80            macuestap  [style.css, favicon.ico, bootstrap.min.css, th...
# 81            lemartinp  [google.maps.Map, z.document.getElementById, g...
# 82          dagofonseca  [style.css, jquery.min.js, maps.js, markerclus...
# 83            jsviveroj  [bootstrap.min.css, freelancer.min.js, style.c...
# 84         luealfonsoru  [bootstrap.min.css, freelancer.css, .custom.cs...
# 85            afforeroc  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...
# 86            djguzmanc  [google.maps.LatLng, google.maps.Map, z.docume...
# 87            uxjudges2                                                 []
# 88           cdcordobaa  [bootstrap.min.css, main.css, .org, .js, maps....
# 89              gcantem  [bootstrap.min.css, theme.min.css, jquery.min....
# 90           feartheGru                                                 []
# 91           lgmoralesa  [bootstrap.min.css, jquery.min.js, Javascript....
# 92       CristianLozano  [z.document.getElementById, google.maps.Map, g...
# 93             mdbelloc  [jquery.min.js, bootstrap.min.css, tutorial.cs...
# 94               Yelis3  [semantic.min.css, calendar.min.css, style.css...
# 95       joahernandezca  [z.document.getElementById, google.maps.Map, g...
# 96          anfmorenoso  [estilos.css, map.PNG, unal.edu.co, bootstrap....
# 97        jumcorredorro  [jquery.min.js, bootstrap.min.css, tutorial.cs...
# 98            begarzonf  [reset.css, layout.css, style.css, jquery.fanc...
# 99               spenas  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 100           smarquezo  [page.php, google.maps.Map, z.document.getElem...
# 101              gabi04  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 102        maikellPardo                                                 []
# 103          jmhurtadoc  [.controls, .pac, searchBox.js, bootstrap.min....
# 104        jusherrerama  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 105          fevargasmo  [this.valueOf, this.name, z.document.getElemen...
# 106            aldiazve  [bootstrap.min.css, main.css, bundle.js, mapEx...
# 107            lsfinite  [.css, awesome.min.css, latest.min.js, room.js...
# 108           jorge52an  [main.css, material.min.js, angular.min.js, an...
# 109          daandradec  [style.css, bootstrap.min.css, jquery.min.js, ...
# 110          jsnarvaezb  [bootstrap.min.css, jquery.min.js, style.css, ...
# 111          capinillab  [z.document.getElementById, google.maps.Map, g...
# 112         djsanabriac  [bootstrap.min.css, main.js, jquery.min.js, z....
# 113      cesarochoa2006  [.getFullYear, nconsole.log, z.document.getEle...
# 114     juasmartinezbel  [bootstrap.min.css, jquery.min.js, .js, js.org...
# 115          debeltranc  [runner.github.io, t.module.exports, config.se...
# 116            adriel62  [favicon.ico, bootstrap.min.css, .min.js, appl...
# 117      diegoaguevarar  [style.css, blocks.css, bootstrap.min.css, the...
# 118           ligibrial  [funciones.js, bootstrap.min.css, jquery.min.j...
# 119           juanescai                                                 []
# 120            jcrubioa  [bootstrap.min.css, awesome.min.css, animate.c...
# 121          Phoenixest  [a.active, a.active, z.document.getElementById...
# 122           juligarji  [jquery.min.js, bootstrap.min.css, awesome.min...
# 123              kancas  [style.css, bootstrap.min.css, theme.min.css, ...
# 124             ItsNavi                                                 []
# 125            leguzman  [pxmlhttp.open, xmlhttp.setRequestHeader, xmlh...
# 126          jmcuestasb  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 127           sacastroc  [js.org, .v, .min.js, collection.v, dispatch.v...
# 128          jhonsd1996  [style.css, .Chicago, z.document.getElementByI...
# 129           jdmonroyg                                                 []
# 130             Zeugmax                                                 []
# 131             MogGy94                                                 []
# 132              sagilm  [data.cityofchicago.org, rows.json, pxmlhttp.o...
# 133             sarizag  [js.org, .v, .min.js, style.css, jquery.min.js...
# 134          dasalgadob  [bootstrap.min.css, theme.min.css, jquery.min....
# 135             Gantiva  [latest.min.js, jquery.min.js, foo.js, rents.j...
# 136            idrojasf  [components.css, responsee.css, owl.carousel.j...
# 137            Moimolcp  [bootstrap.min.css, style.css, scripto.js, jqu...
# 138          anmmunozme  [.ready, k.click, .ajax, data.cityofchicago.or...
# 139          jhriverasa  [style.css, bootstrap.min.css, jquery.min.js, ...
# 140           fffeelipe  [.ready, k.click, .mcheck, .on, .closest, p.li...
# 141       gfalbarracinr  [bootstrap.min.css, profile.css, rid.css, goog...
# 142       cccristanchoc  [unal.edu.co, bootstrap.min.css, template.css,...
# 143           pcberriop  [google.maps.Map, z.document.getElementById, g...
# 144          ncampuzano  [bootstrap.min.css, awesome.min.css, app.css, ...
# 145           helmeraac  [style.css, jquery.min.js, scripto.js, integra...
# 146            ofnanezn  [.create, package.json, pkg.title, pkg.version...
# 147           odprietoh                                                 []
# 148       maikellPardoA  [z.document.getElementById, google.maps.Map, g...
# 149       wapiravaguens  [.css, .js, js.org, .v, bootstrap.min.css, the...
# 150          Dandarprox  [Bootstrap.js, bootstrap.css, style.css, table...
# 151            HashNick  [jquery.min.js, tutorial.js, bootstrap.min.css...
# 152         diegocruz10  [bootstrap.min.css, awesome.min.css, theme.min...
# 153          Davsatu313  [Style.css, .min.js, js.org, .v, maps.js, clim...
# 154         lacardenasv  [awesome.min.css, bootstrap.min.css, materiali...
# 155             bdvegat  [js.org, .v, .js, bootstrap.min.css, bootstrap...
# 156           lizzyt10h  [bootstrap.min.css, jquery.min.js, index.css, ...
# 157             DavidQP  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 158         Judgarciani  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159         oacastillol  [bootstrap.min.css, theme.min.css, awesome.min...
# 160           mnguzmanc  [house.ico, style.css, .css, main.js, maps.js,...
# 161         Semoralesga  [style.css, .js, scripto.js, .ready, k.click, ...
# 162         jhcardenasa                                                 []
# 163              crigar  [z.document.getElementById, google.maps.Map, g...
# 164           AFelipeGA  [materialize.min.css, style.css, awesome.min.c...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          51
# 2    [materialize.css, materialize.js, material.min...        1799
# 3    [jquery.min.js, style.css, init.js, handler.js...          59
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...         188
# 5    [tiry.cloudfront.net, foundation.min.css, styl...          23
# 6    [style.css, bootstrap.css, balloon.css, jquery...         672
# 7                                                   []           0
# 8    [js.org, .v, .min.js, z.document.getElementByI...          36
# 9    [z.document.getElementById, google.maps.Map, g...           7
# 10   [.CSS, .custom.css, .css, awesome.min.css, jqu...          51
# 11   [estilos.css, icon.ico, Etxea.js, z.document.g...           6
# 12   [style.css, main.js, z.document.getElementById...           5
# 13   [.create, package.json, pkg.title, pkg.version...          56
# 14   [home.css, search.css, navicon.jpg, logo.jpg, ...           9
# 15   [latest.min.js, jquery.min.js, bootstrap.min.c...         108
# 16   [up.net, main.css, .css, noscript.css, chicago...         217
# 17   [.l, morado.jpg, a.active, google.maps.Map, z....           6
# 18   [document.getElementsByClassName, dx.length, B...          98
# 19   [t.module.exports, grunt.option, grunt.initCon...       71443
# 20   [.ready, .ajax, nconsole.log, data.result, goo...       34457
# 21   [nearium.css, .js, nearium.js, google.maps.Map...          36
# 22                                                  []           0
# 23                                                  []           0
# 24   [google.maps.Map, z.document.getElementById, g...          32
# 25   [awesome.min.css, bootstrap.min.css, style.css...          92
# 26   [.ready, k.click, .ajax, data.cityofchicago.or...          18
# 27   [style.css, .jpg, google.maps.LatLng, google.m...           6
# 28   [latest.min.js, google.maps.LatLng, google.map...          27
# 29   [google.maps.LatLng, google.maps.mapTypeId.ROA...          41
# 30   [jmalvarezd.js, bootstrap.min.css, jquery.min....          53
# 31                                                  []           0
# 32                                                  []           0
# 33                                                  []           0
# 34   [.bin, e.g, protractor.conf.js, exports.config...       60918
# 35   [bootstrap.min.css, theme.min.css, style.css, ...          42
# 36   [bootstrap.min.css, estilos.css, .min.js, maps...          61
# 37   [google.maps.Map, z.document.getElementById, g...          66
# 38   [body.css, favicon.ico, google.maps.Map, z.doc...          13
# 39   [google.maps.LatLng, google.maps.mapTypeId.ROA...          12
# 40                                                  []           0
# 41   [jquery.min.js, .js, maps.js, info.js, test.js...          52
# 42   [main.js, google.maps.Map, z.document.getEleme...           4
# 43   [illinois.edu, favicon.ico, bootstrap.min.css,...          60
# 44   [bootstrap.css, .js, Bootstrap.js, google.maps...        2072
# 45   [estilos.css, funciones.js, jquery.min.js, .aj...          81
# 46   [style.css, js.org, .v, .min.js, scripto.js, z...          31
# 47                                                  []           0
# 48                                                  []           0
# 49                                                  []           0
# 50   [bootstrap.min.css, theme.min.css, jquery.min....          48
# 51                                                  []           0
# 52   [style.css, scripto.js, bootstrap.min.css, sit...          15
# 53                                                  []           0
# 54   [bootstrap.min.css, style.css, farmermarket.st...          42
# 55   [google.maps.Map, z.document.getElementById, g...          23
# 56   [google.maps.Map, z.document.getElementById, g...          27
# 57   [layout.css, shiv.js, z.document.getElementByI...          46
# 58   [bootstrap.min.css, theme.min.css, jquery.min....          45
# 59   [z.document.getElementById, google.maps.Map, b...          18
# 60   [bootstrap.min.css, style.css, theme.min.css, ...          61
# 61   [fH.css, call.js, jquery.min.js, .js, this.jid...          33
# 62   [navicon.jpg, style.css, z.document.getElement...          17
# 63   [bootstrap.min.css, portfolio.css, awesome.min...           6
# 64   [up.net, main.css, bootstrap.min.css, jquery.m...         148
# 65   [mapController.js, favicon.ico, fluidbox.min.c...          69
# 66   [js.org, .v, .min.js, bar.css, StyleSheet.css,...          72
# 67   [bootstrap.min.css, modifier.css, jquery.min.j...         101
# 68   [.js, style.css, superplaceholder.js, maps.js,...         103
# 69                                                  []           0
# 70   [demos.css, bootstrap.min.css, select.min.css,...          88
# 71   [bootstrap.min.css, theme.min.css, jquery.min....          27
# 72   [favicon.ico, bootstrap.min.css, awesome.css, ...         233
# 73   [gl.js, gl.css, .mapboxgl, mapboxgl.accessToke...        2331
# 74   [t.module.exports, options.keyId, options.clie...         343
# 75                                                  []           0
# 76   [z.document.getElementById, google.maps.Map, g...           3
# 77   [z.document.getElementById, google.maps.Map, g...           3
# 78   [bootstrap.min.css, jquery.min.js, stylesLogin...          19
# 79   [bootstrap.min.css, .js, js.org, .v, .min.js, ...          32
# 80   [style.css, favicon.ico, bootstrap.min.css, th...          15
# 81   [google.maps.Map, z.document.getElementById, g...          14
# 82   [style.css, jquery.min.js, maps.js, markerclus...         232
# 83   [bootstrap.min.css, freelancer.min.js, style.c...          49
# 84   [bootstrap.min.css, freelancer.css, .custom.cs...          81
# 85   [bootstrap.min.css, uic.edu, .js, z.document.g...           6
# 86   [google.maps.LatLng, google.maps.Map, z.docume...          49
# 87                                                  []           0
# 88   [bootstrap.min.css, main.css, .org, .js, maps....          32
# 89   [bootstrap.min.css, theme.min.css, jquery.min....         109
# 90                                                  []           0
# 91   [bootstrap.min.css, jquery.min.js, Javascript....          56
# 92   [z.document.getElementById, google.maps.Map, g...           7
# 93   [jquery.min.js, bootstrap.min.css, tutorial.cs...          53
# 94   [semantic.min.css, calendar.min.css, style.css...       32634
# 95   [z.document.getElementById, google.maps.Map, g...         118
# 96   [estilos.css, map.PNG, unal.edu.co, bootstrap....          18
# 97   [jquery.min.js, bootstrap.min.css, tutorial.cs...          91
# 98   [reset.css, layout.css, style.css, jquery.fanc...         424
# 99   [bootstrap.min.css, mdb.min.css, demos.css, st...          22
# 100  [page.php, google.maps.Map, z.document.getElem...           4
# 101  [google.maps.LatLng, google.maps.mapTypeId.ROA...          58
# 102                                                 []           0
# 103  [.controls, .pac, searchBox.js, bootstrap.min....         145
# 104  [js.org, .v, .min.js, bootstrap.min.css, portf...        2014
# 105  [this.valueOf, this.name, z.document.getElemen...          49
# 106  [bootstrap.min.css, main.css, bundle.js, mapEx...       20706
# 107  [.css, awesome.min.css, latest.min.js, room.js...        4539
# 108  [main.css, material.min.js, angular.min.js, an...         133
# 109  [style.css, bootstrap.min.css, jquery.min.js, ...         143
# 110  [bootstrap.min.css, jquery.min.js, style.css, ...          54
# 111  [z.document.getElementById, google.maps.Map, g...          19
# 112  [bootstrap.min.css, main.js, jquery.min.js, z....          32
# 113  [.getFullYear, nconsole.log, z.document.getEle...         110
# 114  [bootstrap.min.css, jquery.min.js, .js, js.org...         135
# 115  [runner.github.io, t.module.exports, config.se...          19
# 116  [favicon.ico, bootstrap.min.css, .min.js, appl...          39
# 117  [style.css, blocks.css, bootstrap.min.css, the...         132
# 118  [funciones.js, bootstrap.min.css, jquery.min.j...        2019
# 119                                                 []           0
# 120  [bootstrap.min.css, awesome.min.css, animate.c...         335
# 121  [a.active, z.document.getElementById, google.m...           4
# 122  [jquery.min.js, bootstrap.min.css, awesome.min...        2242
# 123  [style.css, bootstrap.min.css, theme.min.css, ...          41
# 124                                                 []           0
# 125  [pxmlhttp.open, xmlhttp.setRequestHeader, xmlh...          87
# 126  [js.org, .v, .min.js, weather.js, mycss.css, b...        6404
# 127  [js.org, .v, .min.js, collection.v, dispatch.v...          68
# 128  [style.css, .Chicago, z.document.getElementByI...           5
# 129                                                 []           0
# 130                                                 []           0
# 131                                                 []           0
# 132  [data.cityofchicago.org, rows.json, pxmlhttp.o...          21
# 133  [js.org, .v, .min.js, style.css, jquery.min.js...          28
# 134  [bootstrap.min.css, theme.min.css, jquery.min....           8
# 135  [latest.min.js, jquery.min.js, foo.js, rents.j...          45
# 136  [components.css, responsee.css, owl.carousel.j...         563
# 137  [bootstrap.min.css, style.css, scripto.js, jqu...          73
# 138  [.ready, k.click, .ajax, data.cityofchicago.or...          35
# 139  [style.css, bootstrap.min.css, jquery.min.js, ...          25
# 140  [.ready, k.click, .mcheck, .on, .closest, p.li...          29
# 141  [bootstrap.min.css, profile.css, rid.css, goog...          10
# 142  [unal.edu.co, bootstrap.min.css, template.css,...          52
# 143  [google.maps.Map, z.document.getElementById, g...          41
# 144  [bootstrap.min.css, awesome.min.css, app.css, ...          82
# 145  [style.css, jquery.min.js, scripto.js, integra...          15
# 146  [.create, package.json, pkg.title, pkg.version...          57
# 147                                                 []           0
# 148  [z.document.getElementById, google.maps.Map, g...           4
# 149  [.css, .js, js.org, .v, bootstrap.min.css, the...          78
# 150  [Bootstrap.js, bootstrap.css, style.css, table...          77
# 151  [jquery.min.js, tutorial.js, bootstrap.min.css...          53
# 152  [bootstrap.min.css, awesome.min.css, theme.min...          39
# 153  [Style.css, .min.js, js.org, .v, maps.js, clim...          34
# 154  [awesome.min.css, bootstrap.min.css, materiali...          47
# 155  [js.org, .v, .js, bootstrap.min.css, cs.css, f...          10
# 156  [bootstrap.min.css, jquery.min.js, index.css, ...          16
# 157  [bootstrap.min.css, Respond.js, shiv.min.js, r...          40
# 158  [bootstrap.min.css, jquery.min.js, Rent.js, Cr...         126
# 159  [bootstrap.min.css, theme.min.css, awesome.min...         124
# 160  [house.ico, style.css, .css, main.js, maps.js,...        1742
# 161  [style.css, .js, scripto.js, .ready, k.click, ...        2011
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [materialize.min.css, style.css, awesome.min.c...        1907
#
#      len_functions
# 0                0
# 1               52
# 2             1944
# 3               59
# 4              193
# 5               23
# 6              713
# 7                0
# 8               36
# 9                7
# 10              52
# 11               6
# 12               5
# 13              57
# 14               9
# 15             108
# 16             223
# 17               7
# 18             100
# 19           86224
# 20           39449
# 21              36
# 22               0
# 23               0
# 24              34
# 25              93
# 26              18
# 27               6
# 28              28
# 29              41
# 30              54
# 31               0
# 32               0
# 33               0
# 34           71867
# 35              43
# 36              62
# 37              66
# 38              13
# 39              12
# 40               0
# 41              52
# 42               4
# 43              61
# 44            2320
# 45              81
# 46              32
# 47               0
# 48               0
# 49               0
# 50              49
# 51               0
# 52              15
# 53               0
# 54              44
# 55              24
# 56              27
# 57              47
# 58              46
# 59              19
# 60              62
# 61              33
# 62              17
# 63               6
# 64             153
# 65              70
# 66              72
# 67             102
# 68             105
# 69               0
# 70              89
# 71              28
# 72             246
# 73            2931
# 74             359
# 75               0
# 76               3
# 77               3
# 78              20
# 79              33
# 80              16
# 81              15
# 82             250
# 83              51
# 84              82
# 85               7
# 86              50
# 87               0
# 88              32
# 89             113
# 90               0
# 91              59
# 92               7
# 93              53
# 94           36982
# 95             123
# 96              18
# 97              95
# 98             432
# 99              22
# 100              4
# 101             58
# 102              0
# 103            150
# 104           2261
# 105             49
# 106          23323
# 107           4860
# 108            138
# 109            145
# 110             54
# 111             20
# 112             32
# 113            110
# 114            141
# 115             19
# 116             40
# 117            137
# 118           2265
# 119              0
# 120            345
# 121              5
# 122           2497
# 123             42
# 124              0
# 125             90
# 126           7051
# 127             72
# 128              5
# 129              0
# 130              0
# 131              0
# 132             21
# 133             29
# 134              9
# 135             45
# 136            595
# 137             78
# 138             36
# 139             27
# 140             30
# 141             10
# 142             53
# 143             41
# 144             84
# 145             15
# 146             58
# 147              0
# 148              4
# 149             84
# 150             77
# 151             53
# 152             40
# 153             34
# 154             48
# 155             11
# 156             17
# 157             40
# 158            133
# 159            126
# 160           2273
# 161           2257
# 162              0
# 163              4
# 164           2059

# %% [markdown]
# ### phase 3 functions dataframe merge with overall dataframe to know the groups.

# %%
overall_phase3 = overall_loc_scores.merge(phase3[['Student','functions', 'unique', 'len_unique', 'len_functions']], on='Student', how='left')
overall_phase3
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# 5                 DglyP    0.0                     20.0           25.00
# 6                cap182    0.0                     20.0           29.17
# 7           annumumozme    0.0                     40.0           37.50
# 8           Judgarciani    0.0                    100.0           58.33
# 9             sacastroc    0.0                     20.0           50.00
# 10            pcberriop    0.0                     20.0           37.50
# 11          hsmartineza    0.0                     20.0           33.33
# 12             Moimolcp    0.0                    100.0           62.50
# 13          CamiloRueda    0.0                      0.0           29.17
# 14            juanescai    0.0                      0.0           25.00
# 15           JoseMolano    0.0                     60.0           66.67
# 16        maikellPardoA    0.0                      0.0           37.50
# 17           NicolasZon    0.0                      0.0           25.00
# 18            camilo654    0.0                     20.0           29.17
# 19       CristianLozano    0.0                     20.0           33.33
# 20            jdsuarezj    0.0                     60.0           50.00
# 21            pipemax85    0.0                     20.0           33.33
# 22          juandavidro    0.0                     20.0           58.33
# 23       UNhcrodriguezl    0.0                     80.0           33.33
# 24          camilo13152    0.0                     60.0           50.00
# 25         leavendanoro    0.0                     40.0           66.67
# 26           cdcordobaa    0.0                     20.0           33.33
# 27           capinillab    0.0                     60.0           54.17
# 28           janoguerab    0.0                     20.0           29.17
# 29         lfvalderrama    0.0                     80.0           66.67
# 30            bsgarciac    0.0                    100.0           70.83
# 31               gabi04    0.0                     20.0           29.17
# 32               annipi    0.0                      0.0            0.00
# 33            jdsolanos    0.0                      0.0            0.00
# 34             jcneivaa    0.0                      0.0            0.00
# 35            fmbernalb    0.0                      0.0            0.00
# 36              MogGy94    0.0                      0.0            0.00
# 37            yocuervoc    0.0                      0.0            0.00
# 38            odprietoh    0.0                      0.0            0.00
# 39            gasierram    1.0                     40.0           62.50
# 40         adamantwharf    1.0                     20.0           25.00
# 41            bdcajicam    1.0                     40.0           29.17
# 42       andfsanchezlem    1.0                     20.0           25.00
# 43          dfhincapiem    1.0                     20.0           25.00
# 44            helmeraac    1.0                      0.0           25.00
# 45           dasalgadob    1.0                      0.0           25.00
# 46           falperezgo    1.0                     20.0           45.83
# 47            djguzmanc    1.0                     80.0           79.17
# 48           gsuarezc04    1.0                      0.0           25.00
# 49               oeroaq    1.0                    100.0           87.50
# 50              gcantem    1.0                    100.0           70.83
# 51          Semoralesga    1.0                     20.0           33.33
# 52           jonatan360    1.0                    100.0           75.00
# 53       jesusfchavarro    1.0                    100.0           62.50
# 99             0.00        120.00         75.0         62.5
# 100           62.50        187.50        100.0         75.0
# 101           62.50        182.50         75.0         62.5
# 102          100.00        345.83         75.0         62.5
# 103           37.50        275.83        100.0         75.0
# 104           25.00        125.00         75.0         50.0
# 105           75.00        211.67         75.0         75.0
# 106           25.00        145.83         87.5         62.5
# 107            0.00         95.00         50.0         62.5
# 108           75.00        224.17         87.5         75.0
# 109            0.00        100.00         62.5         62.5
# 110           62.50        309.17        100.0         87.5
# 111           75.00        227.50         87.5         75.0
# 112           65.63        304.79        100.0         62.5
# 113          100.00        339.17        100.0        100.0
# 114           25.00        158.33         87.5         87.5
# 115           33.33        154.17         87.5         37.5
# 116           12.50        125.00         87.5          0.0
# 117           70.00        357.50        100.0         50.0
# 118            0.00          0.00          0.0          0.0
# 119            0.00          0.00          0.0          0.0
# 120            0.00          0.00          0.0          0.0
# 121            0.00          0.00          0.0          0.0
# 122           87.50        329.17         87.5         87.5
# 123           92.50        355.00         87.5        100.0
# 124           15.00        127.50         75.0         75.0
# 125           56.25        221.25         87.5         75.0
# 126           25.00        112.50         62.5         62.5
# 127           95.00        345.83         87.5         87.5
# 128            0.00        128.33         75.0         62.5
# 129            0.00         75.00         50.0         37.5
# 130           72.50        327.50        100.0         62.5
# 131           56.25        209.58         87.5         75.0
# 132           25.00        145.00         37.5         37.5
# 133           25.00         75.00         25.0          0.0
# 134           60.00        310.00        100.0         75.0
# 135          100.00        358.33         75.0         75.0
# 136           81.25        278.75         87.5         62.5
# 137           50.00        161.67         62.5         50.0
# 138           66.67        231.67         87.5         87.5
# 139           75.00        350.00        100.0         87.5
# 140           37.50        235.00         75.0         62.5
# 141           50.00        203.33         87.5         62.5
# 142           67.50        301.67         87.5         87.5
# 143           58.33        203.33        100.0         87.5
# 144           25.00        198.33         75.0         50.0
# 145           25.00        177.50         62.5         62.5
# 146            0.00        115.83         62.5         62.5
# 147           81.25        298.75         87.5         62.5
# 148           87.50        345.83         87.5         87.5
# 149           12.50        178.33        100.0        100.0
# 150           56.25        197.08         87.5         62.5
# 151           93.75        348.75        100.0         87.5
# 152           57.50        185.83         75.0         62.5
# 153           56.25        209.58        100.0         75.0
# 154            0.00         95.00         50.0         50.0
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
# 160            0.00          0.00          0.0          0.0
# 161            0.00          0.00          0.0          0.0
# 162            0.00          0.00          0.0          0.0
# 163             NaN           NaN          NaN          NaN
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...              104.0
# 5                        0.0           25.00  ...               21.5
# 6                       20.0           29.17  ...              -39.5
# 7                        0.0            0.00  ...                NaN
# 8                       80.0           87.50  ...              -19.5
# 9                       20.0           50.00  ...                0.0
# 14                 0.0                0.0
# 15                -9.0               25.0
# 16                 0.0                0.0
# 17                -0.5                0.0
# 18                16.5                3.0
# 19                 0.0                0.0
# 20                -6.5              201.5
# 21                 2.0                0.0
# 22               274.5              283.0
# 23                 0.0                0.0
# 24                 0.0                0.0
# 25                -2.0               38.5
# 26               -17.5               -8.0
# 27               -75.0              -22.5
# 28                 NaN                0.0
# 29                 2.5                1.5
# 30                 0.0               10.0
# 31                 0.0              -23.5
# 32                 0.0               26.0
# 33                 0.0               16.0
# 34                 0.0                0.0
# 35                 0.0                0.0
# 36                 0.0                0.0
# 37                 0.0                0.0
# 38                 0.0                0.0
# 39               -23.0               -5.5
# 40                 0.0               43.5
# 41                26.0                0.0
# 42               -21.0               16.5
# 43                 0.0              -18.5
# 44                 1.0               -9.5
# 45                 0.0               43.0
# 46                35.5                0.0
# 47              -404.0                0.0
# 48                 0.0                6.5
# 49              -121.0              -33.0
# 50                -6.5               21.0
# 51               -25.0              -16.5
# 52               -15.0               -2.0
# 53                -7.0                0.0
# 54               -34.0               76.5
# 55                 2.0               -5.5
# 56                49.5               31.5
# 57              -183.5             -134.5
# 58                19.5               10.0
# 59                -1.5              -70.5
# ...
# 148  [bootstrap.min.css, jquery.min.js, Javascript....
# 149  [.ready, .ajax, nconsole.log, data.result, goo...
# 150  [unal.edu.co, bootstrap.min.css, template.css,...
# 151  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 152  [page.php, google.maps.Map, z.document.getElem...
# 153  [js.org, .v, .min.js, style.css, jquery.min.js...
# 154  [style.css, main.js, z.document.getElementById...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, farmermarket.st...
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.css, tutorial.cs...
# 160                                                 []
# 161                                                 []
# 162                                                 []
# 163                                                NaN
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, .mcheck, .on, .closest, p.li...        29.0
# 1    [house.ico, style.css, .css, main.js, maps.js,...      1742.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      6404.0
# 3                                                   []         0.0
# 4    [google.maps.Map, z.document.getElementById, g...        27.0
# 5    [google.maps.Map, z.document.getElementById, g...        23.0
# 6                                                   []         0.0
# 7                                                  NaN         NaN
# 8    [bootstrap.min.css, jquery.min.js, Rent.js, Cr...       126.0
# 9    [js.org, .v, .min.js, collection.v, dispatch.v...        68.0
# 10   [google.maps.Map, z.document.getElementById, g...        41.0
# 11   [jquery.min.js, .js, maps.js, info.js, test.js...        52.0
# 12   [bootstrap.min.css, style.css, scripto.js, jqu...        73.0
# 13   [layout.css, shiv.js, z.document.getElementByI...        46.0
# 14                                                  []         0.0
# 15   [bootstrap.min.css, theme.min.css, jquery.min....        48.0
# 16   [z.document.getElementById, google.maps.Map, g...         4.0
# 17   [google.maps.LatLng, google.maps.mapTypeId.ROA...        12.0
# 18   [.ready, k.click, .ajax, data.cityofchicago.or...        18.0
# 19   [z.document.getElementById, google.maps.Map, g...         7.0
# 20   [google.maps.Map, z.document.getElementById, g...        66.0
# 21   [bootstrap.min.css, theme.min.css, jquery.min....        27.0
# 22   [style.css, scripto.js, bootstrap.min.css, sit...        15.0
# 23   [demos.css, bootstrap.min.css, select.min.css,...        88.0
# 24   [mapController.js, favicon.ico, fluidbox.min.c...        69.0
# 25   [style.css, js.org, .v, .min.js, scripto.js, z...        31.0
# 26   [bootstrap.min.css, main.css, .org, .js, maps....        32.0
# 27   [z.document.getElementById, google.maps.Map, g...        19.0
# 28   [js.org, .v, .min.js, z.document.getElementByI...        36.0
# 29   [jquery.min.js, style.css, init.js, handler.js...        59.0
# 30   [document.getElementsByClassName, dx.length, B...        98.0
# 31   [google.maps.LatLng, google.maps.mapTypeId.ROA...        58.0
# 32                                                  []         0.0
# 33                                                  []         0.0
# 34                                                  []         0.0
# 35                                                  []         0.0
# 36                                                  []         0.0
# 37                                                  []         0.0
# 38                                                  []         0.0
# 39   [illinois.edu, favicon.ico, bootstrap.min.css,...        60.0
# 40   [z.document.getElementById, google.maps.Map, g...         3.0
# 41   [nearium.css, .js, nearium.js, google.maps.Map...        36.0
# 42                                                  []         0.0
# 43   [main.js, google.maps.Map, z.document.getEleme...         4.0
# 44   [style.css, jquery.min.js, scripto.js, integra...        15.0
# 45   [bootstrap.min.css, theme.min.css, jquery.min....         8.0
# 46   [materialize.css, materialize.js, material.min...      1799.0
# 47   [google.maps.LatLng, google.maps.Map, z.docume...        49.0
# 48   [google.maps.LatLng, google.maps.mapTypeId.ROA...        41.0
# 49   [style.css, bootstrap.css, balloon.css, jquery...       672.0
# 50   [bootstrap.min.css, theme.min.css, jquery.min....       109.0
# 51   [style.css, .js, scripto.js, .ready, k.click, ...      2011.0
# 52   [awesome.min.css, bootstrap.min.css, style.css...        92.0
# 53   [gl.js, gl.css, .mapboxgl, mapboxgl.accessToke...      2331.0
# 54   [style.css, .jpg, google.maps.LatLng, google.m...         6.0
# 55   [body.css, favicon.ico, google.maps.Map, z.doc...        13.0
# 56   [.CSS, .custom.css, .css, awesome.min.css, jqu...        51.0
# 57   [up.net, main.css, .css, noscript.css, chicago...       217.0
# 58   [bootstrap.min.css, modifier.css, jquery.min.j...       101.0
# 59   [favicon.ico, bootstrap.min.css, awesome.css, ...       233.0
# 60                                                  []         0.0
# 61   [estilos.css, icon.ico, Etxea.js, z.document.g...         6.0
# 62   [bootstrap.min.css, jquery.min.js, style.css, ...        54.0
# 63   [bootstrap.min.css, profile.css, rid.css, goog...        10.0
# 64   [bootstrap.min.css, main.css, bundle.js, mapEx...     20706.0
# 65   [style.css, blocks.css, bootstrap.min.css, the...       132.0
# 66   [this.valueOf, this.name, z.document.getElemen...        49.0
# 67   [.controls, .pac, searchBox.js, bootstrap.min....       145.0
# 68   [estilos.css, map.PNG, unal.edu.co, bootstrap....        18.0
# 69   [z.document.getElementById, google.maps.Map, g...         7.0
# 70   [z.document.getElementById, google.maps.Map, g...         4.0
# 71   [t.module.exports, grunt.option, grunt.initCon...     71443.0
# 72   [bootstrap.min.css, freelancer.min.js, style.c...        49.0
# 73   [style.css, bootstrap.min.css, jquery.min.js, ...       143.0
# 74   [bootstrap.min.css, awesome.min.css, animate.c...       335.0
# 75   [z.document.getElementById, google.maps.Map, g...       118.0
# 76                                                  []         0.0
# 77                                                  []         0.0
# 78                                                 NaN         NaN
# 79   [fH.css, call.js, jquery.min.js, .js, this.jid...        33.0
# 80   [js.org, .v, .min.js, bootstrap.min.css, portf...      2014.0
# 81   [js.org, .v, .js, bootstrap.min.css, cs.css, f...        10.0
# 82   [a.active, z.document.getElementById, google.m...         4.0
# 83   [jquery.min.js, tutorial.js, bootstrap.min.css...        53.0
# 84                                                  []         0.0
# 85   [z.document.getElementById, google.maps.Map, b...        18.0
# 86   [bootstrap.min.css, jquery.min.js, .js, js.org...       135.0
# 87   [jquery.min.js, bootstrap.min.css, tutorial.cs...        53.0
# 88   [bootstrap.min.css, awesome.min.css, theme.min...        39.0
# 89                                                  []         0.0
# 90   [data.cityofchicago.org, rows.json, pxmlhttp.o...        21.0
# 91   [components.css, responsee.css, owl.carousel.j...       563.0
# 92   [up.net, main.css, bootstrap.min.css, jquery.m...       148.0
# 93   [estilos.css, funciones.js, jquery.min.js, .aj...        81.0
# 94   [style.css, bootstrap.min.css, jquery.min.js, ...        25.0
# 95   [style.css, .Chicago, z.document.getElementByI...         5.0
# 96   [bootstrap.css, .js, Bootstrap.js, google.maps...      2072.0
# 97   [Style.css, .min.js, js.org, .v, maps.js, clim...        34.0
# 98   [.getFullYear, nconsole.log, z.document.getEle...       110.0
# 99   [z.document.getElementById, google.maps.Map, g...         3.0
# 100  [home.css, search.css, navicon.jpg, logo.jpg, ...         9.0
# 101  [style.css, bootstrap.min.css, theme.min.css, ...        41.0
# 102  [latest.min.js, jquery.min.js, foo.js, rents.j...        45.0
# 103  [Bootstrap.js, bootstrap.css, style.css, table...        77.0
# 104  [runner.github.io, t.module.exports, config.se...        19.0
# 105  [tiry.cloudfront.net, foundation.min.css, styl...        23.0
# 106  [funciones.js, bootstrap.min.css, jquery.min.j...      2019.0
# 107  [navicon.jpg, style.css, z.document.getElement...        17.0
# 108  [google.maps.Map, z.document.getElementById, g...        32.0
# 109  [bootstrap.min.css, .js, js.org, .v, .min.js, ...        32.0
# 110  [semantic.min.css, calendar.min.css, style.css...     32634.0
# 111  [reset.css, layout.css, style.css, jquery.fanc...       424.0
# 112  [js.org, .v, .min.js, bar.css, StyleSheet.css,...        72.0
# 113  [pxmlhttp.open, xmlhttp.setRequestHeader, xmlh...        87.0
# 114  [bootstrap.min.css, freelancer.css, .custom.cs...        81.0
# 115  [bootstrap.min.css, theme.min.css, jquery.min....        45.0
# 116  [.css, awesome.min.css, latest.min.js, room.js...      4539.0
# 117  [nconsole.log, jQuery.parseJSON, .ajax, Z.done...       188.0
# 118                                                 []         0.0
# 119                                                 []         0.0
# 120                                                NaN         NaN
# 121  [latest.min.js, google.maps.LatLng, google.map...        27.0
# 122  [google.maps.Map, z.document.getElementById, g...        14.0
# 123  [jquery.min.js, bootstrap.min.css, awesome.min...      2242.0
# 124  [FirstLook.css, bootstrap.min.css, jquery.min....        51.0
# 125  [materialize.min.css, style.css, awesome.min.c...      1907.0
# 126  [.bin, e.g, protractor.conf.js, exports.config...     60918.0
# 127  [.js, style.css, superplaceholder.js, maps.js,...       103.0
# 128  [.create, package.json, pkg.title, pkg.version...        56.0
# 129  [t.module.exports, options.keyId, options.clie...       343.0
# 130  [.css, .js, js.org, .v, bootstrap.min.css, the...        78.0
# 131  [bootstrap.min.css, style.css, theme.min.css, ...        61.0
# 132  [.l, morado.jpg, a.active, google.maps.Map, z....         6.0
# 133                                                 []         0.0
# 134  [main.css, material.min.js, angular.min.js, an...       133.0
# 135  [bootstrap.min.css, theme.min.css, style.css, ...        42.0
# 136  [bootstrap.min.css, portfolio.css, awesome.min...         6.0
# 137  [bootstrap.min.css, uic.edu, .js, z.document.g...         6.0
# 138  [style.css, jquery.min.js, maps.js, markerclus...       232.0
# 139  [awesome.min.css, bootstrap.min.css, materiali...        47.0
# 140  [bootstrap.min.css, theme.min.css, awesome.min...       124.0
# 141  [bootstrap.min.css, awesome.min.css, app.css, ...        82.0
# 142  [favicon.ico, bootstrap.min.css, .min.js, appl...        39.0
# 143  [bootstrap.min.css, estilos.css, .min.js, maps...        61.0
# 144  [.create, package.json, pkg.title, pkg.version...        57.0
# 145  [style.css, favicon.ico, bootstrap.min.css, th...        15.0
# 146  [bootstrap.min.css, mdb.min.css, demos.css, st...        22.0
# 147  [latest.min.js, jquery.min.js, bootstrap.min.c...       108.0
# 148  [bootstrap.min.css, jquery.min.js, Javascript....        56.0
# 149  [.ready, .ajax, nconsole.log, data.result, goo...     34457.0
# 150  [unal.edu.co, bootstrap.min.css, template.css,...        52.0
# 151  [jmalvarezd.js, bootstrap.min.css, jquery.min....        53.0
# 152  [page.php, google.maps.Map, z.document.getElem...         4.0
# 153  [js.org, .v, .min.js, style.css, jquery.min.js...        28.0
# 154  [style.css, main.js, z.document.getElementById...         5.0
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        40.0
# 156  [bootstrap.min.css, style.css, farmermarket.st...        42.0
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...        16.0
# 158  [bootstrap.min.css, jquery.min.js, stylesLogin...        19.0
# 159  [jquery.min.js, bootstrap.min.css, tutorial.cs...        91.0
# 160                                                 []         0.0
# 161                                                 []         0.0
# 162                                                 []         0.0
# 163                                                NaN         NaN
#
#      len_functions
# 0             30.0
# 1           2273.0
# 2           7051.0
# 3              0.0
# 4             27.0
# 5             24.0
# 6              0.0
# 7              NaN
# 8            133.0
# 9             72.0
# 10            41.0
# 11            52.0
# 12            78.0
# 13            47.0
# 14             0.0
# 15            49.0
# 16             4.0
# 17            12.0
# 18            18.0
# 19             7.0
# 20            66.0
# 21            28.0
# 22            15.0
# 23            89.0
# 24            70.0
# 25            32.0
# 26            32.0
# 27            20.0
# 28            36.0
# 29            59.0
# 30           100.0
# 31            58.0
# 32             0.0
# 33             0.0
# 34             0.0
# 35             0.0
# 36             0.0
# 37             0.0
# 38             0.0
# 39            61.0
# 40             3.0
# 41            36.0
# 42             0.0
# 43             4.0
# 44            15.0
# 45             9.0
# 46          1944.0
# 47            50.0
# 48            41.0
# 49           713.0
# 50           113.0
# 51          2257.0
# 52            93.0
# 53          2931.0
# 54             6.0
# 55            13.0
# 56            52.0
# 57           223.0
# 58           102.0
# 59           246.0
# 60             0.0
# 61             6.0
# 62            54.0
# 63            10.0
# 64         23323.0
# 65           137.0
# 66            49.0
# 67           150.0
# 68            18.0
# 69             7.0
# 70             4.0
# 71         86224.0
# 72            51.0
# 73           145.0
# 74           345.0
# 75           123.0
# 76             0.0
# 77             0.0
# 78             NaN
# 79            33.0
# 80          2261.0
# 81            11.0
# 82             5.0
# 83            53.0
# 84             0.0
# 85            19.0
# 86           141.0
# 87            53.0
# 88            40.0
# 89             0.0
# 90            21.0
# 91           595.0
# 92           153.0
# 93            81.0
# 94            27.0
# 95             5.0
# 96          2320.0
# 97            34.0
# 98           110.0
# 99             3.0
# 100            9.0
# 101           42.0
# 102           45.0
# 103           77.0
# 104           19.0
# 105           23.0
# 106         2265.0
# 107           17.0
# 108           34.0
# 109           33.0
# 110        36982.0
# 111          432.0
# 112           72.0
# 113           90.0
# 114           82.0
# 115           46.0
# 116         4860.0
# 117          193.0
# 118            0.0
# 119            0.0
# 120            NaN
# 121           28.0
# 122           15.0
# 123         2497.0
# 124           52.0
# 125         2059.0
# 126        71867.0
# 127          105.0
# 128           57.0
# 129          359.0
# 130           84.0
# 131           62.0
# 132            7.0
# 133            0.0
# 134          138.0
# 135           43.0
# 136            6.0
# 137            7.0
# 138          250.0
# 139           48.0
# 140          126.0
# 141           84.0
# 142           40.0
# 143           62.0
# 144           58.0
# 145           16.0
# 146           22.0
# 147          108.0
# 148           59.0
# 149        39449.0
# 150           53.0
# 151           54.0
# 152            4.0
# 153           29.0
# 154            5.0
# 155           40.0
# 156           44.0
# 157           17.0
# 158           20.0
# 159           95.0
# 160            0.0
# 161            0.0
# 162            0.0
# 163            NaN
#
# [164 rows x 90 columns]

# %% [markdown]
# ## Functions Dataframe for Phase 4

# %%
phase4 = pd.concat([phase4_name_drop, phase4_functions], axis=1)

phase4
# Out:
#                 Student                                          functions  \
# 0                cap182                                                 []
# 1             nfmorenog  [FirstLook.css, bootstrap.min.css, jquery.min....
# 2            falperezgo  [.ajax, data.cityofchicago.org, rows.json, Z.d...
# 3          lfvalderrama  [up.net, shiv.js, main.css, .css, jquery.min.j...
# 4             xdanielsb  [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# 5             ykchautai  [tiry.cloudfront.net, foundation.min.css, styl...
# 6                oeroaq  [.css, style.css, bootstrap.css, balloon.css, ...
# 7          Danielsv9207                                                 []
# 8            janoguerab  [js.org, .v, .min.js, z.document.getElementByI...
# 9           nabautistal  [z.document.getElementById, google.maps.Map, g...
# 10           dsbarrerag  [.CSS, .custom.css, .css, awesome.min.css, jqu...
# 11         Christian7sr  [estilos.css, icon.ico, Etxea.js, z.document.g...
# 12             Chranium  [style.css, main.js, z.document.getElementById...
# 13            srmedinac  [.create, package.json, pkg.title, pkg.version...
# 14         jucjimenezmo  [home.css, search.css, navicon.jpg, .js, js.or...
# 15          kgbayala528  [latest.min.js, jquery.min.js, bootstrap.min.c...
# 16            wolfstain  [up.net, main.css, .css, noscript.css, chicago...
# 17       DianaNavarrete  [.l, morado.jpg, a.active, a.active, google.ma...
# 18            bsgarciac  [document.getElementsByClassName, dx.length, B...
# 19          jiapulidoar  [t.module.exports, grunt.option, grunt.initCon...
# 20           ronaldsg20  [icon.css, ownStyle.css, theme.min.css, bootst...
# 21            bdcajicam  [nearium.css, .js, nearium.js, google.maps.Map...
# 22       andfsanchezlem                                                 []
# 23               li2266                                                 []
# 24          JulianaNino  [bootstrap.min.css, .navbar, Respond.js, shiv....
# 25           jonatan360  [awesome.min.css, bootstrap.min.css, style.css...
# 26            camilo654  [.ready, k.click, .ajax, data.cityofchicago.or...
# 27         stevenbustos  [style.css, jquery.min.js, distanceFunc.js, ge...
# 28         jscontrerasp  [latest.min.js, google.maps.LatLng, google.map...
# 29           gsuarezc04  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 30           jmalvarezd  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 31           katherinsb  [reset.css, layout.css, style.css, .js, yui.js...
# 32               annipi                                                 []
# 33            fmbernalb                                                 []
# 34           mballeng91  [.bin, e.g, protractor.conf.js, exports.config...
# 35      jscastelblancoh  [bootstrap.min.css, theme.min.css, style.css, ...
# 36             capinzor  [bootstrap.min.css, estilos.css, .min.js, boot...
# 37            jdsuarezj  [google.maps.Map, z.document.getElementById, g...
# 38       jufcontrerasco  [body.css, favicon.ico, js.org, .v, .min.js, p...
# 39           NicolasZon  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 40                 tres                                                 []
# 41          hsmartineza  [jquery.min.js, .js, maps.js, house.js, weathe...
# 42          dfhincapiem  [main.js, google.maps.Map, z.document.getEleme...
# 43            gasierram  [illinois.edu, favicon.ico, bootstrap.min.css,...
# 44           JuanitoAli  [bootstrap.css, .js, Bootstrap.js, logic.js, u...
# 45            fabianr23  [estilos.css, funciones.js, jquery.min.js, .v,...
# 46         leavendanoro  [style.css, jquery.min.js, js.org, .v, .min.js...
# 47              ccvacad  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 48             jcneivaa                                                 []
# 49            yocuervoc                                                 []
# 50           JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....
# 51          CSebasGomez                                                 []
# 52          juandavidro  [style.css, scripto.js, bootstrap.min.css, sit...
# 53            jdsolanos                                                 []
# 54          afceballosr  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 55                DglyP  [bootstrap.min.css, style.css, jquery.min.js, ...
# 56         jjrodriguezn  [google.maps.Map, z.document.getElementById, g...
# 57          CamiloRueda  [layout.css, shiv.js, z.document.getElementByI...
# 58             oserasoa  [bootstrap.min.css, theme.min.css, jquery.min....
# 59           joaortizro  [z.document.getElementById, google.maps.Map, b...
# 60             davidh17  [bootstrap.min.css, style.css, jquery.min.js, ...
# 61         JairVillalba  [fH.css, jquery.min.js, .js, call.js, climate....
# 62           davidrh195  [navicon.jpg, style.css, z.document.getElement...
# 63           juclopezso  [bootstrap.min.css, portfolio.css, awesome.min...
# 64         raulramirezp  [up.net, main.css, bootstrap.min.css, jquery.m...
# 65          camilo13152  [mapController.js, favicon.ico, fluidbox.min.c...
# 66           kmendezp96  [js.org, .v, .min.js, bar.css, StyleSheet.css,...
# 67           miaborjaac  [bootstrap.min.css, modifier.css, jquery.min.j...
# 68             dduartec  [.js, style.css, superplaceholder.js, superpla...
# 69           crarojasca                                                 []
# 70       UNhcrodriguezl  [demos.css, bootstrap.min.css, select.min.css,...
# 71            pipemax85  [bootstrap.min.css, theme.min.css, jquery.min....
# 72        ivdgonzalezco  [favicon.ico, bootstrap.min.css, awesome.css, ...
# 73       jesusfchavarro  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...
# 74         wilson911013  [.js, jsInitMap.js, .ajax, t.module.exports, o...
# 75   JhonEmmanuelTorres                                                 []
# 76            jjmuesesq  [z.document.getElementById, google.maps.Map, g...
# 77         adamantwharf  [z.document.getElementById, google.maps.Map, g...
# 78           NicolasPrr  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 79             luegilca  [bootstrap.min.css, .js, js.org, .v, .min.js, ...
# 80            macuestap  [style.css, favicon.ico, bootstrap.min.css, th...
# 81            lemartinp  [google.maps.Map, z.document.getElementById, g...
# 82          dagofonseca  [style.css, jquery.min.js, maps.js, markerclus...
# 83            jsviveroj  [.css, bootstrap.min.css, freelancer.min.js, s...
# 84         luealfonsoru  [bootstrap.min.css, balloon.min.css, freelance...
# 85            afforeroc  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...
# 86            djguzmanc  [google.maps.LatLng, google.maps.Map, z.docume...
# 87            uxjudges2                                                 []
# 88           cdcordobaa  [bootstrap.min.css, main.css, .org, .js, maps....
# 89              gcantem  [window.XMLHttpRequest, Microsoft.XMLHTTP, ren...
# 90           feartheGru                                                 []
# 91           lgmoralesa  [bootstrap.min.css, jquery.min.js, Javascript....
# 92       CristianLozano  [z.document.getElementById, google.maps.Map, g...
# 93             mdbelloc  [jquery.min.js, bootstrap.min.css, tutorial.cs...
# 94               Yelis3  [semantic.min.css, calendar.min.css, style.css...
# 95       joahernandezca  [z.document.getElementById, google.maps.Map, g...
# 96          anfmorenoso  [bootstrap.min.css, estilos.css, scripto.js, z...
# 97        jumcorredorro  [jquery.min.js, bootstrap.min.css, .js, script...
# 98            begarzonf  [reset.css, layout.css, style.css, jquery.fanc...
# 99               spenas  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 100           smarquezo  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 101              gabi04  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 102        maikellPardo                                                 []
# 103          jmhurtadoc  [.controls, .pac, searchBox.js, bootstrap.min....
# 104        jusherrerama  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 105          fevargasmo  [this.valueOf, this.name, window.location.relo...
# 106            aldiazve  [bootstrap.min.css, main.css, bundle.js, main....
# 107            lsfinite  [.css, awesome.min.css, latest.min.js, room.js...
# 108           jorge52an  [main.css, material.min.js, angular.min.js, an...
# 109          daandradec  [style.css, bootstrap.min.css, jquery.min.js, ...
# 110          jsnarvaezb  [bootstrap.min.css, jquery.min.js, style.css, ...
# 111          capinillab  [z.document.getElementById, google.maps.Map, g...
# 112         djsanabriac  [bootstrap.min.css, main.js, jquery.min.js, z....
# 113      cesarochoa2006  [.getFullYear, nconsole.log, r.main, O.hide, ....
# 114     juasmartinezbel  [bootstrap.min.css, jquery.min.js, .js, js.org...
# 115          debeltranc  [runner.github.io, t.module.exports, config.se...
# 116            adriel62  [favicon.ico, .min.js, bootstrap.min.css, appl...
# 117      diegoaguevarar  [style.css, blocks.css, bootstrap.min.css, the...
# 118           ligibrial  [funciones.js, bootstrap.min.css, jquery.min.j...
# 119           juanescai                                                 []
# 120            jcrubioa  [bootstrap.min.css, awesome.min.css, animate.c...
# 121          Phoenixest  [a.active, a.active, z.document.getElementById...
# 122           juligarji  [jquery.min.js, bootstrap.min.css, awesome.min...
# 123              kancas  [style.css, bootstrap.min.css, theme.min.css, ...
# 124             ItsNavi                                                 []
# 125            leguzman  [GetDeepSearchResults.htm, .ready, nconsole.lo...
# 126          jmcuestasb  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 127           sacastroc  [js.org, .v, .min.js, collection.v, dispatch.v...
# 128          jhonsd1996  [style.css, .Chicago, z.document.getElementByI...
# 129           jdmonroyg                                                 []
# 130             Zeugmax                                                 []
# 131             MogGy94                                                 []
# 132              sagilm  [data.cityofchicago.org, rows.json, pxmlhttp.o...
# 133             sarizag  [js.org, .v, .min.js, style.css, jquery.min.js...
# 134          dasalgadob  [bootstrap.min.css, theme.min.css, jquery.min....
# 135             Gantiva  [latest.min.js, jquery.min.js, foo.js, opcione...
# 136            idrojasf  [components.css, responsee.css, owl.carousel.j...
# 137            Moimolcp  [bootstrap.min.css, style.css, scripto.js, jqu...
# 138          anmmunozme  [.ajax, data.cityofchicago.org, iimk.json, Z.d...
# 139          jhriverasa  [style.css, bootstrap.min.css, jquery.min.js, ...
# 140           fffeelipe  [.ready, k.click, w.removeClass, .is, .val, .m...
# 141       gfalbarracinr  [bootstrap.min.css, main.css, .jpg, jane.doe, ...
# 142       cccristanchoc  [unal.edu.co, bootstrap.min.css, template.css,...
# 143           pcberriop  [jquery.min.js, Mapa.js, main.css, avatar.jpg,...
# 144          ncampuzano  [bootstrap.min.css, awesome.min.css, app.css, ...
# 145           helmeraac  [style.css, jquery.min.js, integration.js, scr...
# 146            ofnanezn  [.create, package.json, pkg.title, pkg.version...
# 147           odprietoh                                                 []
# 148       maikellPardoA  [z.document.getElementById, google.maps.Map, g...
# 149       wapiravaguens  [.css, .js, js.org, .v, bootstrap.min.css, the...
# 150          Dandarprox  [Bootstrap.js, bootstrap.css, style.css, table...
# 151            HashNick  [jquery.min.js, bootstrap.min.css, .js, js.org...
# 152         diegocruz10  [bootstrap.min.css, awesome.min.css, theme.min...
# 153          Davsatu313  [Style.css, .min.js, js.org, .v, maps.js, clim...
# 154         lacardenasv  [materialize.css, materialize.min.css, styleSe...
# 155             bdvegat  [js.org, .v, .js, bootstrap.min.css, bootstrap...
# 156           lizzyt10h  [bootstrap.min.css, jquery.min.js, index.css, ...
# 157             DavidQP  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 158         Judgarciani  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159         oacastillol  [bootstrap.min.css, theme.min.css, awesome.min...
# 160           mnguzmanc  [house.ico, style.css, .css, main.js, maps.js,...
# 161         Semoralesga  [style.css, bootstrap.min.css, .js, scripto.js...
# 162         jhcardenasa                                                 []
# 163              crigar  [z.document.getElementById, google.maps.Map, g...
# 164           AFelipeGA  [materialize.min.css, style.css, awesome.min.c...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          51
# 2    [.ajax, data.cityofchicago.org, rows.json, Z.d...        1859
# 3    [up.net, shiv.js, main.css, .css, jquery.min.j...          62
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...         224
# 5    [tiry.cloudfront.net, foundation.min.css, styl...          21
# 6    [.css, style.css, bootstrap.css, balloon.css, ...        2512
# 7                                                   []           0
# 8    [js.org, .v, .min.js, z.document.getElementByI...          36
# 9    [z.document.getElementById, google.maps.Map, g...           8
# 10   [.CSS, .custom.css, .css, awesome.min.css, jqu...          56
# 11   [estilos.css, icon.ico, Etxea.js, z.document.g...           6
# 12   [style.css, main.js, z.document.getElementById...           5
# 13   [.create, package.json, pkg.title, pkg.version...          55
# 14   [home.css, search.css, navicon.jpg, .js, js.or...          59
# 15   [latest.min.js, jquery.min.js, bootstrap.min.c...         108
# 16   [up.net, main.css, .css, noscript.css, chicago...         228
# 17   [.l, morado.jpg, a.active, google.maps.Map, z....           6
# 18   [document.getElementsByClassName, dx.length, B...         127
# 19   [t.module.exports, grunt.option, grunt.initCon...       71443
# 20   [icon.css, ownStyle.css, theme.min.css, bootst...       34505
# 21   [nearium.css, .js, nearium.js, google.maps.Map...          36
# 22                                                  []           0
# 23                                                  []           0
# 24   [bootstrap.min.css, .navbar, Respond.js, shiv....          23
# 25   [awesome.min.css, bootstrap.min.css, style.css...         125
# 26   [.ready, k.click, .ajax, data.cityofchicago.or...          30
# 27   [style.css, jquery.min.js, distanceFunc.js, ge...          21
# 28   [latest.min.js, google.maps.LatLng, google.map...          27
# 29   [google.maps.LatLng, google.maps.mapTypeId.ROA...          41
# 30   [jmalvarezd.js, bootstrap.min.css, jquery.min....          53
# 31   [reset.css, layout.css, style.css, .js, yui.js...          21
# 32                                                  []           0
# 33                                                  []           0
# 34   [.bin, e.g, protractor.conf.js, exports.config...       60922
# 35   [bootstrap.min.css, theme.min.css, style.css, ...         174
# 36   [bootstrap.min.css, estilos.css, .min.js, just...        1672
# 37   [google.maps.Map, z.document.getElementById, g...          66
# 38   [body.css, favicon.ico, js.org, .v, .min.js, p...          72
# 39   [google.maps.LatLng, google.maps.mapTypeId.ROA...          12
# 40                                                  []           0
# 41   [jquery.min.js, .js, maps.js, house.js, weathe...          62
# 42   [main.js, google.maps.Map, z.document.getEleme...           4
# 43   [illinois.edu, favicon.ico, bootstrap.min.css,...          60
# 44   [bootstrap.css, .js, Bootstrap.js, logic.js, u...        2121
# 45   [estilos.css, funciones.js, jquery.min.js, .v,...         171
# 46   [style.css, jquery.min.js, js.org, .v, .min.js...          44
# 47   [bootstrap.min.css, jquery.min.js, style.css, ...          71
# 48                                                  []           0
# 49                                                  []           0
# 50   [bootstrap.min.css, theme.min.css, jquery.min....          48
# 51                                                  []           0
# 52   [style.css, scripto.js, bootstrap.min.css, sit...          15
# 53                                                  []           0
# 54   [bootstrap.min.css, style.css, bulk.jpg, jquer...          36
# 55   [bootstrap.min.css, style.css, jquery.min.js, ...        2246
# 56   [google.maps.Map, z.document.getElementById, g...          28
# 57   [layout.css, shiv.js, z.document.getElementByI...          46
# 58   [bootstrap.min.css, theme.min.css, jquery.min....          45
# 59   [z.document.getElementById, google.maps.Map, b...          18
# 60   [bootstrap.min.css, style.css, jquery.min.js, ...          88
# 61   [fH.css, jquery.min.js, .js, call.js, climate....          36
# 62   [navicon.jpg, style.css, z.document.getElement...          20
# 63   [bootstrap.min.css, portfolio.css, awesome.min...          29
# 64   [up.net, main.css, bootstrap.min.css, jquery.m...         247
# 65   [mapController.js, favicon.ico, fluidbox.min.c...          87
# 66   [js.org, .v, .min.js, bar.css, StyleSheet.css,...          93
# 67   [bootstrap.min.css, modifier.css, jquery.min.j...         115
# 68   [.js, style.css, superplaceholder.js, maps.js,...         103
# 69                                                  []           0
# 70   [demos.css, bootstrap.min.css, select.min.css,...          88
# 71   [bootstrap.min.css, theme.min.css, jquery.min....          27
# 72   [favicon.ico, bootstrap.min.css, awesome.css, ...         225
# 73   [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...        5568
# 74   [.js, jsInitMap.js, .ajax, t.module.exports, o...         346
# 75                                                  []           0
# 76   [z.document.getElementById, google.maps.Map, g...          13
# 77   [z.document.getElementById, google.maps.Map, g...           3
# 78   [bootstrap.min.css, jquery.min.js, mapControl....         644
# 79   [bootstrap.min.css, .js, js.org, .v, .min.js, ...          32
# 80   [style.css, favicon.ico, bootstrap.min.css, th...          16
# 81   [google.maps.Map, z.document.getElementById, g...          25
# 82   [style.css, jquery.min.js, maps.js, markerclus...         239
# 83   [.css, bootstrap.min.css, freelancer.min.js, s...          58
# 84   [bootstrap.min.css, balloon.min.css, freelance...          84
# 85   [bootstrap.min.css, uic.edu, .js, z.document.g...           6
# 86   [google.maps.LatLng, google.maps.Map, z.docume...          64
# 87                                                  []           0
# 88   [bootstrap.min.css, main.css, .org, .js, maps....          32
# 89   [window.XMLHttpRequest, Microsoft.XMLHTTP, ren...         165
# 90                                                  []           0
# 91   [bootstrap.min.css, jquery.min.js, Javascript....          71
# 92   [z.document.getElementById, google.maps.Map, g...           7
# 93   [jquery.min.js, bootstrap.min.css, tutorial.cs...          53
# 94   [semantic.min.css, calendar.min.css, style.css...       32726
# 95   [z.document.getElementById, google.maps.Map, g...         120
# 96   [bootstrap.min.css, estilos.css, scripto.js, z...          36
# 97   [jquery.min.js, bootstrap.min.css, .js, script...         150
# 98   [reset.css, layout.css, style.css, jquery.fanc...         424
# 99   [bootstrap.min.css, mdb.min.css, demos.css, st...          22
# 100  [bootstrap.min.css, jquery.min.js, resolution....          20
# 101  [google.maps.LatLng, google.maps.mapTypeId.ROA...          58
# 102                                                 []           0
# 103  [.controls, .pac, searchBox.js, bootstrap.min....         145
# 104  [js.org, .v, .min.js, bootstrap.min.css, portf...        2014
# 105  [this.valueOf, this.name, window.location.relo...          56
# 106  [bootstrap.min.css, main.css, bundle.js, main....       23405
# 107  [.css, awesome.min.css, latest.min.js, room.js...        4541
# 108  [main.css, material.min.js, angular.min.js, an...         271
# 109  [style.css, bootstrap.min.css, jquery.min.js, ...         279
# 110  [bootstrap.min.css, jquery.min.js, style.css, ...          68
# 111  [z.document.getElementById, google.maps.Map, g...          34
# 112  [bootstrap.min.css, main.js, jquery.min.js, z....          32
# 113  [.getFullYear, nconsole.log, r.main, O.hide, ....         180
# 114  [bootstrap.min.css, jquery.min.js, .js, js.org...         194
# 115  [runner.github.io, t.module.exports, config.se...          19
# 116  [favicon.ico, .min.js, bootstrap.min.css, appl...        4394
# 117  [style.css, blocks.css, bootstrap.min.css, the...         132
# 118  [funciones.js, bootstrap.min.css, jquery.min.j...        2019
# 119                                                 []           0
# 120  [bootstrap.min.css, awesome.min.css, animate.c...         335
# 121  [a.active, z.document.getElementById, google.m...           4
# 122  [jquery.min.js, bootstrap.min.css, awesome.min...        2294
# 123  [style.css, bootstrap.min.css, theme.min.css, ...          41
# 124                                                 []           0
# 125  [GetDeepSearchResults.htm, .ready, nconsole.lo...          97
# 126  [js.org, .v, .min.js, weather.js, mycss.css, b...        6404
# 127  [js.org, .v, .min.js, collection.v, dispatch.v...          78
# 128  [style.css, .Chicago, z.document.getElementByI...           5
# 129                                                 []           0
# 130                                                 []           0
# 131                                                 []           0
# 132  [data.cityofchicago.org, rows.json, pxmlhttp.o...          21
# 133  [js.org, .v, .min.js, style.css, jquery.min.js...          30
# 134  [bootstrap.min.css, theme.min.css, jquery.min....           8
# 135  [latest.min.js, jquery.min.js, foo.js, opcione...          50
# 136  [components.css, responsee.css, owl.carousel.j...         564
# 137  [bootstrap.min.css, style.css, scripto.js, jqu...          76
# 138  [.ajax, data.cityofchicago.org, iimk.json, Z.d...          53
# 139  [style.css, bootstrap.min.css, jquery.min.js, ...          86
# 140  [.ready, k.click, w.removeClass, .is, .val, .m...         102
# 141  [bootstrap.min.css, main.css, .jpg, jane.doe, ...          18
# 142  [unal.edu.co, bootstrap.min.css, template.css,...          75
# 143  [jquery.min.js, Mapa.js, main.css, avatar.jpg,...          65
# 144  [bootstrap.min.css, awesome.min.css, app.css, ...          84
# 145  [style.css, jquery.min.js, integration.js, scr...          34
# 146  [.create, package.json, pkg.title, pkg.version...          57
# 147                                                 []           0
# 148  [z.document.getElementById, google.maps.Map, g...           4
# 149  [.css, .js, js.org, .v, bootstrap.min.css, the...          72
# 150  [Bootstrap.js, bootstrap.css, style.css, table...         171
# 151  [jquery.min.js, bootstrap.min.css, .js, js.org...          59
# 152  [bootstrap.min.css, awesome.min.css, theme.min...          39
# 153  [Style.css, .min.js, js.org, .v, maps.js, clim...          90
# 154  [materialize.css, materialize.min.css, styleSe...        9501
# 155  [js.org, .v, .js, bootstrap.min.css, cs.css, f...          10
# 156  [bootstrap.min.css, jquery.min.js, index.css, ...          62
# 157  [bootstrap.min.css, Respond.js, shiv.min.js, r...          44
# 158  [bootstrap.min.css, jquery.min.js, Rent.js, Cr...         130
# 159  [bootstrap.min.css, theme.min.css, awesome.min...         294
# 160  [house.ico, style.css, .css, main.js, maps.js,...        1760
# 161  [style.css, bootstrap.min.css, .js, scripto.js...          17
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [materialize.min.css, style.css, awesome.min.c...        1907
#
#      len_functions
# 0                0
# 1               52
# 2             2003
# 3               62
# 4              229
# 5               21
# 6             3110
# 7                0
# 8               36
# 9                8
# 10              57
# 11               6
# 12               5
# 13              56
# 14              59
# 15             108
# 16             236
# 17               7
# 18             130
# 19           86224
# 20           39502
# 21              36
# 22               0
# 23               0
# 24              25
# 25             127
# 26              30
# 27              21
# 28              28
# 29              41
# 30              54
# 31              21
# 32               0
# 33               0
# 34           71871
# 35             177
# 36            1852
# 37              66
# 38              95
# 39              12
# 40               0
# 41              63
# 42               4
# 43              61
# 44            2375
# 45             185
# 46              46
# 47              73
# 48               0
# 49               0
# 50              49
# 51               0
# 52              15
# 53               0
# 54              39
# 55            2844
# 56              28
# 57              47
# 58              46
# 59              19
# 60              89
# 61              36
# 62              20
# 63              29
# 64             256
# 65              87
# 66              94
# 67             118
# 68             105
# 69               0
# 70              89
# 71              28
# 72             238
# 73            6556
# 74             362
# 75               0
# 76              14
# 77               3
# 78             678
# 79              33
# 80              17
# 81              26
# 82             257
# 83              60
# 84              85
# 85               7
# 86              65
# 87               0
# 88              32
# 89             171
# 90               0
# 91              74
# 92               7
# 93              53
# 94           37076
# 95             125
# 96              36
# 97             166
# 98             432
# 99              22
# 100             21
# 101             58
# 102              0
# 103            150
# 104           2261
# 105             56
# 106          26634
# 107           4862
# 108            284
# 109            286
# 110             68
# 111             35
# 112             32
# 113            184
# 114            203
# 115             19
# 116           4985
# 117            137
# 118           2266
# 119              0
# 120            345
# 121              5
# 122           2563
# 123             42
# 124              0
# 125            100
# 126           7051
# 127             81
# 128              5
# 129              0
# 130              0
# 131              0
# 132             21
# 133             31
# 134              9
# 135             51
# 136            596
# 137             80
# 138             54
# 139             91
# 140            106
# 141             18
# 142             76
# 143             66
# 144             86
# 145             34
# 146             58
# 147              0
# 148              4
# 149             84
# 150            174
# 151             59
# 152             40
# 153             90
# 154          10873
# 155             11
# 156             66
# 157             44
# 158            138
# 159            317
# 160           2290
# 161             17
# 162              0
# 163              4
# 164           2059

# %% [markdown]
# ### phase 4 functions dataframe merge with overall dataframe to know the groups.

# %%
overall_phase4 = overall_loc_scores.merge(phase4[['Student','functions', 'unique', 'len_unique', 'len_functions']], on='Student', how='left')
overall_phase4
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# 5                 DglyP    0.0                     20.0           25.00
# 6                cap182    0.0                     20.0           29.17
# 7           annumumozme    0.0                     40.0           37.50
# 8           Judgarciani    0.0                    100.0           58.33
# 9             sacastroc    0.0                     20.0           50.00
# 10            pcberriop    0.0                     20.0           37.50
# 11          hsmartineza    0.0                     20.0           33.33
# 12             Moimolcp    0.0                    100.0           62.50
# 13          CamiloRueda    0.0                      0.0           29.17
# 14            juanescai    0.0                      0.0           25.00
# 15           JoseMolano    0.0                     60.0           66.67
# 16        maikellPardoA    0.0                      0.0           37.50
# 17           NicolasZon    0.0                      0.0           25.00
# 18            camilo654    0.0                     20.0           29.17
# 19       CristianLozano    0.0                     20.0           33.33
# 20            jdsuarezj    0.0                     60.0           50.00
# 21            pipemax85    0.0                     20.0           33.33
# 22          juandavidro    0.0                     20.0           58.33
# 23       UNhcrodriguezl    0.0                     80.0           33.33
# 24          camilo13152    0.0                     60.0           50.00
# 25         leavendanoro    0.0                     40.0           66.67
# 26           cdcordobaa    0.0                     20.0           33.33
# 27           capinillab    0.0                     60.0           54.17
# 28           janoguerab    0.0                     20.0           29.17
# 29         lfvalderrama    0.0                     80.0           66.67
# 30            bsgarciac    0.0                    100.0           70.83
# 31               gabi04    0.0                     20.0           29.17
# 32               annipi    0.0                      0.0            0.00
# 33            jdsolanos    0.0                      0.0            0.00
# 34             jcneivaa    0.0                      0.0            0.00
# 35            fmbernalb    0.0                      0.0            0.00
# 36              MogGy94    0.0                      0.0            0.00
# 37            yocuervoc    0.0                      0.0            0.00
# 38            odprietoh    0.0                      0.0            0.00
# 39            gasierram    1.0                     40.0           62.50
# 40         adamantwharf    1.0                     20.0           25.00
# 41            bdcajicam    1.0                     40.0           29.17
# 42       andfsanchezlem    1.0                     20.0           25.00
# 43          dfhincapiem    1.0                     20.0           25.00
# 44            helmeraac    1.0                      0.0           25.00
# 45           dasalgadob    1.0                      0.0           25.00
# 46           falperezgo    1.0                     20.0           45.83
# 47            djguzmanc    1.0                     80.0           79.17
# 48           gsuarezc04    1.0                      0.0           25.00
# 49               oeroaq    1.0                    100.0           87.50
# 50              gcantem    1.0                    100.0           70.83
# 51          Semoralesga    1.0                     20.0           33.33
# 52           jonatan360    1.0                    100.0           75.00
# 53       jesusfchavarro    1.0                    100.0           62.50
# 54         stevenbustos    1.0                     20.0           33.33
# 55       jufcontrerasco    1.0                     60.0           79.17
# 56           dsbarrerag    1.0                     80.0           70.83
# 57            wolfstain    1.0                     20.0           33.33
# 103           37.50        275.83        100.0         75.0
# 104           25.00        125.00         75.0         50.0
# 105           75.00        211.67         75.0         75.0
# 106           25.00        145.83         87.5         62.5
# 107            0.00         95.00         50.0         62.5
# 108           75.00        224.17         87.5         75.0
# 109            0.00        100.00         62.5         62.5
# 110           62.50        309.17        100.0         87.5
# 111           75.00        227.50         87.5         75.0
# 112           65.63        304.79        100.0         62.5
# 113          100.00        339.17        100.0        100.0
# 114           25.00        158.33         87.5         87.5
# 115           33.33        154.17         87.5         37.5
# 116           12.50        125.00         87.5          0.0
# 117           70.00        357.50        100.0         50.0
# 118            0.00          0.00          0.0          0.0
# 119            0.00          0.00          0.0          0.0
# 120            0.00          0.00          0.0          0.0
# 121            0.00          0.00          0.0          0.0
# 122           87.50        329.17         87.5         87.5
# 123           92.50        355.00         87.5        100.0
# 124           15.00        127.50         75.0         75.0
# 125           56.25        221.25         87.5         75.0
# 126           25.00        112.50         62.5         62.5
# 127           95.00        345.83         87.5         87.5
# 128            0.00        128.33         75.0         62.5
# 129            0.00         75.00         50.0         37.5
# 130           72.50        327.50        100.0         62.5
# 131           56.25        209.58         87.5         75.0
# 132           25.00        145.00         37.5         37.5
# 133           25.00         75.00         25.0          0.0
# 134           60.00        310.00        100.0         75.0
# 135          100.00        358.33         75.0         75.0
# 136           81.25        278.75         87.5         62.5
# 137           50.00        161.67         62.5         50.0
# 138           66.67        231.67         87.5         87.5
# 139           75.00        350.00        100.0         87.5
# 140           37.50        235.00         75.0         62.5
# 141           50.00        203.33         87.5         62.5
# 142           67.50        301.67         87.5         87.5
# 143           58.33        203.33        100.0         87.5
# 144           25.00        198.33         75.0         50.0
# 145           25.00        177.50         62.5         62.5
# 146            0.00        115.83         62.5         62.5
# 147           81.25        298.75         87.5         62.5
# 148           87.50        345.83         87.5         87.5
# 149           12.50        178.33        100.0        100.0
# 150           56.25        197.08         87.5         62.5
# 151           93.75        348.75        100.0         87.5
# 152           57.50        185.83         75.0         62.5
# 153           56.25        209.58        100.0         75.0
# 154            0.00         95.00         50.0         50.0
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
# 160            0.00          0.00          0.0          0.0
# 161            0.00          0.00          0.0          0.0
# 162            0.00          0.00          0.0          0.0
# 163             NaN           NaN          NaN          NaN
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...              104.0
# 5                        0.0           25.00  ...               21.5
# 6                       20.0           29.17  ...              -39.5
# 7                        0.0            0.00  ...                NaN
# 8                       80.0           87.50  ...              -19.5
# 9                       20.0           50.00  ...                0.0
# 10                      20.0           33.33  ...                2.5
# 11                      20.0           37.50  ...               -1.5
# 12                       0.0           33.33  ...                0.0
# 13                      20.0           25.00  ...                0.0
# 21                 2.0                0.0
# 22               274.5              283.0
# 23                 0.0                0.0
# 24                 0.0                0.0
# 25                -2.0               38.5
# 26               -17.5               -8.0
# 27               -75.0              -22.5
# 28                 NaN                0.0
# 29                 2.5                1.5
# 30                 0.0               10.0
# 31                 0.0              -23.5
# 32                 0.0               26.0
# 33                 0.0               16.0
# 34                 0.0                0.0
# 35                 0.0                0.0
# 36                 0.0                0.0
# 37                 0.0                0.0
# 38                 0.0                0.0
# 39               -23.0               -5.5
# 40                 0.0               43.5
# 41                26.0                0.0
# 42               -21.0               16.5
# 43                 0.0              -18.5
# 44                 1.0               -9.5
# 45                 0.0               43.0
# 46                35.5                0.0
# 47              -404.0                0.0
# 48                 0.0                6.5
# 49              -121.0              -33.0
# 50                -6.5               21.0
# 51               -25.0              -16.5
# 52               -15.0               -2.0
# 53                -7.0                0.0
# 54               -34.0               76.5
# 55                 2.0               -5.5
# 56                49.5               31.5
# 57              -183.5             -134.5
# 58                19.5               10.0
# 59                -1.5              -70.5
# ...
# 148  [bootstrap.min.css, jquery.min.js, Javascript....
# 149  [icon.css, ownStyle.css, theme.min.css, bootst...
# 150  [unal.edu.co, bootstrap.min.css, template.css,...
# 151  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 152  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 153  [js.org, .v, .min.js, style.css, jquery.min.js...
# 154  [style.css, main.js, z.document.getElementById...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.css, .js, script...
# 160                                                 []
# 161                                                 []
# 162                                                 []
# 163                                                NaN
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, w.removeClass, .is, .val, .m...       102.0
# 1    [house.ico, style.css, .css, main.js, maps.js,...      1760.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      6404.0
# 3    [reset.css, layout.css, style.css, .js, yui.js...        21.0
# 4    [google.maps.Map, z.document.getElementById, g...        28.0
# 5    [bootstrap.min.css, style.css, jquery.min.js, ...      2246.0
# 6                                                   []         0.0
# 7                                                  NaN         NaN
# 8    [bootstrap.min.css, jquery.min.js, Rent.js, Cr...       130.0
# 9    [js.org, .v, .min.js, collection.v, dispatch.v...        78.0
# 10   [jquery.min.js, Mapa.js, main.css, avatar.jpg,...        65.0
# 11   [jquery.min.js, .js, maps.js, house.js, weathe...        62.0
# 12   [bootstrap.min.css, style.css, scripto.js, jqu...        76.0
# 13   [layout.css, shiv.js, z.document.getElementByI...        46.0
# 14                                                  []         0.0
# 15   [bootstrap.min.css, theme.min.css, jquery.min....        48.0
# 16   [z.document.getElementById, google.maps.Map, g...         4.0
# 17   [google.maps.LatLng, google.maps.mapTypeId.ROA...        12.0
# 18   [.ready, k.click, .ajax, data.cityofchicago.or...        30.0
# 19   [z.document.getElementById, google.maps.Map, g...         7.0
# 20   [google.maps.Map, z.document.getElementById, g...        66.0
# 21   [bootstrap.min.css, theme.min.css, jquery.min....        27.0
# 22   [style.css, scripto.js, bootstrap.min.css, sit...        15.0
# 23   [demos.css, bootstrap.min.css, select.min.css,...        88.0
# 24   [mapController.js, favicon.ico, fluidbox.min.c...        87.0
# 25   [style.css, jquery.min.js, js.org, .v, .min.js...        44.0
# 26   [bootstrap.min.css, main.css, .org, .js, maps....        32.0
# 27   [z.document.getElementById, google.maps.Map, g...        34.0
# 28   [js.org, .v, .min.js, z.document.getElementByI...        36.0
# 29   [up.net, shiv.js, main.css, .css, jquery.min.j...        62.0
# 30   [document.getElementsByClassName, dx.length, B...       127.0
# 31   [google.maps.LatLng, google.maps.mapTypeId.ROA...        58.0
# 32                                                  []         0.0
# 33                                                  []         0.0
# 34                                                  []         0.0
# 35                                                  []         0.0
# 36                                                  []         0.0
# 37                                                  []         0.0
# 38                                                  []         0.0
# 39   [illinois.edu, favicon.ico, bootstrap.min.css,...        60.0
# 40   [z.document.getElementById, google.maps.Map, g...         3.0
# 41   [nearium.css, .js, nearium.js, google.maps.Map...        36.0
# 42                                                  []         0.0
# 43   [main.js, google.maps.Map, z.document.getEleme...         4.0
# 44   [style.css, jquery.min.js, integration.js, scr...        34.0
# 45   [bootstrap.min.css, theme.min.css, jquery.min....         8.0
# 46   [.ajax, data.cityofchicago.org, rows.json, Z.d...      1859.0
# 47   [google.maps.LatLng, google.maps.Map, z.docume...        64.0
# 48   [google.maps.LatLng, google.maps.mapTypeId.ROA...        41.0
# 49   [.css, style.css, bootstrap.css, balloon.css, ...      2512.0
# 50   [window.XMLHttpRequest, Microsoft.XMLHTTP, ren...       165.0
# 51   [style.css, bootstrap.min.css, .js, scripto.js...        17.0
# 52   [awesome.min.css, bootstrap.min.css, style.css...       125.0
# 53   [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      5568.0
# 54   [style.css, jquery.min.js, distanceFunc.js, ge...        21.0
# 55   [body.css, favicon.ico, js.org, .v, .min.js, p...        72.0
# 56   [.CSS, .custom.css, .css, awesome.min.css, jqu...        56.0
# 57   [up.net, main.css, .css, noscript.css, chicago...       228.0
# 58   [bootstrap.min.css, modifier.css, jquery.min.j...       115.0
# 59   [favicon.ico, bootstrap.min.css, awesome.css, ...       225.0
# 60                                                  []         0.0
# 61   [estilos.css, icon.ico, Etxea.js, z.document.g...         6.0
# 62   [bootstrap.min.css, jquery.min.js, style.css, ...        68.0
# 63   [bootstrap.min.css, main.css, .jpg, jane.doe, ...        18.0
# 64   [bootstrap.min.css, main.css, bundle.js, main....     23405.0
# 65   [style.css, blocks.css, bootstrap.min.css, the...       132.0
# 66   [this.valueOf, this.name, window.location.relo...        56.0
# 67   [.controls, .pac, searchBox.js, bootstrap.min....       145.0
# 68   [bootstrap.min.css, estilos.css, scripto.js, z...        36.0
# 69   [z.document.getElementById, google.maps.Map, g...         8.0
# 70   [z.document.getElementById, google.maps.Map, g...         4.0
# 71   [t.module.exports, grunt.option, grunt.initCon...     71443.0
# 72   [.css, bootstrap.min.css, freelancer.min.js, s...        58.0
# 73   [style.css, bootstrap.min.css, jquery.min.js, ...       279.0
# 74   [bootstrap.min.css, awesome.min.css, animate.c...       335.0
# 75   [z.document.getElementById, google.maps.Map, g...       120.0
# 76                                                  []         0.0
# 77                                                  []         0.0
# 78                                                 NaN         NaN
# 79   [fH.css, jquery.min.js, .js, call.js, climate....        36.0
# 80   [js.org, .v, .min.js, bootstrap.min.css, portf...      2014.0
# 81   [js.org, .v, .js, bootstrap.min.css, cs.css, f...        10.0
# 82   [a.active, z.document.getElementById, google.m...         4.0
# 83   [jquery.min.js, bootstrap.min.css, .js, js.org...        59.0
# 84   [bootstrap.min.css, jquery.min.js, style.css, ...        71.0
# 85   [z.document.getElementById, google.maps.Map, b...        18.0
# 86   [bootstrap.min.css, jquery.min.js, .js, js.org...       194.0
# 87   [jquery.min.js, bootstrap.min.css, tutorial.cs...        53.0
# 88   [bootstrap.min.css, awesome.min.css, theme.min...        39.0
# 89                                                  []         0.0
# 90   [data.cityofchicago.org, rows.json, pxmlhttp.o...        21.0
# 91   [components.css, responsee.css, owl.carousel.j...       564.0
# 92   [up.net, main.css, bootstrap.min.css, jquery.m...       247.0
# 93   [estilos.css, funciones.js, jquery.min.js, .v,...       171.0
# 94   [style.css, bootstrap.min.css, jquery.min.js, ...        86.0
# 95   [style.css, .Chicago, z.document.getElementByI...         5.0
# 96   [bootstrap.css, .js, Bootstrap.js, logic.js, u...      2121.0
# 97   [Style.css, .min.js, js.org, .v, maps.js, clim...        90.0
# 98   [.getFullYear, nconsole.log, r.main, O.hide, ....       180.0
# 99   [z.document.getElementById, google.maps.Map, g...        13.0
# 100  [home.css, search.css, navicon.jpg, .js, js.or...        59.0
# 101  [style.css, bootstrap.min.css, theme.min.css, ...        41.0
# 102  [latest.min.js, jquery.min.js, foo.js, opcione...        50.0
# 103  [Bootstrap.js, bootstrap.css, style.css, table...       171.0
# 104  [runner.github.io, t.module.exports, config.se...        19.0
# 105  [tiry.cloudfront.net, foundation.min.css, styl...        21.0
# 106  [funciones.js, bootstrap.min.css, jquery.min.j...      2019.0
# 107  [navicon.jpg, style.css, z.document.getElement...        20.0
# 108  [bootstrap.min.css, .navbar, Respond.js, shiv....        23.0
# 109  [bootstrap.min.css, .js, js.org, .v, .min.js, ...        32.0
# 110  [semantic.min.css, calendar.min.css, style.css...     32726.0
# 111  [reset.css, layout.css, style.css, jquery.fanc...       424.0
# 112  [js.org, .v, .min.js, bar.css, StyleSheet.css,...        93.0
# 113  [GetDeepSearchResults.htm, .ready, nconsole.lo...        97.0
# 114  [bootstrap.min.css, balloon.min.css, freelance...        84.0
# 115  [bootstrap.min.css, theme.min.css, jquery.min....        45.0
# 116  [.css, awesome.min.css, latest.min.js, room.js...      4541.0
# 117  [nconsole.log, jQuery.parseJSON, .ajax, Z.done...       224.0
# 118                                                 []         0.0
# 119                                                 []         0.0
# 120                                                NaN         NaN
# 121  [latest.min.js, google.maps.LatLng, google.map...        27.0
# 122  [google.maps.Map, z.document.getElementById, g...        25.0
# 123  [jquery.min.js, bootstrap.min.css, awesome.min...      2294.0
# 124  [FirstLook.css, bootstrap.min.css, jquery.min....        51.0
# 125  [materialize.min.css, style.css, awesome.min.c...      1907.0
# 126  [.bin, e.g, protractor.conf.js, exports.config...     60922.0
# 127  [.js, style.css, superplaceholder.js, maps.js,...       103.0
# 128  [.create, package.json, pkg.title, pkg.version...        55.0
# 129  [.js, jsInitMap.js, .ajax, t.module.exports, o...       346.0
# 130  [.css, .js, js.org, .v, bootstrap.min.css, the...        72.0
# 131  [bootstrap.min.css, style.css, jquery.min.js, ...        88.0
# 132  [.l, morado.jpg, a.active, google.maps.Map, z....         6.0
# 133                                                 []         0.0
# 134  [main.css, material.min.js, angular.min.js, an...       271.0
# 135  [bootstrap.min.css, theme.min.css, style.css, ...       174.0
# 136  [bootstrap.min.css, portfolio.css, awesome.min...        29.0
# 137  [bootstrap.min.css, uic.edu, .js, z.document.g...         6.0
# 138  [style.css, jquery.min.js, maps.js, markerclus...       239.0
# 139  [materialize.css, materialize.min.css, styleSe...      9501.0
# 140  [bootstrap.min.css, theme.min.css, awesome.min...       294.0
# 141  [bootstrap.min.css, awesome.min.css, app.css, ...        84.0
# 142  [favicon.ico, .min.js, bootstrap.min.css, appl...      4394.0
# 143  [bootstrap.min.css, estilos.css, .min.js, just...      1672.0
# 144  [.create, package.json, pkg.title, pkg.version...        57.0
# 145  [style.css, favicon.ico, bootstrap.min.css, th...        16.0
# 146  [bootstrap.min.css, mdb.min.css, demos.css, st...        22.0
# 147  [latest.min.js, jquery.min.js, bootstrap.min.c...       108.0
# 148  [bootstrap.min.css, jquery.min.js, Javascript....        71.0
# 149  [icon.css, ownStyle.css, theme.min.css, bootst...     34505.0
# 150  [unal.edu.co, bootstrap.min.css, template.css,...        75.0
# 151  [jmalvarezd.js, bootstrap.min.css, jquery.min....        53.0
# 152  [bootstrap.min.css, jquery.min.js, resolution....        20.0
# 153  [js.org, .v, .min.js, style.css, jquery.min.js...        30.0
# 154  [style.css, main.js, z.document.getElementById...         5.0
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        44.0
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...        36.0
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...        62.0
# 158  [bootstrap.min.css, jquery.min.js, mapControl....       644.0
# 159  [jquery.min.js, bootstrap.min.css, .js, script...       150.0
# 160                                                 []         0.0
# 161                                                 []         0.0
# 162                                                 []         0.0
# 163                                                NaN         NaN
#
#      len_functions
# 0            106.0
# 1           2290.0
# 2           7051.0
# 3             21.0
# 4             28.0
# 5           2844.0
# 6              0.0
# 7              NaN
# 8            138.0
# 9             81.0
# 10            66.0
# 11            63.0
# 12            80.0
# 13            47.0
# 14             0.0
# 15            49.0
# 16             4.0
# 17            12.0
# 18            30.0
# 19             7.0
# 20            66.0
# 21            28.0
# 22            15.0
# 23            89.0
# 24            87.0
# 25            46.0
# 26            32.0
# 27            35.0
# 28            36.0
# 29            62.0
# 30           130.0
# 31            58.0
# 32             0.0
# 33             0.0
# 34             0.0
# 35             0.0
# 36             0.0
# 37             0.0
# 38             0.0
# 39            61.0
# 40             3.0
# 41            36.0
# 42             0.0
# 43             4.0
# 44            34.0
# 45             9.0
# 46          2003.0
# 47            65.0
# 48            41.0
# 49          3110.0
# 50           171.0
# 51            17.0
# 52           127.0
# 53          6556.0
# 54            21.0
# 55            95.0
# 56            57.0
# 57           236.0
# 58           118.0
# 59           238.0
# 60             0.0
# 61             6.0
# 62            68.0
# 63            18.0
# 64         26634.0
# 65           137.0
# 66            56.0
# 67           150.0
# 68            36.0
# 69             8.0
# 70             4.0
# 71         86224.0
# 72            60.0
# 73           286.0
# 74           345.0
# 75           125.0
# 76             0.0
# 77             0.0
# 78             NaN
# 79            36.0
# 80          2261.0
# 81            11.0
# 82             5.0
# 83            59.0
# 84            73.0
# 85            19.0
# 86           203.0
# 87            53.0
# 88            40.0
# 89             0.0
# 90            21.0
# 91           596.0
# 92           256.0
# 93           185.0
# 94            91.0
# 95             5.0
# 96          2375.0
# 97            90.0
# 98           184.0
# 99            14.0
# 100           59.0
# 101           42.0
# 102           51.0
# 103          174.0
# 104           19.0
# 105           21.0
# 106         2266.0
# 107           20.0
# 108           25.0
# 109           33.0
# 110        37076.0
# 111          432.0
# 112           94.0
# 113          100.0
# 114           85.0
# 115           46.0
# 116         4862.0
# 117          229.0
# 118            0.0
# 119            0.0
# 120            NaN
# 121           28.0
# 122           26.0
# 123         2563.0
# 124           52.0
# 125         2059.0
# 126        71871.0
# 127          105.0
# 128           56.0
# 129          362.0
# 130           84.0
# 131           89.0
# 132            7.0
# 133            0.0
# 134          284.0
# 135          177.0
# 136           29.0
# 137            7.0
# 138          257.0
# 139        10873.0
# 140          317.0
# 141           86.0
# 142         4985.0
# 143         1852.0
# 144           58.0
# 145           17.0
# 146           22.0
# 147          108.0
# 148           74.0
# 149        39502.0
# 150           76.0
# 151           54.0
# 152           21.0
# 153           31.0
# 154            5.0
# 155           44.0
# 156           39.0
# 157           66.0
# 158          678.0
# 159          166.0
# 160            0.0
# 161            0.0
# 162            0.0
# 163            NaN
#
# [164 rows x 90 columns]

# %% [markdown]
# ## Functions Dataframe for Phase 5

# %%
phase5 = pd.concat([phase5_name_drop, phase5_functions], axis=1)

phase5
# Out:
#                 Student                                          functions  \
# 0                cap182                                                 []
# 1             nfmorenog  [FirstLook.css, bootstrap.min.css, jquery.min....
# 2            falperezgo  [.ajax, data.cityofchicago.org, rows.json, Z.d...
# 3          lfvalderrama  [up.net, shiv.js, main.css, .css, jquery.min.j...
# 4             xdanielsb  [nconsole.log, jQuery.parseJSON, .ajax, Z.done...
# 5             ykchautai  [tiry.cloudfront.net, foundation.min.css, styl...
# 6                oeroaq  [.css, style.css, bootstrap.css, balloon.css, ...
# 7          Danielsv9207                                                 []
# 8            janoguerab  [js.org, .v, .min.js, z.document.getElementByI...
# 9           nabautistal  [z.document.getElementById, google.maps.Map, g...
# 10           dsbarrerag  [.custom.css, .css, awesome.min.css, jquery.mi...
# 11         Christian7sr  [estilos.css, icon.ico, Etxea.js, z.document.g...
# 12             Chranium  [style.css, main.js, z.document.getElementById...
# 13            srmedinac  [.create, package.json, pkg.title, pkg.version...
# 14         jucjimenezmo  [home.css, search.css, navicon.jpg, .js, js.or...
# 15          kgbayala528  [latest.min.js, jquery.min.js, bootstrap.min.c...
# 16            wolfstain  [up.net, main.css, .css, noscript.css, chicago...
# 17       DianaNavarrete  [.l, morado.jpg, a.active, a.active, google.ma...
# 18            bsgarciac  [document.getElementsByClassName, dx.length, B...
# 19          jiapulidoar  [t.module.exports, grunt.option, grunt.initCon...
# 20           ronaldsg20  [ownStyle.css, theme.min.css, bootstrap.min.cs...
# 21            bdcajicam  [nearium.css, .js, nearium.js, google.maps.Map...
# 22       andfsanchezlem                                                 []
# 23               li2266                                                 []
# 24          JulianaNino  [bootstrap.min.css, .navbar, Respond.js, shiv....
# 25           jonatan360  [awesome.min.css, bootstrap.min.css, style.css...
# 26            camilo654  [bootstrap.min.css, .js, js.js, .ready, k.clic...
# 27         stevenbustos  [style.css, jquery.min.js, distanceFunc.js, ge...
# 28         jscontrerasp  [latest.min.js, google.maps.LatLng, google.map...
# 29           gsuarezc04  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 30           jmalvarezd  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 31           katherinsb  [reset.css, layout.css, style.css, jquery.min....
# 32               annipi                                                 []
# 33            fmbernalb                                                 []
# 34           mballeng91  [.bin, e.g, protractor.conf.js, exports.config...
# 35      jscastelblancoh  [bootstrap.min.css, theme.min.css, style.css, ...
# 36             capinzor  [bootstrap.min.css, estilos.css, .min.js, boot...
# 37            jdsuarezj  [google.maps.Map, z.document.getElementById, g...
# 38       jufcontrerasco  [body.css, favicon.ico, js.org, .v, .min.js, p...
# 39           NicolasZon  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 40                 tres                                                 []
# 41          hsmartineza  [jquery.min.js, .js, maps.js, house.js, weathe...
# 42          dfhincapiem  [main.js, google.maps.Map, z.document.getEleme...
# 43            gasierram  [illinois.edu, favicon.ico, bootstrap.min.css,...
# 44           JuanitoAli  [bootstrap.css, .js, Bootstrap.js, logic.js, u...
# 45            fabianr23  [estilos.css, funciones.js, jquery.min.js, .v,...
# 46         leavendanoro  [chicagoicon.ico, style.css, jquery.min.js, js...
# 47              ccvacad  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 48             jcneivaa                                                 []
# 49            yocuervoc                                                 []
# 50           JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....
# 51          CSebasGomez                                                 []
# 52          juandavidro  [style.css, scripto.js, bootstrap.min.css, sit...
# 53            jdsolanos                                                 []
# 54          afceballosr  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 55                DglyP  [bootstrap.min.css, style.css, jquery.min.js, ...
# 56         jjrodriguezn  [google.maps.Map, z.document.getElementById, g...
# 57          CamiloRueda  [layout.css, shiv.js, z.document.getElementByI...
# 58             oserasoa  [bootstrap.min.css, theme.min.css, jquery.min....
# 59           joaortizro  [z.document.getElementById, google.maps.Map, b...
# 60             davidh17  [bootstrap.min.css, style.css, jquery.min.js, ...
# 61         JairVillalba  [fH.css, jquery.min.js, .js, call.js, climate....
# 62           davidrh195  [navicon.jpg, style.css, z.document.getElement...
# 63           juclopezso  [bootstrap.min.css, portfolio.css, awesome.min...
# 64         raulramirezp  [up.net, main.css, bootstrap.min.css, jquery.m...
# 65          camilo13152  [mapController.js, favicon.ico, fluidbox.min.c...
# 66           kmendezp96  [js.org, .v, .min.js, bar.css, StyleSheet.css,...
# 67           miaborjaac  [bootstrap.min.css, modifier.css, jquery.min.j...
# 68             dduartec  [.js, style.css, superplaceholder.js, superpla...
# 69           crarojasca                                                 []
# 70       UNhcrodriguezl  [demos.css, bootstrap.min.css, select.min.css,...
# 71            pipemax85  [bootstrap.min.css, theme.min.css, jquery.min....
# 72        ivdgonzalezco  [favicon.ico, bootstrap.min.css, awesome.css, ...
# 73       jesusfchavarro  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...
# 74         wilson911013  [.js, jsInitMap.js, .ajax, t.module.exports, o...
# 75   JhonEmmanuelTorres                                                 []
# 76            jjmuesesq  [z.document.getElementById, google.maps.Map, g...
# 77         adamantwharf  [z.document.getElementById, google.maps.Map, g...
# 78           NicolasPrr  [jquery.min.js, bootstrap.min.css, stylesLogin...
# 79             luegilca  [bootstrap.min.css, .js, js.org, .v, .min.js, ...
# 80            macuestap  [style.css, favicon.ico, bootstrap.min.css, th...
# 81            lemartinp  [google.maps.Map, z.document.getElementById, g...
# 82          dagofonseca  [style.css, jquery.min.js, maps.js, markerclus...
# 83            jsviveroj  [.css, bootstrap.min.css, freelancer.min.js, s...
# 84         luealfonsoru  [bootstrap.min.css, balloon.min.css, freelance...
# 85            afforeroc  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...
# 86            djguzmanc  [google.maps.LatLng, google.maps.Map, z.docume...
# 87            uxjudges2                                                 []
# 88           cdcordobaa  [bootstrap.min.css, main.css, .org, .js, maps....
# 89              gcantem                                                 []
# 90           feartheGru                                                 []
# 91           lgmoralesa  [bootstrap.min.css, index.css, criteria.css, j...
# 92       CristianLozano  [z.document.getElementById, google.maps.Map, g...
# 93             mdbelloc  [jquery.min.js, bootstrap.min.css, tutorial.cs...
# 94               Yelis3  [map.css, google.maps.Map, z.document.getEleme...
# 95       joahernandezca  [z.document.getElementById, google.maps.Map, g...
# 96          anfmorenoso  [bootstrap.min.css, estilos.css, scripto.js, f...
# 97        jumcorredorro  [jquery.min.js, bootstrap.min.css, .js, script...
# 98            begarzonf  [reset.css, layout.css, style.css, jquery.fanc...
# 99               spenas  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 100           smarquezo  [bootstrap.min.css, data.json, jquery.min.js, ...
# 101              gabi04  [google.maps.LatLng, google.maps.mapTypeId.ROA...
# 102        maikellPardo                                                 []
# 103          jmhurtadoc  [.controls, .pac, searchBox.js, bootstrap.min....
# 104        jusherrerama  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 105          fevargasmo  [this.valueOf, this.name, window.location.relo...
# 106            aldiazve  [bootstrap.min.css, main.css, data.cityofchica...
# 107            lsfinite  [.css, awesome.min.css, latest.min.js, room.js...
# 108           jorge52an  [main.css, material.min.js, angular.min.js, an...
# 109          daandradec  [style.css, bootstrap.min.css, jquery.min.js, ...
# 110          jsnarvaezb  [bootstrap.min.css, jquery.min.js, style.css, ...
# 111          capinillab  [z.document.getElementById, google.maps.Map, g...
# 112         djsanabriac  [bootstrap.min.css, main.js, jquery.min.js, z....
# 113      cesarochoa2006  [.getFullYear, nconsole.log, r.main, O.hide, ....
# 114     juasmartinezbel  [bootstrap.min.css, jquery.min.js, .js, js.org...
# 115          debeltranc  [runner.github.io, t.module.exports, config.se...
# 116            adriel62  [favicon.ico, .min.js, bootstrap.min.css, appl...
# 117      diegoaguevarar  [style.css, blocks.css, bootstrap.min.css, the...
# 118           ligibrial  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 119           juanescai                                                 []
# 120            jcrubioa  [bootstrap.min.css, awesome.min.css, animate.c...
# 121          Phoenixest  [a.active, a.active, z.document.getElementById...
# 122           juligarji  [jquery.min.js, bootstrap.min.css, awesome.min...
# 123              kancas  [style.css, bootstrap.min.css, theme.min.css, ...
# 124             ItsNavi                                                 []
# 125            leguzman  [today.getDate, today.getMonth, today.getFullY...
# 126          jmcuestasb  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 127           sacastroc  [bootstrap.min.css, theme.min.css, jquery.min....
# 128          jhonsd1996  [style.css, .Chicago, z.document.getElementByI...
# 129           jdmonroyg  [.mifecha, bootstrap.min.css, theme.min.css, j...
# 130             Zeugmax                                                 []
# 131             MogGy94                                                 []
# 132              sagilm  [data.cityofchicago.org, rows.json, pxmlhttp.o...
# 133             sarizag  [js.org, .v, .min.js, style.css, jquery.min.js...
# 134          dasalgadob  [bootstrap.min.css, theme.min.css, jquery.min....
# 135             Gantiva  [latest.min.js, jquery.min.js, foo.js, opcione...
# 136            idrojasf  [components.css, responsee.css, owl.carousel.j...
# 137            Moimolcp  [bootstrap.min.css, style.css, scripto.js, dat...
# 138          anmmunozme  [.ajax, data.cityofchicago.org, iimk.json, Z.d...
# 139          jhriverasa  [style.css, bootstrap.min.css, .min.css, googl...
# 140           fffeelipe  [.ready, k.click, .css, w.removeClass, .is, .v...
# 141       gfalbarracinr  [bootstrap.min.css, main.css, .jpg, jane.doe, ...
# 142       cccristanchoc  [unal.edu.co, bootstrap.min.css, template.css,...
# 143           pcberriop  [Mapa.js, .js, main.css, avatar.jpg, pcberriop...
# 144          ncampuzano  [bootstrap.min.css, awesome.min.css, app.css, ...
# 145           helmeraac  [style.css, jquery.min.js, integration.js, scr...
# 146            ofnanezn  [.create, package.json, pkg.title, pkg.version...
# 147           odprietoh                                                 []
# 148       maikellPardoA  [z.document.getElementById, google.maps.Map, g...
# 149       wapiravaguens  [.css, .js, js.org, .v, bootstrap.min.css, the...
# 150          Dandarprox  [Bootstrap.js, bootstrap.css, style.css, table...
# 151            HashNick  [jquery.min.js, bootstrap.min.css, .js, js.org...
# 152         diegocruz10  [bootstrap.min.css, awesome.min.css, theme.min...
# 153          Davsatu313  [Style.css, .min.js, js.org, .v, maps.js, clim...
# 154         lacardenasv  [materialize.css, materialize.min.css, styleSe...
# 155             bdvegat  [js.org, .v, .js, bootstrap.min.css, bootstrap...
# 156           lizzyt10h  [bootstrap.min.css, jquery.min.js, .min.css, t...
# 157             DavidQP  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 158         Judgarciani  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159         oacastillol  [bootstrap.min.css, theme.min.css, awesome.min...
# 160           mnguzmanc  [house.ico, style.css, .css, main.js, maps.js,...
# 161         Semoralesga  [style.css, bootstrap.min.css, .js, scripto.js...
# 162         jhcardenasa                                                 []
# 163              crigar  [z.document.getElementById, google.maps.Map, g...
# 164           AFelipeGA  [materialize.min.css, style.css, awesome.min.c...
#
#                                                 unique  len_unique  \
# 0                                                   []           0
# 1    [FirstLook.css, bootstrap.min.css, jquery.min....          51
# 2    [.ajax, data.cityofchicago.org, rows.json, Z.d...        1865
# 3    [up.net, shiv.js, main.css, .css, jquery.min.j...          62
# 4    [nconsole.log, jQuery.parseJSON, .ajax, Z.done...         440
# 5    [tiry.cloudfront.net, foundation.min.css, styl...          42
# 6    [.css, style.css, bootstrap.css, balloon.css, ...        2101
# 7                                                   []           0
# 8    [js.org, .v, .min.js, z.document.getElementByI...          36
# 9    [z.document.getElementById, google.maps.Map, g...          51
# 10   [.custom.css, .css, awesome.min.css, jquery.mi...          69
# 11   [estilos.css, icon.ico, Etxea.js, z.document.g...          25
# 12   [style.css, main.js, z.document.getElementById...           5
# 13   [.create, package.json, pkg.title, pkg.version...          55
# 14   [home.css, search.css, navicon.jpg, .js, js.or...          64
# 15   [latest.min.js, jquery.min.js, bootstrap.min.c...         108
# 16   [up.net, main.css, .css, noscript.css, chicago...         228
# 17   [.l, morado.jpg, a.active, google.maps.Map, z....           6
# 18   [document.getElementsByClassName, dx.length, B...         128
# 19   [t.module.exports, grunt.option, grunt.initCon...       71456
# 20   [ownStyle.css, theme.min.css, bootstrap.min.cs...       34477
# 21   [nearium.css, .js, nearium.js, google.maps.Map...          36
# 22                                                  []           0
# 23                                                  []           0
# 24   [bootstrap.min.css, .navbar, Respond.js, shiv....          23
# 25   [awesome.min.css, bootstrap.min.css, style.css...         144
# 26   [bootstrap.min.css, .js, js.js, .ready, k.clic...          30
# 27   [style.css, jquery.min.js, distanceFunc.js, ge...          31
# 28   [latest.min.js, google.maps.LatLng, google.map...          27
# 29   [google.maps.LatLng, google.maps.mapTypeId.ROA...          41
# 30   [jmalvarezd.js, bootstrap.min.css, jquery.min....          52
# 31   [reset.css, layout.css, style.css, jquery.min....        2043
# 32                                                  []           0
# 33                                                  []           0
# 34   [.bin, e.g, protractor.conf.js, exports.config...       60922
# 35   [bootstrap.min.css, theme.min.css, style.css, ...         178
# 36   [bootstrap.min.css, estilos.css, .min.js, just...        1666
# 37   [google.maps.Map, z.document.getElementById, g...          66
# 38   [body.css, favicon.ico, js.org, .v, .min.js, p...          72
# 39   [google.maps.LatLng, google.maps.mapTypeId.ROA...          12
# 40                                                  []           0
# 41   [jquery.min.js, .js, maps.js, house.js, weathe...          65
# 42   [main.js, google.maps.Map, z.document.getEleme...           4
# 43   [illinois.edu, favicon.ico, bootstrap.min.css,...          60
# 44   [bootstrap.css, .js, Bootstrap.js, logic.js, u...        2121
# 45   [estilos.css, funciones.js, jquery.min.js, .v,...         162
# 46   [chicagoicon.ico, style.css, jquery.min.js, js...          45
# 47   [bootstrap.min.css, jquery.min.js, style.css, ...          85
# 48                                                  []           0
# 49                                                  []           0
# 50   [bootstrap.min.css, theme.min.css, jquery.min....          48
# 51                                                  []           0
# 52   [style.css, scripto.js, bootstrap.min.css, sit...          15
# 53                                                  []           0
# 54   [bootstrap.min.css, style.css, bulk.jpg, jquer...          36
# 55   [bootstrap.min.css, style.css, jquery.min.js, ...        1780
# 56   [google.maps.Map, z.document.getElementById, g...          31
# 57   [layout.css, shiv.js, z.document.getElementByI...          46
# 58   [bootstrap.min.css, theme.min.css, jquery.min....          53
# 59   [z.document.getElementById, google.maps.Map, b...          18
# 60   [bootstrap.min.css, style.css, jquery.min.js, ...          87
# 61   [fH.css, jquery.min.js, .js, call.js, climate....          60
# 62   [navicon.jpg, style.css, z.document.getElement...          20
# 63   [bootstrap.min.css, portfolio.css, awesome.min...          30
# 64   [up.net, main.css, bootstrap.min.css, jquery.m...         279
# 65   [mapController.js, favicon.ico, fluidbox.min.c...          87
# 66   [js.org, .v, .min.js, bar.css, StyleSheet.css,...        2092
# 67   [bootstrap.min.css, modifier.css, jquery.min.j...         120
# 68   [.js, style.css, superplaceholder.js, maps.js,...        1806
# 69                                                  []           0
# 70   [demos.css, bootstrap.min.css, select.min.css,...          88
# 71   [bootstrap.min.css, theme.min.css, jquery.min....          27
# 72   [favicon.ico, bootstrap.min.css, awesome.css, ...         239
# 73   [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...       17774
# 74   [.js, jsInitMap.js, .ajax, t.module.exports, o...         346
# 75                                                  []           0
# 76   [z.document.getElementById, google.maps.Map, g...          26
# 77   [z.document.getElementById, google.maps.Map, g...           3
# 78   [jquery.min.js, bootstrap.min.css, stylesLogin...         128
# 79   [bootstrap.min.css, .js, js.org, .v, .min.js, ...          32
# 80   [style.css, favicon.ico, bootstrap.min.css, th...          16
# 81   [google.maps.Map, z.document.getElementById, g...          25
# 82   [style.css, jquery.min.js, maps.js, markerclus...         253
# 83   [.css, bootstrap.min.css, freelancer.min.js, s...          61
# 84   [bootstrap.min.css, balloon.min.css, freelance...          84
# 85   [bootstrap.min.css, uic.edu, .js, z.document.g...           6
# 86   [google.maps.LatLng, google.maps.Map, z.docume...          64
# 87                                                  []           0
# 88   [bootstrap.min.css, main.css, .org, .js, maps....          32
# 89                                                  []           0
# 90                                                  []           0
# 91   [bootstrap.min.css, index.css, criteria.css, j...          74
# 92   [z.document.getElementById, google.maps.Map, g...           7
# 93   [jquery.min.js, bootstrap.min.css, tutorial.cs...          53
# 94   [map.css, google.maps.Map, z.document.getEleme...       10341
# 95   [z.document.getElementById, google.maps.Map, g...         120
# 96   [bootstrap.min.css, estilos.css, scripto.js, f...          75
# 97   [jquery.min.js, bootstrap.min.css, .js, script...         165
# 98   [reset.css, layout.css, style.css, jquery.fanc...         424
# 99   [bootstrap.min.css, mdb.min.css, demos.css, st...          22
# 100  [bootstrap.min.css, data.json, jquery.min.js, ...          61
# 101  [google.maps.LatLng, google.maps.mapTypeId.ROA...          79
# 102                                                 []           0
# 103  [.controls, .pac, searchBox.js, bootstrap.min....         145
# 104  [js.org, .v, .min.js, bootstrap.min.css, portf...        2014
# 105  [this.valueOf, this.name, window.location.relo...          57
# 106  [bootstrap.min.css, main.css, data.cityofchica...       28497
# 107  [.css, awesome.min.css, latest.min.js, room.js...        4541
# 108  [main.css, material.min.js, angular.min.js, an...         298
# 109  [style.css, bootstrap.min.css, jquery.min.js, ...         279
# 110  [bootstrap.min.css, jquery.min.js, style.css, ...          68
# 111  [z.document.getElementById, google.maps.Map, g...          44
# 112  [bootstrap.min.css, main.js, jquery.min.js, z....          32
# 113  [.getFullYear, nconsole.log, r.main, O.hide, ....         182
# 114  [bootstrap.min.css, jquery.min.js, .js, js.org...         194
# 115  [runner.github.io, t.module.exports, config.se...          44
# 116  [favicon.ico, .min.js, bootstrap.min.css, appl...         149
# 117  [style.css, blocks.css, bootstrap.min.css, the...         115
# 118  [bootstrap.min.css, jquery.min.js, .js, .css, ...        3480
# 119                                                 []           0
# 120  [bootstrap.min.css, awesome.min.css, animate.c...         335
# 121  [a.active, z.document.getElementById, google.m...           4
# 122  [jquery.min.js, bootstrap.min.css, awesome.min...        2295
# 123  [style.css, bootstrap.min.css, theme.min.css, ...          41
# 124                                                 []           0
# 125  [today.getDate, today.getMonth, today.getFullY...         123
# 126  [js.org, .v, .min.js, weather.js, mycss.css, b...        6404
# 127  [bootstrap.min.css, theme.min.css, jquery.min....          78
# 128  [style.css, .Chicago, z.document.getElementByI...           5
# 129  [.mifecha, bootstrap.min.css, theme.min.css, j...          13
# 130                                                 []           0
# 131                                                 []           0
# 132  [data.cityofchicago.org, rows.json, pxmlhttp.o...          36
# 133  [js.org, .v, .min.js, style.css, jquery.min.js...          39
# 134  [bootstrap.min.css, theme.min.css, jquery.min....           8
# 135  [latest.min.js, jquery.min.js, foo.js, opcione...          50
# 136  [components.css, responsee.css, owl.carousel.j...         564
# 137  [bootstrap.min.css, style.css, scripto.js, dat...          83
# 138  [.ajax, data.cityofchicago.org, iimk.json, Z.d...        1766
# 139  [style.css, bootstrap.min.css, .min.css, googl...          83
# 140  [.ready, k.click, .css, w.removeClass, .is, .v...         112
# 141  [bootstrap.min.css, main.css, .jpg, jane.doe, ...          37
# 142  [unal.edu.co, bootstrap.min.css, template.css,...          97
# 143  [Mapa.js, .js, main.css, avatar.jpg, pcberriop...          89
# 144  [bootstrap.min.css, awesome.min.css, app.css, ...         140
# 145  [style.css, jquery.min.js, integration.js, scr...          34
# 146  [.create, package.json, pkg.title, pkg.version...          57
# 147                                                 []           0
# 148  [z.document.getElementById, google.maps.Map, g...           4
# 149  [.css, .js, js.org, .v, bootstrap.min.css, the...          77
# 150  [Bootstrap.js, bootstrap.css, style.css, table...         171
# 151  [jquery.min.js, bootstrap.min.css, .js, js.org...          59
# 152  [bootstrap.min.css, awesome.min.css, theme.min...          39
# 153  [Style.css, .min.js, js.org, .v, maps.js, clim...          76
# 154  [materialize.css, materialize.min.css, styleSe...        9513
# 155  [js.org, .v, .js, bootstrap.min.css, cs.css, f...          10
# 156  [bootstrap.min.css, jquery.min.js, .min.css, t...          71
# 157  [bootstrap.min.css, Respond.js, shiv.min.js, r...          56
# 158  [bootstrap.min.css, jquery.min.js, js.org, .v,...         199
# 159  [bootstrap.min.css, theme.min.css, awesome.min...         293
# 160  [house.ico, style.css, .css, main.js, maps.js,...        1766
# 161  [style.css, bootstrap.min.css, .js, scripto.js...          21
# 162                                                 []           0
# 163  [z.document.getElementById, google.maps.Map, g...           4
# 164  [materialize.min.css, style.css, awesome.min.c...        1907
#
#      len_functions
# 0                0
# 1               52
# 2             2009
# 3               62
# 4              463
# 5               42
# 6             2677
# 7                0
# 8               36
# 9               51
# 10              71
# 11              25
# 12               5
# 13              56
# 14              64
# 15             108
# 16             236
# 17               7
# 18             131
# 19           86241
# 20           39470
# 21              36
# 22               0
# 23               0
# 24              25
# 25             146
# 26              30
# 27              31
# 28              28
# 29              41
# 30              53
# 31            2290
# 32               0
# 33               0
# 34           71871
# 35             181
# 36            1846
# 37              66
# 38              95
# 39              12
# 40               0
# 41              66
# 42               4
# 43              61
# 44            2375
# 45             175
# 46              46
# 47              88
# 48               0
# 49               0
# 50              49
# 51               0
# 52              15
# 53               0
# 54              42
# 55            2312
# 56              31
# 57              47
# 58              54
# 59              19
# 60              88
# 61              60
# 62              20
# 63              30
# 64             293
# 65              87
# 66            2339
# 67             123
# 68            2338
# 69               0
# 70              89
# 71              28
# 72             252
# 73           28443
# 74             362
# 75               0
# 76              27
# 77               3
# 78             133
# 79              33
# 80              17
# 81              26
# 82             271
# 83              64
# 84              85
# 85               7
# 86              65
# 87               0
# 88              32
# 89               0
# 90               0
# 91              77
# 92               7
# 93              53
# 94           11771
# 95             125
# 96              76
# 97             181
# 98             432
# 99              22
# 100             64
# 101             79
# 102              0
# 103            150
# 104           2261
# 105             57
# 106          33042
# 107           4862
# 108            318
# 109            286
# 110             68
# 111             45
# 112             32
# 113            186
# 114            203
# 115             44
# 116            161
# 117            120
# 118           4169
# 119              0
# 120            345
# 121              5
# 122           2567
# 123             42
# 124              0
# 125            127
# 126           7051
# 127             80
# 128              5
# 129             14
# 130              0
# 131              0
# 132             36
# 133             40
# 134              9
# 135             51
# 136            596
# 137             90
# 138           2297
# 139             86
# 140            116
# 141             37
# 142            100
# 143             90
# 144            146
# 145             34
# 146             58
# 147              0
# 148              4
# 149             89
# 150            174
# 151             59
# 152             40
# 153             76
# 154          10885
# 155             11
# 156             75
# 157             57
# 158            210
# 159            316
# 160           2297
# 161             21
# 162              0
# 163              4
# 164           2059

# %% [markdown]
# ### phase 5 functions dataframe merge with overall dataframe to know the groups.

# %%
overall_phase5 = overall_loc_scores.merge(phase5[['Student','functions', 'unique', 'len_unique', 'len_functions']], on='Student', how='left')
overall_phase5
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# 5                 DglyP    0.0                     20.0           25.00
# 6                cap182    0.0                     20.0           29.17
# 7           annumumozme    0.0                     40.0           37.50
# 8           Judgarciani    0.0                    100.0           58.33
# 9             sacastroc    0.0                     20.0           50.00
# 10            pcberriop    0.0                     20.0           37.50
# 11          hsmartineza    0.0                     20.0           33.33
# 12             Moimolcp    0.0                    100.0           62.50
# 13          CamiloRueda    0.0                      0.0           29.17
# 14            juanescai    0.0                      0.0           25.00
# 15           JoseMolano    0.0                     60.0           66.67
# 16        maikellPardoA    0.0                      0.0           37.50
# 17           NicolasZon    0.0                      0.0           25.00
# 18            camilo654    0.0                     20.0           29.17
# 19       CristianLozano    0.0                     20.0           33.33
# 20            jdsuarezj    0.0                     60.0           50.00
# 21            pipemax85    0.0                     20.0           33.33
# 22          juandavidro    0.0                     20.0           58.33
# 23       UNhcrodriguezl    0.0                     80.0           33.33
# 24          camilo13152    0.0                     60.0           50.00
# 25         leavendanoro    0.0                     40.0           66.67
# 26           cdcordobaa    0.0                     20.0           33.33
# 27           capinillab    0.0                     60.0           54.17
# 28           janoguerab    0.0                     20.0           29.17
# 29         lfvalderrama    0.0                     80.0           66.67
# 30            bsgarciac    0.0                    100.0           70.83
# 31               gabi04    0.0                     20.0           29.17
# 32               annipi    0.0                      0.0            0.00
# 33            jdsolanos    0.0                      0.0            0.00
# 34             jcneivaa    0.0                      0.0            0.00
# 35            fmbernalb    0.0                      0.0            0.00
# 36              MogGy94    0.0                      0.0            0.00
# 37            yocuervoc    0.0                      0.0            0.00
# 38            odprietoh    0.0                      0.0            0.00
# 39            gasierram    1.0                     40.0           62.50
# 40         adamantwharf    1.0                     20.0           25.00
# 41            bdcajicam    1.0                     40.0           29.17
# 42       andfsanchezlem    1.0                     20.0           25.00
# 43          dfhincapiem    1.0                     20.0           25.00
# 44            helmeraac    1.0                      0.0           25.00
# 45           dasalgadob    1.0                      0.0           25.00
# 46           falperezgo    1.0                     20.0           45.83
# 47            djguzmanc    1.0                     80.0           79.17
# 48           gsuarezc04    1.0                      0.0           25.00
# 49               oeroaq    1.0                    100.0           87.50
# 50              gcantem    1.0                    100.0           70.83
# 51          Semoralesga    1.0                     20.0           33.33
# 52           jonatan360    1.0                    100.0           75.00
# 53       jesusfchavarro    1.0                    100.0           62.50
# 54         stevenbustos    1.0                     20.0           33.33
# 55       jufcontrerasco    1.0                     60.0           79.17
# 56           dsbarrerag    1.0                     80.0           70.83
# 57            wolfstain    1.0                     20.0           33.33
# 103           37.50        275.83        100.0         75.0
# 104           25.00        125.00         75.0         50.0
# 105           75.00        211.67         75.0         75.0
# 106           25.00        145.83         87.5         62.5
# 107            0.00         95.00         50.0         62.5
# 108           75.00        224.17         87.5         75.0
# 109            0.00        100.00         62.5         62.5
# 110           62.50        309.17        100.0         87.5
# 111           75.00        227.50         87.5         75.0
# 112           65.63        304.79        100.0         62.5
# 113          100.00        339.17        100.0        100.0
# 114           25.00        158.33         87.5         87.5
# 115           33.33        154.17         87.5         37.5
# 116           12.50        125.00         87.5          0.0
# 117           70.00        357.50        100.0         50.0
# 118            0.00          0.00          0.0          0.0
# 119            0.00          0.00          0.0          0.0
# 120            0.00          0.00          0.0          0.0
# 121            0.00          0.00          0.0          0.0
# 122           87.50        329.17         87.5         87.5
# 123           92.50        355.00         87.5        100.0
# 124           15.00        127.50         75.0         75.0
# 125           56.25        221.25         87.5         75.0
# 126           25.00        112.50         62.5         62.5
# 127           95.00        345.83         87.5         87.5
# 128            0.00        128.33         75.0         62.5
# 129            0.00         75.00         50.0         37.5
# 130           72.50        327.50        100.0         62.5
# 131           56.25        209.58         87.5         75.0
# 132           25.00        145.00         37.5         37.5
# 133           25.00         75.00         25.0          0.0
# 134           60.00        310.00        100.0         75.0
# 135          100.00        358.33         75.0         75.0
# 136           81.25        278.75         87.5         62.5
# 137           50.00        161.67         62.5         50.0
# 138           66.67        231.67         87.5         87.5
# 139           75.00        350.00        100.0         87.5
# 140           37.50        235.00         75.0         62.5
# 141           50.00        203.33         87.5         62.5
# 142           67.50        301.67         87.5         87.5
# 143           58.33        203.33        100.0         87.5
# 144           25.00        198.33         75.0         50.0
# 145           25.00        177.50         62.5         62.5
# 146            0.00        115.83         62.5         62.5
# 147           81.25        298.75         87.5         62.5
# 148           87.50        345.83         87.5         87.5
# 149           12.50        178.33        100.0        100.0
# 150           56.25        197.08         87.5         62.5
# 151           93.75        348.75        100.0         87.5
# 152           57.50        185.83         75.0         62.5
# 153           56.25        209.58        100.0         75.0
# 154            0.00         95.00         50.0         50.0
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
# 160            0.00          0.00          0.0          0.0
# 161            0.00          0.00          0.0          0.0
# 162            0.00          0.00          0.0          0.0
# 163             NaN           NaN          NaN          NaN
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...              104.0
# 5                        0.0           25.00  ...               21.5
# 6                       20.0           29.17  ...              -39.5
# 7                        0.0            0.00  ...                NaN
# 8                       80.0           87.50  ...              -19.5
# 9                       20.0           50.00  ...                0.0
# 10                      20.0           33.33  ...                2.5
# 11                      20.0           37.50  ...               -1.5
# 12                       0.0           33.33  ...                0.0
# 13                      20.0           25.00  ...                0.0
# 14                       0.0           25.00  ...                0.0
# 15                       0.0           58.33  ...              -20.5
# 16                       0.0            0.00  ...                0.0
# 17                       0.0           25.00  ...               -0.5
# 18                      60.0           33.33  ...                0.0
# 19                      60.0           50.00  ...                0.0
# 20                      60.0           66.67  ...              -48.0
# 21                      20.0           33.33  ...                2.0
# 22                      20.0           54.17  ...               66.0
# 23                      20.0           41.67  ...                0.0
# 24                      60.0           45.83  ...                0.0
# 25                       0.0           25.00  ...              -19.0
# 26                      20.0           33.33  ...                0.0
# 27                      60.0           54.17  ...                0.0
# 28                      20.0           29.17  ...                0.0
# 29                      20.0           50.00  ...               -2.0
# 30                      80.0           70.83  ...                9.5
# 31                      20.0           29.17  ...               -3.0
# 32                       0.0            0.00  ...                0.0
# 33                       0.0            0.00  ...               -7.5
# 34                       0.0            0.00  ...               -1.0
# 35                       0.0            0.00  ...                0.0
# 36                       0.0            0.00  ...                0.0
# 37                       0.0            0.00  ...                0.0
# 38                       0.0            0.00  ...                0.0
# 39                      40.0           58.33  ...                1.5
# 40                      20.0           25.00  ...                0.0
# 41                      20.0           29.17  ...                0.0
# 42                      20.0           25.00  ...                0.0
# 43                      20.0           50.00  ...                0.0
# 44                      20.0           29.17  ...                0.5
# 45                     100.0           75.00  ...                0.0
# 46                      40.0           62.50  ...             -124.0
# 47                      60.0           79.17  ...                0.0
# 48                       0.0           25.00  ...                0.0
# 49                     100.0           79.17  ...               10.5
# 50                      60.0           29.17  ...                1.5
# 51                      20.0           33.33  ...                0.0
# 52                      60.0           83.33  ...                8.0
# 53                     100.0           70.83  ...               -8.5
# 54                      20.0           33.33  ...              156.0
# 55                      20.0           41.67  ...                0.0
# 56                      60.0           62.50  ...               43.0
# 57                      20.0           33.33  ...                0.0
# 58                      80.0           66.67  ...              -11.0
# 59                      40.0           50.00  ...               -0.5
# 60                       0.0           25.00  ...                0.0
# 61                      20.0           29.17  ...                2.5
# 62                      40.0           54.17  ...                0.0
# 63                       0.0            0.00  ...               -1.0
# 64                      60.0           54.17  ...              -27.5
# 65                     100.0           75.00  ...                0.0
# 66                      40.0           58.33  ...               22.5
# 67                       0.0           29.17  ...                0.0
# 68                      20.0           33.33  ...               19.5
# 69                      20.0           33.33  ...                2.0
# 70                      20.0           25.00  ...                0.0
# 71                      40.0           62.50  ...              -14.5
# 72                      60.0           58.33  ...              -10.0
# 73                     100.0           75.00  ...                0.0
# 74                      20.0           45.83  ...                0.0
# 75                      20.0           37.50  ...                0.0
# 76                       0.0            0.00  ...                0.0
# 77                       0.0            0.00  ...                0.0
# 78                       0.0            0.00  ...                NaN
# 79                       0.0            0.00  ...              -46.5
# 80                      20.0           25.00  ...                0.0
# 81                      20.0           25.00  ...                0.0
# 82                      20.0           25.00  ...                0.0
# 83                      40.0           54.17  ...                0.5
# 84                       0.0            0.00  ...              -17.5
# 85                      80.0           50.00  ...                NaN
# 86                     100.0           58.33  ...               -1.0
# 87                       0.0           29.17  ...                0.0
# 88                      40.0           29.17  ...               -1.0
# 89                      20.0           25.00  ...                0.0
# 90                       0.0           37.50  ...               -3.5
# 21                 2.0                0.0
# 22               274.5              283.0
# 23                 0.0                0.0
# 24                 0.0                0.0
# 25                -2.0               38.5
# 26               -17.5               -8.0
# 27               -75.0              -22.5
# 28                 NaN                0.0
# 29                 2.5                1.5
# 30                 0.0               10.0
# 31                 0.0              -23.5
# 32                 0.0               26.0
# 33                 0.0               16.0
# 34                 0.0                0.0
# 35                 0.0                0.0
# 36                 0.0                0.0
# 37                 0.0                0.0
# 38                 0.0                0.0
# 39               -23.0               -5.5
# 40                 0.0               43.5
# 41                26.0                0.0
# 42               -21.0               16.5
# 43                 0.0              -18.5
# 44                 1.0               -9.5
# 45                 0.0               43.0
# 46                35.5                0.0
# 47              -404.0                0.0
# 48                 0.0                6.5
# 49              -121.0              -33.0
# 50                -6.5               21.0
# 51               -25.0              -16.5
# 52               -15.0               -2.0
# 53                -7.0                0.0
# 54               -34.0               76.5
# 55                 2.0               -5.5
# 56                49.5               31.5
# 57              -183.5             -134.5
# 58                19.5               10.0
# 59                -1.5              -70.5
# ...
# 148  [bootstrap.min.css, index.css, criteria.css, j...
# 149  [ownStyle.css, theme.min.css, bootstrap.min.cs...
# 150  [unal.edu.co, bootstrap.min.css, template.css,...
# 151  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 152  [bootstrap.min.css, data.json, jquery.min.js, ...
# 153  [js.org, .v, .min.js, style.css, jquery.min.js...
# 154  [style.css, main.js, z.document.getElementById...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 157  [bootstrap.min.css, jquery.min.js, .min.css, t...
# 158  [jquery.min.js, bootstrap.min.css, stylesLogin...
# 159  [jquery.min.js, bootstrap.min.css, .js, script...
# 160                                                 []
# 161                                                 []
# 162                                                 []
# 163                                                NaN
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, .css, w.removeClass, .is, .v...       112.0
# 1    [house.ico, style.css, .css, main.js, maps.js,...      1766.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      6404.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2043.0
# 4    [google.maps.Map, z.document.getElementById, g...        31.0
# 5    [bootstrap.min.css, style.css, jquery.min.js, ...      1780.0
# 6                                                   []         0.0
# 7                                                  NaN         NaN
# 8    [bootstrap.min.css, jquery.min.js, js.org, .v,...       199.0
# 9    [bootstrap.min.css, theme.min.css, jquery.min....        78.0
# 10   [Mapa.js, .js, main.css, avatar.jpg, pcberriop...        89.0
# 11   [jquery.min.js, .js, maps.js, house.js, weathe...        65.0
# 12   [bootstrap.min.css, style.css, scripto.js, dat...        83.0
# 13   [layout.css, shiv.js, z.document.getElementByI...        46.0
# 14                                                  []         0.0
# 15   [bootstrap.min.css, theme.min.css, jquery.min....        48.0
# 16   [z.document.getElementById, google.maps.Map, g...         4.0
# 17   [google.maps.LatLng, google.maps.mapTypeId.ROA...        12.0
# 18   [bootstrap.min.css, .js, js.js, .ready, k.clic...        30.0
# 19   [z.document.getElementById, google.maps.Map, g...         7.0
# 20   [google.maps.Map, z.document.getElementById, g...        66.0
# 21   [bootstrap.min.css, theme.min.css, jquery.min....        27.0
# 22   [style.css, scripto.js, bootstrap.min.css, sit...        15.0
# 23   [demos.css, bootstrap.min.css, select.min.css,...        88.0
# 24   [mapController.js, favicon.ico, fluidbox.min.c...        87.0
# 25   [chicagoicon.ico, style.css, jquery.min.js, js...        45.0
# 26   [bootstrap.min.css, main.css, .org, .js, maps....        32.0
# 27   [z.document.getElementById, google.maps.Map, g...        44.0
# 28   [js.org, .v, .min.js, z.document.getElementByI...        36.0
# 29   [up.net, shiv.js, main.css, .css, jquery.min.j...        62.0
# 30   [document.getElementsByClassName, dx.length, B...       128.0
# 31   [google.maps.LatLng, google.maps.mapTypeId.ROA...        79.0
# 32                                                  []         0.0
# 33                                                  []         0.0
# 34                                                  []         0.0
# 35                                                  []         0.0
# 36                                                  []         0.0
# 37                                                  []         0.0
# 38                                                  []         0.0
# 39   [illinois.edu, favicon.ico, bootstrap.min.css,...        60.0
# 40   [z.document.getElementById, google.maps.Map, g...         3.0
# 41   [nearium.css, .js, nearium.js, google.maps.Map...        36.0
# 42                                                  []         0.0
# 43   [main.js, google.maps.Map, z.document.getEleme...         4.0
# 44   [style.css, jquery.min.js, integration.js, scr...        34.0
# 45   [bootstrap.min.css, theme.min.css, jquery.min....         8.0
# 46   [.ajax, data.cityofchicago.org, rows.json, Z.d...      1865.0
# 47   [google.maps.LatLng, google.maps.Map, z.docume...        64.0
# 48   [google.maps.LatLng, google.maps.mapTypeId.ROA...        41.0
# 49   [.css, style.css, bootstrap.css, balloon.css, ...      2101.0
# 50                                                  []         0.0
# 51   [style.css, bootstrap.min.css, .js, scripto.js...        21.0
# 52   [awesome.min.css, bootstrap.min.css, style.css...       144.0
# 53   [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...     17774.0
# 54   [style.css, jquery.min.js, distanceFunc.js, ge...        31.0
# 55   [body.css, favicon.ico, js.org, .v, .min.js, p...        72.0
# 56   [.custom.css, .css, awesome.min.css, jquery.mi...        69.0
# 57   [up.net, main.css, .css, noscript.css, chicago...       228.0
# 58   [bootstrap.min.css, modifier.css, jquery.min.j...       120.0
# 59   [favicon.ico, bootstrap.min.css, awesome.css, ...       239.0
# 60                                                  []         0.0
# 61   [estilos.css, icon.ico, Etxea.js, z.document.g...        25.0
# 62   [bootstrap.min.css, jquery.min.js, style.css, ...        68.0
# 63   [bootstrap.min.css, main.css, .jpg, jane.doe, ...        37.0
# 64   [bootstrap.min.css, main.css, data.cityofchica...     28497.0
# 65   [style.css, blocks.css, bootstrap.min.css, the...       115.0
# 66   [this.valueOf, this.name, window.location.relo...        57.0
# 67   [.controls, .pac, searchBox.js, bootstrap.min....       145.0
# 68   [bootstrap.min.css, estilos.css, scripto.js, f...        75.0
# 69   [z.document.getElementById, google.maps.Map, g...        51.0
# 70   [z.document.getElementById, google.maps.Map, g...         4.0
# 71   [t.module.exports, grunt.option, grunt.initCon...     71456.0
# 72   [.css, bootstrap.min.css, freelancer.min.js, s...        61.0
# 73   [style.css, bootstrap.min.css, jquery.min.js, ...       279.0
# 74   [bootstrap.min.css, awesome.min.css, animate.c...       335.0
# 75   [z.document.getElementById, google.maps.Map, g...       120.0
# 76                                                  []         0.0
# 77                                                  []         0.0
# 78                                                 NaN         NaN
# 79   [fH.css, jquery.min.js, .js, call.js, climate....        60.0
# 80   [js.org, .v, .min.js, bootstrap.min.css, portf...      2014.0
# 81   [js.org, .v, .js, bootstrap.min.css, cs.css, f...        10.0
# 82   [a.active, z.document.getElementById, google.m...         4.0
# 83   [jquery.min.js, bootstrap.min.css, .js, js.org...        59.0
# 84   [bootstrap.min.css, jquery.min.js, style.css, ...        85.0
# 85   [z.document.getElementById, google.maps.Map, b...        18.0
# 86   [bootstrap.min.css, jquery.min.js, .js, js.org...       194.0
# 87   [jquery.min.js, bootstrap.min.css, tutorial.cs...        53.0
# 88   [bootstrap.min.css, awesome.min.css, theme.min...        39.0
# 89                                                  []         0.0
# 90   [data.cityofchicago.org, rows.json, pxmlhttp.o...        36.0
# 91   [components.css, responsee.css, owl.carousel.j...       564.0
# 92   [up.net, main.css, bootstrap.min.css, jquery.m...       279.0
# 93   [estilos.css, funciones.js, jquery.min.js, .v,...       162.0
# 94   [style.css, bootstrap.min.css, .min.css, googl...        83.0
# 95   [style.css, .Chicago, z.document.getElementByI...         5.0
# 96   [bootstrap.css, .js, Bootstrap.js, logic.js, u...      2121.0
# 97   [Style.css, .min.js, js.org, .v, maps.js, clim...        76.0
# 98   [.getFullYear, nconsole.log, r.main, O.hide, ....       182.0
# 99   [z.document.getElementById, google.maps.Map, g...        26.0
# 100  [home.css, search.css, navicon.jpg, .js, js.or...        64.0
# 101  [style.css, bootstrap.min.css, theme.min.css, ...        41.0
# 102  [latest.min.js, jquery.min.js, foo.js, opcione...        50.0
# 103  [Bootstrap.js, bootstrap.css, style.css, table...       171.0
# 104  [runner.github.io, t.module.exports, config.se...        44.0
# 105  [tiry.cloudfront.net, foundation.min.css, styl...        42.0
# 106  [bootstrap.min.css, jquery.min.js, .js, .css, ...      3480.0
# 107  [navicon.jpg, style.css, z.document.getElement...        20.0
# 108  [bootstrap.min.css, .navbar, Respond.js, shiv....        23.0
# 109  [bootstrap.min.css, .js, js.org, .v, .min.js, ...        32.0
# 110  [map.css, google.maps.Map, z.document.getEleme...     10341.0
# 111  [reset.css, layout.css, style.css, jquery.fanc...       424.0
# 112  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      2092.0
# 113  [today.getDate, today.getMonth, today.getFullY...       123.0
# 114  [bootstrap.min.css, balloon.min.css, freelance...        84.0
# 115  [bootstrap.min.css, theme.min.css, jquery.min....        53.0
# 116  [.css, awesome.min.css, latest.min.js, room.js...      4541.0
# 117  [nconsole.log, jQuery.parseJSON, .ajax, Z.done...       440.0
# 118                                                 []         0.0
# 119                                                 []         0.0
# 120                                                NaN         NaN
# 121  [latest.min.js, google.maps.LatLng, google.map...        27.0
# 122  [google.maps.Map, z.document.getElementById, g...        25.0
# 123  [jquery.min.js, bootstrap.min.css, awesome.min...      2295.0
# 124  [FirstLook.css, bootstrap.min.css, jquery.min....        51.0
# 125  [materialize.min.css, style.css, awesome.min.c...      1907.0
# 126  [.bin, e.g, protractor.conf.js, exports.config...     60922.0
# 127  [.js, style.css, superplaceholder.js, maps.js,...      1806.0
# 128  [.create, package.json, pkg.title, pkg.version...        55.0
# 129  [.js, jsInitMap.js, .ajax, t.module.exports, o...       346.0
# 130  [.css, .js, js.org, .v, bootstrap.min.css, the...        77.0
# 131  [bootstrap.min.css, style.css, jquery.min.js, ...        87.0
# 132  [.l, morado.jpg, a.active, google.maps.Map, z....         6.0
# 133  [.mifecha, bootstrap.min.css, theme.min.css, j...        13.0
# 134  [main.css, material.min.js, angular.min.js, an...       298.0
# 135  [bootstrap.min.css, theme.min.css, style.css, ...       178.0
# 136  [bootstrap.min.css, portfolio.css, awesome.min...        30.0
# 137  [bootstrap.min.css, uic.edu, .js, z.document.g...         6.0
# 138  [style.css, jquery.min.js, maps.js, markerclus...       253.0
# 139  [materialize.css, materialize.min.css, styleSe...      9513.0
# 140  [bootstrap.min.css, theme.min.css, awesome.min...       293.0
# 141  [bootstrap.min.css, awesome.min.css, app.css, ...       140.0
# 142  [favicon.ico, .min.js, bootstrap.min.css, appl...       149.0
# 143  [bootstrap.min.css, estilos.css, .min.js, just...      1666.0
# 144  [.create, package.json, pkg.title, pkg.version...        57.0
# 145  [style.css, favicon.ico, bootstrap.min.css, th...        16.0
# 146  [bootstrap.min.css, mdb.min.css, demos.css, st...        22.0
# 147  [latest.min.js, jquery.min.js, bootstrap.min.c...       108.0
# 148  [bootstrap.min.css, index.css, criteria.css, j...        74.0
# 149  [ownStyle.css, theme.min.css, bootstrap.min.cs...     34477.0
# 150  [unal.edu.co, bootstrap.min.css, template.css,...        97.0
# 151  [jmalvarezd.js, bootstrap.min.css, jquery.min....        52.0
# 152  [bootstrap.min.css, data.json, jquery.min.js, ...        61.0
# 153  [js.org, .v, .min.js, style.css, jquery.min.js...        39.0
# 154  [style.css, main.js, z.document.getElementById...         5.0
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        56.0
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...        36.0
# 157  [bootstrap.min.css, jquery.min.js, .min.css, t...        71.0
# 158  [jquery.min.js, bootstrap.min.css, stylesLogin...       128.0
# 159  [jquery.min.js, bootstrap.min.css, .js, script...       165.0
# 160                                                 []         0.0
# 161                                                 []         0.0
# 162                                                 []         0.0
# 163                                                NaN         NaN
#
#      len_functions
# 0            116.0
# 1           2297.0
# 2           7051.0
# 3           2290.0
# 4             31.0
# 5           2312.0
# 6              0.0
# 7              NaN
# 8            210.0
# 9             80.0
# 10            90.0
# 11            66.0
# 12            90.0
# 13            47.0
# 14             0.0
# 15            49.0
# 16             4.0
# 17            12.0
# 18            30.0
# 19             7.0
# 20            66.0
# 21            28.0
# 22            15.0
# 23            89.0
# 24            87.0
# 25            46.0
# 26            32.0
# 27            45.0
# 28            36.0
# 29            62.0
# 30           131.0
# 31            79.0
# 32             0.0
# 33             0.0
# 34             0.0
# 35             0.0
# 36             0.0
# 37             0.0
# 38             0.0
# 39            61.0
# 40             3.0
# 41            36.0
# 42             0.0
# 43             4.0
# 44            34.0
# 45             9.0
# 46          2009.0
# 47            65.0
# 48            41.0
# 49          2677.0
# 50             0.0
# 51            21.0
# 52           146.0
# 53         28443.0
# 54            31.0
# 55            95.0
# 56            71.0
# 57           236.0
# 58           123.0
# 59           252.0
# 60             0.0
# 61            25.0
# 62            68.0
# 63            37.0
# 64         33042.0
# 65           120.0
# 66            57.0
# 67           150.0
# 68            76.0
# 69            51.0
# 70             4.0
# 71         86241.0
# 72            64.0
# 73           286.0
# 74           345.0
# 75           125.0
# 76             0.0
# 77             0.0
# 78             NaN
# 79            60.0
# 80          2261.0
# 81            11.0
# 82             5.0
# 83            59.0
# 84            88.0
# 85            19.0
# 86           203.0
# 87            53.0
# 88            40.0
# 89             0.0
# 90            36.0
# 91           596.0
# 92           293.0
# 93           175.0
# 94            86.0
# 95             5.0
# 96          2375.0
# 97            76.0
# 98           186.0
# 99            27.0
# 100           64.0
# 101           42.0
# 102           51.0
# 103          174.0
# 104           44.0
# 105           42.0
# 106         4169.0
# 107           20.0
# 108           25.0
# 109           33.0
# 110        11771.0
# 111          432.0
# 112         2339.0
# 113          127.0
# 114           85.0
# 115           54.0
# 116         4862.0
# 117          463.0
# 118            0.0
# 119            0.0
# 120            NaN
# 121           28.0
# 122           26.0
# 123         2567.0
# 124           52.0
# 125         2059.0
# 126        71871.0
# 127         2338.0
# 128           56.0
# 129          362.0
# 130           89.0
# 131           88.0
# 132            7.0
# 133           14.0
# 134          318.0
# 135          181.0
# 136           30.0
# 137            7.0
# 138          271.0
# 139        10885.0
# 140          316.0
# 141          146.0
# 142          161.0
# 143         1846.0
# 144           58.0
# 145           17.0
# 146           22.0
# 147          108.0
# 148           77.0
# 149        39470.0
# 150          100.0
# 151           53.0
# 152           64.0
# 153           40.0
# 154            5.0
# 155           57.0
# 156           42.0
# 157           75.0
# 158          133.0
# 159          181.0
# 160            0.0
# 161            0.0
# 162            0.0
# 163            NaN
#
# [164 rows x 90 columns]

# %% [markdown]
# ## Extract Bogota 0, 1, 2, 3 from Phase 1 Dataframe

# %%
overall_phase1_bogota0 = overall_phase1.loc[overall_phase1['Group'] == 0]
overall_phase1_bogota1 = overall_phase1.loc[overall_phase1['Group'] == 1]
overall_phase1_bogota2 = overall_phase1.loc[overall_phase1['Group'] == 2]
overall_phase1_bogota3 = overall_phase1.loc[overall_phase1['Group'] == 3]

# %% [markdown]
# ## Extract Bogota 0, 1, 2, 3 from Phase 2 Data Frame

# %%
overall_phase2_bogota0 = overall_phase2.loc[overall_phase2['Group'] == 0]
overall_phase2_bogota1 = overall_phase2.loc[overall_phase2['Group'] == 1]
overall_phase2_bogota2 = overall_phase2.loc[overall_phase2['Group'] == 2]
overall_phase2_bogota3 = overall_phase2.loc[overall_phase2['Group'] == 3]

# %% [markdown]
# ## Extract Bogota 0, 1, 2, 3 from Phase 3 Data Frame

# %%
overall_phase3_bogota0 = overall_phase3.loc[overall_phase3['Group'] == 0]
overall_phase3_bogota1 = overall_phase3.loc[overall_phase3['Group'] == 1]
overall_phase3_bogota2 = overall_phase3.loc[overall_phase3['Group'] == 2]
overall_phase3_bogota3 = overall_phase3.loc[overall_phase3['Group'] == 3]

# %% [markdown]
# ## Extract Bogota 0, 1, 2, 3 from Phase 4 Data Frame

# %%
overall_phase4_bogota0 = overall_phase4.loc[overall_phase4['Group'] == 0]
overall_phase4_bogota1 = overall_phase4.loc[overall_phase4['Group'] == 1]
overall_phase4_bogota2 = overall_phase4.loc[overall_phase4['Group'] == 2]
overall_phase4_bogota3 = overall_phase4.loc[overall_phase4['Group'] == 3]

# %% [markdown]
# ## Extract Bogota 0, 1, 2, 3 from Phase 5 Data Frame

# %%
overall_phase5_bogota0 = overall_phase5.loc[overall_phase5['Group'] == 0]
overall_phase5_bogota1 = overall_phase5.loc[overall_phase5['Group'] == 1]
overall_phase5_bogota2 = overall_phase5.loc[overall_phase5['Group'] == 2]
overall_phase5_bogota3 = overall_phase5.loc[overall_phase5['Group'] == 3]

# %%
# %store overall_phase1
# %store overall_phase2
# %store overall_phase3
# %store overall_phase4
# %store overall_phase5

# %store overall_phase1_bogota0
# %store overall_phase1_bogota1
# %store overall_phase1_bogota2
# %store overall_phase1_bogota3

# %store overall_phase2_bogota0
# %store overall_phase2_bogota1
# %store overall_phase2_bogota2
# %store overall_phase2_bogota3

# %store overall_phase3_bogota0
# %store overall_phase3_bogota1
# %store overall_phase3_bogota2
# %store overall_phase3_bogota3

# %store overall_phase4_bogota0
# %store overall_phase4_bogota1
# %store overall_phase4_bogota2
# %store overall_phase4_bogota3

# %store overall_phase5_bogota0
# %store overall_phase5_bogota1
# %store overall_phase5_bogota2
# %store overall_phase5_bogota3
# Out:
# Stored 'overall_phase1' (DataFrame)
# Stored 'overall_phase2' (DataFrame)
# Stored 'overall_phase3' (DataFrame)
# Stored 'overall_phase4' (DataFrame)
# Stored 'overall_phase5' (DataFrame)
# Stored 'overall_phase1_bogota0' (DataFrame)
# Stored 'overall_phase1_bogota1' (DataFrame)
# Stored 'overall_phase1_bogota2' (DataFrame)
# Stored 'overall_phase1_bogota3' (DataFrame)
# Stored 'overall_phase2_bogota0' (DataFrame)
# Stored 'overall_phase2_bogota1' (DataFrame)
# Stored 'overall_phase2_bogota2' (DataFrame)
# Stored 'overall_phase2_bogota3' (DataFrame)
# Stored 'overall_phase3_bogota0' (DataFrame)
# Stored 'overall_phase3_bogota1' (DataFrame)
# Stored 'overall_phase3_bogota2' (DataFrame)
# Stored 'overall_phase3_bogota3' (DataFrame)
# Stored 'overall_phase4_bogota0' (DataFrame)
# Stored 'overall_phase4_bogota1' (DataFrame)
# Stored 'overall_phase4_bogota2' (DataFrame)
# Stored 'overall_phase4_bogota3' (DataFrame)
# Stored 'overall_phase5_bogota0' (DataFrame)
# Stored 'overall_phase5_bogota1' (DataFrame)
# Stored 'overall_phase5_bogota2' (DataFrame)
# Stored 'overall_phase5_bogota3' (DataFrame)
