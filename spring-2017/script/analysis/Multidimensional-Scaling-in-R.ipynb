# %%
# %store -r stage1_bogota0_high_similarity
# %store -r stage1_bogota1_high_similarity
# %store -r stage1_bogota2_high_similarity
# %store -r stage1_bogota3_high_similarity

# %store -r stage2_bogota0_high_similarity
# %store -r stage2_bogota1_high_similarity
# %store -r stage2_bogota2_high_similarity
# %store -r stage2_bogota3_high_similarity

# %store -r stage3_bogota0_high_similarity
# %store -r stage3_bogota1_high_similarity
# %store -r stage3_bogota2_high_similarity
# %store -r stage3_bogota3_high_similarity

# %store -r stage4_bogota0_high_similarity
# %store -r stage4_bogota1_high_similarity
# %store -r stage4_bogota2_high_similarity
# %store -r stage4_bogota3_high_similarity

# %store -r stage1_bogota0
# %store -r stage1_bogota1
# %store -r stage1_bogota2
# %store -r stage1_bogota3

# %store -r stage2_bogota0
# %store -r stage2_bogota1
# %store -r stage2_bogota2
# %store -r stage2_bogota3

# %store -r stage3_bogota0
# %store -r stage3_bogota1
# %store -r stage3_bogota2
# %store -r stage3_bogota3

# %store -r stage4_bogota0
# %store -r stage4_bogota1
# %store -r stage4_bogota2
# %store -r stage4_bogota3

# %%
#define list of values
values = ['feartheGru', 'Danielsv9207', 'JhonEmmanuelTorres']


stage1_bogota3 = stage1_bogota3[stage1_bogota3.user2.isin(values) == False]

stage1_bogota3 = stage1_bogota3[stage1_bogota3.user1.isin(values) == False]

stage2_bogota3 = stage2_bogota3[stage2_bogota3.user2.isin(values) == False]

stage2_bogota3 = stage2_bogota3[stage2_bogota3.user1.isin(values) == False]

stage3_bogota3 = stage3_bogota3[stage3_bogota3.user2.isin(values) == False]

stage3_bogota3 = stage3_bogota3[stage3_bogota3.user1.isin(values) == False]

stage4_bogota3 = stage4_bogota3[stage4_bogota3.user2.isin(values) == False]

stage4_bogota3 = stage4_bogota3[stage4_bogota3.user1.isin(values) == False]

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage1_bogota3,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage1_bogota3_edge.csv")
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1681/2445892969.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   nx.adjacency_matrix(G, weight='similarity').todense(),

# %%
adjacency_df
# Out:
#                  juligarji  lemartinp  nfmorenog  AFelipeGA  mballeng91  \
# juligarji         0.000000   0.107143   0.056338   0.012295    0.003356
# lemartinp         0.107143   0.000000   0.291667   0.015873    0.000000
# nfmorenog         0.056338   0.291667   0.000000   0.019608    0.000000
# AFelipeGA         0.012295   0.015873   0.019608   0.000000    0.006335
# mballeng91        0.003356   0.000000   0.000000   0.006335    0.000000
# dduartec          0.026846   0.172414   0.215686   0.002412    0.000000
# srmedinac         0.049180   0.158730   0.188235   0.005701    0.008658
# wilson911013      0.000000   0.000000   0.000000   0.000000    0.000000
# wapiravaguens     0.050314   0.142857   0.225806   0.004803    0.009709
# davidh17          0.041667   0.192308   0.113208   0.002900    0.010582
# DianaNavarrete    0.014493   0.105263   0.042553   0.001455    0.000000
# jdmonroyg         0.000000   0.066667   0.000000   0.000486    0.000000
# jorge52an         0.020690   0.115385   0.055556   0.001449    0.000000
# jscastelblancoh   0.040000   0.233333   0.140351   0.002892    0.005102
# juclopezso        0.037975   0.125000   0.158730   0.003362    0.000000
# afforeroc         0.036765   0.222222   0.111111   0.001454    0.005525
# dagofonseca       0.026490   0.200000   0.254902   0.002893    0.005128
# lacardenasv       0.040462   0.173077   0.112500   0.012993    0.004545
# oacastillol       0.043796   0.263158   0.130435   0.001453    0.000000
# ncampuzano        0.042857   0.173913   0.222222   0.002906    0.000000
# adriel62          0.043478   0.190476   0.127660   0.001937    0.005435
# capinzor          0.033557   0.129032   0.086207   0.001928    0.000000
# ofnanezn          0.035714   0.105263   0.066667   0.008531    0.012448
# macuestap         0.019355   0.083333   0.046875   0.004339    0.031088
# spenas            0.021429   0.200000   0.061224   0.001453    0.000000
# kgbayala528       0.026786   0.057143   0.120968   0.013164    0.003704
# lgmoralesa        0.038961   0.171429   0.095238   0.001922    0.005000
# ronaldsg20        0.047619   0.129032   0.105263   0.002894    0.015625
# cccristanchoc     0.043478   0.166667   0.115942   0.001915    0.000000
# jmalvarezd        0.057325   0.146341   0.190476   0.003841    0.004854
# smarquezo         0.014925   0.133333   0.046512   0.000971    0.000000
# sarizag           0.027027   0.100000   0.070175   0.003867    0.005208
# Chranium          0.022059   0.176471   0.066667   0.001942    0.005587
# DavidQP           0.026667   0.093750   0.067797   0.000963    0.000000
# afceballosr       0.032051   0.200000   0.206897   0.002885    0.004975
# lizzyt10h         0.036437   0.078740   0.122449   0.014419    0.013652
# NicolasPrr        0.047619   0.166667   0.125000   0.002894    0.000000
# jumcorredorro     0.037267   0.230769   0.245902   0.005286    0.004831
#
#                  dduartec  srmedinac  wilson911013  wapiravaguens  davidh17  \
# juligarji        0.026846   0.049180           0.0       0.050314  0.041667
# lemartinp        0.172414   0.158730           0.0       0.142857  0.192308
# nfmorenog        0.215686   0.188235           0.0       0.225806  0.113208
# AFelipeGA        0.002412   0.005701           0.0       0.004803  0.002900
# mballeng91       0.000000   0.008658           0.0       0.009709  0.010582
# dduartec         0.000000   0.182927           0.0       0.107692  0.078431
# srmedinac        0.182927   0.000000           0.0       0.084337  0.106061
# wilson911013     0.000000   0.000000           0.0       0.000000  0.000000
# wapiravaguens    0.107692   0.084337           0.0       0.000000  0.128571
# davidh17         0.078431   0.106061           0.0       0.128571  0.000000
# DianaNavarrete   0.046512   0.032787           0.0       0.029851  0.042553
# jdmonroyg        0.025641   0.000000           0.0       0.000000  0.000000
# jorge52an        0.060000   0.044118           0.0       0.069444  0.075472
# jscastelblancoh  0.150943   0.082192           0.0       0.133333  0.181818
# juclopezso       0.095238   0.060976           0.0       0.148148  0.123077
# afforeroc        0.095238   0.103448           0.0       0.093750  0.136364
# dagofonseca      0.276596   0.040000           0.0       0.105263  0.254902
# lacardenasv      0.089744   0.183908           0.0       0.101010  0.098765
# oacastillol      0.090909   0.100000           0.0       0.090909  0.155556
# ncampuzano       0.108696   0.061538           0.0       0.136364  0.100000
# adriel62         0.088889   0.080645           0.0       0.089552  0.152174
# capinzor         0.053571   0.069444           0.0       0.064103  0.105263
# ofnanezn         0.058824   0.575000           0.0       0.073171  0.066667
# macuestap        0.067797   0.038462           0.0       0.060976  0.098361
# spenas           0.043478   0.064516           0.0       0.043478  0.061224
# kgbayala528      0.144068   0.062500           0.0       0.052980  0.094488
# lgmoralesa       0.048387   0.121622           0.0       0.072289  0.095238
# ronaldsg20       0.072727   0.069444           0.0       0.106667  0.105263
# cccristanchoc    0.057971   0.083333           0.0       0.065934  0.084507
# jmalvarezd       0.092308   0.059524           0.0       0.202532  0.119403
# smarquezo        0.051282   0.035088           0.0       0.031746  0.046512
# sarizag          0.096154   0.041667           0.0       0.094595  0.109091
# Chranium         0.100000   0.050847           0.0       0.046154  0.066667
# DavidQP          0.053571   0.040541           0.0       0.050633  0.050000
# afceballosr      0.269231   0.063291           0.0       0.084337  0.272727
# lizzyt10h        0.125874   0.059172           0.0       0.107784  0.195652
# NicolasPrr       0.072727   0.100000           0.0       0.092105  0.105263
# jumcorredorro    0.333333   0.084337           0.0       0.103448  0.357143
#
#                  ...  cccristanchoc  jmalvarezd  smarquezo   sarizag  \
# juligarji        ...       0.043478    0.057325   0.014925  0.027027
# lemartinp        ...       0.166667    0.146341   0.133333  0.100000
# nfmorenog        ...       0.115942    0.190476   0.046512  0.070175
# AFelipeGA        ...       0.001915    0.003841   0.000971  0.003867
# mballeng91       ...       0.000000    0.004854   0.000000  0.005208
# dduartec         ...       0.057971    0.092308   0.051282  0.096154
# srmedinac        ...       0.083333    0.059524   0.035088  0.041667
# wilson911013     ...       0.000000    0.000000   0.000000  0.000000
# wapiravaguens    ...       0.065934    0.202532   0.031746  0.094595
# davidh17         ...       0.084507    0.119403   0.046512  0.109091
# DianaNavarrete   ...       0.078947    0.083333   0.285714  0.136364
# jdmonroyg        ...       0.000000    0.000000   0.000000  0.000000
# jorge52an        ...       0.034884    0.074074   0.000000  0.028169
# jscastelblancoh  ...       0.096774    0.118644   0.058824  0.106383
# juclopezso       ...       0.081081    0.085714   0.333333  0.090909
# afforeroc        ...       0.138889    0.114286   0.285714  0.136364
# dagofonseca      ...       0.081633    0.133333   0.105263  0.121212
# lacardenasv      ...       0.092105    0.173913   0.040816  0.080645
# oacastillol      ...       0.050000    0.074074   0.017699  0.056452
# ncampuzano       ...       0.097222    0.166667   0.044444  0.067797
# adriel62         ...       0.088235    0.125000   0.050000  0.094340
# capinzor         ...       0.500000    0.083333   0.100000  0.117647
# ofnanezn         ...       0.095745    0.063158   0.028986  0.048193
# macuestap        ...       0.136364    0.142857   0.125000  0.259259
# spenas           ...       0.400000    0.080000   0.090909  0.052632
# kgbayala528      ...       0.056911    0.049180   0.020833  0.036364
# lgmoralesa       ...       0.327586    0.171875   0.046512  0.070175
# ronaldsg20       ...       0.102041    0.181818   0.100000  0.266667
# cccristanchoc    ...       0.000000    0.089744   0.037736  0.059701
# jmalvarezd       ...       0.089744    0.000000   0.038462  0.060606
# smarquezo        ...       0.037736    0.038462   0.000000  0.100000
# sarizag          ...       0.059701    0.060606   0.100000  0.000000
# Chranium         ...       0.054545    0.055556   0.285714  0.133333
# DavidQP          ...       0.351852    0.058824   0.090909  0.088889
# afceballosr      ...       0.230769    0.234375   0.033333  0.166667
# lizzyt10h        ...       0.121795    0.175676   0.016129  0.094203
# NicolasPrr       ...       0.123077    0.107692   0.090909  0.166667
# jumcorredorro    ...       0.246377    0.268657   0.057143  0.169811
#
#                  Chranium   DavidQP  afceballosr  lizzyt10h  NicolasPrr  \
# juligarji        0.022059  0.026667     0.032051   0.036437    0.047619
# lemartinp        0.176471  0.093750     0.200000   0.078740    0.166667
# nfmorenog        0.066667  0.067797     0.206897   0.122449    0.125000
# AFelipeGA        0.001942  0.000963     0.002885   0.014419    0.002894
# mballeng91       0.005587  0.000000     0.004975   0.013652    0.000000
# dduartec         0.100000  0.053571     0.269231   0.125874    0.072727
# srmedinac        0.050847  0.040541     0.063291   0.059172    0.100000
# wilson911013     0.000000  0.000000     0.000000   0.000000    0.000000
# wapiravaguens    0.046154  0.050633     0.084337   0.107784    0.092105
# davidh17         0.066667  0.050000     0.272727   0.195652    0.105263
# DianaNavarrete   0.333333  0.080000     0.030303   0.023810    0.125000
# jdmonroyg        0.000000  0.000000     0.000000   0.000000    0.000000
# jorge52an        0.016949  0.013514     0.000000   0.023121    0.027397
# jscastelblancoh  0.114286  0.080000     0.109091   0.068493    0.148936
# juclopezso       0.222222  0.130435     0.064516   0.024000    0.130435
# afforeroc        0.333333  0.125000     0.133333   0.048780    0.227273
# dagofonseca      0.142857  0.083333     0.210526   0.101562    0.114286
# lacardenasv      0.080000  0.061538     0.070423   0.075472    0.112903
# oacastillol      0.026087  0.031008     0.138211   0.169154    0.055556
# ncampuzano       0.063830  0.065574     0.058824   0.050314    0.120690
# adriel62         0.071429  0.071429     0.196429   0.255814    0.111111
# capinzor         0.136364  0.600000     0.093023   0.044118    0.142857
# ofnanezn         0.042254  0.047059     0.054945   0.055249    0.098765
# macuestap        0.235294  0.090909     0.228571   0.078125    0.200000
# spenas           0.080000  0.555556     0.065217   0.028571    0.105263
# kgbayala528      0.030612  0.035714     0.118182   0.129534    0.054545
# lgmoralesa       0.066667  0.340426     0.186441   0.137931    0.125000
# ronaldsg20       0.086957  0.111111     0.093023   0.051852    0.142857
# cccristanchoc    0.054545  0.351852     0.230769   0.121795    0.123077
# jmalvarezd       0.055556  0.058824     0.234375   0.175676    0.107692
# smarquezo        0.285714  0.090909     0.033333   0.016129    0.090909
# sarizag          0.133333  0.088889     0.166667   0.094203    0.166667
# Chranium         0.000000  0.086957     0.066667   0.024194    0.136364
# DavidQP          0.086957  0.000000     0.183673   0.085106    0.108696
# afceballosr      0.066667  0.183673     0.000000   0.102041    0.071429
# lizzyt10h        0.024194  0.085106     0.102041   0.000000    0.137931
# NicolasPrr       0.136364  0.108696     0.071429   0.137931    0.000000
# jumcorredorro    0.085714  0.207547     0.280702   0.210526    0.104167
#
#                  jumcorredorro
# juligarji             0.037267
# lemartinp             0.230769
# nfmorenog             0.245902
# AFelipeGA             0.005286
# mballeng91            0.004831
# dduartec              0.333333
# srmedinac             0.084337
# wilson911013          0.000000
# wapiravaguens         0.103448
# davidh17              0.357143
# DianaNavarrete        0.081081
# jdmonroyg             0.000000
# jorge52an             0.047619
# jscastelblancoh       0.135593
# juclopezso            0.054054
# afforeroc             0.142857
# dagofonseca           0.333333
# lacardenasv           0.093333
# oacastillol           0.168000
# ncampuzano            0.083333
# adriel62              0.258621
# capinzor              0.104167
# ofnanezn              0.073684
# macuestap             0.195122
# spenas                0.057692
# kgbayala528           0.151786
# lgmoralesa            0.245902
# ronaldsg20            0.081633
# cccristanchoc         0.246377
# jmalvarezd            0.268657
# smarquezo             0.057143
# sarizag               0.169811
# Chranium              0.085714
# DavidQP               0.207547
# afceballosr           0.280702
# lizzyt10h             0.210526
# NicolasPrr            0.104167
# jumcorredorro         0.000000
#
# [38 rows x 38 columns]

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage2_bogota3,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage2_bogota3_edge.csv")
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1681/2762521802.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   nx.adjacency_matrix(G, weight='similarity').todense(),

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage4_bogota3,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage4_bogota3_edge.csv")
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1681/2111772807.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   nx.adjacency_matrix(G, weight='similarity').todense(),

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage1_bogota0,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage1_bogota0_edge.csv")
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1681/4130421060.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   nx.adjacency_matrix(G, weight='similarity').todense(),

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage2_bogota0,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage2_bogota0_edge.csv")
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1681/2984318465.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   nx.adjacency_matrix(G, weight='similarity').todense(),

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage4_bogota0,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage4_bogota0_edge.csv")
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1681/1764197587.py:14: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   nx.adjacency_matrix(G, weight='similarity').todense(),
