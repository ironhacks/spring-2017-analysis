# %%
# %store -r stage1_bogota0_high_similarity
# %store -r stage1_bogota1_high_similarity
# %store -r stage1_bogota2_high_similarity
# %store -r stage1_bogota3_high_similarity

# %store -r stage2_bogota0_high_similarity
# %store -r stage2_bogota1_high_similarity
# %store -r stage2_bogota2_high_similarity
# %store -r stage2_bogota3_high_similarity

# %store -r stage3_bogota0_high_similarity
# %store -r stage3_bogota1_high_similarity
# %store -r stage3_bogota2_high_similarity
# %store -r stage3_bogota3_high_similarity

# %store -r stage4_bogota0_high_similarity
# %store -r stage4_bogota1_high_similarity
# %store -r stage4_bogota2_high_similarity
# %store -r stage4_bogota3_high_similarity

# %store -r stage1_bogota0
# %store -r stage1_bogota1
# %store -r stage1_bogota2
# %store -r stage1_bogota3

# %store -r stage2_bogota0
# %store -r stage2_bogota1
# %store -r stage2_bogota2
# %store -r stage2_bogota3

# %store -r stage3_bogota0
# %store -r stage3_bogota1
# %store -r stage3_bogota2
# %store -r stage3_bogota3

# %store -r stage4_bogota0
# %store -r stage4_bogota1
# %store -r stage4_bogota2
# %store -r stage4_bogota3

# %store -r df_g3_p1_top
# %store -r df_g3_p1_bottom
# %store -r df_g3_p2_top
# %store -r df_g3_p2_bottom
# %store -r df_g3_p3_top
# %store -r df_g3_p3_bottom
# %store -r df_g3_p4_top
# %store -r df_g3_p4_bottom

# %store -r df_g2_p1_top
# %store -r df_g2_p1_bottom
# %store -r df_g2_p2_top
# %store -r df_g2_p2_bottom
# %store -r df_g2_p3_top
# %store -r df_g2_p3_bottom
# %store -r df_g2_p4_top
# %store -r df_g2_p4_bottom

# %store -r df_g1_p1_top
# %store -r df_g1_p1_bottom
# %store -r df_g1_p2_top
# %store -r df_g1_p2_bottom
# %store -r df_g1_p3_top
# %store -r df_g1_p3_bottom
# %store -r df_g1_p4_top
# %store -r df_g1_p4_bottom

# %store -r df_g0_p1_top
# %store -r df_g0_p1_bottom
# %store -r df_g0_p2_top
# %store -r df_g0_p2_bottom
# %store -r df_g0_p3_top
# %store -r df_g0_p3_bottom
# %store -r df_g0_p4_top
# %store -r df_g0_p4_bottom

import pandas as pd

# %%
pd.set_option('display.max_rows', None)
l1 = [ 'top1', 'top2', 'top3', 'top4' ]
l2 = [ 'bottom1', 'bottom2', 'bottom3', 'bottom4' ]

l3 = [ 'top1', 'top2', 'top3', 'top4', 'top5' ]
l4 = [ 'bottom1', 'bottom2', 'bottom3', 'bottom4', 'bottom5' ]
#stage1_bogota3.loc[stage1_bogota3['user2'].isin(df_g3_p1_top), 'user2'] = 'top'
#stage1_bogota3.loc[stage1_bogota3['user2'].isin(df_g3_p1_bottom), 'user2'] = 'bottom'
stage1_bogota3['user2'] = stage1_bogota3['user2'].map(dict(zip(df_g3_p1_top, l1))).fillna(stage1_bogota3['user2'])
stage1_bogota3['user2'] = stage1_bogota3['user2'].map(dict(zip(df_g3_p1_bottom, l2))).fillna(stage1_bogota3['user2'])
stage2_bogota3['user2'] = stage2_bogota3['user2'].map(dict(zip(df_g3_p2_top, l1))).fillna(stage2_bogota3['user2'])
stage2_bogota3['user2'] = stage2_bogota3['user2'].map(dict(zip(df_g3_p2_bottom, l2))).fillna(stage2_bogota3['user2'])
stage3_bogota3['user2'] = stage3_bogota3['user2'].map(dict(zip(df_g3_p3_top, l1))).fillna(stage3_bogota3['user2'])
stage3_bogota3['user2'] = stage3_bogota3['user2'].map(dict(zip(df_g3_p3_bottom, l2))).fillna(stage3_bogota3['user2'])
stage4_bogota3['user2'] = stage4_bogota3['user2'].map(dict(zip(df_g3_p4_top, l1))).fillna(stage4_bogota3['user2'])
stage4_bogota3['user2'] = stage4_bogota3['user2'].map(dict(zip(df_g3_p4_bottom, l2))).fillna(stage4_bogota3['user2'])

stage1_bogota2['user2'] = stage1_bogota2['user2'].map(dict(zip(df_g2_p1_top, l3))).fillna(stage1_bogota2['user2'])
stage1_bogota2['user2'] = stage1_bogota2['user2'].map(dict(zip(df_g2_p1_bottom, l4))).fillna(stage1_bogota2['user2'])
stage2_bogota2['user2'] = stage2_bogota2['user2'].map(dict(zip(df_g2_p2_top, l3))).fillna(stage2_bogota2['user2'])
stage2_bogota2['user2'] = stage2_bogota2['user2'].map(dict(zip(df_g2_p2_bottom, l4))).fillna(stage2_bogota2['user2'])
stage3_bogota2['user2'] = stage3_bogota2['user2'].map(dict(zip(df_g2_p3_top, l3))).fillna(stage3_bogota2['user2'])
stage3_bogota2['user2'] = stage3_bogota2['user2'].map(dict(zip(df_g2_p3_bottom, l4))).fillna(stage3_bogota2['user2'])
stage4_bogota2['user2'] = stage4_bogota2['user2'].map(dict(zip(df_g2_p4_top, l3))).fillna(stage4_bogota2['user2'])
stage4_bogota2['user2'] = stage4_bogota2['user2'].map(dict(zip(df_g2_p4_bottom, l4))).fillna(stage4_bogota2['user2'])

stage1_bogota1['user2'] = stage1_bogota1['user2'].map(dict(zip(df_g1_p1_top, l3))).fillna(stage1_bogota1['user2'])
stage1_bogota1['user2'] = stage1_bogota1['user2'].map(dict(zip(df_g1_p1_bottom, l4))).fillna(stage1_bogota1['user2'])
stage2_bogota1['user2'] = stage2_bogota1['user2'].map(dict(zip(df_g1_p2_top, l3))).fillna(stage2_bogota1['user2'])
stage2_bogota1['user2'] = stage2_bogota1['user2'].map(dict(zip(df_g1_p2_bottom, l4))).fillna(stage2_bogota1['user2'])
stage3_bogota1['user2'] = stage3_bogota1['user2'].map(dict(zip(df_g1_p3_top, l3))).fillna(stage3_bogota1['user2'])
stage3_bogota1['user2'] = stage3_bogota1['user2'].map(dict(zip(df_g1_p3_bottom, l4))).fillna(stage3_bogota1['user2'])
stage4_bogota1['user2'] = stage4_bogota1['user2'].map(dict(zip(df_g1_p4_top, l3))).fillna(stage4_bogota1['user2'])
stage4_bogota1['user2'] = stage4_bogota1['user2'].map(dict(zip(df_g1_p4_bottom, l4))).fillna(stage4_bogota1['user2'])

stage1_bogota0['user2'] = stage1_bogota0['user2'].map(dict(zip(df_g0_p1_top, l1))).fillna(stage1_bogota0['user2'])
stage1_bogota0['user2'] = stage1_bogota0['user2'].map(dict(zip(df_g0_p1_bottom, l2))).fillna(stage1_bogota0['user2'])
stage2_bogota0['user2'] = stage2_bogota0['user2'].map(dict(zip(df_g0_p2_top, l1))).fillna(stage2_bogota0['user2'])
stage2_bogota0['user2'] = stage3_bogota0['user2'].map(dict(zip(df_g0_p2_bottom, l2))).fillna(stage2_bogota0['user2'])
stage3_bogota0['user2'] = stage3_bogota0['user2'].map(dict(zip(df_g0_p3_top, l1))).fillna(stage3_bogota0['user2'])
stage3_bogota0['user2'] = stage3_bogota0['user2'].map(dict(zip(df_g0_p3_bottom, l2))).fillna(stage3_bogota0['user2'])
stage4_bogota0['user2'] = stage4_bogota0['user2'].map(dict(zip(df_g0_p4_top, l1))).fillna(stage4_bogota0['user2'])
stage4_bogota0['user2'] = stage4_bogota0['user2'].map(dict(zip(df_g0_p4_bottom, l2))).fillna(stage4_bogota0['user2'])

stage1_bogota3['user1'] = stage1_bogota3['user1'].map(dict(zip(df_g3_p1_top, l1))).fillna(stage1_bogota3['user1'])
stage1_bogota3['user1'] = stage1_bogota3['user1'].map(dict(zip(df_g3_p1_bottom, l2))).fillna(stage1_bogota3['user1'])
stage2_bogota3['user1'] = stage2_bogota3['user1'].map(dict(zip(df_g3_p2_top, l1))).fillna(stage2_bogota3['user1'])
stage2_bogota3['user1'] = stage2_bogota3['user1'].map(dict(zip(df_g3_p2_bottom, l2))).fillna(stage2_bogota3['user1'])
stage3_bogota3['user1'] = stage3_bogota3['user1'].map(dict(zip(df_g3_p3_top, l1))).fillna(stage3_bogota3['user1'])
stage3_bogota3['user1'] = stage3_bogota3['user1'].map(dict(zip(df_g3_p3_bottom, l2))).fillna(stage3_bogota3['user1'])
stage4_bogota3['user1'] = stage4_bogota3['user1'].map(dict(zip(df_g3_p4_top, l1))).fillna(stage4_bogota3['user1'])
stage4_bogota3['user1'] = stage4_bogota3['user1'].map(dict(zip(df_g3_p4_bottom, l2))).fillna(stage4_bogota3['user1'])

stage1_bogota2['user1'] = stage1_bogota2['user1'].map(dict(zip(df_g2_p1_top, l3))).fillna(stage1_bogota2['user1'])
stage1_bogota2['user1'] = stage1_bogota2['user1'].map(dict(zip(df_g2_p1_bottom, l4))).fillna(stage1_bogota2['user1'])
stage2_bogota2['user1'] = stage2_bogota2['user1'].map(dict(zip(df_g2_p2_top, l3))).fillna(stage2_bogota2['user1'])
stage2_bogota2['user1'] = stage2_bogota2['user1'].map(dict(zip(df_g2_p2_bottom, l4))).fillna(stage2_bogota2['user1'])
stage3_bogota2['user1'] = stage3_bogota2['user1'].map(dict(zip(df_g2_p3_top, l3))).fillna(stage3_bogota2['user1'])
stage3_bogota2['user1'] = stage3_bogota2['user1'].map(dict(zip(df_g2_p3_bottom, l4))).fillna(stage3_bogota2['user1'])
stage4_bogota2['user1'] = stage4_bogota2['user1'].map(dict(zip(df_g2_p4_top, l3))).fillna(stage4_bogota2['user1'])
stage4_bogota2['user1'] = stage4_bogota2['user1'].map(dict(zip(df_g2_p4_bottom, l4))).fillna(stage4_bogota2['user1'])

stage1_bogota1['user1'] = stage1_bogota1['user1'].map(dict(zip(df_g1_p1_top, l3))).fillna(stage1_bogota1['user1'])
stage1_bogota1['user1'] = stage1_bogota1['user1'].map(dict(zip(df_g1_p1_bottom, l4))).fillna(stage1_bogota1['user1'])
stage2_bogota1['user1'] = stage2_bogota1['user1'].map(dict(zip(df_g1_p2_top, l3))).fillna(stage2_bogota1['user1'])
stage2_bogota1['user1'] = stage2_bogota1['user1'].map(dict(zip(df_g1_p2_bottom, l4))).fillna(stage2_bogota1['user1'])
stage3_bogota1['user1'] = stage3_bogota1['user1'].map(dict(zip(df_g1_p3_top, l3))).fillna(stage3_bogota1['user1'])
stage3_bogota1['user1'] = stage3_bogota1['user1'].map(dict(zip(df_g1_p3_bottom, l4))).fillna(stage3_bogota1['user1'])
stage4_bogota1['user1'] = stage4_bogota1['user1'].map(dict(zip(df_g1_p4_top, l3))).fillna(stage4_bogota1['user1'])
stage4_bogota1['user1'] = stage4_bogota1['user1'].map(dict(zip(df_g1_p4_bottom, l4))).fillna(stage4_bogota1['user1'])

stage1_bogota0['user1'] = stage1_bogota0['user1'].map(dict(zip(df_g0_p1_top, l1))).fillna(stage1_bogota0['user1'])
stage1_bogota0['user1'] = stage1_bogota0['user1'].map(dict(zip(df_g0_p1_bottom, l2))).fillna(stage1_bogota0['user1'])
stage2_bogota0['user1'] = stage2_bogota0['user1'].map(dict(zip(df_g0_p2_top, l1))).fillna(stage2_bogota0['user1'])
stage2_bogota0['user1'] = stage3_bogota0['user1'].map(dict(zip(df_g0_p2_bottom, l2))).fillna(stage2_bogota0['user1'])
stage3_bogota0['user1'] = stage3_bogota0['user1'].map(dict(zip(df_g0_p3_top, l1))).fillna(stage3_bogota0['user1'])
stage3_bogota0['user1'] = stage3_bogota0['user1'].map(dict(zip(df_g0_p3_bottom, l2))).fillna(stage3_bogota0['user1'])
stage4_bogota0['user1'] = stage4_bogota0['user1'].map(dict(zip(df_g0_p4_top, l1))).fillna(stage4_bogota0['user1'])
stage4_bogota0['user1'] = stage4_bogota0['user1'].map(dict(zip(df_g0_p4_bottom, l2))).fillna(stage4_bogota0['user1'])

# %%
#define list of values
values = ['feartheGru', 'Danielsv9207', 'JhonEmmanuelTorres']


stage1_bogota3 = stage1_bogota3[stage1_bogota3.user2.isin(values) == False]

stage1_bogota3 = stage1_bogota3[stage1_bogota3.user1.isin(values) == False]

stage2_bogota3 = stage2_bogota3[stage2_bogota3.user2.isin(values) == False]

stage2_bogota3 = stage2_bogota3[stage2_bogota3.user1.isin(values) == False]

stage3_bogota3 = stage3_bogota3[stage3_bogota3.user2.isin(values) == False]

stage3_bogota3 = stage3_bogota3[stage3_bogota3.user1.isin(values) == False]

stage4_bogota3 = stage4_bogota3[stage4_bogota3.user2.isin(values) == False]

stage4_bogota3 = stage4_bogota3[stage4_bogota3.user1.isin(values) == False]

# %%
stage1_bogota3
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 41         lemartinp       juligarji            1            2    0.021583
# 42         lemartinp       nfmorenog            1            2    0.085106
# 43         lemartinp       AFelipeGA            1            2    0.090909
# 44         lemartinp         bottom3            1            2    0.000000
# 45         lemartinp            top1            1            2    0.021739
# 46         lemartinp       srmedinac            1            2    0.083333
# 47         lemartinp         bottom2            1            2    0.000000
# 48         lemartinp   wapiravaguens            1            2    0.000000
# 49         lemartinp        davidh17            1            2    0.062500
# 50         lemartinp  DianaNavarrete            1            2    0.000000
# 51         lemartinp       jdmonroyg            1            2    0.000000
# ...

# %%
import pandas as pd

df = pd.read_csv('merged-sim-best.csv')
df
# Out:
#      Unnamed: 0.1  Unnamed: 0          Student  phase   novelty  group  \
# 0               0           1     wilson911013      1  0.000000      3
# 1               2           5        lizzyt10h      1  0.400000      3
# 2               3           6        AFelipeGA      1  0.400000      3
# 3               4           7    wapiravaguens      1  0.400000      3
# 4               5           8         capinzor      1  0.413793      3
# 5               6           9      lacardenasv      1  0.424658      3
# 6               7          10       ncampuzano      1  0.428571      3
# 7               8          11        afforeroc      1  0.428571      3
# 8               9          12         adriel62      1  0.431373      3
# 9              10          13           spenas      1  0.444444      3
# 10             11          14         Chranium      1  0.500000      3
# 11             12          15        macuestap      1  0.545455      3
# ...

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage1_bogota3,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage1_bogota3_edge.csv")

# %%
adjacency_df
# Out:
#                 juligarji  lemartinp  nfmorenog  AFelipeGA   bottom3  \
# juligarji        0.000000   0.107143   0.056338   0.029851  0.003356
# lemartinp        0.107143   0.000000   0.291667   0.187500  0.000000
# nfmorenog        0.056338   0.291667   0.000000   0.093023  0.000000
# AFelipeGA        0.029851   0.187500   0.093023   0.000000  0.000000
# bottom3          0.003356   0.000000   0.000000   0.000000  0.000000
# top1             0.026846   0.172414   0.215686   0.150000  0.000000
# srmedinac        0.049180   0.158730   0.188235   0.068966  0.008658
# bottom2          0.000000   0.000000   0.000000   0.000000  0.000000
# wapiravaguens    0.022222   0.117647   0.068182   0.600000  0.000000
# davidh17         0.041667   0.192308   0.113208   0.250000  0.010582
# DianaNavarrete   0.014493   0.105263   0.042553   0.250000  0.000000
# jdmonroyg        0.000000   0.066667   0.000000   0.000000  0.000000
# jorge52an        0.020690   0.115385   0.055556   0.200000  0.000000
# ...

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage2_bogota3,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage2_bogota3_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage3_bogota3,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage3_bogota3_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage4_bogota3,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage4_bogota3_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage1_bogota2,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage1_bogota2_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage2_bogota2,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage2_bogota2_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage3_bogota2,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage3_bogota2_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage4_bogota2,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage4_bogota2_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage1_bogota1,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage1_bogota1_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage2_bogota1,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage2_bogota1_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage3_bogota1,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage3_bogota1_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage4_bogota1,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage4_bogota1_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage1_bogota0,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage1_bogota0_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage2_bogota0,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage2_bogota0_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage3_bogota0,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage3_bogota0_edge.csv")

# %%
import networkx as nx
import pandas as pd

# Create Graph
G = nx.from_pandas_edgelist(
    stage4_bogota0,
    source='user2',
    target='user1',
    edge_attr='similarity'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='similarity').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv("stage4_bogota0_edge.csv")
