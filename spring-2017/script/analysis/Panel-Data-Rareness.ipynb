# %%
# retrieve variables from rareness notebook

# %store -r group0_phase1_match10
# %store -r group0_phase2_match10
# %store -r group0_phase3_match10
# %store -r group0_phase4_match10
# %store -r group0_phase5_match10

# %store -r group1_phase1_match10
# %store -r group1_phase2_match10
# %store -r group1_phase3_match10
# %store -r group1_phase4_match10
# %store -r group1_phase5_match10

# %store -r group2_phase1_match10
# %store -r group2_phase2_match10
# %store -r group2_phase3_match10
# %store -r group2_phase4_match10
# %store -r group2_phase5_match10

# %store -r group3_phase1_match10
# %store -r group3_phase2_match10
# %store -r group3_phase3_match10
# %store -r group3_phase4_match10
# %store -r group3_phase5_match10

# store rareness top 10% to be used in correlation charts 

# %store -r group0_phase1_match5
# %store -r group0_phase2_match5
# %store -r group0_phase3_match5
# %store -r group0_phase4_match5
# %store -r group0_phase5_match5

# %store -r group1_phase1_match5
# %store -r group1_phase2_match5
# %store -r group1_phase3_match5
# %store -r group1_phase4_match5
# %store -r group1_phase5_match5

# %store -r group2_phase1_match5
# %store -r group2_phase2_match5
# %store -r group2_phase3_match5
# %store -r group2_phase4_match5
# %store -r group2_phase5_match5

# %store -r group3_phase1_match5
# %store -r group3_phase2_match5
# %store -r group3_phase3_match5
# %store -r group3_phase4_match5
# %store -r group3_phase5_match5

# retrive  variables from relational novelty notebook
# %store -r survey
# %store -r commits

import pandas as pd

# %%
group0_phase1_match10['phase'] = 1
group0_phase2_match10['phase'] = 2
group0_phase3_match10['phase'] = 3
group0_phase4_match10['phase'] = 4
group0_phase5_match10['phase'] = 5

group1_phase1_match10['phase'] = 1
group1_phase2_match10['phase'] = 2
group1_phase3_match10['phase'] = 3
group1_phase4_match10['phase'] = 4
group1_phase5_match10['phase'] = 5

group2_phase1_match10['phase'] = 1
group2_phase2_match10['phase'] = 2
group2_phase3_match10['phase'] = 3
group2_phase4_match10['phase'] = 4
group2_phase5_match10['phase'] = 5

group3_phase1_match10['phase'] = 1
group3_phase2_match10['phase'] = 2
group3_phase3_match10['phase'] = 3
group3_phase4_match10['phase'] = 4
group3_phase5_match10['phase'] = 5

group0_phase1_match5['phase'] = 1
group0_phase2_match5['phase'] = 2
group0_phase3_match5['phase'] = 3
group0_phase4_match5['phase'] = 4
group0_phase5_match5['phase'] = 5

group1_phase1_match5['phase'] = 1
group1_phase2_match5['phase'] = 2
group1_phase3_match5['phase'] = 3
group1_phase4_match5['phase'] = 4
group1_phase5_match5['phase'] = 5

group2_phase1_match5['phase'] = 1
group2_phase2_match5['phase'] = 2
group2_phase3_match5['phase'] = 3
group2_phase4_match5['phase'] = 4
group2_phase5_match5['phase'] = 5

group3_phase1_match5['phase'] = 1
group3_phase2_match5['phase'] = 2
group3_phase3_match5['phase'] = 3
group3_phase4_match5['phase'] = 4
group3_phase5_match5['phase'] = 5

# %%
rare = pd.concat([group0_phase1_match10, group0_phase2_match10, group0_phase3_match10, 
                         group0_phase4_match10, group0_phase5_match10, 
                         group1_phase1_match10, group1_phase2_match10, group1_phase3_match10, group1_phase4_match10,
                         group1_phase5_match10, group2_phase1_match10, group2_phase2_match10, group2_phase3_match10,
                         group2_phase4_match10, group2_phase5_match10, group3_phase1_match10, group3_phase2_match10,
                         group3_phase3_match10, group3_phase4_match10, group3_phase5_match10], ignore_index = True)
rare
# Out:
#      len_match  Group        Student  phase
# 0          0.0    0.0      fffeelipe      1
# 1          0.0    0.0      mnguzmanc      1
# 2          0.0    0.0          DglyP      1
# 3          0.0    0.0    Judgarciani      1
# 4          0.0    0.0      sacastroc      1
# ..         ...    ...            ...    ...
# 668        2.0    3.0        DavidQP      5
# 669       10.0    3.0    afceballosr      5
# 670       17.0    3.0      lizzyt10h      5
# 671       28.0    3.0     NicolasPrr      5
# 672        9.0    3.0  jumcorredorro      5
#
# [673 rows x 4 columns]

# %%
rare5 = pd.concat([group0_phase1_match5, group0_phase2_match5, group0_phase3_match5, 
                         group0_phase4_match5, group0_phase5_match5, 
                         group1_phase1_match5, group1_phase2_match5, group1_phase3_match5, group1_phase4_match5,
                         group1_phase5_match5, group2_phase1_match5, group2_phase2_match5, group2_phase3_match5,
                         group2_phase4_match5, group2_phase5_match5, group3_phase1_match5, group3_phase2_match5,
                         group3_phase3_match5, group3_phase4_match5, group3_phase5_match5], ignore_index = True)
rare5
# Out:
#      len_match5  Group        Student  phase
# 0           0.0    0.0      mnguzmanc      1
# 1           0.0    0.0          DglyP      1
# 2           0.0    0.0    Judgarciani      1
# 3           0.0    0.0      sacastroc      1
# 4           0.0    0.0      pcberriop      1
# ..          ...    ...            ...    ...
# 663         1.0    3.0        DavidQP      5
# 664         3.0    3.0    afceballosr      5
# 665         0.0    3.0      lizzyt10h      5
# 666         2.0    3.0     NicolasPrr      5
# 667         5.0    3.0  jumcorredorro      5
#
# [668 rows x 4 columns]

# %%
final5 = pd.merge(rare5, survey, how='left', left_on='Student', right_on ='user2')
final5 = final5.drop_duplicates(subset=['Student', 'Group', 'phase'])
final5
# Out:
#      len_match5  Group        Student  phase          user2  Q7_Q7_1  Q7_Q7_2  \
# 0           0.0    0.0      mnguzmanc      1      mnguzmanc      2.0      1.0
# 1           0.0    0.0          DglyP      1          DglyP      1.0      3.0
# 2           0.0    0.0    Judgarciani      1    Judgarciani      3.0      3.0
# 3           0.0    0.0      sacastroc      1      sacastroc      1.0      2.0
# 4           0.0    0.0      pcberriop      1      pcberriop      0.0      1.0
# ..          ...    ...            ...    ...            ...      ...      ...
# 668         1.0    3.0        DavidQP      5        DavidQP      2.0      3.0
# 669         3.0    3.0    afceballosr      5    afceballosr      1.0      3.0
# 670         0.0    3.0      lizzyt10h      5      lizzyt10h      2.0      1.0
# 671         2.0    3.0     NicolasPrr      5     NicolasPrr      3.0      4.0
# 672         5.0    3.0  jumcorredorro      5  jumcorredorro      1.0      1.0
#
#      Q8_Q8_1  Q10
# ...

# %%
final = pd.merge(rare, survey, how='left', left_on='Student', right_on ='user2')
final
# Out:
#      len_match  Group        Student  phase          user2  Q7_Q7_1  Q7_Q7_2  \
# 0          0.0    0.0      fffeelipe      1      fffeelipe      1.0      0.0
# 1          0.0    0.0      mnguzmanc      1      mnguzmanc      2.0      1.0
# 2          0.0    0.0          DglyP      1          DglyP      1.0      3.0
# 3          0.0    0.0    Judgarciani      1    Judgarciani      3.0      3.0
# 4          0.0    0.0      sacastroc      1      sacastroc      1.0      2.0
# ..         ...    ...            ...    ...            ...      ...      ...
# 673        2.0    3.0        DavidQP      5        DavidQP      2.0      3.0
# 674       10.0    3.0    afceballosr      5    afceballosr      1.0      3.0
# 675       17.0    3.0      lizzyt10h      5      lizzyt10h      2.0      1.0
# 676       28.0    3.0     NicolasPrr      5     NicolasPrr      3.0      4.0
# 677        9.0    3.0  jumcorredorro      5  jumcorredorro      1.0      1.0
#
#      Q8_Q8_1  Q10
# 0        5.0  3.0
# ...

# %%
commits
# Out:
#      Unnamed: 0  index        Student  Group  user-requirement-phase5  \
# 0             0      0      fffeelipe    0.0                     20.0
# 1             1      3      fffeelipe    0.0                     20.0
# 2             2      4      fffeelipe    0.0                     20.0
# 3             3      5      fffeelipe    0.0                     20.0
# 4             4      7      fffeelipe    0.0                     20.0
# ..          ...    ...            ...    ...                      ...
# 535         535   1508  jumcorredorro    3.0                    100.0
# 536         536   1509  jumcorredorro    3.0                    100.0
# 537         537   1512  jumcorredorro    3.0                    100.0
# 538         538   1514  jumcorredorro    3.0                    100.0
# 539         539   1518  jumcorredorro    3.0                    100.0
#
#      infovis-phase5  novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
end = pd.merge(final, commits[['Student', 'count', 'phase']], how='left', left_on=['Student', 'phase'], right_on =['Student', 'phase'])
end['count'] = end['count'].fillna(0)
end = end.drop(['Student'], axis=1)
end
# Out:
#      len_match  Group  phase          user2  Q7_Q7_1  Q7_Q7_2  Q8_Q8_1  Q10  \
# 0          0.0    0.0      1      fffeelipe      1.0      0.0      5.0  3.0
# 1          0.0    0.0      1      mnguzmanc      2.0      1.0      3.0  2.0
# 2          0.0    0.0      1          DglyP      1.0      3.0      4.0  3.0
# 3          0.0    0.0      1    Judgarciani      3.0      3.0      4.0  2.0
# 4          0.0    0.0      1      sacastroc      1.0      2.0      4.0  2.0
# ..         ...    ...    ...            ...      ...      ...      ...  ...
# 673        2.0    3.0      5        DavidQP      2.0      3.0      4.0  3.0
# 674       10.0    3.0      5    afceballosr      1.0      3.0      5.0  2.0
# 675       17.0    3.0      5      lizzyt10h      2.0      1.0      5.0  2.0
# 676       28.0    3.0      5     NicolasPrr      3.0      4.0      3.0  2.0
# 677        9.0    3.0      5  jumcorredorro      1.0      1.0      5.0  2.0
#
#      count
# 0      2.0
# 1      0.0
# 2      3.0
# ...

# %%
end.to_csv('rare.csv')

# %%
end5 = pd.merge(final5, commits[['Student', 'count', 'phase']], how='left', left_on=['Student', 'phase'], right_on =['Student', 'phase'])
end5['count'] = end5['count'].fillna(0)
end5 = end5.drop_duplicates(subset=['Student', 'Group', 'phase'])
end5 = end5.drop(['Student'], axis=1)
end5
# Out:
#      len_match5  Group  phase          user2  Q7_Q7_1  Q7_Q7_2  Q8_Q8_1  Q10  \
# 0           0.0    0.0      1      mnguzmanc      2.0      1.0      3.0  2.0
# 1           0.0    0.0      1          DglyP      1.0      3.0      4.0  3.0
# 2           0.0    0.0      1    Judgarciani      3.0      3.0      4.0  2.0
# 3           0.0    0.0      1      sacastroc      1.0      2.0      4.0  2.0
# 4           0.0    0.0      1      pcberriop      0.0      1.0      3.0  2.0
# ..          ...    ...    ...            ...      ...      ...      ...  ...
# 663         1.0    3.0      5        DavidQP      2.0      3.0      4.0  3.0
# 664         3.0    3.0      5    afceballosr      1.0      3.0      5.0  2.0
# 665         0.0    3.0      5      lizzyt10h      2.0      1.0      5.0  2.0
# 666         2.0    3.0      5     NicolasPrr      3.0      4.0      3.0  2.0
# 667         5.0    3.0      5  jumcorredorro      1.0      1.0      5.0  2.0
#
#      count
# 0      0.0
# 1      3.0
# ...

# %%
end5.to_csv('rare5.csv')
