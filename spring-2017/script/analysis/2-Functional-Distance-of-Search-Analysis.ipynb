# %% [markdown]
# ## Distance of Search
#
# > The set of choices available to a decision maker is discovered through search, according to Simon, 1957. Success promotes local search whereas failures promotes distance search (Billinger et. al., 2014). From Billinger et. al. (2014), we know that people start exploring from the beginning. Bodreau & Lakhani (2014) argues that transparency reduces the number of solutions tried.

# %%
# retrive variables stored in other Jupyter notebooks

# %store -r overall_loc_scores_final
# %store -r overall_loc_scores

# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5

# %store -r overall_phase1_bogota0
# %store -r overall_phase1_bogota1
# %store -r overall_phase1_bogota2
# %store -r overall_phase1_bogota3

# %store -r overall_phase2_bogota0
# %store -r overall_phase2_bogota1
# %store -r overall_phase2_bogota2
# %store -r overall_phase2_bogota3

# %store -r overall_phase3_bogota0
# %store -r overall_phase3_bogota1
# %store -r overall_phase3_bogota2
# %store -r overall_phase3_bogota3

# %store -r overall_phase4_bogota0
# %store -r overall_phase4_bogota1
# %store -r overall_phase4_bogota2
# %store -r overall_phase4_bogota3

# %store -r overall_phase5_bogota0
# %store -r overall_phase5_bogota1
# %store -r overall_phase5_bogota2
# %store -r overall_phase5_bogota3

# %store -r bogota0_phase1_high
# %store -r bogota0_phase2_high
# %store -r bogota0_phase3_high
# %store -r bogota0_phase4_high

# %store -r bogota1_phase1_high
# %store -r bogota1_phase2_high
# %store -r bogota1_phase3_high
# %store -r bogota1_phase4_high

# %store -r bogota2_phase1_high
# %store -r bogota2_phase2_high
# %store -r bogota2_phase3_high
# %store -r bogota2_phase4_high

# %store -r bogota3_phase1_high
# %store -r bogota3_phase2_high
# %store -r bogota3_phase3_high
# %store -r bogota3_phase4_high
# Out:
# no stored variable or alias bogota0_phase1_high
# no stored variable or alias bogota0_phase2_high
# no stored variable or alias bogota0_phase3_high
# no stored variable or alias bogota0_phase4_high
# no stored variable or alias bogota1_phase1_high
# no stored variable or alias bogota1_phase2_high
# no stored variable or alias bogota1_phase3_high
# no stored variable or alias bogota1_phase4_high
# no stored variable or alias bogota2_phase1_high
# no stored variable or alias bogota2_phase2_high
# no stored variable or alias bogota2_phase3_high
# no stored variable or alias bogota2_phase4_high
# no stored variable or alias bogota3_phase1_high
# no stored variable or alias bogota3_phase2_high
# no stored variable or alias bogota3_phase3_high
# no stored variable or alias bogota3_phase4_high

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import shapiro
import inspect
from scipy.stats import ttest_ind
from scipy.stats import mannwhitneyu

# %%
import itertools
import pandas as pd


def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_bogota3["functions"], overall_phase1_bogota3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#              user1               user2  similarity
# 0        lemartinp           juligarji    0.050955
# 1        lemartinp           nfmorenog    0.222222
# 2        lemartinp           AFelipeGA    0.073171
# 3        lemartinp          mballeng91    0.250000
# 4        lemartinp            dduartec    0.120000
# ..             ...                 ...         ...
# 815  jumcorredorro        Danielsv9207    0.000000
# 816  jumcorredorro  JhonEmmanuelTorres    0.187500
# 817     feartheGru        Danielsv9207    1.000000
# 818     feartheGru  JhonEmmanuelTorres    0.000000
# 819   Danielsv9207  JhonEmmanuelTorres    0.000000
#
# [820 rows x 3 columns]

# %%
overall_phase1_bogota3['functions']
# Out:
# 122    [document.getElementById, google.maps.Map, goo...
# 123    [bootstrap.min.css, theme.min.css, jquery.min....
# 124    [js.org, .v, .min.js, style.css, google.maps.M...
# 125    [jquery.min.js, styles.css, init.js, .containe...
# 126    [styles.css, developers.google, default.css, ....
# 127    [lml.jpg, google.maps.LatLng, google.maps.MapT...
# 128    [bootstrap.min.css, awesome.min.css, theme.min...
# 129    [jquery.min.js, .js, Rent.js, Crimes.js, googl...
# 130    [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 131    [bootstrap.min.css, theme.min.css, style.css, ...
# 132    [illinois.edu, favicon.ico, bootstrap.min.css,...
# 133    [bootstrap.min.css, theme.min.css, jquery.min....
# 134    [bootstrap.min.css, main.css, .org, .js, map.j...
# 135                                                   []
# 136    [bootstrap.min.css, demos.css, .jumbotron, .fl...
# 137    [bootstrap.min.css, theme.min.css, aos.css, co...
# 138                                                   []
# 139    [data.cityofchicago.org, iimk.geojson, xi.geoj...
# 140    [components.css, responsee.css, owl.carousel.c...
# 141    [google.maps.Map, document.getElementById, goo...
# 142    [FirstLook.css, bootstrap.min.css, jquery.min....
# 143    [.js, Mapa.js, Data.js, labels.text.stroke, la...
# 144    [style.css, jquery.min.js, .ready, .click, .aj...
# 145    [mainPage.css, resetStyle.css, jquery.min.js, ...
# 146    [jquery.min.js, bootstrap.min.js, .js, js.org,...
# 147    [main.css, angular.min.js, app.js, mainControl...
# 148    [runner.github.io, module.exports, config.set,...
# 149    [styles.css, scripts.js, integration.js, googl...
# 150    [ownStyle.css, bootstrap.min.css, theme.min.cs...
# 151    [styles.css, loadUpData.js, map.js, data.cityo...
# 152    [bootstrap.js, bootstrap.css, styles.css, goog...
# 153    [PROJECT.HTML, document.getElementById, google...
# 154    [bootstrap.min.css, item.css, Respond.js, shiv...
# 155    [bootstrap.min.css, estilos.css, maps.js, .min...
# 156    [materialize.min.css, materialize.min.js, .min...
# 157    [funciones.js, jquery.min.js, bootstrap.min.js...
# 158    [bootstrap.min.css, theme.min.css, jquery.min....
# 159    [bootstrap.min.css, portfolio.css, awesome.min...
# 160                                                   []
# 161                                                   []
# 162    [document.getElementById, google.maps.Map, goo...
# Name: functions, dtype: object

# %%
import itertools
import pandas as pd

overall_phase2_bogota3 = overall_phase2_bogota3[overall_phase2_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_bogota3["functions"], overall_phase2_bogota3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#              user1               user2  similarity
# 0        lemartinp           juligarji    0.244186
# 1        lemartinp           nfmorenog    0.107143
# 2        lemartinp           AFelipeGA    0.130435
# 3        lemartinp          mballeng91    0.530864
# 4        lemartinp            dduartec    0.101449
# ..             ...                 ...         ...
# 815  jumcorredorro        Danielsv9207    0.000000
# 816  jumcorredorro  JhonEmmanuelTorres    0.187500
# 817     feartheGru        Danielsv9207    1.000000
# 818     feartheGru  JhonEmmanuelTorres    0.000000
# 819   Danielsv9207  JhonEmmanuelTorres    0.000000
#
# [820 rows x 3 columns]

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_bogota3["functions"], overall_phase4_bogota3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#              user1               user2  similarity
# 0        lemartinp           juligarji    0.136054
# 1        lemartinp           nfmorenog    0.038647
# 2        lemartinp           AFelipeGA    0.046809
# 3        lemartinp          mballeng91    0.159184
# 4        lemartinp            dduartec    0.037037
# ..             ...                 ...         ...
# 815  jumcorredorro        Danielsv9207    0.000000
# 816  jumcorredorro  JhonEmmanuelTorres    0.200000
# 817     feartheGru        Danielsv9207    1.000000
# 818     feartheGru  JhonEmmanuelTorres    0.000000
# 819   Danielsv9207  JhonEmmanuelTorres    0.000000
#
# [820 rows x 3 columns]

# %%
import itertools
import pandas as pd

overall_phase5_bogota3 = overall_phase5_bogota3[overall_phase5_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_bogota3["functions"], overall_phase5_bogota3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#              user1               user2  similarity
# 0        lemartinp           juligarji    0.138983
# 1        lemartinp           nfmorenog    0.066038
# 2        lemartinp           AFelipeGA    0.050847
# 3        lemartinp          mballeng91    0.167910
# 4        lemartinp            dduartec    0.036649
# ..             ...                 ...         ...
# 815  jumcorredorro        Danielsv9207    0.000000
# 816  jumcorredorro  JhonEmmanuelTorres    0.139535
# 817     feartheGru        Danielsv9207    1.000000
# 818     feartheGru  JhonEmmanuelTorres    0.000000
# 819   Danielsv9207  JhonEmmanuelTorres    0.000000
#
# [820 rows x 3 columns]

# %% [markdown]
# ## Subset Bogota 0 Phase 5

# %%
import numpy as np
overall_phase5_bogota0['phase'] = 5
overall_phase5_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase5_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase5 = overall_phase5_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase5
# Out:
#            Student                                          functions  phase
# 0        fffeelipe                                                 []      5
# 1        mnguzmanc  [style.css, .Chicago, document.getElementById,...      5
# 2       jmcuestasb  [.css, bootstrap.min.css, freelancer.min.css, ...      5
# 3       katherinsb  [.css, awesome.min.css, latest.min.js, room.js...      5
# 4     jjrodriguezn  [bootstrap.min.css, style.css, jquery.min.js, ...      5
# 5            DglyP  [main.js, google.maps.Map, document.getElement...      5
# 6           cap182  [.l, morado.jpg, a.active, .active, google.map...      5
# 8      Judgarciani  [bootstrap.min.css, data.json, jquery.min.js, ...      5
# 9        sacastroc  [bootstrap.min.css, awesome.min.css, grayscale...      5
# 10       pcberriop  [bootstrap.min.css, main.css, .jpg, jane.doe, ...      5
# 11     hsmartineza  [bootstrap.min.css, portfolio.css, awesome.min...      5
# 12        Moimolcp                                                 []      5
# 13     CamiloRueda  [up.net, main.css, .css, noscript.css, chicago...      5
# 14       juanescai  [document.getElementById, google.maps.Map, goo...      5
# 15      JoseMolano                                                 []      5
# 16   maikellPardoA                                                 []      5
# 17      NicolasZon  [latest.min.js, jquery.min.js, food.js, opcion...      5
# 18       camilo654  [latest.min.js, jquery.min.js, bootstrap.min.c...      5
# 19  CristianLozano  [jquery.min.js, stylesheet.css, main.js, lates...      5
# 20       jdsuarezj  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      5
# 21       pipemax85  [Map.js, .js, main.css, avatar.jpg, pcberriop....      5
# 22     juandavidro  [gl.css, semantic.min.css, calendar.min.css, s...      5
# 23  UNhcrodriguezl  [document.getElementById, .innerHTML, google.m...      5
# 24     camilo13152  [home.css, search.css, favicon.jpg, .js, js.or...      5
# 25    leavendanoro  [bootstrap.min.css, style.css, .container, scr...      5
# 26      cdcordobaa                                                 []      5
# 27      capinillab  [awesome.min.css, CSS.css, jquery.min.js, Java...      5
# 29    lfvalderrama  [bootstrap.min.css, jquery.min.js, .js, js.org...      5
# 30       bsgarciac  [bootstrap.min.css, awesome.min.css, icons.css...      5
# 31          gabi04  [bootstrap.min.css, style.css, jquery.min.js, ...      5
# 32          annipi  [.css, jquery.min.js, Mapa.js, .js, style.css,...      5
# 33       jdsolanos  [favicon.ico, bootstrap.min.css, awesome.css, ...      5
# 34        jcneivaa                                                 []      5
# 35       fmbernalb  [bootstrap.min.css, style.css, bulk.jpg, jquer...      5
# 36         MogGy94  [.mifecha, bootstrap.min.css, theme.min.css, j...      5
# 37       yocuervoc  [document.getElementById, google.maps.Map, goo...      5
# 38       odprietoh  [bootstrap.min.css, style.css, script.js, data...      5

# %% [markdown]
# ## Subset Bogota 0 Phase 4

# %%
import numpy as np
overall_phase4_bogota0['phase'] = 4
overall_phase4_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase4_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase4 = overall_phase4_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase4
# Out:
#            Student                                          functions  phase
# 0        fffeelipe                                                 []      4
# 1        mnguzmanc  [style.css, .Chicago, document.getElementById,...      4
# 2       jmcuestasb  [.css, bootstrap.min.css, freelancer.min.css, ...      4
# 3       katherinsb  [.css, awesome.min.css, latest.min.js, room.js...      4
# 4     jjrodriguezn  [bootstrap.min.css, style.css, jquery.min.js, ...      4
# 5            DglyP  [main.js, google.maps.Map, document.getElement...      4
# 6           cap182  [.l, morado.jpg, a.active, .active, google.map...      4
# 8      Judgarciani  [bootstrap.min.css, jquery.min.js, bootstrap.m...      4
# 9        sacastroc  [bootstrap.min.css, awesome.min.css, grayscale...      4
# 10       pcberriop  [bootstrap.min.css, main.css, .jpg, jane.doe, ...      4
# 11     hsmartineza  [bootstrap.min.css, portfolio.css, awesome.min...      4
# 12        Moimolcp                                                 []      4
# 13     CamiloRueda  [up.net, main.css, .css, noscript.css, chicago...      4
# 14       juanescai  [document.getElementById, google.maps.Map, goo...      4
# 15      JoseMolano  [window.setTimeout, google.maps.MarkerImage, g...      4
# 16   maikellPardoA                                                 []      4
# 17      NicolasZon  [latest.min.js, jquery.min.js, food.js, opcion...      4
# 18       camilo654  [latest.min.js, jquery.min.js, bootstrap.min.c...      4
# 19  CristianLozano  [jquery.min.js, stylesheet.css, main.js, lates...      4
# 20       jdsuarezj  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      4
# 21       pipemax85  [jquery.min.js, Map.js, main.css, avatar.jpg, ...      4
# 22     juandavidro  [semantic.min.css, calendar.min.css, styles.cs...      4
# 23  UNhcrodriguezl  [document.getElementById, .innerHTML, google.m...      4
# 24     camilo13152  [home.css, search.css, favicon.jpg, .js, js.or...      4
# 25    leavendanoro  [bootstrap.min.css, style.css, .container, scr...      4
# 26      cdcordobaa                                                 []      4
# 27      capinillab  [awesome.min.css, CSS.css, jquery.min.js, Java...      4
# 29    lfvalderrama  [bootstrap.min.css, jquery.min.js, .js, js.org...      4
# 30       bsgarciac  [bootstrap.min.css, awesome.min.css, icons.css...      4
# 31          gabi04  [bootstrap.min.css, style.css, jquery.min.js, ...      4
# 32          annipi  [style.css, document.getElementById, google.ma...      4
# 33       jdsolanos  [favicon.ico, bootstrap.min.css, awesome.css, ...      4
# 34        jcneivaa                                                 []      4
# 35       fmbernalb  [bootstrap.min.css, style.css, bulk.jpg, jquer...      4
# 36         MogGy94                                                 []      4
# 37       yocuervoc  [document.getElementById, google.maps.Map, goo...      4
# 38       odprietoh  [bootstrap.min.css, style.css, script.js, jque...      4

# %% [markdown]
# ## Subset Bogota 0 Phase 3

# %%
import numpy as np
overall_phase3_bogota0['phase'] = 3
overall_phase3_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase3_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase3 = overall_phase3_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase3
# Out:
#            Student                                          functions  phase
# 0        fffeelipe                                                 []      3
# 1        mnguzmanc  [style.css, .Chicago, document.getElementById,...      3
# 2       jmcuestasb  [bootstrap.min.css, freelancer.min.css, style....      3
# 3       katherinsb  [.css, awesome.min.css, latest.min.js, room.js...      3
# 4     jjrodriguezn  [bootstrap.min.css, style.css, script.js, unal...      3
# 5            DglyP  [main.js, google.maps.Map, document.getElement...      3
# 6           cap182  [.l, morado.jpg, a.active, .active, google.map...      3
# 8      Judgarciani  [page.php, google.maps.Map, document.getElemen...      3
# 9        sacastroc  [bootstrap.min.css, awesome.min.css, grayscale...      3
# 10       pcberriop  [bootstrap.min.css, profile.css, rid.css, goog...      3
# 11     hsmartineza  [bootstrap.min.css, portfolio.css, awesome.min...      3
# 12        Moimolcp                                                 []      3
# 13     CamiloRueda  [up.net, main.css, .css, noscript.css, chicago...      3
# 14       juanescai  [document.getElementById, google.maps.Map, goo...      3
# 15      JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....      3
# 16   maikellPardoA                                                 []      3
# 17      NicolasZon  [latest.min.js, jquery.min.js, food.js, rents....      3
# 18       camilo654  [latest.min.js, jquery.min.js, bootstrap.min.c...      3
# 19  CristianLozano  [jquery.min.js, stylesheet.css, main.js, lates...      3
# 20       jdsuarezj  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      3
# 21       pipemax85  [jquery.min.js, bootstrap.min.js, Map.js, main...      3
# 22     juandavidro  [semantic.min.css, calendar.min.css, styles.cs...      3
# 23  UNhcrodriguezl  [document.getElementById, .innerHTML, google.m...      3
# 24     camilo13152  [home.css, search.css, favicon.jpg, logo.jpg, ...      3
# 25    leavendanoro  [bootstrap.min.css, style.css, .container, dat...      3
# 26      cdcordobaa                                                 []      3
# 27      capinillab  [awesome.min.css, CSS.css, jquery.min.js, Java...      3
# 29    lfvalderrama  [bootstrap.min.css, jquery.min.js, .js, js.org...      3
# 30       bsgarciac  [bootstrap.min.css, awesome.min.css, icons.css...      3
# 31          gabi04  [.ready, .click, .ajax, console.log, result.re...      3
# 32          annipi  [document.getElementById, google.maps.Map, goo...      3
# 33       jdsolanos  [favicon.ico, bootstrap.min.css, awesome.css, ...      3
# 34        jcneivaa                                                 []      3
# 35       fmbernalb  [bootstrap.min.css, style.css, farmermarket.st...      3
# 36         MogGy94                                                 []      3
# 37       yocuervoc  [document.getElementById, google.maps.Map, goo...      3
# 38       odprietoh  [bootstrap.min.css, style.css, script.js, jque...      3

# %% [markdown]
# ## Subset Bogota 0 Phase 2

# %%
import numpy as np
overall_phase2_bogota0['phase'] = 2
overall_phase2_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase2_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase2 = overall_phase2_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase2
# Out:
#            Student                                          functions  phase
# 0        fffeelipe                                                 []      2
# 1        mnguzmanc  [style.css, .Chicago, document.getElementById,...      2
# 2       jmcuestasb  [bootstrap.min.css, freelancer.min.css, style....      2
# 3       katherinsb  [.css, awesome.min.css, latest.min.js, room.js...      2
# 4     jjrodriguezn  [bootstrap.min.css, style.css, script.js, unal...      2
# 5            DglyP  [main.js, google.maps.Map, document.getElement...      2
# 6           cap182  [.l, morado.jpg, a.active, .active, google.map...      2
# 8      Judgarciani  [page.php, google.maps.Map, document.getElemen...      2
# 9        sacastroc  [bootstrap.min.css, awesome.min.css, grayscale...      2
# 10       pcberriop  [bootstrap.min.css, blueberry.css, main.css, j...      2
# 11     hsmartineza  [bootstrap.min.css, portfolio.css, awesome.min...      2
# 12        Moimolcp                                                 []      2
# 13     CamiloRueda  [bootstrap.min.css, map.js, jquery.min.js, boo...      2
# 14       juanescai  [document.getElementById, google.maps.Map, goo...      2
# 15      JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 16   maikellPardoA                                                 []      2
# 17      NicolasZon  [latest.min.js, jquery.min.js, clear.js, food....      2
# 18       camilo654  [bootstrap.min.css, dashboard.css, styles.css,...      2
# 19  CristianLozano  [jquery.min.js, stylesheet.css, main.js, googl...      2
# 20       jdsuarezj  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      2
# 21       pipemax85  [jquery.min.js, bootstrap.min.js, Map.js, main...      2
# 22     juandavidro  [semantic.min.css, styles.css, .min.js, bootst...      2
# 23  UNhcrodriguezl  [document.getElementById, google.maps.Map, goo...      2
# 24     camilo13152  [home.css, search.css, favicon.jpg, logo.jpg, ...      2
# 25    leavendanoro  [bootstrap.min.css, style.css, .container, dat...      2
# 26      cdcordobaa                                                 []      2
# 27      capinillab  [awesome.min.css, CSS.css, jquery.min.js, Java...      2
# 29    lfvalderrama  [bootstrap.min.css, jquery.min.js, .js, js.org...      2
# 30       bsgarciac  [bootstrap.min.css, awesome.min.css, icons.css...      2
# 31          gabi04  [.ready, .click, .ajax, console.log, result.re...      2
# 32          annipi  [document.getElementById, google.maps.Map, goo...      2
# 33       jdsolanos  [favicon.ico, bootstrap.min.css, awesome.css, ...      2
# 34        jcneivaa                                                 []      2
# 35       fmbernalb  [bootstrap.min.css, style.css, farmermarket.st...      2
# 36         MogGy94                                                 []      2
# 37       yocuervoc  [document.getElementById, google.maps.Map, goo...      2
# 38       odprietoh  [style.css, script.js, jquery.min.js, google.m...      2

# %% [markdown]
# ## Subset Bogota 0 Phase 1

# %%
import numpy as np
overall_phase1_bogota0['phase'] = 1
overall_phase1_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase1_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase1 = overall_phase1_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase1
# Out:
#            Student                                          functions  phase
# 0        fffeelipe                                                 []      1
# 1        mnguzmanc                              [style.css, .Chicago]      1
# 2       jmcuestasb  [bootstrap.min.css, freelancer.min.css, style....      1
# 3       katherinsb  [.css, awesome.min.css, .w, google.maps.Map, d...      1
# 4     jjrodriguezn  [bootstrap.min.css, style.css, unal.edu.co, .n...      1
# 5            DglyP                                                 []      1
# 6           cap182  [.l, .active, plupa.jpg, lupa.jpg, google.maps...      1
# 8      Judgarciani         [google.maps.Map, document.getElementById]      1
# 9        sacastroc  [bootstrap.min.css, awesome.min.css, grayscale...      1
# 10       pcberriop  [blueberry.css, main.css, jquery.min.js, jquer...      1
# 11     hsmartineza  [bootstrap.min.css, portfolio.css, awesome.min...      1
# 12        Moimolcp                                                 []      1
# 13     CamiloRueda  [bootstrap.min.css, map.js, jquery.min.js, boo...      1
# 14       juanescai  [document.getElementById, google.maps.Map, goo...      1
# 15      JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 16   maikellPardoA                                                 []      1
# 17      NicolasZon  [latest.min.js, jquery.min.js, rent.js, js.org...      1
# 18       camilo654  [bootstrap.min.css, dashboard.css, styles.css,...      1
# 19  CristianLozano  [stylesheet.css, main.js, document.getElementB...      1
# 20       jdsuarezj  [gl.js, .min.js, js.org, .v, gl.css, awesome.m...      1
# 21       pipemax85  [jquery.min.js, bootstrap.min.js, Map.js, styl...      1
# 22     juandavidro  [semantic.min.css, styles.css, .min.js, jquery...      1
# 23  UNhcrodriguezl  [document.getElementById, google.maps.Map, goo...      1
# 24     camilo13152                                                 []      1
# 25    leavendanoro  [bootstrap.min.css, style.css, script.js, .con...      1
# 26      cdcordobaa                                                 []      1
# 27      capinillab  [awesome.min.css, CSS.css, jquery.min.js, Java...      1
# 29    lfvalderrama  [bootstrap.min.css, jquery.min.js, .js, js.org...      1
# 30       bsgarciac  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 31          gabi04           [bootstrap.min.css, style.css, .JS, .js]      1
# 32          annipi  [document.getElementById, google.maps.Map, goo...      1
# 33       jdsolanos  [favicon.ico, bootstrap.min.css, awesome.css, ...      1
# 34        jcneivaa                                                 []      1
# 35       fmbernalb  [bootstrap.min.css, style.css, jquery.min.js, ...      1
# 36         MogGy94                                        [style.css]      1
# 37       yocuervoc  [document.getElementById, google.maps.Map, goo...      1
# 38       odprietoh  [style.css, script.js, jquery.min.js, google.m...      1

# %% [markdown]
# ## Subset Bogota 1 Phase 5

# %%
import numpy as np
overall_phase5_bogota1['phase'] = 5
overall_phase5_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase5_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase5 = overall_phase5_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase5
# Out:
#            Student                                          functions  phase
# 39       gasierram  [layout.css, shiv.js, document.getElementById,...      5
# 40    adamantwharf                                                 []      5
# 41       bdcajicam  [custom.css, .css, awesome.min.css, jquery.min...      5
# 42  andfsanchezlem  [.css, style.css, bootstrap.css, balloon.css, ...      5
# 43     dfhincapiem  [jquery.min.js, .js, map.js, house.js, weather...      5
# 44       helmeraac  [navicon.jpg, style.css, document.getElementBy...      5
# 45      dasalgadob  [Error.stackTraceLimit, jasmine.DEFAULT, karma...      5
# 46      falperezgo  [bootstrap.min.css, theme.min.css, jquery.min....      5
# 47       djguzmanc  [chicagoicon.ico, styles.css, jquery.min.js, j...      5
# 48      gsuarezc04  [bootstrap.min.css, styles.css, jquery.min.js,...      5
# 49          oeroaq  [main.css, bootstrap.min.css, awesome.min.css,...      5
# 50         gcantem  [bootstrap.min.css, theme.min.css, jquery.min....      5
# 51     Semoralesga  [.css, .js, js.org, .v, bootstrap.min.css, the...      5
# 52      jonatan360                                                 []      5
# 53  jesusfchavarro                         [.js, jsInitMap.js, .ajax]      5
# 54    stevenbustos  [Style.css, .min.js, js.org, .v, map.js, Clima...      5
# 55  jufcontrerasco  [google.maps.LatLng, google.maps.MapTypeId.ROA...      5
# 56      dsbarrerag                                                 []      5
# 57       wolfstain  [bootstrap.min.css, theme.min.css, awesome.min...      5
# 58      miaborjaac  [bootstrap.min.css, theme.min.css, jquery.min....      5
# 59   ivdgonzalezco  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      5
# 60    maikellPardo  [style.css, bootstrap.min.css, theme.min.css, ...      5
# 61    Christian7sr  [awesome.min.css, bootstrap.min.css, style.css...      5
# 62      jsnarvaezb  [document.getElementById, google.maps.Map, goo...      5
# 63   gfalbarracinr  [bootstrap.min.css, style.css, bootstrap.min.j...      5
# 64        aldiazve  [tiry.cloudfront.net, foundation.min.css, styl...      5
# 65  diegoaguevarar  [bootstrap.css, .js, bootstrap.js, logic.js, u...      5
# 66      fevargasmo  [styles.css, script.js, bootstrap.min.css, sit...      5
# 67      jmhurtadoc  [bootstrap.min.css, balloon.min.css, freelance...      5
# 68     anfmorenoso                                                 []      5
# 69     nabautistal                                                 []      5
# 70          crigar  [style.css, jquery.min.js, distanceFunc.js, ge...      5
# 71     jiapulidoar  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      5
# 72       jsviveroj  [jquery.min.js, bootstrap.min.js, tutorial.css...      5
# 73      daandradec  [jmalvarezd.js, bootstrap.min.css, jquery.min....      5
# 74        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      5
# 75  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      5
# 76         ItsNavi  [mapController.js, favicon.ico, fluidbox.min.c...      5
# 77         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      5
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      5

# %% [markdown]
# ## Subset Bogota 1 Phase 4

# %%
import numpy as np
overall_phase4_bogota1['phase'] = 4
overall_phase4_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase4_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase4 = overall_phase4_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase4
# Out:
#            Student                                          functions  phase
# 39       gasierram  [layout.css, shiv.js, document.getElementById,...      4
# 40    adamantwharf                                                 []      4
# 41       bdcajicam  [.CSS, custom.css, .css, awesome.min.css, jque...      4
# 42  andfsanchezlem  [.css, style.css, bootstrap.css, balloon.css, ...      4
# 43     dfhincapiem  [jquery.min.js, .js, map.js, house.js, weather...      4
# 44       helmeraac  [navicon.jpg, style.css, document.getElementBy...      4
# 45      dasalgadob  [Error.stackTraceLimit, jasmine.DEFAULT, karma...      4
# 46      falperezgo  [bootstrap.min.css, theme.min.css, jquery.min....      4
# 47       djguzmanc  [styles.css, jquery.min.js, js.org, .v, .min.j...      4
# 48      gsuarezc04  [bootstrap.min.css, styles.css, jquery.min.js,...      4
# 49          oeroaq  [main.css, bootstrap.min.css, awesome.min.css,...      4
# 50         gcantem  [bootstrap.min.css, theme.min.css, jquery.min....      4
# 51     Semoralesga  [.css, .js, js.org, .v, bootstrap.min.css, the...      4
# 52      jonatan360                                                 []      4
# 53  jesusfchavarro                         [.js, jsInitMap.js, .ajax]      4
# 54    stevenbustos  [Style.css, .min.js, js.org, .v, map.js, Clima...      4
# 55  jufcontrerasco  [google.maps.LatLng, google.maps.MapTypeId.ROA...      4
# 56      dsbarrerag                                                 []      4
# 57       wolfstain  [bootstrap.min.css, theme.min.css, awesome.min...      4
# 58      miaborjaac  [js.org, .v, .min.js, collection.v, dispatch.v...      4
# 59   ivdgonzalezco  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      4
# 60    maikellPardo  [style.css, bootstrap.min.css, theme.min.css, ...      4
# 61    Christian7sr  [awesome.min.css, bootstrap.min.css, style.css...      4
# 62      jsnarvaezb  [document.getElementById, google.maps.Map, goo...      4
# 63   gfalbarracinr  [bootstrap.min.css, style.css, bootstrap.min.j...      4
# 64        aldiazve  [tiry.cloudfront.net, foundation.min.css, styl...      4
# 65  diegoaguevarar  [bootstrap.css, .js, bootstrap.js, logic.js, u...      4
# 66      fevargasmo  [styles.css, script.js, bootstrap.min.css, sit...      4
# 67      jmhurtadoc  [bootstrap.min.css, balloon.min.css, freelance...      4
# 68     anfmorenoso                                                 []      4
# 69     nabautistal                                                 []      4
# 70          crigar  [style.css, jquery.min.js, distanceFunc.js, ge...      4
# 71     jiapulidoar  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      4
# 72       jsviveroj  [jquery.min.js, bootstrap.min.js, tutorial.css...      4
# 73      daandradec  [jmalvarezd.js, bootstrap.min.css, jquery.min....      4
# 74        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      4
# 75  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      4
# 76         ItsNavi  [mapController.js, favicon.ico, fluidbox.min.c...      4
# 77         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      4
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      4

# %% [markdown]
# ## Subset Bogota 1 Phase 3

# %%
import numpy as np
overall_phase3_bogota1['phase'] = 3
overall_phase3_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase3_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase3 = overall_phase3_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase3
# Out:
#            Student                                          functions  phase
# 39       gasierram  [layout.css, shiv.js, document.getElementById,...      3
# 40    adamantwharf                                                 []      3
# 41       bdcajicam  [.CSS, custom.css, .css, awesome.min.css, jque...      3
# 42  andfsanchezlem  [style.css, bootstrap.css, balloon.css, jquery...      3
# 43     dfhincapiem  [jquery.min.js, .js, map.js, info.js, test.js,...      3
# 44       helmeraac  [navicon.jpg, style.css, document.getElementBy...      3
# 45      dasalgadob  [Error.stackTraceLimit, jasmine.DEFAULT, karma...      3
# 46      falperezgo  [bootstrap.min.css, theme.min.css, jquery.min....      3
# 47       djguzmanc  [styles.css, js.org, .v, .min.js, script.js, d...      3
# 48      gsuarezc04  [bootstrap.min.css, styles.css, theme.min.css,...      3
# 49          oeroaq  [main.css, bootstrap.min.css, awesome.min.css,...      3
# 50         gcantem  [bootstrap.min.css, theme.min.css, jquery.min....      3
# 51     Semoralesga  [.css, .js, js.org, .v, bootstrap.min.css, the...      3
# 52      jonatan360                                                 []      3
# 53  jesusfchavarro                                                 []      3
# 54    stevenbustos  [Style.css, .min.js, js.org, .v, map.js, Clima...      3
# 55  jufcontrerasco  [google.maps.LatLng, google.maps.MapTypeId.ROA...      3
# 56      dsbarrerag                                                 []      3
# 57       wolfstain  [bootstrap.min.css, theme.min.css, awesome.min...      3
# 58      miaborjaac  [js.org, .v, .min.js, collection.v, dispatch.v...      3
# 59   ivdgonzalezco  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      3
# 60    maikellPardo  [style.css, bootstrap.min.css, theme.min.css, ...      3
# 61    Christian7sr  [awesome.min.css, bootstrap.min.css, style.css...      3
# 62      jsnarvaezb  [document.getElementById, google.maps.Map, goo...      3
# 63   gfalbarracinr  [bootstrap.min.css, style.css, bootstrap.min.j...      3
# 64        aldiazve  [tiry.cloudfront.net, foundation.min.css, styl...      3
# 65  diegoaguevarar  [bootstrap.css, .js, bootstrap.js, google.maps...      3
# 66      fevargasmo  [styles.css, script.js, bootstrap.min.css, sit...      3
# 67      jmhurtadoc  [bootstrap.min.css, freelancer.css, custom.css...      3
# 68     anfmorenoso                                                 []      3
# 69     nabautistal                                                 []      3
# 70          crigar  [style.css, .jpg, google.maps.LatLng, google.m...      3
# 71     jiapulidoar  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      3
# 72       jsviveroj  [jquery.min.js, bootstrap.min.js, tutorial.css...      3
# 73      daandradec  [jmalvarezd.js, bootstrap.min.css, jquery.min....      3
# 74        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      3
# 75  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      3
# 76         ItsNavi  [mapController.js, favicon.ico, fluidbox.min.c...      3
# 77         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      3
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      3

# %% [markdown]
# ## Subset Bogota 2 Phase 2

# %%
import numpy as np
overall_phase2_bogota1['phase'] = 2
overall_phase2_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase2_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase2 = overall_phase2_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase2
# Out:
#            Student                                          functions  phase
# 39       gasierram  [layout.css, shiv.js, document.getElementById,...      2
# 40    adamantwharf                                                 []      2
# 41       bdcajicam  [.CSS, custom.css, .css, awesome.min.css, jque...      2
# 42  andfsanchezlem  [style.css, bootstrap.css, jquery.js, bootstra...      2
# 43     dfhincapiem  [jquery.min.js, .js, info.js, chicago.jpg, doc...      2
# 44       helmeraac  [navicon.jpg, style.css, document.getElementBy...      2
# 45      dasalgadob  [Error.stackTraceLimit, jasmine.DEFAULT, karma...      2
# 46      falperezgo  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 47       djguzmanc  [styles.css, js.org, .v, .min.js, myArrayOfObj...      2
# 48      gsuarezc04  [bootstrap.min.css, styles.css, theme.min.css,...      2
# 49          oeroaq  [main.css, bootstrap.min.css, awesome.min.css,...      2
# 50         gcantem  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 51     Semoralesga  [.css, .js, js.org, .v, bootstrap.min.css, the...      2
# 52      jonatan360                                                 []      2
# 53  jesusfchavarro                                                 []      2
# 54    stevenbustos  [Style.css, .min.js, js.org, .v, map.js, Clima...      2
# 55  jufcontrerasco  [google.maps.LatLng, google.maps.MapTypeId.ROA...      2
# 56      dsbarrerag                                                 []      2
# 57       wolfstain  [bootstrap.min.css, theme.min.css, awesome.min...      2
# 58      miaborjaac  [js.org, .v, .min.js, collection.v, dispatch.v...      2
# 59   ivdgonzalezco  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      2
# 60    maikellPardo  [style.css, bootstrap.min.css, theme.min.css, ...      2
# 61    Christian7sr  [awesome.min.css, bootstrap.min.css, style.css...      2
# 62      jsnarvaezb  [document.getElementById, google.maps.Map, goo...      2
# 63   gfalbarracinr  [bootstrap.min.css, style.css, bootstrap.min.j...      2
# 64        aldiazve  [tiry.cloudfront.net, foundation.min.css, styl...      2
# 65  diegoaguevarar  [templates.asp, bootstrap.min.css, jquery.min....      2
# 66      fevargasmo  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 67      jmhurtadoc  [bootstrap.min.css, freelancer.css, custom.css...      2
# 68     anfmorenoso                                                 []      2
# 69     nabautistal                                                 []      2
# 70          crigar  [style.css, .jpg, google.maps.LatLng, google.m...      2
# 71     jiapulidoar  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      2
# 72       jsviveroj  [jquery.min.js, bootstrap.min.js, tutorial.css...      2
# 73      daandradec  [jmalvarezd.js, bootstrap.min.css, jquery.min....      2
# 74        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      2
# 75  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      2
# 76         ItsNavi  [favicon.ico, fluidbox.min.css, main.css, goog...      2
# 77         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      2
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      2

# %% [markdown]
# ## Subset Bogota 1 Phase 1

# %%
import numpy as np
overall_phase1_bogota1['phase'] = 1
overall_phase1_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase1_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase1 = overall_phase1_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase1
# Out:
#            Student                                          functions  phase
# 39       gasierram                                                 []      1
# 40    adamantwharf                                                 []      1
# 41       bdcajicam  [.CSS, .css, awesome.min.css, .mySlides, page....      1
# 42  andfsanchezlem  [style.css, bootstrap.min.css, jquery.js, boot...      1
# 43     dfhincapiem  [jquery.min.js, .js, info.js, document.getElem...      1
# 44       helmeraac  [navicon.jpg, style.css, document.getElementBy...      1
# 45      dasalgadob  [Error.stackTraceLimit, jasmine.DEFAULT, karma...      1
# 46      falperezgo  [document.getElementById, google.maps.Map, goo...      1
# 47       djguzmanc  [styles.css, script.js, js.org, .v, .min.js, d...      1
# 48      gsuarezc04  [bootstrap.min.css, styles.css, theme.min.css,...      1
# 49          oeroaq  [main.css, bootstrap.min.css, jquery.min.js, b...      1
# 50         gcantem  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 51     Semoralesga  [.css, .js, js.org, .v, bootstrap.min.css, the...      1
# 52      jonatan360                                                 []      1
# 53  jesusfchavarro                                                 []      1
# 54    stevenbustos  [Style.css, .min.js, js.org, .v, map.js, Clima...      1
# 55  jufcontrerasco                                                 []      1
# 56      dsbarrerag                                                 []      1
# 57       wolfstain  [bootstrap.min.css, theme.min.css, Aux.css, ma...      1
# 58      miaborjaac  [js.org, .v, .min.js, bootstrap.min.css, theme...      1
# 59   ivdgonzalezco  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      1
# 60    maikellPardo  [style.css, main.js, bootstrap.min.css, theme....      1
# 61    Christian7sr  [awesome.min.css, bootstrap.min.css, style.css...      1
# 62      jsnarvaezb  [document.getElementById, google.maps.Map, goo...      1
# 63   gfalbarracinr  [bootstrap.min.css, theme.min.css, bootstrap.m...      1
# 64        aldiazve  [tiry.cloudfront.net, foundation.min.css, chic...      1
# 65  diegoaguevarar  [.flex, .nav, .article, bootstrap.min.css, the...      1
# 66      fevargasmo  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 67      jmhurtadoc  [bootstrap.min.css, freelancer.min.css, custom...      1
# 68     anfmorenoso                                                 []      1
# 69     nabautistal                                                 []      1
# 70          crigar                                                 []      1
# 71     jiapulidoar  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      1
# 72       jsviveroj  [jquery.min.js, bootstrap.min.js, tutorial.css...      1
# 73      daandradec  [jmalvarezd.js, jquery.min.js, bootstrap.min.c...      1
# 74        jcrubioa  [demos.css, bootstrap.min.css, style.css, map....      1
# 75  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      1
# 76         ItsNavi  [.js, .css, this.App, App.cable, ActionCable.c...      1
# 77         Zeugmax  [bootstrap.min.css, .min.js, bootstrap.min.js,...      1
# 79    JairVillalba  [bootstrap.min.css, modifier.css, js.org, .v, ...      1

# %%
import numpy as np
overall_phase5_bogota2['phase'] = 5
overall_phase5_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase5_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase5 = overall_phase5_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase5
# Out:
#              Student                                          functions  phase
# 80      jusherrerama  [this.value, this.name, window.location.reload...      5
# 81           bdvegat  [estilos.css, icon.ico, Etxea.js, document.get...      5
# 82        Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      5
# 83          HashNick  [fH.css, jquery.min.js, .js, call.js, climate....      5
# 84           ccvacad  [nearium.css, .js, nearium.js, google.maps.Map...      5
# 85        joaortizro  [bootstrap.min.css, style.css, jquery.min.js, ...      5
# 86   juasmartinezbel  [jquery.min.js, bootstrap.min.js, .js, script....      5
# 87          mdbelloc  [js.org, .v, .min.js, weather.js, myss.css, bo...      5
# 88       diegocruz10  [estilos.css, jquery.min.js, functions.js, .v,...      5
# 89        crarojasca  [bootstrap.min.css, .js, js.js, .ready, .click...      5
# 90            sagilm                                                 []      5
# 91          idrojasf  [up.net, main.css, bootstrap.min.css, jquery.m...      5
# 92      raulramirezp  [bootstrap.min.css, awesome.min.css, app.css, ...      5
# 93         fabianr23                                                 []      5
# 94        jhriverasa  [bootstrap.min.css, jquery.min.js, bootstrap.m...      5
# 95        jhonsd1996  [document.getElementById, google.maps.Map, goo...      5
# 96        JuanitoAli  [bootstrap.min.css, estilos.css, script.js, fo...      5
# 97        Davsatu313  [body.css, favicon.ico, js.org, .v, .min.js, p...      5
# 98    cesarochoa2006                                                 []      5
# 99         jjmuesesq  [style.css, favicon.ico, bootstrap.min.css, th...      5
# 100     jucjimenezmo  [reset.css, layout.css, style.css, jquery.fanc...      5
# 101           kancas  [bootstrap.min.css, main.css, data.cityofchica...      5
# 102          Gantiva  [google.maps.Map, document.getElementById, goo...      5
# 103       Dandarprox                                                 []      5
# 104       debeltranc                                                 []      5
# 105        ykchautai                                                 []      5
# 106        ligibrial  [styles.css, blocks.css, bootstrap.min.css, th...      5
# 107       davidrh195  [weather.js, style.css, api.openweathermap.org...      5
# 108      JulianaNino                                                 []      5
# 109         luegilca  [a.active, .active, document.getElementById, g...      5
# 110           Yelis3  [style.css, bootstrap.min.css, .js, scripts.js...      5
# 111        begarzonf  [style.css, main.js, document.getElementById, ...      5
# 112       kmendezp96  [styles.css, bootstrap.min.css, jquery.min.js,...      5
# 113         leguzman  [bootstrap.min.css, main.js, jquery.min.js, do...      5
# 114     luealfonsoru  [bootstrap.min.css, awesome.min.css, animate.c...      5
# 115         oserasoa  [.ready, .click, .css, .removeClass, .is, .val...      5
# 116         lsfinite                                                 []      5
# 117        xdanielsb  [house.ico, style.css, .css, main.js, map.js, ...      5
# 118      CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      5
# 119      jhcardenasa                                                 []      5
# 121     jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      5

# %%
import numpy as np
overall_phase4_bogota2['phase'] = 4
overall_phase4_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase4_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase4 = overall_phase4_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase4
# Out:
#              Student                                          functions  phase
# 80      jusherrerama  [this.value, this.name, window.location.reload...      4
# 81           bdvegat  [estilos.css, icon.ico, Etxea.js, document.get...      4
# 82        Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      4
# 83          HashNick  [fH.css, jquery.min.js, .js, call.js, climate....      4
# 84           ccvacad  [nearium.css, .js, nearium.js, google.maps.Map...      4
# 85        joaortizro  [bootstrap.min.css, style.css, jquery.min.js, ...      4
# 86   juasmartinezbel  [jquery.min.js, bootstrap.min.js, .js, script....      4
# 87          mdbelloc  [js.org, .v, .min.js, weather.js, mycss.css, b...      4
# 88       diegocruz10  [estilos.css, jquery.min.js, functions.js, .v,...      4
# 89        crarojasca  [.ready, .click, .ajax, data.cityofchicago.org...      4
# 90            sagilm                                                 []      4
# 91          idrojasf  [up.net, main.css, bootstrap.min.css, jquery.m...      4
# 92      raulramirezp  [bootstrap.min.css, awesome.min.css, app.css, ...      4
# 93         fabianr23                                                 []      4
# 94        jhriverasa  [bootstrap.min.css, jquery.min.js, bootstrap.m...      4
# 95        jhonsd1996  [document.getElementById, google.maps.Map, goo...      4
# 96        JuanitoAli  [bootstrap.min.css, estilos.css, script.js, do...      4
# 97        Davsatu313  [body.css, favicon.ico, js.org, .v, .min.js, p...      4
# 98    cesarochoa2006                                                 []      4
# 99         jjmuesesq  [style.css, favicon.ico, bootstrap.min.css, th...      4
# 100     jucjimenezmo  [reset.css, layout.css, style.css, jquery.fanc...      4
# 101           kancas  [bootstrap.min.css, main.css, bundle.js, main....      4
# 102          Gantiva  [google.maps.Map, document.getElementById, goo...      4
# 103       Dandarprox                                                 []      4
# 104       debeltranc                                                 []      4
# 105        ykchautai                                                 []      4
# 106        ligibrial  [styles.css, blocks.css, bootstrap.min.css, th...      4
# 107       davidrh195  [weather.js, style.css, api.openweathermap.org...      4
# 108      JulianaNino                                                 []      4
# 109         luegilca  [a.active, .active, document.getElementById, g...      4
# 110           Yelis3  [style.css, bootstrap.min.css, .js, scripts.js...      4
# 111        begarzonf  [style.css, main.js, document.getElementById, ...      4
# 112       kmendezp96  [styles.css, bootstrap.min.css, jquery.min.js,...      4
# 113         leguzman  [bootstrap.min.css, main.js, jquery.min.js, do...      4
# 114     luealfonsoru  [bootstrap.min.css, awesome.min.css, animate.c...      4
# 115         oserasoa  [.ready, .click, .removeClass, .is, .val, .che...      4
# 116         lsfinite                                                 []      4
# 117        xdanielsb  [house.ico, style.css, .css, main.js, map.js, ...      4
# 118      CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      4
# 119      jhcardenasa                                                 []      4
# 121     jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      4

# %%
import numpy as np
overall_phase3_bogota2['phase'] = 3
overall_phase3_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase3_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase3 = overall_phase3_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase3
# Out:
#              Student                                          functions  phase
# 80      jusherrerama  [this.value, this.name, document.getElementByI...      3
# 81           bdvegat  [estilos.css, icon.ico, Etxea.js, document.get...      3
# 82        Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      3
# 83          HashNick  [fH.css, call.js, jquery.min.js, .js, this.id,...      3
# 84           ccvacad  [nearium.css, .js, nearium.js, google.maps.Map...      3
# 85        joaortizro  [bootstrap.css, style.css, jquery.min.js, code...      3
# 86   juasmartinezbel  [jquery.min.js, bootstrap.min.js, tutorial.css...      3
# 87          mdbelloc  [js.org, .v, .min.js, weather.js, mycss.css, b...      3
# 88       diegocruz10  [estilos.css, jquery.min.js, functions.js, .aj...      3
# 89        crarojasca  [.ready, .click, .ajax, data.cityofchicago.org...      3
# 90            sagilm                                                 []      3
# 91          idrojasf  [up.net, main.css, bootstrap.min.css, jquery.m...      3
# 92      raulramirezp  [bootstrap.min.css, awesome.min.css, app.css, ...      3
# 93         fabianr23                                                 []      3
# 94        jhriverasa  [bootstrap.min.css, jquery.min.js, bootstrap.m...      3
# 95        jhonsd1996  [document.getElementById, google.maps.Map, goo...      3
# 96        JuanitoAli  [bootstrap.min.css, estilos.css, script.js, do...      3
# 97        Davsatu313  [body.css, favicon.ico, google.maps.Map, docum...      3
# 98    cesarochoa2006                                                 []      3
# 99         jjmuesesq  [style.css, favicon.ico, bootstrap.min.css, th...      3
# 100     jucjimenezmo  [reset.css, layout.css, style.css, jquery.fanc...      3
# 101           kancas  [bootstrap.min.css, main.css, bundle.js, MapEx...      3
# 102          Gantiva  [google.maps.Map, document.getElementById, goo...      3
# 103       Dandarprox                                                 []      3
# 104       debeltranc                                                 []      3
# 105        ykchautai                                                 []      3
# 106        ligibrial  [styles.css, blocks.css, bootstrap.min.css, th...      3
# 107       davidrh195  [weather.js, style.css, api.openweathermap.org...      3
# 108      JulianaNino                                                 []      3
# 109         luegilca  [a.active, .active, document.getElementById, g...      3
# 110           Yelis3  [style.css, .js, scripts.js, .ready, .click, ....      3
# 111        begarzonf  [style.css, main.js, document.getElementById, ...      3
# 112       kmendezp96  [styles.css, bootstrap.min.css, jquery.min.js,...      3
# 113         leguzman  [bootstrap.min.css, main.js, jquery.min.js, do...      3
# 114     luealfonsoru  [bootstrap.min.css, awesome.min.css, animate.c...      3
# 115         oserasoa  [.ready, .click, .mcheck, .on, .closest, .list...      3
# 116         lsfinite                                                 []      3
# 117        xdanielsb  [house.ico, style.css, .css, main.js, map.js, ...      3
# 118      CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      3
# 119      jhcardenasa                                                 []      3
# 121     jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      3

# %%
import numpy as np
overall_phase2_bogota2['phase'] = 2
overall_phase2_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase2_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase2 = overall_phase2_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase2
# Out:
#              Student                                          functions  phase
# 80      jusherrerama  [this.value, this.name, document.getElementByI...      2
# 81           bdvegat                            [estilos.css, icon.ico]      2
# 82        Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      2
# 83          HashNick  [fH.css, call.js, jquery.min.js, .js, this.id,...      2
# 84           ccvacad  [google.maps.Map, document.getElementById, goo...      2
# 85        joaortizro  [bootstrap.css, style.css, jquery.min.js, code...      2
# 86   juasmartinezbel  [jquery.min.js, bootstrap.min.js, tutorial.css...      2
# 87          mdbelloc  [js.org, .v, .min.js, weather.js, mycss.css, b...      2
# 88       diegocruz10  [estilos.css, jquery.min.js, functions.js, .aj...      2
# 89        crarojasca  [.ready, .click, .ajax, data.cityofchicago.org...      2
# 90            sagilm                                                 []      2
# 91          idrojasf  [up.net, main.css, bootstrap.min.css, jquery.m...      2
# 92      raulramirezp  [.ajax, data.cityofchicago.org, y.json, .done,...      2
# 93         fabianr23                                                 []      2
# 94        jhriverasa  [bootstrap.min.css, jquery.min.js, bootstrap.m...      2
# 95        jhonsd1996  [document.getElementById, google.maps.Map, goo...      2
# 96        JuanitoAli  [bootstrap.min.css, estilos.css, script.js, do...      2
# 97        Davsatu313  [body.css, favicon.ico, google.maps.Map, docum...      2
# 98    cesarochoa2006                                                 []      2
# 99         jjmuesesq  [style.css, favicon.ico, bootstrap.min.css, th...      2
# 100     jucjimenezmo  [reset.css, layout.css, style.css, jquery.fanc...      2
# 101           kancas  [bootstrap.min.css, main.css, bundle.js, MapEx...      2
# 102          Gantiva  [data.cityofchicago.org, rows.json, .ajax, goo...      2
# 103       Dandarprox                                                 []      2
# 104       debeltranc                                                 []      2
# 105        ykchautai                                                 []      2
# 106        ligibrial  [styles.css, blocks.css, bootstrap.min.css, th...      2
# 107       davidrh195  [style.css, k.jpg, code.js, setmaps.js, .js, j...      2
# 108      JulianaNino                                                 []      2
# 109         luegilca  [a.active, .active, document.getElementById, g...      2
# 110           Yelis3  [style.css, .js, scripts.js, .ready, .click, ....      2
# 111        begarzonf  [style.css, main.js, document.getElementById, ...      2
# 112       kmendezp96  [styles.css, bootstrap.min.css, jquery.min.js,...      2
# 113         leguzman  [bootstrap.min.css, main.js, jquery.min.js, do...      2
# 114     luealfonsoru  [bootstrap.min.css, awesome.min.css, animate.c...      2
# 115         oserasoa  [.ready, .click, .mcheck, .on, .closest, .list...      2
# 116         lsfinite                                                 []      2
# 117        xdanielsb  [house.ico, style.css, map.js, Chicago.jpg, do...      2
# 118      CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      2
# 119      jhcardenasa                                                 []      2
# 121     jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      2

# %%
import numpy as np
overall_phase1_bogota2['phase'] = 1
overall_phase1_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase1_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase1 = overall_phase1_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase1
# Out:
#              Student                                          functions  phase
# 80      jusherrerama  [this.value, this.name, document.getElementByI...      1
# 81           bdvegat                                      [estilos.css]      1
# 82        Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      1
# 83          HashNick  [fH.css, document.getElementById, google.maps....      1
# 84           ccvacad  [google.maps.Map, document.getElementById, goo...      1
# 85        joaortizro  [bootstrap.css, style.css, jquery.min.js, code...      1
# 86   juasmartinezbel  [jquery.min.js, bootstrap.min.js, tutorial.css...      1
# 87          mdbelloc                                                 []      1
# 88       diegocruz10  [estilos.css, functions.js, google.maps.Map, d...      1
# 89        crarojasca  [.floating, document.getElementById, google.ma...      1
# 90            sagilm                                                 []      1
# 91          idrojasf  [google.maps.Map, document.getElementById, Scr...      1
# 92      raulramirezp  [jquery.min.js, google.maps.Map, document.getE...      1
# 93         fabianr23                                                 []      1
# 94        jhriverasa  [bootstrap.min.css, jquery.min.js, bootstrap.m...      1
# 95        jhonsd1996  [document.getElementById, google.maps.Map, goo...      1
# 96        JuanitoAli                                                 []      1
# 97        Davsatu313  [body.css, google.maps.Map, document.getElemen...      1
# 98    cesarochoa2006                                                 []      1
# 99         jjmuesesq  [runner.github.io, module.exports, config.set,...      1
# 100     jucjimenezmo  [document.getElementById, google.maps.Map, goo...      1
# 101           kancas  [bootstrap.min.css, main.css, .js, .min.js, ma...      1
# 102          Gantiva                                                 []      1
# 103       Dandarprox                                                 []      1
# 104       debeltranc                                                 []      1
# 105        ykchautai                                                 []      1
# 106        ligibrial  [styles.css, blocks.css, bootstrap.min.css, th...      1
# 107       davidrh195  [style.css, k.jpg, code.js, google.maps.Map, d...      1
# 108      JulianaNino                                                 []      1
# 109         luegilca  [a.active, .active, document.getElementById, g...      1
# 110           Yelis3  [style.css, scripts.js, document.getElementByI...      1
# 111        begarzonf  [style.css, main.js, document.getElementById, ...      1
# 112       kmendezp96  [styles.css, awesome.min.css, imageManager.js,...      1
# 113         leguzman  [bootstrap.min.css, main.js, jquery.min.js, do...      1
# 114     luealfonsoru  [bootstrap.min.css, awesome.min.css, animate.c...      1
# 115         oserasoa  [.ready, .click, .mcheck, .on, .closest, .list...      1
# 116         lsfinite                                                 []      1
# 117        xdanielsb  [style.css, map.js, document.getElementById, g...      1
# 118      CSebasGomez                                                 []      1
# 119      jhcardenasa                                                 []      1
# 121     jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      1

# %% [markdown]
# ## Merge Two Phases into One Frame

# %%
phase15_bogota0 = overall_phase1_bogota0.append(overall_phase5_bogota0, ignore_index = True)
df_phase15_bogota0 = phase15_bogota0[['Student', 'functions', 'phase']]
df_phase15_bogota0
# Out:
#          Student                                          functions  phase
# 0      fffeelipe                                                 []      1
# 1      mnguzmanc                              [style.css, .Chicago]      1
# 2     jmcuestasb  [bootstrap.min.css, freelancer.min.css, style....      1
# 3     katherinsb  [.css, awesome.min.css, .w, google.maps.Map, d...      1
# 4   jjrodriguezn  [bootstrap.min.css, style.css, unal.edu.co, .n...      1
# ..           ...                                                ...    ...
# 69      jcneivaa                                                 []      5
# 70     fmbernalb  [bootstrap.min.css, style.css, bulk.jpg, jquer...      5
# 71       MogGy94  [.mifecha, bootstrap.min.css, theme.min.css, j...      5
# 72     yocuervoc  [document.getElementById, google.maps.Map, goo...      5
# 73     odprietoh  [bootstrap.min.css, style.css, script.js, data...      5
#
# [74 rows x 3 columns]

# %%
phase12_bogota0 = overall_phase1_bogota0.append(overall_phase2_bogota0, ignore_index = True)
df_phase12_bogota0 = phase12_bogota0[['Student', 'functions', 'phase']]
df_phase12_bogota0
# Out:
#          Student                                          functions  phase
# 0      fffeelipe                                                 []      1
# 1      mnguzmanc                              [style.css, .Chicago]      1
# 2     jmcuestasb  [bootstrap.min.css, freelancer.min.css, style....      1
# 3     katherinsb  [.css, awesome.min.css, .w, google.maps.Map, d...      1
# 4   jjrodriguezn  [bootstrap.min.css, style.css, unal.edu.co, .n...      1
# ..           ...                                                ...    ...
# 69      jcneivaa                                                 []      2
# 70     fmbernalb  [bootstrap.min.css, style.css, farmermarket.st...      2
# 71       MogGy94                                                 []      2
# 72     yocuervoc  [document.getElementById, google.maps.Map, goo...      2
# 73     odprietoh  [style.css, script.js, jquery.min.js, google.m...      2
#
# [74 rows x 3 columns]

# %%
phase23_bogota0 = overall_phase2_bogota0.append(overall_phase3_bogota0, ignore_index = True)
df_phase23_bogota0 = phase23_bogota0[['Student', 'functions', 'phase']]
df_phase23_bogota0
# Out:
#          Student                                          functions  phase
# 0      fffeelipe                                                 []      2
# 1      mnguzmanc  [style.css, .Chicago, document.getElementById,...      2
# 2     jmcuestasb  [bootstrap.min.css, freelancer.min.css, style....      2
# 3     katherinsb  [.css, awesome.min.css, latest.min.js, room.js...      2
# 4   jjrodriguezn  [bootstrap.min.css, style.css, script.js, unal...      2
# ..           ...                                                ...    ...
# 69      jcneivaa                                                 []      3
# 70     fmbernalb  [bootstrap.min.css, style.css, farmermarket.st...      3
# 71       MogGy94                                                 []      3
# 72     yocuervoc  [document.getElementById, google.maps.Map, goo...      3
# 73     odprietoh  [bootstrap.min.css, style.css, script.js, jque...      3
#
# [74 rows x 3 columns]

# %%
phase34_bogota0 = overall_phase3_bogota0.append(overall_phase4_bogota0, ignore_index = True)
df_phase34_bogota0 = phase34_bogota0[['Student', 'functions', 'phase']]
df_phase34_bogota0
# Out:
#          Student                                          functions  phase
# 0      fffeelipe                                                 []      3
# 1      mnguzmanc  [style.css, .Chicago, document.getElementById,...      3
# 2     jmcuestasb  [bootstrap.min.css, freelancer.min.css, style....      3
# 3     katherinsb  [.css, awesome.min.css, latest.min.js, room.js...      3
# 4   jjrodriguezn  [bootstrap.min.css, style.css, script.js, unal...      3
# ..           ...                                                ...    ...
# 69      jcneivaa                                                 []      4
# 70     fmbernalb  [bootstrap.min.css, style.css, bulk.jpg, jquer...      4
# 71       MogGy94                                                 []      4
# 72     yocuervoc  [document.getElementById, google.maps.Map, goo...      4
# 73     odprietoh  [bootstrap.min.css, style.css, script.js, jque...      4
#
# [74 rows x 3 columns]

# %%
phase45_bogota0 = overall_phase4_bogota0.append(overall_phase5_bogota0, ignore_index = True)
df_phase45_bogota0 = phase45_bogota0[['Student', 'functions', 'phase']]
df_phase45_bogota0
# Out:
#          Student                                          functions  phase
# 0      fffeelipe                                                 []      4
# 1      mnguzmanc  [style.css, .Chicago, document.getElementById,...      4
# 2     jmcuestasb  [.css, bootstrap.min.css, freelancer.min.css, ...      4
# 3     katherinsb  [.css, awesome.min.css, latest.min.js, room.js...      4
# 4   jjrodriguezn  [bootstrap.min.css, style.css, jquery.min.js, ...      4
# ..           ...                                                ...    ...
# 69      jcneivaa                                                 []      5
# 70     fmbernalb  [bootstrap.min.css, style.css, bulk.jpg, jquer...      5
# 71       MogGy94  [.mifecha, bootstrap.min.css, theme.min.css, j...      5
# 72     yocuervoc  [document.getElementById, google.maps.Map, goo...      5
# 73     odprietoh  [bootstrap.min.css, style.css, script.js, data...      5
#
# [74 rows x 3 columns]

# %%
phase15_bogota1 = overall_phase1_bogota1.append(overall_phase5_bogota1, ignore_index = True)
df_phase15_bogota1 = phase15_bogota1[['Student', 'functions', 'phase']]
df_phase15_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram                                                 []      1
# 1     adamantwharf                                                 []      1
# 2        bdcajicam  [.CSS, .css, awesome.min.css, .mySlides, page....      1
# 3   andfsanchezlem  [style.css, bootstrap.min.css, jquery.js, boot...      1
# 4      dfhincapiem  [jquery.min.js, .js, info.js, document.getElem...      1
# ..             ...                                                ...    ...
# 75        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      5
# 76  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      5
# 77         ItsNavi  [mapController.js, favicon.ico, fluidbox.min.c...      5
# 78         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      5
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      5
#
# [80 rows x 3 columns]

# %%
phase12_bogota1 = overall_phase1_bogota1.append(overall_phase2_bogota1, ignore_index = True)
df_phase12_bogota1 = phase12_bogota1[['Student', 'functions', 'phase']]
df_phase12_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram                                                 []      1
# 1     adamantwharf                                                 []      1
# 2        bdcajicam  [.CSS, .css, awesome.min.css, .mySlides, page....      1
# 3   andfsanchezlem  [style.css, bootstrap.min.css, jquery.js, boot...      1
# 4      dfhincapiem  [jquery.min.js, .js, info.js, document.getElem...      1
# ..             ...                                                ...    ...
# 75        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      2
# 76  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      2
# 77         ItsNavi  [favicon.ico, fluidbox.min.css, main.css, goog...      2
# 78         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      2
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      2
#
# [80 rows x 3 columns]

# %%
phase23_bogota1 = overall_phase2_bogota1.append(overall_phase3_bogota1, ignore_index = True)
df_phase23_bogota1 = phase23_bogota1[['Student', 'functions', 'phase']]
df_phase23_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram  [layout.css, shiv.js, document.getElementById,...      2
# 1     adamantwharf                                                 []      2
# 2        bdcajicam  [.CSS, custom.css, .css, awesome.min.css, jque...      2
# 3   andfsanchezlem  [style.css, bootstrap.css, jquery.js, bootstra...      2
# 4      dfhincapiem  [jquery.min.js, .js, info.js, chicago.jpg, doc...      2
# ..             ...                                                ...    ...
# 75        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      3
# 76  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      3
# 77         ItsNavi  [mapController.js, favicon.ico, fluidbox.min.c...      3
# 78         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      3
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      3
#
# [80 rows x 3 columns]

# %%
phase34_bogota1 = overall_phase3_bogota1.append(overall_phase4_bogota1, ignore_index = True)
df_phase34_bogota1 = phase34_bogota1[['Student', 'functions', 'phase']]
df_phase34_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram  [layout.css, shiv.js, document.getElementById,...      3
# 1     adamantwharf                                                 []      3
# 2        bdcajicam  [.CSS, custom.css, .css, awesome.min.css, jque...      3
# 3   andfsanchezlem  [style.css, bootstrap.css, balloon.css, jquery...      3
# 4      dfhincapiem  [jquery.min.js, .js, map.js, info.js, test.js,...      3
# ..             ...                                                ...    ...
# 75        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      4
# 76  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      4
# 77         ItsNavi  [mapController.js, favicon.ico, fluidbox.min.c...      4
# 78         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      4
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      4
#
# [80 rows x 3 columns]

# %%
phase45_bogota1 = overall_phase4_bogota1.append(overall_phase5_bogota1, ignore_index = True)
df_phase45_bogota1 = phase45_bogota1[['Student', 'functions', 'phase']]
df_phase45_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram  [layout.css, shiv.js, document.getElementById,...      4
# 1     adamantwharf                                                 []      4
# 2        bdcajicam  [.CSS, custom.css, .css, awesome.min.css, jque...      4
# 3   andfsanchezlem  [.css, style.css, bootstrap.css, balloon.css, ...      4
# 4      dfhincapiem  [jquery.min.js, .js, map.js, house.js, weather...      4
# ..             ...                                                ...    ...
# 75        jcrubioa  [demos.css, bootstrap.min.css, select.min.css,...      5
# 76  joahernandezca  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...      5
# 77         ItsNavi  [mapController.js, favicon.ico, fluidbox.min.c...      5
# 78         Zeugmax  [materialize.min.css, style.css, awesome.min.c...      5
# 79    JairVillalba  [bootstrap.min.css, modifier.css, jquery.min.j...      5
#
# [80 rows x 3 columns]

# %%
phase12_bogota2 = overall_phase1_bogota2.append(overall_phase2_bogota2, ignore_index = True)
df_phase12_bogota2 = phase12_bogota2[['Student', 'functions', 'phase']]
df_phase12_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  [this.value, this.name, document.getElementByI...      1
# 1        bdvegat                                      [estilos.css]      1
# 2     Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      1
# 3       HashNick  [fH.css, document.getElementById, google.maps....      1
# 4        ccvacad  [google.maps.Map, document.getElementById, goo...      1
# ..           ...                                                ...    ...
# 77      lsfinite                                                 []      2
# 78     xdanielsb  [house.ico, style.css, map.js, Chicago.jpg, do...      2
# 79   CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      2
# 80   jhcardenasa                                                 []      2
# 81  jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      2
#
# [82 rows x 3 columns]

# %%
phase23_bogota2 = overall_phase2_bogota2.append(overall_phase3_bogota2, ignore_index = True)
df_phase23_bogota2 = phase23_bogota2[['Student', 'functions', 'phase']]
df_phase23_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  [this.value, this.name, document.getElementByI...      2
# 1        bdvegat                            [estilos.css, icon.ico]      2
# 2     Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      2
# 3       HashNick  [fH.css, call.js, jquery.min.js, .js, this.id,...      2
# 4        ccvacad  [google.maps.Map, document.getElementById, goo...      2
# ..           ...                                                ...    ...
# 77      lsfinite                                                 []      3
# 78     xdanielsb  [house.ico, style.css, .css, main.js, map.js, ...      3
# 79   CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      3
# 80   jhcardenasa                                                 []      3
# 81  jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      3
#
# [82 rows x 3 columns]

# %%
phase34_bogota2 = overall_phase3_bogota2.append(overall_phase4_bogota2, ignore_index = True)
df_phase34_bogota2 = phase34_bogota2[['Student', 'functions', 'phase']]
df_phase34_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  [this.value, this.name, document.getElementByI...      3
# 1        bdvegat  [estilos.css, icon.ico, Etxea.js, document.get...      3
# 2     Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      3
# 3       HashNick  [fH.css, call.js, jquery.min.js, .js, this.id,...      3
# 4        ccvacad  [nearium.css, .js, nearium.js, google.maps.Map...      3
# ..           ...                                                ...    ...
# 77      lsfinite                                                 []      4
# 78     xdanielsb  [house.ico, style.css, .css, main.js, map.js, ...      4
# 79   CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      4
# 80   jhcardenasa                                                 []      4
# 81  jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      4
#
# [82 rows x 3 columns]

# %%
phase45_bogota2 = overall_phase4_bogota2.append(overall_phase5_bogota2, ignore_index = True)
df_phase45_bogota2 = phase45_bogota2[['Student', 'functions', 'phase']]
df_phase45_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  [this.value, this.name, window.location.reload...      4
# 1        bdvegat  [estilos.css, icon.ico, Etxea.js, document.get...      4
# 2     Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      4
# 3       HashNick  [fH.css, jquery.min.js, .js, call.js, climate....      4
# 4        ccvacad  [nearium.css, .js, nearium.js, google.maps.Map...      4
# ..           ...                                                ...    ...
# 77      lsfinite                                                 []      5
# 78     xdanielsb  [house.ico, style.css, .css, main.js, map.js, ...      5
# 79   CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      5
# 80   jhcardenasa                                                 []      5
# 81  jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      5
#
# [82 rows x 3 columns]

# %%
phase15_bogota2 = overall_phase1_bogota2.append(overall_phase5_bogota2, ignore_index = True)
df_phase15_bogota2 = phase15_bogota2[['Student', 'functions', 'phase']]
df_phase15_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  [this.value, this.name, document.getElementByI...      1
# 1        bdvegat                                      [estilos.css]      1
# 2     Phoenixest  [unal.edu.co, bootstrap.min.css, template.css,...      1
# 3       HashNick  [fH.css, document.getElementById, google.maps....      1
# 4        ccvacad  [google.maps.Map, document.getElementById, goo...      1
# ..           ...                                                ...    ...
# 77      lsfinite                                                 []      5
# 78     xdanielsb  [house.ico, style.css, .css, main.js, map.js, ...      5
# 79   CSebasGomez  [google.maps.LatLng, google.maps.MapTypeId.ROA...      5
# 80   jhcardenasa                                                 []      5
# 81  jscontrerasp  [bootstrap.min.css, index.css, jquery.js, boot...      5
#
# [82 rows x 3 columns]

# %% [markdown]
# ## Comparing Phase 4 and Phase 5 Bogota 3

# %%
overall_phase5_bogota3['phase'] = 5
overall_phase5_bogota3
overall_phase5_bogota3[['Student', 'functions', 'phase']]
# Out:
#                 Student                                          functions  \
# 122           lemartinp  [.getFullYear, console.log, .main, .hide, .rou...
# 123           juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 124           nfmorenog  [js.org, .v, .min.js, style.css, jquery.min.js...
# 125           AFelipeGA  [jquery.min.js, init.js, handler.js, search.js...
# 126          mballeng91  [.js, bootstrap.min.js, styles.css, bootstrap....
# 127            dduartec  [google.maps.LatLng, google.maps.MapTypeId.ROA...
# 128           srmedinac  [bootstrap.min.css, awesome.min.css, theme.min...
# 129        wilson911013  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 130       wapiravaguens  [bootstrap.min.css, creative.min.css, jquery.m...
# 131            davidh17  [bootstrap.min.css, theme.min.css, style.css, ...
# 132      DianaNavarrete  [illinois.edu, favicon.ico, bootstrap.min.css,...
# 133           jdmonroyg  [bootstrap.min.css, theme.min.css, jquery.min....
# 134           jorge52an  [bootstrap.min.css, main.css, .org, .js, map.j...
# 135     jscastelblancoh                                                 []
# 136          juclopezso  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 137           afforeroc  [google.maps.Map, google.maps.Marker, google.m...
# 138         dagofonseca  [reset.css, layout.css, style.css, jquery.min....
# 139         lacardenasv  [bootstrap.min.css, jquery.min.js, style.css, ...
# 140         oacastillol  [components.css, responsee.css, owl.carousel.c...
# 141          ncampuzano  [data.cityofchicago.org, rows.json, xmlhttp.op...
# 142            adriel62  [FirstLook.css, bootstrap.min.css, jquery.min....
# 143            capinzor  [module.exports, grunt.option, grunt.initConfi...
# 144            ofnanezn  [style.css, bootstrap.min.css, .min.css, googl...
# 145           macuestap  [bootstrap.min.css, mainPage.css, awesome.min....
# 146              spenas  [jquery.min.js, bootstrap.min.js, .js, js.org,...
# 147         kgbayala528  [main.css, material.min.css, angular.min.js, a...
# 148          lgmoralesa  [runner.github.io, module.exports, config.set,...
# 149          ronaldsg20  [styles.css, jquery.min.js, integration.js, sc...
# 150       cccristanchoc  [ownStyle.css, theme.min.css, bootstrap.min.cs...
# 151          jmalvarezd  [campuapi.azurewebsites.net, GetRegionChildren...
# 152           smarquezo  [bootstrap.js, bootstrap.css, styles.css, tabl...
# 153             sarizag  [PROJECT.HTML, document.getElementById, google...
# 154            Chranium  [bootstrap.min.css, .navbar, Respond.js, shiv....
# 155             DavidQP  [bootstrap.min.css, estilos.css, .min.js, boot...
# 156         afceballosr  [materialize.css, materialize.js, materialize....
# 157           lizzyt10h  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 158          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 159       jumcorredorro  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 160          feartheGru                                                 []
# 161        Danielsv9207                                                 []
# 162  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#      phase
# 122      5
# 123      5
# 124      5
# 125      5
# 126      5
# 127      5
# 128      5
# 129      5
# 130      5
# 131      5
# 132      5
# 133      5
# 134      5
# 135      5
# 136      5
# 137      5
# 138      5
# 139      5
# 140      5
# 141      5
# 142      5
# 143      5
# 144      5
# 145      5
# 146      5
# 147      5
# 148      5
# 149      5
# 150      5
# 151      5
# 152      5
# 153      5
# 154      5
# 155      5
# 156      5
# 157      5
# 158      5
# 159      5
# 160      5
# 161      5
# 162      5

# %%
overall_phase4_bogota3['phase'] = 4
overall_phase4_bogota3
overall_phase4_bogota3[['Student', 'functions', 'phase']]
# Out:
#                 Student                                          functions  \
# 122           lemartinp  [.getFullYear, console.log, .main, .hide, .rou...
# 123           juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 124           nfmorenog  [js.org, .v, .min.js, style.css, jquery.min.js...
# 125           AFelipeGA  [jquery.min.js, styles.css, init.js, handler.j...
# 126          mballeng91  [.js, bootstrap.min.js, styles.css, bootstrap....
# 127            dduartec  [google.maps.LatLng, google.maps.MapTypeId.ROA...
# 128           srmedinac  [bootstrap.min.css, awesome.min.css, theme.min...
# 129        wilson911013  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 130       wapiravaguens  [bootstrap.min.css, creative.min.css, jquery.m...
# 131            davidh17  [bootstrap.min.css, theme.min.css, style.css, ...
# 132      DianaNavarrete  [illinois.edu, favicon.ico, bootstrap.min.css,...
# 133           jdmonroyg  [bootstrap.min.css, theme.min.css, jquery.min....
# 134           jorge52an  [bootstrap.min.css, main.css, .org, .js, map.j...
# 135     jscastelblancoh                                                 []
# 136          juclopezso  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 137           afforeroc  [.ready, .modal, module.exports, define.amd, e...
# 138         dagofonseca  [reset.css, layout.css, style.css, .js, yui.js...
# 139         lacardenasv  [bootstrap.min.css, jquery.min.js, style.css, ...
# 140         oacastillol  [components.css, responsee.css, owl.carousel.c...
# 141          ncampuzano  [data.cityofchicago.org, rows.json, xmlhttp.op...
# 142            adriel62  [FirstLook.css, bootstrap.min.css, jquery.min....
# 143            capinzor  [module.exports, grunt.option, grunt.initConfi...
# 144            ofnanezn  [style.css, bootstrap.min.css, .min.css, googl...
# 145           macuestap  [bootstrap.min.css, mainPage.css, awesome.min....
# 146              spenas  [jquery.min.js, bootstrap.min.js, .js, js.org,...
# 147         kgbayala528  [main.css, material.min.css, angular.min.js, a...
# 148          lgmoralesa  [runner.github.io, module.exports, config.set,...
# 149          ronaldsg20  [styles.css, jquery.min.js, integration.js, sc...
# 150       cccristanchoc  [icons.css, ownStyle.css, theme.min.css, boots...
# 151          jmalvarezd  [.js, google.maps.Map, google.maps.Marker, goo...
# 152           smarquezo  [bootstrap.js, bootstrap.css, styles.css, tabl...
# 153             sarizag  [PROJECT.HTML, document.getElementById, google...
# 154            Chranium  [bootstrap.min.css, .navbar, Respond.js, shiv....
# 155             DavidQP  [bootstrap.min.css, estilos.css, .min.js, boot...
# 156         afceballosr  [materialize.css, materialize.js, materialize....
# 157           lizzyt10h  [funciones.js, bootstrap.min.css, jquery.min.j...
# 158          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 159       jumcorredorro  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 160          feartheGru                                                 []
# 161        Danielsv9207                                                 []
# 162  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#      phase
# 122      4
# 123      4
# 124      4
# 125      4
# 126      4
# 127      4
# 128      4
# 129      4
# 130      4
# 131      4
# 132      4
# 133      4
# 134      4
# 135      4
# 136      4
# 137      4
# 138      4
# 139      4
# 140      4
# 141      4
# 142      4
# 143      4
# 144      4
# 145      4
# 146      4
# 147      4
# 148      4
# 149      4
# 150      4
# 151      4
# 152      4
# 153      4
# 154      4
# 155      4
# 156      4
# 157      4
# 158      4
# 159      4
# 160      4
# 161      4
# 162      4

# %%
import numpy as np
overall_phase3_bogota3['phase'] = 3
overall_phase3_bogota3['functions'].replace('', np.nan, inplace=True)
overall_phase3_bogota3.dropna(subset=['functions'], inplace=True)
subset_bogota3_phase3 = overall_phase3_bogota3[['Student', 'functions', 'phase']]
subset_bogota3_phase3
# Out:
#                 Student                                          functions  \
# 122           lemartinp  [.getFullYear, console.log, document.getElemen...
# 123           juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 124           nfmorenog  [js.org, .v, .min.js, style.css, jquery.min.js...
# 125           AFelipeGA  [jquery.min.js, styles.css, init.js, handler.j...
# 126          mballeng91  [.js, bootstrap.min.js, styles.css, bootstrap....
# 127            dduartec  [google.maps.LatLng, google.maps.MapTypeId.ROA...
# 128           srmedinac  [bootstrap.min.css, awesome.min.css, theme.min...
# 129        wilson911013  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 130       wapiravaguens  [bootstrap.min.css, jquery.min.js, implementat...
# 131            davidh17  [bootstrap.min.css, theme.min.css, style.css, ...
# 132      DianaNavarrete  [illinois.edu, favicon.ico, bootstrap.min.css,...
# 133           jdmonroyg  [bootstrap.min.css, theme.min.css, jquery.min....
# 134           jorge52an  [bootstrap.min.css, main.css, .org, .js, map.j...
# 135     jscastelblancoh                                                 []
# 136          juclopezso  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 137           afforeroc  [.ready, .modal, module.exports, define.amd, e...
# 138         dagofonseca                                                 []
# 139         lacardenasv  [bootstrap.min.css, jquery.min.js, style.css, ...
# 140         oacastillol  [components.css, responsee.css, owl.carousel.c...
# 141          ncampuzano  [data.cityofchicago.org, rows.json, xmlhttp.op...
# 142            adriel62  [FirstLook.css, bootstrap.min.css, jquery.min....
# 143            capinzor  [module.exports, grunt.option, grunt.initConfi...
# 144            ofnanezn  [style.css, bootstrap.min.css, jquery.min.js, ...
# 145           macuestap  [bootstrap.min.css, mainPage.css, awesome.min....
# 146              spenas  [jquery.min.js, tutorial.js, bootstrap.min.js,...
# 147         kgbayala528  [main.css, material.min.css, angular.min.js, a...
# 148          lgmoralesa  [runner.github.io, module.exports, config.set,...
# 149          ronaldsg20  [styles.css, jquery.min.js, scripts.js, integr...
# 150       cccristanchoc  [ownStyle.css, theme.min.css, bootstrap.min.cs...
# 151          jmalvarezd  [.js, google.maps.Map, google.maps.Marker, goo...
# 152           smarquezo  [bootstrap.js, bootstrap.css, styles.css, tabl...
# 153             sarizag  [PROJECT.HTML, document.getElementById, google...
# 154            Chranium  [google.maps.Map, document.getElementById, goo...
# 155             DavidQP  [bootstrap.min.css, estilos.css, .min.js, boot...
# 156         afceballosr  [materialize.css, materialize.js, materialize....
# 157           lizzyt10h  [funciones.js, bootstrap.min.css, jquery.min.j...
# 158          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 159       jumcorredorro  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 160          feartheGru                                                 []
# 161        Danielsv9207                                                 []
# 162  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#      phase
# 122      3
# 123      3
# 124      3
# 125      3
# 126      3
# 127      3
# 128      3
# 129      3
# 130      3
# 131      3
# 132      3
# 133      3
# 134      3
# 135      3
# 136      3
# 137      3
# 138      3
# 139      3
# 140      3
# 141      3
# 142      3
# 143      3
# 144      3
# 145      3
# 146      3
# 147      3
# 148      3
# 149      3
# 150      3
# 151      3
# 152      3
# 153      3
# 154      3
# 155      3
# 156      3
# 157      3
# 158      3
# 159      3
# 160      3
# 161      3
# 162      3

# %%
overall_phase2_bogota3['phase'] = 2
overall_phase2_bogota3
overall_phase2_bogota3[['Student', 'functions', 'phase']]
# Out:
#                 Student                                          functions  \
# 122           lemartinp  [google.maps.DirectionsRenderer, document.getE...
# 123           juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 124           nfmorenog  [js.org, .v, .min.js, style.css, jquery.min.js...
# 125           AFelipeGA  [jquery.min.js, styles.css, init.js, test.js, ...
# 126          mballeng91  [.js, bootstrap.min.js, styles.css, bootstrap....
# 127            dduartec  [google.maps.LatLng, google.maps.MapTypeId.ROA...
# 128           srmedinac  [bootstrap.min.css, awesome.min.css, theme.min...
# 129        wilson911013  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 130       wapiravaguens  [bootstrap.min.css, implementation.js, google....
# 131            davidh17  [bootstrap.min.css, theme.min.css, style.css, ...
# 132      DianaNavarrete  [illinois.edu, favicon.ico, bootstrap.min.css,...
# 133           jdmonroyg  [bootstrap.min.css, theme.min.css, jquery.min....
# 134           jorge52an  [bootstrap.min.css, main.css, .org, .js, map.j...
# 135     jscastelblancoh                                                 []
# 136          juclopezso  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 137           afforeroc  [module.exports, define.amd, exports.AOS, e.AO...
# 138         dagofonseca                                                 []
# 139         lacardenasv  [bootstrap.min.css, jquery.min.js, style.css, ...
# 140         oacastillol  [components.css, responsee.css, owl.carousel.c...
# 141          ncampuzano  [.css, buttons.css, google.maps.Map, document....
# 142            adriel62  [FirstLook.css, bootstrap.min.css, jquery.min....
# 143            capinzor  [module.exports, grunt.option, grunt.initConfi...
# 144            ofnanezn  [style.css, bootstrap.min.css, jquery.min.js, ...
# 145           macuestap  [jquery.min.js, bootstrap.min.css, bootstrap.m...
# 146              spenas  [jquery.min.js, tutorial.js, bootstrap.min.js,...
# 147         kgbayala528  [main.css, material.min.css, angular.min.js, a...
# 148          lgmoralesa  [runner.github.io, module.exports, config.set,...
# 149          ronaldsg20  [styles.css, jquery.min.js, scripts.js, integr...
# 150       cccristanchoc  [ownStyle.css, bootstrap.min.css, theme.min.cs...
# 151          jmalvarezd  [styles.css, loadUpData.js, map.js, data.cityo...
# 152           smarquezo  [bootstrap.js, bootstrap.css, styles.css, tabl...
# 153             sarizag  [PROJECT.HTML, document.getElementById, google...
# 154            Chranium  [google.maps.Map, document.getElementById, goo...
# 155             DavidQP  [bootstrap.min.css, estilos.css, maps.js, .min...
# 156         afceballosr  [materialize.css, materialize.js, materialize....
# 157           lizzyt10h  [funciones.js, jquery.min.js, bootstrap.min.js...
# 158          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 159       jumcorredorro  [bootstrap.min.css, portfolio.css, awesome.min...
# 160          feartheGru                                                 []
# 161        Danielsv9207                                                 []
# 162  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#      phase
# 122      2
# 123      2
# 124      2
# 125      2
# 126      2
# 127      2
# 128      2
# 129      2
# 130      2
# 131      2
# 132      2
# 133      2
# 134      2
# 135      2
# 136      2
# 137      2
# 138      2
# 139      2
# 140      2
# 141      2
# 142      2
# 143      2
# 144      2
# 145      2
# 146      2
# 147      2
# 148      2
# 149      2
# 150      2
# 151      2
# 152      2
# 153      2
# 154      2
# 155      2
# 156      2
# 157      2
# 158      2
# 159      2
# 160      2
# 161      2
# 162      2

# %%
import numpy as np
overall_phase1_bogota3['phase'] = 1
overall_phase1_bogota3['functions'].replace('', np.nan, inplace=True)
overall_phase1_bogota3.dropna(subset=['functions'], inplace=True)
subset_bogota3_phase1 = overall_phase1_bogota3[['Student', 'functions', 'phase']]
subset_bogota3_phase1
# Out:
#                 Student                                          functions  \
# 122           lemartinp  [document.getElementById, google.maps.Map, goo...
# 123           juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 124           nfmorenog  [js.org, .v, .min.js, style.css, google.maps.M...
# 125           AFelipeGA  [jquery.min.js, styles.css, init.js, .containe...
# 126          mballeng91  [styles.css, developers.google, default.css, ....
# 127            dduartec  [lml.jpg, google.maps.LatLng, google.maps.MapT...
# 128           srmedinac  [bootstrap.min.css, awesome.min.css, theme.min...
# 129        wilson911013  [jquery.min.js, .js, Rent.js, Crimes.js, googl...
# 130       wapiravaguens  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 131            davidh17  [bootstrap.min.css, theme.min.css, style.css, ...
# 132      DianaNavarrete  [illinois.edu, favicon.ico, bootstrap.min.css,...
# 133           jdmonroyg  [bootstrap.min.css, theme.min.css, jquery.min....
# 134           jorge52an  [bootstrap.min.css, main.css, .org, .js, map.j...
# 135     jscastelblancoh                                                 []
# 136          juclopezso  [bootstrap.min.css, demos.css, .jumbotron, .fl...
# 137           afforeroc  [bootstrap.min.css, theme.min.css, aos.css, co...
# 138         dagofonseca                                                 []
# 139         lacardenasv  [data.cityofchicago.org, iimk.geojson, xi.geoj...
# 140         oacastillol  [components.css, responsee.css, owl.carousel.c...
# 141          ncampuzano  [google.maps.Map, document.getElementById, goo...
# 142            adriel62  [FirstLook.css, bootstrap.min.css, jquery.min....
# 143            capinzor  [.js, Mapa.js, Data.js, labels.text.stroke, la...
# 144            ofnanezn  [style.css, jquery.min.js, .ready, .click, .aj...
# 145           macuestap  [mainPage.css, resetStyle.css, jquery.min.js, ...
# 146              spenas  [jquery.min.js, bootstrap.min.js, .js, js.org,...
# 147         kgbayala528  [main.css, angular.min.js, app.js, mainControl...
# 148          lgmoralesa  [runner.github.io, module.exports, config.set,...
# 149          ronaldsg20  [styles.css, scripts.js, integration.js, googl...
# 150       cccristanchoc  [ownStyle.css, bootstrap.min.css, theme.min.cs...
# 151          jmalvarezd  [styles.css, loadUpData.js, map.js, data.cityo...
# 152           smarquezo  [bootstrap.js, bootstrap.css, styles.css, goog...
# 153             sarizag  [PROJECT.HTML, document.getElementById, google...
# 154            Chranium  [bootstrap.min.css, item.css, Respond.js, shiv...
# 155             DavidQP  [bootstrap.min.css, estilos.css, maps.js, .min...
# 156         afceballosr  [materialize.min.css, materialize.min.js, .min...
# 157           lizzyt10h  [funciones.js, jquery.min.js, bootstrap.min.js...
# 158          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 159       jumcorredorro  [bootstrap.min.css, portfolio.css, awesome.min...
# 160          feartheGru                                                 []
# 161        Danielsv9207                                                 []
# 162  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#      phase
# 122      1
# 123      1
# 124      1
# 125      1
# 126      1
# 127      1
# 128      1
# 129      1
# 130      1
# 131      1
# 132      1
# 133      1
# 134      1
# 135      1
# 136      1
# 137      1
# 138      1
# 139      1
# 140      1
# 141      1
# 142      1
# 143      1
# 144      1
# 145      1
# 146      1
# 147      1
# 148      1
# 149      1
# 150      1
# 151      1
# 152      1
# 153      1
# 154      1
# 155      1
# 156      1
# 157      1
# 158      1
# 159      1
# 160      1
# 161      1
# 162      1

# %%
phase12 = subset_bogota3_phase1.append(overall_phase2_bogota3, ignore_index = True)
df_phase12 = phase12[['Student', 'functions', 'phase']]
df_phase12
# Out:
#                Student                                          functions  \
# 0            lemartinp  [document.getElementById, google.maps.Map, goo...
# 1            juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 2            nfmorenog  [js.org, .v, .min.js, style.css, google.maps.M...
# 3            AFelipeGA  [jquery.min.js, styles.css, init.js, .containe...
# 4           mballeng91  [styles.css, developers.google, default.css, ....
# ..                 ...                                                ...
# 77          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 78       jumcorredorro  [bootstrap.min.css, portfolio.css, awesome.min...
# 79          feartheGru                                                 []
# 80        Danielsv9207                                                 []
# 81  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#     phase
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 77      2
# 78      2
# 79      2
# 80      2
# 81      2
#
# [82 rows x 3 columns]

# %%
phase23 = overall_phase2_bogota3.append(subset_bogota3_phase3, ignore_index = True)
df_phase23 = phase23[['Student', 'functions', 'phase']]
df_phase23
# Out:
#                Student                                          functions  \
# 0            lemartinp  [google.maps.DirectionsRenderer, document.getE...
# 1            juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 2            nfmorenog  [js.org, .v, .min.js, style.css, jquery.min.js...
# 3            AFelipeGA  [jquery.min.js, styles.css, init.js, test.js, ...
# 4           mballeng91  [.js, bootstrap.min.js, styles.css, bootstrap....
# ..                 ...                                                ...
# 77          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 78       jumcorredorro  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 79          feartheGru                                                 []
# 80        Danielsv9207                                                 []
# 81  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#     phase
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
# ..    ...
# 77      3
# 78      3
# 79      3
# 80      3
# 81      3
#
# [82 rows x 3 columns]

# %%
phase34 = subset_bogota3_phase3.append(overall_phase4_bogota3, ignore_index = True)
df_phase34 = phase34[['Student', 'functions', 'phase']]
df_phase34
# Out:
#                Student                                          functions  \
# 0            lemartinp  [.getFullYear, console.log, document.getElemen...
# 1            juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 2            nfmorenog  [js.org, .v, .min.js, style.css, jquery.min.js...
# 3            AFelipeGA  [jquery.min.js, styles.css, init.js, handler.j...
# 4           mballeng91  [.js, bootstrap.min.js, styles.css, bootstrap....
# ..                 ...                                                ...
# 77          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 78       jumcorredorro  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 79          feartheGru                                                 []
# 80        Danielsv9207                                                 []
# 81  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#     phase
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
# ..    ...
# 77      4
# 78      4
# 79      4
# 80      4
# 81      4
#
# [82 rows x 3 columns]

# %%
phase45 = overall_phase4_bogota3.append(overall_phase5_bogota3, ignore_index = True)
df_phase45 = phase45[['Student', 'functions', 'phase']]
df_phase45
# Out:
#                Student                                          functions  \
# 0            lemartinp  [.getFullYear, console.log, .main, .hide, .rou...
# 1            juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 2            nfmorenog  [js.org, .v, .min.js, style.css, jquery.min.js...
# 3            AFelipeGA  [jquery.min.js, styles.css, init.js, handler.j...
# 4           mballeng91  [.js, bootstrap.min.js, styles.css, bootstrap....
# ..                 ...                                                ...
# 77          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 78       jumcorredorro  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 79          feartheGru                                                 []
# 80        Danielsv9207                                                 []
# 81  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#     phase
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# ..    ...
# 77      5
# 78      5
# 79      5
# 80      5
# 81      5
#
# [82 rows x 3 columns]

# %%
phase15 = overall_phase1_bogota3.append(overall_phase5_bogota3, ignore_index = True)
df_phase15 = phase15[['Student', 'functions', 'phase']]
df_phase15
# Out:
#                Student                                          functions  \
# 0            lemartinp  [document.getElementById, google.maps.Map, goo...
# 1            juligarji  [bootstrap.min.css, theme.min.css, jquery.min....
# 2            nfmorenog  [js.org, .v, .min.js, style.css, google.maps.M...
# 3            AFelipeGA  [jquery.min.js, styles.css, init.js, .containe...
# 4           mballeng91  [styles.css, developers.google, default.css, ....
# ..                 ...                                                ...
# 77          NicolasPrr  [bootstrap.min.css, theme.min.css, jquery.min....
# 78       jumcorredorro  [js.org, .v, .min.js, bootstrap.min.css, portf...
# 79          feartheGru                                                 []
# 80        Danielsv9207                                                 []
# 81  JhonEmmanuelTorres  [document.getElementById, google.maps.Map, goo...
#
#     phase
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 77      5
# 78      5
# 79      5
# 80      5
# 81      5
#
# [82 rows x 3 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase15_bogota1["functions"], df_phase15_bogota1["Student"], df_phase15_bogota1["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df0_bogota1 = pd.DataFrame(result)
df0_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            1            1    1.000000
# 1          gasierram       bdcajicam            1            1    0.000000
# 2          gasierram  andfsanchezlem            1            1    0.000000
# 3          gasierram     dfhincapiem            1            1    0.000000
# 4          gasierram       helmeraac            1            1    0.000000
# ...              ...             ...          ...          ...         ...
# 3155  joahernandezca         Zeugmax            5            5    0.001454
# 3156  joahernandezca    JairVillalba            5            5    0.048387
# 3157         ItsNavi         Zeugmax            5            5    0.007039
# 3158         ItsNavi    JairVillalba            5            5    0.044776
# 3159         Zeugmax    JairVillalba            5            5    0.012529
#
# [3160 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase15_bogota2["functions"], df_phase15_bogota2["Student"], df_phase15_bogota2["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df0_bogota2 = pd.DataFrame(result)
df0_bogota2
# Out:
#              user1         user2  user1_phase  user2_phase  similarity
# 0     jusherrerama       bdvegat            1            1    0.000000
# 1     jusherrerama    Phoenixest            1            1    0.162162
# 2     jusherrerama      HashNick            1            1    0.300000
# 3     jusherrerama       ccvacad            1            1    0.333333
# 4     jusherrerama    joaortizro            1            1    0.102564
# ...            ...           ...          ...          ...         ...
# 3316     xdanielsb   jhcardenasa            5            5    0.000000
# 3317     xdanielsb  jscontrerasp            5            5    0.010213
# 3318   CSebasGomez   jhcardenasa            5            5    0.000000
# 3319   CSebasGomez  jscontrerasp            5            5    0.092593
# 3320   jhcardenasa  jscontrerasp            5            5    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase15["functions"], df_phase15["Student"], df_phase15["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df0 = pd.DataFrame(result)
df0
# Out:
#               user1               user2  user1_phase  user2_phase  similarity
# 0         lemartinp           juligarji            1            1    0.050955
# 1         lemartinp           nfmorenog            1            1    0.222222
# 2         lemartinp           AFelipeGA            1            1    0.073171
# 3         lemartinp          mballeng91            1            1    0.250000
# 4         lemartinp            dduartec            1            1    0.120000
# ...             ...                 ...          ...          ...         ...
# 3316  jumcorredorro        Danielsv9207            5            5    0.000000
# 3317  jumcorredorro  JhonEmmanuelTorres            5            5    0.139535
# 3318     feartheGru        Danielsv9207            5            5    1.000000
# 3319     feartheGru  JhonEmmanuelTorres            5            5    0.000000
# 3320   Danielsv9207  JhonEmmanuelTorres            5            5    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase45_bogota0["functions"], df_phase45_bogota0["Student"], df_phase45_bogota0["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    print(similarity)
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)
    print(result)

df1_bogota0 = pd.DataFrame(result)
df1_bogota0
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 0.09523809523809523
# [{'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jjrodriguezn', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'DglyP', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cap182', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Judgarciani', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'sacastroc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pcberriop', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'hsmartineza', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Moimolcp', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'CamiloRueda', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juanescai', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'JoseMolano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'maikellPardoA', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'NicolasZon', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo654', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'CristianLozano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsuarezj', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pipemax85', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juandavidro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'UNhcrodriguezl', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo13152', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'leavendanoro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cdcordobaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'capinillab', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'lfvalderrama', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'bsgarciac', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'gabi04', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'annipi', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsolanos', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jcneivaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'fmbernalb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'MogGy94', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'yocuervoc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'odprietoh', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'fffeelipe', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'us ...
# 0.07317073170731707
# [{'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jjrodriguezn', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'DglyP', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cap182', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Judgarciani', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'sacastroc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pcberriop', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'hsmartineza', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Moimolcp', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'CamiloRueda', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juanescai', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'JoseMolano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'maikellPardoA', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'NicolasZon', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo654', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'CristianLozano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsuarezj', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pipemax85', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juandavidro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'UNhcrodriguezl', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo13152', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'leavendanoro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cdcordobaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'capinillab', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'lfvalderrama', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'bsgarciac', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'gabi04', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'annipi', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsolanos', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jcneivaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'fmbernalb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'MogGy94', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'yocuervoc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'odprietoh', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'fffeelipe', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'us ...
# 0.2857142857142857
# [{'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jjrodriguezn', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'DglyP', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cap182', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Judgarciani', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'sacastroc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pcberriop', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'hsmartineza', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Moimolcp', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'CamiloRueda', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juanescai', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'JoseMolano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'maikellPardoA', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'NicolasZon', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo654', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'CristianLozano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsuarezj', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pipemax85', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juandavidro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'UNhcrodriguezl', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo13152', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'leavendanoro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cdcordobaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'capinillab', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'lfvalderrama', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'bsgarciac', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'gabi04', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'annipi', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsolanos', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jcneivaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'fmbernalb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'MogGy94', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'yocuervoc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'odprietoh', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'fffeelipe', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'us ...
# 0.050505050505050504
# [{'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jjrodriguezn', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'DglyP', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cap182', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Judgarciani', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'sacastroc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pcberriop', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'hsmartineza', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Moimolcp', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'CamiloRueda', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juanescai', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'JoseMolano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'maikellPardoA', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'NicolasZon', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo654', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'CristianLozano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsuarezj', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pipemax85', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juandavidro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'UNhcrodriguezl', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo13152', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'leavendanoro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cdcordobaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'capinillab', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'lfvalderrama', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'bsgarciac', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'gabi04', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'annipi', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsolanos', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jcneivaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'fmbernalb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'MogGy94', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'yocuervoc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'odprietoh', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'fffeelipe', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'us ...
# 0.03296703296703297
# [{'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jjrodriguezn', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'DglyP', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cap182', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Judgarciani', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'sacastroc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pcberriop', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'hsmartineza', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'Moimolcp', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'CamiloRueda', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juanescai', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'JoseMolano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'maikellPardoA', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'NicolasZon', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo654', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'CristianLozano', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsuarezj', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'pipemax85', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'juandavidro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'UNhcrodriguezl', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'camilo13152', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'leavendanoro', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'cdcordobaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'capinillab', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'lfvalderrama', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'bsgarciac', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'gabi04', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'annipi', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jdsolanos', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jcneivaa', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'fmbernalb', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'MogGy94', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'yocuervoc', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'odprietoh', 'user1_phase': 4, 'user2_phase': 4, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'fffeelipe', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 1}, {'user1': 'fffeelipe', 'user2': 'mnguzmanc', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'jmcuestasb', 'user1_phase': 4, 'user2_phase': 5, 'similarity': 0.0}, {'user1': 'fffeelipe', 'user2': 'katherinsb', 'us ...
#           user1         user2  user1_phase  user2_phase  similarity
# 0     fffeelipe     mnguzmanc            4            4    0.000000
# 1     fffeelipe    jmcuestasb            4            4    0.000000
# 2     fffeelipe    katherinsb            4            4    0.000000
# 3     fffeelipe  jjrodriguezn            4            4    0.000000
# 4     fffeelipe         DglyP            4            4    0.000000
# ...         ...           ...          ...          ...         ...
# 2696  fmbernalb     yocuervoc            5            5    0.095238
# 2697  fmbernalb     odprietoh            5            5    0.073171
# 2698    MogGy94     yocuervoc            5            5    0.285714
# 2699    MogGy94     odprietoh            5            5    0.050505
# 2700  yocuervoc     odprietoh            5            5    0.032967
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase45_bogota1["functions"], df_phase45_bogota1["Student"], df_phase45_bogota1["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df1_bogota1 = pd.DataFrame(result)
df1_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            4            4    0.000000
# 1          gasierram       bdcajicam            4            4    0.029703
# 2          gasierram  andfsanchezlem            4            4    0.001904
# 3          gasierram     dfhincapiem            4            4    0.028037
# 4          gasierram       helmeraac            4            4    0.046875
# ...              ...             ...          ...          ...         ...
# 3155  joahernandezca         Zeugmax            5            5    0.001454
# 3156  joahernandezca    JairVillalba            5            5    0.048387
# 3157         ItsNavi         Zeugmax            5            5    0.007039
# 3158         ItsNavi    JairVillalba            5            5    0.044776
# 3159         Zeugmax    JairVillalba            5            5    0.012529
#
# [3160 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase45_bogota2["functions"], df_phase45_bogota2["Student"], df_phase45_bogota2["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df1_bogota2 = pd.DataFrame(result)
df1_bogota2
# Out:
#              user1         user2  user1_phase  user2_phase  similarity
# 0     jusherrerama       bdvegat            4            4    0.050847
# 1     jusherrerama    Phoenixest            4            4    0.168142
# 2     jusherrerama      HashNick            4            4    0.194805
# 3     jusherrerama       ccvacad            4            4    0.194805
# 4     jusherrerama    joaortizro            4            4    0.198020
# ...            ...           ...          ...          ...         ...
# 3316     xdanielsb   jhcardenasa            5            5    0.000000
# 3317     xdanielsb  jscontrerasp            5            5    0.010213
# 3318   CSebasGomez   jhcardenasa            5            5    0.000000
# 3319   CSebasGomez  jscontrerasp            5            5    0.092593
# 3320   jhcardenasa  jscontrerasp            5            5    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase45["functions"], df_phase45["Student"], df_phase45["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#               user1               user2  user1_phase  user2_phase  similarity
# 0         lemartinp           juligarji            4            4    0.136054
# 1         lemartinp           nfmorenog            4            4    0.038647
# 2         lemartinp           AFelipeGA            4            4    0.046809
# 3         lemartinp          mballeng91            4            4    0.159184
# 4         lemartinp            dduartec            4            4    0.037037
# ...             ...                 ...          ...          ...         ...
# 3316  jumcorredorro        Danielsv9207            5            5    0.000000
# 3317  jumcorredorro  JhonEmmanuelTorres            5            5    0.139535
# 3318     feartheGru        Danielsv9207            5            5    1.000000
# 3319     feartheGru  JhonEmmanuelTorres            5            5    0.000000
# 3320   Danielsv9207  JhonEmmanuelTorres            5            5    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase34["functions"], df_phase34["Student"], df_phase34["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df2 = pd.DataFrame(result)
df2
# Out:
#               user1               user2  user1_phase  user2_phase  similarity
# 0         lemartinp           juligarji            3            3    0.232227
# 1         lemartinp           nfmorenog            3            3    0.077519
# 2         lemartinp           AFelipeGA            3            3    0.097403
# 3         lemartinp          mballeng91            3            3    0.324503
# 4         lemartinp            dduartec            3            3    0.060870
# ...             ...                 ...          ...          ...         ...
# 3316  jumcorredorro        Danielsv9207            4            4    0.000000
# 3317  jumcorredorro  JhonEmmanuelTorres            4            4    0.200000
# 3318     feartheGru        Danielsv9207            4            4    1.000000
# 3319     feartheGru  JhonEmmanuelTorres            4            4    0.000000
# 3320   Danielsv9207  JhonEmmanuelTorres            4            4    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase34_bogota2["functions"], df_phase34_bogota2["Student"], df_phase34_bogota2["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df2_bogota2 = pd.DataFrame(result)
df2_bogota2
# Out:
#              user1         user2  user1_phase  user2_phase  similarity
# 0     jusherrerama       bdvegat            3            3    0.057692
# 1     jusherrerama    Phoenixest            3            3    0.146067
# 2     jusherrerama      HashNick            3            3    0.223881
# 3     jusherrerama       ccvacad            3            3    0.214286
# 4     jusherrerama    joaortizro            3            3    0.192771
# ...            ...           ...          ...          ...         ...
# 3316     xdanielsb   jhcardenasa            4            4    0.000000
# 3317     xdanielsb  jscontrerasp            4            4    0.009394
# 3318   CSebasGomez   jhcardenasa            4            4    0.000000
# 3319   CSebasGomez  jscontrerasp            4            4    0.095238
# 3320   jhcardenasa  jscontrerasp            4            4    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase34_bogota1["functions"], df_phase34_bogota1["Student"], df_phase34_bogota1["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df2_bogota1 = pd.DataFrame(result)
df2_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            3            3    0.000000
# 1          gasierram       bdcajicam            3            3    0.031250
# 2          gasierram  andfsanchezlem            3            3    0.006623
# 3          gasierram     dfhincapiem            3            3    0.031250
# 4          gasierram       helmeraac            3            3    0.049180
# ...              ...             ...          ...          ...         ...
# 3155  joahernandezca         Zeugmax            4            4    0.001454
# 3156  joahernandezca    JairVillalba            4            4    0.050420
# 3157         ItsNavi         Zeugmax            4            4    0.007039
# 3158         ItsNavi    JairVillalba            4            4    0.045918
# 3159         Zeugmax    JairVillalba            4            4    0.012558
#
# [3160 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase34_bogota0["functions"], df_phase34_bogota0["Student"], df_phase34_bogota0["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df2_bogota0 = pd.DataFrame(result)
df2_bogota0
# Out:
#           user1         user2  user1_phase  user2_phase  similarity
# 0     fffeelipe     mnguzmanc            3            3    0.000000
# 1     fffeelipe    jmcuestasb            3            3    0.000000
# 2     fffeelipe    katherinsb            3            3    0.000000
# 3     fffeelipe  jjrodriguezn            3            3    0.000000
# 4     fffeelipe         DglyP            3            3    0.000000
# ...         ...           ...          ...          ...         ...
# 2696  fmbernalb     yocuervoc            4            4    0.102564
# 2697  fmbernalb     odprietoh            4            4    0.081818
# 2698    MogGy94     yocuervoc            4            4    0.000000
# 2699    MogGy94     odprietoh            4            4    0.000000
# 2700  yocuervoc     odprietoh            4            4    0.037037
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase23["functions"], df_phase23["Student"], df_phase23["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df3 = pd.DataFrame(result)
df3
# Out:
#               user1               user2  user1_phase  user2_phase  similarity
# 0         lemartinp           juligarji            2            2    0.244186
# 1         lemartinp           nfmorenog            2            2    0.107143
# 2         lemartinp           AFelipeGA            2            2    0.130435
# 3         lemartinp          mballeng91            2            2    0.530864
# 4         lemartinp            dduartec            2            2    0.101449
# ...             ...                 ...          ...          ...         ...
# 3316  jumcorredorro        Danielsv9207            3            3    0.000000
# 3317  jumcorredorro  JhonEmmanuelTorres            3            3    0.136364
# 3318     feartheGru        Danielsv9207            3            3    1.000000
# 3319     feartheGru  JhonEmmanuelTorres            3            3    0.000000
# 3320   Danielsv9207  JhonEmmanuelTorres            3            3    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase23_bogota2["functions"], df_phase23_bogota2["Student"], df_phase23_bogota2["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df3_bogota2 = pd.DataFrame(result)
df3_bogota2
# Out:
#              user1         user2  user1_phase  user2_phase  similarity
# 0     jusherrerama       bdvegat            2            2    0.000000
# 1     jusherrerama    Phoenixest            2            2    0.200000
# 2     jusherrerama      HashNick            2            2    0.454545
# 3     jusherrerama       ccvacad            2            2    0.120000
# 4     jusherrerama    joaortizro            2            2    0.272727
# ...            ...           ...          ...          ...         ...
# 3316     xdanielsb   jhcardenasa            3            3    0.000000
# 3317     xdanielsb  jscontrerasp            3            3    0.007779
# 3318   CSebasGomez   jhcardenasa            3            3    0.000000
# 3319   CSebasGomez  jscontrerasp            3            3    0.111111
# 3320   jhcardenasa  jscontrerasp            3            3    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase23_bogota1["functions"], df_phase23_bogota1["Student"], df_phase23_bogota1["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df3_bogota1 = pd.DataFrame(result)
df3_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            2            2    0.000000
# 1          gasierram       bdcajicam            2            2    0.038462
# 2          gasierram  andfsanchezlem            2            2    0.015385
# 3          gasierram     dfhincapiem            2            2    0.037975
# 4          gasierram       helmeraac            2            2    0.049180
# ...              ...             ...          ...          ...         ...
# 3155  joahernandezca         Zeugmax            3            3    0.001454
# 3156  joahernandezca    JairVillalba            3            3    0.058252
# 3157         ItsNavi         Zeugmax            3            3    0.006619
# 3158         ItsNavi    JairVillalba            3            3    0.042424
# 3159         Zeugmax    JairVillalba            3            3    0.009813
#
# [3160 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase23_bogota0["functions"], df_phase23_bogota0["Student"], df_phase23_bogota0["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df3_bogota0 = pd.DataFrame(result)
df3_bogota0
# Out:
#           user1         user2  user1_phase  user2_phase  similarity
# 0     fffeelipe     mnguzmanc            2            2    0.000000
# 1     fffeelipe    jmcuestasb            2            2    0.000000
# 2     fffeelipe    katherinsb            2            2    0.000000
# 3     fffeelipe  jjrodriguezn            2            2    0.000000
# 4     fffeelipe         DglyP            2            2    0.000000
# ...         ...           ...          ...          ...         ...
# 2696  fmbernalb     yocuervoc            3            3    0.043478
# 2697  fmbernalb     odprietoh            3            3    0.060870
# 2698    MogGy94     yocuervoc            3            3    0.000000
# 2699    MogGy94     odprietoh            3            3    0.000000
# 2700  yocuervoc     odprietoh            3            3    0.037975
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase12["functions"], df_phase12["Student"], df_phase12["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df4 = pd.DataFrame(result)
df4
# Out:
#               user1               user2  user1_phase  user2_phase  similarity
# 0         lemartinp           juligarji            1            1    0.050955
# 1         lemartinp           nfmorenog            1            1    0.222222
# 2         lemartinp           AFelipeGA            1            1    0.073171
# 3         lemartinp          mballeng91            1            1    0.250000
# 4         lemartinp            dduartec            1            1    0.120000
# ...             ...                 ...          ...          ...         ...
# 3316  jumcorredorro        Danielsv9207            2            2    0.000000
# 3317  jumcorredorro  JhonEmmanuelTorres            2            2    0.187500
# 3318     feartheGru        Danielsv9207            2            2    1.000000
# 3319     feartheGru  JhonEmmanuelTorres            2            2    0.000000
# 3320   Danielsv9207  JhonEmmanuelTorres            2            2    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase12_bogota2["functions"], df_phase12_bogota2["Student"], df_phase12_bogota2["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df4_bogota2 = pd.DataFrame(result)
df4_bogota2
# Out:
#              user1         user2  user1_phase  user2_phase  similarity
# 0     jusherrerama       bdvegat            1            1    0.000000
# 1     jusherrerama    Phoenixest            1            1    0.162162
# 2     jusherrerama      HashNick            1            1    0.300000
# 3     jusherrerama       ccvacad            1            1    0.333333
# 4     jusherrerama    joaortizro            1            1    0.102564
# ...            ...           ...          ...          ...         ...
# 3316     xdanielsb   jhcardenasa            2            2    0.000000
# 3317     xdanielsb  jscontrerasp            2            2    0.283019
# 3318   CSebasGomez   jhcardenasa            2            2    0.000000
# 3319   CSebasGomez  jscontrerasp            2            2    0.135135
# 3320   jhcardenasa  jscontrerasp            2            2    0.000000
#
# [3321 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase12_bogota1["functions"], df_phase12_bogota1["Student"], df_phase12_bogota1["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df4_bogota1 = pd.DataFrame(result)
df4_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            1            1    1.000000
# 1          gasierram       bdcajicam            1            1    0.000000
# 2          gasierram  andfsanchezlem            1            1    0.000000
# 3          gasierram     dfhincapiem            1            1    0.000000
# 4          gasierram       helmeraac            1            1    0.000000
# ...              ...             ...          ...          ...         ...
# 3155  joahernandezca         Zeugmax            2            2    0.001454
# 3156  joahernandezca    JairVillalba            2            2    0.053763
# 3157         ItsNavi         Zeugmax            2            2    0.002903
# 3158         ItsNavi    JairVillalba            2            2    0.050000
# 3159         Zeugmax    JairVillalba            2            2    0.008443
#
# [3160 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase12_bogota0["functions"], df_phase12_bogota0["Student"], df_phase12_bogota0["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df4_bogota0 = pd.DataFrame(result)
df4_bogota0
# Out:
#           user1         user2  user1_phase  user2_phase  similarity
# 0     fffeelipe     mnguzmanc            1            1    0.000000
# 1     fffeelipe    jmcuestasb            1            1    0.000000
# 2     fffeelipe    katherinsb            1            1    0.000000
# 3     fffeelipe  jjrodriguezn            1            1    0.000000
# 4     fffeelipe         DglyP            1            1    1.000000
# ...         ...           ...          ...          ...         ...
# 2696  fmbernalb     yocuervoc            2            2    0.047619
# 2697  fmbernalb     odprietoh            2            2    0.067568
# 2698    MogGy94     yocuervoc            2            2    0.000000
# 2699    MogGy94     odprietoh            2            2    0.000000
# 2700  yocuervoc     odprietoh            2            2    0.075000
#
# [2701 rows x 5 columns]

# %%
phase12_bogota3 = df4[df4['user1'] == df4['user2']]
phase12_bogota3
# Out:
#                    user1               user2  user1_phase  user2_phase  \
# 40             lemartinp           lemartinp            1            2
# 121            juligarji           juligarji            1            2
# 201            nfmorenog           nfmorenog            1            2
# 280            AFelipeGA           AFelipeGA            1            2
# 358           mballeng91          mballeng91            1            2
# 435             dduartec            dduartec            1            2
# 511            srmedinac           srmedinac            1            2
# 586         wilson911013        wilson911013            1            2
# 660        wapiravaguens       wapiravaguens            1            2
# 733             davidh17            davidh17            1            2
# 805       DianaNavarrete      DianaNavarrete            1            2
# 876            jdmonroyg           jdmonroyg            1            2
# 946            jorge52an           jorge52an            1            2
# 1015     jscastelblancoh     jscastelblancoh            1            2
# 1083          juclopezso          juclopezso            1            2
# 1150           afforeroc           afforeroc            1            2
# 1216         dagofonseca         dagofonseca            1            2
# 1281         lacardenasv         lacardenasv            1            2
# 1345         oacastillol         oacastillol            1            2
# 1408          ncampuzano          ncampuzano            1            2
# 1470            adriel62            adriel62            1            2
# 1531            capinzor            capinzor            1            2
# 1591            ofnanezn            ofnanezn            1            2
# 1650           macuestap           macuestap            1            2
# 1708              spenas              spenas            1            2
# 1765         kgbayala528         kgbayala528            1            2
# 1821          lgmoralesa          lgmoralesa            1            2
# 1876          ronaldsg20          ronaldsg20            1            2
# 1930       cccristanchoc       cccristanchoc            1            2
# 1983          jmalvarezd          jmalvarezd            1            2
# 2035           smarquezo           smarquezo            1            2
# 2086             sarizag             sarizag            1            2
# 2136            Chranium            Chranium            1            2
# 2185             DavidQP             DavidQP            1            2
# 2233         afceballosr         afceballosr            1            2
# 2280           lizzyt10h           lizzyt10h            1            2
# 2326          NicolasPrr          NicolasPrr            1            2
# 2371       jumcorredorro       jumcorredorro            1            2
# 2415          feartheGru          feartheGru            1            2
# 2458        Danielsv9207        Danielsv9207            1            2
# 2500  JhonEmmanuelTorres  JhonEmmanuelTorres            1            2
#
#       similarity
# 40      0.234375
# 121     1.000000
# 201     0.566667
# 280     0.725000
# 358     0.194030
# 435     0.923077
# 511     0.962963
# 586     0.481481
# 660     0.645161
# 733     0.647059
# 805     1.000000
# 876     0.954545
# 946     0.562500
# 1015    1.000000
# 1083    0.148148
# 1150    0.861702
# 1216    1.000000
# 1281    0.245902
# 1345    1.000000
# 1408    0.600000
# 1470    0.340909
# 1531    0.111588
# 1591    0.791667
# 1650    0.094891
# 1708    0.898305
# 1765    0.189655
# 1821    0.431818
# 1876    0.400000
# 1930    1.000000
# 1983    0.739130
# 2035    0.725490
# 2086    1.000000
# 2136    0.440000
# 2185    1.000000
# 2233    0.010802
# 2280    0.789474
# 2326    1.000000
# 2371    1.000000
# 2415    1.000000
# 2458    1.000000
# 2500    1.000000

# %%
phase45_bogota3 = df1[df1['user1'] == df1['user2']]
phase45_bogota3
# Out:
#                    user1               user2  user1_phase  user2_phase  \
# 40             lemartinp           lemartinp            4            5
# 121            juligarji           juligarji            4            5
# 201            nfmorenog           nfmorenog            4            5
# 280            AFelipeGA           AFelipeGA            4            5
# 358           mballeng91          mballeng91            4            5
# 435             dduartec            dduartec            4            5
# 511            srmedinac           srmedinac            4            5
# 586         wilson911013        wilson911013            4            5
# 660        wapiravaguens       wapiravaguens            4            5
# 733             davidh17            davidh17            4            5
# 805       DianaNavarrete      DianaNavarrete            4            5
# 876            jdmonroyg           jdmonroyg            4            5
# 946            jorge52an           jorge52an            4            5
# 1015     jscastelblancoh     jscastelblancoh            4            5
# 1083          juclopezso          juclopezso            4            5
# 1150           afforeroc           afforeroc            4            5
# 1216         dagofonseca         dagofonseca            4            5
# 1281         lacardenasv         lacardenasv            4            5
# 1345         oacastillol         oacastillol            4            5
# 1408          ncampuzano          ncampuzano            4            5
# 1470            adriel62            adriel62            4            5
# 1531            capinzor            capinzor            4            5
# 1591            ofnanezn            ofnanezn            4            5
# 1650           macuestap           macuestap            4            5
# 1708              spenas              spenas            4            5
# 1765         kgbayala528         kgbayala528            4            5
# 1821          lgmoralesa          lgmoralesa            4            5
# 1876          ronaldsg20          ronaldsg20            4            5
# 1930       cccristanchoc       cccristanchoc            4            5
# 1983          jmalvarezd          jmalvarezd            4            5
# 2035           smarquezo           smarquezo            4            5
# 2086             sarizag             sarizag            4            5
# 2136            Chranium            Chranium            4            5
# 2185             DavidQP             DavidQP            4            5
# 2233         afceballosr         afceballosr            4            5
# 2280           lizzyt10h           lizzyt10h            4            5
# 2326          NicolasPrr          NicolasPrr            4            5
# 2371       jumcorredorro       jumcorredorro            4            5
# 2415          feartheGru          feartheGru            4            5
# 2458        Danielsv9207        Danielsv9207            4            5
# 2500  JhonEmmanuelTorres  JhonEmmanuelTorres            4            5
#
#       similarity
# 40      0.989247
# 121     1.000000
# 201     0.775000
# 280     0.878788
# 358     0.787402
# 435     1.000000
# 511     1.000000
# 586     0.603687
# 660     0.741379
# 733     0.894180
# 805     1.000000
# 876     1.000000
# 946     1.000000
# 1015    1.000000
# 1083    1.000000
# 1150    0.488172
# 1216    0.003910
# 1281    1.000000
# 1345    1.000000
# 1408    0.540541
# 1470    1.000000
# 1531    0.936567
# 1591    0.824742
# 1650    0.993007
# 1708    1.000000
# 1765    0.858025
# 1821    0.431818
# 1876    1.000000
# 1930    0.471074
# 1983    0.948339
# 2035    1.000000
# 2086    1.000000
# 2136    0.923077
# 2185    0.986037
# 2233    0.997013
# 2280    0.425926
# 2326    1.000000
# 2371    1.000000
# 2415    1.000000
# 2458    1.000000
# 2500    0.518519

# %% [markdown]
# ## Get Individual Exploration Rows

# %% [markdown]
# ## Phase 4 and Phase 5

# %%
phase45_bogota3 = df1[df1['user1'] == df1['user2']]
phase45_bogota2 = df1_bogota2[df1_bogota2['user1'] == df1_bogota2['user2']]
phase45_bogota1 = df1_bogota1[df1_bogota1['user1'] == df1_bogota1['user2']]
phase45_bogota0 = df1_bogota0[df1_bogota0['user1'] == df1_bogota0['user2']]

# %% [markdown]
# ## Phase 3 and Phase 4

# %%
phase34_bogota3 = df2[df2['user1'] == df2['user2']]
phase34_bogota2 = df2_bogota2[df2_bogota2['user1'] == df2_bogota2['user2']]
phase34_bogota1 = df2_bogota1[df2_bogota1['user1'] == df2_bogota1['user2']]
phase34_bogota0 = df2_bogota0[df2_bogota0['user1'] == df2_bogota0['user2']]

# %% [markdown]
# ## Phase 2 and Phase 3

# %%
phase23_bogota3 = df3[df3['user1'] == df3['user2']]
phase23_bogota2 = df3_bogota2[df3_bogota2['user1'] == df3_bogota2['user2']]
phase23_bogota1 = df3_bogota1[df3_bogota1['user1'] == df3_bogota1['user2']]
phase23_bogota0 = df3_bogota0[df3_bogota0['user1'] == df3_bogota0['user2']]

# %% [markdown]
# ## Phase 1 and Phase 2

# %%
phase12_bogota3 = df4[df4['user1'] == df4['user2']]
phase12_bogota2 = df4_bogota2[df4_bogota2['user1'] == df4_bogota2['user2']]
phase12_bogota1 = df4_bogota1[df4_bogota1['user1'] == df4_bogota1['user2']]
phase12_bogota0 = df4_bogota0[df4_bogota0['user1'] == df4_bogota0['user2']]

# %% [markdown]
# ## Get Distributions Before Transformation

# %%
phase45_bogota3['phase'] = 'phase45'
phase34_bogota3['phase'] = 'phase34'
phase23_bogota3['phase'] = 'phase23'
phase12_bogota3['phase'] = 'phase12'
df_bogota3 = pd.concat([phase45_bogota3, phase34_bogota3, phase23_bogota3, phase12_bogota3], ignore_index=True)
df_bogota3['exploration'] = 1 - df_bogota3['similarity']
# Out:
# <ipython-input-73-4a7c55853afa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase45_bogota3['phase'] = 'phase45'
# <ipython-input-73-4a7c55853afa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase34_bogota3['phase'] = 'phase34'
# <ipython-input-73-4a7c55853afa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase23_bogota3['phase'] = 'phase23'
# <ipython-input-73-4a7c55853afa>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase12_bogota3['phase'] = 'phase12'

# %%
import pylab as pl

#df_bogota3.hist(column='exploration', by='phase')
#pl.suptitle("Bogota 3")
sns.displot(x='exploration', data=df_bogota3, hue="phase", col="phase", kde=True)

# %% [markdown]
# >> Comments: Distribution becomes more skewed over time.

# %%
phase45_bogota2['phase'] = 'phase45'
phase34_bogota2['phase'] = 'phase34'
phase23_bogota2['phase'] = 'phase23'
phase12_bogota2['phase'] = 'phase12'
df_bogota2 = pd.concat([phase45_bogota2, phase34_bogota2, phase23_bogota2, phase12_bogota2], ignore_index=True)
df_bogota2['exploration'] = 1 - df_bogota2['similarity']
# Out:
# <ipython-input-75-02c62759ca30>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase45_bogota2['phase'] = 'phase45'
# <ipython-input-75-02c62759ca30>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase34_bogota2['phase'] = 'phase34'
# <ipython-input-75-02c62759ca30>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase23_bogota2['phase'] = 'phase23'
# <ipython-input-75-02c62759ca30>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase12_bogota2['phase'] = 'phase12'

# %%
import pylab as pl

#df_bogota2.hist(column='exploration', by='phase')
#pl.suptitle("Bogota 2")
sns.displot(x='exploration', data=df_bogota2, hue="phase", col="phase", kde=True)

# %%
phase45_bogota1['phase'] = 'phase45'
phase34_bogota1['phase'] = 'phase34'
phase23_bogota1['phase'] = 'phase23'
phase12_bogota1['phase'] = 'phase12'
df_bogota1 = pd.concat([phase45_bogota1, phase34_bogota1, phase23_bogota1, phase12_bogota1], ignore_index=True)
df_bogota1['exploration'] = 1 - df_bogota1['similarity']
# Out:
# <ipython-input-77-e9baf3b9d1a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase45_bogota1['phase'] = 'phase45'
# <ipython-input-77-e9baf3b9d1a3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase34_bogota1['phase'] = 'phase34'
# <ipython-input-77-e9baf3b9d1a3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase23_bogota1['phase'] = 'phase23'
# <ipython-input-77-e9baf3b9d1a3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase12_bogota1['phase'] = 'phase12'

# %%
import pylab as pl

#df_bogota1.hist(column='exploration', by='phase')
#pl.suptitle("Bogota 1")
sns.displot(x='exploration', data=df_bogota1, hue="phase", col="phase", kde=True)

# %%
phase45_bogota0['phase'] = 'phase45'
phase34_bogota0['phase'] = 'phase34'
phase23_bogota0['phase'] = 'phase23'
phase12_bogota0['phase'] = 'phase12'
df_bogota0 = pd.concat([phase45_bogota0, phase34_bogota0, phase23_bogota0, phase12_bogota0], ignore_index=True)
df_bogota0['exploration'] = 1 - df_bogota1['similarity']
# Out:
# <ipython-input-79-b51c70e5f5ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase45_bogota0['phase'] = 'phase45'
# <ipython-input-79-b51c70e5f5ec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase34_bogota0['phase'] = 'phase34'
# <ipython-input-79-b51c70e5f5ec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase23_bogota0['phase'] = 'phase23'
# <ipython-input-79-b51c70e5f5ec>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase12_bogota0['phase'] = 'phase12'

# %%
import pylab as pl

#df_bogota0.hist(column='exploration', by='phase')
#pl.suptitle("Bogota 0")
sns.displot(x='exploration', data=df_bogota0, hue="phase", col="phase", kde=True)

# %% [markdown]
# ## Distributions after Log-Transformation

# %%
import seaborn as sns 

for df in [phase12_bogota0, phase23_bogota0, phase34_bogota0, phase45_bogota0]:
    plt.figure()
    plt.title("Exploration Plot Bogota 0")
    sns.distplot((np.arcsin(1-df['similarity'])))
    #print(shapiro((np.log(1-df['similarity']+1))))
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# >> Interpretation:
#     Over time, data become more skewed for the case of bogota 0 ( no transparency case ). Smaller number of people are exploring over time. The data is skewed so we should look at median rather than mean.

# %%
import seaborn as sns 

for df in [phase12_bogota1, phase23_bogota1, phase34_bogota1, phase45_bogota1]:
    plt.figure()
    plt.title("Exploration Plot Bogota 1")
    sns.distplot((1-np.arcsin(df['similarity'])))
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns 

for df in [phase12_bogota2, phase23_bogota2, phase34_bogota2, phase45_bogota2]:
    plt.figure()
    plt.title("Exploration Plot Bogota 2")
    sns.distplot((1-np.arcsin(df['similarity'])))
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns 

for df in [phase12_bogota3, phase23_bogota3, phase34_bogota3, phase45_bogota3]:
    plt.figure()
    plt.title("Exploration Plot Bogota 3")
    sns.distplot((1-np.arcsin(df['similarity'])))
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# > Interpretation: The distributions tend to be normal at the beginning of the phase, specifially phase 1 - 2, but the distributions are
# getting more positively skewed over time.

# %%
median_log_bogota3 = []
median_log_bogota2 = []
median_log_bogota1 = []
median_log_bogota0 = []

for df in [phase12_bogota3, phase23_bogota3, phase34_bogota3, phase45_bogota3]:
    median_value = (np.arcsin(1-df['similarity'])).median()
    median_log_bogota3.append(median_value)

for df in [phase12_bogota2, phase23_bogota2, phase34_bogota2, phase45_bogota2]:
    median_value = (np.arcsin(1-df['similarity'])).median()
    median_log_bogota2.append(median_value)
    
for df in [phase12_bogota1, phase23_bogota1, phase34_bogota1, phase45_bogota1]:
    median_value = (np.arcsin(1-df['similarity'])).median()
    median_log_bogota1.append(median_value)

for df in [phase12_bogota0, phase23_bogota0, phase34_bogota0, phase45_bogota0]:
    median_value = (np.arcsin(1-df['similarity'])).median()
    median_log_bogota0.append(median_value)

# %%
mean_log_bogota3 = []
mean_log_bogota2 = []
mean_log_bogota1 = []
mean_log_bogota0 = []

max_log_bogota3 = []
max_log_bogota2 = []
max_log_bogota1 = []
max_log_bogota0 = []

for df in [phase12_bogota3, phase23_bogota3, phase34_bogota3, phase45_bogota3]:
    mean_value = (np.log(1-df['similarity']+1)).mean()
    max_value = (np.log(1-df['similarity']+1)).max()
    mean_log_bogota3.append(mean_value)
    max_log_bogota3.append(max_value)

for df in [phase12_bogota2, phase23_bogota2, phase34_bogota2, phase45_bogota2]:
    mean_value = (np.log(1-df['similarity']+1)).mean()
    max_value = (np.log(1-df['similarity']+1)).max()
    mean_log_bogota2.append(mean_value)
    max_log_bogota2.append(max_value)
    
for df in [phase12_bogota1, phase23_bogota1, phase34_bogota1, phase45_bogota1]:
    mean_value = (np.log(1-df['similarity']+1)).mean()
    max_value = (np.log(1-df['similarity']+1)).max()
    mean_log_bogota1.append(mean_value)
    max_log_bogota1.append(max_value)

for df in [phase12_bogota0, phase23_bogota0, phase34_bogota0, phase45_bogota0]:
    mean_value = (np.log(1-df['similarity']+1)).mean()
    max_value = (np.log(1-df['similarity']+1)).max()
    mean_log_bogota0.append(mean_value)
    max_log_bogota0.append(max_value)

# %%
y1 = max_log_bogota0
y2 = max_log_bogota1
y3 = max_log_bogota2
y4 = max_log_bogota3

x_axis=['Phase 1-2', 'Phase 2-3', 'Phase 3-4', 'Phase 4-5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Max Log-Transform Exploration")
plt.ylabel("Max Log-Transform Exploration")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
y1 = median_log_bogota0
y2 = median_log_bogota1
y3 = median_log_bogota2
y4 = median_log_bogota3

x_axis=['Phase 1-2', 'Phase 2-3', 'Phase 3-4', 'Phase 4-5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median Log-Transform Exploration")
plt.ylabel("Median Log-Transform-Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
y1 = mean_log_bogota0
y2 = mean_log_bogota1
y3 = mean_log_bogota2
y4 = mean_log_bogota3

x_axis=['Phase 1-2', 'Phase 2-3', 'Phase 3-4', 'Phase 4-5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Mean Log-Transform Exploration")
plt.ylabel("Mean Log-Transform Exploration")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# > The first option is to run 4 regression model with the treatment as the independent variables and the exploration as the dependent variables. We would control for the exploration in the prior phase. This is the not optimal method, but we can do this for now.
#
# > Linear model with log-transformed data / negative binominal or poisson regression for skewed outcomes.
#
# > Look up Bernstein paper and get clarity on the modeling.
#
# > Also read up on fixed and variable effects.

# %% [markdown]
# ## Test Code

# %%
## Jaccard similarity with List

import itertools
import pandas as pd

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# set initial data and create dataframe
data = {"wordings": [[], [], ['apple','jackfruit'], ['banana','jackfruit','berries','apple'], ['apple']], "users": ['adeline', 'adeline', 'kenzi', 'ericko', 'mary'], "phase":[1, 3, 2, 2, 3], "group": [1, 2, 2, 3, 3]}
df = pd.DataFrame(data)
print(df)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(df["wordings"], df["users"], df["phase"], df["group"]))
print(wordings_users)

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "phase1": item[0][2], "phase2": item[1][2], "group1": item[0][3], "group2": item[1][3], "similarity": similarity}
    result.append(data)

df1_test = pd.DataFrame(result)
df1_test
# Out:
#                               wordings    users  phase  group
# 0                                   []  adeline      1      1
# 1                                   []  adeline      3      2
# 2                   [apple, jackfruit]    kenzi      2      2
# 3  [banana, jackfruit, berries, apple]   ericko      2      3
# 4                              [apple]     mary      3      3
# [([], 'adeline', 1, 1), ([], 'adeline', 3, 2), (['apple', 'jackfruit'], 'kenzi', 2, 2), (['banana', 'jackfruit', 'berries', 'apple'], 'ericko', 2, 3), (['apple'], 'mary', 3, 3)]
#      user1    user2  phase1  phase2  group1  group2  similarity
# 0  adeline  adeline       1       3       1       2        1.00
# 1  adeline    kenzi       1       2       1       2        0.00
# 2  adeline   ericko       1       2       1       3        0.00
# 3  adeline     mary       1       3       1       3        0.00
# 4  adeline    kenzi       3       2       2       2        0.00
# 5  adeline   ericko       3       2       2       3        0.00
# 6  adeline     mary       3       3       2       3        0.00
# 7    kenzi   ericko       2       2       2       3        0.50
# 8    kenzi     mary       2       3       2       3        0.50
# 9   ericko     mary       2       3       3       3        0.25

# %%
import itertools
import pandas as pd

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# set initial data and create dataframe
data = {"wordings": ["apple,banana,orange,pears", "apple, banana", "apple,jackfruit", "banana,jackfruit,berries,apple", "berries,grapes,watermelon"], "users": ["adeline", "adeline", "kenzi", "ericko", "mary"], "phase":[1, 3, 2, 2, 3], "group": [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)
print(df)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(df["wordings"], df["users"], df["phase"], df["group"]))
print(wordings_users)

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "phase1": item[0][2], "phase2": item[1][2], "group1": item[0][3], "group2": item[1][3], "similarity": similarity}
    result.append(data)

df1_test = pd.DataFrame(result)
df1_test
# Out:
#                          wordings    users  phase  group
# 0       apple,banana,orange,pears  adeline      1      1
# 1                   apple, banana  adeline      3      2
# 2                 apple,jackfruit    kenzi      2      3
# 3  banana,jackfruit,berries,apple   ericko      2      4
# 4       berries,grapes,watermelon     mary      3      5
# [('apple,banana,orange,pears', 'adeline', 1, 1), ('apple, banana', 'adeline', 3, 2), ('apple,jackfruit', 'kenzi', 2, 3), ('banana,jackfruit,berries,apple', 'ericko', 2, 4), ('berries,grapes,watermelon', 'mary', 3, 5)]
#      user1    user2  phase1  phase2  group1  group2  similarity
# 0  adeline  adeline       1       3       1       2    0.583333
# 1  adeline    kenzi       1       2       1       3    0.333333
# 2  adeline   ericko       1       2       1       4    0.500000
# 3  adeline     mary       1       3       1       5    0.733333
# 4  adeline    kenzi       3       2       2       3    0.312500
# 5  adeline   ericko       3       2       2       4    0.411765
# 6  adeline     mary       3       3       2       5    0.437500
# 7    kenzi   ericko       2       2       3       4    0.812500
# 8    kenzi     mary       2       3       3       5    0.400000
# 9   ericko     mary       2       3       4       5    0.550000

# %%
# %store df1
# %store df2
# %store df3
# %store df4

# %store df1_bogota0
# %store df2_bogota0
# %store df3_bogota0
# %store df4_bogota0

# %store df1_bogota1
# %store df2_bogota1
# %store df3_bogota1
# %store df4_bogota1

# %store df1_bogota2
# %store df2_bogota2
# %store df3_bogota2
# %store df4_bogota2

# %store subset_bogota0_phase1
# %store subset_bogota0_phase2
# %store subset_bogota0_phase3
# %store overall_phase3_bogota0
# %store subset_bogota0_phase4
# %store overall_phase4_bogota0
# %store overall_phase5_bogota0
# %store subset_bogota0_phase5
# %store subset_bogota1_phase1
# %store subset_bogota1_phase2
# %store subset_bogota1_phase3
# %store overall_phase3_bogota1
# %store overall_phase4_bogota1
# %store overall_phase5_bogota1
# %store subset_bogota1_phase4
# %store subset_bogota1_phase5
# %store subset_bogota2_phase1
# %store subset_bogota2_phase2
# %store subset_bogota2_phase3
# %store overall_phase3_bogota2
# %store overall_phase4_bogota2
# %store subset_bogota2_phase5
# %store overall_phase5_bogota2
# %store subset_bogota3_phase1
# %store overall_phase1_bogota3
# %store overall_phase2_bogota3
# %store overall_phase3_bogota3
# %store subset_bogota3_phase3
# %store overall_phase4_bogota3
# %store overall_phase5_bogota3
# %store subset_bogota2_phase4


# %store overall_phase2_bogota0
# %store overall_phase2_bogota1
# %store overall_phase2_bogota2
# %store overall_phase2_bogota3


# %store overall_phase1_bogota0
# %store overall_phase1_bogota1
# %store overall_phase1_bogota2
# %store overall_phase1_bogota3


# %store overall_phase1
# %store overall_phase2
# %store overall_phase3
# %store overall_phase4
# %store overall_phase5
# Out:
# Stored 'df1' (DataFrame)
# Stored 'df2' (DataFrame)
# Stored 'df3' (DataFrame)
# Stored 'df4' (DataFrame)
# Stored 'df1_bogota0' (DataFrame)
# Stored 'df2_bogota0' (DataFrame)
# Stored 'df3_bogota0' (DataFrame)
# Stored 'df4_bogota0' (DataFrame)
# Stored 'df1_bogota1' (DataFrame)
# Stored 'df2_bogota1' (DataFrame)
# Stored 'df3_bogota1' (DataFrame)
# Stored 'df4_bogota1' (DataFrame)
# Stored 'df1_bogota2' (DataFrame)
# Stored 'df2_bogota2' (DataFrame)
# Stored 'df3_bogota2' (DataFrame)
# Stored 'df4_bogota2' (DataFrame)
# Stored 'subset_bogota0_phase1' (DataFrame)
# Stored 'subset_bogota0_phase2' (DataFrame)
# Stored 'subset_bogota0_phase3' (DataFrame)
# Stored 'overall_phase3_bogota0' (DataFrame)
# Stored 'subset_bogota0_phase4' (DataFrame)
# Stored 'overall_phase4_bogota0' (DataFrame)
# Stored 'overall_phase5_bogota0' (DataFrame)
# Stored 'subset_bogota0_phase5' (DataFrame)
# Stored 'subset_bogota1_phase1' (DataFrame)
# Stored 'subset_bogota1_phase2' (DataFrame)
# Stored 'subset_bogota1_phase3' (DataFrame)
# Stored 'overall_phase3_bogota1' (DataFrame)
# Stored 'overall_phase4_bogota1' (DataFrame)
# Stored 'overall_phase5_bogota1' (DataFrame)
# Stored 'subset_bogota1_phase4' (DataFrame)
# Stored 'subset_bogota1_phase5' (DataFrame)
# Stored 'subset_bogota2_phase1' (DataFrame)
# Stored 'subset_bogota2_phase2' (DataFrame)
# Stored 'subset_bogota2_phase3' (DataFrame)
# Stored 'overall_phase3_bogota2' (DataFrame)
# Stored 'overall_phase4_bogota2' (DataFrame)
# Stored 'subset_bogota2_phase5' (DataFrame)
# Stored 'overall_phase5_bogota2' (DataFrame)
# Stored 'subset_bogota3_phase1' (DataFrame)
# Stored 'overall_phase1_bogota3' (DataFrame)
# Stored 'overall_phase2_bogota3' (DataFrame)
# Stored 'overall_phase3_bogota3' (DataFrame)
# Stored 'subset_bogota3_phase3' (DataFrame)
# Stored 'overall_phase4_bogota3' (DataFrame)
# Stored 'overall_phase5_bogota3' (DataFrame)
# Stored 'subset_bogota2_phase4' (DataFrame)
# Stored 'overall_phase2_bogota0' (DataFrame)
# Stored 'overall_phase2_bogota1' (DataFrame)
# Stored 'overall_phase2_bogota2' (DataFrame)
# Stored 'overall_phase2_bogota3' (DataFrame)
# Stored 'overall_phase1_bogota0' (DataFrame)
# Stored 'overall_phase1_bogota1' (DataFrame)
# Stored 'overall_phase1_bogota2' (DataFrame)
# Stored 'overall_phase1_bogota3' (DataFrame)
# Stored 'overall_phase1' (DataFrame)
# Stored 'overall_phase2' (DataFrame)
# Stored 'overall_phase3' (DataFrame)
# Stored 'overall_phase4' (DataFrame)
# Stored 'overall_phase5' (DataFrame)

# %%
# to be used in correlation notebook

# %store phase12_bogota0
# %store phase23_bogota0
# %store phase34_bogota0
# %store phase45_bogota0

# %store phase12_bogota1
# %store phase23_bogota1
# %store phase34_bogota1
# %store phase45_bogota1

# %store phase12_bogota2
# %store phase23_bogota2
# %store phase34_bogota2
# %store phase45_bogota2

# %store phase12_bogota3
# %store phase23_bogota3
# %store phase34_bogota3
# %store phase45_bogota3
# Out:
# Stored 'phase12_bogota0' (DataFrame)
# Stored 'phase23_bogota0' (DataFrame)
# Stored 'phase34_bogota0' (DataFrame)
# Stored 'phase45_bogota0' (DataFrame)
# Stored 'phase12_bogota1' (DataFrame)
# Stored 'phase23_bogota1' (DataFrame)
# Stored 'phase34_bogota1' (DataFrame)
# Stored 'phase45_bogota1' (DataFrame)
# Stored 'phase12_bogota2' (DataFrame)
# Stored 'phase23_bogota2' (DataFrame)
# Stored 'phase34_bogota2' (DataFrame)
# Stored 'phase45_bogota2' (DataFrame)
# Stored 'phase12_bogota3' (DataFrame)
# Stored 'phase23_bogota3' (DataFrame)
# Stored 'phase34_bogota3' (DataFrame)
# Stored 'phase45_bogota3' (DataFrame)

# %% [markdown]
# > Interpretation: We see higher exploration in the first phase and declining explorations over time. However, it's not a linear decline, we see an inverted relationship. We should check whether in line with the prediction of the Billinger.
#
# > Modeling implication: we should run a regression model or HLM model where the phase transitions is a variable effect. Purpose a model structure for this.
#
# > Do a T-test on the mean. Do a T-test on the max.

# %% [markdown]
# ## T-test

# %%
# T-tests between Bogota 3 and Bogota 0

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [phase12_bogota0, phase23_bogota0, phase34_bogota0, phase45_bogota0], [phase12_bogota3, phase23_bogota3, phase34_bogota3, phase45_bogota3]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(1-list1[x]['similarity']+1), np.log(1-list2[y]['similarity']+1), equal_var = False, alternative = 'less')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[0] == df.group2.str.split("_", expand=True)[0]]
# Out:
#              group1           group2  statistics    pvalue
# 0   phase12_bogota0  phase12_bogota3    1.257599  0.893677
# 5   phase23_bogota0  phase23_bogota3   -1.546662  0.063049
# 10  phase34_bogota0  phase34_bogota3    0.362286  0.640921
# 15  phase45_bogota0  phase45_bogota3    0.360076  0.640042

# %%
# T-tests between Bogota 2 and Bogota 3

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [phase12_bogota2, phase23_bogota2, phase34_bogota2, phase45_bogota2], [phase12_bogota3, phase23_bogota3, phase34_bogota3, phase45_bogota3]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(1-list1[x]['similarity']+1), np.log(1-list2[y]['similarity']+1), equal_var = False, alternative = 'greater')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[0] == df.group2.str.split("_", expand=True)[0]]
# Out:
#              group1           group2  statistics    pvalue
# 0   phase12_bogota2  phase12_bogota3    0.979033  0.165304
# 5   phase23_bogota2  phase23_bogota3   -1.532119  0.935279
# 10  phase34_bogota2  phase34_bogota3    0.106420  0.457758
# 15  phase45_bogota2  phase45_bogota3   -0.696926  0.756062

# %%
# T-tests between Bogota 0 and Bogota 1

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [phase12_bogota0, phase23_bogota0, phase34_bogota0, phase45_bogota0], [phase12_bogota1, phase23_bogota1, phase34_bogota1, phase45_bogota1]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(1-list1[x]['similarity']+1), np.log(1-list2[y]['similarity']+1), equal_var = False, alternative = 'less')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[0] == df.group2.str.split("_", expand=True)[0]]
# Out:
#              group1           group2  statistics    pvalue
# 0   phase12_bogota0  phase12_bogota1   -0.361176  0.359504
# 5   phase23_bogota0  phase23_bogota1   -0.744187  0.229557
# 10  phase34_bogota0  phase34_bogota1    0.543742  0.705853
# 15  phase45_bogota0  phase45_bogota1    0.865236  0.804981

# %%
# T-tests between Bogota 1 and Bogota 3

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [phase12_bogota1, phase23_bogota1, phase34_bogota1, phase45_bogota1], [phase12_bogota3, phase23_bogota3, phase34_bogota3, phase45_bogota3]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        
        # Now, I am calculating the t-test with the assumptions of 2 independent samples where one sample 
        # is the log-transform one treatment group in a particular phase. https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html
        # The package tests the null hypothesis (H0) that there is no significant difference in the mean between 2 independent samples.  
        
        ttest_result = ttest_ind(np.log(1-list1[x]['similarity']+1), np.log(1-list2[y]['similarity']+1), equal_var = False, alternative = 'less' )
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[0] == df.group2.str.split("_", expand=True)[0]]
# Out:
#              group1           group2  statistics    pvalue
# 0   phase12_bogota1  phase12_bogota3    1.748467  0.957846
# 5   phase23_bogota1  phase23_bogota3   -0.869252  0.193685
# 10  phase34_bogota1  phase34_bogota3   -0.173318  0.431424
# 15  phase45_bogota1  phase45_bogota3   -0.604062  0.273767

# %% [markdown]
# ## Comments

# %% [markdown]
# > Significant Difference Between Full Transparency and No Transparency
# * Stage 3 - 0.014828
