# %% [markdown]
# # Functional Variety
#
# > The concept of variety comes from Schilling et al. (2011) where the authors separated the cites into classes and assigns point system to each of those classes.

# %%
# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5
# %store -r df_all
# %store -r overall_loc_scores_final
# %store -r overall_loc_scores


# %store -r subset_bogota0_phase1
# %store -r subset_bogota0_phase2
# %store -r subset_bogota0_phase3
# %store -r overall_phase4_bogota0
# %store -r subset_bogota0_phase5
# %store -r subset_bogota1_phase1
# %store -r subset_bogota1_phase2
# %store -r subset_bogota1_phase3
# %store -r overall_phase4_bogota1
# %store -r overall_phase5_bogota1
# %store -r subset_bogota2_phase1
# %store -r subset_bogota2_phase2
# %store -r subset_bogota2_phase3
# %store -r overall_phase4_bogota2
# %store -r subset_bogota2_phase5
# %store -r subset_bogota3_phase1
# %store -r overall_phase1_bogota3
# %store -r overall_phase2_bogota3
# %store -r subset_bogota3_phase3
# %store -r overall_phase4_bogota3
# %store -r overall_phase5_bogota3

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind

# %%
overall_phase1 = overall_phase1.fillna(0)
overall_phase2 = overall_phase2.fillna(0)
overall_phase3 = overall_phase3.fillna(0)
overall_phase4 = overall_phase4.fillna(0)
overall_phase5 = overall_phase5.fillna(0)

# %%
overall_phase1_bogota0 = overall_phase1.loc[overall_phase1['Group'] == 0]
overall_phase1_bogota1 = overall_phase1.loc[overall_phase1['Group'] == 1]
overall_phase1_bogota2 = overall_phase1.loc[overall_phase1['Group'] == 2]
overall_phase1_bogota3 = overall_phase1.loc[overall_phase1['Group'] == 3]

# %%
overall_phase2_bogota0 = overall_phase2.loc[overall_phase2['Group'] == 0]
overall_phase2_bogota1 = overall_phase2.loc[overall_phase2['Group'] == 1]
overall_phase2_bogota2 = overall_phase2.loc[overall_phase2['Group'] == 2]
overall_phase2_bogota3 = overall_phase2.loc[overall_phase2['Group'] == 3]

# %%
overall_phase3_bogota0 = overall_phase3.loc[overall_phase3['Group'] == 0]
overall_phase3_bogota1 = overall_phase3.loc[overall_phase3['Group'] == 1]
overall_phase3_bogota2 = overall_phase3.loc[overall_phase3['Group'] == 2]
overall_phase3_bogota3 = overall_phase3.loc[overall_phase3['Group'] == 3]

# %%
overall_phase4_bogota0 = overall_phase4.loc[overall_phase4['Group'] == 0]
overall_phase4_bogota1 = overall_phase4.loc[overall_phase4['Group'] == 1]
overall_phase4_bogota2 = overall_phase4.loc[overall_phase4['Group'] == 2]
overall_phase4_bogota3 = overall_phase4.loc[overall_phase4['Group'] == 3]

# %%
overall_phase5_bogota0 = overall_phase5.loc[overall_phase5['Group'] == 0]
overall_phase5_bogota1 = overall_phase5.loc[overall_phase5['Group'] == 1]
overall_phase5_bogota2 = overall_phase5.loc[overall_phase5['Group'] == 2]
overall_phase5_bogota3 = overall_phase5.loc[overall_phase5['Group'] == 3]

# %% [markdown]
# ## Before Log-Transform Functions Count

# %%
mean_log_bogota3 = []
mean_log_bogota2 = []
mean_log_bogota1 = []
mean_log_bogota0 = []

median_log_bogota3 = []
median_log_bogota2 = []
median_log_bogota1 = []
median_log_bogota0 = []

min_log_bogota3 = []
min_log_bogota2 = []
min_log_bogota1 = []
min_log_bogota0 = []

max_log_bogota3 = []
max_log_bogota2 = []
max_log_bogota1 = []
max_log_bogota0 = []



for df in [overall_phase1_bogota3, overall_phase2_bogota3, overall_phase3_bogota3, overall_phase4_bogota3, overall_phase5_bogota3]:
    mean_value = df['len_functions'].mean()
    median_value = df['len_functions'].median()
    median_log_bogota3.append(median_value)
    min_value = df['len_functions'].min()
    min_log_bogota3.append(min_value)
    max_value = df['len_functions'].max()
    max_log_bogota3.append(max_value)
    mean_log_bogota3.append(mean_value)
    plt.figure()
    plt.title("Distributions of Number of Functions for Bogota 3")
    sns.distplot(df['len_functions'])

for df in [overall_phase1_bogota2, overall_phase2_bogota2, overall_phase3_bogota2, overall_phase4_bogota2, overall_phase5_bogota2]:
    mean_value = df['len_functions'].mean()
    median_value = df['len_functions'].median()
    median_log_bogota2.append(median_value)
    min_value = df['len_functions'].min()
    min_log_bogota2.append(min_value)
    max_value = df['len_functions'].max()
    max_log_bogota2.append(max_value)
    mean_log_bogota2.append(mean_value)
    plt.figure()
    plt.title("Distributions of Number of Functions for Bogota 2")
    sns.distplot(df['len_functions'])
    
for df in [overall_phase1_bogota1, overall_phase2_bogota1, overall_phase3_bogota1, overall_phase4_bogota1, overall_phase5_bogota1]:
    mean_value = df['len_functions'].mean()
    median_value = df['len_functions'].median()
    median_log_bogota1.append(median_value)
    min_value = df['len_functions'].min()
    min_log_bogota1.append(min_value)
    max_value = df['len_functions'].max()
    max_log_bogota1.append(max_value)
    mean_log_bogota1.append(mean_value)
    plt.figure()
    plt.title("Distributions of Number of Functions for Bogota 1")
    sns.distplot(df['len_functions'])

for df in [overall_phase1_bogota0, overall_phase2_bogota0, overall_phase3_bogota0, overall_phase4_bogota0, overall_phase5_bogota0]:
    mean_value = df['len_functions'].mean()
    median_value = df['len_functions'].median()
    median_log_bogota0.append(median_value)
    min_value = df['len_functions'].min()
    min_log_bogota0.append(min_value)
    max_value = df['len_functions'].max()
    max_log_bogota0.append(max_value)
    mean_log_bogota0.append(mean_value)
    plt.figure()
    plt.title("Distributions of Number of Functions for Bogota 0")
    sns.distplot(df['len_functions'])
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = median_log_bogota0
y2 = median_log_bogota1
y3 = median_log_bogota2
y4 = median_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median BEFORE Log-Transform Number of Functions Per Individual")
plt.ylabel("Median BEFORE Log-Transform Number of Functions Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = mean_log_bogota0
y2 = mean_log_bogota1
y3 = mean_log_bogota2
y4 = mean_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Mean BEFORE Log-Transform Number of Functions Per Individual")
plt.ylabel("Mean BEFORE Log-Transform Number of Functions Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = max_log_bogota0
y2 = max_log_bogota1
y3 = max_log_bogota2
y4 = max_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Max BEFORE Log-Transform Number of Functions Per Individual")
plt.ylabel("Max BEFORE Log-Transform Number of Functions Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# ## After Log-Transform Functions Count

# %%
mean_log_bogota3 = []
mean_log_bogota2 = []
mean_log_bogota1 = []
mean_log_bogota0 = []

median_log_bogota3 = []
median_log_bogota2 = []
median_log_bogota1 = []
median_log_bogota0 = []

min_log_bogota3 = []
min_log_bogota2 = []
min_log_bogota1 = []
min_log_bogota0 = []

max_log_bogota3 = []
max_log_bogota2 = []
max_log_bogota1 = []
max_log_bogota0 = []



for df in [overall_phase1_bogota3, overall_phase2_bogota3, overall_phase3_bogota3, overall_phase4_bogota3, overall_phase5_bogota3]:
    mean_value = (np.log(df['len_functions']+1)).mean()
    median_value = (np.log(df['len_functions']+1)).median()
    median_log_bogota3.append(median_value)
    min_value = (np.log(df['len_functions']+1)).min()
    min_log_bogota3.append(min_value)
    max_value = (np.log(df['len_functions']+1)).max()
    max_log_bogota3.append(max_value)
    mean_log_bogota3.append(mean_value)
    plt.figure()
    plt.title("Distributions of Number of Functions for Bogota 3")
    sns.distplot(np.log(df['len_functions']+1))

for df in [overall_phase1_bogota2, overall_phase2_bogota2, overall_phase3_bogota2, overall_phase4_bogota2, overall_phase5_bogota2]:
    mean_value = (np.log(df['len_functions']+1)).mean()
    median_value = (np.log(df['len_functions']+1)).median()
    median_log_bogota2.append(median_value)
    min_value = (np.log(df['len_functions']+1)).min()
    min_log_bogota2.append(min_value)
    max_value = (np.log(df['len_functions']+1)).max()
    max_log_bogota2.append(max_value)
    mean_log_bogota2.append(mean_value)
    plt.figure()
    plt.title("Distributions of Number of Functions for Bogota 2")
    sns.distplot(np.log(df['len_functions']+1))
    
for df in [overall_phase1_bogota1, overall_phase2_bogota1, overall_phase3_bogota1, overall_phase4_bogota1, overall_phase5_bogota1]:
    mean_value = (np.log(df['len_functions']+1)).mean()
    median_value = (np.log(df['len_functions']+1)).median()
    median_log_bogota1.append(median_value)
    min_value = (np.log(df['len_functions']+1)).min()
    min_log_bogota1.append(min_value)
    max_value = (np.log(df['len_functions']+1)).max()
    max_log_bogota1.append(max_value)
    mean_log_bogota1.append(mean_value)
    plt.figure()
    plt.title("Distributions of Number of Functions for Bogota 1")
    sns.distplot(np.log(df['len_functions']+1))

for df in [overall_phase1_bogota0, overall_phase2_bogota0, overall_phase3_bogota0, overall_phase4_bogota0, overall_phase5_bogota0]:
    mean_value = (np.log(df['len_functions']+1)).mean()
    median_value = (np.log(df['len_functions']+1)).median()
    median_log_bogota0.append(median_value)
    min_value = (np.log(df['len_functions']+1)).min()
    min_log_bogota0.append(min_value)
    max_value = (np.log(df['len_functions']+1)).max()
    max_log_bogota0.append(max_value)
    mean_log_bogota0.append(mean_value)
    plt.figure()
    plt.title("Distributions of Number of Functions for Bogota 0")
    sns.distplot(np.log(df['len_functions']+1))
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = median_log_bogota0
y2 = median_log_bogota1
y3 = median_log_bogota2
y4 = median_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median After Log-Transform Number of Functions Per Individual")
plt.ylabel("Median After Log-Transform Number of Functions Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = mean_log_bogota0
y2 = mean_log_bogota1
y3 = mean_log_bogota2
y4 = mean_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median After Log-Transform Number of Functions Per Individual")
plt.ylabel("Median After Log-Transform Number of Functions Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# ## Before Log-Transform Functions Variety

# %%
overall_phase1['len_unique'].hist(by=overall_phase1['Group'])
# Out:
# array([[<AxesSubplot:title={'center':'0.0'}>,
#         <AxesSubplot:title={'center':'1.0'}>],
#        [<AxesSubplot:title={'center':'2.0'}>,
#         <AxesSubplot:title={'center':'3.0'}>]], dtype=object)

# %%
overall_phase2['len_unique'].hist(by=overall_phase2['Group'])
# Out:
# array([[<AxesSubplot:title={'center':'0.0'}>,
#         <AxesSubplot:title={'center':'1.0'}>],
#        [<AxesSubplot:title={'center':'2.0'}>,
#         <AxesSubplot:title={'center':'3.0'}>]], dtype=object)

# %%
overall_phase3['len_unique'].hist(by=overall_phase3['Group'])
# Out:
# array([[<AxesSubplot:title={'center':'0.0'}>,
#         <AxesSubplot:title={'center':'1.0'}>],
#        [<AxesSubplot:title={'center':'2.0'}>,
#         <AxesSubplot:title={'center':'3.0'}>]], dtype=object)

# %%
overall_phase4['len_unique'].hist(by=overall_phase4['Group'])
# Out:
# array([[<AxesSubplot:title={'center':'0.0'}>,
#         <AxesSubplot:title={'center':'1.0'}>],
#        [<AxesSubplot:title={'center':'2.0'}>,
#         <AxesSubplot:title={'center':'3.0'}>]], dtype=object)

# %%
overall_phase5['len_unique'].hist(by=overall_phase5['Group'])
# Out:
# array([[<AxesSubplot:title={'center':'0.0'}>,
#         <AxesSubplot:title={'center':'1.0'}>],
#        [<AxesSubplot:title={'center':'2.0'}>,
#         <AxesSubplot:title={'center':'3.0'}>]], dtype=object)

# %%
sns.kdeplot(data=overall_phase2, x='len_unique', hue='Group')
# Out:
# <AxesSubplot:xlabel='len_unique', ylabel='Density'>

# %%
sns.kdeplot(data=overall_phase3, x='len_unique', hue='Group')
# Out:
# <AxesSubplot:xlabel='len_unique', ylabel='Density'>

# %%
sns.kdeplot(data=overall_phase4, x='len_unique', hue='Group')
# Out:
# <AxesSubplot:xlabel='len_unique', ylabel='Density'>

# %%
sns.kdeplot(data=overall_phase5, x='len_unique', hue='Group')
# Out:
# <AxesSubplot:xlabel='len_unique', ylabel='Density'>

# %%
mean_log_bogota3 = []
mean_log_bogota2 = []
mean_log_bogota1 = []
mean_log_bogota0 = []

median_log_bogota3 = []
median_log_bogota2 = []
median_log_bogota1 = []
median_log_bogota0 = []

min_log_bogota3 = []
min_log_bogota2 = []
min_log_bogota1 = []
min_log_bogota0 = []

max_log_bogota3 = []
max_log_bogota2 = []
max_log_bogota1 = []
max_log_bogota0 = []


for df in [overall_phase1_bogota3, overall_phase2_bogota3, overall_phase3_bogota3, overall_phase4_bogota3, overall_phase5_bogota3]:
    mean_value = df['len_unique'].mean()
    median_value = df['len_unique'].median()
    median_log_bogota3.append(median_value)
    min_value = df['len_unique'].min()
    min_log_bogota3.append(min_value)
    max_value = df['len_unique'].max()
    max_log_bogota3.append(max_value)
    mean_log_bogota3.append(mean_value)

for df in [overall_phase1_bogota2, overall_phase2_bogota2, overall_phase3_bogota2, overall_phase4_bogota2, overall_phase5_bogota2]:
    mean_value = df['len_unique'].mean()
    median_value = df['len_unique'].median()
    median_log_bogota2.append(median_value)
    min_value = df['len_unique'].min()
    min_log_bogota2.append(min_value)
    max_value = df['len_unique'].max()
    max_log_bogota2.append(max_value)
    mean_log_bogota2.append(mean_value)
    
for df in [overall_phase1_bogota1, overall_phase2_bogota1, overall_phase3_bogota1, overall_phase4_bogota1, overall_phase5_bogota1]:
    mean_value = df['len_unique'].mean()
    median_value = df['len_unique'].median()
    median_log_bogota1.append(median_value)
    min_value = df['len_unique'].min()
    min_log_bogota1.append(min_value)
    max_value = df['len_unique'].max()
    max_log_bogota1.append(max_value)
    mean_log_bogota1.append(mean_value)

for df in [overall_phase1_bogota0, overall_phase2_bogota0, overall_phase3_bogota0, overall_phase4_bogota0, overall_phase5_bogota0]:
    mean_value = df['len_unique'].mean()
    median_value = df['len_unique'].median()
    median_log_bogota0.append(median_value)
    min_value = df['len_unique'].min()
    min_log_bogota0.append(min_value)
    max_value = df['len_unique'].max()
    max_log_bogota0.append(max_value)
    mean_log_bogota0.append(mean_value)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = median_log_bogota0
y2 = median_log_bogota1
y3 = median_log_bogota2
y4 = median_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median BEFORE Log-Transform Variety Per Individual")
plt.ylabel("Median BEFORE Log-Transform Variety Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = mean_log_bogota0
y2 = mean_log_bogota1
y3 = mean_log_bogota2
y4 = mean_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Mean BEFORE Log-Transform Variety Per Individual")
plt.ylabel("Mean BEFORE Log-Transform Variety Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = max_log_bogota0
y2 = max_log_bogota1
y3 = max_log_bogota2
y4 = max_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Max BEFORE Log-Transform Variety Per Individual")
plt.ylabel("Max BEFORE Log-Transform Variety Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# ## After Log-Transform Functions Variety

# %%
mean_log_bogota3 = []
mean_log_bogota2 = []
mean_log_bogota1 = []
mean_log_bogota0 = []

median_log_bogota3 = []
median_log_bogota2 = []
median_log_bogota1 = []
median_log_bogota0 = []

min_log_bogota3 = []
min_log_bogota2 = []
min_log_bogota1 = []
min_log_bogota0 = []

max_log_bogota3 = []
max_log_bogota2 = []
max_log_bogota1 = []
max_log_bogota0 = []


for df in [overall_phase1_bogota3, overall_phase2_bogota3, overall_phase3_bogota3, overall_phase4_bogota3, overall_phase5_bogota3]:
    mean_value = (np.log(df['len_unique']+1)).mean()
    median_value = (np.log(df['len_unique']+1)).median()
    median_log_bogota3.append(median_value)
    min_value = (np.log(df['len_unique']+1)).min()
    min_log_bogota3.append(min_value)
    max_value = (np.log(df['len_unique']+1)).max()
    max_log_bogota3.append(max_value)
    mean_log_bogota3.append(mean_value)

for df in [overall_phase1_bogota2, overall_phase2_bogota2, overall_phase3_bogota2, overall_phase4_bogota2, overall_phase5_bogota2]:
    mean_value = (np.log(df['len_unique']+1)).mean()
    median_value = (np.log(df['len_unique']+1)).median()
    median_log_bogota2.append(median_value)
    min_value = (np.log(df['len_unique']+1)).min()
    min_log_bogota2.append(min_value)
    max_value = (np.log(df['len_unique']+1)).max()
    max_log_bogota2.append(max_value)
    mean_log_bogota2.append(mean_value)
    
for df in [overall_phase1_bogota1, overall_phase2_bogota1, overall_phase3_bogota1, overall_phase4_bogota1, overall_phase5_bogota1]:
    mean_value = (np.log(df['len_unique']+1)).mean()
    median_value = (np.log(df['len_unique']+1)).median()
    median_log_bogota1.append(median_value)
    min_value = (np.log(df['len_unique']+1)).min()
    min_log_bogota1.append(min_value)
    max_value = (np.log(df['len_unique']+1)).max()
    max_log_bogota1.append(max_value)
    mean_log_bogota1.append(mean_value)

for df in [overall_phase1_bogota0, overall_phase2_bogota0, overall_phase3_bogota0, overall_phase4_bogota0, overall_phase5_bogota0]:
    mean_value = (np.log(df['len_unique']+1)).mean()
    median_value = (np.log(df['len_unique']+1)).median()
    median_log_bogota0.append(median_value)
    min_value = (np.log(df['len_unique']+1)).min()
    min_log_bogota0.append(min_value)
    max_value = (np.log(df['len_unique']+1)).max()
    max_log_bogota0.append(max_value)
    mean_log_bogota0.append(mean_value)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = median_log_bogota0
y2 = median_log_bogota1
y3 = median_log_bogota2
y4 = median_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median Log-Transform Variety Per Individual")
plt.ylabel("Median Log-Transform Variety Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = mean_log_bogota0
y2 = mean_log_bogota1
y3 = mean_log_bogota2
y4 = mean_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Mean Log-Transform Variety Per Individual")
plt.ylabel("Mean Log-Transform Variety Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = max_log_bogota0
y2 = max_log_bogota1
y3 = max_log_bogota2
y4 = max_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Max Log-Transform Variety Per Individual")
plt.ylabel("Max Log-Transform Variety Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = min_log_bogota0
y2 = min_log_bogota1
y3 = min_log_bogota2
y4 = min_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Min Log-Transform Variety Per Individual")
plt.ylabel("Min Log-Transform Variety Per Individual")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# ## Distributions of Variety for Bogota 0

# %%
import seaborn as sns 

for df in [overall_phase1_bogota0, overall_phase2_bogota0, overall_phase3_bogota0, overall_phase4_bogota0, overall_phase5_bogota0]:
    plt.figure()
    plt.title("Distributions of Variety for Bogota 0")
    sns.distplot(np.log(df['len_unique']+1))
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Distributions of Variety for Bogota 1

# %%
import seaborn as sns 

for df in [overall_phase1_bogota1, overall_phase2_bogota1, overall_phase3_bogota1, overall_phase4_bogota1, overall_phase5_bogota1]:
    plt.figure()
    plt.title("Distributions of Variety for Bogota 1")
    sns.distplot(np.log(df['len_unique']+1))
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Distributions of Variety for Bogota 2

# %%
import seaborn as sns 

for df in [overall_phase1_bogota2, overall_phase2_bogota2, overall_phase3_bogota2, overall_phase4_bogota2, overall_phase5_bogota2]:
    plt.figure()
    plt.title("Distributions of Variety for Bogota 2")
    sns.distplot(np.log(df['len_unique']+1))
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ## Distributions of Variety for Bogota 3

# %%
import seaborn as sns 

for df in [overall_phase1_bogota3, overall_phase2_bogota3, overall_phase3_bogota3, overall_phase4_bogota3, overall_phase5_bogota3]:
    plt.figure()
    plt.title("Distributions of Variety for Bogota 3")
    sns.distplot(np.log(df['len_unique']+1))
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# > The distributions are approximately normal for the variety metrics, so perhaps the mean should be considered.

# %%
# store variables to be used in correlation charts 

# %store overall_phase1_bogota0
# %store overall_phase2_bogota0
# %store overall_phase3_bogota0
# %store overall_phase4_bogota0
# %store overall_phase5_bogota0

# %store overall_phase1_bogota1
# %store overall_phase2_bogota1
# %store overall_phase3_bogota1
# %store overall_phase4_bogota1
# %store overall_phase5_bogota1

# %store overall_phase1_bogota2
# %store overall_phase2_bogota2
# %store overall_phase3_bogota2
# %store overall_phase4_bogota2
# %store overall_phase5_bogota2

# %store overall_phase1_bogota3
# %store overall_phase2_bogota3
# %store overall_phase3_bogota3
# %store overall_phase4_bogota3
# %store overall_phase5_bogota3
# Out:
# Stored 'overall_phase1_bogota0' (DataFrame)
# Stored 'overall_phase2_bogota0' (DataFrame)
# Stored 'overall_phase3_bogota0' (DataFrame)
# Stored 'overall_phase4_bogota0' (DataFrame)
# Stored 'overall_phase5_bogota0' (DataFrame)
# Stored 'overall_phase1_bogota1' (DataFrame)
# Stored 'overall_phase2_bogota1' (DataFrame)
# Stored 'overall_phase3_bogota1' (DataFrame)
# Stored 'overall_phase4_bogota1' (DataFrame)
# Stored 'overall_phase5_bogota1' (DataFrame)
# Stored 'overall_phase1_bogota2' (DataFrame)
# Stored 'overall_phase2_bogota2' (DataFrame)
# Stored 'overall_phase3_bogota2' (DataFrame)
# Stored 'overall_phase4_bogota2' (DataFrame)
# Stored 'overall_phase5_bogota2' (DataFrame)
# Stored 'overall_phase1_bogota3' (DataFrame)
# Stored 'overall_phase2_bogota3' (DataFrame)
# Stored 'overall_phase3_bogota3' (DataFrame)
# Stored 'overall_phase4_bogota3' (DataFrame)
# Stored 'overall_phase5_bogota3' (DataFrame)

# %% [markdown]
# ## T-test

# %%
# T-tests between Bogota 2 and Bogota 1

import pandas as pd
import inspect

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [overall_phase1_bogota2, overall_phase2_bogota2, overall_phase3_bogota2, overall_phase4_bogota2, overall_phase5_bogota2], [overall_phase1_bogota1, overall_phase2_bogota1, overall_phase3_bogota1, overall_phase4_bogota1, overall_phase5_bogota1]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(list1[x]['len_unique']+1), np.log(list2[y]['len_unique']+1), equal_var = False, alternative = 'greater')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[1] == df.group2.str.split("_", expand=True)[1]]
# Out:
#                     group1                  group2  statistics    pvalue
# 0   overall_phase1_bogota2  overall_phase1_bogota1    0.455486  0.325014
# 6   overall_phase2_bogota2  overall_phase2_bogota1   -0.268114  0.605345
# 12  overall_phase3_bogota2  overall_phase3_bogota1   -0.410205  0.658617
# 18  overall_phase4_bogota2  overall_phase4_bogota1    0.019807  0.492124
# 24  overall_phase5_bogota2  overall_phase5_bogota1    0.507837  0.306482

# %%
# T-tests between Bogota 3 and Bogota 2

import pandas as pd
import inspect

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [overall_phase1_bogota3, overall_phase2_bogota3, overall_phase3_bogota3, overall_phase4_bogota3, overall_phase5_bogota3], [overall_phase1_bogota2, overall_phase2_bogota2, overall_phase3_bogota2, overall_phase4_bogota2, overall_phase5_bogota2]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(list1[x]['len_unique']+1), np.log(list2[y]['len_unique']+1), equal_var = False, alternative = 'greater')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[1] == df.group2.str.split("_", expand=True)[1]]
# Out:
#                     group1                  group2  statistics    pvalue
# 0   overall_phase1_bogota3  overall_phase1_bogota2    0.834635  0.203199
# 6   overall_phase2_bogota3  overall_phase2_bogota2   -0.448816  0.672602
# 12  overall_phase3_bogota3  overall_phase3_bogota2   -0.147290  0.558365
# 18  overall_phase4_bogota3  overall_phase4_bogota2    0.623628  0.267333
# 24  overall_phase5_bogota3  overall_phase5_bogota2    0.240085  0.405435

# %%
# T-tests between Bogota 3 and Bogota 1

import pandas as pd
import inspect

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [overall_phase1_bogota3, overall_phase2_bogota3, overall_phase3_bogota3, overall_phase4_bogota3, overall_phase5_bogota3], [overall_phase1_bogota1, overall_phase2_bogota1, overall_phase3_bogota1, overall_phase4_bogota1, overall_phase5_bogota1]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(list1[x]['len_unique']+1), np.log(list2[y]['len_unique']+1), equal_var = False, alternative = 'greater')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[1] == df.group2.str.split("_", expand=True)[1]]
# Out:
#                     group1                  group2  statistics    pvalue
# 0   overall_phase1_bogota3  overall_phase1_bogota1    1.217049  0.113732
# 6   overall_phase2_bogota3  overall_phase2_bogota1   -0.696544  0.755845
# 12  overall_phase3_bogota3  overall_phase3_bogota1   -0.552856  0.709021
# 18  overall_phase4_bogota3  overall_phase4_bogota1    0.591422  0.277954
# 24  overall_phase5_bogota3  overall_phase5_bogota1    0.742051  0.230132

# %%
# T-tests between Bogota 3 and Bogota 0

import pandas as pd
import inspect

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [overall_phase1_bogota3, overall_phase2_bogota3, overall_phase3_bogota3, overall_phase4_bogota3, overall_phase5_bogota3], [overall_phase1_bogota0, overall_phase2_bogota0, overall_phase3_bogota0, overall_phase4_bogota0, overall_phase5_bogota0]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(list1[x]['len_unique']+1), np.log(list2[y]['len_unique']+1), equal_var = False, alternative = 'greater')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[1] == df.group2.str.split("_", expand=True)[1]]
# Out:
#                     group1                  group2  statistics    pvalue
# 0   overall_phase1_bogota3  overall_phase1_bogota0    3.763694  0.000163
# 6   overall_phase2_bogota3  overall_phase2_bogota0    1.971491  0.026105
# 12  overall_phase3_bogota3  overall_phase3_bogota0    1.917526  0.029415
# 18  overall_phase4_bogota3  overall_phase4_bogota0    2.471924  0.007795
# 24  overall_phase5_bogota3  overall_phase5_bogota0    2.321935  0.011445

# %%
# T-tests between Bogota 2 and Bogota 0

import pandas as pd
import inspect

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [overall_phase1_bogota2, overall_phase2_bogota2, overall_phase3_bogota2, overall_phase4_bogota2, overall_phase5_bogota2], [overall_phase1_bogota0, overall_phase2_bogota0, overall_phase3_bogota0, overall_phase4_bogota0, overall_phase5_bogota0]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(list1[x]['len_unique']+1), np.log(list2[y]['len_unique']+1), equal_var = False, alternative = 'greater')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[1] == df.group2.str.split("_", expand=True)[1]]
# Out:
#                     group1                  group2  statistics    pvalue
# 0   overall_phase1_bogota2  overall_phase1_bogota0    2.823161  0.003004
# 6   overall_phase2_bogota2  overall_phase2_bogota0    2.232910  0.014180
# 12  overall_phase3_bogota2  overall_phase3_bogota0    2.021551  0.023295
# 18  overall_phase4_bogota2  overall_phase4_bogota0    2.023221  0.023254
# 24  overall_phase5_bogota2  overall_phase5_bogota0    2.073554  0.020709

# %%
# T-tests between Bogota 1 and Bogota 0

import pandas as pd
import inspect

def retrieve_name(var):
   callers_local_vars = inspect.currentframe().f_back.f_globals.items()
   return [var_name for var_name, var_val in callers_local_vars if var_val is var][0]

list1,list2 = [overall_phase1_bogota1, overall_phase2_bogota1, overall_phase3_bogota1, overall_phase4_bogota1, overall_phase5_bogota1], [overall_phase1_bogota0, overall_phase2_bogota0, overall_phase3_bogota0, overall_phase4_bogota0, overall_phase5_bogota0]
results = []
for x in range(len(list1)):
    for y in range(len(list2)):
        
        name_list1 = retrieve_name(list1[x])
        name_list2 = retrieve_name(list2[y])
        ttest_result = ttest_ind(np.log(list1[x]['len_unique']+1), np.log(list2[y]['len_unique']+1), equal_var = False, alternative = 'greater')
        results.append([name_list1, name_list2, ttest_result[0], ttest_result[1]])
        
df = pd.DataFrame(results, columns=["group1", "group2", "statistics", "pvalue"])
df[df.group1.str.split("_", expand=True)[1] == df.group2.str.split("_", expand=True)[1]]
# Out:
#                     group1                  group2  statistics    pvalue
# 0   overall_phase1_bogota1  overall_phase1_bogota0    2.109632  0.019051
# 6   overall_phase2_bogota1  overall_phase2_bogota0    2.327231  0.011319
# 12  overall_phase3_bogota1  overall_phase3_bogota0    2.274012  0.012848
# 18  overall_phase4_bogota1  overall_phase4_bogota0    1.843173  0.034527
# 24  overall_phase5_bogota1  overall_phase5_bogota0    1.506770  0.067934

# %% [markdown]
# ## Comments

# %% [markdown]
# > No transparency has significantly lower variety than Performance Transparency
#
# * Phase 1 - 0.019051
# * Phase 2 - 0.011319
# * Phase 3 - 0.012848
# * Phase 4 - 0.032906
# * Phase 5 - 0.064787
#
# > No Transparency has significantly lower variety than Solution Transparency
#
# * Phase 1 - 0.001791
# * Phase 2 - 0.005609
# * Phase 3 - 0.007071
# * Phase 4 - 0.007247
# * Phase 5 - 0.008119
#
# > No Transparency has significantly lower variety than Full Transparency
#
# * Phase 1 - 0.000163
# * Phase 2 - 0.026105
# * Phase 3 - 0.029415
# * Phase 4 - 0.007795
# * Phase 5 - 0.011445
