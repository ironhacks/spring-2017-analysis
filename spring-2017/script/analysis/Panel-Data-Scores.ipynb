# %%
# %store -r overall_survey
overall_survey
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 160       jumcorredorro    3.0                    100.0           62.50
# 161          feartheGru    3.0                      0.0            0.00
# 162        Danielsv9207    3.0                      0.0            0.00
# 163  JhonEmmanuelTorres    3.0                      0.0            0.00
# 164          Januguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
phase5 = overall_survey[['user-requirement-phase5', 'infovis-phase5', 'total-phase5', 'novelty-phase5', 'tech-phase5','Group', 'Student', 'Q7_Q7_1', 'Q7_Q7_2', 'Q8_Q8_1', 'Q10']]
phase5['phase'] = 5
phase5 = phase5.rename(columns={'user-requirement-phase5': 'user-requirement', 'infovis-phase5': 'infovis', 
                              'total-phase5': 'total', 'novelty-phase5': 'novelty', 'tech-phase5': 'tech' })
phase5.dropna()
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_31365/819671983.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5['phase'] = 5
#      user-requirement  infovis   total  novelty   tech  Group  \
# 0                20.0    29.17  199.17    50.00  100.0    0.0
# 1                60.0    75.00  290.00    67.50   87.5    0.0
# 2               100.0    54.17  254.17    25.00   75.0    0.0
# 3                20.0    37.50  136.67    16.67   62.5    0.0
# 4                60.0    58.33  255.83    87.50   50.0    0.0
# ..                ...      ...     ...      ...    ...    ...
# 159             100.0    83.33  360.83    90.00   87.5    3.0
# 160             100.0    62.50  325.00    75.00   87.5    3.0
# ...

# %%
phase4 = overall_survey[['user-requirement-phase4', 'infovis-phase4', 'total-phase4', 'novelty-phase4', 'tech-phase4','Group', 'Student', 'Q7_Q7_1', 'Q7_Q7_2', 'Q8_Q8_1', 'Q10']]
phase4['phase'] = 4
phase4 = phase4.rename(columns={'user-requirement-phase4': 'user-requirement', 'infovis-phase4': 'infovis', 
                              'total-phase4': 'total', 'novelty-phase4': 'novelty', 'tech-phase4': 'tech' })
phase4.dropna()
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_31365/3103725194.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4['phase'] = 4
#      user-requirement  infovis   total  novelty   tech  Group  \
# 0                20.0    29.17  192.92    43.75  100.0    0.0
# 1                20.0    37.50  245.00   100.00   87.5    0.0
# 2               100.0    58.33  220.83     0.00   62.5    0.0
# 3                20.0    45.83  128.33    25.00   37.5    0.0
# 4                40.0    54.17  131.67     0.00   37.5    0.0
# ..                ...      ...     ...      ...    ...    ...
# 159               0.0    33.33  120.83    25.00   62.5    3.0
# 160              80.0    58.33  305.00    79.17   87.5    3.0
# ...

# %%
phase3 = overall_survey[['user-requirement-phase3', 'infovis-phase3', 'total-phase3', 'novelty-phase3', 'tech-phase3','Group', 'Student', 'Q7_Q7_1', 'Q7_Q7_2', 'Q8_Q8_1', 'Q10']]
phase3['phase'] = 3
phase3 = phase3.rename(columns={'user-requirement-phase3': 'user-requirement', 'infovis-phase3': 'infovis', 
                              'total-phase3': 'total', 'novelty-phase3': 'novelty', 'tech-phase3': 'tech' })
phase3.dropna()
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_31365/4140580897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3['phase'] = 3
#      user-requirement  infovis   total  novelty   tech  Group  \
# 0                60.0    37.50  172.50      0.0   75.0    0.0
# 1                20.0    41.67  236.67     75.0  100.0    0.0
# 2                20.0    50.00  132.50      0.0   62.5    0.0
# 3                 0.0     0.00    0.00      0.0    0.0    0.0
# 4                20.0    45.83  103.33      0.0   37.5    0.0
# ..                ...      ...     ...      ...    ...    ...
# 159               0.0    33.33  108.33     25.0   50.0    3.0
# 160              80.0    75.00  330.00     87.5   87.5    3.0
# ...

# %%
phase2 = overall_survey[['user-requirement-phase2', 'infovis-phase2', 'total-phase2', 'novelty-phase2', 'tech-phase2','Group', 'Student', 'Q7_Q7_1', 'Q7_Q7_2', 'Q8_Q8_1', 'Q10']]
phase2['phase'] = 2
phase2 = phase2.rename(columns={'user-requirement-phase2': 'user-requirement', 'infovis-phase2': 'infovis', 
                              'total-phase2': 'total', 'novelty-phase2': 'novelty', 'tech-phase2': 'tech' })
phase2.dropna()
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_31365/4177867414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2['phase'] = 2
#      user-requirement  infovis   total  novelty  tech  Group  \
# 0                60.0    37.50  172.50      0.0  75.0    0.0
# 1                20.0    37.50  220.00     75.0  87.5    0.0
# 2                20.0    33.33  140.83     25.0  62.5    0.0
# 3                 0.0     0.00   12.50      0.0  12.5    0.0
# 4                20.0    29.17  111.67      0.0  62.5    0.0
# ..                ...      ...     ...      ...   ...    ...
# 159               0.0    25.00  100.00     25.0  50.0    3.0
# 160              80.0    54.17  309.17     87.5  87.5    3.0
# ...

# %%
phase1 = overall_survey[['user-requirement-phase1', 'infovis-phase1', 'total-phase1', 'novelty-phase1', 'tech-phase1','Group', 'Student', 'Q7_Q7_1', 'Q7_Q7_2', 'Q8_Q8_1', 'Q10']]
phase1['phase'] = 1
phase1 = phase1.rename(columns={'user-requirement-phase1': 'user-requirement', 'infovis-phase1': 'infovis', 
                              'total-phase1': 'total', 'novelty-phase1': 'novelty', 'tech-phase1': 'tech' })
phase1.dropna()
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_31365/1614142466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1['phase'] = 1
#      user-requirement  infovis   total  novelty  tech  Group  \
# 0                20.0    29.17   99.17      0.0  50.0    0.0
# 1                 0.0     0.00   87.50      0.0  87.5    0.0
# 2                 0.0     0.00   50.00      0.0  50.0    0.0
# 3                 0.0     0.00    0.00      0.0   0.0    0.0
# 4                 0.0     0.00    0.00      0.0   0.0    0.0
# ..                ...      ...     ...      ...   ...    ...
# 159               0.0    25.00  112.50     25.0  62.5    3.0
# 160              40.0    33.33  185.83     50.0  62.5    3.0
# ...

# %%
overall_scores = phase1.append([phase2, phase3, phase4, phase5], ignore_index = True)
overall_scores = overall_scores[~overall_scores['Group'].isna()]
overall_scores
# Out:
#      user-requirement  infovis   total  novelty  tech  Group  \
# 0                20.0    29.17   99.17      0.0  50.0    0.0
# 1                 0.0     0.00   87.50      0.0  87.5    0.0
# 2                 0.0     0.00   50.00      0.0  50.0    0.0
# 3                 0.0     0.00    0.00      0.0   0.0    0.0
# 4                 0.0     0.00    0.00      0.0   0.0    0.0
# ..                ...      ...     ...      ...   ...    ...
# 819             100.0    83.33  360.83     90.0  87.5    3.0
# 820             100.0    62.50  325.00     75.0  87.5    3.0
# 821               0.0     0.00    0.00      0.0   0.0    3.0
# 822               0.0     0.00    0.00      0.0   0.0    3.0
# 823               0.0     0.00    0.00      0.0   0.0    3.0
#
#                 Student  Q7_Q7_1  Q7_Q7_2  Q8_Q8_1  Q10  phase
# 0             fffeelipe      1.0      0.0      5.0  3.0      1
# 1             mnguzmanc      2.0      1.0      3.0  2.0      1
# ...

# %%
overall_scores.to_csv('overall_scores.csv')

# %%
phase5_improve = overall_survey[['improve-ur-45', 'improve-vis-45', 'improve-total-45', 'improve-novel-45', 'improve-tech-45','Group', 'Student', 'Q7_Q7_1', 'Q7_Q7_2', 'Q8_Q8_1', 'Q10']]
phase5_improve['stage'] = 4
phase5_improve = phase5_improve.rename(columns={'improve-ur-45': 'improve-ur', 'improve-vis-45': 'improve-vis', 
                              'improve-total-45': 'improve-total', 'improve-novel-45': 'improve-novel', 'improve-tech-45': 'improve-tech' })
phase5_improve.dropna()
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1302/365399796.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_improve['stage'] = 4
#      improve-ur  improve-vis  improve-total  improve-novel  improve-tech  \
# 0           0.0         0.00           6.25           6.25           0.0
# 1          40.0        37.50          45.00         -32.50           0.0
# 2           0.0        -4.16          33.34          25.00          12.5
# 3           0.0        -8.33           8.34          -8.33          25.0
# 4          20.0         4.16         124.16          87.50          12.5
# ..          ...          ...            ...            ...           ...
# ...

# %%
phase4_improve = overall_survey[['improve-ur-34', 'improve-vis-34', 'improve-total-34', 'improve-novel-34', 'improve-tech-34','Group', 'Student', 'Q7_Q7_1', 'Q7_Q7_2', 'Q8_Q8_1', 'Q10']]
phase4_improve['stage'] = 3
phase4_improve = phase4_improve.rename(columns={'improve-ur-34': 'improve-ur', 'improve-vis-34': 'improve-vis', 
                              'improve-total-34': 'improve-total', 'improve-novel-34': 'improve-novel', 'improve-tech-34': 'improve-tech' })
phase4_improve.dropna()
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1302/442681368.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_improve['stage'] = 3
#      improve-ur  improve-vis  improve-total  improve-novel  improve-tech  \
# 0         -40.0        -8.33          20.42          43.75          25.0
# 1           0.0        -4.17           8.33          25.00         -12.5
# 2          80.0         8.33          88.33           0.00           0.0
# 3          20.0        45.83         128.33          25.00          37.5
# 4          20.0         8.34          28.34           0.00           0.0
# ..          ...          ...            ...            ...           ...
# ...

# %%
phase3_improve = overall_survey[['improve-ur-23', 'improve-vis-23', 'improve-total-23', 'improve-novel-23', 'improve-tech-23','Group', 'Student', 'Q7_Q7_1', 'Q7_Q7_2', 'Q8_Q8_1', 'Q10']]
phase3_improve['stage'] = 2
phase3_improve = phase3_improve.rename(columns={'improve-ur-23': 'improve-ur', 'improve-vis-23': 'improve-vis', 
                              'improve-total-23': 'improve-total', 'improve-novel-23':'improve-novel', 'improve-tech-23': 'improve-tech' })
phase3_improve.dropna()
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1302/4233688141.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_improve['stage'] = 2
#      improve-ur  improve-vis  improve-total  improve-novel  improve-tech  \
# 0           0.0         0.00           0.00            0.0           0.0
# 1           0.0         4.17          16.67            0.0          12.5
# 2           0.0        16.67          -8.33          -25.0           0.0
# 3           0.0         0.00         -12.50            0.0         -12.5
# 4           0.0        16.66          -8.34            0.0         -25.0
# ..          ...          ...            ...            ...           ...
# ...
