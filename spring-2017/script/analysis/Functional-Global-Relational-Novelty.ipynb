# %% [markdown]
# # Rareness

# %% [markdown]
# ## Get All Functions from All Phases and Groups

# %%
import pandas as pd
import numpy as np
import math
import collections

# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5


# %store -r subset_bogota0_phase1
# %store -r subset_bogota0_phase2
# %store -r subset_bogota0_phase3
# %store -r overall_phase3_bogota0
# %store -r subset_bogota0_phase4
# %store -r overall_phase4_bogota0
# %store -r overall_phase5_bogota0
# %store -r subset_bogota0_phase5
# %store -r subset_bogota1_phase1
# %store -r subset_bogota1_phase2
# %store -r subset_bogota1_phase3
# %store -r overall_phase3_bogota1
# %store -r overall_phase4_bogota1
# %store -r overall_phase5_bogota1
# %store -r subset_bogota1_phase5
# %store -r subset_bogota1_phase4
# %store -r subset_bogota2_phase1
# %store -r subset_bogota2_phase2
# %store -r subset_bogota2_phase3
# %store -r overall_phase3_bogota2
# %store -r overall_phase4_bogota2
# %store -r overall_phase5_bogota2
# %store -r subset_bogota2_phase5
# %store -r subset_bogota3_phase1
# %store -r overall_phase1_bogota3
# %store -r overall_phase2_bogota3
# %store -r subset_bogota3_phase3
# %store -r overall_phase3_bogota3
# %store -r overall_phase4_bogota3
# %store -r overall_phase5_bogota3
# %store -r subset_bogota2_phase4

# %store -r overall_phase2_bogota0
# %store -r overall_phase2_bogota1
# %store -r overall_phase2_bogota2
# %store -r overall_phase2_bogota3

# %store -r overall_phase1_bogota0
# %store -r overall_phase1_bogota1
# %store -r overall_phase1_bogota2
# %store -r overall_phase1_bogota3

# %%
## List the 20,000 least common functions in a counter

overall_12 = overall_phase1.append(overall_phase2, ignore_index=True)
overall_23 = overall_12.append(overall_phase3, ignore_index=True)
overall_34 = overall_23.append(overall_phase4, ignore_index=True)
overall_45 = overall_34.append(overall_phase5, ignore_index=True)
new_list = overall_45['functions'].explode().to_list()
new_list = list(filter(None, new_list))
new_list
# Out:
# ['.ready',
#  '.click',
#  '.mcheck',
#  '.on',
#  '.closest',
#  '.list',
#  '.find',
#  '.form',
#  '.toggleClass',
#  '.val',
#  'document.getElementById',
#  'google.maps.Map',
#  '.getJSON',
#  'test.json',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'js.js',
#  'jsondata.js',
#  'css.css',
#  'style.css',
#  'map.js',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'bootstrap.min.css',
#  'style.css',
#  '.JS',
#  '.js',
#  nan,
#  'jquery.min.js',
#  '.js',
#  'Rent.js',
#  'Crimes.js',
#  'google.maps.Map',
#  'document.getElementById',
#  '.ajax',
#  'data.cityofchicago.org',
#  'xi.json',
#  '.done',
#  'data.length',
#  'google.maps.Marker',
#  'google.maps.LatLng',
#  '.latitude',
#  '.longitude',
#  '.primary',
#  'crimeMarker.push',
#  'crimeMarker.length',
#  '.setMap',
#  'google.maps.InfoWindow',
#  'google.maps.event.addListener',
#  'infowindow.close',
#  'infowindow.setContent',
#  'data.primary',
#  'infowindow.open',
#  'marker.get',
#  '.innerHTML',
#  'data.id',
#  'data.date',
#  'data.description',
#  'data.year',
#  'iimk.json',
#  '.address',
#  'rentMarker.push',
#  'rentMarker.length',
#  'data.property',
#  'data.address',
#  'data.zip',
#  'data.phone',
#  'data.management',
#  'js.org',
#  '.v',
#  '.min.js',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data',
#  '.innerHTML',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'boundBox.getNorthEast',
#  'google.maps.LatLng',
#  'southWest.lat',
#  'southWest.lng',
#  'locations.push',
#  'elevator.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'google.maps.Marker',
#  'key.toString',
#  '.slice',
#  'infowindow.close',
#  'infowindow.setContent',
#  'infowindow.open',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'Map.js',
#  'style.css',
#  'jquery.min.js',
#  '.js',
#  'info.js',
#  'document.getElementById',
#  'google.maps.Map',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'dataRental.push',
#  'json.data',
#  'wData.push',
#  'wData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'google.maps.LatLng',
#  'style.css',
#  'script.js',
#  'jquery.min.js',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.InfoWindow',
#  'google.maps.Marker',
#  'google.maps.Size',
#  'marker.addListener',
#  'infowindow.close',
#  'infowindow.open',
#  'marker.get',
#  '.ajax',
#  'data.cityofchicago.org',
#  'iimk.json',
#  '.done',
#  'data.length',
#  'google.maps.LatLng',
#  '.latitude',
#  '.longitude',
#  '.property',
#  '.address',
#  '.phone',
#  'select.icon',
#  'select.setMap',
#  'this.property',
#  'this.get',
#  'this.icon',
#  '.innerHTML',
#  'this.address',
#  'this.phone',
#  'this.distance',
#  'console.log',
#  'aux.latitude',
#  'Math.round',
#  'xi.json',
#  'aux.longitude',
#  'map.setCenter',
#  'map.c',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'PROJECT.HTML',
#  'lml.jpg',
#  'google.maps.LatLng',
#  'google.maps.MapTypeId.ROADMAP',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.Marker',
#  'google.maps.event.addListener',
#  'google.maps.event.addDomListener',
#  'map.setZoom',
#  'map.setCenter',
#  'marker.getPosition',
#  'google.maps.InfoWindow',
#  'infowindow.open',
#  '.floating',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.MapTypeId.HIBRID',
#  'google.maps.TrafficLayer',
#  'map.data.loadGeoJson',
#  'data.cityofchicago.org',
#  'xi.geojson',
#  'map.data.setStyle',
#  'google.maps.SymbolPath.CIRCLE',
#  'iimk.geojson',
#  'google.maps.LatLng',
#  'google.maps.Marker',
#  'google.maps.InfoWindow',
#  'google.maps.event.addListener',
#  'infowindow.open',
#  'style.css',
#  'k.jpg',
#  'code.js',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'stylescss.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'map.js',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'tutorial.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'RadarChart.js',
#  'tutorial.js',
#  'script.js',
#  '.navbar',
#  '.container',
#  'sites.jpg',
#  'social.jpg',
#  'api.openweathermap.org',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  '.coord.lon',
#  'document.getElementById',
#  '.innerHTML',
#  'json.weather',
#  '.main',
#  '.select',
#  '.selectAll',
#  '.append',
#  '.attr',
#  'cfg.w',
#  'cfg.h',
#  '.scale.category',
#  'svg.append',
#  '.text',
#  'title.selectAll',
#  '.data',
#  '.enter',
#  '.style',
#  'arr.length',
#  '.url',
#  '.display',
#  '.resize',
#  '.height',
#  '.css',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.Map',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'json.data',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'boundBox.getNorthEast',
#  'northEast.lng',
#  'southWest.lng',
#  'northEast.lat',
#  'southWest.lat',
#  'google.maps.LatLng',
#  'Math.random',
#  'locations.push',
#  'elevator.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'google.maps.Marker',
#  'key.toString',
#  '.slice',
#  'infowindow.close',
#  'infowindow.setContent',
#  'infowindow.open',
#  '.capitalizeFirstLetter',
#  'RadarChart.draw',
#  'str.indexOf',
#  'd.getDay',
#  'Math.PI',
#  'cfg.maxValue',
#  'Math.max',
#  '.max',
#  'i.map',
#  'o.value',
#  '.map',
#  'i.axis',
#  'allAxis.length',
#  'cfg.factor',
#  'Math.min',
#  '.format',
#  '.remove',
#  'cfg.ExtraWidthX',
#  'cfg.ExtraWidthY',
#  'cfg.TranslateX',
#  'cfg.TranslateY',
#  'cfg.levels',
#  'g.selectAll',
#  '.levels',
#  'Math.sin',
#  'cfg.radians',
#  'Math.cos',
#  'cfg.ToRight',
#  '.axis',
#  'axis.append',
#  'cfg.factortitle',
#  'd.forEach',
#  '.nodes',
#  'dataValues.push',
#  'j.value',
#  '.area',
#  'cfg.color',
#  'd.length',
#  'cfg.opacityArea',
#  '.on',
#  '.transition',
#  'cfg.radius',
#  'j.axis',
#  'd.value',
#  'g.append',
#  'demos.css',
#  'bootstrap.min.css',
#  'style.css',
#  'map.gif',
#  'UI.jpg',
#  '.jpg',
#  'map.js',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'google.maps.Map',
#  'document.getElementById',
#  'map.setOptions',
#  'labels.text.fill',
#  'labels.text.stroke',
#  'geometry.stroke',
#  'administrative.land',
#  'landscape.natural',
#  'poi.park',
#  'geometry.fill',
#  'road.arterial',
#  'road.highway',
#  'road.highway.controlled',
#  'road.local',
#  'transit.line',
#  'transit.station',
#  'application.js',
#  'this.App',
#  'App.cable',
#  'ActionCable.createConsumer',
#  '.call',
#  '.js',
#  '.css',
#  'div.dialog',
#  'styles.css',
#  'script.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'document.getElementById',
#  '.style.width',
#  'google.maps.Map',
#  'google.maps.Size',
#  'google.maps.Point',
#  'beaches.length',
#  'google.maps.Marker',
#  'bootstrap.min.css',
#  'main.css',
#  '.org',
#  '.js',
#  'map.js',
#  'google.maps.event.addDomListener',
#  'google.maps.LatLng',
#  'labels.text.fill',
#  'labels.text.stroke',
#  'labels.icon',
#  'geometry.fill',
#  'geometry.stroke',
#  'road.highway',
#  'road.arterial',
#  'road.local',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'bootstrap.min.css',
#  'style.css',
#  'script.js',
#  '.container',
#  nan,
#  'jquery.min.js',
#  'styles.css',
#  'init.js',
#  '.container',
#  'listener.js',
#  'document.getElementById',
#  '.innerHTML',
#  'console.log',
#  'inpObj.checkValidity',
#  'inpObj.validationMessage',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  '.push',
#  'info.data',
#  'check.checked',
#  '.length',
#  '.setMap',
#  'document.addEventListener',
#  'document.querySelector',
#  '.addEventListener',
#  'document.getElementsByClassName',
#  'x.length',
#  '.style.display',
#  'bootstrap.min.css',
#  '.css',
#  'CSS.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'Javascript.js',
#  '.container',
#  '.person',
#  '.carousel',
#  '.bg',
#  '.list',
#  '.thumbnail',
#  '.btn',
#  '.modal',
#  '.close',
#  '.nav',
#  '.navbar',
#  'li.active',
#  '.open',
#  '.dropdown',
#  '.form',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  '.jpg',
#  'unal.edu.co',
#  '.ready',
#  '.tooltip',
#  '.on',
#  'this.hash',
#  'event.preventDefault',
#  '.animate',
#  '.offset',
#  '.top',
#  'window.location.hash',
#  'awesome.min.css',
#  'illinois.edu',
#  'favicon.ico',
#  'bootstrap.min.css',
#  'awesome.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'style.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'main.js',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.LatLng',
#  'google.maps.Marker',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.Marker',
#  'styles.css',
#  'scripts.js',
#  'integration.js',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.Marker',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'tutorial.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'materialize.min.css',
#  'materialize.min.js',
#  '.min.js',
#  '.ajax',
#  'data.cityofchicago.org',
#  'rows.json',
#  '.done',
#  'console.log',
#  'msg.data',
#  'rents.length',
#  'google.maps.LatLng',
#  'google.maps.Marker',
#  'google.maps.Animation.DROP',
#  'marker.addListener',
#  'marker.getAnimation',
#  'marker.setAnimation',
#  'google.maps.Animation.BOUNCE',
#  'markerArray.length',
#  'document.getElementById',
#  'google.maps.Map',
#  '.ready',
#  'google.maps.LatLng',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.event.addDomListener',
#  'map.getCenter',
#  'google.maps.event.trigger',
#  'map.setCenter',
#  'google.maps.Size',
#  'google.maps.Marker',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data.length',
#  'dataLine.push',
#  'json.data',
#  'washedData.push',
#  'washedData.length',
#  'console.log',
#  '.toFixed',
#  'bootstrap.css',
#  'style.css',
#  'jquery.min.js',
#  'code.js',
#  'style.css',
#  'bootstrap.min.css',
#  'jquery.js',
#  'bootstrap.js',
#  'globalVariables.js',
#  'mapController.js',
#  'popUpController.js',
#  'markerController.js',
#  'openWeaterController.js',
#  'rentServicesController.js',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  '.each',
#  'json.data',
#  'info.position',
#  'pinUser.position',
#  'pinHouse.title',
#  'info.uuid',
#  'pinHouse.position',
#  '.marker',
#  'api.openweathermap.org',
#  'data.cityofchicago.org',
#  'rows.json',
#  '.fadeIn',
#  '.fadeOut',
#  '.offset',
#  'position.y',
#  'position.x',
#  '.css',
#  '.contextmenu',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.StreetViewPanorama',
#  'google.maps.MapTypeControlStyle.DROPDOWN',
#  'google.maps.MapTypeId.ROADMAP',
#  'google.maps.MapTypeId.TERRAIN',
#  'map.setCenter',
#  'map.addListener',
#  'event.pixel',
#  'navigator.geolocation',
#  'navigator.geolocation.getCurrentPosition',
#  'positionCenter.lat',
#  'position.coords.latitude',
#  'positionCenter.lng',
#  'position.coords.longitude',
#  'panorama.setPov',
#  'panorama.setPosition',
#  'marker.getPosition',
#  'marker.title',
#  'panorama.addListener',
#  'userMarker.setPosition',
#  'this.getPosition',
#  'panorama.setVisible',
#  'marker.icon',
#  'pinUser.img',
#  'marker.setAnimation',
#  'google.maps.Animation.BOUNCE',
#  'map.panTo',
#  'userMarker.getPosition',
#  'google.maps.Marker',
#  'pinToSet.position',
#  'pinToSet.img',
#  'pinToSet.draggable',
#  'pinToSet.title',
#  'marker.setVisible',
#  'window.setTimeout',
#  'google.maps.Animation.DROP',
#  '.width',
#  '.height',
#  'Math.pow',
#  'map.getZoom',
#  'map.getProjection',
#  'map.getBounds',
#  'proj.fromLatLngToPoint',
#  'google.maps.LatLng',
#  'bounds.getNorthEast',
#  '.lat',
#  'bounds.getSouthWest',
#  '.lng',
#  'google.maps.Point',
#  'point.x',
#  'pixel.x',
#  'nw.x',
#  'point.y',
#  'pixel.y',
#  'nw.y',
#  'proj.fromPointToLatLng',
#  '.getNorthEast',
#  '.getSouthWest',
#  '.fromLatLngToPoint',
#  'Math.floor',
#  'worldCoordinate.x',
#  'worldCoordinateNW.x',
#  'worldCoordinate.y',
#  'worldCoordinateNW.y',
#  'Math.sqrt',
#  '.position',
#  'userPin.position',
#  'marker.addListener',
#  'marker.position',
#  'pixels.x',
#  'pixels.y',
#  '.house',
#  '.text',
#  'houseRent.propertyName',
#  'houseRent.propertyType',
#  'houseRent.address',
#  'houseRent.phoneNumber',
#  'houseRent.units',
#  'pinHouse.img',
#  'pinHouse.imgMin',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'style.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'RadarChart.js',
#  'script.js',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.MarkerImage',
#  'google.maps.Size',
#  'google.maps.Point',
#  'google.maps.Marker',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data',
#  '.innerHTML',
#  'json.data.length',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'boundBox.getNorthEast',
#  'northEast.lng',
#  'southWest.lng',
#  'northEast.lat',
#  'southWest.lat',
#  'google.maps.LatLng',
#  'Math.random',
#  'locations.push',
#  'elevator.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'key.toString',
#  '.slice',
#  'infowindow.close',
#  'infowindow.setContent',
#  'infowindow.open',
#  'RadarChart.draw',
#  'arr.length',
#  '.url',
#  '.display',
#  'Math.PI',
#  '.scale.category',
#  'cfg.maxValue',
#  'Math.max',
#  '.max',
#  'i.map',
#  'o.value',
#  '.map',
#  'i.axis',
#  'allAxis.length',
#  'cfg.factor',
#  'Math.min',
#  'cfg.w',
#  'cfg.h',
#  '.format',
#  '.select',
#  '.remove',
#  '.append',
#  '.attr',
#  'cfg.ExtraWidthX',
#  'cfg.ExtraWidthY',
#  'cfg.TranslateX',
#  'cfg.TranslateY',
#  'cfg.levels',
#  'g.selectAll',
#  '.levels',
#  '.data',
#  '.enter',
#  'Math.sin',
#  'cfg.radians',
#  'Math.cos',
#  '.style',
#  'cfg.ToRight',
#  '.text',
#  '.axis',
#  'axis.append',
#  'cfg.factortitle',
#  'd.forEach',
#  '.nodes',
#  'dataValues.push',
#  'j.value',
#  '.area',
#  'cfg.color',
#  'd.length',
#  'cfg.opacityArea',
#  '.on',
#  '.transition',
#  'cfg.radius',
#  'j.axis',
#  'd.value',
#  'g.append',
#  'style.css',
#  'scripts.js',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'awesome.min.css',
#  'bootstrap.min.css',
#  'style.css',
#  'favicon.ico',
#  '.navbar',
#  'jquery.min.js',
#  'jquery.easing.min.js',
#  'bootstrap.min.js',
#  'custom.js',
#  'data.js',
#  'map.js',
#  '.ready',
#  '.click',
#  '.ajax',
#  '.done',
#  '.text',
#  'data.name',
#  'console.log',
#  '.fail',
#  'data.cityofchicago.org',
#  'a.btn',
#  '.quick',
#  '.overlay',
#  '.on',
#  'event.preventDefault',
#  'this.hash',
#  '.animate',
#  '.offset',
#  '.top',
#  'window.location.hash',
#  '.scroll',
#  '.addClass',
#  '.removeClass',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.Marker',
#  'google.maps.InfoWindow',
#  'google.maps.event.addListener',
#  'infowindow.setContent',
#  'infowindow.open',
#  'initialMarker.setAnimation',
#  'google.maps.Animation.BOUNCE',
#  'initialMarker.addListener',
#  'initialMarker.getAnimation',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data.length',
#  'json.data',
#  'google.maps.LatLng',
#  'google.maps.TravelMode.WALKING',
#  'google.maps.DistanceMatrixService',
#  'service.getDistanceMatrix',
#  'google.maps.UnitSystem.METRIC',
#  'google.maps.DistanceMatrixStatus.OK',
#  'response.originAddresses',
#  'response.destinationAddresses',
#  'origins.length',
#  'response.rows',
#  '.elements',
#  'results.length',
#  'element.distance.text',
#  'element.duration.text',
#  'gl.js',
#  '.min.js',
#  'js.org',
#  '.v',
#  'gl.css',
#  'awesome.min.css',
#  'menu.css',
#  'main.css',
#  'mapboxgl.accessToken',
#  'pk.eyJ',
#  '.gbHmrqcN',
#  'HelloWorldControl.prototype.onAdd',
#  'button.children',
#  '.click',
#  'layerMenu.animate',
#  'layerMenu.children',
#  'map.setStyle',
#  'this.id',
#  'container.appendChild',
#  'HelloWorldControl.prototype.onRemove',
#  'container.parentNode.removeChild',
#  'mapboxgl.Map',
#  'map.addControl',
#  'mapboxgl.NavigationControl',
#  'mapboxgl.Popup',
#  '.setText',
#  'document.createElement',
#  'flag.id',
#  'mapboxgl.Marker',
#  '.setLngLat',
#  '.setPopup',
#  '.addTo',
#  '.json',
#  'data.cityofchicago.org',
#  'iimk.json',
#  'data.length',
#  '.setHTML',
#  '.address',
#  '.property',
#  '.phone',
#  '.zip',
#  'point.className',
#  '.longitude',
#  '.latitude',
#  'gl.js',
#  '.min.js',
#  'js.org',
#  '.v',
#  'gl.css',
#  'awesome.min.css',
#  'menu.css',
#  'main.css',
#  'mapboxgl.accessToken',
#  'pk.eyJ',
#  '.gbHmrqcN',
#  'HelloWorldControl.prototype.onAdd',
#  'button.children',
#  '.click',
#  'layerMenu.animate',
#  'layerMenu.children',
#  'map.setStyle',
#  'this.id',
#  'container.appendChild',
#  'HelloWorldControl.prototype.onRemove',
#  'container.parentNode.removeChild',
#  'mapboxgl.Map',
#  'map.addControl',
#  'mapboxgl.NavigationControl',
#  'mapboxgl.Popup',
#  '.setText',
#  'document.createElement',
#  'flag.id',
#  'mapboxgl.Marker',
#  '.setLngLat',
#  '.setPopup',
#  '.addTo',
#  '.json',
#  'data.cityofchicago.org',
#  'iimk.json',
#  'data.length',
#  '.setHTML',
#  '.address',
#  '.property',
#  '.phone',
#  '.zip',
#  'point.className',
#  '.longitude',
#  '.latitude',
#  'body.css',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.LatLng',
#  'google.maps.Marker',
#  ...]

# %%
str1 = [x for x in new_list if str(x) != 'nan']
str1
# Out:
# ['.ready',
#  '.click',
#  '.mcheck',
#  '.on',
#  '.closest',
#  '.list',
#  '.find',
#  '.form',
#  '.toggleClass',
#  '.val',
#  'document.getElementById',
#  'google.maps.Map',
#  '.getJSON',
#  'test.json',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'js.js',
#  'jsondata.js',
#  'css.css',
#  'style.css',
#  'map.js',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'bootstrap.min.css',
#  'style.css',
#  '.JS',
#  '.js',
#  'jquery.min.js',
#  '.js',
#  'Rent.js',
#  'Crimes.js',
#  'google.maps.Map',
#  'document.getElementById',
#  '.ajax',
#  'data.cityofchicago.org',
#  'xi.json',
#  '.done',
#  'data.length',
#  'google.maps.Marker',
#  'google.maps.LatLng',
#  '.latitude',
#  '.longitude',
#  '.primary',
#  'crimeMarker.push',
#  'crimeMarker.length',
#  '.setMap',
#  'google.maps.InfoWindow',
#  'google.maps.event.addListener',
#  'infowindow.close',
#  'infowindow.setContent',
#  'data.primary',
#  'infowindow.open',
#  'marker.get',
#  '.innerHTML',
#  'data.id',
#  'data.date',
#  'data.description',
#  'data.year',
#  'iimk.json',
#  '.address',
#  'rentMarker.push',
#  'rentMarker.length',
#  'data.property',
#  'data.address',
#  'data.zip',
#  'data.phone',
#  'data.management',
#  'js.org',
#  '.v',
#  '.min.js',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data',
#  '.innerHTML',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'boundBox.getNorthEast',
#  'google.maps.LatLng',
#  'southWest.lat',
#  'southWest.lng',
#  'locations.push',
#  'elevator.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'google.maps.Marker',
#  'key.toString',
#  '.slice',
#  'infowindow.close',
#  'infowindow.setContent',
#  'infowindow.open',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'Map.js',
#  'style.css',
#  'jquery.min.js',
#  '.js',
#  'info.js',
#  'document.getElementById',
#  'google.maps.Map',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'dataRental.push',
#  'json.data',
#  'wData.push',
#  'wData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'google.maps.LatLng',
#  'style.css',
#  'script.js',
#  'jquery.min.js',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.InfoWindow',
#  'google.maps.Marker',
#  'google.maps.Size',
#  'marker.addListener',
#  'infowindow.close',
#  'infowindow.open',
#  'marker.get',
#  '.ajax',
#  'data.cityofchicago.org',
#  'iimk.json',
#  '.done',
#  'data.length',
#  'google.maps.LatLng',
#  '.latitude',
#  '.longitude',
#  '.property',
#  '.address',
#  '.phone',
#  'select.icon',
#  'select.setMap',
#  'this.property',
#  'this.get',
#  'this.icon',
#  '.innerHTML',
#  'this.address',
#  'this.phone',
#  'this.distance',
#  'console.log',
#  'aux.latitude',
#  'Math.round',
#  'xi.json',
#  'aux.longitude',
#  'map.setCenter',
#  'map.c',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'PROJECT.HTML',
#  'lml.jpg',
#  'google.maps.LatLng',
#  'google.maps.MapTypeId.ROADMAP',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.Marker',
#  'google.maps.event.addListener',
#  'google.maps.event.addDomListener',
#  'map.setZoom',
#  'map.setCenter',
#  'marker.getPosition',
#  'google.maps.InfoWindow',
#  'infowindow.open',
#  '.floating',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.MapTypeId.HIBRID',
#  'google.maps.TrafficLayer',
#  'map.data.loadGeoJson',
#  'data.cityofchicago.org',
#  'xi.geojson',
#  'map.data.setStyle',
#  'google.maps.SymbolPath.CIRCLE',
#  'iimk.geojson',
#  'google.maps.LatLng',
#  'google.maps.Marker',
#  'google.maps.InfoWindow',
#  'google.maps.event.addListener',
#  'infowindow.open',
#  'style.css',
#  'k.jpg',
#  'code.js',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'stylescss.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'map.js',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'tutorial.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'RadarChart.js',
#  'tutorial.js',
#  'script.js',
#  '.navbar',
#  '.container',
#  'sites.jpg',
#  'social.jpg',
#  'api.openweathermap.org',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  '.coord.lon',
#  'document.getElementById',
#  '.innerHTML',
#  'json.weather',
#  '.main',
#  '.select',
#  '.selectAll',
#  '.append',
#  '.attr',
#  'cfg.w',
#  'cfg.h',
#  '.scale.category',
#  'svg.append',
#  '.text',
#  'title.selectAll',
#  '.data',
#  '.enter',
#  '.style',
#  'arr.length',
#  '.url',
#  '.display',
#  '.resize',
#  '.height',
#  '.css',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.Map',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'json.data',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'boundBox.getNorthEast',
#  'northEast.lng',
#  'southWest.lng',
#  'northEast.lat',
#  'southWest.lat',
#  'google.maps.LatLng',
#  'Math.random',
#  'locations.push',
#  'elevator.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'google.maps.Marker',
#  'key.toString',
#  '.slice',
#  'infowindow.close',
#  'infowindow.setContent',
#  'infowindow.open',
#  '.capitalizeFirstLetter',
#  'RadarChart.draw',
#  'str.indexOf',
#  'd.getDay',
#  'Math.PI',
#  'cfg.maxValue',
#  'Math.max',
#  '.max',
#  'i.map',
#  'o.value',
#  '.map',
#  'i.axis',
#  'allAxis.length',
#  'cfg.factor',
#  'Math.min',
#  '.format',
#  '.remove',
#  'cfg.ExtraWidthX',
#  'cfg.ExtraWidthY',
#  'cfg.TranslateX',
#  'cfg.TranslateY',
#  'cfg.levels',
#  'g.selectAll',
#  '.levels',
#  'Math.sin',
#  'cfg.radians',
#  'Math.cos',
#  'cfg.ToRight',
#  '.axis',
#  'axis.append',
#  'cfg.factortitle',
#  'd.forEach',
#  '.nodes',
#  'dataValues.push',
#  'j.value',
#  '.area',
#  'cfg.color',
#  'd.length',
#  'cfg.opacityArea',
#  '.on',
#  '.transition',
#  'cfg.radius',
#  'j.axis',
#  'd.value',
#  'g.append',
#  'demos.css',
#  'bootstrap.min.css',
#  'style.css',
#  'map.gif',
#  'UI.jpg',
#  '.jpg',
#  'map.js',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'google.maps.Map',
#  'document.getElementById',
#  'map.setOptions',
#  'labels.text.fill',
#  'labels.text.stroke',
#  'geometry.stroke',
#  'administrative.land',
#  'landscape.natural',
#  'poi.park',
#  'geometry.fill',
#  'road.arterial',
#  'road.highway',
#  'road.highway.controlled',
#  'road.local',
#  'transit.line',
#  'transit.station',
#  'application.js',
#  'this.App',
#  'App.cable',
#  'ActionCable.createConsumer',
#  '.call',
#  '.js',
#  '.css',
#  'div.dialog',
#  'styles.css',
#  'script.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'document.getElementById',
#  '.style.width',
#  'google.maps.Map',
#  'google.maps.Size',
#  'google.maps.Point',
#  'beaches.length',
#  'google.maps.Marker',
#  'bootstrap.min.css',
#  'main.css',
#  '.org',
#  '.js',
#  'map.js',
#  'google.maps.event.addDomListener',
#  'google.maps.LatLng',
#  'labels.text.fill',
#  'labels.text.stroke',
#  'labels.icon',
#  'geometry.fill',
#  'geometry.stroke',
#  'road.highway',
#  'road.arterial',
#  'road.local',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'bootstrap.min.css',
#  'style.css',
#  'script.js',
#  '.container',
#  'jquery.min.js',
#  'styles.css',
#  'init.js',
#  '.container',
#  'listener.js',
#  'document.getElementById',
#  '.innerHTML',
#  'console.log',
#  'inpObj.checkValidity',
#  'inpObj.validationMessage',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  '.push',
#  'info.data',
#  'check.checked',
#  '.length',
#  '.setMap',
#  'document.addEventListener',
#  'document.querySelector',
#  '.addEventListener',
#  'document.getElementsByClassName',
#  'x.length',
#  '.style.display',
#  'bootstrap.min.css',
#  '.css',
#  'CSS.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'Javascript.js',
#  '.container',
#  '.person',
#  '.carousel',
#  '.bg',
#  '.list',
#  '.thumbnail',
#  '.btn',
#  '.modal',
#  '.close',
#  '.nav',
#  '.navbar',
#  'li.active',
#  '.open',
#  '.dropdown',
#  '.form',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  '.jpg',
#  'unal.edu.co',
#  '.ready',
#  '.tooltip',
#  '.on',
#  'this.hash',
#  'event.preventDefault',
#  '.animate',
#  '.offset',
#  '.top',
#  'window.location.hash',
#  'awesome.min.css',
#  'illinois.edu',
#  'favicon.ico',
#  'bootstrap.min.css',
#  'awesome.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'style.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'main.js',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.LatLng',
#  'google.maps.Marker',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.Marker',
#  'styles.css',
#  'scripts.js',
#  'integration.js',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.Marker',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'tutorial.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'materialize.min.css',
#  'materialize.min.js',
#  '.min.js',
#  '.ajax',
#  'data.cityofchicago.org',
#  'rows.json',
#  '.done',
#  'console.log',
#  'msg.data',
#  'rents.length',
#  'google.maps.LatLng',
#  'google.maps.Marker',
#  'google.maps.Animation.DROP',
#  'marker.addListener',
#  'marker.getAnimation',
#  'marker.setAnimation',
#  'google.maps.Animation.BOUNCE',
#  'markerArray.length',
#  'document.getElementById',
#  'google.maps.Map',
#  '.ready',
#  'google.maps.LatLng',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.event.addDomListener',
#  'map.getCenter',
#  'google.maps.event.trigger',
#  'map.setCenter',
#  'google.maps.Size',
#  'google.maps.Marker',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data.length',
#  'dataLine.push',
#  'json.data',
#  'washedData.push',
#  'washedData.length',
#  'console.log',
#  '.toFixed',
#  'bootstrap.css',
#  'style.css',
#  'jquery.min.js',
#  'code.js',
#  'style.css',
#  'bootstrap.min.css',
#  'jquery.js',
#  'bootstrap.js',
#  'globalVariables.js',
#  'mapController.js',
#  'popUpController.js',
#  'markerController.js',
#  'openWeaterController.js',
#  'rentServicesController.js',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  '.each',
#  'json.data',
#  'info.position',
#  'pinUser.position',
#  'pinHouse.title',
#  'info.uuid',
#  'pinHouse.position',
#  '.marker',
#  'api.openweathermap.org',
#  'data.cityofchicago.org',
#  'rows.json',
#  '.fadeIn',
#  '.fadeOut',
#  '.offset',
#  'position.y',
#  'position.x',
#  '.css',
#  '.contextmenu',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.StreetViewPanorama',
#  'google.maps.MapTypeControlStyle.DROPDOWN',
#  'google.maps.MapTypeId.ROADMAP',
#  'google.maps.MapTypeId.TERRAIN',
#  'map.setCenter',
#  'map.addListener',
#  'event.pixel',
#  'navigator.geolocation',
#  'navigator.geolocation.getCurrentPosition',
#  'positionCenter.lat',
#  'position.coords.latitude',
#  'positionCenter.lng',
#  'position.coords.longitude',
#  'panorama.setPov',
#  'panorama.setPosition',
#  'marker.getPosition',
#  'marker.title',
#  'panorama.addListener',
#  'userMarker.setPosition',
#  'this.getPosition',
#  'panorama.setVisible',
#  'marker.icon',
#  'pinUser.img',
#  'marker.setAnimation',
#  'google.maps.Animation.BOUNCE',
#  'map.panTo',
#  'userMarker.getPosition',
#  'google.maps.Marker',
#  'pinToSet.position',
#  'pinToSet.img',
#  'pinToSet.draggable',
#  'pinToSet.title',
#  'marker.setVisible',
#  'window.setTimeout',
#  'google.maps.Animation.DROP',
#  '.width',
#  '.height',
#  'Math.pow',
#  'map.getZoom',
#  'map.getProjection',
#  'map.getBounds',
#  'proj.fromLatLngToPoint',
#  'google.maps.LatLng',
#  'bounds.getNorthEast',
#  '.lat',
#  'bounds.getSouthWest',
#  '.lng',
#  'google.maps.Point',
#  'point.x',
#  'pixel.x',
#  'nw.x',
#  'point.y',
#  'pixel.y',
#  'nw.y',
#  'proj.fromPointToLatLng',
#  '.getNorthEast',
#  '.getSouthWest',
#  '.fromLatLngToPoint',
#  'Math.floor',
#  'worldCoordinate.x',
#  'worldCoordinateNW.x',
#  'worldCoordinate.y',
#  'worldCoordinateNW.y',
#  'Math.sqrt',
#  '.position',
#  'userPin.position',
#  'marker.addListener',
#  'marker.position',
#  'pixels.x',
#  'pixels.y',
#  '.house',
#  '.text',
#  'houseRent.propertyName',
#  'houseRent.propertyType',
#  'houseRent.address',
#  'houseRent.phoneNumber',
#  'houseRent.units',
#  'pinHouse.img',
#  'pinHouse.imgMin',
#  'bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'style.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'RadarChart.js',
#  'script.js',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.MarkerImage',
#  'google.maps.Size',
#  'google.maps.Point',
#  'google.maps.Marker',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data',
#  '.innerHTML',
#  'json.data.length',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'boundBox.getNorthEast',
#  'northEast.lng',
#  'southWest.lng',
#  'northEast.lat',
#  'southWest.lat',
#  'google.maps.LatLng',
#  'Math.random',
#  'locations.push',
#  'elevator.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'key.toString',
#  '.slice',
#  'infowindow.close',
#  'infowindow.setContent',
#  'infowindow.open',
#  'RadarChart.draw',
#  'arr.length',
#  '.url',
#  '.display',
#  'Math.PI',
#  '.scale.category',
#  'cfg.maxValue',
#  'Math.max',
#  '.max',
#  'i.map',
#  'o.value',
#  '.map',
#  'i.axis',
#  'allAxis.length',
#  'cfg.factor',
#  'Math.min',
#  'cfg.w',
#  'cfg.h',
#  '.format',
#  '.select',
#  '.remove',
#  '.append',
#  '.attr',
#  'cfg.ExtraWidthX',
#  'cfg.ExtraWidthY',
#  'cfg.TranslateX',
#  'cfg.TranslateY',
#  'cfg.levels',
#  'g.selectAll',
#  '.levels',
#  '.data',
#  '.enter',
#  'Math.sin',
#  'cfg.radians',
#  'Math.cos',
#  '.style',
#  'cfg.ToRight',
#  '.text',
#  '.axis',
#  'axis.append',
#  'cfg.factortitle',
#  'd.forEach',
#  '.nodes',
#  'dataValues.push',
#  'j.value',
#  '.area',
#  'cfg.color',
#  'd.length',
#  'cfg.opacityArea',
#  '.on',
#  '.transition',
#  'cfg.radius',
#  'j.axis',
#  'd.value',
#  'g.append',
#  'style.css',
#  'scripts.js',
#  'document.getElementById',
#  'google.maps.Map',
#  'google.maps.Marker',
#  'awesome.min.css',
#  'bootstrap.min.css',
#  'style.css',
#  'favicon.ico',
#  '.navbar',
#  'jquery.min.js',
#  'jquery.easing.min.js',
#  'bootstrap.min.js',
#  'custom.js',
#  'data.js',
#  'map.js',
#  '.ready',
#  '.click',
#  '.ajax',
#  '.done',
#  '.text',
#  'data.name',
#  'console.log',
#  '.fail',
#  'data.cityofchicago.org',
#  'a.btn',
#  '.quick',
#  '.overlay',
#  '.on',
#  'event.preventDefault',
#  'this.hash',
#  '.animate',
#  '.offset',
#  '.top',
#  'window.location.hash',
#  '.scroll',
#  '.addClass',
#  '.removeClass',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.Marker',
#  'google.maps.InfoWindow',
#  'google.maps.event.addListener',
#  'infowindow.setContent',
#  'infowindow.open',
#  'initialMarker.setAnimation',
#  'google.maps.Animation.BOUNCE',
#  'initialMarker.addListener',
#  'initialMarker.getAnimation',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data.length',
#  'json.data',
#  'google.maps.LatLng',
#  'google.maps.TravelMode.WALKING',
#  'google.maps.DistanceMatrixService',
#  'service.getDistanceMatrix',
#  'google.maps.UnitSystem.METRIC',
#  'google.maps.DistanceMatrixStatus.OK',
#  'response.originAddresses',
#  'response.destinationAddresses',
#  'origins.length',
#  'response.rows',
#  '.elements',
#  'results.length',
#  'element.distance.text',
#  'element.duration.text',
#  'gl.js',
#  '.min.js',
#  'js.org',
#  '.v',
#  'gl.css',
#  'awesome.min.css',
#  'menu.css',
#  'main.css',
#  'mapboxgl.accessToken',
#  'pk.eyJ',
#  '.gbHmrqcN',
#  'HelloWorldControl.prototype.onAdd',
#  'button.children',
#  '.click',
#  'layerMenu.animate',
#  'layerMenu.children',
#  'map.setStyle',
#  'this.id',
#  'container.appendChild',
#  'HelloWorldControl.prototype.onRemove',
#  'container.parentNode.removeChild',
#  'mapboxgl.Map',
#  'map.addControl',
#  'mapboxgl.NavigationControl',
#  'mapboxgl.Popup',
#  '.setText',
#  'document.createElement',
#  'flag.id',
#  'mapboxgl.Marker',
#  '.setLngLat',
#  '.setPopup',
#  '.addTo',
#  '.json',
#  'data.cityofchicago.org',
#  'iimk.json',
#  'data.length',
#  '.setHTML',
#  '.address',
#  '.property',
#  '.phone',
#  '.zip',
#  'point.className',
#  '.longitude',
#  '.latitude',
#  'gl.js',
#  '.min.js',
#  'js.org',
#  '.v',
#  'gl.css',
#  'awesome.min.css',
#  'menu.css',
#  'main.css',
#  'mapboxgl.accessToken',
#  'pk.eyJ',
#  '.gbHmrqcN',
#  'HelloWorldControl.prototype.onAdd',
#  'button.children',
#  '.click',
#  'layerMenu.animate',
#  'layerMenu.children',
#  'map.setStyle',
#  'this.id',
#  'container.appendChild',
#  'HelloWorldControl.prototype.onRemove',
#  'container.parentNode.removeChild',
#  'mapboxgl.Map',
#  'map.addControl',
#  'mapboxgl.NavigationControl',
#  'mapboxgl.Popup',
#  '.setText',
#  'document.createElement',
#  'flag.id',
#  'mapboxgl.Marker',
#  '.setLngLat',
#  '.setPopup',
#  '.addTo',
#  '.json',
#  'data.cityofchicago.org',
#  'iimk.json',
#  'data.length',
#  '.setHTML',
#  '.address',
#  '.property',
#  '.phone',
#  '.zip',
#  'point.className',
#  '.longitude',
#  '.latitude',
#  'body.css',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.LatLng',
#  'google.maps.Marker',
#  'document.createElement',
#  'script.src',
#  ...]

# %%
global_functions = {'Student': 'all', 'functions': [str1], 'phase': 0}
global_functions = pd.DataFrame(data=global_functions)
global_functions
# Out:
#   Student                                          functions  phase
# 0     all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %% [markdown]
# ## Append Global Functions with Bogota 0 Phase 5

# %%
subset_bogota0_phase5_all = subset_bogota0_phase5.append(global_functions, ignore_index=True)
subset_bogota0_phase5_all
# Out:
#            Student                                          functions  phase
# 0        fffeelipe  [.ready, .click, .css, .removeClass, .is, .val...      5
# 1        mnguzmanc  [house.ico, style.css, .css, main.js, map.js, ...      5
# 2       jmcuestasb  [js.org, .v, .min.js, weather.js, myss.css, bo...      5
# 3       katherinsb  [reset.css, layout.css, style.css, jquery.min....      5
# 4     jjrodriguezn  [google.maps.Map, document.getElementById, goo...      5
# 5            DglyP  [bootstrap.min.css, style.css, jquery.min.js, ...      5
# 6           cap182                                                 []      5
# 7      Judgarciani  [bootstrap.min.css, jquery.min.js, bootstrap.m...      5
# 8        sacastroc  [bootstrap.min.css, theme.min.css, jquery.min....      5
# 9        pcberriop  [Map.js, .js, main.css, avatar.jpg, pcberriop....      5
# 10     hsmartineza  [jquery.min.js, .js, map.js, house.js, weather...      5
# 11        Moimolcp  [bootstrap.min.css, style.css, script.js, data...      5
# 12     CamiloRueda  [layout.css, shiv.js, document.getElementById,...      5
# 13       juanescai                                                 []      5
# 14      JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....      5
# 15   maikellPardoA  [document.getElementById, google.maps.Map, goo...      5
# 16      NicolasZon  [google.maps.LatLng, google.maps.MapTypeId.ROA...      5
# 17       camilo654  [bootstrap.min.css, .js, js.js, .ready, .click...      5
# 18  CristianLozano  [document.getElementById, google.maps.Map, goo...      5
# 19       jdsuarezj  [google.maps.Map, document.getElementById, goo...      5
# 20       pipemax85  [bootstrap.min.css, theme.min.css, jquery.min....      5
# 21     juandavidro  [styles.css, script.js, bootstrap.min.css, sit...      5
# 22  UNhcrodriguezl  [demos.css, bootstrap.min.css, select.min.css,...      5
# 23     camilo13152  [mapController.js, favicon.ico, fluidbox.min.c...      5
# 24    leavendanoro  [chicagoicon.ico, styles.css, jquery.min.js, j...      5
# 25      cdcordobaa  [bootstrap.min.css, main.css, .org, .js, map.j...      5
# 26      capinillab  [document.getElementById, google.maps.Map, goo...      5
# 27    lfvalderrama  [up.net, shiv.js, main.css, .css, jquery.min.j...      5
# 28       bsgarciac  [document.getElementsByClassName, x.length, .s...      5
# 29          gabi04  [google.maps.LatLng, google.maps.MapTypeId.ROA...      5
# 30          annipi                                                 []      5
# 31       jdsolanos                                                 []      5
# 32        jcneivaa                                                 []      5
# 33       fmbernalb                                                 []      5
# 34         MogGy94                                                 []      5
# 35       yocuervoc                                                 []      5
# 36       odprietoh                                                 []      5
# 37      janoguerab  [js.org, .v, .min.js, document.getElementById,...      5
# 38     djsanabriac  [bootstrap.min.css, main.js, jquery.min.js, do...      5
# 39      anmmunozme  [.ajax, data.cityofchicago.org, iimk.json, .do...      5
# 40          li2266                                                 []      5
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota0_phase5_all["functions"], subset_bogota0_phase5_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota0_phase5_compare_all = pd.DataFrame(result)
subset_bogota0_phase5_compare_all
# Out:
#            user1         user2  similarity
# 0      fffeelipe     mnguzmanc    0.014280
# 1      fffeelipe    jmcuestasb    0.005329
# 2      fffeelipe    katherinsb    0.009644
# 3      fffeelipe  jjrodriguezn    0.041958
# 4      fffeelipe         DglyP    0.012500
# ..           ...           ...         ...
# 856  djsanabriac        li2266    0.030303
# 857  djsanabriac           all    0.000154
# 858   anmmunozme        li2266    0.000435
# 859   anmmunozme           all    0.011069
# 860       li2266           all    0.000000
#
# [861 rows x 3 columns]

# %%
subset_bogota0_phase5_all_only = subset_bogota0_phase5_compare_all.loc[subset_bogota0_phase5_compare_all['user2'] == 'all']
subset_bogota0_phase5_all_only
# Out:
#               user1 user2  similarity
# 40        fffeelipe   all    0.000559
# 80        mnguzmanc   all    0.011069
# 119      jmcuestasb   all    0.033979
# 157      katherinsb   all    0.011036
# 194    jjrodriguezn   all    0.000149
# 230           DglyP   all    0.011142
# 265          cap182   all    0.000000
# 299     Judgarciani   all    0.001012
# 332       sacastroc   all    0.000386
# 364       pcberriop   all    0.000434
# 395     hsmartineza   all    0.000318
# 425        Moimolcp   all    0.000434
# 454     CamiloRueda   all    0.000226
# 482       juanescai   all    0.000000
# 509      JoseMolano   all    0.000236
# 535   maikellPardoA   all    0.000019
# 560      NicolasZon   all    0.000058
# 584       camilo654   all    0.000145
# 607  CristianLozano   all    0.000034
# 629       jdsuarezj   all    0.000318
# 650       pipemax85   all    0.000135
# 670     juandavidro   all    0.000072
# 689  UNhcrodriguezl   all    0.000429
# 707     camilo13152   all    0.000419
# 724    leavendanoro   all    0.000222
# 740      cdcordobaa   all    0.000154
# 755      capinillab   all    0.000217
# 769    lfvalderrama   all    0.000299
# 782       bsgarciac   all    0.000631
# 794          gabi04   all    0.000381
# 805          annipi   all    0.000000
# 815       jdsolanos   all    0.000000
# 824        jcneivaa   all    0.000000
# 832       fmbernalb   all    0.000000
# 839         MogGy94   all    0.000000
# 845       yocuervoc   all    0.000000
# 850       odprietoh   all    0.000000
# 854      janoguerab   all    0.000173
# 857     djsanabriac   all    0.000154
# 859      anmmunozme   all    0.011069
# 860          li2266   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 0 Phase 4

# %%
subset_bogota0_phase4_all = subset_bogota0_phase4.append(global_functions, ignore_index=True)
print(subset_bogota0_phase4_all)
# Out:
#            Student                                          functions  phase
# 0        fffeelipe  [.ready, .click, .removeClass, .is, .val, .che...      4
# 1        mnguzmanc  [house.ico, style.css, .css, main.js, map.js, ...      4
# 2       jmcuestasb  [js.org, .v, .min.js, weather.js, mycss.css, b...      4
# 3       katherinsb  [reset.css, layout.css, style.css, .js, yui.js...      4
# 4     jjrodriguezn  [google.maps.Map, document.getElementById, goo...      4
# 5            DglyP  [bootstrap.min.css, style.css, jquery.min.js, ...      4
# 6           cap182                                                 []      4
# 7      Judgarciani  [bootstrap.min.css, jquery.min.js, bootstrap.m...      4
# 8        sacastroc  [js.org, .v, .min.js, collection.v, dispatch.v...      4
# 9        pcberriop  [jquery.min.js, Map.js, main.css, avatar.jpg, ...      4
# 10     hsmartineza  [jquery.min.js, .js, map.js, house.js, weather...      4
# 11        Moimolcp  [bootstrap.min.css, style.css, script.js, jque...      4
# 12     CamiloRueda  [layout.css, shiv.js, document.getElementById,...      4
# 13       juanescai                                                 []      4
# 14      JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....      4
# 15   maikellPardoA  [document.getElementById, google.maps.Map, goo...      4
# 16      NicolasZon  [google.maps.LatLng, google.maps.MapTypeId.ROA...      4
# 17       camilo654  [.ready, .click, .ajax, data.cityofchicago.org...      4
# 18  CristianLozano  [document.getElementById, google.maps.Map, goo...      4
# 19       jdsuarezj  [google.maps.Map, document.getElementById, goo...      4
# 20       pipemax85  [bootstrap.min.css, theme.min.css, jquery.min....      4
# 21     juandavidro  [styles.css, script.js, bootstrap.min.css, sit...      4
# 22  UNhcrodriguezl  [demos.css, bootstrap.min.css, select.min.css,...      4
# 23     camilo13152  [mapController.js, favicon.ico, fluidbox.min.c...      4
# 24    leavendanoro  [styles.css, jquery.min.js, js.org, .v, .min.j...      4
# 25      cdcordobaa  [bootstrap.min.css, main.css, .org, .js, map.j...      4
# 26      capinillab  [document.getElementById, google.maps.Map, goo...      4
# 27    lfvalderrama  [up.net, shiv.js, main.css, .css, jquery.min.j...      4
# 28       bsgarciac  [document.getElementsByClassName, x.length, .s...      4
# 29          gabi04  [google.maps.LatLng, google.maps.MapTypeId.ROA...      4
# 30          annipi                                                 []      4
# 31       jdsolanos                                                 []      4
# 32        jcneivaa                                                 []      4
# 33       fmbernalb                                                 []      4
# 34         MogGy94                                                 []      4
# 35       yocuervoc                                                 []      4
# 36       odprietoh                                                 []      4
# 37      janoguerab  [js.org, .v, .min.js, document.getElementById,...      4
# 38     djsanabriac  [bootstrap.min.css, main.js, jquery.min.js, do...      4
# 39      anmmunozme  [.ajax, data.cityofchicago.org, iimk.json, .do...      4
# 40          li2266                                                 []      4
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota0_phase4_all["functions"], subset_bogota0_phase4_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota0_phase4_compare_all = pd.DataFrame(result)
subset_bogota0_phase4_compare_all
# Out:
#            user1         user2  similarity
# 0      fffeelipe     mnguzmanc    0.013525
# 1      fffeelipe    jmcuestasb    0.005054
# 2      fffeelipe    katherinsb    0.032000
# 3      fffeelipe  jjrodriguezn    0.046154
# 4      fffeelipe         DglyP    0.010959
# ..           ...           ...         ...
# 856  djsanabriac        li2266    0.030303
# 857  djsanabriac           all    0.000154
# 858   anmmunozme        li2266    0.018182
# 859   anmmunozme           all    0.000260
# 860       li2266           all    0.000000
#
# [861 rows x 3 columns]

# %%
subset_bogota0_phase4_all_only = subset_bogota0_phase4_compare_all.loc[subset_bogota0_phase4_compare_all['user2'] == 'all']
subset_bogota0_phase4_all_only
# Out:
#               user1 user2  similarity
# 40        fffeelipe   all    0.000511
# 80        mnguzmanc   all    0.011036
# 119      jmcuestasb   all    0.033979
# 157      katherinsb   all    0.000101
# 194    jjrodriguezn   all    0.000135
# 230           DglyP   all    0.013705
# 265          cap182   all    0.000000
# 299     Judgarciani   all    0.000665
# 332       sacastroc   all    0.000390
# 364       pcberriop   all    0.000318
# 395     hsmartineza   all    0.000304
# 425        Moimolcp   all    0.000386
# 454     CamiloRueda   all    0.000226
# 482       juanescai   all    0.000000
# 509      JoseMolano   all    0.000236
# 535   maikellPardoA   all    0.000019
# 560      NicolasZon   all    0.000058
# 584       camilo654   all    0.000145
# 607  CristianLozano   all    0.000034
# 629       jdsuarezj   all    0.000318
# 650       pipemax85   all    0.000135
# 670     juandavidro   all    0.000072
# 689  UNhcrodriguezl   all    0.000429
# 707     camilo13152   all    0.000419
# 724    leavendanoro   all    0.000222
# 740      cdcordobaa   all    0.000154
# 755      capinillab   all    0.000169
# 769    lfvalderrama   all    0.000299
# 782       bsgarciac   all    0.000626
# 794          gabi04   all    0.000280
# 805          annipi   all    0.000000
# 815       jdsolanos   all    0.000000
# 824        jcneivaa   all    0.000000
# 832       fmbernalb   all    0.000000
# 839         MogGy94   all    0.000000
# 845       yocuervoc   all    0.000000
# 850       odprietoh   all    0.000000
# 854      janoguerab   all    0.000173
# 857     djsanabriac   all    0.000154
# 859      anmmunozme   all    0.000260
# 860          li2266   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 0 Phase 3

# %%
subset_bogota0_phase3_all = subset_bogota0_phase3.append(global_functions, ignore_index=True)
print(subset_bogota0_phase3_all)
# Out:
#            Student                                          functions  phase
# 0        fffeelipe  [.ready, .click, .mcheck, .on, .closest, .list...      3
# 1        mnguzmanc  [house.ico, style.css, .css, main.js, map.js, ...      3
# 2       jmcuestasb  [js.org, .v, .min.js, weather.js, mycss.css, b...      3
# 3       katherinsb                                                 []      3
# 4     jjrodriguezn  [google.maps.Map, document.getElementById, goo...      3
# 5            DglyP  [google.maps.Map, document.getElementById, goo...      3
# 6           cap182                                                 []      3
# 7      Judgarciani  [bootstrap.min.css, jquery.min.js, bootstrap.m...      3
# 8        sacastroc  [js.org, .v, .min.js, collection.v, dispatch.v...      3
# 9        pcberriop  [google.maps.Map, document.getElementById, goo...      3
# 10     hsmartineza  [jquery.min.js, .js, map.js, info.js, test.js,...      3
# 11        Moimolcp  [bootstrap.min.css, style.css, script.js, jque...      3
# 12     CamiloRueda  [layout.css, shiv.js, document.getElementById,...      3
# 13       juanescai                                                 []      3
# 14      JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....      3
# 15   maikellPardoA  [document.getElementById, google.maps.Map, goo...      3
# 16      NicolasZon  [google.maps.LatLng, google.maps.MapTypeId.ROA...      3
# 17       camilo654  [.ready, .click, .ajax, data.cityofchicago.org...      3
# 18  CristianLozano  [document.getElementById, google.maps.Map, goo...      3
# 19       jdsuarezj  [google.maps.Map, document.getElementById, goo...      3
# 20       pipemax85  [bootstrap.min.css, theme.min.css, jquery.min....      3
# 21     juandavidro  [styles.css, script.js, bootstrap.min.css, sit...      3
# 22  UNhcrodriguezl  [demos.css, bootstrap.min.css, select.min.css,...      3
# 23     camilo13152  [mapController.js, favicon.ico, fluidbox.min.c...      3
# 24    leavendanoro  [styles.css, js.org, .v, .min.js, script.js, d...      3
# 25      cdcordobaa  [bootstrap.min.css, main.css, .org, .js, map.j...      3
# 26      capinillab  [document.getElementById, google.maps.Map, goo...      3
# 27    lfvalderrama  [jquery.min.js, styles.css, init.js, handler.j...      3
# 28       bsgarciac  [document.getElementsByClassName, x.length, .s...      3
# 29          gabi04  [google.maps.LatLng, google.maps.MapTypeId.ROA...      3
# 30          annipi                                                 []      3
# 31       jdsolanos                                                 []      3
# 32        jcneivaa                                                 []      3
# 33       fmbernalb                                                 []      3
# 34         MogGy94                                                 []      3
# 35       yocuervoc                                                 []      3
# 36       odprietoh                                                 []      3
# 37      janoguerab  [js.org, .v, .min.js, document.getElementById,...      3
# 38     djsanabriac  [bootstrap.min.css, main.js, jquery.min.js, do...      3
# 39      anmmunozme  [.ready, .click, .ajax, data.cityofchicago.org...      3
# 40          li2266                                                 []      3
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota0_phase3_all["functions"], subset_bogota0_phase3_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota0_phase3_compare_all = pd.DataFrame(result)
subset_bogota0_phase3_compare_all
# Out:
#            user1         user2  similarity
# 0      fffeelipe     mnguzmanc    0.004357
# 1      fffeelipe    jmcuestasb    0.001980
# 2      fffeelipe    katherinsb    0.032258
# 3      fffeelipe  jjrodriguezn    0.113208
# 4      fffeelipe         DglyP    0.272727
# ..           ...           ...         ...
# 856  djsanabriac        li2266    0.030303
# 857  djsanabriac           all    0.000154
# 858   anmmunozme        li2266    0.027027
# 859   anmmunozme           all    0.000173
# 860       li2266           all    0.000000
#
# [861 rows x 3 columns]

# %%
subset_bogota0_phase3_all_only = subset_bogota0_phase3_compare_all.loc[subset_bogota0_phase3_compare_all['user2'] == 'all']
subset_bogota0_phase3_all_only
# Out:
#               user1 user2  similarity
# 40        fffeelipe   all    0.000145
# 80        mnguzmanc   all    0.010954
# 119      jmcuestasb   all    0.033979
# 157      katherinsb   all    0.000000
# 194    jjrodriguezn   all    0.000130
# 230           DglyP   all    0.000116
# 265          cap182   all    0.000000
# 299     Judgarciani   all    0.000641
# 332       sacastroc   all    0.000347
# 364       pcberriop   all    0.000198
# 395     hsmartineza   all    0.000251
# 425        Moimolcp   all    0.000376
# 454     CamiloRueda   all    0.000226
# 482       juanescai   all    0.000000
# 509      JoseMolano   all    0.000236
# 535   maikellPardoA   all    0.000019
# 560      NicolasZon   all    0.000058
# 584       camilo654   all    0.000087
# 607  CristianLozano   all    0.000034
# 629       jdsuarezj   all    0.000318
# 650       pipemax85   all    0.000135
# 670     juandavidro   all    0.000072
# 689  UNhcrodriguezl   all    0.000429
# 707     camilo13152   all    0.000337
# 724    leavendanoro   all    0.000154
# 740      cdcordobaa   all    0.000154
# 755      capinillab   all    0.000096
# 769    lfvalderrama   all    0.000284
# 782       bsgarciac   all    0.000482
# 794          gabi04   all    0.000280
# 805          annipi   all    0.000000
# 815       jdsolanos   all    0.000000
# 824        jcneivaa   all    0.000000
# 832       fmbernalb   all    0.000000
# 839         MogGy94   all    0.000000
# 845       yocuervoc   all    0.000000
# 850       odprietoh   all    0.000000
# 854      janoguerab   all    0.000173
# 857     djsanabriac   all    0.000154
# 859      anmmunozme   all    0.000173
# 860          li2266   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 0 Phase 2

# %%
subset_bogota0_phase2_all = subset_bogota0_phase2.append(global_functions, ignore_index=True)
print(subset_bogota0_phase2_all)
# Out:
#            Student                                          functions  phase
# 0        fffeelipe  [.ready, .click, .mcheck, .on, .closest, .list...      2
# 1        mnguzmanc  [house.ico, style.css, map.js, Chicago.jpg, do...      2
# 2       jmcuestasb  [js.org, .v, .min.js, weather.js, mycss.css, b...      2
# 3       katherinsb                                                 []      2
# 4     jjrodriguezn  [data.cityofchicago.org, rows.json, .ajax, goo...      2
# 5            DglyP  [google.maps.Map, document.getElementById, goo...      2
# 6           cap182                                                 []      2
# 7      Judgarciani  [bootstrap.min.css, jquery.min.js, bootstrap.m...      2
# 8        sacastroc  [js.org, .v, .min.js, collection.v, dispatch.v...      2
# 9        pcberriop  [google.maps.Map, document.getElementById, goo...      2
# 10     hsmartineza  [jquery.min.js, .js, info.js, chicago.jpg, doc...      2
# 11        Moimolcp  [style.css, script.js, jquery.min.js, google.m...      2
# 12     CamiloRueda  [layout.css, shiv.js, document.getElementById,...      2
# 13       juanescai                                                 []      2
# 14      JoseMolano  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 15   maikellPardoA  [document.getElementById, google.maps.Map, goo...      2
# 16      NicolasZon  [google.maps.LatLng, google.maps.MapTypeId.ROA...      2
# 17       camilo654  [.ready, .click, .ajax, data.cityofchicago.org...      2
# 18  CristianLozano  [document.getElementById, google.maps.Map, goo...      2
# 19       jdsuarezj  [google.maps.Map, document.getElementById, goo...      2
# 20       pipemax85  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 21     juandavidro  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 22  UNhcrodriguezl  [demos.css, bootstrap.min.css, select.min.css,...      2
# 23     camilo13152  [favicon.ico, fluidbox.min.css, main.css, goog...      2
# 24    leavendanoro  [styles.css, js.org, .v, .min.js, myArrayOfObj...      2
# 25      cdcordobaa  [bootstrap.min.css, main.css, .org, .js, map.j...      2
# 26      capinillab  [document.getElementById, google.maps.Map, goo...      2
# 27    lfvalderrama  [jquery.min.js, styles.css, init.js, test.js, ...      2
# 28       bsgarciac  [document.getElementsByClassName, x.length, .s...      2
# 29          gabi04  [google.maps.LatLng, google.maps.MapTypeId.ROA...      2
# 30          annipi                                                 []      2
# 31       jdsolanos                                                 []      2
# 32        jcneivaa                                                 []      2
# 33       fmbernalb                                                 []      2
# 34         MogGy94                                                 []      2
# 35       yocuervoc                                                 []      2
# 36       odprietoh                                                 []      2
# 37      janoguerab  [js.org, .v, .min.js, document.getElementById,...      2
# 38     djsanabriac  [bootstrap.min.css, main.js, jquery.min.js, do...      2
# 39      anmmunozme  [.ready, .click, .ajax, data.cityofchicago.org...      2
# 40          li2266                                                 []      2
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota0_phase2_all["functions"], subset_bogota0_phase2_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota0_phase2_compare_all = pd.DataFrame(result)
subset_bogota0_phase2_compare_all
# Out:
#            user1         user2  similarity
# 0      fffeelipe     mnguzmanc    0.117647
# 1      fffeelipe    jmcuestasb    0.001980
# 2      fffeelipe    katherinsb    0.032258
# 3      fffeelipe  jjrodriguezn    0.214286
# 4      fffeelipe         DglyP    0.272727
# ..           ...           ...         ...
# 856  djsanabriac        li2266    0.030303
# 857  djsanabriac           all    0.000154
# 858   anmmunozme        li2266    0.041667
# 859   anmmunozme           all    0.000111
# 860       li2266           all    0.000000
#
# [861 rows x 3 columns]

# %%
subset_bogota0_phase2_all_only = subset_bogota0_phase2_compare_all.loc[subset_bogota0_phase2_compare_all['user2'] == 'all']
subset_bogota0_phase2_all_only
# Out:
#               user1 user2  similarity
# 40        fffeelipe   all    0.000145
# 80        mnguzmanc   all    0.000120
# 119      jmcuestasb   all    0.033979
# 157      katherinsb   all    0.000000
# 194    jjrodriguezn   all    0.000092
# 230           DglyP   all    0.000116
# 265          cap182   all    0.000000
# 299     Judgarciani   all    0.000386
# 332       sacastroc   all    0.000202
# 364       pcberriop   all    0.000198
# 395     hsmartineza   all    0.000169
# 425        Moimolcp   all    0.000188
# 454     CamiloRueda   all    0.000226
# 482       juanescai   all    0.000000
# 509      JoseMolano   all    0.000226
# 535   maikellPardoA   all    0.000019
# 560      NicolasZon   all    0.000058
# 584       camilo654   all    0.000087
# 607  CristianLozano   all    0.000034
# 629       jdsuarezj   all    0.000198
# 650       pipemax85   all    0.000106
# 670     juandavidro   all    0.000612
# 689  UNhcrodriguezl   all    0.000376
# 707     camilo13152   all    0.000067
# 724    leavendanoro   all    0.000106
# 740      cdcordobaa   all    0.000154
# 755      capinillab   all    0.000096
# 769    lfvalderrama   all    0.000193
# 782       bsgarciac   all    0.000289
# 794          gabi04   all    0.000198
# 805          annipi   all    0.000000
# 815       jdsolanos   all    0.000000
# 824        jcneivaa   all    0.000000
# 832       fmbernalb   all    0.000000
# 839         MogGy94   all    0.000000
# 845       yocuervoc   all    0.000000
# 850       odprietoh   all    0.000000
# 854      janoguerab   all    0.000173
# 857     djsanabriac   all    0.000154
# 859      anmmunozme   all    0.000111
# 860          li2266   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 0 Phase 1

# %%
subset_bogota0_phase1_all = subset_bogota0_phase1.append(global_functions, ignore_index=True)
print(subset_bogota0_phase1_all)
# Out:
#            Student                                          functions  phase
# 0        fffeelipe  [.ready, .click, .mcheck, .on, .closest, .list...      1
# 1        mnguzmanc  [style.css, map.js, document.getElementById, g...      1
# 2       jmcuestasb                                                 []      1
# 3       katherinsb                                                 []      1
# 4     jjrodriguezn                                                 []      1
# 5            DglyP         [bootstrap.min.css, style.css, .JS, .js, ]      1
# 6           cap182                                                 []      1
# 7      Judgarciani  [jquery.min.js, .js, Rent.js, Crimes.js, googl...      1
# 8        sacastroc  [js.org, .v, .min.js, bootstrap.min.css, theme...      1
# 9        pcberriop  [google.maps.Map, document.getElementById, goo...      1
# 10     hsmartineza  [jquery.min.js, .js, info.js, document.getElem...      1
# 11        Moimolcp  [style.css, script.js, jquery.min.js, google.m...      1
# 12     CamiloRueda                                                 []      1
# 13       juanescai                                                 []      1
# 14      JoseMolano  [document.getElementById, google.maps.Map, goo...      1
# 15   maikellPardoA  [document.getElementById, google.maps.Map, goo...      1
# 16      NicolasZon  [lml.jpg, google.maps.LatLng, google.maps.MapT...      1
# 17       camilo654  [.floating, document.getElementById, google.ma...      1
# 18  CristianLozano  [document.getElementById, google.maps.Map, goo...      1
# 19       jdsuarezj  [google.maps.Map, document.getElementById, goo...      1
# 20       pipemax85  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 21     juandavidro  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 22  UNhcrodriguezl  [demos.css, bootstrap.min.css, style.css, map....      1
# 23     camilo13152  [application.js, this.App, App.cable, ActionCa...      1
# 24    leavendanoro  [styles.css, script.js, js.org, .v, .min.js, d...      1
# 25      cdcordobaa  [bootstrap.min.css, main.css, .org, .js, map.j...      1
# 26      capinillab  [document.getElementById, google.maps.Map, goo...      1
# 27    lfvalderrama  [jquery.min.js, styles.css, init.js, .containe...      1
# 28       bsgarciac  [document.getElementsByClassName, x.length, .s...      1
# 29          gabi04                                                 []      1
# 30          annipi                                                 []      1
# 31       jdsolanos                                                 []      1
# 32        jcneivaa                                                 []      1
# 33       fmbernalb                                                 []      1
# 34         MogGy94                                                 []      1
# 35       yocuervoc                                                 []      1
# 36       odprietoh                                                 []      1
# 37      janoguerab  [document.getElementById, google.maps.Map, goo...      1
# 38     djsanabriac  [bootstrap.min.css, main.js, jquery.min.js, do...      1
# 39      anmmunozme  [main.css, bootstrap.min.css, jquery.min.js, b...      1
# 40          li2266                                                 []      1
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota0_phase1_all["functions"], subset_bogota0_phase1_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota0_phase1_compare_all = pd.DataFrame(result)
subset_bogota0_phase1_compare_all
# Out:
#            user1         user2  similarity
# 0      fffeelipe     mnguzmanc    0.120000
# 1      fffeelipe    jmcuestasb    0.045455
# 2      fffeelipe    katherinsb    0.045455
# 3      fffeelipe  jjrodriguezn    0.045455
# 4      fffeelipe         DglyP    0.080000
# ..           ...           ...         ...
# 856  djsanabriac        li2266    0.034483
# 857  djsanabriac           all    0.000135
# 858   anmmunozme        li2266    0.125000
# 859   anmmunozme           all    0.000034
# 860       li2266           all    0.000000
#
# [861 rows x 3 columns]

# %%
subset_bogota0_phase1_all_only = subset_bogota0_phase1_compare_all.loc[subset_bogota0_phase1_compare_all['user2'] == 'all']
subset_bogota0_phase1_all_only
# Out:
#               user1 user2  similarity
# 40        fffeelipe   all    0.000101
# 80        mnguzmanc   all    0.000024
# 119      jmcuestasb   all    0.000000
# 157      katherinsb   all    0.000000
# 194    jjrodriguezn   all    0.000000
# 230           DglyP   all    0.000019
# 265          cap182   all    0.000000
# 299     Judgarciani   all    0.000193
# 332       sacastroc   all    0.000034
# 364       pcberriop   all    0.000193
# 395     hsmartineza   all    0.000111
# 425        Moimolcp   all    0.000188
# 454     CamiloRueda   all    0.000000
# 482       juanescai   all    0.000000
# 509      JoseMolano   all    0.000014
# 535   maikellPardoA   all    0.000019
# 560      NicolasZon   all    0.000063
# 584       camilo654   all    0.000019
# 607  CristianLozano   all    0.000014
# 629       jdsuarezj   all    0.000087
# 650       pipemax85   all    0.000101
# 670     juandavidro   all    0.000612
# 689  UNhcrodriguezl   all    0.000120
# 707     camilo13152   all    0.000039
# 724    leavendanoro   all    0.000058
# 740      cdcordobaa   all    0.000087
# 755      capinillab   all    0.000034
# 769    lfvalderrama   all    0.000140
# 782       bsgarciac   all    0.000188
# 794          gabi04   all    0.000000
# 805          annipi   all    0.000000
# 815       jdsolanos   all    0.000000
# 824        jcneivaa   all    0.000000
# 832       fmbernalb   all    0.000000
# 839         MogGy94   all    0.000000
# 845       yocuervoc   all    0.000000
# 850       odprietoh   all    0.000000
# 854      janoguerab   all    0.000014
# 857     djsanabriac   all    0.000135
# 859      anmmunozme   all    0.000034
# 860          li2266   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 1 Phase 5

# %%
subset_bogota1_phase5_all = subset_bogota1_phase5.append(global_functions, ignore_index=True)
print(subset_bogota1_phase5_all)
# Out:
#            Student                                          functions  phase
# 0        gasierram  [illinois.edu, favicon.ico, bootstrap.min.css,...      5
# 1     adamantwharf  [document.getElementById, google.maps.Map, goo...      5
# 2        bdcajicam  [nearium.css, .js, nearium.js, google.maps.Map...      5
# 3   andfsanchezlem                                                 []      5
# 4      dfhincapiem  [main.js, google.maps.Map, document.getElement...      5
# 5        helmeraac  [styles.css, jquery.min.js, integration.js, sc...      5
# 6       dasalgadob  [bootstrap.min.css, theme.min.css, jquery.min....      5
# 7       falperezgo  [.ajax, data.cityofchicago.org, rows.json, .do...      5
# 8        djguzmanc  [google.maps.LatLng, google.maps.Map, document...      5
# 9       gsuarezc04  [google.maps.LatLng, google.maps.MapTypeId.ROA...      5
# 10          oeroaq  [.css, style.css, bootstrap.css, balloon.css, ...      5
# 11         gcantem                                                 []      5
# 12     Semoralesga  [style.css, bootstrap.min.css, .js, scripts.js...      5
# 13      jonatan360  [awesome.min.css, bootstrap.min.css, style.css...      5
# 14  jesusfchavarro  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      5
# 15  jesusfchavarro  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      5
# 16    stevenbustos  [style.css, jquery.min.js, distanceFunc.js, ge...      5
# 17  jufcontrerasco  [body.css, favicon.ico, js.org, .v, .min.js, p...      5
# 18      dsbarrerag  [custom.css, .css, awesome.min.css, jquery.min...      5
# 19       wolfstain  [up.net, main.css, .css, noscript.css, chicago...      5
# 20      miaborjaac  [bootstrap.min.css, modifier.css, jquery.min.j...      5
# 21   ivdgonzalezco  [favicon.ico, bootstrap.min.css, awesome.css, ...      5
# 22    maikellPardo                                                 []      5
# 23    Christian7sr  [estilos.css, icon.ico, Etxea.js, document.get...      5
# 24      jsnarvaezb  [bootstrap.min.css, jquery.min.js, style.css, ...      5
# 25   gfalbarracinr  [bootstrap.min.css, main.css, .jpg, jane.doe, ...      5
# 26        aldiazve  [bootstrap.min.css, main.css, data.cityofchica...      5
# 27  diegoaguevarar  [styles.css, blocks.css, bootstrap.min.css, th...      5
# 28      fevargasmo  [this.value, this.name, window.location.reload...      5
# 29      jmhurtadoc  [.controls, .pac, searchBox.js, bootstrap.min....      5
# 30     anfmorenoso  [bootstrap.min.css, estilos.css, script.js, fo...      5
# 31     nabautistal  [document.getElementById, google.maps.Map, goo...      5
# 32          crigar  [document.getElementById, google.maps.Map, goo...      5
# 33     jiapulidoar  [module.exports, grunt.option, grunt.initConfi...      5
# 34       jsviveroj  [.css, bootstrap.min.css, freelancer.min.css, ...      5
# 35      daandradec  [styles.css, bootstrap.min.css, jquery.min.js,...      5
# 36        jcrubioa  [bootstrap.min.css, awesome.min.css, animate.c...      5
# 37  joahernandezca  [document.getElementById, google.maps.Map, goo...      5
# 38         ItsNavi                                                 []      5
# 39         Zeugmax                                                 []      5
# 40    JairVillalba  [fH.css, jquery.min.js, .js, call.js, climate....      5
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota1_phase5_all["functions"], subset_bogota1_phase5_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota1_phase5_compare_all = pd.DataFrame(result)
subset_bogota1_phase5_compare_all
# Out:
#             user1           user2  similarity
# 0       gasierram    adamantwharf    0.064516
# 1       gasierram       bdcajicam    0.523077
# 2       gasierram  andfsanchezlem    0.016129
# 3       gasierram     dfhincapiem    0.080645
# 4       gasierram       helmeraac    0.102273
# ..            ...             ...         ...
# 856       ItsNavi    JairVillalba    0.016393
# 857       ItsNavi             all    0.000000
# 858       Zeugmax    JairVillalba    0.016393
# 859       Zeugmax             all    0.000000
# 860  JairVillalba             all    0.000289
#
# [861 rows x 3 columns]

# %%
subset_bogota1_phase5_all_only = subset_bogota1_phase5_compare_all.loc[subset_bogota1_phase5_compare_all['user2'] == 'all']
subset_bogota1_phase5_all_only
# Out:
#               user1 user2  similarity
# 40        gasierram   all    0.000294
# 80     adamantwharf   all    0.000014
# 119       bdcajicam   all    0.000173
# 157  andfsanchezlem   all    0.000000
# 194     dfhincapiem   all    0.000019
# 230       helmeraac   all    0.000164
# 265      dasalgadob   all    0.000043
# 299      falperezgo   all    0.009681
# 332       djguzmanc   all    0.000313
# 364      gsuarezc04   all    0.000198
# 395          oeroaq   all    0.012901
# 425         gcantem   all    0.000000
# 454     Semoralesga   all    0.000101
# 482      jonatan360   all    0.000704
# 509  jesusfchavarro   all    0.137067
# 535  jesusfchavarro   all    0.137067
# 560    stevenbustos   all    0.000149
# 584  jufcontrerasco   all    0.000458
# 607      dsbarrerag   all    0.000342
# 629       wolfstain   all    0.001137
# 650      miaborjaac   all    0.000593
# 670   ivdgonzalezco   all    0.001214
# 689    maikellPardo   all    0.000000
# 707    Christian7sr   all    0.000120
# 724      jsnarvaezb   all    0.000328
# 740   gfalbarracinr   all    0.000178
# 755        aldiazve   all    0.159230
# 769  diegoaguevarar   all    0.000578
# 782      fevargasmo   all    0.000275
# 794      jmhurtadoc   all    0.000723
# 805     anfmorenoso   all    0.000366
# 815     nabautistal   all    0.000246
# 824          crigar   all    0.000019
# 832     jiapulidoar   all    0.415597
# 839       jsviveroj   all    0.000308
# 845      daandradec   all    0.001378
# 850        jcrubioa   all    0.001663
# 854  joahernandezca   all    0.000602
# 857         ItsNavi   all    0.000000
# 859         Zeugmax   all    0.000000
# 860    JairVillalba   all    0.000289

# %% [markdown]
# ## Append Global Functions with Bogota 1 Phase 4

# %%
subset_bogota1_phase4_all = subset_bogota1_phase4.append(global_functions, ignore_index=True)
print(subset_bogota1_phase4_all)
# Out:
#            Student                                          functions  phase
# 0        gasierram  [illinois.edu, favicon.ico, bootstrap.min.css,...      4
# 1     adamantwharf  [document.getElementById, google.maps.Map, goo...      4
# 2        bdcajicam  [nearium.css, .js, nearium.js, google.maps.Map...      4
# 3   andfsanchezlem                                                 []      4
# 4      dfhincapiem  [main.js, google.maps.Map, document.getElement...      4
# 5        helmeraac  [styles.css, jquery.min.js, integration.js, sc...      4
# 6       dasalgadob  [bootstrap.min.css, theme.min.css, jquery.min....      4
# 7       falperezgo  [.ajax, data.cityofchicago.org, rows.json, .do...      4
# 8        djguzmanc  [google.maps.LatLng, google.maps.Map, document...      4
# 9       gsuarezc04  [google.maps.LatLng, google.maps.MapTypeId.ROA...      4
# 10          oeroaq  [.css, style.css, bootstrap.css, balloon.css, ...      4
# 11         gcantem  [window.XMLHttpRequest, Microsoft.XMLHTTP, xml...      4
# 12     Semoralesga  [style.css, bootstrap.min.css, .js, scripts.js...      4
# 13      jonatan360  [awesome.min.css, bootstrap.min.css, style.css...      4
# 14  jesusfchavarro  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      4
# 15  jesusfchavarro  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      4
# 16    stevenbustos  [style.css, jquery.min.js, distanceFunc.js, ge...      4
# 17  jufcontrerasco  [body.css, favicon.ico, js.org, .v, .min.js, p...      4
# 18      dsbarrerag  [.CSS, custom.css, .css, awesome.min.css, jque...      4
# 19       wolfstain  [up.net, main.css, .css, noscript.css, chicago...      4
# 20      miaborjaac  [bootstrap.min.css, modifier.css, jquery.min.j...      4
# 21   ivdgonzalezco  [favicon.ico, bootstrap.min.css, awesome.css, ...      4
# 22    maikellPardo                                                 []      4
# 23    Christian7sr  [estilos.css, icon.ico, Etxea.js, document.get...      4
# 24      jsnarvaezb  [bootstrap.min.css, jquery.min.js, style.css, ...      4
# 25   gfalbarracinr  [bootstrap.min.css, main.css, .jpg, jane.doe, ...      4
# 26        aldiazve  [bootstrap.min.css, main.css, bundle.js, main....      4
# 27  diegoaguevarar  [styles.css, blocks.css, bootstrap.min.css, th...      4
# 28      fevargasmo  [this.value, this.name, window.location.reload...      4
# 29      jmhurtadoc  [.controls, .pac, searchBox.js, bootstrap.min....      4
# 30     anfmorenoso  [bootstrap.min.css, estilos.css, script.js, do...      4
# 31     nabautistal  [document.getElementById, google.maps.Map, goo...      4
# 32          crigar  [document.getElementById, google.maps.Map, goo...      4
# 33     jiapulidoar  [module.exports, grunt.option, grunt.initConfi...      4
# 34       jsviveroj  [.css, bootstrap.min.css, freelancer.min.css, ...      4
# 35      daandradec  [styles.css, bootstrap.min.css, jquery.min.js,...      4
# 36        jcrubioa  [bootstrap.min.css, awesome.min.css, animate.c...      4
# 37  joahernandezca  [document.getElementById, google.maps.Map, goo...      4
# 38         ItsNavi                                                 []      4
# 39         Zeugmax                                                 []      4
# 40    JairVillalba  [fH.css, jquery.min.js, .js, call.js, climate....      4
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota1_phase4_all["functions"], subset_bogota1_phase4_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota1_phase4_compare_all = pd.DataFrame(result)
subset_bogota1_phase4_compare_all
# Out:
#             user1           user2  similarity
# 0       gasierram    adamantwharf    0.064516
# 1       gasierram       bdcajicam    0.523077
# 2       gasierram  andfsanchezlem    0.016129
# 3       gasierram     dfhincapiem    0.080645
# 4       gasierram       helmeraac    0.102273
# ..            ...             ...         ...
# 856       ItsNavi    JairVillalba    0.027027
# 857       ItsNavi             all    0.000000
# 858       Zeugmax    JairVillalba    0.027027
# 859       Zeugmax             all    0.000000
# 860  JairVillalba             all    0.000173
#
# [861 rows x 3 columns]

# %%
subset_bogota1_phase4_all_only = subset_bogota1_phase4_compare_all.loc[subset_bogota1_phase4_compare_all['user2'] == 'all']
subset_bogota1_phase4_all_only
# Out:
#               user1 user2  similarity
# 40        gasierram   all    0.000294
# 80     adamantwharf   all    0.000014
# 119       bdcajicam   all    0.000173
# 157  andfsanchezlem   all    0.000000
# 194     dfhincapiem   all    0.000019
# 230       helmeraac   all    0.000164
# 265      dasalgadob   all    0.000043
# 299      falperezgo   all    0.009653
# 332       djguzmanc   all    0.000313
# 364      gsuarezc04   all    0.000198
# 395          oeroaq   all    0.014987
# 425         gcantem   all    0.000824
# 454     Semoralesga   all    0.000082
# 482      jonatan360   all    0.000612
# 509  jesusfchavarro   all    0.031594
# 535  jesusfchavarro   all    0.031594
# 560    stevenbustos   all    0.000101
# 584  jufcontrerasco   all    0.000458
# 607      dsbarrerag   all    0.000275
# 629       wolfstain   all    0.001137
# 650      miaborjaac   all    0.000569
# 670   ivdgonzalezco   all    0.001147
# 689    maikellPardo   all    0.000000
# 707    Christian7sr   all    0.000029
# 724      jsnarvaezb   all    0.000328
# 740   gfalbarracinr   all    0.000087
# 755        aldiazve   all    0.128350
# 769  diegoaguevarar   all    0.000660
# 782      fevargasmo   all    0.000270
# 794      jmhurtadoc   all    0.000723
# 805     anfmorenoso   all    0.000173
# 815     nabautistal   all    0.000039
# 824          crigar   all    0.000019
# 832     jiapulidoar   all    0.415515
# 839       jsviveroj   all    0.000289
# 845      daandradec   all    0.001378
# 850        jcrubioa   all    0.001663
# 854  joahernandezca   all    0.000602
# 857         ItsNavi   all    0.000000
# 859         Zeugmax   all    0.000000
# 860    JairVillalba   all    0.000173

# %% [markdown]
# ## Append Global Functions with Bogota 1 Phase 3

# %%
subset_bogota1_phase3_all = subset_bogota1_phase3.append(global_functions, ignore_index=True)
print(subset_bogota1_phase3_all)
# Out:
#            Student                                          functions  phase
# 0        gasierram  [illinois.edu, favicon.ico, bootstrap.min.css,...      3
# 1     adamantwharf  [document.getElementById, google.maps.Map, goo...      3
# 2        bdcajicam  [nearium.css, .js, nearium.js, google.maps.Map...      3
# 3   andfsanchezlem                                                 []      3
# 4      dfhincapiem  [main.js, google.maps.Map, document.getElement...      3
# 5        helmeraac  [styles.css, jquery.min.js, scripts.js, integr...      3
# 6       dasalgadob  [bootstrap.min.css, theme.min.css, jquery.min....      3
# 7       falperezgo  [materialize.css, materialize.js, materialize....      3
# 8        djguzmanc  [google.maps.LatLng, google.maps.Map, document...      3
# 9       gsuarezc04  [google.maps.LatLng, google.maps.MapTypeId.ROA...      3
# 10          oeroaq  [style.css, bootstrap.css, balloon.css, jquery...      3
# 11         gcantem  [bootstrap.min.css, theme.min.css, jquery.min....      3
# 12     Semoralesga  [style.css, .js, scripts.js, .ready, .click, ....      3
# 13      jonatan360  [awesome.min.css, bootstrap.min.css, style.css...      3
# 14  jesusfchavarro  [gl.js, gl.css, .mapboxgl, mapboxgl.accessToke...      3
# 15  jesusfchavarro  [gl.js, gl.css, .mapboxgl, mapboxgl.accessToke...      3
# 16    stevenbustos  [style.css, .jpg, google.maps.LatLng, google.m...      3
# 17  jufcontrerasco  [body.css, favicon.ico, google.maps.Map, docum...      3
# 18      dsbarrerag  [.CSS, custom.css, .css, awesome.min.css, jque...      3
# 19       wolfstain  [up.net, main.css, .css, noscript.css, chicago...      3
# 20      miaborjaac  [bootstrap.min.css, modifier.css, jquery.min.j...      3
# 21   ivdgonzalezco  [favicon.ico, bootstrap.min.css, awesome.css, ...      3
# 22    maikellPardo                                                 []      3
# 23    Christian7sr  [estilos.css, icon.ico, Etxea.js, document.get...      3
# 24      jsnarvaezb  [bootstrap.min.css, jquery.min.js, style.css, ...      3
# 25   gfalbarracinr  [bootstrap.min.css, profile.css, rid.css, goog...      3
# 26        aldiazve  [bootstrap.min.css, main.css, bundle.js, MapEx...      3
# 27  diegoaguevarar  [styles.css, blocks.css, bootstrap.min.css, th...      3
# 28      fevargasmo  [this.value, this.name, document.getElementByI...      3
# 29      jmhurtadoc  [.controls, .pac, searchBox.js, bootstrap.min....      3
# 30     anfmorenoso  [estilos.css, map.PNG, unal.edu.co, bootstrap....      3
# 31     nabautistal  [document.getElementById, google.maps.Map, goo...      3
# 32          crigar  [document.getElementById, google.maps.Map, goo...      3
# 33     jiapulidoar  [module.exports, grunt.option, grunt.initConfi...      3
# 34       jsviveroj  [bootstrap.min.css, freelancer.min.css, style....      3
# 35      daandradec  [styles.css, bootstrap.min.css, jquery.min.js,...      3
# 36        jcrubioa  [bootstrap.min.css, awesome.min.css, animate.c...      3
# 37  joahernandezca  [document.getElementById, google.maps.Map, goo...      3
# 38         ItsNavi                                                 []      3
# 39         Zeugmax                                                 []      3
# 40    JairVillalba  [fH.css, call.js, jquery.min.js, .js, this.id,...      3
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota1_phase3_all["functions"], subset_bogota1_phase3_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota1_phase3_compare_all = pd.DataFrame(result)
subset_bogota1_phase3_compare_all
# Out:
#             user1           user2  similarity
# 0       gasierram    adamantwharf    0.064516
# 1       gasierram       bdcajicam    0.523077
# 2       gasierram  andfsanchezlem    0.016129
# 3       gasierram     dfhincapiem    0.080645
# 4       gasierram       helmeraac    0.083333
# ..            ...             ...         ...
# 856       ItsNavi    JairVillalba    0.029412
# 857       ItsNavi             all    0.000000
# 858       Zeugmax    JairVillalba    0.029412
# 859       Zeugmax             all    0.000000
# 860  JairVillalba             all    0.000159
#
# [861 rows x 3 columns]

# %%
subset_bogota1_phase3_all_only = subset_bogota1_phase3_compare_all.loc[subset_bogota1_phase3_compare_all['user2'] == 'all']
subset_bogota1_phase3_all_only
# Out:
#               user1 user2  similarity
# 40        gasierram   all    0.000294
# 80     adamantwharf   all    0.000014
# 119       bdcajicam   all    0.000173
# 157  andfsanchezlem   all    0.000000
# 194     dfhincapiem   all    0.000019
# 230       helmeraac   all    0.000072
# 265      dasalgadob   all    0.000043
# 299      falperezgo   all    0.009368
# 332       djguzmanc   all    0.000241
# 364      gsuarezc04   all    0.000198
# 395          oeroaq   all    0.003436
# 425         gcantem   all    0.000545
# 454     Semoralesga   all    0.010877
# 482      jonatan360   all    0.000448
# 509  jesusfchavarro   all    0.014125
# 535  jesusfchavarro   all    0.014125
# 560    stevenbustos   all    0.000029
# 584  jufcontrerasco   all    0.000063
# 607      dsbarrerag   all    0.000251
# 629       wolfstain   all    0.001075
# 650      miaborjaac   all    0.000492
# 670   ivdgonzalezco   all    0.001185
# 689    maikellPardo   all    0.000000
# 707    Christian7sr   all    0.000029
# 724      jsnarvaezb   all    0.000260
# 740   gfalbarracinr   all    0.000048
# 755        aldiazve   all    0.112394
# 769  diegoaguevarar   all    0.000660
# 782      fevargasmo   all    0.000236
# 794      jmhurtadoc   all    0.000723
# 805     anfmorenoso   all    0.000087
# 815     nabautistal   all    0.000034
# 824          crigar   all    0.000019
# 832     jiapulidoar   all    0.415515
# 839       jsviveroj   all    0.000246
# 845      daandradec   all    0.000699
# 850        jcrubioa   all    0.001663
# 854  joahernandezca   all    0.000593
# 857         ItsNavi   all    0.000000
# 859         Zeugmax   all    0.000000
# 860    JairVillalba   all    0.000159

# %% [markdown]
# ## Append Global Functions with Bogota 1 Phase 2

# %%
subset_bogota1_phase2_all = subset_bogota1_phase2.append(global_functions, ignore_index=True)
print(subset_bogota1_phase2_all)
# Out:
#            Student                                          functions  phase
# 0        gasierram  [illinois.edu, favicon.ico, bootstrap.min.css,...      2
# 1     adamantwharf  [document.getElementById, google.maps.Map, goo...      2
# 2        bdcajicam  [google.maps.Map, document.getElementById, goo...      2
# 3   andfsanchezlem                                                 []      2
# 4      dfhincapiem  [main.js, google.maps.Map, document.getElement...      2
# 5        helmeraac  [styles.css, jquery.min.js, scripts.js, integr...      2
# 6       dasalgadob  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 7       falperezgo  [materialize.css, materialize.js, materialize....      2
# 8        djguzmanc  [google.maps.LatLng, google.maps.Map, document...      2
# 9       gsuarezc04  [google.maps.LatLng, google.maps.MapTypeId.ROA...      2
# 10          oeroaq  [style.css, bootstrap.css, jquery.js, bootstra...      2
# 11         gcantem  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 12     Semoralesga  [style.css, .js, scripts.js, .ready, .click, ....      2
# 13      jonatan360  [awesome.min.css, bootstrap.min.css, style.css...      2
# 14  jesusfchavarro  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      2
# 15  jesusfchavarro  [gl.js, .min.js, cdn.jsdelivr.net, semantic.mi...      2
# 16    stevenbustos  [style.css, .jpg, google.maps.LatLng, google.m...      2
# 17  jufcontrerasco  [body.css, favicon.ico, google.maps.Map, docum...      2
# 18      dsbarrerag  [.CSS, custom.css, .css, awesome.min.css, jque...      2
# 19       wolfstain  [bootstrap.min.css, map.js, jquery.min.js, boo...      2
# 20      miaborjaac  [bootstrap.min.css, modifier.css, jquery.min.j...      2
# 21   ivdgonzalezco  [favicon.ico, bootstrap.min.css, awesome.css, ...      2
# 22    maikellPardo                                                 []      2
# 23    Christian7sr                          [estilos.css, icon.ico, ]      2
# 24      jsnarvaezb  [bootstrap.min.css, jquery.min.js, style.css, ...      2
# 25   gfalbarracinr  [bootstrap.min.css, blueberry.css, main.css, j...      2
# 26        aldiazve  [bootstrap.min.css, main.css, bundle.js, MapEx...      2
# 27  diegoaguevarar  [styles.css, blocks.css, bootstrap.min.css, th...      2
# 28      fevargasmo  [this.value, this.name, document.getElementByI...      2
# 29      jmhurtadoc  [.controls, .pac, searchBox.js, bootstrap.min....      2
# 30     anfmorenoso  [estilos.css, map.PNG, unal.edu.co, bootstrap....      2
# 31     nabautistal  [document.getElementById, google.maps.Map, goo...      2
# 32          crigar  [document.getElementById, google.maps.Map, goo...      2
# 33     jiapulidoar  [module.exports, grunt.option, grunt.initConfi...      2
# 34       jsviveroj  [bootstrap.min.css, freelancer.min.css, style....      2
# 35      daandradec  [styles.css, bootstrap.min.css, jquery.min.js,...      2
# 36        jcrubioa  [bootstrap.min.css, awesome.min.css, animate.c...      2
# 37  joahernandezca  [document.getElementById, google.maps.Map, goo...      2
# 38         ItsNavi                                                 []      2
# 39         Zeugmax                                                 []      2
# 40    JairVillalba  [fH.css, call.js, jquery.min.js, .js, this.id,...      2
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota1_phase2_all["functions"], subset_bogota1_phase2_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota1_phase2_compare_all = pd.DataFrame(result)
subset_bogota1_phase2_compare_all
# Out:
#             user1           user2  similarity
# 0       gasierram    adamantwharf    0.222222
# 1       gasierram       bdcajicam    0.222222
# 2       gasierram  andfsanchezlem    0.055556
# 3       gasierram     dfhincapiem    0.277778
# 4       gasierram       helmeraac    0.172414
# ..            ...             ...         ...
# 856       ItsNavi    JairVillalba    0.041667
# 857       ItsNavi             all    0.000000
# 858       Zeugmax    JairVillalba    0.041667
# 859       Zeugmax             all    0.000000
# 860  JairVillalba             all    0.000111
#
# [861 rows x 3 columns]

# %%
subset_bogota1_phase2_all_only = subset_bogota1_phase2_compare_all.loc[subset_bogota1_phase2_compare_all['user2'] == 'all']
subset_bogota1_phase2_all_only
# Out:
#               user1 user2  similarity
# 40        gasierram   all    0.000082
# 80     adamantwharf   all    0.000014
# 119       bdcajicam   all    0.000014
# 157  andfsanchezlem   all    0.000000
# 194     dfhincapiem   all    0.000019
# 230       helmeraac   all    0.000072
# 265      dasalgadob   all    0.000043
# 299      falperezgo   all    0.009368
# 332       djguzmanc   all    0.000217
# 364      gsuarezc04   all    0.000198
# 395          oeroaq   all    0.000728
# 425         gcantem   all    0.000545
# 454     Semoralesga   all    0.010877
# 482      jonatan360   all    0.000419
# 509  jesusfchavarro   all    0.013888
# 535  jesusfchavarro   all    0.013888
# 560    stevenbustos   all    0.000029
# 584  jufcontrerasco   all    0.000063
# 607      dsbarrerag   all    0.000164
# 629       wolfstain   all    0.000188
# 650      miaborjaac   all    0.000439
# 670   ivdgonzalezco   all    0.001185
# 689    maikellPardo   all    0.000000
# 707    Christian7sr   all    0.000010
# 724      jsnarvaezb   all    0.000255
# 740   gfalbarracinr   all    0.000043
# 755        aldiazve   all    0.112394
# 769  diegoaguevarar   all    0.000660
# 782      fevargasmo   all    0.000120
# 794      jmhurtadoc   all    0.000723
# 805     anfmorenoso   all    0.000087
# 815     nabautistal   all    0.000014
# 824          crigar   all    0.000019
# 832     jiapulidoar   all    0.415453
# 839       jsviveroj   all    0.000193
# 845      daandradec   all    0.000525
# 850        jcrubioa   all    0.001663
# 854  joahernandezca   all    0.000593
# 857         ItsNavi   all    0.000000
# 859         Zeugmax   all    0.000000
# 860    JairVillalba   all    0.000111

# %% [markdown]
# ## Append Global Functions with Bogota 1 Phase 1

# %%
subset_bogota1_phase1_all = subset_bogota1_phase1.append(global_functions, ignore_index=True)
print(subset_bogota1_phase1_all)
# Out:
#            Student                                          functions  phase
# 0        gasierram  [illinois.edu, favicon.ico, bootstrap.min.css,...      1
# 1     adamantwharf  [document.getElementById, google.maps.Map, goo...      1
# 2        bdcajicam  [google.maps.Map, document.getElementById, goo...      1
# 3   andfsanchezlem                                                 []      1
# 4      dfhincapiem                                                 []      1
# 5        helmeraac  [styles.css, scripts.js, integration.js, googl...      1
# 6       dasalgadob  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 7       falperezgo  [materialize.min.css, materialize.min.js, .min...      1
# 8        djguzmanc  [google.maps.LatLng, google.maps.Map, document...      1
# 9       gsuarezc04                                                 []      1
# 10          oeroaq  [style.css, bootstrap.min.css, jquery.js, boot...      1
# 11         gcantem  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 12     Semoralesga  [style.css, scripts.js, document.getElementByI...      1
# 13      jonatan360  [awesome.min.css, bootstrap.min.css, style.css...      1
# 14  jesusfchavarro  [gl.js, .min.js, js.org, .v, gl.css, awesome.m...      1
# 15  jesusfchavarro  [gl.js, .min.js, js.org, .v, gl.css, awesome.m...      1
# 16    stevenbustos                                                 []      1
# 17  jufcontrerasco  [body.css, google.maps.Map, document.getElemen...      1
# 18      dsbarrerag  [.CSS, .css, awesome.min.css, .mySlides, page....      1
# 19       wolfstain  [bootstrap.min.css, map.js, jquery.min.js, boo...      1
# 20      miaborjaac  [bootstrap.min.css, modifier.css, js.org, .v, ...      1
# 21   ivdgonzalezco  [favicon.ico, bootstrap.min.css, awesome.css, ...      1
# 22    maikellPardo                                                 []      1
# 23    Christian7sr                                    [estilos.css, ]      1
# 24      jsnarvaezb  [data.cityofchicago.org, iimk.geojson, xi.geoj...      1
# 25   gfalbarracinr  [blueberry.css, main.css, jquery.min.js, jquer...      1
# 26        aldiazve  [bootstrap.min.css, main.css, .js, .min.js, ma...      1
# 27  diegoaguevarar  [styles.css, blocks.css, bootstrap.min.css, th...      1
# 28      fevargasmo  [this.value, this.name, document.getElementByI...      1
# 29      jmhurtadoc  [.controls, .pac, searchBox.js, bootstrap.min....      1
# 30     anfmorenoso                                                 []      1
# 31     nabautistal  [document.getElementById, google.maps.Map, goo...      1
# 32          crigar  [document.getElementById, google.maps.Map, goo...      1
# 33     jiapulidoar  [.js, Mapa.js, Data.js, labels.text.stroke, la...      1
# 34       jsviveroj  [bootstrap.min.css, freelancer.min.css, style....      1
# 35      daandradec  [styles.css, awesome.min.css, imageManager.js,...      1
# 36        jcrubioa  [bootstrap.min.css, awesome.min.css, animate.c...      1
# 37  joahernandezca  [document.getElementById, google.maps.Map, goo...      1
# 38         ItsNavi                                                 []      1
# 39         Zeugmax                                                 []      1
# 40    JairVillalba  [fH.css, document.getElementById, google.maps....      1
# 41             all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota1_phase1_all["functions"], subset_bogota1_phase1_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota1_phase1_compare_all = pd.DataFrame(result)
subset_bogota1_phase1_compare_all
# Out:
#             user1           user2  similarity
# 0       gasierram    adamantwharf    0.222222
# 1       gasierram       bdcajicam    0.222222
# 2       gasierram  andfsanchezlem    0.055556
# 3       gasierram     dfhincapiem    0.055556
# 4       gasierram       helmeraac    0.190476
# ..            ...             ...         ...
# 856       ItsNavi    JairVillalba    0.200000
# 857       ItsNavi             all    0.000000
# 858       Zeugmax    JairVillalba    0.200000
# 859       Zeugmax             all    0.000000
# 860  JairVillalba             all    0.000019
#
# [861 rows x 3 columns]

# %%
subset_bogota1_phase1_all_only = subset_bogota1_phase1_compare_all.loc[subset_bogota1_phase1_compare_all['user2'] == 'all']
subset_bogota1_phase1_all_only
# Out:
#               user1 user2  similarity
# 40        gasierram   all    0.000082
# 80     adamantwharf   all    0.000014
# 119       bdcajicam   all    0.000014
# 157  andfsanchezlem   all    0.000000
# 194     dfhincapiem   all    0.000000
# 230       helmeraac   all    0.000029
# 265      dasalgadob   all    0.000043
# 299      falperezgo   all    0.000101
# 332       djguzmanc   all    0.000164
# 364      gsuarezc04   all    0.000000
# 395          oeroaq   all    0.000559
# 425         gcantem   all    0.000545
# 454     Semoralesga   all    0.000024
# 482      jonatan360   all    0.000328
# 509  jesusfchavarro   all    0.000212
# 535  jesusfchavarro   all    0.000212
# 560    stevenbustos   all    0.000000
# 584  jufcontrerasco   all    0.000058
# 607      dsbarrerag   all    0.000067
# 629       wolfstain   all    0.000130
# 650      miaborjaac   all    0.000308
# 670   ivdgonzalezco   all    0.001185
# 689    maikellPardo   all    0.000000
# 707    Christian7sr   all    0.000005
# 724      jsnarvaezb   all    0.000111
# 740   gfalbarracinr   all    0.000034
# 755        aldiazve   all    0.000106
# 769  diegoaguevarar   all    0.000655
# 782      fevargasmo   all    0.000043
# 794      jmhurtadoc   all    0.000723
# 805     anfmorenoso   all    0.000000
# 815     nabautistal   all    0.000014
# 824          crigar   all    0.000019
# 832     jiapulidoar   all    0.000125
# 839       jsviveroj   all    0.000053
# 845      daandradec   all    0.000193
# 850        jcrubioa   all    0.001619
# 854  joahernandezca   all    0.000014
# 857         ItsNavi   all    0.000000
# 859         Zeugmax   all    0.000000
# 860    JairVillalba   all    0.000019

# %% [markdown]
# ## Append Global Functions with Bogota 2 Phase 5

# %%
subset_bogota2_phase5_all = subset_bogota2_phase5.append(global_functions, ignore_index=True)
print(subset_bogota2_phase5_all)
# Out:
#             Student                                          functions  phase
# 0      jusherrerama  [js.org, .v, .min.js, bootstrap.min.css, portf...      5
# 1           bdvegat  [js.org, .v, .js, bootstrap.min.css, bootstrap...      5
# 2        Phoenixest  [a.active, .active, document.getElementById, g...      5
# 3          HashNick  [jquery.min.js, bootstrap.min.js, .js, js.org,...      5
# 4           ccvacad  [bootstrap.min.css, jquery.min.js, bootstrap.m...      5
# 5        joaortizro  [document.getElementById, google.maps.Map, boo...      5
# 6   juasmartinezbel  [bootstrap.min.css, jquery.min.js, .js, js.org...      5
# 7          mdbelloc  [jquery.min.js, bootstrap.min.js, tutorial.css...      5
# 8       diegocruz10  [bootstrap.min.css, awesome.min.css, theme.min...      5
# 9        crarojasca                                                 []      5
# 10           sagilm  [data.cityofchicago.org, rows.json, xmlhttp.op...      5
# 11         idrojasf  [components.css, responsee.css, owl.carousel.c...      5
# 12     raulramirezp  [up.net, main.css, bootstrap.min.css, jquery.m...      5
# 13        fabianr23  [estilos.css, functions.js, jquery.min.js, .v,...      5
# 14       jhriverasa  [style.css, bootstrap.min.css, .min.css, googl...      5
# 15       jhonsd1996  [style.css, .Chicago, document.getElementById,...      5
# 16       JuanitoAli  [bootstrap.css, .js, bootstrap.js, logic.js, u...      5
# 17       Davsatu313  [Style.css, .min.js, js.org, .v, map.js, Clima...      5
# 18   cesarochoa2006  [.getFullYear, console.log, .main, .hide, .rou...      5
# 19        jjmuesesq  [document.getElementById, google.maps.Map, goo...      5
# 20     jucjimenezmo  [home.css, search.css, favicon.jpg, .js, js.or...      5
# 21           kancas  [style.css, bootstrap.min.css, theme.min.css, ...      5
# 22          Gantiva  [latest.min.js, jquery.min.js, food.js, opcion...      5
# 23       Dandarprox  [bootstrap.js, bootstrap.css, styles.css, tabl...      5
# 24       debeltranc  [runner.github.io, module.exports, config.set,...      5
# 25        ykchautai  [tiry.cloudfront.net, foundation.min.css, styl...      5
# 26        ligibrial  [bootstrap.min.css, jquery.min.js, bootstrap.m...      5
# 27       davidrh195  [navicon.jpg, style.css, document.getElementBy...      5
# 28      JulianaNino  [bootstrap.min.css, .navbar, Respond.js, shiv....      5
# 29         luegilca  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      5
# 30           Yelis3  [map.css, google.maps.Map, document.getElement...      5
# 31        begarzonf  [reset.css, layout.css, style.css, jquery.fanc...      5
# 32       kmendezp96  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      5
# 33         leguzman  [today.getDate, today.getMonth, today.getFullY...      5
# 34     luealfonsoru  [bootstrap.min.css, balloon.min.css, freelance...      5
# 35         oserasoa  [bootstrap.min.css, theme.min.css, jquery.min....      5
# 36         lsfinite  [.css, awesome.min.css, latest.min.js, room.js...      5
# 37        xdanielsb  [console.log, jQuery.parseJSON, .ajax, .done, ...      5
# 38      CSebasGomez                                                 []      5
# 39      jhcardenasa                                                 []      5
# 40     jscontrerasp  [latest.min.js, google.maps.LatLng, google.map...      5
# 41              all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota2_phase5_all["functions"], subset_bogota2_phase5_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota2_phase5_compare_all = pd.DataFrame(result)
subset_bogota2_phase5_compare_all
# Out:
#             user1         user2  similarity
# 0    jusherrerama       bdvegat    0.003530
# 1    jusherrerama    Phoenixest    0.001767
# 2    jusherrerama      HashNick    0.006066
# 3    jusherrerama       ccvacad    0.004701
# 4    jusherrerama    joaortizro    0.003077
# ..            ...           ...         ...
# 856   CSebasGomez  jscontrerasp    0.034483
# 857   CSebasGomez           all    0.000000
# 858   jhcardenasa  jscontrerasp    0.034483
# 859   jhcardenasa           all    0.000000
# 860  jscontrerasp           all    0.000135
#
# [861 rows x 3 columns]

# %%
subset_bogota2_phase5_all_only = subset_bogota2_phase5_compare_all.loc[subset_bogota2_phase5_compare_all['user2'] == 'all']
subset_bogota2_phase5_all_only
# Out:
#                user1 user2  similarity
# 40      jusherrerama   all    0.010896
# 80           bdvegat   all    0.000053
# 119       Phoenixest   all    0.000024
# 157         HashNick   all    0.000284
# 194          ccvacad   all    0.000424
# 230       joaortizro   all    0.000092
# 265  juasmartinezbel   all    0.000978
# 299         mdbelloc   all    0.000255
# 332      diegocruz10   all    0.000193
# 364       crarojasca   all    0.000000
# 395           sagilm   all    0.000173
# 425         idrojasf   all    0.002872
# 454     raulramirezp   all    0.001412
# 482        fabianr23   all    0.000843
# 509       jhriverasa   all    0.000414
# 535       jhonsd1996   all    0.000024
# 560       JuanitoAli   all    0.011445
# 584       Davsatu313   all    0.000366
# 607   cesarochoa2006   all    0.000896
# 629        jjmuesesq   all    0.000130
# 650     jucjimenezmo   all    0.000308
# 670           kancas   all    0.000202
# 689          Gantiva   all    0.000246
# 707       Dandarprox   all    0.000839
# 724       debeltranc   all    0.000212
# 740        ykchautai   all    0.000202
# 755        ligibrial   all    0.020091
# 769       davidrh195   all    0.000096
# 782      JulianaNino   all    0.000120
# 794         luegilca   all    0.000159
# 805           Yelis3   all    0.056725
# 815        begarzonf   all    0.002082
# 824       kmendezp96   all    0.011272
# 832         leguzman   all    0.000612
# 839     luealfonsoru   all    0.000410
# 845         oserasoa   all    0.000260
# 850         lsfinite   all    0.023430
# 854        xdanielsb   all    0.002231
# 857      CSebasGomez   all    0.000000
# 859      jhcardenasa   all    0.000000
# 860     jscontrerasp   all    0.000135

# %% [markdown]
# ## Append Global Functions with Bogota 2 Phase 4

# %%
subset_bogota2_phase4_all = subset_bogota2_phase4.append(global_functions, ignore_index=True)
print(subset_bogota2_phase4_all)
# Out:
#             Student                                          functions  phase
# 0      jusherrerama  [js.org, .v, .min.js, bootstrap.min.css, portf...      4
# 1           bdvegat  [js.org, .v, .js, bootstrap.min.css, bootstrap...      4
# 2        Phoenixest  [a.active, .active, document.getElementById, g...      4
# 3          HashNick  [jquery.min.js, bootstrap.min.js, .js, js.org,...      4
# 4           ccvacad  [bootstrap.min.css, jquery.min.js, bootstrap.m...      4
# 5        joaortizro  [document.getElementById, google.maps.Map, boo...      4
# 6   juasmartinezbel  [bootstrap.min.css, jquery.min.js, .js, js.org...      4
# 7          mdbelloc  [jquery.min.js, bootstrap.min.js, tutorial.css...      4
# 8       diegocruz10  [bootstrap.min.css, awesome.min.css, theme.min...      4
# 9        crarojasca                                                 []      4
# 10           sagilm  [data.cityofchicago.org, rows.json, xmlhttp.op...      4
# 11         idrojasf  [components.css, responsee.css, owl.carousel.c...      4
# 12     raulramirezp  [up.net, main.css, bootstrap.min.css, jquery.m...      4
# 13        fabianr23  [estilos.css, functions.js, jquery.min.js, .v,...      4
# 14       jhriverasa  [style.css, bootstrap.min.css, jquery.min.js, ...      4
# 15       jhonsd1996  [style.css, .Chicago, document.getElementById,...      4
# 16       JuanitoAli  [bootstrap.css, .js, bootstrap.js, logic.js, u...      4
# 17       Davsatu313  [Style.css, .min.js, js.org, .v, map.js, Clima...      4
# 18   cesarochoa2006  [.getFullYear, console.log, .main, .hide, .rou...      4
# 19        jjmuesesq  [document.getElementById, google.maps.Map, goo...      4
# 20     jucjimenezmo  [home.css, search.css, favicon.jpg, .js, js.or...      4
# 21           kancas  [style.css, bootstrap.min.css, theme.min.css, ...      4
# 22          Gantiva  [latest.min.js, jquery.min.js, food.js, opcion...      4
# 23       Dandarprox  [bootstrap.js, bootstrap.css, styles.css, tabl...      4
# 24       debeltranc  [runner.github.io, module.exports, config.set,...      4
# 25        ykchautai  [tiry.cloudfront.net, foundation.min.css, styl...      4
# 26        ligibrial  [funciones.js, bootstrap.min.css, jquery.min.j...      4
# 27       davidrh195  [navicon.jpg, style.css, document.getElementBy...      4
# 28      JulianaNino  [bootstrap.min.css, .navbar, Respond.js, shiv....      4
# 29         luegilca  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      4
# 30           Yelis3  [semantic.min.css, calendar.min.css, styles.cs...      4
# 31        begarzonf  [reset.css, layout.css, style.css, jquery.fanc...      4
# 32       kmendezp96  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      4
# 33         leguzman  [GetDeepSearchResults.htm, .ready, console.log...      4
# 34     luealfonsoru  [bootstrap.min.css, balloon.min.css, freelance...      4
# 35         oserasoa  [bootstrap.min.css, theme.min.css, jquery.min....      4
# 36         lsfinite  [.css, awesome.min.css, latest.min.js, room.js...      4
# 37        xdanielsb  [console.log, jQuery.parseJSON, .ajax, .done, ...      4
# 38      CSebasGomez                                                 []      4
# 39      jhcardenasa                                                 []      4
# 40     jscontrerasp  [latest.min.js, google.maps.LatLng, google.map...      4
# 41              all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota2_phase4_all["functions"], subset_bogota2_phase4_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota2_phase4_compare_all = pd.DataFrame(result)
subset_bogota2_phase4_compare_all
# Out:
#             user1         user2  similarity
# 0    jusherrerama       bdvegat    0.003530
# 1    jusherrerama    Phoenixest    0.001767
# 2    jusherrerama      HashNick    0.006066
# 3    jusherrerama       ccvacad    0.004299
# 4    jusherrerama    joaortizro    0.003077
# ..            ...           ...         ...
# 856   CSebasGomez  jscontrerasp    0.034483
# 857   CSebasGomez           all    0.000000
# 858   jhcardenasa  jscontrerasp    0.034483
# 859   jhcardenasa           all    0.000000
# 860  jscontrerasp           all    0.000135
#
# [861 rows x 3 columns]

# %%
subset_bogota2_phase4_all_only = subset_bogota2_phase4_compare_all.loc[subset_bogota2_phase5_compare_all['user2'] == 'all']
subset_bogota2_phase4_all_only
# Out:
#                user1 user2  similarity
# 40      jusherrerama   all    0.010896
# 80           bdvegat   all    0.000053
# 119       Phoenixest   all    0.000024
# 157         HashNick   all    0.000284
# 194          ccvacad   all    0.000352
# 230       joaortizro   all    0.000092
# 265  juasmartinezbel   all    0.000978
# 299         mdbelloc   all    0.000255
# 332      diegocruz10   all    0.000193
# 364       crarojasca   all    0.000000
# 395           sagilm   all    0.000101
# 425         idrojasf   all    0.002872
# 454     raulramirezp   all    0.001234
# 482        fabianr23   all    0.000892
# 509       jhriverasa   all    0.000439
# 535       jhonsd1996   all    0.000024
# 560       JuanitoAli   all    0.011445
# 584       Davsatu313   all    0.000434
# 607   cesarochoa2006   all    0.000887
# 629        jjmuesesq   all    0.000067
# 650     jucjimenezmo   all    0.000284
# 670           kancas   all    0.000202
# 689          Gantiva   all    0.000246
# 707       Dandarprox   all    0.000839
# 724       debeltranc   all    0.000092
# 740        ykchautai   all    0.000101
# 755        ligibrial   all    0.010920
# 769       davidrh195   all    0.000096
# 782      JulianaNino   all    0.000120
# 794         luegilca   all    0.000159
# 805           Yelis3   all    0.178670
# 815        begarzonf   all    0.002082
# 824       kmendezp96   all    0.000453
# 832         leguzman   all    0.000482
# 839     luealfonsoru   all    0.000410
# 845         oserasoa   all    0.000222
# 850         lsfinite   all    0.023430
# 854        xdanielsb   all    0.001104
# 857      CSebasGomez   all    0.000000
# 859      jhcardenasa   all    0.000000
# 860     jscontrerasp   all    0.000135

# %% [markdown]
# ## Append Global Functions with Bogota 2 Phase 3

# %%
subset_bogota2_phase3_all = subset_bogota2_phase3.append(global_functions, ignore_index=True)
print(subset_bogota2_phase3_all)
# Out:
#             Student                                          functions  phase
# 0      jusherrerama  [js.org, .v, .min.js, bootstrap.min.css, portf...      3
# 1           bdvegat  [js.org, .v, .js, bootstrap.min.css, bootstrap...      3
# 2        Phoenixest  [a.active, .active, document.getElementById, g...      3
# 3          HashNick  [jquery.min.js, tutorial.js, bootstrap.min.js,...      3
# 4           ccvacad                                                 []      3
# 5        joaortizro  [document.getElementById, google.maps.Map, boo...      3
# 6   juasmartinezbel  [bootstrap.min.css, jquery.min.js, .js, js.org...      3
# 7          mdbelloc  [jquery.min.js, bootstrap.min.js, tutorial.css...      3
# 8       diegocruz10  [bootstrap.min.css, awesome.min.css, theme.min...      3
# 9        crarojasca                                                 []      3
# 10           sagilm  [data.cityofchicago.org, rows.json, xmlhttp.op...      3
# 11         idrojasf  [components.css, responsee.css, owl.carousel.c...      3
# 12     raulramirezp  [up.net, main.css, bootstrap.min.css, jquery.m...      3
# 13        fabianr23  [estilos.css, functions.js, jquery.min.js, .aj...      3
# 14       jhriverasa  [style.css, bootstrap.min.css, jquery.min.js, ...      3
# 15       jhonsd1996  [style.css, .Chicago, document.getElementById,...      3
# 16       JuanitoAli  [bootstrap.css, .js, bootstrap.js, google.maps...      3
# 17       Davsatu313  [Style.css, .min.js, js.org, .v, map.js, Clima...      3
# 18   cesarochoa2006  [.getFullYear, console.log, document.getElemen...      3
# 19        jjmuesesq  [document.getElementById, google.maps.Map, goo...      3
# 20     jucjimenezmo  [home.css, search.css, favicon.jpg, logo.jpg, ...      3
# 21           kancas  [style.css, bootstrap.min.css, theme.min.css, ...      3
# 22          Gantiva  [latest.min.js, jquery.min.js, food.js, rents....      3
# 23       Dandarprox  [bootstrap.js, bootstrap.css, styles.css, tabl...      3
# 24       debeltranc  [runner.github.io, module.exports, config.set,...      3
# 25        ykchautai  [tiry.cloudfront.net, foundation.min.css, styl...      3
# 26        ligibrial  [funciones.js, bootstrap.min.css, jquery.min.j...      3
# 27       davidrh195  [navicon.jpg, style.css, document.getElementBy...      3
# 28      JulianaNino  [google.maps.Map, document.getElementById, goo...      3
# 29         luegilca  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      3
# 30           Yelis3  [semantic.min.css, calendar.min.css, styles.cs...      3
# 31        begarzonf  [reset.css, layout.css, style.css, jquery.fanc...      3
# 32       kmendezp96  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      3
# 33         leguzman  [xmlhttp.open, xmlhttp.setRequestHeader, xmlht...      3
# 34     luealfonsoru  [bootstrap.min.css, freelancer.css, custom.css...      3
# 35         oserasoa  [bootstrap.min.css, theme.min.css, jquery.min....      3
# 36         lsfinite  [.css, awesome.min.css, latest.min.js, room.js...      3
# 37        xdanielsb  [console.log, jQuery.parseJSON, .ajax, .done, ...      3
# 38      CSebasGomez                                                 []      3
# 39      jhcardenasa                                                 []      3
# 40     jscontrerasp  [latest.min.js, google.maps.LatLng, google.map...      3
# 41              all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota2_phase3_all["functions"], subset_bogota2_phase3_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota2_phase3_compare_all = pd.DataFrame(result)
subset_bogota2_phase3_compare_all
# Out:
#             user1         user2  similarity
# 0    jusherrerama       bdvegat    0.003530
# 1    jusherrerama    Phoenixest    0.001767
# 2    jusherrerama      HashNick    0.004772
# 3    jusherrerama       ccvacad    0.000442
# 4    jusherrerama    joaortizro    0.003077
# ..            ...           ...         ...
# 856   CSebasGomez  jscontrerasp    0.034483
# 857   CSebasGomez           all    0.000000
# 858   jhcardenasa  jscontrerasp    0.034483
# 859   jhcardenasa           all    0.000000
# 860  jscontrerasp           all    0.000135
#
# [861 rows x 3 columns]

# %%
subset_bogota2_phase3_all_only = subset_bogota2_phase3_compare_all.loc[subset_bogota2_phase3_compare_all['user2'] == 'all']
subset_bogota2_phase3_all_only
# Out:
#                user1 user2  similarity
# 40      jusherrerama   all    0.010896
# 80           bdvegat   all    0.000053
# 119       Phoenixest   all    0.000024
# 157         HashNick   all    0.000255
# 194          ccvacad   all    0.000000
# 230       joaortizro   all    0.000092
# 265  juasmartinezbel   all    0.000679
# 299         mdbelloc   all    0.000255
# 332      diegocruz10   all    0.000193
# 364       crarojasca   all    0.000000
# 395           sagilm   all    0.000101
# 425         idrojasf   all    0.002867
# 454     raulramirezp   all    0.000737
# 482        fabianr23   all    0.000390
# 509       jhriverasa   all    0.000130
# 535       jhonsd1996   all    0.000024
# 560       JuanitoAli   all    0.011180
# 584       Davsatu313   all    0.000164
# 607   cesarochoa2006   all    0.000530
# 629        jjmuesesq   all    0.000014
# 650     jucjimenezmo   all    0.000043
# 670           kancas   all    0.000202
# 689          Gantiva   all    0.000217
# 707       Dandarprox   all    0.000371
# 724       debeltranc   all    0.000092
# 740        ykchautai   all    0.000111
# 755        ligibrial   all    0.010915
# 769       davidrh195   all    0.000082
# 782      JulianaNino   all    0.000164
# 794         luegilca   all    0.000159
# 805           Yelis3   all    0.178217
# 815        begarzonf   all    0.002082
# 824       kmendezp96   all    0.000347
# 832         leguzman   all    0.000434
# 839     luealfonsoru   all    0.000395
# 845         oserasoa   all    0.000222
# 850         lsfinite   all    0.023420
# 854        xdanielsb   all    0.000930
# 857      CSebasGomez   all    0.000000
# 859      jhcardenasa   all    0.000000
# 860     jscontrerasp   all    0.000135

# %% [markdown]
# ## Append Global Functions with Bogota 2 Phase 2

# %%
subset_bogota2_phase2_all = subset_bogota2_phase2.append(global_functions, ignore_index=True)
print(subset_bogota2_phase2_all)
# Out:
#             Student                                          functions  phase
# 0      jusherrerama  [bootstrap.min.css, portfolio.css, awesome.min...      2
# 1           bdvegat  [cs.css, document.getElementById, google.maps....      2
# 2        Phoenixest  [a.active, .active, document.getElementById, g...      2
# 3          HashNick  [jquery.min.js, tutorial.js, bootstrap.min.js,...      2
# 4           ccvacad                                                 []      2
# 5        joaortizro  [document.getElementById, google.maps.Map, boo...      2
# 6   juasmartinezbel  [bootstrap.min.css, jquery.min.js, .js, js.org...      2
# 7          mdbelloc  [jquery.min.js, bootstrap.min.js, tutorial.css...      2
# 8       diegocruz10  [bootstrap.min.css, awesome.min.css, theme.min...      2
# 9        crarojasca                                                 []      2
# 10           sagilm  [.css, buttons.css, google.maps.Map, document....      2
# 11         idrojasf  [components.css, responsee.css, owl.carousel.c...      2
# 12     raulramirezp  [up.net, main.css, bootstrap.min.css, jquery.m...      2
# 13        fabianr23  [estilos.css, functions.js, jquery.min.js, .aj...      2
# 14       jhriverasa  [style.css, jquery.min.js, .ready, .click, .aj...      2
# 15       jhonsd1996  [style.css, .Chicago, document.getElementById,...      2
# 16       JuanitoAli  [templates.asp, bootstrap.min.css, jquery.min....      2
# 17       Davsatu313  [Style.css, .min.js, js.org, .v, map.js, Clima...      2
# 18   cesarochoa2006  [google.maps.DirectionsRenderer, document.getE...      2
# 19        jjmuesesq  [document.getElementById, google.maps.Map, goo...      2
# 20     jucjimenezmo  [home.css, search.css, favicon.jpg, logo.jpg, ...      2
# 21           kancas  [style.css, bootstrap.min.css, theme.min.css, ...      2
# 22          Gantiva  [latest.min.js, jquery.min.js, clear.js, food....      2
# 23       Dandarprox  [bootstrap.js, bootstrap.css, styles.css, tabl...      2
# 24       debeltranc  [runner.github.io, module.exports, config.set,...      2
# 25        ykchautai  [tiry.cloudfront.net, foundation.min.css, styl...      2
# 26        ligibrial  [funciones.js, jquery.min.js, bootstrap.min.js...      2
# 27       davidrh195  [navicon.jpg, style.css, document.getElementBy...      2
# 28      JulianaNino  [google.maps.Map, document.getElementById, goo...      2
# 29         luegilca  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      2
# 30           Yelis3  [semantic.min.css, styles.css, .min.js, bootst...      2
# 31        begarzonf  [reset.css, layout.css, style.css, jquery.fanc...      2
# 32       kmendezp96  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      2
# 33         leguzman  [xmlhttp.open, xmlhttp.setRequestHeader, xmlht...      2
# 34     luealfonsoru  [bootstrap.min.css, freelancer.css, custom.css...      2
# 35         oserasoa  [bootstrap.min.css, theme.min.css, jquery.min....      2
# 36         lsfinite  [.css, awesome.min.css, latest.min.js, room.js...      2
# 37        xdanielsb  [.ajax, .done, console.log, .fail, data.cityof...      2
# 38      CSebasGomez                                                 []      2
# 39      jhcardenasa                                                 []      2
# 40     jscontrerasp  [google.maps.LatLng, google.maps.MapTypeId.ROA...      2
# 41              all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota2_phase2_all["functions"], subset_bogota2_phase2_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota2_phase2_compare_all = pd.DataFrame(result)
subset_bogota2_phase2_compare_all
# Out:
#             user1         user2  similarity
# 0    jusherrerama       bdvegat    0.222222
# 1    jusherrerama    Phoenixest    0.210526
# 2    jusherrerama      HashNick    0.059701
# 3    jusherrerama       ccvacad    0.058824
# 4    jusherrerama    joaortizro    0.208333
# ..            ...           ...         ...
# 856   CSebasGomez  jscontrerasp    0.043478
# 857   CSebasGomez           all    0.000000
# 858   jhcardenasa  jscontrerasp    0.043478
# 859   jhcardenasa           all    0.000000
# 860  jscontrerasp           all    0.000106
#
# [861 rows x 3 columns]

# %%
subset_bogota2_phase2_all_only = subset_bogota2_phase2_compare_all.loc[subset_bogota2_phase2_compare_all['user2'] == 'all']
subset_bogota2_phase2_all_only
# Out:
#                user1 user2  similarity
# 40      jusherrerama   all    0.000077
# 80           bdvegat   all    0.000019
# 119       Phoenixest   all    0.000024
# 157         HashNick   all    0.000255
# 194          ccvacad   all    0.000000
# 230       joaortizro   all    0.000053
# 265  juasmartinezbel   all    0.000492
# 299         mdbelloc   all    0.000255
# 332      diegocruz10   all    0.000130
# 364       crarojasca   all    0.000000
# 395           sagilm   all    0.000024
# 425         idrojasf   all    0.002867
# 454     raulramirezp   all    0.000737
# 482        fabianr23   all    0.000231
# 509       jhriverasa   all    0.000116
# 535       jhonsd1996   all    0.000024
# 560       JuanitoAli   all    0.011040
# 584       Davsatu313   all    0.000275
# 607   cesarochoa2006   all    0.000308
# 629        jjmuesesq   all    0.000014
# 650     jucjimenezmo   all    0.000043
# 670           kancas   all    0.000202
# 689          Gantiva   all    0.000178
# 707       Dandarprox   all    0.000246
# 724       debeltranc   all    0.000092
# 740        ykchautai   all    0.000072
# 755        ligibrial   all    0.010886
# 769       davidrh195   all    0.000082
# 782      JulianaNino   all    0.000120
# 794         luegilca   all    0.000159
# 805           Yelis3   all    0.173721
# 815        begarzonf   all    0.002024
# 824       kmendezp96   all    0.000323
# 832         leguzman   all    0.000289
# 839     luealfonsoru   all    0.000405
# 845         oserasoa   all    0.000169
# 850         lsfinite   all    0.023334
# 854        xdanielsb   all    0.000892
# 857      CSebasGomez   all    0.000000
# 859      jhcardenasa   all    0.000000
# 860     jscontrerasp   all    0.000106

# %% [markdown]
# ## Append Global Functions with Bogota 2 Phase 1

# %%
subset_bogota2_phase1_all = subset_bogota2_phase1.append(global_functions, ignore_index=True)
print(subset_bogota2_phase1_all)
# Out:
#             Student                                          functions  phase
# 0      jusherrerama  [bootstrap.min.css, portfolio.css, awesome.min...      1
# 1           bdvegat  [cs.css, document.getElementById, google.maps....      1
# 2        Phoenixest  [a.active, .active, document.getElementById, g...      1
# 3          HashNick  [jquery.min.js, bootstrap.min.js, .js, js.org,...      1
# 4           ccvacad                                                 []      1
# 5        joaortizro  [bootstrap.min.css, theme.min.css, bootstrap.m...      1
# 6   juasmartinezbel  [bootstrap.min.css, jquery.min.js, .js, js.org...      1
# 7          mdbelloc  [jquery.min.js, bootstrap.min.js, tutorial.css...      1
# 8       diegocruz10  [bootstrap.min.css, awesome.min.css, theme.min...      1
# 9        crarojasca                                                 []      1
# 10           sagilm  [google.maps.Map, document.getElementById, goo...      1
# 11         idrojasf  [components.css, responsee.css, owl.carousel.c...      1
# 12     raulramirezp  [google.maps.Map, document.getElementById, Scr...      1
# 13        fabianr23  [estilos.css, functions.js, google.maps.Map, d...      1
# 14       jhriverasa  [style.css, jquery.min.js, .ready, .click, .aj...      1
# 15       jhonsd1996                            [style.css, .Chicago, ]      1
# 16       JuanitoAli  [document.createElement, script.src, week.geoj...      1
# 17       Davsatu313  [Style.css, .min.js, js.org, .v, map.js, Clima...      1
# 18   cesarochoa2006  [document.getElementById, google.maps.Map, goo...      1
# 19        jjmuesesq  [document.getElementById, google.maps.Map, goo...      1
# 20     jucjimenezmo                                                 []      1
# 21           kancas  [style.css, main.js, bootstrap.min.css, theme....      1
# 22          Gantiva  [latest.min.js, jquery.min.js, rent.js, js.org...      1
# 23       Dandarprox  [bootstrap.js, bootstrap.css, styles.css, goog...      1
# 24       debeltranc  [runner.github.io, module.exports, config.set,...      1
# 25        ykchautai  [tiry.cloudfront.net, foundation.min.css, chic...      1
# 26        ligibrial  [funciones.js, jquery.min.js, bootstrap.min.js...      1
# 27       davidrh195  [navicon.jpg, style.css, document.getElementBy...      1
# 28      JulianaNino  [bootstrap.min.css, item.css, Respond.js, shiv...      1
# 29         luegilca  [bootstrap.min.css, .js, js.org, .v, .min.js, ...      1
# 30           Yelis3  [semantic.min.css, styles.css, .min.js, jquery...      1
# 31        begarzonf  [document.getElementById, google.maps.Map, goo...      1
# 32       kmendezp96  [js.org, .v, .min.js, bar.css, StyleSheet.css,...      1
# 33         leguzman  [.ready, .click, styles.css, developers.google...      1
# 34     luealfonsoru  [bootstrap.min.css, freelancer.min.css, custom...      1
# 35         oserasoa  [bootstrap.min.css, theme.min.css, jquery.min....      1
# 36         lsfinite  [.CSS, .css, this.parentElement.style.display,...      1
# 37        xdanielsb  [bootstrap.min.css, theme.min.css, aos.css, co...      1
# 38      CSebasGomez                                                 []      1
# 39      jhcardenasa                                                 []      1
# 40     jscontrerasp  [stylesheet.css, main.js, document.getElementB...      1
# 41              all  [.ready, .click, .mcheck, .on, .closest, .list...      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota2_phase1_all["functions"], subset_bogota2_phase1_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota2_phase1_compare_all = pd.DataFrame(result)
subset_bogota2_phase1_compare_all
# Out:
#             user1         user2  similarity
# 0    jusherrerama       bdvegat    0.222222
# 1    jusherrerama    Phoenixest    0.210526
# 2    jusherrerama      HashNick    0.054795
# 3    jusherrerama       ccvacad    0.058824
# 4    jusherrerama    joaortizro    0.076923
# ..            ...           ...         ...
# 856   CSebasGomez  jscontrerasp    0.166667
# 857   CSebasGomez           all    0.000000
# 858   jhcardenasa  jscontrerasp    0.166667
# 859   jhcardenasa           all    0.000000
# 860  jscontrerasp           all    0.000024
#
# [861 rows x 3 columns]

# %%
subset_bogota2_phase1_all_only = subset_bogota2_phase1_compare_all.loc[subset_bogota2_phase1_compare_all['user2'] == 'all']
subset_bogota2_phase1_all_only
# Out:
#                user1 user2  similarity
# 40      jusherrerama   all    0.000077
# 80           bdvegat   all    0.000019
# 119       Phoenixest   all    0.000024
# 157         HashNick   all    0.000284
# 194          ccvacad   all    0.000000
# 230       joaortizro   all    0.000048
# 265  juasmartinezbel   all    0.000439
# 299         mdbelloc   all    0.000255
# 332      diegocruz10   all    0.000125
# 364       crarojasca   all    0.000000
# 395           sagilm   all    0.000014
# 425         idrojasf   all    0.002867
# 454     raulramirezp   all    0.000019
# 482        fabianr23   all    0.000096
# 509       jhriverasa   all    0.000092
# 535       jhonsd1996   all    0.000010
# 560       JuanitoAli   all    0.000096
# 584       Davsatu313   all    0.000072
# 607   cesarochoa2006   all    0.000072
# 629        jjmuesesq   all    0.000014
# 650     jucjimenezmo   all    0.000000
# 670           kancas   all    0.000116
# 689          Gantiva   all    0.000072
# 707       Dandarprox   all    0.000178
# 724       debeltranc   all    0.000212
# 740        ykchautai   all    0.000034
# 755        ligibrial   all    0.000072
# 769       davidrh195   all    0.000058
# 782      JulianaNino   all    0.000053
# 794         luegilca   all    0.000159
# 805           Yelis3   all    0.169273
# 815        begarzonf   all    0.000058
# 824       kmendezp96   all    0.000323
# 832         leguzman   all    0.000096
# 839     luealfonsoru   all    0.000154
# 845         oserasoa   all    0.000101
# 850         lsfinite   all    0.000043
# 854        xdanielsb   all    0.000795
# 857      CSebasGomez   all    0.000000
# 859      jhcardenasa   all    0.000000
# 860     jscontrerasp   all    0.000024

# %% [markdown]
# ## Append Global Functions with Bogota 3 Phase 5

# %%
overall_phase5_bogota3_all = overall_phase5_bogota3.append(global_functions, ignore_index=True)

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_bogota3_all["functions"], overall_phase5_bogota3_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

overall_phase5_bogota3_compare_all = pd.DataFrame(result)
overall_phase5_bogota3_compare_all
# Out:
#                   user1               user2  similarity
# 0             lemartinp           juligarji    0.005814
# 1             lemartinp           nfmorenog    0.176471
# 2             lemartinp           AFelipeGA    0.006753
# 3             lemartinp          mballeng91    0.000181
# 4             lemartinp            dduartec    0.005952
# ..                  ...                 ...         ...
# 856          feartheGru  JhonEmmanuelTorres    1.000000
# 857          feartheGru                 all    0.000000
# 858        Danielsv9207  JhonEmmanuelTorres    1.000000
# 859        Danielsv9207                 all    0.000000
# 860  JhonEmmanuelTorres                 all    0.000000
#
# [861 rows x 3 columns]

# %%
overall_phase5_bogota3_all_only = overall_phase5_bogota3_compare_all.loc[overall_phase5_bogota3_compare_all['user2'] == 'all']
overall_phase5_bogota3_all_only
# Out:
#                   user1 user2  similarity
# 40            lemartinp   all    0.000125
# 80            juligarji   all    0.012370
# 119           nfmorenog   all    0.000251
# 157           AFelipeGA   all    0.009922
# 194          mballeng91   all    0.346348
# 230            dduartec   all    0.011267
# 265           srmedinac   all    0.000270
# 299        wilson911013   all    0.001744
# 332       wapiravaguens   all    0.000429
# 364            davidh17   all    0.000424
# 395      DianaNavarrete   all    0.000034
# 425           jdmonroyg   all    0.000067
# 454           jorge52an   all    0.001532
# 482     jscastelblancoh   all    0.000872
# 509          juclopezso   all    0.000145
# 535           afforeroc   all    0.000034
# 560         dagofonseca   all    0.001306
# 584         lacardenasv   all    0.052455
# 607         oacastillol   all    0.001523
# 629          ncampuzano   all    0.000704
# 650            adriel62   all    0.000776
# 670            capinzor   all    0.008896
# 689            ofnanezn   all    0.000280
# 707           macuestap   all    0.000082
# 724              spenas   all    0.000106
# 740         kgbayala528   all    0.000520
# 755          lgmoralesa   all    0.000371
# 769          ronaldsg20   all    0.190207
# 782       cccristanchoc   all    0.000482
# 794          jmalvarezd   all    0.000255
# 805           smarquezo   all    0.000308
# 815             sarizag   all    0.000193
# 824            Chranium   all    0.000024
# 832             DavidQP   all    0.000275
# 839         afceballosr   all    0.000202
# 845           lizzyt10h   all    0.000361
# 850          NicolasPrr   all    0.000641
# 854       jumcorredorro   all    0.000872
# 857          feartheGru   all    0.000000
# 859        Danielsv9207   all    0.000000
# 860  JhonEmmanuelTorres   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 3 Phase 4

# %%
overall_phase4_bogota3_all = overall_phase4_bogota3.append(global_functions, ignore_index=True)

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_bogota3_all["functions"], overall_phase4_bogota3_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

overall_phase4_bogota3_compare_all = pd.DataFrame(result)
overall_phase4_bogota3_compare_all
# Out:
#                   user1               user2  similarity
# 0             lemartinp           juligarji    0.005823
# 1             lemartinp           nfmorenog    0.176471
# 2             lemartinp           AFelipeGA    0.006753
# 3             lemartinp          mballeng91    0.000181
# 4             lemartinp            dduartec    0.055556
# ..                  ...                 ...         ...
# 856          feartheGru  JhonEmmanuelTorres    1.000000
# 857          feartheGru                 all    0.000000
# 858        Danielsv9207  JhonEmmanuelTorres    1.000000
# 859        Danielsv9207                 all    0.000000
# 860  JhonEmmanuelTorres                 all    0.000000
#
# [861 rows x 3 columns]

# %%
overall_phase4_bogota3_all_only = overall_phase4_bogota3_compare_all.loc[overall_phase4_bogota3_compare_all['user2'] == 'all']
overall_phase4_bogota3_all_only
# Out:
#                   user1 user2  similarity
# 40            lemartinp   all    0.000125
# 80            juligarji   all    0.012351
# 119           nfmorenog   all    0.000251
# 157           AFelipeGA   all    0.009922
# 194          mballeng91   all    0.346348
# 230            dduartec   all    0.000506
# 265           srmedinac   all    0.000270
# 299        wilson911013   all    0.001744
# 332       wapiravaguens   all    0.000405
# 364            davidh17   all    0.000429
# 395      DianaNavarrete   all    0.000034
# 425           jdmonroyg   all    0.000000
# 454           jorge52an   all    0.001369
# 482     jscastelblancoh   all    0.000853
# 509          juclopezso   all    0.000140
# 535           afforeroc   all    0.000034
# 560         dagofonseca   all    0.001238
# 584         lacardenasv   all    0.052397
# 607         oacastillol   all    0.001528
# 629          ncampuzano   all    0.000414
# 650            adriel62   all    0.024023
# 670            capinzor   all    0.008925
# 689            ofnanezn   all    0.000280
# 707           macuestap   all    0.000082
# 724              spenas   all    0.000106
# 740         kgbayala528   all    0.000520
# 755          lgmoralesa   all    0.000357
# 769          ronaldsg20   all    0.190361
# 782       cccristanchoc   all    0.000366
# 794          jmalvarezd   all    0.000260
# 805           smarquezo   all    0.000101
# 815             sarizag   all    0.000149
# 824            Chranium   all    0.000024
# 832             DavidQP   all    0.000212
# 839         afceballosr   all    0.000188
# 845           lizzyt10h   all    0.000318
# 850          NicolasPrr   all    0.003267
# 854       jumcorredorro   all    0.000800
# 857          feartheGru   all    0.000000
# 859        Danielsv9207   all    0.000000
# 860  JhonEmmanuelTorres   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 3 Phase 3

# %%
subset_bogota3_phase3_all = subset_bogota3_phase3.append(global_functions, ignore_index=True)
print(subset_bogota3_phase3_all)
# Out:
#                Student                                          functions  \
# 0            lemartinp  [google.maps.Map, document.getElementById, goo...
# 1            juligarji  [jquery.min.js, bootstrap.min.css, awesome.min...
# 2            nfmorenog  [FirstLook.css, bootstrap.min.css, jquery.min....
# 3            AFelipeGA  [materialize.min.css, style.css, awesome.min.c...
# 4           mballeng91  [.bin, e.g, protractor.config.js, exports.conf...
# 5             dduartec  [.js, style.css, superplaceholder.js, superpla...
# 6            srmedinac  [.create, package.json, pkg.title, pkg.version...
# 7         wilson911013  [module.exports, options.key, options.clientId...
# 8        wapiravaguens  [.css, .js, js.org, .v, bootstrap.min.css, the...
# 9             davidh17  [bootstrap.min.css, styles.css, theme.min.css,...
# 10      DianaNavarrete  [.l, morado.jpg, a.active, .active, google.map...
# 11           jdmonroyg                                                 []
# 12           jorge52an  [main.css, material.min.css, angular.min.js, a...
# 13     jscastelblancoh  [bootstrap.min.css, theme.min.css, style.css, ...
# 14          juclopezso  [bootstrap.min.css, portfolio.css, awesome.min...
# 15           afforeroc  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...
# 16         dagofonseca  [styles.css, jquery.min.js, map.js, markerclus...
# 17         lacardenasv  [awesome.min.css, bootstrap.min.css, materiali...
# 18         oacastillol  [bootstrap.min.css, theme.min.css, awesome.min...
# 19          ncampuzano  [bootstrap.min.css, awesome.min.css, app.css, ...
# 20            adriel62  [favicon.ico, bootstrap.min.js, .min.js, appli...
# 21            capinzor  [bootstrap.min.css, estilos.css, .min.js, boot...
# 22            ofnanezn  [.create, package.json, pkg.title, pkg.version...
# 23           macuestap  [style.css, favicon.ico, bootstrap.min.css, th...
# 24              spenas  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 25         kgbayala528  [latest.min.js, jquery.min.js, bootstrap.min.c...
# 26          lgmoralesa  [bootstrap.min.css, jquery.min.js, javascript....
# 27          ronaldsg20  [.ready, .ajax, console.log, data.results, goo...
# 28       cccristanchoc  [unal.edu.co, bootstrap.min.css, template.css,...
# 29          jmalvarezd  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 30           smarquezo  [page.php, google.maps.Map, document.getElemen...
# 31             sarizag  [js.org, .v, .min.js, style.css, jquery.min.js...
# 32            Chranium  [style.css, main.js, document.getElementById, ...
# 33             DavidQP  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 34         afceballosr  [bootstrap.min.css, style.css, farmermarket.st...
# 35           lizzyt10h  [bootstrap.min.css, jquery.min.js, index.css, ...
# 36          NicolasPrr  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 37       jumcorredorro  [jquery.min.js, bootstrap.min.js, tutorial.css...
# 38          feartheGru                                                 []
# 39        Danielsv9207                                                 []
# 40  JhonEmmanuelTorres                                                 []
# 41                 all  [.ready, .click, .mcheck, .on, .closest, .list...
#
#     phase
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
# 5       3
# 6       3
# 7       3
# 8       3
# 9       3
# 10      3
# 11      3
# 12      3
# 13      3
# 14      3
# 15      3
# 16      3
# 17      3
# 18      3
# 19      3
# 20      3
# 21      3
# 22      3
# 23      3
# 24      3
# 25      3
# 26      3
# 27      3
# 28      3
# 29      3
# 30      3
# 31      3
# 32      3
# 33      3
# 34      3
# 35      3
# 36      3
# 37      3
# 38      3
# 39      3
# 40      3
# 41      0

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota3_phase3_all["functions"], subset_bogota3_phase3_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota3_phase3_compare_all = pd.DataFrame(result)
subset_bogota3_phase3_compare_all
# Out:
#                   user1               user2  similarity
# 0             lemartinp           juligarji    0.002792
# 1             lemartinp           nfmorenog    0.169492
# 2             lemartinp           AFelipeGA    0.002899
# 3             lemartinp          mballeng91    0.000056
# 4             lemartinp            dduartec    0.060870
# ..                  ...                 ...         ...
# 856          feartheGru  JhonEmmanuelTorres    1.000000
# 857          feartheGru                 all    0.000000
# 858        Danielsv9207  JhonEmmanuelTorres    1.000000
# 859        Danielsv9207                 all    0.000000
# 860  JhonEmmanuelTorres                 all    0.000000
#
# [861 rows x 3 columns]

# %%
subset_bogota3_phase3_all_only = subset_bogota3_phase3_compare_all.loc[subset_bogota3_phase3_compare_all['user2'] == 'all']
subset_bogota3_phase3_all_only
# Out:
#                   user1 user2  similarity
# 40            lemartinp   all    0.000072
# 80            juligarji   all    0.012033
# 119           nfmorenog   all    0.000251
# 157           AFelipeGA   all    0.009922
# 194          mballeng91   all    0.346329
# 230            dduartec   all    0.000506
# 265           srmedinac   all    0.000275
# 299        wilson911013   all    0.001730
# 332       wapiravaguens   all    0.000405
# 364            davidh17   all    0.000299
# 395      DianaNavarrete   all    0.000034
# 425           jdmonroyg   all    0.000000
# 454           jorge52an   all    0.000665
# 482     jscastelblancoh   all    0.000207
# 509          juclopezso   all    0.000029
# 535           afforeroc   all    0.000034
# 560         dagofonseca   all    0.001205
# 584         lacardenasv   all    0.000231
# 607         oacastillol   all    0.000607
# 629          ncampuzano   all    0.000405
# 650            adriel62   all    0.000193
# 670            capinzor   all    0.000299
# 689            ofnanezn   all    0.000280
# 707           macuestap   all    0.000077
# 724              spenas   all    0.000106
# 740         kgbayala528   all    0.000520
# 755          lgmoralesa   all    0.000284
# 769          ronaldsg20   all    0.190106
# 782       cccristanchoc   all    0.000255
# 794          jmalvarezd   all    0.000260
# 805           smarquezo   all    0.000019
# 815             sarizag   all    0.000140
# 824            Chranium   all    0.000024
# 832             DavidQP   all    0.000193
# 839         afceballosr   all    0.000212
# 845           lizzyt10h   all    0.000082
# 850          NicolasPrr   all    0.000096
# 854       jumcorredorro   all    0.000458
# 857          feartheGru   all    0.000000
# 859        Danielsv9207   all    0.000000
# 860  JhonEmmanuelTorres   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 3 Phase 2

# %%
overall_phase2_bogota3_all = overall_phase2_bogota3.append(global_functions, ignore_index=True)

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_bogota3_all["functions"], overall_phase2_bogota3_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

overall_phase2_bogota3_compare_all = pd.DataFrame(result)
overall_phase2_bogota3_compare_all
# Out:
#                   user1               user2  similarity
# 0             lemartinp           juligarji    0.041379
# 1             lemartinp           nfmorenog    0.200000
# 2             lemartinp           AFelipeGA    0.002899
# 3             lemartinp          mballeng91    0.000056
# 4             lemartinp            dduartec    0.142857
# ..                  ...                 ...         ...
# 856          feartheGru  JhonEmmanuelTorres    1.000000
# 857          feartheGru                 all    0.000000
# 858        Danielsv9207  JhonEmmanuelTorres    1.000000
# 859        Danielsv9207                 all    0.000000
# 860  JhonEmmanuelTorres                 all    0.000000
#
# [861 rows x 3 columns]

# %%
overall_phase2_bogota3_all_only = overall_phase2_bogota3_compare_all.loc[overall_phase2_bogota3_compare_all['user2'] == 'all']
overall_phase2_bogota3_all_only
# Out:
#                   user1 user2  similarity
# 40            lemartinp   all    0.000072
# 80            juligarji   all    0.000646
# 119           nfmorenog   all    0.000207
# 157           AFelipeGA   all    0.009922
# 194          mballeng91   all    0.346329
# 230            dduartec   all    0.000188
# 265           srmedinac   all    0.000275
# 299        wilson911013   all    0.001730
# 332       wapiravaguens   all    0.000304
# 364            davidh17   all    0.000207
# 395      DianaNavarrete   all    0.000034
# 425           jdmonroyg   all    0.000000
# 454           jorge52an   all    0.000265
# 482     jscastelblancoh   all    0.000164
# 509          juclopezso   all    0.000029
# 535           afforeroc   all    0.000034
# 560         dagofonseca   all    0.000092
# 584         lacardenasv   all    0.000236
# 607         oacastillol   all    0.000545
# 629          ncampuzano   all    0.000217
# 650            adriel62   all    0.000193
# 670            capinzor   all    0.000096
# 689            ofnanezn   all    0.000333
# 707           macuestap   all    0.000077
# 724              spenas   all    0.000106
# 740         kgbayala528   all    0.000463
# 755          lgmoralesa   all    0.000207
# 769          ronaldsg20   all    0.190033
# 782       cccristanchoc   all    0.000255
# 794          jmalvarezd   all    0.000251
# 805           smarquezo   all    0.000019
# 815             sarizag   all    0.000140
# 824            Chranium   all    0.000024
# 832             DavidQP   all    0.000149
# 839         afceballosr   all    0.000193
# 845           lizzyt10h   all    0.000063
# 850          NicolasPrr   all    0.000096
# 854       jumcorredorro   all    0.000188
# 857          feartheGru   all    0.000000
# 859        Danielsv9207   all    0.000000
# 860  JhonEmmanuelTorres   all    0.000000

# %% [markdown]
# ## Append Global Functions with Bogota 3 Phase 1

# %%
subset_bogota3_phase1_all = subset_bogota3_phase1.append(global_functions, ignore_index=True)

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(subset_bogota3_phase1_all["functions"], subset_bogota3_phase1_all["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

subset_bogota3_phase1_compare_all = pd.DataFrame(result)
subset_bogota3_phase1_compare_all
# Out:
#                   user1               user2  similarity
# 0             lemartinp           juligarji    0.083333
# 1             lemartinp           nfmorenog    0.238095
# 2             lemartinp           AFelipeGA    0.025000
# 3             lemartinp          mballeng91    0.000042
# 4             lemartinp            dduartec    0.074074
# ..                  ...                 ...         ...
# 856          feartheGru  JhonEmmanuelTorres    1.000000
# 857          feartheGru                 all    0.000000
# 858        Danielsv9207  JhonEmmanuelTorres    1.000000
# 859        Danielsv9207                 all    0.000000
# 860  JhonEmmanuelTorres                 all    0.000000
#
# [861 rows x 3 columns]

# %%
subset_bogota3_phase1_all_only = subset_bogota3_phase1_compare_all.loc[subset_bogota3_phase1_compare_all['user2'] == 'all']
subset_bogota3_phase1_all_only
# Out:
#                   user1 user2  similarity
# 40            lemartinp   all    0.000039
# 80            juligarji   all    0.000077
# 119           nfmorenog   all    0.000077
# 157           AFelipeGA   all    0.000545
# 194          mballeng91   all    0.346290
# 230            dduartec   all    0.000092
# 265           srmedinac   all    0.000280
# 299        wilson911013   all    0.000000
# 332       wapiravaguens   all    0.000159
# 364            davidh17   all    0.000077
# 395      DianaNavarrete   all    0.000029
# 425           jdmonroyg   all    0.000005
# 454           jorge52an   all    0.000067
# 482     jscastelblancoh   all    0.000106
# 509          juclopezso   all    0.000145
# 535           afforeroc   all    0.000034
# 560         dagofonseca   all    0.000101
# 584         lacardenasv   all    0.000222
# 607         oacastillol   all    0.000043
# 629          ncampuzano   all    0.000058
# 650            adriel62   all    0.000048
# 670            capinzor   all    0.000096
# 689            ofnanezn   all    0.000333
# 707           macuestap   all    0.000116
# 724              spenas   all    0.000043
# 740         kgbayala528   all    0.000463
# 755          lgmoralesa   all    0.000125
# 769          ronaldsg20   all    0.190033
# 782       cccristanchoc   all    0.000164
# 794          jmalvarezd   all    0.000154
# 805           smarquezo   all    0.000010
# 815             sarizag   all    0.000087
# 824            Chranium   all    0.000024
# 832             DavidQP   all    0.000096
# 839         afceballosr   all    0.000130
# 845           lizzyt10h   all    0.000588
# 850          NicolasPrr   all    0.000096
# 854       jumcorredorro   all    0.000159
# 857          feartheGru   all    0.000000
# 859        Danielsv9207   all    0.000000
# 860  JhonEmmanuelTorres   all    0.000000

# %% [markdown]
# ## Descriptive Statistics of Comparisons with Global Functions

# %% [markdown]
# ## Bogota 3

# %%
global_bogota3_phase1_mean = subset_bogota3_phase1_all_only['similarity'].describe().loc['mean']
global_bogota3_phase1_median = subset_bogota3_phase1_all_only['similarity'].median()
global_bogota3_phase1_min = subset_bogota3_phase1_all_only['similarity'].describe().loc['min']

# %%
global_bogota3_phase2_mean = overall_phase2_bogota3_all_only['similarity'].describe().loc['mean']
global_bogota3_phase2_median = overall_phase2_bogota3_all_only['similarity'].median()
global_bogota3_phase2_min = overall_phase2_bogota3_all_only['similarity'].describe().loc['min']

# %%
global_bogota3_phase3_mean = subset_bogota3_phase3_all_only['similarity'].describe().loc['mean']
global_bogota3_phase3_median = subset_bogota3_phase3_all_only['similarity'].median()
global_bogota3_phase3_min = subset_bogota3_phase3_all_only['similarity'].describe().loc['min']

# %%
global_bogota3_phase4_mean  = overall_phase4_bogota3_all_only['similarity'].describe().loc['mean']
global_bogota3_phase4_median  = overall_phase4_bogota3_all_only['similarity'].median()
global_bogota3_phase4_min = overall_phase4_bogota3_all_only['similarity'].describe().loc['min']

# %%
global_bogota3_phase5_mean = overall_phase5_bogota3_all_only['similarity'].describe().loc['mean']
global_bogota3_phase5_median = overall_phase5_bogota3_all_only['similarity'].median()
global_bogota3_phase5_min = overall_phase5_bogota3_all_only['similarity'].describe().loc['min']

# %% [markdown]
# ## Bogota 2

# %%
global_bogota2_phase1_mean  = subset_bogota2_phase1_all_only['similarity'].describe().loc['mean']
global_bogota2_phase1_median = subset_bogota2_phase1_all_only['similarity'].median()
global_bogota2_phase1_min = subset_bogota2_phase1_all_only['similarity'].describe().loc['min']

# %%
global_bogota2_phase2_mean  = subset_bogota2_phase2_all_only['similarity'].describe().loc['mean']
global_bogota2_phase2_median = subset_bogota2_phase2_all_only['similarity'].median()
global_bogota2_phase2_min = subset_bogota2_phase2_all_only['similarity'].describe().loc['min']

# %%
global_bogota2_phase3_mean  = subset_bogota2_phase3_all_only['similarity'].describe().loc['mean']
global_bogota2_phase3_median = subset_bogota2_phase3_all_only['similarity'].median()
global_bogota2_phase3_min = subset_bogota2_phase3_all_only['similarity'].describe().loc['min']

# %%
global_bogota2_phase4_mean  = subset_bogota2_phase4_all_only['similarity'].describe().loc['mean']
global_bogota2_phase4_median = subset_bogota2_phase4_all_only['similarity'].median()
global_bogota2_phase4_min = subset_bogota2_phase4_all_only['similarity'].describe().loc['min']

# %%
global_bogota2_phase5_mean  = subset_bogota2_phase5_all_only['similarity'].describe().loc['mean']
global_bogota2_phase5_median = subset_bogota2_phase5_all_only['similarity'].median()
global_bogota2_phase5_min = subset_bogota2_phase5_all_only['similarity'].describe().loc['min']

# %% [markdown]
# ## Bogota 1

# %%
global_bogota1_phase1_mean = subset_bogota1_phase1_all_only['similarity'].describe().loc['mean']
global_bogota1_phase1_median = subset_bogota1_phase1_all_only['similarity'].median()
global_bogota1_phase1_min = subset_bogota1_phase1_all_only['similarity'].describe().loc['min']

# %%
global_bogota1_phase2_mean = subset_bogota1_phase2_all_only['similarity'].describe().loc['mean']
global_bogota1_phase2_median = subset_bogota1_phase2_all_only['similarity'].median()
global_bogota1_phase2_min = subset_bogota1_phase2_all_only['similarity'].describe().loc['min']

# %%
global_bogota1_phase3_mean = subset_bogota1_phase3_all_only['similarity'].describe().loc['mean']
global_bogota1_phase3_median = subset_bogota1_phase3_all_only['similarity'].median()
global_bogota1_phase3_min = subset_bogota1_phase3_all_only['similarity'].describe().loc['min']

# %%
global_bogota1_phase4_mean = subset_bogota1_phase4_all_only['similarity'].describe().loc['mean']
global_bogota1_phase4_median = subset_bogota1_phase4_all_only['similarity'].median()
global_bogota1_phase4_min = subset_bogota1_phase4_all_only['similarity'].describe().loc['min']

# %%
global_bogota1_phase5_mean = subset_bogota1_phase5_all_only['similarity'].describe().loc['mean']
global_bogota1_phase5_median = subset_bogota1_phase5_all_only['similarity'].median()
global_bogota1_phase5_min = subset_bogota1_phase5_all_only['similarity'].describe().loc['min']

# %% [markdown]
# ## Bogota 0

# %%
global_bogota0_phase1_mean = subset_bogota0_phase1_all_only['similarity'].describe().loc['mean']
global_bogota0_phase1_median = subset_bogota0_phase1_all_only['similarity'].median()
global_bogota0_phase1_min = subset_bogota0_phase1_all_only['similarity'].describe().loc['min']

# %%
global_bogota0_phase2_mean  = subset_bogota0_phase2_all_only['similarity'].describe().loc['mean']
global_bogota0_phase2_median = subset_bogota0_phase2_all_only['similarity'].median()
global_bogota0_phase2_min = subset_bogota0_phase2_all_only['similarity'].describe().loc['min']

# %%
global_bogota0_phase3_mean  = subset_bogota0_phase3_all_only['similarity'].describe().loc['mean']
global_bogota0_phase3_median = subset_bogota0_phase3_all_only['similarity'].median()
global_bogota0_phase3_min = subset_bogota0_phase3_all_only['similarity'].describe().loc['min']

# %%
global_bogota0_phase4_mean = subset_bogota0_phase4_all_only['similarity'].describe().loc['mean']
global_bogota0_phase4_median = subset_bogota0_phase4_all_only['similarity'].median()
global_bogota0_phase4_min = subset_bogota0_phase4_all_only['similarity'].describe().loc['min']

# %%
global_bogota0_phase5_mean  = subset_bogota0_phase5_all_only['similarity'].describe().loc['mean']
global_bogota0_phase5_median = subset_bogota0_phase5_all_only['similarity'].median()
global_bogota0_phase5_min = subset_bogota0_phase5_all_only['similarity'].describe().loc['min']

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = [global_bogota0_phase1_mean, global_bogota0_phase2_mean, global_bogota0_phase3_mean, global_bogota0_phase4_mean, global_bogota0_phase5_mean]
y2 = [global_bogota1_phase1_mean, global_bogota1_phase2_mean, global_bogota1_phase3_mean, global_bogota1_phase4_mean, global_bogota1_phase5_mean]
y3 = [global_bogota2_phase1_mean, global_bogota2_phase2_mean, global_bogota2_phase3_mean, global_bogota2_phase4_mean, global_bogota2_phase5_mean]
y4 = [global_bogota3_phase1_mean, global_bogota3_phase2_mean, global_bogota3_phase3_mean, global_bogota3_phase4_mean, global_bogota3_phase5_mean]


x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Mean Similarity in Global Functions Context")
plt.ylabel("Mean Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = [global_bogota0_phase1_median, global_bogota0_phase2_median, global_bogota0_phase3_median, global_bogota0_phase4_median, global_bogota0_phase5_median]
y2 = [global_bogota1_phase1_median, global_bogota1_phase2_median, global_bogota1_phase3_median, global_bogota1_phase4_median, global_bogota1_phase5_median]
y3 = [global_bogota2_phase1_median, global_bogota2_phase2_median, global_bogota2_phase3_median, global_bogota2_phase4_median, global_bogota2_phase5_median]
y4 = [global_bogota3_phase1_median, global_bogota3_phase2_median, global_bogota3_phase3_median, global_bogota3_phase4_median, global_bogota3_phase5_median]
print(y1)


x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median Similarity in Global Functions Context")
plt.ylabel("Median Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)
# Out:
# [1.927608656890478e-05, 0.0001108374977712025, 0.00014457064926678585, 0.00016866575747791684, 0.00021685597390017877]

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = [global_bogota0_phase1_min, global_bogota0_phase2_min, global_bogota0_phase3_min, global_bogota0_phase4_min, global_bogota0_phase5_min ]
y2 = [global_bogota1_phase1_min, global_bogota1_phase2_min, global_bogota1_phase3_min, global_bogota1_phase4_min, global_bogota1_phase5_min]
y3 = [global_bogota2_phase1_min, global_bogota2_phase2_min, global_bogota2_phase3_min, global_bogota2_phase4_min, global_bogota2_phase5_min ]
y4 = [global_bogota3_phase1_min, global_bogota3_phase2_min, global_bogota3_phase3_min, global_bogota3_phase4_min, global_bogota3_phase5_min]



x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line3 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line4 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line1 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line2 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Minimum Similarity in Global Functions Context")
plt.ylabel("Minimum Similarity Scores")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
df0_1 = subset_bogota0_phase1_all_only.rename(columns={'similarity':'b0-p1-similarity'}, inplace=False)
df0_2 = subset_bogota0_phase2_all_only.rename(columns={'similarity':'b0-p2-similarity'}, inplace=False)
df0_3 = subset_bogota0_phase3_all_only.rename(columns={'similarity':'b0-p3-similarity'}, inplace=False)
df0_4 = subset_bogota0_phase4_all_only.rename(columns={'similarity':'b0-p4-similarity'}, inplace=False)
df0_5 = subset_bogota0_phase5_all_only.rename(columns={'similarity':'b0-p5-similarity'}, inplace=False)

from functools import reduce

df0_merged_original = reduce(lambda x,y: pd.merge(x,y, on='user1', how='outer'), [df0_1, df0_2, df0_3, df0_4, df0_5])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5004/1214607353.py:9: FutureWarning: Passing 'suffixes' which cause duplicate columns {'user2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df0_merged_original = reduce(lambda x,y: pd.merge(x,y, on='user1', how='outer'), [df0_1, df0_2, df0_3, df0_4, df0_5])

# %%
subset = df0_merged_original[["b0-p1-similarity", "b0-p2-similarity", "b0-p3-similarity", "b0-p4-similarity", "b0-p5-similarity"]]
import matplotlib.pyplot as plt
import seaborn as sns

median_list_b0_o=[]
mean_list_b0_o=[]
min_list_b0_o=[]
max_list_b0_o=[]

for i, column in enumerate(subset.columns, 1):
    plt.subplot(2,3,i)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    sns.distplot(subset[column])
    median_list_b0_o.append(subset[column].describe().loc['50%'])
    mean_list_b0_o.append(subset[column].describe().loc['mean'])
    min_list_b0_o.append(subset[column].describe().loc['min'])
    max_list_b0_o.append(subset[column].describe().loc['max'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df0_merged = df0_merged_original[["b0-p1-similarity", "b0-p2-similarity", "b0-p3-similarity", "b0-p4-similarity", "b0-p5-similarity"]].apply(np.log1p)
df0_merged
# Out:
#     b0-p1-similarity  b0-p2-similarity  b0-p3-similarity  b0-p4-similarity  \
# 0           0.000101          0.000145          0.000145          0.000511
# 1           0.000024          0.000120          0.010894          0.010975
# 2           0.000000          0.033414          0.033414          0.033414
# 3           0.000000          0.000000          0.000000          0.000101
# 4           0.000000          0.000092          0.000130          0.000135
# 5           0.000019          0.000116          0.000116          0.013612
# 6           0.000000          0.000000          0.000000          0.000000
# 7           0.000193          0.000385          0.000641          0.000665
# 8           0.000034          0.000202          0.000347          0.000390
# 9           0.000193          0.000198          0.000198          0.000318
# 10          0.000111          0.000169          0.000251          0.000304
# 11          0.000188          0.000188          0.000376          0.000385
# 12          0.000000          0.000226          0.000226          0.000226
# 13          0.000000          0.000000          0.000000          0.000000
# 14          0.000014          0.000226          0.000236          0.000236
# 15          0.000019          0.000019          0.000019          0.000019
# 16          0.000063          0.000058          0.000058          0.000058
# 17          0.000019          0.000087          0.000087          0.000145
# 18          0.000014          0.000034          0.000034          0.000034
# 19          0.000087          0.000198          0.000318          0.000318
# 20          0.000101          0.000106          0.000135          0.000135
# 21          0.000612          0.000612          0.000072          0.000072
# 22          0.000120          0.000376          0.000429          0.000429
# 23          0.000039          0.000067          0.000337          0.000419
# 24          0.000058          0.000106          0.000154          0.000222
# 25          0.000087          0.000154          0.000154          0.000154
# 26          0.000034          0.000096          0.000096          0.000169
# 27          0.000140          0.000193          0.000284          0.000299
# 28          0.000188          0.000289          0.000482          0.000626
# 29          0.000000          0.000198          0.000279          0.000279
# 30          0.000000          0.000000          0.000000          0.000000
# 31          0.000000          0.000000          0.000000          0.000000
# 32          0.000000          0.000000          0.000000          0.000000
# 33          0.000000          0.000000          0.000000          0.000000
# 34          0.000000          0.000000          0.000000          0.000000
# 35          0.000000          0.000000          0.000000          0.000000
# 36          0.000000          0.000000          0.000000          0.000000
# 37          0.000014          0.000173          0.000173          0.000173
# 38          0.000135          0.000154          0.000154          0.000154
# 39          0.000034          0.000111          0.000173          0.000260
# 40          0.000000          0.000000          0.000000          0.000000
#
#     b0-p5-similarity
# 0           0.000559
# 1           0.011008
# 2           0.033414
# 3           0.010975
# 4           0.000149
# 5           0.011080
# 6           0.000000
# 7           0.001011
# 8           0.000385
# 9           0.000434
# 10          0.000318
# 11          0.000434
# 12          0.000226
# 13          0.000000
# 14          0.000236
# 15          0.000019
# 16          0.000058
# 17          0.000145
# 18          0.000034
# 19          0.000318
# 20          0.000135
# 21          0.000072
# 22          0.000429
# 23          0.000419
# 24          0.000222
# 25          0.000154
# 26          0.000217
# 27          0.000299
# 28          0.000631
# 29          0.000381
# 30          0.000000
# 31          0.000000
# 32          0.000000
# 33          0.000000
# 34          0.000000
# 35          0.000000
# 36          0.000000
# 37          0.000173
# 38          0.000154
# 39          0.011008
# 40          0.000000

# %%
subset = df0_merged[["b0-p1-similarity", "b0-p2-similarity", "b0-p3-similarity", "b0-p4-similarity", "b0-p5-similarity"]]
import matplotlib.pyplot as plt
import seaborn as sns

median_list_b0=[]
mean_list_b0=[]
min_list_b0=[]
max_list_b0=[]

for i, column in enumerate(subset.columns, 1):
    plt.subplot(2,3,i)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    sns.distplot(subset[column])
    median_list_b0.append(subset[column].describe().loc['50%'])
    mean_list_b0.append(subset[column].describe().loc['mean'])
    min_list_b0.append(subset[column].describe().loc['min'])
    max_list_b0.append(subset[column].describe().loc['max'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from functools import reduce
pd.set_option('display.max_rows', None)
b1_p1 = subset_bogota1_phase1_all_only.rename(columns = {'similarity':'b1-p1-similarity'}, inplace = False)
b1_p2 = subset_bogota1_phase2_all_only.rename(columns = {'similarity':'b1-p2-similarity'}, inplace = False)
b1_p3 = subset_bogota1_phase3_all_only.rename(columns = {'similarity':'b1-p3-similarity'}, inplace = False)
b1_p4 = subset_bogota1_phase4_all_only.rename(columns = {'similarity':'b1-p4-similarity'}, inplace = False)
b1_p5 = subset_bogota1_phase5_all_only.rename(columns = {'similarity':'b1-p5-similarity'}, inplace = False)
data_frames = [b1_p1, b1_p2, b1_p3, b1_p4, b1_p5]
df1_merged_original = reduce(lambda  left, right: pd.merge(left, right,on=['user1'], how='left'), data_frames)
df1_merged_original
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5004/698879051.py:9: FutureWarning: Passing 'suffixes' which cause duplicate columns {'user2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df1_merged_original = reduce(lambda  left, right: pd.merge(left, right,on=['user1'], how='left'), data_frames)
#              user1 user2_x  b1-p1-similarity user2_y  b1-p2-similarity  \
# 0        gasierram     all          0.000082     all          0.000082
# 1     adamantwharf     all          0.000014     all          0.000014
# 2        bdcajicam     all          0.000014     all          0.000014
# 3   andfsanchezlem     all          0.000000     all          0.000000
# 4      dfhincapiem     all          0.000000     all          0.000019
# 5        helmeraac     all          0.000029     all          0.000072
# 6       dasalgadob     all          0.000043     all          0.000043
# 7       falperezgo     all          0.000101     all          0.009368
# 8        djguzmanc     all          0.000164     all          0.000217
# 9       gsuarezc04     all          0.000000     all          0.000198
# 10          oeroaq     all          0.000559     all          0.000728
# 11         gcantem     all          0.000545     all          0.000545
# 12     Semoralesga     all          0.000024     all          0.010877
# 13      jonatan360     all          0.000328     all          0.000419
# 14  jesusfchavarro     all          0.000212     all          0.013888
# 15  jesusfchavarro     all          0.000212     all          0.013888
# 16  jesusfchavarro     all          0.000212     all          0.013888
# 17  jesusfchavarro     all          0.000212     all          0.013888
# 18  jesusfchavarro     all          0.000212     all          0.013888
# 19  jesusfchavarro     all          0.000212     all          0.013888
# 20  jesusfchavarro     all          0.000212     all          0.013888
# 21  jesusfchavarro     all          0.000212     all          0.013888
# 22  jesusfchavarro     all          0.000212     all          0.013888
# 23  jesusfchavarro     all          0.000212     all          0.013888
# 24  jesusfchavarro     all          0.000212     all          0.013888
# 25  jesusfchavarro     all          0.000212     all          0.013888
# 26  jesusfchavarro     all          0.000212     all          0.013888
# 27  jesusfchavarro     all          0.000212     all          0.013888
# 28  jesusfchavarro     all          0.000212     all          0.013888
# 29  jesusfchavarro     all          0.000212     all          0.013888
# 30  jesusfchavarro     all          0.000212     all          0.013888
# 31  jesusfchavarro     all          0.000212     all          0.013888
# 32  jesusfchavarro     all          0.000212     all          0.013888
# 33  jesusfchavarro     all          0.000212     all          0.013888
# 34  jesusfchavarro     all          0.000212     all          0.013888
# 35  jesusfchavarro     all          0.000212     all          0.013888
# 36  jesusfchavarro     all          0.000212     all          0.013888
# 37  jesusfchavarro     all          0.000212     all          0.013888
# 38  jesusfchavarro     all          0.000212     all          0.013888
# 39  jesusfchavarro     all          0.000212     all          0.013888
# 40  jesusfchavarro     all          0.000212     all          0.013888
# 41  jesusfchavarro     all          0.000212     all          0.013888
# 42  jesusfchavarro     all          0.000212     all          0.013888
# 43  jesusfchavarro     all          0.000212     all          0.013888
# 44  jesusfchavarro     all          0.000212     all          0.013888
# 45  jesusfchavarro     all          0.000212     all          0.013888
# 46    stevenbustos     all          0.000000     all          0.000029
# 47  jufcontrerasco     all          0.000058     all          0.000063
# 48      dsbarrerag     all          0.000067     all          0.000164
# 49       wolfstain     all          0.000130     all          0.000188
# 50      miaborjaac     all          0.000308     all          0.000439
# 51   ivdgonzalezco     all          0.001185     all          0.001185
# 52    maikellPardo     all          0.000000     all          0.000000
# 53    Christian7sr     all          0.000005     all          0.000010
# 54      jsnarvaezb     all          0.000111     all          0.000255
# 55   gfalbarracinr     all          0.000034     all          0.000043
# 56        aldiazve     all          0.000106     all          0.112394
# 57  diegoaguevarar     all          0.000655     all          0.000660
# 58      fevargasmo     all          0.000043     all          0.000120
# 59      jmhurtadoc     all          0.000723     all          0.000723
# 60     anfmorenoso     all          0.000000     all          0.000087
# 61     nabautistal     all          0.000014     all          0.000014
# 62          crigar     all          0.000019     all          0.000019
# 63     jiapulidoar     all          0.000125     all          0.415453
# 64       jsviveroj     all          0.000053     all          0.000193
# 65      daandradec     all          0.000193     all          0.000525
# 66        jcrubioa     all          0.001619     all          0.001663
# 67  joahernandezca     all          0.000014     all          0.000593
# 68         ItsNavi     all          0.000000     all          0.000000
# 69         Zeugmax     all          0.000000     all          0.000000
# 70    JairVillalba     all          0.000019     all          0.000111
#
#    user2_x  b1-p3-similarity user2_y  b1-p4-similarity user2  b1-p5-similarity
# 0      all          0.000294     all          0.000294   all          0.000294
# 1      all          0.000014     all          0.000014   all          0.000014
# 2      all          0.000173     all          0.000173   all          0.000173
# 3      all          0.000000     all          0.000000   all          0.000000
# 4      all          0.000019     all          0.000019   all          0.000019
# 5      all          0.000072     all          0.000164   all          0.000164
# 6      all          0.000043     all          0.000043   all          0.000043
# 7      all          0.009368     all          0.009653   all          0.009681
# 8      all          0.000241     all          0.000313   all          0.000313
# 9      all          0.000198     all          0.000198   all          0.000198
# 10     all          0.003436     all          0.014987   all          0.012901
# 11     all          0.000545     all          0.000824   all          0.000000
# 12     all          0.010877     all          0.000082   all          0.000101
# 13     all          0.000448     all          0.000612   all          0.000704
# 14     all          0.014125     all          0.031594   all          0.137067
# 15     all          0.014125     all          0.031594   all          0.137067
# 16     all          0.014125     all          0.031594   all          0.137067
# 17     all          0.014125     all          0.031594   all          0.137067
# 18     all          0.014125     all          0.031594   all          0.137067
# 19     all          0.014125     all          0.031594   all          0.137067
# 20     all          0.014125     all          0.031594   all          0.137067
# 21     all          0.014125     all          0.031594   all          0.137067
# 22     all          0.014125     all          0.031594   all          0.137067
# 23     all          0.014125     all          0.031594   all          0.137067
# 24     all          0.014125     all          0.031594   all          0.137067
# 25     all          0.014125     all          0.031594   all          0.137067
# 26     all          0.014125     all          0.031594   all          0.137067
# 27     all          0.014125     all          0.031594   all          0.137067
# 28     all          0.014125     all          0.031594   all          0.137067
# 29     all          0.014125     all          0.031594   all          0.137067
# 30     all          0.014125     all          0.031594   all          0.137067
# 31     all          0.014125     all          0.031594   all          0.137067
# 32     all          0.014125     all          0.031594   all          0.137067
# 33     all          0.014125     all          0.031594   all          0.137067
# 34     all          0.014125     all          0.031594   all          0.137067
# 35     all          0.014125     all          0.031594   all          0.137067
# 36     all          0.014125     all          0.031594   all          0.137067
# 37     all          0.014125     all          0.031594   all          0.137067
# 38     all          0.014125     all          0.031594   all          0.137067
# 39     all          0.014125     all          0.031594   all          0.137067
# 40     all          0.014125     all          0.031594   all          0.137067
# 41     all          0.014125     all          0.031594   all          0.137067
# 42     all          0.014125     all          0.031594   all          0.137067
# 43     all          0.014125     all          0.031594   all          0.137067
# 44     all          0.014125     all          0.031594   all          0.137067
# 45     all          0.014125     all          0.031594   all          0.137067
# 46     all          0.000029     all          0.000101   all          0.000149
# 47     all          0.000063     all          0.000458   all          0.000458
# 48     all          0.000251     all          0.000275   all          0.000342
# 49     all          0.001075     all          0.001137   all          0.001137
# 50     all          0.000492     all          0.000569   all          0.000593
# 51     all          0.001185     all          0.001147   all          0.001214
# 52     all          0.000000     all          0.000000   all          0.000000
# 53     all          0.000029     all          0.000029   all          0.000120
# 54     all          0.000260     all          0.000328   all          0.000328
# 55     all          0.000048     all          0.000087   all          0.000178
# 56     all          0.112394     all          0.128350   all          0.159230
# 57     all          0.000660     all          0.000660   all          0.000578
# 58     all          0.000236     all          0.000270   all          0.000275
# 59     all          0.000723     all          0.000723   all          0.000723
# 60     all          0.000087     all          0.000173   all          0.000366
# 61     all          0.000034     all          0.000039   all          0.000246
# 62     all          0.000019     all          0.000019   all          0.000019
# 63     all          0.415515     all          0.415515   all          0.415597
# 64     all          0.000246     all          0.000289   all          0.000308
# 65     all          0.000699     all          0.001378   all          0.001378
# 66     all          0.001663     all          0.001663   all          0.001663
# 67     all          0.000593     all          0.000602   all          0.000602
# 68     all          0.000000     all          0.000000   all          0.000000
# 69     all          0.000000     all          0.000000   all          0.000000
# 70     all          0.000159     all          0.000173   all          0.000289

# %%
 subset_bogota1_phase1_all_only.reset_index(drop=True)
# Out:
#              user1 user2  similarity
# 0        gasierram   all    0.000082
# 1     adamantwharf   all    0.000014
# 2        bdcajicam   all    0.000014
# 3   andfsanchezlem   all    0.000000
# 4      dfhincapiem   all    0.000000
# 5        helmeraac   all    0.000029
# 6       dasalgadob   all    0.000043
# 7       falperezgo   all    0.000101
# 8        djguzmanc   all    0.000164
# 9       gsuarezc04   all    0.000000
# 10          oeroaq   all    0.000559
# 11         gcantem   all    0.000545
# 12     Semoralesga   all    0.000024
# 13      jonatan360   all    0.000328
# 14  jesusfchavarro   all    0.000212
# 15  jesusfchavarro   all    0.000212
# 16    stevenbustos   all    0.000000
# 17  jufcontrerasco   all    0.000058
# 18      dsbarrerag   all    0.000067
# 19       wolfstain   all    0.000130
# 20      miaborjaac   all    0.000308
# 21   ivdgonzalezco   all    0.001185
# 22    maikellPardo   all    0.000000
# 23    Christian7sr   all    0.000005
# 24      jsnarvaezb   all    0.000111
# 25   gfalbarracinr   all    0.000034
# 26        aldiazve   all    0.000106
# 27  diegoaguevarar   all    0.000655
# 28      fevargasmo   all    0.000043
# 29      jmhurtadoc   all    0.000723
# 30     anfmorenoso   all    0.000000
# 31     nabautistal   all    0.000014
# 32          crigar   all    0.000019
# 33     jiapulidoar   all    0.000125
# 34       jsviveroj   all    0.000053
# 35      daandradec   all    0.000193
# 36        jcrubioa   all    0.001619
# 37  joahernandezca   all    0.000014
# 38         ItsNavi   all    0.000000
# 39         Zeugmax   all    0.000000
# 40    JairVillalba   all    0.000019

# %%
subset = df1_merged_original[["b1-p1-similarity", "b1-p2-similarity", "b1-p3-similarity", "b1-p4-similarity", "b1-p5-similarity"]]
import matplotlib.pyplot as plt
import seaborn as sns

median_list_b1_o=[]
mean_list_b1_o=[]
max_list_b1_o=[]
min_list_b1_o=[]

for i, column in enumerate(subset.columns, 1):
    plt.subplot(2,3,i)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    sns.distplot(subset[column])
    median_list_b1_o.append(subset[column].describe().loc['50%'])
    mean_list_b1_o.append(subset[column].describe().loc['mean'])
    max_list_b1_o.append(subset[column].describe().loc['max'])
    min_list_b1_o.append(subset[column].describe().loc['min'])
print(median_list_b1_o)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [0.00021203695225795259, 0.009368178072487724, 0.009368178072487724, 0.009652500349379069, 0.009681414479232426]

# %%
df1_merged = df1_merged_original[["b1-p1-similarity", "b1-p2-similarity", "b1-p3-similarity", "b1-p4-similarity", "b1-p5-similarity"]].apply(np.log1p)
df1_merged
# Out:
#     b1-p1-similarity  b1-p2-similarity  b1-p3-similarity  b1-p4-similarity  \
# 0           0.000082          0.000082          0.000294          0.000294
# 1           0.000014          0.000014          0.000014          0.000014
# 2           0.000014          0.000014          0.000173          0.000173
# 3           0.000000          0.000000          0.000000          0.000000
# 4           0.000000          0.000019          0.000019          0.000019
# ..               ...               ...               ...               ...
# 66          0.001618          0.001661          0.001661          0.001661
# 67          0.000014          0.000593          0.000593          0.000602
# 68          0.000000          0.000000          0.000000          0.000000
# 69          0.000000          0.000000          0.000000          0.000000
# 70          0.000019          0.000111          0.000159          0.000173
#
#     b1-p5-similarity
# 0           0.000294
# 1           0.000014
# 2           0.000173
# 3           0.000000
# 4           0.000019
# ..               ...
# 66          0.001661
# 67          0.000602
# 68          0.000000
# 69          0.000000
# 70          0.000289
#
# [71 rows x 5 columns]

# %%
subset = df1_merged[["b1-p1-similarity", "b1-p2-similarity", "b1-p3-similarity", "b1-p4-similarity", "b1-p5-similarity"]]
import matplotlib.pyplot as plt
import seaborn as sns

median_list_b1=[]
mean_list_b1=[]
max_list_b1=[]
min_list_b1=[]

for i, column in enumerate(subset.columns, 1):
    plt.subplot(2,3,i)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    sns.distplot(subset[column])
    median_list_b1.append(subset[column].describe().loc['50%'])
    mean_list_b1.append(subset[column].describe().loc['mean'])
    max_list_b1.append(subset[column].describe().loc['max'])
    min_list_b1.append(subset[column].describe().loc['min'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from functools import reduce
b2_p1 = subset_bogota2_phase1_all_only.rename(columns = {'similarity':'b2-p1-similarity'}, inplace = False)
b2_p2 = subset_bogota2_phase2_all_only.rename(columns = {'similarity':'b2-p2-similarity'}, inplace = False)
b2_p3 = subset_bogota2_phase3_all_only.rename(columns = {'similarity':'b2-p3-similarity'}, inplace = False)
b2_p4 = subset_bogota2_phase4_all_only.rename(columns = {'similarity':'b2-p4-similarity'}, inplace = False)
b2_p5 = subset_bogota2_phase5_all_only.rename(columns = {'similarity':'b2-p5-similarity'}, inplace = False)
data_frames = [b2_p1, b2_p2, b2_p3, b2_p4, b2_p5]
df2_merged_original = reduce(lambda  left, right: pd.merge(left, right,on=['user1'], how='outer'), data_frames)
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5004/1132933561.py:8: FutureWarning: Passing 'suffixes' which cause duplicate columns {'user2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df2_merged_original = reduce(lambda  left, right: pd.merge(left, right,on=['user1'], how='outer'), data_frames)

# %%
subset = df2_merged_original[["b2-p1-similarity", "b2-p2-similarity", "b2-p3-similarity", "b2-p4-similarity", "b2-p5-similarity"]]
import matplotlib.pyplot as plt
import seaborn as sns

median_list_b2_o=[]
mean_list_b2_o=[]
min_list_b2_o=[]
max_list_b2_o=[]

for i, column in enumerate(subset.columns, 1):
    plt.subplot(2,3,i)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    sns.distplot(subset[column])
    median_list_b2_o.append(subset[column].describe().loc['50%'])
    mean_list_b2_o.append(subset[column].describe().loc['mean'])
    min_list_b2_o.append(subset[column].describe().loc['min'])
    max_list_b2_o.append(subset[column].describe().loc['max'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df2_merged = df2_merged_original[["b2-p1-similarity", "b2-p2-similarity", "b2-p3-similarity", "b2-p4-similarity", "b2-p5-similarity"]].apply(np.log1p)
df2_merged
# Out:
#     b2-p1-similarity  b2-p2-similarity  b2-p3-similarity  b2-p4-similarity  \
# 0           0.000077          0.000077          0.010837          0.010837
# 1           0.000019          0.000019          0.000053          0.000053
# 2           0.000024          0.000024          0.000024          0.000024
# 3           0.000284          0.000255          0.000255          0.000284
# 4           0.000000          0.000000          0.000000          0.000352
# 5           0.000048          0.000053          0.000092          0.000092
# 6           0.000438          0.000491          0.000679          0.000978
# 7           0.000255          0.000255          0.000255          0.000255
# 8           0.000125          0.000130          0.000193          0.000193
# 9           0.000000          0.000000          0.000000          0.000000
# 10          0.000014          0.000024          0.000101          0.000101
# 11          0.002863          0.002863          0.002863          0.002868
# 12          0.000019          0.000737          0.000737          0.001233
# 13          0.000096          0.000231          0.000390          0.000891
# 14          0.000092          0.000116          0.000130          0.000438
# 15          0.000010          0.000024          0.000024          0.000024
# 16          0.000096          0.010980          0.011118          0.011380
# 17          0.000072          0.000275          0.000164          0.000434
# 18          0.000072          0.000308          0.000530          0.000886
# 19          0.000014          0.000014          0.000014          0.000067
# 20          0.000000          0.000043          0.000043          0.000284
# 21          0.000116          0.000202          0.000202          0.000202
# 22          0.000072          0.000178          0.000217          0.000246
# 23          0.000178          0.000246          0.000371          0.000838
# 24          0.000212          0.000092          0.000092          0.000092
# 25          0.000034          0.000072          0.000111          0.000101
# 26          0.000072          0.010827          0.010856          0.010861
# 27          0.000058          0.000082          0.000082          0.000096
# 28          0.000053          0.000120          0.000164          0.000120
# 29          0.000159          0.000159          0.000159          0.000159
# 30          0.156382          0.160179          0.164002          0.164387
# 31          0.000058          0.002022          0.002080          0.002080
# 32          0.000323          0.000323          0.000347          0.000453
# 33          0.000096          0.000289          0.000434          0.000482
# 34          0.000154          0.000405          0.000395          0.000410
# 35          0.000101          0.000169          0.000222          0.000222
# 36          0.000043          0.023066          0.023150          0.023160
# 37          0.000795          0.000891          0.000930          0.001103
# 38          0.000000          0.000000          0.000000          0.000000
# 39          0.000000          0.000000          0.000000          0.000000
# 40          0.000024          0.000106          0.000135          0.000135
#
#     b2-p5-similarity
# 0           0.010837
# 1           0.000053
# 2           0.000024
# 3           0.000284
# 4           0.000424
# 5           0.000092
# 6           0.000978
# 7           0.000255
# 8           0.000193
# 9           0.000000
# 10          0.000173
# 11          0.002868
# 12          0.001411
# 13          0.000843
# 14          0.000414
# 15          0.000024
# 16          0.011380
# 17          0.000366
# 18          0.000896
# 19          0.000130
# 20          0.000308
# 21          0.000202
# 22          0.000246
# 23          0.000838
# 24          0.000212
# 25          0.000202
# 26          0.019891
# 27          0.000096
# 28          0.000120
# 29          0.000159
# 30          0.055174
# 31          0.002080
# 32          0.011209
# 33          0.000612
# 34          0.000410
# 35          0.000260
# 36          0.023160
# 37          0.002229
# 38          0.000000
# 39          0.000000
# 40          0.000135

# %%
subset = df2_merged[["b2-p1-similarity", "b2-p2-similarity", "b2-p3-similarity", "b2-p4-similarity", "b2-p5-similarity"]]
import matplotlib.pyplot as plt
import seaborn as sns

median_list_b2=[]
mean_list_b2=[]
min_list_b2=[]
max_list_b2=[]

for i, column in enumerate(subset.columns, 1):
    plt.subplot(2,3,i)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    sns.distplot(subset[column])
    median_list_b2.append(subset[column].describe().loc['50%'])
    mean_list_b2.append(subset[column].describe().loc['mean'])
    min_list_b2.append(subset[column].describe().loc['min'])
    max_list_b2.append(subset[column].describe().loc['max'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from functools import reduce
b3_p1 = subset_bogota3_phase1_all_only.rename(columns = {'similarity':'b3-p1-similarity'}, inplace = False)
b3_p2 = overall_phase2_bogota3_all_only.rename(columns = {'similarity':'b3-p2-similarity'}, inplace = False)
b3_p3 = subset_bogota3_phase3_all_only.rename(columns = {'similarity':'b3-p3-similarity'}, inplace = False)
b3_p4 = overall_phase4_bogota3_all_only.rename(columns = {'similarity':'b3-p4-similarity'}, inplace = False)
b3_p5 = overall_phase5_bogota3_all_only.rename(columns = {'similarity':'b3-p5-similarity'}, inplace = False)
data_frames = [b3_p1, b3_p2, b3_p3, b3_p4, b3_p5]
df3_merged_original = reduce(lambda  left, right: pd.merge(left, right,on=['user1'], how='outer'), data_frames)
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5004/2153003912.py:8: FutureWarning: Passing 'suffixes' which cause duplicate columns {'user2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df3_merged_original = reduce(lambda  left, right: pd.merge(left, right,on=['user1'], how='outer'), data_frames)

# %%
subset = df3_merged_original[["b3-p1-similarity", "b3-p2-similarity", "b3-p3-similarity", "b3-p4-similarity", "b3-p5-similarity"]]
import matplotlib.pyplot as plt
import seaborn as sns

median_list_b3_o=[]
mean_list_b3_o=[]
min_list_b3_o=[]
max_list_b3_o=[]

for i, column in enumerate(subset.columns, 1):
    plt.subplot(2,3,i)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    sns.distplot(subset[column])
    median_list_b3_o.append(subset[column].describe().loc['50%'])
    mean_list_b3_o.append(subset[column].describe().loc['mean'])
    max_list_b3_o.append(subset[column].describe().loc['max'])
    min_list_b3_o.append(subset[column].describe().loc['min'])
    
print(median_list_b3_o)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [9.63804328445239e-05, 0.00018794184404682162, 0.00025058912539576214, 0.00035660760152473844, 0.00037106466645141705]

# %%
df3_merged = df3_merged_original[["b3-p1-similarity", "b3-p2-similarity", "b3-p3-similarity", "b3-p4-similarity", "b3-p5-similarity"]].apply(np.log1p)
df3_merged
# Out:
#     b3-p1-similarity  b3-p2-similarity  b3-p3-similarity  b3-p4-similarity  \
# 0           0.000039          0.000072          0.000072          0.000125
# 1           0.000077          0.000646          0.011961          0.012275
# 2           0.000077          0.000207          0.000251          0.000251
# 3           0.000544          0.009873          0.009873          0.009873
# 4           0.297353          0.297381          0.297381          0.297396
# 5           0.000092          0.000188          0.000506          0.000506
# 6           0.000279          0.000275          0.000275          0.000270
# 7           0.000000          0.001729          0.001729          0.001743
# 8           0.000159          0.000304          0.000405          0.000405
# 9           0.000077          0.000207          0.000299          0.000429
# 10          0.000029          0.000034          0.000034          0.000034
# 11          0.000005          0.000000          0.000000          0.000000
# 12          0.000067          0.000265          0.000665          0.001368
# 13          0.000106          0.000164          0.000207          0.000853
# 14          0.000145          0.000029          0.000029          0.000140
# 15          0.000034          0.000034          0.000034          0.000034
# 16          0.000101          0.000092          0.001204          0.001238
# 17          0.000222          0.000236          0.000231          0.051071
# 18          0.000043          0.000544          0.000607          0.001526
# 19          0.000058          0.000217          0.000405          0.000414
# 20          0.000048          0.000193          0.000193          0.023739
# 21          0.000096          0.000096          0.000299          0.008885
# 22          0.000332          0.000332          0.000279          0.000279
# 23          0.000116          0.000077          0.000077          0.000082
# 24          0.000043          0.000106          0.000106          0.000106
# 25          0.000463          0.000463          0.000520          0.000520
# 26          0.000125          0.000207          0.000284          0.000357
# 27          0.173981          0.173981          0.174042          0.174257
# 28          0.000164          0.000255          0.000255          0.000366
# 29          0.000154          0.000251          0.000260          0.000260
# 30          0.000010          0.000019          0.000019          0.000101
# 31          0.000087          0.000140          0.000140          0.000149
# 32          0.000024          0.000024          0.000024          0.000024
# 33          0.000096          0.000149          0.000193          0.000212
# 34          0.000130          0.000193          0.000212          0.000188
# 35          0.000588          0.000063          0.000082          0.000318
# 36          0.000096          0.000096          0.000096          0.003262
# 37          0.000159          0.000188          0.000458          0.000800
# 38          0.000000          0.000000          0.000000          0.000000
# 39          0.000000          0.000000          0.000000          0.000000
# 40          0.000000          0.000000          0.000000          0.000000
#
#     b3-p5-similarity
# 0           0.000125
# 1           0.012295
# 2           0.000251
# 3           0.009873
# 4           0.297396
# 5           0.011204
# 6           0.000270
# 7           0.001743
# 8           0.000429
# 9           0.000424
# 10          0.000034
# 11          0.000067
# 12          0.001531
# 13          0.000872
# 14          0.000145
# 15          0.000034
# 16          0.001305
# 17          0.051126
# 18          0.001522
# 19          0.000703
# 20          0.000776
# 21          0.008857
# 22          0.000279
# 23          0.000082
# 24          0.000106
# 25          0.000520
# 26          0.000371
# 27          0.174127
# 28          0.000482
# 29          0.000255
# 30          0.000308
# 31          0.000193
# 32          0.000024
# 33          0.000275
# 34          0.000202
# 35          0.000361
# 36          0.000641
# 37          0.000872
# 38          0.000000
# 39          0.000000
# 40          0.000000

# %%
subset = df3_merged[["b3-p1-similarity", "b3-p2-similarity", "b3-p3-similarity", "b3-p4-similarity", "b3-p5-similarity"]]
import matplotlib.pyplot as plt
import seaborn as sns

median_list_b3=[]
mean_list_b3=[]
min_list_b3=[]
max_list_b3=[]

for i, column in enumerate(subset.columns, 1):
    plt.subplot(2,3,i)
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    sns.distplot(subset[column])
    median_list_b3.append(subset[column].describe().loc['50%'])
    mean_list_b3.append(subset[column].describe().loc['mean'])
    max_list_b3.append(subset[column].describe().loc['max'])
    min_list_b3.append(subset[column].describe().loc['min'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1_o = median_list_b0_o
y2_o = median_list_b1_o
print(y1_o)
print(y2_o)
y3_o = median_list_b2_o
print(y3_o)
y4_o = median_list_b3_o
print(y4)

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1_o,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2_o,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3_o,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4_o,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Raw Median Similarity in Global Functions Context")
plt.ylabel("Raw Median Similarity in Global Functions Context")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)
# Out:
# [1.927608656890478e-05, 0.0001108374977712025, 0.00014457064926678585, 0.00016866575747791684, 0.00021685597390017877]
# [0.00021203695225795259, 0.009368178072487724, 0.009368178072487724, 0.009652500349379069, 0.009681414479232426]
# [7.228532463339292e-05, 0.00016866575747791684, 0.0002023989089735002, 0.0002843222768913455, 0.0002843222768913455]
# [9.63804328445239e-05, 0.00018794184404682162, 0.00025058912539576214, 0.00035660760152473844, 0.00037106466645141705]

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = median_list_b0
y2 = median_list_b1
y3 = median_list_b2
y4 = median_list_b3


x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Median Similarity in Global Functions Context")
plt.ylabel("Log-Transform Median Similarity in Global Functions Context")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = mean_list_b0
y2 = mean_list_b1
y3 = mean_list_b2
y4 = mean_list_b3


x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Mean Similarity in Global Functions Context")
plt.ylabel("Log-Transform Mean Similarity in Global Functions Context")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = mean_list_b0_o
y2 = mean_list_b1_o
y3 = mean_list_b2_o
y4 = mean_list_b3_o


x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Raw Mean Similarity in Global Functions Context")
plt.ylabel("Raw Mean Similarity in Global Functions Context")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = min_list_b0
y2 = min_list_b1
y3 = min_list_b2
y4 = min_list_b3


x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Min Similarity in Global Functions Context")
plt.ylabel("Log-Transform Min Similarity in Global Functions Context")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = max_list_b0
y2 = max_list_b1
y3 = max_list_b2
y4 = max_list_b3


x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Max Similarity in Global Functions Context")
plt.ylabel("Log-Transform Max Similarity in Global Functions Context")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
# %store overall_phase1
# %store overall_phase2
# %store overall_phase3
# %store overall_phase4
# %store overall_phase5
# %store df_all
# %store subset_bogota0_phase1
# %store subset_bogota0_phase2
# %store subset_bogota0_phase3
# %store subset_bogota0_phase4
# %store subset_bogota0_phase5
# %store subset_bogota1_phase1
# %store subset_bogota1_phase2
# %store subset_bogota1_phase3
# %store subset_bogota1_phase4
# %store subset_bogota1_phase5
# %store subset_bogota2_phase1
# %store subset_bogota2_phase2
# %store subset_bogota2_phase3
# %store subset_bogota2_phase4
# %store subset_bogota2_phase5
# %store subset_bogota3_phase1
# %store overall_phase2_bogota3
# %store overall_phase3_bogota3
# %store overall_phase4_bogota3
# %store overall_phase5_bogota3
# Out:
# Stored 'overall_phase1' (DataFrame)
# Stored 'overall_phase2' (DataFrame)
# Stored 'overall_phase3' (DataFrame)
# Stored 'overall_phase4' (DataFrame)
# Stored 'overall_phase5' (DataFrame)
# UsageError: Unknown variable 'df_all'

# %%
import pandas as pd
 
# Initialize data to Dicts of series.
d = {'one': pd.Series([10, 20, 30, 40],
                      index=['a', 'b', 'c', 'd']),
     'two': pd.Series([10, 20, 30, 40],
                      index=['a', 'b', 'c', 'd'])}
 
# creates Dataframe.
df = pd.DataFrame(d)

d1 = {'one': pd.Series([10, 20, 30, 40],
                      index=['a', 'b', 'c', 'd']),
     'two': pd.Series([10, 20, 30, 40],
                      index=['a', 'b', 'c', 'd'])}
 
# creates Dataframe.
df1 = pd.DataFrame(d1)

d2 = {'one': pd.Series([1, 2, 3, 4],
                      index=['a', 'b', 'c', 'd']),
     'two': pd.Series([10, 20, 30, 40],
                      index=['a', 'b', 'c', 'd'])}
 
# creates Dataframe.
df2 = pd.DataFrame(d2)

# %%
l = [df,df1,df2]

DF = pd.concat(l,keys=range(len(l))).groupby(level=1)

DF
