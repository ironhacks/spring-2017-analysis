# %%
# restore variables from Data-Frame-Spring-2017(Scores,LOC,Survey,D3).ipynb

# %store -r bogota0
# %store -r bogota1
# %store -r bogota2
# %store -r bogota3

# restore variables from Functional-Basic-Preprocessing.ipynb

# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5

# load the libraries

import pandas as pd
import numpy as np

# %% [markdown]
# ## Performance Distance from the Best

# %%
# append all dataframes from all groups

bogota0['group'] = 0
bogota1['group'] = 1
bogota2['group'] = 2
bogota3['group'] = 3

bogota01 = bogota0.append(bogota1, ignore_index=True)
bogota12 = bogota01.append(bogota2, ignore_index=True)
bogota_final = bogota12.append(bogota3, ignore_index=True)
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1559/169917622.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bogota01 = bogota0.append(bogota1, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1559/169917622.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bogota12 = bogota01.append(bogota2, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1559/169917622.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bogota_final = bogota12.append(bogota3, ignore_index=True)

# %%
# get max total score for each group

bogota_final['total-max-phase1'] = bogota_final.groupby(["group"])['total-phase1'].transform(np.max)
bogota_final['total-max-phase2'] = bogota_final.groupby(["group"])['total-phase2'].transform(np.max)
bogota_final['total-max-phase3'] = bogota_final.groupby(["group"])['total-phase3'].transform(np.max)
bogota_final['total-max-phase4'] = bogota_final.groupby(["group"])['total-phase4'].transform(np.max)
bogota_final['total-max-phase5'] = bogota_final.groupby(["group"])['total-phase5'].transform(np.max)

# %%
# create new column for max performance distance in the dataframe

bogota_final['perform_diff_best_phase2'] = bogota_final['total-phase2'] - bogota_final['total-max-phase1']
bogota_final['perform_diff_best_phase3'] = bogota_final['total-phase3'] - bogota_final['total-max-phase2']
bogota_final['perform_diff_best_phase4'] = bogota_final['total-phase4'] - bogota_final['total-max-phase3']
bogota_final['perform_diff_best_phase5'] = bogota_final['total-phase5'] - bogota_final['total-max-phase4']

# %%
# see how the overall dataframe looks like

bogota_final
# Out:
#      Unnamed: 0             Student  Group  user-requirement-phase5  \
# 0             0           fffeelipe      0                       20
# 1             1           mnguzmanc      0                       60
# 2             2          jmcuestasb      0                      100
# 3             3          katherinsb      0                       20
# 4             4        jjrodriguezn      0                       60
# ..          ...                 ...    ...                      ...
# 158          36          NicolasPrr      3                      100
# 159          37       jumcorredorro      3                      100
# 160          38          feartheGru      3                        0
# 161          39        Danielsv9207      3                        0
# 162          40  JhonEmmanuelTorres      3                        0
#
#      infovis-phase5  novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %% [markdown]
# ## Similarity from the Best

# %%
maxima0 = bogota_final.groupby('Group')['total-phase1'].max().iloc[0]

# %%
# Restructure Functions Dataframe

overall_phase1.rename({'functions': 'functions-phase1', 'unique': 'unique-phase1', 'len_unique': 'len_unique_phase1'}, axis=1, inplace=True)
overall_phase2.rename({'functions': 'functions-phase2', 'unique': 'unique-phase2', 'len_unique': 'len_unique_phase2'}, axis=1, inplace=True)
overall_phase3.rename({'functions': 'functions-phase3', 'unique': 'unique-phase3', 'len_unique': 'len_unique_phase3'}, axis=1, inplace=True)
overall_phase4.rename({'functions': 'functions-phase4', 'unique': 'unique-phase4', 'len_unique': 'len_unique_phase4'}, axis=1, inplace=True)
overall_phase5.rename({'functions': 'functions-phase5', 'unique': 'unique-phase5', 'len_unique': 'len_unique_phase5'}, axis=1, inplace=True)

# %%
df = pd.merge(overall_phase1[['Student','functions-phase1','unique-phase1', 'len_unique_phase1']], bogota_final, on='Student', how='left')
string0 = df['functions-phase1'].loc[df['total-phase1'] == maxima0].iloc[0]
list(string0.split(","))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 3>()
#       1 df = pd.merge(overall_phase1[['Student','functions-phase1','unique-phase1', 'len_unique_phase1']], bogota_final, on='Student', how='left')
#       2 string0 = df['functions-phase1'].loc[df['total-phase1'] == maxima0].iloc[0]
# ----> 3 list(string0.split(","))
#
# AttributeError: 'list' object has no attribute 'split'

# %%
# Get row for bogota 0 for every phase and append them together
# we will need to have separate dataframes for each group since we can't compare similarity intergroups

group0_phase1 = overall_phase1[overall_phase1['Group'] == 0]
group0_phase2 = overall_phase2[overall_phase2['Group'] == 0]
group0_phase3 = overall_phase3[overall_phase3['Group'] == 0]
group0_phase4 = overall_phase4[overall_phase4['Group'] == 0]
group0_phase5 = overall_phase5[overall_phase5['Group'] == 0]

group0_12 = group0_phase1.append(group0_phase2, ignore_index=True)
group0_23 = group0_12.append(group0_phase3, ignore_index=True)
group0_34 = group0_23.append(group0_phase4, ignore_index=True)
group0_final = group0_34.append(group0_phase5, ignore_index=True)

# %%
group0_final

# %%
# Get row for bogota 1 for every phase and append them together
# we will need to have separate dataframes for each group since we can't compare similarity intergroups

group1_phase1 = overall_phase1[overall_phase1['Group'] == 1]
group1_phase2 = overall_phase2[overall_phase2['Group'] == 1]
group1_phase3 = overall_phase3[overall_phase3['Group'] == 1]
group1_phase4 = overall_phase4[overall_phase4['Group'] == 1]
group1_phase5 = overall_phase5[overall_phase5['Group'] == 1]

group1_12 = group0_phase1.append(group0_phase2, ignore_index=True)
group1_23 = group0_12.append(group0_phase3, ignore_index=True)
group1_34 = group0_23.append(group0_phase4, ignore_index=True)
group1_final = group0_34.append(group0_phase5, ignore_index=True)
