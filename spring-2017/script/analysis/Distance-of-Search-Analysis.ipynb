# %% [markdown]
# # Metrics for Functional Similarity

# %% [markdown]
# ## In this notebook, we are constructing the distance of search, which is the cross-stage similarity on an individual level.

# %%
# retrive variables stored in other Jupyter notebooks

# %store -r overall_loc_scores_final
# %store -r overall_loc_scores

# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5

# %store -r overall_phase1_bogota0
# %store -r overall_phase1_bogota1
# %store -r overall_phase1_bogota2
# %store -r overall_phase1_bogota3

# %store -r overall_phase2_bogota0
# %store -r overall_phase2_bogota1
# %store -r overall_phase2_bogota2
# %store -r overall_phase2_bogota3

# %store -r overall_phase3_bogota0
# %store -r overall_phase3_bogota1
# %store -r overall_phase3_bogota2
# %store -r overall_phase3_bogota3

# %store -r overall_phase4_bogota0
# %store -r overall_phase4_bogota1
# %store -r overall_phase4_bogota2
# %store -r overall_phase4_bogota3

# %store -r overall_phase5_bogota0
# %store -r overall_phase5_bogota1
# %store -r overall_phase5_bogota2
# %store -r overall_phase5_bogota3

# %%
import itertools
import pandas as pd

overall_phase2_bogota3 = overall_phase2_bogota3[overall_phase2_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_bogota3["functions"], overall_phase2_bogota3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#            user1          user2  similarity
# 0      lemartinp      juligarji    0.659574
# 1      lemartinp      nfmorenog    0.617021
# 2      lemartinp      AFelipeGA    0.574074
# 3      lemartinp     mballeng91    0.574074
# 4      lemartinp       dduartec    0.659091
# ..           ...            ...         ...
# 661  afceballosr     NicolasPrr    0.804878
# 662  afceballosr  jumcorredorro    0.904762
# 663    lizzyt10h     NicolasPrr    0.764706
# 664    lizzyt10h  jumcorredorro    0.692308
# 665   NicolasPrr  jumcorredorro    0.800000
#
# [666 rows x 3 columns]

# %%
import itertools
import pandas as pd

overall_phase4_bogota3 = overall_phase4_bogota3[overall_phase4_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_bogota3["functions"], overall_phase4_bogota3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#            user1          user2  similarity
# 0      lemartinp      juligarji    0.685185
# 1      lemartinp      nfmorenog    0.744681
# 2      lemartinp      AFelipeGA    0.685185
# 3      lemartinp     mballeng91    0.685185
# 4      lemartinp       dduartec    0.729167
# ..           ...            ...         ...
# 661  afceballosr     NicolasPrr    0.796296
# 662  afceballosr  jumcorredorro    0.895833
# 663    lizzyt10h     NicolasPrr    0.870370
# 664    lizzyt10h  jumcorredorro    0.900000
# 665   NicolasPrr  jumcorredorro    0.888889
#
# [666 rows x 3 columns]

# %%
import itertools
import pandas as pd

overall_phase5_bogota3 = overall_phase5_bogota3[overall_phase5_bogota3.functions != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_bogota3["functions"], overall_phase5_bogota3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#            user1          user2  similarity
# 0      lemartinp      juligarji    0.685185
# 1      lemartinp      nfmorenog    0.744681
# 2      lemartinp      AFelipeGA    0.685185
# 3      lemartinp     mballeng91    0.685185
# 4      lemartinp       dduartec    0.685185
# ..           ...            ...         ...
# 698  afceballosr     NicolasPrr    0.843137
# 699  afceballosr  jumcorredorro    0.877551
# 700    lizzyt10h     NicolasPrr    0.921569
# 701    lizzyt10h  jumcorredorro    0.882353
# 702   NicolasPrr  jumcorredorro    0.960784
#
# [703 rows x 3 columns]

# %% [markdown]
# ## Subset Bogota 0 Phase 5

# %%
import numpy as np
overall_phase5_bogota0['phase'] = 5
overall_phase5_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase5_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase5 = overall_phase5_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase5
# Out:
#             Student                                          functions  phase
# 0         fffeelipe  .ready,.click,.css,.removeClass,.is,.val,.chec...      5
# 1         mnguzmanc  house.ico,style.css,.css,main.js,map.js,weathe...      5
# 2        jmcuestasb  js.org,.v,.min.js,weather.js,myss.css,bootstra...      5
# 3        katherinsb  reset.css,layout.css,style.css,jquery.min.js,....      5
# 4      jjrodriguezn  google.maps.Map,document.getElementById,google...      5
# 5             DglyP  bootstrap.min.css,style.css,jquery.min.js,mark...      5
# 8       Judgarciani  bootstrap.min.css,jquery.min.js,bootstrap.min....      5
# 9         sacastroc  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 10        pcberriop  Map.js,.js,main.css,avatar.jpg,pcberriop.githu...      5
# 11      hsmartineza  jquery.min.js,.js,map.js,house.js,weather.js,p...      5
# 12         Moimolcp  bootstrap.min.css,style.css,script.js,dataPric...      5
# 13      CamiloRueda  layout.css,shiv.js,document.getElementById,goo...      5
# 15       JoseMolano  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 16    maikellPardoA  document.getElementById,google.maps.Map,google...      5
# 17       NicolasZon  google.maps.LatLng,google.maps.MapTypeId.ROADM...      5
# 18        camilo654  bootstrap.min.css,.js,js.js,.ready,.click,.aja...      5
# 19   CristianLozano  document.getElementById,google.maps.Map,google...      5
# 20        jdsuarezj  google.maps.Map,document.getElementById,google...      5
# 21        pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 22      juandavidro  styles.css,script.js,bootstrap.min.css,sites.j...      5
# 23   UNhcrodriguezl  demos.css,bootstrap.min.css,select.min.css,sty...      5
# 24      camilo13152  mapController.js,favicon.ico,fluidbox.min.css,...      5
# 25     leavendanoro  chicagoicon.ico,styles.css,jquery.min.js,js.or...      5
# 26       cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,myJ...      5
# 27       capinillab  document.getElementById,google.maps.Map,google...      5
# 29     lfvalderrama  up.net,shiv.js,main.css,.css,jquery.min.js,ini...      5
# 30        bsgarciac  document.getElementsByClassName,x.length,.styl...      5
# 31           gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      5
# 164      janoguerab  js.org,.v,.min.js,document.getElementById,goog...      5
# 165     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      5
# 166      anmmunozme  .ajax,data.cityofchicago.org,iimk.json,.done,d...      5

# %% [markdown]
# ## Subset Bogota 0 Phase 4

# %%
import numpy as np
overall_phase4_bogota0['phase'] = 4
overall_phase4_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase4_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase4 = overall_phase4_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase4
# Out:
#             Student                                          functions  phase
# 0         fffeelipe  .ready,.click,.removeClass,.is,.val,.check,.on...      4
# 1         mnguzmanc  house.ico,style.css,.css,main.js,map.js,weathe...      4
# 2        jmcuestasb  js.org,.v,.min.js,weather.js,mycss.css,bootstr...      4
# 3        katherinsb  reset.css,layout.css,style.css,.js,yui.js,repl...      4
# 4      jjrodriguezn  google.maps.Map,document.getElementById,google...      4
# 5             DglyP  bootstrap.min.css,style.css,jquery.min.js,mark...      4
# 8       Judgarciani  bootstrap.min.css,jquery.min.js,bootstrap.min....      4
# 9         sacastroc  js.org,.v,.min.js,collection.v,dispatch.v,dsv....      4
# 10        pcberriop  jquery.min.js,Map.js,main.css,avatar.jpg,pcber...      4
# 11      hsmartineza  jquery.min.js,.js,map.js,house.js,weather.js,p...      4
# 12         Moimolcp  bootstrap.min.css,style.css,script.js,jquery.m...      4
# 13      CamiloRueda  layout.css,shiv.js,document.getElementById,goo...      4
# 15       JoseMolano  bootstrap.min.css,theme.min.css,jquery.min.js,...      4
# 16    maikellPardoA  document.getElementById,google.maps.Map,google...      4
# 17       NicolasZon  google.maps.LatLng,google.maps.MapTypeId.ROADM...      4
# 18        camilo654  .ready,.click,.ajax,data.cityofchicago.org,row...      4
# 19   CristianLozano  document.getElementById,google.maps.Map,google...      4
# 20        jdsuarezj  google.maps.Map,document.getElementById,google...      4
# 21        pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      4
# 22      juandavidro  styles.css,script.js,bootstrap.min.css,sites.j...      4
# 23   UNhcrodriguezl  demos.css,bootstrap.min.css,select.min.css,sty...      4
# 24      camilo13152  mapController.js,favicon.ico,fluidbox.min.css,...      4
# 25     leavendanoro  styles.css,jquery.min.js,js.org,.v,.min.js,scr...      4
# 26       cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,myJ...      4
# 27       capinillab  document.getElementById,google.maps.Map,google...      4
# 29     lfvalderrama  up.net,shiv.js,main.css,.css,jquery.min.js,sty...      4
# 30        bsgarciac  document.getElementsByClassName,x.length,.styl...      4
# 31           gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      4
# 164      janoguerab  js.org,.v,.min.js,document.getElementById,goog...      4
# 165     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      4
# 166      anmmunozme  .ajax,data.cityofchicago.org,iimk.json,.done,d...      4

# %% [markdown]
# ## Subset Bogota 0 Phase 3

# %%
import numpy as np
overall_phase3_bogota0['phase'] = 3
overall_phase3_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase3_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase3 = overall_phase3_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase3
# Out:
#             Student                                          functions  phase
# 0         fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      3
# 1         mnguzmanc  house.ico,style.css,.css,main.js,map.js,weathe...      3
# 2        jmcuestasb  js.org,.v,.min.js,weather.js,mycss.css,bootstr...      3
# 4      jjrodriguezn  google.maps.Map,document.getElementById,google...      3
# 5             DglyP  google.maps.Map,document.getElementById,google...      3
# 8       Judgarciani  bootstrap.min.css,jquery.min.js,bootstrap.min....      3
# 9         sacastroc  js.org,.v,.min.js,collection.v,dispatch.v,dsv....      3
# 10        pcberriop  google.maps.Map,document.getElementById,google...      3
# 11      hsmartineza  jquery.min.js,.js,map.js,info.js,test.js,chica...      3
# 12         Moimolcp  bootstrap.min.css,style.css,script.js,jquery.m...      3
# 13      CamiloRueda  layout.css,shiv.js,document.getElementById,goo...      3
# 15       JoseMolano  bootstrap.min.css,theme.min.css,jquery.min.js,...      3
# 16    maikellPardoA  document.getElementById,google.maps.Map,google...      3
# 17       NicolasZon  google.maps.LatLng,google.maps.MapTypeId.ROADM...      3
# 18        camilo654  .ready,.click,.ajax,data.cityofchicago.org,row...      3
# 19   CristianLozano  document.getElementById,google.maps.Map,google...      3
# 20        jdsuarezj  google.maps.Map,document.getElementById,google...      3
# 21        pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      3
# 22      juandavidro  styles.css,script.js,bootstrap.min.css,sites.j...      3
# 23   UNhcrodriguezl  demos.css,bootstrap.min.css,select.min.css,sty...      3
# 24      camilo13152  mapController.js,favicon.ico,fluidbox.min.css,...      3
# 25     leavendanoro  styles.css,js.org,.v,.min.js,script.js,documen...      3
# 26       cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,myJ...      3
# 27       capinillab  document.getElementById,google.maps.Map,google...      3
# 29     lfvalderrama  jquery.min.js,styles.css,init.js,handler.js,se...      3
# 30        bsgarciac  document.getElementsByClassName,x.length,.styl...      3
# 31           gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      3
# 164      janoguerab  js.org,.v,.min.js,document.getElementById,goog...      3
# 165     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      3
# 166      anmmunozme  .ready,.click,.ajax,data.cityofchicago.org,row...      3

# %% [markdown]
# ## Subset Bogota 0 Phase 2

# %%
import numpy as np
overall_phase2_bogota0['phase'] = 2
overall_phase2_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase2_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase2 = overall_phase2_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase2
# Out:
#             Student                                          functions  phase
# 0         fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      2
# 1         mnguzmanc  house.ico,style.css,map.js,Chicago.jpg,documen...      2
# 2        jmcuestasb  js.org,.v,.min.js,weather.js,mycss.css,bootstr...      2
# 4      jjrodriguezn  data.cityofchicago.org,rows.json,.ajax,google....      2
# 5             DglyP  google.maps.Map,document.getElementById,google...      2
# 8       Judgarciani  bootstrap.min.css,jquery.min.js,bootstrap.min....      2
# 9         sacastroc  js.org,.v,.min.js,collection.v,dispatch.v,dsv....      2
# 10        pcberriop  google.maps.Map,document.getElementById,google...      2
# 11      hsmartineza  jquery.min.js,.js,info.js,chicago.jpg,document...      2
# 12         Moimolcp  style.css,script.js,jquery.min.js,google.maps....      2
# 13      CamiloRueda  layout.css,shiv.js,document.getElementById,goo...      2
# 15       JoseMolano  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 16    maikellPardoA  document.getElementById,google.maps.Map,google...      2
# 17       NicolasZon  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2
# 18        camilo654  .ready,.click,.ajax,data.cityofchicago.org,row...      2
# 19   CristianLozano  document.getElementById,google.maps.Map,google...      2
# 20        jdsuarezj  google.maps.Map,document.getElementById,google...      2
# 21        pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 22      juandavidro  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 23   UNhcrodriguezl  demos.css,bootstrap.min.css,select.min.css,sty...      2
# 24      camilo13152  favicon.ico,fluidbox.min.css,main.css,google.m...      2
# 25     leavendanoro  styles.css,js.org,.v,.min.js,myArrayOfObjects....      2
# 26       cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,myJ...      2
# 27       capinillab  document.getElementById,google.maps.Map,google...      2
# 29     lfvalderrama  jquery.min.js,styles.css,init.js,test.js,.cont...      2
# 30        bsgarciac  document.getElementsByClassName,x.length,.styl...      2
# 31           gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2
# 164      janoguerab  js.org,.v,.min.js,document.getElementById,goog...      2
# 165     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      2
# 166      anmmunozme  .ready,.click,.ajax,data.cityofchicago.org,row...      2

# %% [markdown]
# ## Subset Bogota 0 Phase 1

# %%
import numpy as np
overall_phase1_bogota0['phase'] = 1
overall_phase1_bogota0['functions'].replace('', np.nan, inplace=True)
overall_phase1_bogota0.dropna(subset=['functions'], inplace=True)
subset_bogota0_phase1 = overall_phase1_bogota0[['Student', 'functions', 'phase']]
subset_bogota0_phase1
# Out:
#             Student                                          functions  phase
# 0         fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      1
# 1         mnguzmanc  style.css,map.js,document.getElementById,googl...      1
# 5             DglyP               bootstrap.min.css,style.css,.JS,.js,      1
# 8       Judgarciani  jquery.min.js,.js,Rent.js,Crimes.js,google.map...      1
# 9         sacastroc  js.org,.v,.min.js,bootstrap.min.css,theme.min....      1
# 10        pcberriop  google.maps.Map,document.getElementById,google...      1
# 11      hsmartineza  jquery.min.js,.js,info.js,document.getElementB...      1
# 12         Moimolcp  style.css,script.js,jquery.min.js,google.maps....      1
# 15       JoseMolano  document.getElementById,google.maps.Map,google...      1
# 16    maikellPardoA  document.getElementById,google.maps.Map,google...      1
# 17       NicolasZon  lml.jpg,google.maps.LatLng,google.maps.MapType...      1
# 18        camilo654  .floating,document.getElementById,google.maps....      1
# 19   CristianLozano  document.getElementById,google.maps.Map,google...      1
# 20        jdsuarezj  google.maps.Map,document.getElementById,google...      1
# 21        pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 22      juandavidro  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 23   UNhcrodriguezl  demos.css,bootstrap.min.css,style.css,map.gif,...      1
# 24      camilo13152  application.js,this.App,App.cable,ActionCable....      1
# 25     leavendanoro  styles.css,script.js,js.org,.v,.min.js,documen...      1
# 26       cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,goo...      1
# 27       capinillab  document.getElementById,google.maps.Map,google...      1
# 29     lfvalderrama  jquery.min.js,styles.css,init.js,.container,li...      1
# 30        bsgarciac  document.getElementsByClassName,x.length,.styl...      1
# 164      janoguerab  document.getElementById,google.maps.Map,google...      1
# 165     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      1
# 166      anmmunozme  main.css,bootstrap.min.css,jquery.min.js,boots...      1

# %% [markdown]
# ## Subset Bogota 1 Phase 5

# %%
import numpy as np
overall_phase5_bogota1['phase'] = 5
overall_phase5_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase5_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase5 = overall_phase5_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase5
# Out:
#            Student                                          functions  phase
# 39       gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      5
# 40    adamantwharf  document.getElementById,google.maps.Map,google...      5
# 41       bdcajicam  nearium.css,.js,nearium.js,google.maps.Map,doc...      5
# 43     dfhincapiem  main.js,google.maps.Map,document.getElementByI...      5
# 44       helmeraac  styles.css,jquery.min.js,integration.js,script...      5
# 45      dasalgadob  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 46      falperezgo  .ajax,data.cityofchicago.org,rows.json,.done,m...      5
# 47       djguzmanc  google.maps.LatLng,google.maps.Map,document.ge...      5
# 48      gsuarezc04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      5
# 49          oeroaq  .css,style.css,bootstrap.css,balloon.css,js.or...      5
# 51     Semoralesga  style.css,bootstrap.min.css,.js,scripts.js,js....      5
# 52      jonatan360  awesome.min.css,bootstrap.min.css,style.css,ch...      5
# 53  jesusfchavarro  gl.js,.min.js,cdn.jsdelivr.net,semantic.min.js...      5
# 54  jesusfchavarro  gl.js,.min.js,cdn.jsdelivr.net,semantic.min.js...      5
# 55    stevenbustos  style.css,jquery.min.js,distanceFunc.js,getDat...      5
# 56  jufcontrerasco  body.css,favicon.ico,js.org,.v,.min.js,policeb...      5
# 57      dsbarrerag  custom.css,.css,awesome.min.css,jquery.min.js,...      5
# 58       wolfstain  up.net,main.css,.css,noscript.css,chicago.gif,...      5
# 59      miaborjaac  bootstrap.min.css,modifier.css,jquery.min.js,j...      5
# 60   ivdgonzalezco  favicon.ico,bootstrap.min.css,awesome.css,pris...      5
# 62    Christian7sr  estilos.css,icon.ico,Etxea.js,document.getElem...      5
# 63      jsnarvaezb  bootstrap.min.css,jquery.min.js,style.css,data...      5
# 64   gfalbarracinr  bootstrap.min.css,main.css,.jpg,jane.doe,profi...      5
# 65        aldiazve  bootstrap.min.css,main.css,data.cityofchicago....      5
# 66  diegoaguevarar  styles.css,blocks.css,bootstrap.min.css,theme....      5
# 67      fevargasmo  this.value,this.name,window.location.reload,do...      5
# 68      jmhurtadoc  .controls,.pac,searchBox.js,bootstrap.min.css,...      5
# 69     anfmorenoso  bootstrap.min.css,estilos.css,script.js,form.j...      5
# 70     nabautistal  document.getElementById,google.maps.Map,google...      5
# 71          crigar  document.getElementById,google.maps.Map,google...      5
# 72     jiapulidoar  module.exports,grunt.option,grunt.initConfig,g...      5
# 73       jsviveroj  .css,bootstrap.min.css,freelancer.min.css,styl...      5
# 74      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      5
# 75        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      5
# 76  joahernandezca  document.getElementById,google.maps.Map,google...      5
# 80    JairVillalba  fH.css,jquery.min.js,.js,call.js,climate.js,th...      5

# %% [markdown]
# ## Subset Bogota 1 Phase 4

# %%
import numpy as np
overall_phase4_bogota1['phase'] = 4
overall_phase4_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase4_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase4 = overall_phase4_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase4
# Out:
#            Student                                          functions  phase
# 39       gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      4
# 40    adamantwharf  document.getElementById,google.maps.Map,google...      4
# 41       bdcajicam  nearium.css,.js,nearium.js,google.maps.Map,doc...      4
# 43     dfhincapiem  main.js,google.maps.Map,document.getElementByI...      4
# 44       helmeraac  styles.css,jquery.min.js,integration.js,script...      4
# 45      dasalgadob  bootstrap.min.css,theme.min.css,jquery.min.js,...      4
# 46      falperezgo  .ajax,data.cityofchicago.org,rows.json,.done,c...      4
# 47       djguzmanc  google.maps.LatLng,google.maps.Map,document.ge...      4
# 48      gsuarezc04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      4
# 49          oeroaq  .css,style.css,bootstrap.css,balloon.css,jquer...      4
# 50         gcantem  window.XMLHttpRequest,Microsoft.XMLHTTP,xmlhtt...      4
# 51     Semoralesga  style.css,bootstrap.min.css,.js,scripts.js,js....      4
# 52      jonatan360  awesome.min.css,bootstrap.min.css,style.css,ch...      4
# 53  jesusfchavarro  gl.js,.min.js,cdn.jsdelivr.net,semantic.min.js...      4
# 54  jesusfchavarro  gl.js,.min.js,cdn.jsdelivr.net,semantic.min.js...      4
# 55    stevenbustos  style.css,jquery.min.js,distanceFunc.js,getDat...      4
# 56  jufcontrerasco  body.css,favicon.ico,js.org,.v,.min.js,policeb...      4
# 57      dsbarrerag  .CSS,custom.css,.css,awesome.min.css,jquery.mi...      4
# 58       wolfstain  up.net,main.css,.css,noscript.css,chicago.gif,...      4
# 59      miaborjaac  bootstrap.min.css,modifier.css,jquery.min.js,j...      4
# 60   ivdgonzalezco  favicon.ico,bootstrap.min.css,awesome.css,pris...      4
# 62    Christian7sr  estilos.css,icon.ico,Etxea.js,document.getElem...      4
# 63      jsnarvaezb  bootstrap.min.css,jquery.min.js,style.css,data...      4
# 64   gfalbarracinr  bootstrap.min.css,main.css,.jpg,jane.doe,profi...      4
# 65        aldiazve  bootstrap.min.css,main.css,bundle.js,main.onGo...      4
# 66  diegoaguevarar  styles.css,blocks.css,bootstrap.min.css,theme....      4
# 67      fevargasmo  this.value,this.name,window.location.reload,do...      4
# 68      jmhurtadoc  .controls,.pac,searchBox.js,bootstrap.min.css,...      4
# 69     anfmorenoso  bootstrap.min.css,estilos.css,script.js,docume...      4
# 70     nabautistal  document.getElementById,google.maps.Map,google...      4
# 71          crigar  document.getElementById,google.maps.Map,google...      4
# 72     jiapulidoar  module.exports,grunt.option,grunt.initConfig,g...      4
# 73       jsviveroj  .css,bootstrap.min.css,freelancer.min.css,styl...      4
# 74      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      4
# 75        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      4
# 76  joahernandezca  document.getElementById,google.maps.Map,google...      4
# 80    JairVillalba  fH.css,jquery.min.js,.js,call.js,climate.js,th...      4

# %% [markdown]
# ## Subset Bogota 1 Phase 3

# %%
import numpy as np
overall_phase3_bogota1['phase'] = 3
overall_phase3_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase3_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase3 = overall_phase3_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase3
# Out:
#            Student                                          functions  phase
# 39       gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      3
# 40    adamantwharf  document.getElementById,google.maps.Map,google...      3
# 41       bdcajicam  nearium.css,.js,nearium.js,google.maps.Map,doc...      3
# 43     dfhincapiem  main.js,google.maps.Map,document.getElementByI...      3
# 44       helmeraac  styles.css,jquery.min.js,scripts.js,integratio...      3
# 45      dasalgadob  bootstrap.min.css,theme.min.css,jquery.min.js,...      3
# 46      falperezgo  materialize.css,materialize.js,materialize.min...      3
# 47       djguzmanc  google.maps.LatLng,google.maps.Map,document.ge...      3
# 48      gsuarezc04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      3
# 49          oeroaq  style.css,bootstrap.css,balloon.css,jquery.ran...      3
# 50         gcantem  bootstrap.min.css,theme.min.css,jquery.min.js,...      3
# 51     Semoralesga  style.css,.js,scripts.js,.ready,.click,.ajax,d...      3
# 52      jonatan360  awesome.min.css,bootstrap.min.css,style.css,ch...      3
# 53  jesusfchavarro  gl.js,gl.css,.mapboxgl,mapboxgl.accessToken,pk...      3
# 54  jesusfchavarro  gl.js,gl.css,.mapboxgl,mapboxgl.accessToken,pk...      3
# 55    stevenbustos  style.css,.jpg,google.maps.LatLng,google.maps....      3
# 56  jufcontrerasco  body.css,favicon.ico,google.maps.Map,document....      3
# 57      dsbarrerag  .CSS,custom.css,.css,awesome.min.css,jquery.mi...      3
# 58       wolfstain  up.net,main.css,.css,noscript.css,chicago.gif,...      3
# 59      miaborjaac  bootstrap.min.css,modifier.css,jquery.min.js,j...      3
# 60   ivdgonzalezco  favicon.ico,bootstrap.min.css,awesome.css,pris...      3
# 62    Christian7sr  estilos.css,icon.ico,Etxea.js,document.getElem...      3
# 63      jsnarvaezb  bootstrap.min.css,jquery.min.js,style.css,data...      3
# 64   gfalbarracinr  bootstrap.min.css,profile.css,rid.css,google.m...      3
# 65        aldiazve  bootstrap.min.css,main.css,bundle.js,MapExerci...      3
# 66  diegoaguevarar  styles.css,blocks.css,bootstrap.min.css,theme....      3
# 67      fevargasmo  this.value,this.name,document.getElementById,....      3
# 68      jmhurtadoc  .controls,.pac,searchBox.js,bootstrap.min.css,...      3
# 69     anfmorenoso  estilos.css,map.PNG,unal.edu.co,bootstrap.min....      3
# 70     nabautistal  document.getElementById,google.maps.Map,google...      3
# 71          crigar  document.getElementById,google.maps.Map,google...      3
# 72     jiapulidoar  module.exports,grunt.option,grunt.initConfig,g...      3
# 73       jsviveroj  bootstrap.min.css,freelancer.min.css,style.css...      3
# 74      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      3
# 75        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      3
# 76  joahernandezca  document.getElementById,google.maps.Map,google...      3
# 80    JairVillalba  fH.css,call.js,jquery.min.js,.js,this.id,docum...      3

# %% [markdown]
# ## Subset Bogota 2 Phase 2

# %%
import numpy as np
overall_phase2_bogota1['phase'] = 2
overall_phase2_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase2_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase2 = overall_phase2_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase2
# Out:
#            Student                                          functions  phase
# 39       gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      2
# 40    adamantwharf  document.getElementById,google.maps.Map,google...      2
# 41       bdcajicam  google.maps.Map,document.getElementById,google...      2
# 43     dfhincapiem  main.js,google.maps.Map,document.getElementByI...      2
# 44       helmeraac  styles.css,jquery.min.js,scripts.js,integratio...      2
# 45      dasalgadob  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 46      falperezgo  materialize.css,materialize.js,materialize.min...      2
# 47       djguzmanc  google.maps.LatLng,google.maps.Map,document.ge...      2
# 48      gsuarezc04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2
# 49          oeroaq  style.css,bootstrap.css,jquery.js,bootstrap.js...      2
# 50         gcantem  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 51     Semoralesga  style.css,.js,scripts.js,.ready,.click,.ajax,d...      2
# 52      jonatan360  awesome.min.css,bootstrap.min.css,style.css,fa...      2
# 53  jesusfchavarro  gl.js,.min.js,cdn.jsdelivr.net,semantic.min.js...      2
# 54  jesusfchavarro  gl.js,.min.js,cdn.jsdelivr.net,semantic.min.js...      2
# 55    stevenbustos  style.css,.jpg,google.maps.LatLng,google.maps....      2
# 56  jufcontrerasco  body.css,favicon.ico,google.maps.Map,document....      2
# 57      dsbarrerag  .CSS,custom.css,.css,awesome.min.css,jquery.mi...      2
# 58       wolfstain  bootstrap.min.css,map.js,jquery.min.js,bootstr...      2
# 59      miaborjaac  bootstrap.min.css,modifier.css,jquery.min.js,j...      2
# 60   ivdgonzalezco  favicon.ico,bootstrap.min.css,awesome.css,pris...      2
# 62    Christian7sr                              estilos.css,icon.ico,      2
# 63      jsnarvaezb  bootstrap.min.css,jquery.min.js,style.css,data...      2
# 64   gfalbarracinr  bootstrap.min.css,blueberry.css,main.css,jquer...      2
# 65        aldiazve  bootstrap.min.css,main.css,bundle.js,MapExerci...      2
# 66  diegoaguevarar  styles.css,blocks.css,bootstrap.min.css,theme....      2
# 67      fevargasmo  this.value,this.name,document.getElementById,....      2
# 68      jmhurtadoc  .controls,.pac,searchBox.js,bootstrap.min.css,...      2
# 69     anfmorenoso  estilos.css,map.PNG,unal.edu.co,bootstrap.min....      2
# 70     nabautistal  document.getElementById,google.maps.Map,google...      2
# 71          crigar  document.getElementById,google.maps.Map,google...      2
# 72     jiapulidoar  module.exports,grunt.option,grunt.initConfig,g...      2
# 73       jsviveroj  bootstrap.min.css,freelancer.min.css,style.css...      2
# 74      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      2
# 75        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      2
# 76  joahernandezca  document.getElementById,google.maps.Map,google...      2
# 80    JairVillalba  fH.css,call.js,jquery.min.js,.js,this.id,docum...      2

# %% [markdown]
# ## Subset Bogota 1 Phase 1

# %%
import numpy as np
overall_phase1_bogota1['phase'] = 1
overall_phase1_bogota1['functions'].replace('', np.nan, inplace=True)
overall_phase1_bogota1.dropna(subset=['functions'], inplace=True)
subset_bogota1_phase1 = overall_phase1_bogota1[['Student', 'functions', 'phase']]
subset_bogota1_phase1
# Out:
#            Student                                          functions  phase
# 39       gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      1
# 40    adamantwharf  document.getElementById,google.maps.Map,google...      1
# 41       bdcajicam  google.maps.Map,document.getElementById,google...      1
# 44       helmeraac  styles.css,scripts.js,integration.js,google.ma...      1
# 45      dasalgadob  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 46      falperezgo  materialize.min.css,materialize.min.js,.min.js...      1
# 47       djguzmanc  google.maps.LatLng,google.maps.Map,document.ge...      1
# 49          oeroaq  style.css,bootstrap.min.css,jquery.js,bootstra...      1
# 50         gcantem  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 51     Semoralesga  style.css,scripts.js,document.getElementById,g...      1
# 52      jonatan360  awesome.min.css,bootstrap.min.css,style.css,fa...      1
# 53  jesusfchavarro  gl.js,.min.js,js.org,.v,gl.css,awesome.min.css...      1
# 54  jesusfchavarro  gl.js,.min.js,js.org,.v,gl.css,awesome.min.css...      1
# 56  jufcontrerasco  body.css,google.maps.Map,document.getElementBy...      1
# 57      dsbarrerag  .CSS,.css,awesome.min.css,.mySlides,page.php,d...      1
# 58       wolfstain  bootstrap.min.css,map.js,jquery.min.js,bootstr...      1
# 59      miaborjaac  bootstrap.min.css,modifier.css,js.org,.v,.js,s...      1
# 60   ivdgonzalezco  favicon.ico,bootstrap.min.css,awesome.css,pris...      1
# 62    Christian7sr                                       estilos.css,      1
# 63      jsnarvaezb  data.cityofchicago.org,iimk.geojson,xi.geojson...      1
# 64   gfalbarracinr  blueberry.css,main.css,jquery.min.js,jquery.bl...      1
# 65        aldiazve  bootstrap.min.css,main.css,.js,.min.js,main.js...      1
# 66  diegoaguevarar  styles.css,blocks.css,bootstrap.min.css,theme....      1
# 67      fevargasmo  this.value,this.name,document.getElementById,....      1
# 68      jmhurtadoc  .controls,.pac,searchBox.js,bootstrap.min.css,...      1
# 70     nabautistal  document.getElementById,google.maps.Map,google...      1
# 71          crigar  document.getElementById,google.maps.Map,google...      1
# 72     jiapulidoar  .js,Mapa.js,Data.js,labels.text.stroke,labels....      1
# 73       jsviveroj  bootstrap.min.css,freelancer.min.css,style.css...      1
# 74      daandradec  styles.css,awesome.min.css,imageManager.js,loc...      1
# 75        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      1
# 76  joahernandezca  document.getElementById,google.maps.Map,google...      1
# 80    JairVillalba  fH.css,document.getElementById,google.maps.Map...      1

# %%
import numpy as np
overall_phase5_bogota2['phase'] = 5
overall_phase5_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase5_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase5 = overall_phase5_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase5
# Out:
#              Student                                          functions  phase
# 81      jusherrerama  js.org,.v,.min.js,bootstrap.min.css,portfolio....      5
# 82           bdvegat  js.org,.v,.js,bootstrap.min.css,bootstrap.min....      5
# 83        Phoenixest  a.active,.active,document.getElementById,googl...      5
# 84          HashNick  jquery.min.js,bootstrap.min.js,.js,js.org,.v,....      5
# 85           ccvacad  bootstrap.min.css,jquery.min.js,bootstrap.min....      5
# 86        joaortizro  document.getElementById,google.maps.Map,bootst...      5
# 87   juasmartinezbel  bootstrap.min.css,jquery.min.js,.js,js.org,.v,...      5
# 88          mdbelloc  jquery.min.js,bootstrap.min.js,tutorial.css,.j...      5
# 89       diegocruz10  bootstrap.min.css,awesome.min.css,theme.min.cs...      5
# 91            sagilm  data.cityofchicago.org,rows.json,xmlhttp.open,...      5
# 92          idrojasf  components.css,responsee.css,owl.carousel.css,...      5
# 93      raulramirezp  up.net,main.css,bootstrap.min.css,jquery.min.j...      5
# 94         fabianr23  estilos.css,functions.js,jquery.min.js,.v,.min...      5
# 95        jhriverasa  style.css,bootstrap.min.css,.min.css,google.ma...      5
# 96        jhonsd1996  style.css,.Chicago,document.getElementById,goo...      5
# 97        JuanitoAli  bootstrap.css,.js,bootstrap.js,logic.js,update...      5
# 98        Davsatu313  Style.css,.min.js,js.org,.v,map.js,Climate.js,...      5
# 99    cesarochoa2006  .getFullYear,console.log,.main,.hide,.routeBut...      5
# 100        jjmuesesq  document.getElementById,google.maps.Map,google...      5
# 101     jucjimenezmo  home.css,search.css,favicon.jpg,.js,js.org,.v,...      5
# 102           kancas  style.css,bootstrap.min.css,theme.min.css,jque...      5
# 103          Gantiva  latest.min.js,jquery.min.js,food.js,opciones.j...      5
# 104       Dandarprox  bootstrap.js,bootstrap.css,styles.css,tables.c...      5
# 105       debeltranc  runner.github.io,module.exports,config.set,tes...      5
# 106        ykchautai  tiry.cloudfront.net,foundation.min.css,style.c...      5
# 107        ligibrial  bootstrap.min.css,jquery.min.js,bootstrap.min....      5
# 108       davidrh195  navicon.jpg,style.css,document.getElementById,...      5
# 109      JulianaNino  bootstrap.min.css,.navbar,Respond.js,shiv.js,r...      5
# 110         luegilca  bootstrap.min.css,.js,js.org,.v,.min.js,jquery...      5
# 111           Yelis3  map.css,google.maps.Map,document.getElementByI...      5
# 112        begarzonf  reset.css,layout.css,style.css,jquery.fancybox...      5
# 113       kmendezp96  js.org,.v,.min.js,bar.css,StyleSheet.css,jquer...      5
# 114         leguzman  today.getDate,today.getMonth,today.getFullYear...      5
# 115     luealfonsoru  bootstrap.min.css,balloon.min.css,freelancer.c...      5
# 116         oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 117         lsfinite  .css,awesome.min.css,latest.min.js,room.js,sho...      5
# 118        xdanielsb  console.log,jQuery.parseJSON,.ajax,.done,.fail...      5
# 122     jscontrerasp  latest.min.js,google.maps.LatLng,google.maps.M...      5

# %%
import numpy as np
overall_phase4_bogota2['phase'] = 4
overall_phase4_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase4_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase4 = overall_phase4_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase4
# Out:
#              Student                                          functions  phase
# 81      jusherrerama  js.org,.v,.min.js,bootstrap.min.css,portfolio....      4
# 82           bdvegat  js.org,.v,.js,bootstrap.min.css,bootstrap.min....      4
# 83        Phoenixest  a.active,.active,document.getElementById,googl...      4
# 84          HashNick  jquery.min.js,bootstrap.min.js,.js,js.org,.v,....      4
# 85           ccvacad  bootstrap.min.css,jquery.min.js,bootstrap.min....      4
# 86        joaortizro  document.getElementById,google.maps.Map,bootst...      4
# 87   juasmartinezbel  bootstrap.min.css,jquery.min.js,.js,js.org,.v,...      4
# 88          mdbelloc  jquery.min.js,bootstrap.min.js,tutorial.css,.j...      4
# 89       diegocruz10  bootstrap.min.css,awesome.min.css,theme.min.cs...      4
# 91            sagilm  data.cityofchicago.org,rows.json,xmlhttp.open,...      4
# 92          idrojasf  components.css,responsee.css,owl.carousel.css,...      4
# 93      raulramirezp  up.net,main.css,bootstrap.min.css,jquery.min.j...      4
# 94         fabianr23  estilos.css,functions.js,jquery.min.js,.v,.min...      4
# 95        jhriverasa  style.css,bootstrap.min.css,jquery.min.js,boot...      4
# 96        jhonsd1996  style.css,.Chicago,document.getElementById,goo...      4
# 97        JuanitoAli  bootstrap.css,.js,bootstrap.js,logic.js,update...      4
# 98        Davsatu313  Style.css,.min.js,js.org,.v,map.js,Climate.js,...      4
# 99    cesarochoa2006  .getFullYear,console.log,.main,.hide,.routeBut...      4
# 100        jjmuesesq  document.getElementById,google.maps.Map,google...      4
# 101     jucjimenezmo  home.css,search.css,favicon.jpg,.js,js.org,.v,...      4
# 102           kancas  style.css,bootstrap.min.css,theme.min.css,jque...      4
# 103          Gantiva  latest.min.js,jquery.min.js,food.js,opciones.j...      4
# 104       Dandarprox  bootstrap.js,bootstrap.css,styles.css,tables.c...      4
# 105       debeltranc  runner.github.io,module.exports,config.set,tes...      4
# 106        ykchautai  tiry.cloudfront.net,foundation.min.css,style.c...      4
# 107        ligibrial  funciones.js,bootstrap.min.css,jquery.min.js,b...      4
# 108       davidrh195  navicon.jpg,style.css,document.getElementById,...      4
# 109      JulianaNino  bootstrap.min.css,.navbar,Respond.js,shiv.js,r...      4
# 110         luegilca  bootstrap.min.css,.js,js.org,.v,.min.js,jquery...      4
# 111           Yelis3  semantic.min.css,calendar.min.css,styles.css,....      4
# 112        begarzonf  reset.css,layout.css,style.css,jquery.fancybox...      4
# 113       kmendezp96  js.org,.v,.min.js,bar.css,StyleSheet.css,scrip...      4
# 114         leguzman  GetDeepSearchResults.htm,.ready,console.log,.s...      4
# 115     luealfonsoru  bootstrap.min.css,balloon.min.css,freelancer.c...      4
# 116         oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      4
# 117         lsfinite  .css,awesome.min.css,latest.min.js,room.js,sho...      4
# 118        xdanielsb  console.log,jQuery.parseJSON,.ajax,.done,.fail...      4
# 122     jscontrerasp  latest.min.js,google.maps.LatLng,google.maps.M...      4

# %%
import numpy as np
overall_phase3_bogota2['phase'] = 3
overall_phase3_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase3_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase3 = overall_phase3_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase3
# Out:
#              Student                                          functions  phase
# 81      jusherrerama  js.org,.v,.min.js,bootstrap.min.css,portfolio....      3
# 82           bdvegat  js.org,.v,.js,bootstrap.min.css,bootstrap.min....      3
# 83        Phoenixest  a.active,.active,document.getElementById,googl...      3
# 84          HashNick  jquery.min.js,tutorial.js,bootstrap.min.js,doc...      3
# 86        joaortizro  document.getElementById,google.maps.Map,bootst...      3
# 87   juasmartinezbel  bootstrap.min.css,jquery.min.js,.js,js.org,.v,...      3
# 88          mdbelloc  jquery.min.js,bootstrap.min.js,tutorial.css,.j...      3
# 89       diegocruz10  bootstrap.min.css,awesome.min.css,theme.min.cs...      3
# 91            sagilm  data.cityofchicago.org,rows.json,xmlhttp.open,...      3
# 92          idrojasf  components.css,responsee.css,owl.carousel.css,...      3
# 93      raulramirezp  up.net,main.css,bootstrap.min.css,jquery.min.j...      3
# 94         fabianr23  estilos.css,functions.js,jquery.min.js,.ajax,c...      3
# 95        jhriverasa  style.css,bootstrap.min.css,jquery.min.js,boot...      3
# 96        jhonsd1996  style.css,.Chicago,document.getElementById,goo...      3
# 97        JuanitoAli  bootstrap.css,.js,bootstrap.js,google.maps.Map...      3
# 98        Davsatu313  Style.css,.min.js,js.org,.v,map.js,Climate.js,...      3
# 99    cesarochoa2006  .getFullYear,console.log,document.getElementBy...      3
# 100        jjmuesesq  document.getElementById,google.maps.Map,google...      3
# 101     jucjimenezmo  home.css,search.css,favicon.jpg,logo.jpg,unive...      3
# 102           kancas  style.css,bootstrap.min.css,theme.min.css,jque...      3
# 103          Gantiva  latest.min.js,jquery.min.js,food.js,rents.js,c...      3
# 104       Dandarprox  bootstrap.js,bootstrap.css,styles.css,tables.c...      3
# 105       debeltranc  runner.github.io,module.exports,config.set,tes...      3
# 106        ykchautai  tiry.cloudfront.net,foundation.min.css,style.c...      3
# 107        ligibrial  funciones.js,bootstrap.min.css,jquery.min.js,e...      3
# 108       davidrh195  navicon.jpg,style.css,document.getElementById,...      3
# 109      JulianaNino  google.maps.Map,document.getElementById,google...      3
# 110         luegilca  bootstrap.min.css,.js,js.org,.v,.min.js,jquery...      3
# 111           Yelis3  semantic.min.css,calendar.min.css,styles.css,....      3
# 112        begarzonf  reset.css,layout.css,style.css,jquery.fancybox...      3
# 113       kmendezp96  js.org,.v,.min.js,bar.css,StyleSheet.css,scrip...      3
# 114         leguzman  xmlhttp.open,xmlhttp.setRequestHeader,xmlhttp....      3
# 115     luealfonsoru  bootstrap.min.css,freelancer.css,custom.css,cu...      3
# 116         oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      3
# 117         lsfinite  .css,awesome.min.css,latest.min.js,room.js,sho...      3
# 118        xdanielsb  console.log,jQuery.parseJSON,.ajax,.done,.fail...      3
# 122     jscontrerasp  latest.min.js,google.maps.LatLng,google.maps.M...      3

# %%
import numpy as np
overall_phase2_bogota2['phase'] = 2
overall_phase2_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase2_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase2 = overall_phase2_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase2
# Out:
#              Student                                          functions  phase
# 81      jusherrerama  bootstrap.min.css,portfolio.css,awesome.min.cs...      2
# 82           bdvegat  cs.css,document.getElementById,google.maps.Map...      2
# 83        Phoenixest  a.active,.active,document.getElementById,googl...      2
# 84          HashNick  jquery.min.js,tutorial.js,bootstrap.min.js,doc...      2
# 86        joaortizro  document.getElementById,google.maps.Map,bootst...      2
# 87   juasmartinezbel  bootstrap.min.css,jquery.min.js,.js,js.org,.v,...      2
# 88          mdbelloc  jquery.min.js,bootstrap.min.js,tutorial.css,.j...      2
# 89       diegocruz10  bootstrap.min.css,awesome.min.css,theme.min.cs...      2
# 91            sagilm  .css,buttons.css,google.maps.Map,document.getE...      2
# 92          idrojasf  components.css,responsee.css,owl.carousel.css,...      2
# 93      raulramirezp  up.net,main.css,bootstrap.min.css,jquery.min.j...      2
# 94         fabianr23  estilos.css,functions.js,jquery.min.js,.ajax,c...      2
# 95        jhriverasa  style.css,jquery.min.js,.ready,.click,.ajax,re...      2
# 96        jhonsd1996  style.css,.Chicago,document.getElementById,goo...      2
# 97        JuanitoAli  templates.asp,bootstrap.min.css,jquery.min.js,...      2
# 98        Davsatu313  Style.css,.min.js,js.org,.v,map.js,Climate.js,...      2
# 99    cesarochoa2006  google.maps.DirectionsRenderer,document.getEle...      2
# 100        jjmuesesq  document.getElementById,google.maps.Map,google...      2
# 101     jucjimenezmo  home.css,search.css,favicon.jpg,logo.jpg,unive...      2
# 102           kancas  style.css,bootstrap.min.css,theme.min.css,jque...      2
# 103          Gantiva  latest.min.js,jquery.min.js,clear.js,food.js,r...      2
# 104       Dandarprox  bootstrap.js,bootstrap.css,styles.css,tables.c...      2
# 105       debeltranc  runner.github.io,module.exports,config.set,tes...      2
# 106        ykchautai  tiry.cloudfront.net,foundation.min.css,style.c...      2
# 107        ligibrial  funciones.js,jquery.min.js,bootstrap.min.js,es...      2
# 108       davidrh195  navicon.jpg,style.css,document.getElementById,...      2
# 109      JulianaNino  google.maps.Map,document.getElementById,google...      2
# 110         luegilca  bootstrap.min.css,.js,js.org,.v,.min.js,jquery...      2
# 111           Yelis3  semantic.min.css,styles.css,.min.js,bootstrap....      2
# 112        begarzonf  reset.css,layout.css,style.css,jquery.fancybox...      2
# 113       kmendezp96  js.org,.v,.min.js,bar.css,StyleSheet.css,scrip...      2
# 114         leguzman  xmlhttp.open,xmlhttp.setRequestHeader,xmlhttp....      2
# 115     luealfonsoru  bootstrap.min.css,freelancer.css,custom.css,cu...      2
# 116         oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 117         lsfinite  .css,awesome.min.css,latest.min.js,room.js,.w,...      2
# 118        xdanielsb  .ajax,.done,console.log,.fail,data.cityofchica...      2
# 122     jscontrerasp  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2

# %%
import numpy as np
overall_phase1_bogota2['phase'] = 1
overall_phase1_bogota2['functions'].replace('', np.nan, inplace=True)
overall_phase1_bogota2.dropna(subset=['functions'], inplace=True)
subset_bogota2_phase1 = overall_phase1_bogota2[['Student', 'functions', 'phase']]
subset_bogota2_phase1
# Out:
#              Student                                          functions  phase
# 81      jusherrerama  bootstrap.min.css,portfolio.css,awesome.min.cs...      1
# 82           bdvegat  cs.css,document.getElementById,google.maps.Map...      1
# 83        Phoenixest  a.active,.active,document.getElementById,googl...      1
# 84          HashNick  jquery.min.js,bootstrap.min.js,.js,js.org,.v,....      1
# 86        joaortizro  bootstrap.min.css,theme.min.css,bootstrap.min....      1
# 87   juasmartinezbel  bootstrap.min.css,jquery.min.js,.js,js.org,.v,...      1
# 88          mdbelloc  jquery.min.js,bootstrap.min.js,tutorial.css,.j...      1
# 89       diegocruz10  bootstrap.min.css,awesome.min.css,theme.min.cs...      1
# 91            sagilm  google.maps.Map,document.getElementById,google...      1
# 92          idrojasf  components.css,responsee.css,owl.carousel.css,...      1
# 93      raulramirezp  google.maps.Map,document.getElementById,Script...      1
# 94         fabianr23  estilos.css,functions.js,google.maps.Map,docum...      1
# 95        jhriverasa  style.css,jquery.min.js,.ready,.click,.ajax,re...      1
# 96        jhonsd1996                                style.css,.Chicago,      1
# 97        JuanitoAli  document.createElement,script.src,week.geojson...      1
# 98        Davsatu313  Style.css,.min.js,js.org,.v,map.js,Climate.js,...      1
# 99    cesarochoa2006  document.getElementById,google.maps.Map,google...      1
# 100        jjmuesesq  document.getElementById,google.maps.Map,google...      1
# 102           kancas  style.css,main.js,bootstrap.min.css,theme.min....      1
# 103          Gantiva  latest.min.js,jquery.min.js,rent.js,js.org,.v,...      1
# 104       Dandarprox  bootstrap.js,bootstrap.css,styles.css,googleMa...      1
# 105       debeltranc  runner.github.io,module.exports,config.set,tes...      1
# 106        ykchautai  tiry.cloudfront.net,foundation.min.css,chicago...      1
# 107        ligibrial  funciones.js,jquery.min.js,bootstrap.min.js,es...      1
# 108       davidrh195  navicon.jpg,style.css,document.getElementById,...      1
# 109      JulianaNino  bootstrap.min.css,item.css,Respond.js,shiv.js,...      1
# 110         luegilca  bootstrap.min.css,.js,js.org,.v,.min.js,jquery...      1
# 111           Yelis3  semantic.min.css,styles.css,.min.js,jquery.min...      1
# 112        begarzonf  document.getElementById,google.maps.Map,google...      1
# 113       kmendezp96  js.org,.v,.min.js,bar.css,StyleSheet.css,scrip...      1
# 114         leguzman  .ready,.click,styles.css,developers.google,def...      1
# 115     luealfonsoru  bootstrap.min.css,freelancer.min.css,custom.cs...      1
# 116         oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 117         lsfinite  .CSS,.css,this.parentElement.style.display,awe...      1
# 118        xdanielsb  bootstrap.min.css,theme.min.css,aos.css,conten...      1
# 122     jscontrerasp  stylesheet.css,main.js,document.getElementById...      1

# %% [markdown]
# ## Merge Two Phases into One Frame

# %%
phase15_bogota0 = overall_phase1_bogota0.append(overall_phase5_bogota0, ignore_index = True)
df_phase15_bogota0 = phase15_bogota0[['Student', 'functions', 'phase']]
df_phase15_bogota0
# Out:
#            Student                                          functions  phase
# 0        fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      1
# 1        mnguzmanc  style.css,map.js,document.getElementById,googl...      1
# 2            DglyP               bootstrap.min.css,style.css,.JS,.js,      1
# 3      Judgarciani  jquery.min.js,.js,Rent.js,Crimes.js,google.map...      1
# 4        sacastroc  js.org,.v,.min.js,bootstrap.min.css,theme.min....      1
# 5        pcberriop  google.maps.Map,document.getElementById,google...      1
# 6      hsmartineza  jquery.min.js,.js,info.js,document.getElementB...      1
# 7         Moimolcp  style.css,script.js,jquery.min.js,google.maps....      1
# 8       JoseMolano  document.getElementById,google.maps.Map,google...      1
# 9    maikellPardoA  document.getElementById,google.maps.Map,google...      1
# 10      NicolasZon  lml.jpg,google.maps.LatLng,google.maps.MapType...      1
# 11       camilo654  .floating,document.getElementById,google.maps....      1
# 12  CristianLozano  document.getElementById,google.maps.Map,google...      1
# 13       jdsuarezj  google.maps.Map,document.getElementById,google...      1
# 14       pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 15     juandavidro  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 16  UNhcrodriguezl  demos.css,bootstrap.min.css,style.css,map.gif,...      1
# 17     camilo13152  application.js,this.App,App.cable,ActionCable....      1
# 18    leavendanoro  styles.css,script.js,js.org,.v,.min.js,documen...      1
# 19      cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,goo...      1
# 20      capinillab  document.getElementById,google.maps.Map,google...      1
# 21    lfvalderrama  jquery.min.js,styles.css,init.js,.container,li...      1
# 22       bsgarciac  document.getElementsByClassName,x.length,.styl...      1
# 23      janoguerab  document.getElementById,google.maps.Map,google...      1
# 24     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      1
# 25      anmmunozme  main.css,bootstrap.min.css,jquery.min.js,boots...      1
# 26       fffeelipe  .ready,.click,.css,.removeClass,.is,.val,.chec...      5
# 27       mnguzmanc  house.ico,style.css,.css,main.js,map.js,weathe...      5
# 28      jmcuestasb  js.org,.v,.min.js,weather.js,myss.css,bootstra...      5
# 29      katherinsb  reset.css,layout.css,style.css,jquery.min.js,....      5
# 30    jjrodriguezn  google.maps.Map,document.getElementById,google...      5
# 31           DglyP  bootstrap.min.css,style.css,jquery.min.js,mark...      5
# 32     Judgarciani  bootstrap.min.css,jquery.min.js,bootstrap.min....      5
# 33       sacastroc  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 34       pcberriop  Map.js,.js,main.css,avatar.jpg,pcberriop.githu...      5
# 35     hsmartineza  jquery.min.js,.js,map.js,house.js,weather.js,p...      5
# 36        Moimolcp  bootstrap.min.css,style.css,script.js,dataPric...      5
# 37     CamiloRueda  layout.css,shiv.js,document.getElementById,goo...      5
# 38      JoseMolano  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 39   maikellPardoA  document.getElementById,google.maps.Map,google...      5
# 40      NicolasZon  google.maps.LatLng,google.maps.MapTypeId.ROADM...      5
# 41       camilo654  bootstrap.min.css,.js,js.js,.ready,.click,.aja...      5
# 42  CristianLozano  document.getElementById,google.maps.Map,google...      5
# 43       jdsuarezj  google.maps.Map,document.getElementById,google...      5
# 44       pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 45     juandavidro  styles.css,script.js,bootstrap.min.css,sites.j...      5
# 46  UNhcrodriguezl  demos.css,bootstrap.min.css,select.min.css,sty...      5
# 47     camilo13152  mapController.js,favicon.ico,fluidbox.min.css,...      5
# 48    leavendanoro  chicagoicon.ico,styles.css,jquery.min.js,js.or...      5
# 49      cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,myJ...      5
# 50      capinillab  document.getElementById,google.maps.Map,google...      5
# 51    lfvalderrama  up.net,shiv.js,main.css,.css,jquery.min.js,ini...      5
# 52       bsgarciac  document.getElementsByClassName,x.length,.styl...      5
# 53          gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      5
# 54      janoguerab  js.org,.v,.min.js,document.getElementById,goog...      5
# 55     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      5
# 56      anmmunozme  .ajax,data.cityofchicago.org,iimk.json,.done,d...      5

# %%
phase12_bogota0 = overall_phase1_bogota0.append(overall_phase2_bogota0, ignore_index = True)
df_phase12_bogota0 = phase12_bogota0[['Student', 'functions', 'phase']]
df_phase12_bogota0
# Out:
#            Student                                          functions  phase
# 0        fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      1
# 1        mnguzmanc  style.css,map.js,document.getElementById,googl...      1
# 2            DglyP               bootstrap.min.css,style.css,.JS,.js,      1
# 3      Judgarciani  jquery.min.js,.js,Rent.js,Crimes.js,google.map...      1
# 4        sacastroc  js.org,.v,.min.js,bootstrap.min.css,theme.min....      1
# 5        pcberriop  google.maps.Map,document.getElementById,google...      1
# 6      hsmartineza  jquery.min.js,.js,info.js,document.getElementB...      1
# 7         Moimolcp  style.css,script.js,jquery.min.js,google.maps....      1
# 8       JoseMolano  document.getElementById,google.maps.Map,google...      1
# 9    maikellPardoA  document.getElementById,google.maps.Map,google...      1
# 10      NicolasZon  lml.jpg,google.maps.LatLng,google.maps.MapType...      1
# 11       camilo654  .floating,document.getElementById,google.maps....      1
# 12  CristianLozano  document.getElementById,google.maps.Map,google...      1
# 13       jdsuarezj  google.maps.Map,document.getElementById,google...      1
# 14       pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 15     juandavidro  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 16  UNhcrodriguezl  demos.css,bootstrap.min.css,style.css,map.gif,...      1
# 17     camilo13152  application.js,this.App,App.cable,ActionCable....      1
# 18    leavendanoro  styles.css,script.js,js.org,.v,.min.js,documen...      1
# 19      cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,goo...      1
# 20      capinillab  document.getElementById,google.maps.Map,google...      1
# 21    lfvalderrama  jquery.min.js,styles.css,init.js,.container,li...      1
# 22       bsgarciac  document.getElementsByClassName,x.length,.styl...      1
# 23      janoguerab  document.getElementById,google.maps.Map,google...      1
# 24     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      1
# 25      anmmunozme  main.css,bootstrap.min.css,jquery.min.js,boots...      1
# 26       fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      2
# 27       mnguzmanc  house.ico,style.css,map.js,Chicago.jpg,documen...      2
# 28      jmcuestasb  js.org,.v,.min.js,weather.js,mycss.css,bootstr...      2
# 29    jjrodriguezn  data.cityofchicago.org,rows.json,.ajax,google....      2
# 30           DglyP  google.maps.Map,document.getElementById,google...      2
# 31     Judgarciani  bootstrap.min.css,jquery.min.js,bootstrap.min....      2
# 32       sacastroc  js.org,.v,.min.js,collection.v,dispatch.v,dsv....      2
# 33       pcberriop  google.maps.Map,document.getElementById,google...      2
# 34     hsmartineza  jquery.min.js,.js,info.js,chicago.jpg,document...      2
# 35        Moimolcp  style.css,script.js,jquery.min.js,google.maps....      2
# 36     CamiloRueda  layout.css,shiv.js,document.getElementById,goo...      2
# 37      JoseMolano  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 38   maikellPardoA  document.getElementById,google.maps.Map,google...      2
# 39      NicolasZon  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2
# 40       camilo654  .ready,.click,.ajax,data.cityofchicago.org,row...      2
# 41  CristianLozano  document.getElementById,google.maps.Map,google...      2
# 42       jdsuarezj  google.maps.Map,document.getElementById,google...      2
# 43       pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 44     juandavidro  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 45  UNhcrodriguezl  demos.css,bootstrap.min.css,select.min.css,sty...      2
# 46     camilo13152  favicon.ico,fluidbox.min.css,main.css,google.m...      2
# 47    leavendanoro  styles.css,js.org,.v,.min.js,myArrayOfObjects....      2
# 48      cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,myJ...      2
# 49      capinillab  document.getElementById,google.maps.Map,google...      2
# 50    lfvalderrama  jquery.min.js,styles.css,init.js,test.js,.cont...      2
# 51       bsgarciac  document.getElementsByClassName,x.length,.styl...      2
# 52          gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2
# 53      janoguerab  js.org,.v,.min.js,document.getElementById,goog...      2
# 54     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      2
# 55      anmmunozme  .ready,.click,.ajax,data.cityofchicago.org,row...      2

# %%
phase23_bogota0 = overall_phase2_bogota0.append(overall_phase3_bogota0, ignore_index = True)
df_phase23_bogota0 = phase23_bogota0[['Student', 'functions', 'phase']]
df_phase23_bogota0
# Out:
#            Student                                          functions  phase
# 0        fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      2
# 1        mnguzmanc  house.ico,style.css,map.js,Chicago.jpg,documen...      2
# 2       jmcuestasb  js.org,.v,.min.js,weather.js,mycss.css,bootstr...      2
# 3     jjrodriguezn  data.cityofchicago.org,rows.json,.ajax,google....      2
# 4            DglyP  google.maps.Map,document.getElementById,google...      2
# 5      Judgarciani  bootstrap.min.css,jquery.min.js,bootstrap.min....      2
# 6        sacastroc  js.org,.v,.min.js,collection.v,dispatch.v,dsv....      2
# 7        pcberriop  google.maps.Map,document.getElementById,google...      2
# 8      hsmartineza  jquery.min.js,.js,info.js,chicago.jpg,document...      2
# 9         Moimolcp  style.css,script.js,jquery.min.js,google.maps....      2
# 10     CamiloRueda  layout.css,shiv.js,document.getElementById,goo...      2
# 11      JoseMolano  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 12   maikellPardoA  document.getElementById,google.maps.Map,google...      2
# 13      NicolasZon  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2
# 14       camilo654  .ready,.click,.ajax,data.cityofchicago.org,row...      2
# 15  CristianLozano  document.getElementById,google.maps.Map,google...      2
# 16       jdsuarezj  google.maps.Map,document.getElementById,google...      2
# 17       pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 18     juandavidro  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 19  UNhcrodriguezl  demos.css,bootstrap.min.css,select.min.css,sty...      2
# 20     camilo13152  favicon.ico,fluidbox.min.css,main.css,google.m...      2
# 21    leavendanoro  styles.css,js.org,.v,.min.js,myArrayOfObjects....      2
# 22      cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,myJ...      2
# 23      capinillab  document.getElementById,google.maps.Map,google...      2
# 24    lfvalderrama  jquery.min.js,styles.css,init.js,test.js,.cont...      2
# 25       bsgarciac  document.getElementsByClassName,x.length,.styl...      2
# 26          gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2
# 27      janoguerab  js.org,.v,.min.js,document.getElementById,goog...      2
# 28     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      2
# 29      anmmunozme  .ready,.click,.ajax,data.cityofchicago.org,row...      2
# 30       fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      3
# 31       mnguzmanc  house.ico,style.css,.css,main.js,map.js,weathe...      3
# 32      jmcuestasb  js.org,.v,.min.js,weather.js,mycss.css,bootstr...      3
# 33    jjrodriguezn  google.maps.Map,document.getElementById,google...      3
# 34           DglyP  google.maps.Map,document.getElementById,google...      3
# 35     Judgarciani  bootstrap.min.css,jquery.min.js,bootstrap.min....      3
# 36       sacastroc  js.org,.v,.min.js,collection.v,dispatch.v,dsv....      3
# 37       pcberriop  google.maps.Map,document.getElementById,google...      3
# 38     hsmartineza  jquery.min.js,.js,map.js,info.js,test.js,chica...      3
# 39        Moimolcp  bootstrap.min.css,style.css,script.js,jquery.m...      3
# 40     CamiloRueda  layout.css,shiv.js,document.getElementById,goo...      3
# 41      JoseMolano  bootstrap.min.css,theme.min.css,jquery.min.js,...      3
# 42   maikellPardoA  document.getElementById,google.maps.Map,google...      3
# 43      NicolasZon  google.maps.LatLng,google.maps.MapTypeId.ROADM...      3
# 44       camilo654  .ready,.click,.ajax,data.cityofchicago.org,row...      3
# 45  CristianLozano  document.getElementById,google.maps.Map,google...      3
# 46       jdsuarezj  google.maps.Map,document.getElementById,google...      3
# 47       pipemax85  bootstrap.min.css,theme.min.css,jquery.min.js,...      3
# 48     juandavidro  styles.css,script.js,bootstrap.min.css,sites.j...      3
# 49  UNhcrodriguezl  demos.css,bootstrap.min.css,select.min.css,sty...      3
# 50     camilo13152  mapController.js,favicon.ico,fluidbox.min.css,...      3
# 51    leavendanoro  styles.css,js.org,.v,.min.js,script.js,documen...      3
# 52      cdcordobaa  bootstrap.min.css,main.css,.org,.js,map.js,myJ...      3
# 53      capinillab  document.getElementById,google.maps.Map,google...      3
# 54    lfvalderrama  jquery.min.js,styles.css,init.js,handler.js,se...      3
# 55       bsgarciac  document.getElementsByClassName,x.length,.styl...      3
# 56          gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      3
# 57      janoguerab  js.org,.v,.min.js,document.getElementById,goog...      3
# 58     djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      3
# 59      anmmunozme  .ready,.click,.ajax,data.cityofchicago.org,row...      3

# %%
phase34_bogota0 = overall_phase3_bogota0.append(overall_phase4_bogota0, ignore_index = True)
df_phase34_bogota0 = phase34_bogota0[['Student', 'functions', 'phase']]
df_phase34_bogota0
# Out:
#          Student                                          functions  phase
# 0      fffeelipe  .ready,.click,.mcheck,.on,.closest,.list,.find...      3
# 1      mnguzmanc  house.ico,style.css,.css,main.js,map.js,weathe...      3
# 2     jmcuestasb  js.org,.v,.min.js,weather.js,mycss.css,bootstr...      3
# 3   jjrodriguezn  google.maps.Map,document.getElementById,google...      3
# 4          DglyP  google.maps.Map,document.getElementById,google...      3
# ..           ...                                                ...    ...
# 56     bsgarciac  document.getElementsByClassName,x.length,.styl...      4
# 57        gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      4
# 58    janoguerab  js.org,.v,.min.js,document.getElementById,goog...      4
# 59   djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      4
# 60    anmmunozme  .ajax,data.cityofchicago.org,iimk.json,.done,d...      4
#
# [61 rows x 3 columns]

# %%
phase45_bogota0 = overall_phase4_bogota0.append(overall_phase5_bogota0, ignore_index = True)
df_phase45_bogota0 = phase45_bogota0[['Student', 'functions', 'phase']]
df_phase45_bogota0
# Out:
#          Student                                          functions  phase
# 0      fffeelipe  .ready,.click,.removeClass,.is,.val,.check,.on...      4
# 1      mnguzmanc  house.ico,style.css,.css,main.js,map.js,weathe...      4
# 2     jmcuestasb  js.org,.v,.min.js,weather.js,mycss.css,bootstr...      4
# 3     katherinsb  reset.css,layout.css,style.css,.js,yui.js,repl...      4
# 4   jjrodriguezn  google.maps.Map,document.getElementById,google...      4
# ..           ...                                                ...    ...
# 57     bsgarciac  document.getElementsByClassName,x.length,.styl...      5
# 58        gabi04  google.maps.LatLng,google.maps.MapTypeId.ROADM...      5
# 59    janoguerab  js.org,.v,.min.js,document.getElementById,goog...      5
# 60   djsanabriac  bootstrap.min.css,main.js,jquery.min.js,docume...      5
# 61    anmmunozme  .ajax,data.cityofchicago.org,iimk.json,.done,d...      5
#
# [62 rows x 3 columns]

# %%
phase15_bogota1 = overall_phase1_bogota1.append(overall_phase5_bogota1, ignore_index = True)
df_phase15_bogota1 = phase15_bogota1[['Student', 'functions', 'phase']]
df_phase15_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      1
# 1     adamantwharf  document.getElementById,google.maps.Map,google...      1
# 2        bdcajicam  google.maps.Map,document.getElementById,google...      1
# 3        helmeraac  styles.css,scripts.js,integration.js,google.ma...      1
# 4       dasalgadob  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# ..             ...                                                ...    ...
# 64       jsviveroj  .css,bootstrap.min.css,freelancer.min.css,styl...      5
# 65      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      5
# 66        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      5
# 67  joahernandezca  document.getElementById,google.maps.Map,google...      5
# 68    JairVillalba  fH.css,jquery.min.js,.js,call.js,climate.js,th...      5
#
# [69 rows x 3 columns]

# %%
phase12_bogota1 = overall_phase1_bogota1.append(overall_phase2_bogota1, ignore_index = True)
df_phase12_bogota1 = phase12_bogota1[['Student', 'functions', 'phase']]
df_phase12_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      1
# 1     adamantwharf  document.getElementById,google.maps.Map,google...      1
# 2        bdcajicam  google.maps.Map,document.getElementById,google...      1
# 3        helmeraac  styles.css,scripts.js,integration.js,google.ma...      1
# 4       dasalgadob  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# ..             ...                                                ...    ...
# 65       jsviveroj  bootstrap.min.css,freelancer.min.css,style.css...      2
# 66      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      2
# 67        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      2
# 68  joahernandezca  document.getElementById,google.maps.Map,google...      2
# 69    JairVillalba  fH.css,call.js,jquery.min.js,.js,this.id,docum...      2
#
# [70 rows x 3 columns]

# %%
phase23_bogota1 = overall_phase2_bogota1.append(overall_phase3_bogota1, ignore_index = True)
df_phase23_bogota1 = phase23_bogota1[['Student', 'functions', 'phase']]
df_phase23_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      2
# 1     adamantwharf  document.getElementById,google.maps.Map,google...      2
# 2        bdcajicam  google.maps.Map,document.getElementById,google...      2
# 3      dfhincapiem  main.js,google.maps.Map,document.getElementByI...      2
# 4        helmeraac  styles.css,jquery.min.js,scripts.js,integratio...      2
# ..             ...                                                ...    ...
# 69       jsviveroj  bootstrap.min.css,freelancer.min.css,style.css...      3
# 70      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      3
# 71        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      3
# 72  joahernandezca  document.getElementById,google.maps.Map,google...      3
# 73    JairVillalba  fH.css,call.js,jquery.min.js,.js,this.id,docum...      3
#
# [74 rows x 3 columns]

# %%
phase34_bogota1 = overall_phase3_bogota1.append(overall_phase4_bogota1, ignore_index = True)
df_phase34_bogota1 = phase34_bogota1[['Student', 'functions', 'phase']]
df_phase34_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      3
# 1     adamantwharf  document.getElementById,google.maps.Map,google...      3
# 2        bdcajicam  nearium.css,.js,nearium.js,google.maps.Map,doc...      3
# 3      dfhincapiem  main.js,google.maps.Map,document.getElementByI...      3
# 4        helmeraac  styles.css,jquery.min.js,scripts.js,integratio...      3
# ..             ...                                                ...    ...
# 69       jsviveroj  .css,bootstrap.min.css,freelancer.min.css,styl...      4
# 70      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      4
# 71        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      4
# 72  joahernandezca  document.getElementById,google.maps.Map,google...      4
# 73    JairVillalba  fH.css,jquery.min.js,.js,call.js,climate.js,th...      4
#
# [74 rows x 3 columns]

# %%
phase45_bogota1 = overall_phase4_bogota1.append(overall_phase5_bogota1, ignore_index = True)
df_phase45_bogota1 = phase45_bogota1[['Student', 'functions', 'phase']]
df_phase45_bogota1
# Out:
#            Student                                          functions  phase
# 0        gasierram  illinois.edu,favicon.ico,bootstrap.min.css,awe...      4
# 1     adamantwharf  document.getElementById,google.maps.Map,google...      4
# 2        bdcajicam  nearium.css,.js,nearium.js,google.maps.Map,doc...      4
# 3      dfhincapiem  main.js,google.maps.Map,document.getElementByI...      4
# 4        helmeraac  styles.css,jquery.min.js,integration.js,script...      4
# ..             ...                                                ...    ...
# 68       jsviveroj  .css,bootstrap.min.css,freelancer.min.css,styl...      5
# 69      daandradec  styles.css,bootstrap.min.css,jquery.min.js,boo...      5
# 70        jcrubioa  bootstrap.min.css,awesome.min.css,animate.css,...      5
# 71  joahernandezca  document.getElementById,google.maps.Map,google...      5
# 72    JairVillalba  fH.css,jquery.min.js,.js,call.js,climate.js,th...      5
#
# [73 rows x 3 columns]

# %%
phase12_bogota2 = overall_phase1_bogota2.append(overall_phase2_bogota2, ignore_index = True)
df_phase12_bogota2 = phase12_bogota2[['Student', 'functions', 'phase']]
df_phase12_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  bootstrap.min.css,portfolio.css,awesome.min.cs...      1
# 1        bdvegat  cs.css,document.getElementById,google.maps.Map...      1
# 2     Phoenixest  a.active,.active,document.getElementById,googl...      1
# 3       HashNick  jquery.min.js,bootstrap.min.js,.js,js.org,.v,....      1
# 4     joaortizro  bootstrap.min.css,theme.min.css,bootstrap.min....      1
# ..           ...                                                ...    ...
# 68  luealfonsoru  bootstrap.min.css,freelancer.css,custom.css,cu...      2
# 69      oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      2
# 70      lsfinite  .css,awesome.min.css,latest.min.js,room.js,.w,...      2
# 71     xdanielsb  .ajax,.done,console.log,.fail,data.cityofchica...      2
# 72  jscontrerasp  google.maps.LatLng,google.maps.MapTypeId.ROADM...      2
#
# [73 rows x 3 columns]

# %%
phase23_bogota2 = overall_phase2_bogota2.append(overall_phase3_bogota2, ignore_index = True)
df_phase23_bogota2 = phase23_bogota2[['Student', 'functions', 'phase']]
df_phase23_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  bootstrap.min.css,portfolio.css,awesome.min.cs...      2
# 1        bdvegat  cs.css,document.getElementById,google.maps.Map...      2
# 2     Phoenixest  a.active,.active,document.getElementById,googl...      2
# 3       HashNick  jquery.min.js,tutorial.js,bootstrap.min.js,doc...      2
# 4     joaortizro  document.getElementById,google.maps.Map,bootst...      2
# ..           ...                                                ...    ...
# 69  luealfonsoru  bootstrap.min.css,freelancer.css,custom.css,cu...      3
# 70      oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      3
# 71      lsfinite  .css,awesome.min.css,latest.min.js,room.js,sho...      3
# 72     xdanielsb  console.log,jQuery.parseJSON,.ajax,.done,.fail...      3
# 73  jscontrerasp  latest.min.js,google.maps.LatLng,google.maps.M...      3
#
# [74 rows x 3 columns]

# %%
phase34_bogota2 = overall_phase3_bogota2.append(overall_phase4_bogota2, ignore_index = True)
df_phase34_bogota2 = phase34_bogota2[['Student', 'functions', 'phase']]
df_phase34_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  js.org,.v,.min.js,bootstrap.min.css,portfolio....      3
# 1        bdvegat  js.org,.v,.js,bootstrap.min.css,bootstrap.min....      3
# 2     Phoenixest  a.active,.active,document.getElementById,googl...      3
# 3       HashNick  jquery.min.js,tutorial.js,bootstrap.min.js,doc...      3
# 4     joaortizro  document.getElementById,google.maps.Map,bootst...      3
# ..           ...                                                ...    ...
# 70  luealfonsoru  bootstrap.min.css,balloon.min.css,freelancer.c...      4
# 71      oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      4
# 72      lsfinite  .css,awesome.min.css,latest.min.js,room.js,sho...      4
# 73     xdanielsb  console.log,jQuery.parseJSON,.ajax,.done,.fail...      4
# 74  jscontrerasp  latest.min.js,google.maps.LatLng,google.maps.M...      4
#
# [75 rows x 3 columns]

# %%
phase45_bogota2 = overall_phase4_bogota2.append(overall_phase5_bogota2, ignore_index = True)
df_phase45_bogota2 = phase45_bogota2[['Student', 'functions', 'phase']]
df_phase45_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  js.org,.v,.min.js,bootstrap.min.css,portfolio....      4
# 1        bdvegat  js.org,.v,.js,bootstrap.min.css,bootstrap.min....      4
# 2     Phoenixest  a.active,.active,document.getElementById,googl...      4
# 3       HashNick  jquery.min.js,bootstrap.min.js,.js,js.org,.v,....      4
# 4        ccvacad  bootstrap.min.css,jquery.min.js,bootstrap.min....      4
# ..           ...                                                ...    ...
# 71  luealfonsoru  bootstrap.min.css,balloon.min.css,freelancer.c...      5
# 72      oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 73      lsfinite  .css,awesome.min.css,latest.min.js,room.js,sho...      5
# 74     xdanielsb  console.log,jQuery.parseJSON,.ajax,.done,.fail...      5
# 75  jscontrerasp  latest.min.js,google.maps.LatLng,google.maps.M...      5
#
# [76 rows x 3 columns]

# %%
phase15_bogota2 = overall_phase1_bogota2.append(overall_phase5_bogota2, ignore_index = True)
df_phase15_bogota2 = phase15_bogota2[['Student', 'functions', 'phase']]
df_phase15_bogota2
# Out:
#          Student                                          functions  phase
# 0   jusherrerama  bootstrap.min.css,portfolio.css,awesome.min.cs...      1
# 1        bdvegat  cs.css,document.getElementById,google.maps.Map...      1
# 2     Phoenixest  a.active,.active,document.getElementById,googl...      1
# 3       HashNick  jquery.min.js,bootstrap.min.js,.js,js.org,.v,....      1
# 4     joaortizro  bootstrap.min.css,theme.min.css,bootstrap.min....      1
# ..           ...                                                ...    ...
# 69  luealfonsoru  bootstrap.min.css,balloon.min.css,freelancer.c...      5
# 70      oserasoa  bootstrap.min.css,theme.min.css,jquery.min.js,...      5
# 71      lsfinite  .css,awesome.min.css,latest.min.js,room.js,sho...      5
# 72     xdanielsb  console.log,jQuery.parseJSON,.ajax,.done,.fail...      5
# 73  jscontrerasp  latest.min.js,google.maps.LatLng,google.maps.M...      5
#
# [74 rows x 3 columns]

# %% [markdown]
# ## Comparing Phase 4 and Phase 5 Bogota 3

# %%
overall_phase5_bogota3['phase'] = 5
overall_phase5_bogota3
overall_phase5_bogota3[['Student', 'functions', 'phase']]
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/1059781046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_bogota3['phase'] = 5
#              Student                                          functions  phase
# 123        lemartinp  google.maps.Map,document.getElementById,google...      5
# 124        juligarji  jquery.min.js,bootstrap.min.css,awesome.min.cs...      5
# 125        nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      5
# 126        AFelipeGA  materialize.min.css,style.css,awesome.min.css,...      5
# 127       mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      5
# 128         dduartec  .js,style.css,superplaceholder.js,superplaceho...      5
# 129        srmedinac  .create,package.json,pkg.title,pkg.version,pkg...      5
# 130     wilson911013  .js,jsInitMap.js,.ajax,module.exports,options....      5
# 131    wapiravaguens  .css,.js,js.org,.v,bootstrap.min.css,theme.min...      5
# 132         davidh17  bootstrap.min.css,styles.css,jquery.min.js,boo...      5
# 133   DianaNavarrete  .l,morado.jpg,a.active,.active,google.maps.Map...      5
# 134        jdmonroyg  .mifecha,bootstrap.min.css,theme.min.css,jquer...      5
# 135        jorge52an  main.css,material.min.css,angular.min.js,angul...      5
# 136  jscastelblancoh  bootstrap.min.css,theme.min.css,style.css,hove...      5
# 137       juclopezso  bootstrap.min.css,portfolio.css,awesome.min.cs...      5
# 138        afforeroc  bootstrap.min.css,uic.edu,.js,bootstrap.min.js...      5
# 139      dagofonseca  styles.css,jquery.min.js,map.js,markerclustere...      5
# 140      lacardenasv  materialize.css,materialize.min.css,styleSearc...      5
# 141      oacastillol  bootstrap.min.css,theme.min.css,awesome.min.cs...      5
# 142       ncampuzano  bootstrap.min.css,awesome.min.css,app.css,jque...      5
# 143         adriel62  favicon.ico,.min.js,bootstrap.min.js,applicati...      5
# 144         capinzor  bootstrap.min.css,estilos.css,.min.js,bootstra...      5
# 145         ofnanezn  .create,package.json,pkg.title,pkg.version,pkg...      5
# 146        macuestap  style.css,favicon.ico,bootstrap.min.css,theme....      5
# 147           spenas  bootstrap.min.css,mdb.min.css,demos.css,styles...      5
# 148      kgbayala528  latest.min.js,jquery.min.js,bootstrap.min.css,...      5
# 149       lgmoralesa  bootstrap.min.css,index.css,criteria.css,jquer...      5
# 150       ronaldsg20  ownStyle.css,theme.min.css,bootstrap.min.css,m...      5
# 151    cccristanchoc  unal.edu.co,bootstrap.min.css,template.css,dat...      5
# 152       jmalvarezd  jmalvarezd.js,bootstrap.min.css,jquery.min.js,...      5
# 153        smarquezo  bootstrap.min.css,data.json,jquery.min.js,boot...      5
# 154          sarizag  js.org,.v,.min.js,style.css,jquery.min.js,scri...      5
# 155         Chranium  style.css,main.js,document.getElementById,goog...      5
# 156          DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      5
# 157      afceballosr  bootstrap.min.css,style.css,bulk.jpg,jquery.mi...      5
# 158        lizzyt10h  bootstrap.min.css,jquery.min.js,.min.css,this....      5
# 159       NicolasPrr  jquery.min.js,bootstrap.min.css,stylesLoginf.c...      5
# 160    jumcorredorro  jquery.min.js,bootstrap.min.js,.js,script.js,m...      5

# %%
overall_phase4_bogota3['phase'] = 4
overall_phase4_bogota3
overall_phase4_bogota3[['Student', 'functions', 'phase']]
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/1857560765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_bogota3['phase'] = 4
#              Student                                          functions  phase
# 123        lemartinp  google.maps.Map,document.getElementById,google...      4
# 124        juligarji  jquery.min.js,bootstrap.min.css,awesome.min.cs...      4
# 125        nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      4
# 126        AFelipeGA  materialize.min.css,style.css,awesome.min.css,...      4
# 127       mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      4
# 128         dduartec  .js,style.css,superplaceholder.js,superplaceho...      4
# 129        srmedinac  .create,package.json,pkg.title,pkg.version,pkg...      4
# 130     wilson911013  .js,jsInitMap.js,.ajax,module.exports,options....      4
# 131    wapiravaguens  .css,.js,js.org,.v,bootstrap.min.css,theme.min...      4
# 132         davidh17  bootstrap.min.css,styles.css,jquery.min.js,boo...      4
# 133   DianaNavarrete  .l,morado.jpg,a.active,.active,google.maps.Map...      4
# 135        jorge52an  main.css,material.min.css,angular.min.js,angul...      4
# 136  jscastelblancoh  bootstrap.min.css,theme.min.css,style.css,hove...      4
# 137       juclopezso  bootstrap.min.css,portfolio.css,awesome.min.cs...      4
# 138        afforeroc  bootstrap.min.css,uic.edu,.js,bootstrap.min.js...      4
# 139      dagofonseca  styles.css,jquery.min.js,map.js,markerclustere...      4
# 140      lacardenasv  materialize.css,materialize.min.css,styleSearc...      4
# 141      oacastillol  bootstrap.min.css,theme.min.css,awesome.min.cs...      4
# 142       ncampuzano  bootstrap.min.css,awesome.min.css,app.css,jque...      4
# 143         adriel62  favicon.ico,.min.js,bootstrap.min.js,applicati...      4
# 144         capinzor  bootstrap.min.css,estilos.css,.min.js,bootstra...      4
# 145         ofnanezn  .create,package.json,pkg.title,pkg.version,pkg...      4
# 146        macuestap  style.css,favicon.ico,bootstrap.min.css,theme....      4
# 147           spenas  bootstrap.min.css,mdb.min.css,demos.css,styles...      4
# 148      kgbayala528  latest.min.js,jquery.min.js,bootstrap.min.css,...      4
# 149       lgmoralesa  bootstrap.min.css,jquery.min.js,javascript.js,...      4
# 150       ronaldsg20  icons.css,ownStyle.css,theme.min.css,bootstrap...      4
# 151    cccristanchoc  unal.edu.co,bootstrap.min.css,template.css,dat...      4
# 152       jmalvarezd  jmalvarezd.js,bootstrap.min.css,jquery.min.js,...      4
# 153        smarquezo  bootstrap.min.css,jquery.min.js,bootstrap.min....      4
# 154          sarizag  js.org,.v,.min.js,style.css,jquery.min.js,boot...      4
# 155         Chranium  style.css,main.js,document.getElementById,goog...      4
# 156          DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      4
# 157      afceballosr  bootstrap.min.css,style.css,bulk.jpg,jquery.mi...      4
# 158        lizzyt10h  bootstrap.min.css,jquery.min.js,index.css,jsIn...      4
# 159       NicolasPrr  bootstrap.min.css,jquery.min.js,bootstrap.min....      4
# 160    jumcorredorro  jquery.min.js,bootstrap.min.js,.js,script.js,m...      4

# %%
import numpy as np
overall_phase3_bogota3['phase'] = 3
overall_phase3_bogota3['functions'].replace('', np.nan, inplace=True)
overall_phase3_bogota3.dropna(subset=['functions'], inplace=True)
subset_bogota3_phase3 = overall_phase3_bogota3[['Student', 'functions', 'phase']]
subset_bogota3_phase3
# Out:
#              Student                                          functions  phase
# 123        lemartinp  google.maps.Map,document.getElementById,google...      3
# 124        juligarji  jquery.min.js,bootstrap.min.css,awesome.min.cs...      3
# 125        nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      3
# 126        AFelipeGA  materialize.min.css,style.css,awesome.min.css,...      3
# 127       mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      3
# 128         dduartec  .js,style.css,superplaceholder.js,superplaceho...      3
# 129        srmedinac  .create,package.json,pkg.title,pkg.version,pkg...      3
# 130     wilson911013  module.exports,options.key,options.clientId,op...      3
# 131    wapiravaguens  .css,.js,js.org,.v,bootstrap.min.css,theme.min...      3
# 132         davidh17  bootstrap.min.css,styles.css,theme.min.css,jqu...      3
# 133   DianaNavarrete  .l,morado.jpg,a.active,.active,google.maps.Map...      3
# 135        jorge52an  main.css,material.min.css,angular.min.js,angul...      3
# 136  jscastelblancoh  bootstrap.min.css,theme.min.css,style.css,hove...      3
# 137       juclopezso  bootstrap.min.css,portfolio.css,awesome.min.cs...      3
# 138        afforeroc  bootstrap.min.css,uic.edu,.js,bootstrap.min.js...      3
# 139      dagofonseca  styles.css,jquery.min.js,map.js,markerclustere...      3
# 140      lacardenasv  awesome.min.css,bootstrap.min.css,materialize....      3
# 141      oacastillol  bootstrap.min.css,theme.min.css,awesome.min.cs...      3
# 142       ncampuzano  bootstrap.min.css,awesome.min.css,app.css,jque...      3
# 143         adriel62  favicon.ico,bootstrap.min.js,.min.js,applicati...      3
# 144         capinzor  bootstrap.min.css,estilos.css,.min.js,bootstra...      3
# 145         ofnanezn  .create,package.json,pkg.title,pkg.version,pkg...      3
# 146        macuestap  style.css,favicon.ico,bootstrap.min.css,theme....      3
# 147           spenas  bootstrap.min.css,mdb.min.css,demos.css,styles...      3
# 148      kgbayala528  latest.min.js,jquery.min.js,bootstrap.min.css,...      3
# 149       lgmoralesa  bootstrap.min.css,jquery.min.js,javascript.js,...      3
# 150       ronaldsg20  .ready,.ajax,console.log,data.results,google.m...      3
# 151    cccristanchoc  unal.edu.co,bootstrap.min.css,template.css,dat...      3
# 152       jmalvarezd  jmalvarezd.js,bootstrap.min.css,jquery.min.js,...      3
# 153        smarquezo  page.php,google.maps.Map,document.getElementBy...      3
# 154          sarizag  js.org,.v,.min.js,style.css,jquery.min.js,boot...      3
# 155         Chranium  style.css,main.js,document.getElementById,goog...      3
# 156          DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      3
# 157      afceballosr  bootstrap.min.css,style.css,farmermarket.style...      3
# 158        lizzyt10h  bootstrap.min.css,jquery.min.js,index.css,jsIn...      3
# 159       NicolasPrr  bootstrap.min.css,jquery.min.js,bootstrap.min....      3
# 160    jumcorredorro  jquery.min.js,bootstrap.min.js,tutorial.css,.j...      3

# %%
overall_phase2_bogota3['phase'] = 2
overall_phase2_bogota3
overall_phase2_bogota3[['Student', 'functions', 'phase']]
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/409680276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_bogota3['phase'] = 2
#              Student                                          functions  phase
# 123        lemartinp  google.maps.Map,document.getElementById,google...      2
# 124        juligarji  jquery.min.js,bootstrap.min.css,bootstrap.min....      2
# 125        nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      2
# 126        AFelipeGA  materialize.min.css,style.css,awesome.min.css,...      2
# 127       mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      2
# 128         dduartec  style.css,map.js,weather.js,api.openweathermap...      2
# 129        srmedinac  .create,package.json,pkg.title,pkg.version,pkg...      2
# 130     wilson911013  module.exports,options.key,options.clientId,op...      2
# 131    wapiravaguens  .css,.js,js.org,.v,bootstrap.min.css,theme.min...      2
# 132         davidh17  bootstrap.min.css,styles.css,theme.min.css,jqu...      2
# 133   DianaNavarrete  .l,morado.jpg,a.active,.active,google.maps.Map...      2
# 135        jorge52an  main.css,material.min.css,angular.min.js,angul...      2
# 136  jscastelblancoh  bootstrap.min.css,theme.min.css,style.css,.js,...      2
# 137       juclopezso  bootstrap.min.css,portfolio.css,awesome.min.cs...      2
# 138        afforeroc  bootstrap.min.css,uic.edu,.js,bootstrap.min.js...      2
# 139      dagofonseca  styles.css,loadUpData.js,map.js,google.maps.La...      2
# 140      lacardenasv  awesome.min.css,bootstrap.min.css,materialize....      2
# 141      oacastillol  bootstrap.min.css,theme.min.css,awesome.min.cs...      2
# 142       ncampuzano  .ajax,data.cityofchicago.org,j.json,.done,data...      2
# 143         adriel62  favicon.ico,bootstrap.min.js,.min.js,applicati...      2
# 144         capinzor  bootstrap.min.css,estilos.css,maps.js,.min.js,...      2
# 145         ofnanezn  .create,package.json,pkg.title,pkg.version,pkg...      2
# 146        macuestap  style.css,favicon.ico,bootstrap.min.css,theme....      2
# 147           spenas  bootstrap.min.css,mdb.min.css,demos.css,styles...      2
# 148      kgbayala528  bootstrap.min.css,dashboard.css,styles.css,mat...      2
# 149       lgmoralesa  bootstrap.min.css,jquery.min.js,javascript.js,...      2
# 150       ronaldsg20  google.maps.Map,document.getElementById,google...      2
# 151    cccristanchoc  unal.edu.co,bootstrap.min.css,template.css,dat...      2
# 152       jmalvarezd  jmalvarezd.js,bootstrap.min.css,jquery.min.js,...      2
# 153        smarquezo  page.php,google.maps.Map,document.getElementBy...      2
# 154          sarizag  js.org,.v,.min.js,style.css,jquery.min.js,boot...      2
# 155         Chranium  style.css,main.js,document.getElementById,goog...      2
# 156          DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      2
# 157      afceballosr  bootstrap.min.css,style.css,farmermarket.style...      2
# 158        lizzyt10h  .js,jsInitMap.js,document.getElementById,googl...      2
# 159       NicolasPrr  bootstrap.min.css,jquery.min.js,bootstrap.min....      2
# 160    jumcorredorro  script.js,jquery.min.js,bootstrap.min.js,tutor...      2

# %%
import numpy as np
overall_phase1_bogota3['phase'] = 1
overall_phase1_bogota3['functions'].replace('', np.nan, inplace=True)
overall_phase1_bogota3.dropna(subset=['functions'], inplace=True)
subset_bogota3_phase1 = overall_phase1_bogota3[['Student', 'functions', 'phase']]
subset_bogota3_phase1
# Out:
#              Student                                          functions  phase
# 123        lemartinp  bootstrap.min.css,style.css,unal.edu.co,.navba...      1
# 124        juligarji  mainPage.css,resetStyle.css,jquery.min.js,mapF...      1
# 125        nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      1
# 126        AFelipeGA  eslint.org,module.exports,RULES.md,.vue,proces...      1
# 127       mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      1
# 128         dduartec  style.css,map.js,weather.js,api.openweathermap...      1
# 129        srmedinac  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 131    wapiravaguens  .css,.js,js.org,.v,bootstrap.min.css,theme.min...      1
# 132         davidh17  bootstrap.min.css,styles.css,theme.min.css,jqu...      1
# 133   DianaNavarrete  .l,.active,plupa.jpg,lupa.jpg,google.maps.Map,...      1
# 134        jdmonroyg                                         style.css,      1
# 135        jorge52an  main.css,angular.min.js,app.js,mainController....      1
# 136  jscastelblancoh  bootstrap.min.css,theme.min.css,style.css,load...      1
# 137       juclopezso  bootstrap.min.css,portfolio.css,awesome.min.cs...      1
# 138        afforeroc  bootstrap.min.css,uic.edu,.js,bootstrap.min.js...      1
# 139      dagofonseca  styles.css,loadUpData.js,map.js,google.maps.La...      1
# 140      lacardenasv  .ready,.getJSON,data.cityofchicago.org,iimk.js...      1
# 141      oacastillol  bootstrap.min.css,theme.min.css,Aux.css,map.js...      1
# 142       ncampuzano  jquery.min.js,google.maps.Map,document.getElem...      1
# 143         adriel62  favicon.ico,bootstrap.min.js,.min.js,applicati...      1
# 144         capinzor  bootstrap.min.css,estilos.css,maps.js,.min.js,...      1
# 145         ofnanezn  .create,package.json,pkg.title,pkg.version,pkg...      1
# 146        macuestap  runner.github.io,module.exports,config.set,tes...      1
# 147           spenas  bootstrap.min.css,demos.css,.jumbotron,.fluid,...      1
# 148      kgbayala528  bootstrap.min.css,dashboard.css,styles.css,mat...      1
# 149       lgmoralesa  .css,.bgimg,bootstrap.min.css,jquery.min.js,da...      1
# 150       ronaldsg20  google.maps.Map,document.getElementById,google...      1
# 151    cccristanchoc  unal.edu.co,bootstrap.min.css,template.css,war...      1
# 152       jmalvarezd  jmalvarezd.js,jquery.min.js,bootstrap.min.css,...      1
# 153        smarquezo           google.maps.Map,document.getElementById,      1
# 154          sarizag  js.org,.v,.min.js,style.css,google.maps.Map,do...      1
# 155         Chranium  style.css,main.js,document.getElementById,goog...      1
# 156          DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      1
# 157      afceballosr  bootstrap.min.css,style.css,jquery.min.js,boot...      1
# 158        lizzyt10h  bootstrap.min.css,theme.min.css,jquery.min.js,...      1
# 159       NicolasPrr  bootstrap.min.css,jquery.min.js,bootstrap.min....      1
# 160    jumcorredorro  script.js,jquery.min.js,bootstrap.min.js,tutor...      1

# %%
phase12 = subset_bogota3_phase1.append(overall_phase2_bogota3, ignore_index = True)
df_phase12 = phase12[['Student', 'functions', 'phase']]
df_phase12
# Out:
#           Student                                          functions  phase
# 0       lemartinp  bootstrap.min.css,style.css,unal.edu.co,.navba...      1
# 1       juligarji  mainPage.css,resetStyle.css,jquery.min.js,mapF...      1
# 2       nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      1
# 3       AFelipeGA  eslint.org,module.exports,RULES.md,.vue,proces...      1
# 4      mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      1
# ..            ...                                                ...    ...
# 69        DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      2
# 70    afceballosr  bootstrap.min.css,style.css,farmermarket.style...      2
# 71      lizzyt10h  .js,jsInitMap.js,document.getElementById,googl...      2
# 72     NicolasPrr  bootstrap.min.css,jquery.min.js,bootstrap.min....      2
# 73  jumcorredorro  script.js,jquery.min.js,bootstrap.min.js,tutor...      2
#
# [74 rows x 3 columns]

# %%
phase23 = overall_phase2_bogota3.append(subset_bogota3_phase3, ignore_index = True)
df_phase23 = phase23[['Student', 'functions', 'phase']]
df_phase23
# Out:
#           Student                                          functions  phase
# 0       lemartinp  google.maps.Map,document.getElementById,google...      2
# 1       juligarji  jquery.min.js,bootstrap.min.css,bootstrap.min....      2
# 2       nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      2
# 3       AFelipeGA  materialize.min.css,style.css,awesome.min.css,...      2
# 4      mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      2
# ..            ...                                                ...    ...
# 69        DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      3
# 70    afceballosr  bootstrap.min.css,style.css,farmermarket.style...      3
# 71      lizzyt10h  bootstrap.min.css,jquery.min.js,index.css,jsIn...      3
# 72     NicolasPrr  bootstrap.min.css,jquery.min.js,bootstrap.min....      3
# 73  jumcorredorro  jquery.min.js,bootstrap.min.js,tutorial.css,.j...      3
#
# [74 rows x 3 columns]

# %%
phase34 = subset_bogota3_phase3.append(overall_phase4_bogota3, ignore_index = True)
df_phase34 = phase34[['Student', 'functions', 'phase']]
df_phase34
# Out:
#           Student                                          functions  phase
# 0       lemartinp  google.maps.Map,document.getElementById,google...      3
# 1       juligarji  jquery.min.js,bootstrap.min.css,awesome.min.cs...      3
# 2       nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      3
# 3       AFelipeGA  materialize.min.css,style.css,awesome.min.css,...      3
# 4      mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      3
# ..            ...                                                ...    ...
# 69        DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      4
# 70    afceballosr  bootstrap.min.css,style.css,bulk.jpg,jquery.mi...      4
# 71      lizzyt10h  bootstrap.min.css,jquery.min.js,index.css,jsIn...      4
# 72     NicolasPrr  bootstrap.min.css,jquery.min.js,bootstrap.min....      4
# 73  jumcorredorro  jquery.min.js,bootstrap.min.js,.js,script.js,m...      4
#
# [74 rows x 3 columns]

# %%
phase45 = overall_phase4_bogota3.append(overall_phase5_bogota3, ignore_index = True)
df_phase45 = phase45[['Student', 'functions', 'phase']]
df_phase45
# Out:
#           Student                                          functions  phase
# 0       lemartinp  google.maps.Map,document.getElementById,google...      4
# 1       juligarji  jquery.min.js,bootstrap.min.css,awesome.min.cs...      4
# 2       nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      4
# 3       AFelipeGA  materialize.min.css,style.css,awesome.min.css,...      4
# 4      mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      4
# ..            ...                                                ...    ...
# 70        DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      5
# 71    afceballosr  bootstrap.min.css,style.css,bulk.jpg,jquery.mi...      5
# 72      lizzyt10h  bootstrap.min.css,jquery.min.js,.min.css,this....      5
# 73     NicolasPrr  jquery.min.js,bootstrap.min.css,stylesLoginf.c...      5
# 74  jumcorredorro  jquery.min.js,bootstrap.min.js,.js,script.js,m...      5
#
# [75 rows x 3 columns]

# %%
phase15 = overall_phase1_bogota3.append(overall_phase5_bogota3, ignore_index = True)
df_phase15 = phase15[['Student', 'functions', 'phase']]
df_phase15
# Out:
#           Student                                          functions  phase
# 0       lemartinp  bootstrap.min.css,style.css,unal.edu.co,.navba...      1
# 1       juligarji  mainPage.css,resetStyle.css,jquery.min.js,mapF...      1
# 2       nfmorenog  FirstLook.css,bootstrap.min.css,jquery.min.js,...      1
# 3       AFelipeGA  eslint.org,module.exports,RULES.md,.vue,proces...      1
# 4      mballeng91  .bin,e.g,protractor.config.js,exports.config,s...      1
# ..            ...                                                ...    ...
# 70        DavidQP  bootstrap.min.css,Respond.js,shiv.min.js,respo...      5
# 71    afceballosr  bootstrap.min.css,style.css,bulk.jpg,jquery.mi...      5
# 72      lizzyt10h  bootstrap.min.css,jquery.min.js,.min.css,this....      5
# 73     NicolasPrr  jquery.min.js,bootstrap.min.css,stylesLoginf.c...      5
# 74  jumcorredorro  jquery.min.js,bootstrap.min.js,.js,script.js,m...      5
#
# [75 rows x 3 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase15_bogota0["functions"], df_phase15_bogota0["Student"], df_phase15_bogota0["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df0_bogota0 = pd.DataFrame(result)
df0_bogota0
# Out:
#             user1        user2  user1_phase  user2_phase  similarity
# 0       fffeelipe    mnguzmanc            1            1    0.676471
# 1       fffeelipe        DglyP            1            1    0.558824
# 2       fffeelipe  Judgarciani            1            1    0.690476
# 3       fffeelipe    sacastroc            1            1    0.617647
# 4       fffeelipe    pcberriop            1            1    0.790698
# ...           ...          ...          ...          ...         ...
# 1591       gabi04  djsanabriac            5            5    0.686275
# 1592       gabi04   anmmunozme            5            5    0.870370
# 1593   janoguerab  djsanabriac            5            5    0.795455
# 1594   janoguerab   anmmunozme            5            5    0.740741
# 1595  djsanabriac   anmmunozme            5            5    0.722222
#
# [1596 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase15_bogota1["functions"], df_phase15_bogota1["Student"], df_phase15_bogota1["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df0_bogota1 = pd.DataFrame(result)
df0_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            1            1    0.709677
# 1          gasierram       bdcajicam            1            1    0.709677
# 2          gasierram       helmeraac            1            1    0.774194
# 3          gasierram      dasalgadob            1            1    0.709677
# 4          gasierram      falperezgo            1            1    0.682927
# ...              ...             ...          ...          ...         ...
# 2341      daandradec  joahernandezca            5            5    0.943396
# 2342      daandradec    JairVillalba            5            5    0.792453
# 2343        jcrubioa  joahernandezca            5            5    1.000000
# 2344        jcrubioa    JairVillalba            5            5    0.843137
# 2345  joahernandezca    JairVillalba            5            5    0.843137
#
# [2346 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase15_bogota2["functions"], df_phase15_bogota2["Student"], df_phase15_bogota2["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df0_bogota2 = pd.DataFrame(result)
df0_bogota2
# Out:
#              user1            user2  user1_phase  user2_phase  similarity
# 0     jusherrerama          bdvegat            1            1    0.733333
# 1     jusherrerama       Phoenixest            1            1    0.800000
# 2     jusherrerama         HashNick            1            1    0.638298
# 3     jusherrerama       joaortizro            1            1    0.718750
# 4     jusherrerama  juasmartinezbel            1            1    0.652174
# ...            ...              ...          ...          ...         ...
# 2696      oserasoa        xdanielsb            5            5    0.811321
# 2697      oserasoa     jscontrerasp            5            5    0.787234
# 2698      lsfinite        xdanielsb            5            5    0.962963
# 2699      lsfinite     jscontrerasp            5            5    0.740741
# 2700     xdanielsb     jscontrerasp            5            5    0.735849
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase15["functions"], df_phase15["Student"], df_phase15["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df0 = pd.DataFrame(result)
df0
# Out:
#             user1          user2  user1_phase  user2_phase  similarity
# 0       lemartinp      juligarji            1            1    0.500000
# 1       lemartinp      nfmorenog            1            1    0.526316
# 2       lemartinp      AFelipeGA            1            1    0.446809
# 3       lemartinp     mballeng91            1            1    0.388889
# 4       lemartinp       dduartec            1            1    0.486486
# ...           ...            ...          ...          ...         ...
# 2770  afceballosr     NicolasPrr            5            5    0.843137
# 2771  afceballosr  jumcorredorro            5            5    0.877551
# 2772    lizzyt10h     NicolasPrr            5            5    0.921569
# 2773    lizzyt10h  jumcorredorro            5            5    0.882353
# 2774   NicolasPrr  jumcorredorro            5            5    0.960784
#
# [2775 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase45_bogota0["functions"], df_phase45_bogota0["Student"], df_phase45_bogota0["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df1_bogota0 = pd.DataFrame(result)
df1_bogota0
# Out:
#             user1         user2  user1_phase  user2_phase  similarity
# 0       fffeelipe     mnguzmanc            4            4    0.796296
# 1       fffeelipe    jmcuestasb            4            4    0.796296
# 2       fffeelipe    katherinsb            4            4    0.720930
# 3       fffeelipe  jjrodriguezn            4            4    0.739130
# 4       fffeelipe         DglyP            4            4    0.796296
# ...           ...           ...          ...          ...         ...
# 1886       gabi04   djsanabriac            5            5    0.686275
# 1887       gabi04    anmmunozme            5            5    0.870370
# 1888   janoguerab   djsanabriac            5            5    0.795455
# 1889   janoguerab    anmmunozme            5            5    0.740741
# 1890  djsanabriac    anmmunozme            5            5    0.722222
#
# [1891 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase45_bogota1["functions"], df_phase45_bogota1["Student"], df_phase45_bogota1["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df1_bogota1 = pd.DataFrame(result)
df1_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            4            4    0.500000
# 1          gasierram       bdcajicam            4            4    0.909091
# 2          gasierram     dfhincapiem            4            4    0.545455
# 3          gasierram       helmeraac            4            4    0.693878
# 4          gasierram      dasalgadob            4            4    0.500000
# ...              ...             ...          ...          ...         ...
# 2623      daandradec  joahernandezca            5            5    0.943396
# 2624      daandradec    JairVillalba            5            5    0.792453
# 2625        jcrubioa  joahernandezca            5            5    1.000000
# 2626        jcrubioa    JairVillalba            5            5    0.843137
# 2627  joahernandezca    JairVillalba            5            5    0.843137
#
# [2628 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase45_bogota2["functions"], df_phase45_bogota2["Student"], df_phase45_bogota2["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df1_bogota2 = pd.DataFrame(result)
df1_bogota2
# Out:
#              user1         user2  user1_phase  user2_phase  similarity
# 0     jusherrerama       bdvegat            4            4    0.555556
# 1     jusherrerama    Phoenixest            4            4    0.444444
# 2     jusherrerama      HashNick            4            4    0.870370
# 3     jusherrerama       ccvacad            4            4    0.888889
# 4     jusherrerama    joaortizro            4            4    0.537037
# ...            ...           ...          ...          ...         ...
# 2845      oserasoa     xdanielsb            5            5    0.811321
# 2846      oserasoa  jscontrerasp            5            5    0.787234
# 2847      lsfinite     xdanielsb            5            5    0.962963
# 2848      lsfinite  jscontrerasp            5            5    0.740741
# 2849     xdanielsb  jscontrerasp            5            5    0.735849
#
# [2850 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase45["functions"], df_phase45["Student"], df_phase45["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df1 = pd.DataFrame(result)
df1
# Out:
#             user1          user2  user1_phase  user2_phase  similarity
# 0       lemartinp      juligarji            4            4    0.685185
# 1       lemartinp      nfmorenog            4            4    0.744681
# 2       lemartinp      AFelipeGA            4            4    0.685185
# 3       lemartinp     mballeng91            4            4    0.685185
# 4       lemartinp       dduartec            4            4    0.729167
# ...           ...            ...          ...          ...         ...
# 2770  afceballosr     NicolasPrr            5            5    0.843137
# 2771  afceballosr  jumcorredorro            5            5    0.877551
# 2772    lizzyt10h     NicolasPrr            5            5    0.921569
# 2773    lizzyt10h  jumcorredorro            5            5    0.882353
# 2774   NicolasPrr  jumcorredorro            5            5    0.960784
#
# [2775 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase34["functions"], df_phase34["Student"], df_phase34["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df2 = pd.DataFrame(result)
df2
# Out:
#             user1          user2  user1_phase  user2_phase  similarity
# 0       lemartinp      juligarji            3            3    0.574074
# 1       lemartinp      nfmorenog            3            3    0.617021
# 2       lemartinp      AFelipeGA            3            3    0.574074
# 3       lemartinp     mballeng91            3            3    0.574074
# 4       lemartinp       dduartec            3            3    0.604167
# ...           ...            ...          ...          ...         ...
# 2696  afceballosr     NicolasPrr            4            4    0.796296
# 2697  afceballosr  jumcorredorro            4            4    0.895833
# 2698    lizzyt10h     NicolasPrr            4            4    0.870370
# 2699    lizzyt10h  jumcorredorro            4            4    0.900000
# 2700   NicolasPrr  jumcorredorro            4            4    0.888889
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase34_bogota2["functions"], df_phase34_bogota2["Student"], df_phase34_bogota2["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df2_bogota2 = pd.DataFrame(result)
df2_bogota2
# Out:
#              user1            user2  user1_phase  user2_phase  similarity
# 0     jusherrerama          bdvegat            3            3    0.555556
# 1     jusherrerama       Phoenixest            3            3    0.444444
# 2     jusherrerama         HashNick            3            3    0.870370
# 3     jusherrerama       joaortizro            3            3    0.537037
# 4     jusherrerama  juasmartinezbel            3            3    0.851852
# ...            ...              ...          ...          ...         ...
# 2770      oserasoa        xdanielsb            4            4    0.807692
# 2771      oserasoa     jscontrerasp            4            4    0.787234
# 2772      lsfinite        xdanielsb            4            4    0.925926
# 2773      lsfinite     jscontrerasp            4            4    0.740741
# 2774     xdanielsb     jscontrerasp            4            4    0.764706
#
# [2775 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase34_bogota1["functions"], df_phase34_bogota1["Student"], df_phase34_bogota1["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df2_bogota1 = pd.DataFrame(result)
df2_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            3            3    0.500000
# 1          gasierram       bdcajicam            3            3    0.909091
# 2          gasierram     dfhincapiem            3            3    0.545455
# 3          gasierram       helmeraac            3            3    0.727273
# 4          gasierram      dasalgadob            3            3    0.500000
# ...              ...             ...          ...          ...         ...
# 2696      daandradec  joahernandezca            4            4    0.943396
# 2697      daandradec    JairVillalba            4            4    0.769231
# 2698        jcrubioa  joahernandezca            4            4    1.000000
# 2699        jcrubioa    JairVillalba            4            4    0.784314
# 2700  joahernandezca    JairVillalba            4            4    0.784314
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase34_bogota0["functions"], df_phase34_bogota0["Student"], df_phase34_bogota0["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df2_bogota0 = pd.DataFrame(result)
df2_bogota0
# Out:
#             user1         user2  user1_phase  user2_phase  similarity
# 0       fffeelipe     mnguzmanc            3            3    0.629630
# 1       fffeelipe    jmcuestasb            3            3    0.629630
# 2       fffeelipe  jjrodriguezn            3            3    0.731707
# 3       fffeelipe         DglyP            3            3    0.775000
# 4       fffeelipe   Judgarciani            3            3    0.739130
# ...           ...           ...          ...          ...         ...
# 1825       gabi04   djsanabriac            4            4    0.686275
# 1826       gabi04    anmmunozme            4            4    0.700000
# 1827   janoguerab   djsanabriac            4            4    0.795455
# 1828   janoguerab    anmmunozme            4            4    0.772727
# 1829  djsanabriac    anmmunozme            4            4    0.878049
#
# [1830 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase23["functions"], df_phase23["Student"], df_phase23["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df3 = pd.DataFrame(result)
df3
# Out:
#             user1          user2  user1_phase  user2_phase  similarity
# 0       lemartinp      juligarji            2            2    0.659574
# 1       lemartinp      nfmorenog            2            2    0.617021
# 2       lemartinp      AFelipeGA            2            2    0.574074
# 3       lemartinp     mballeng91            2            2    0.574074
# 4       lemartinp       dduartec            2            2    0.659091
# ...           ...            ...          ...          ...         ...
# 2696  afceballosr     NicolasPrr            3            3    0.804878
# 2697  afceballosr  jumcorredorro            3            3    0.816327
# 2698    lizzyt10h     NicolasPrr            3            3    0.852941
# 2699    lizzyt10h  jumcorredorro            3            3    0.625000
# 2700   NicolasPrr  jumcorredorro            3            3    0.687500
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase23_bogota2["functions"], df_phase23_bogota2["Student"], df_phase23_bogota2["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df3_bogota2 = pd.DataFrame(result)
df3_bogota2
# Out:
#              user1            user2  user1_phase  user2_phase  similarity
# 0     jusherrerama          bdvegat            2            2    0.733333
# 1     jusherrerama       Phoenixest            2            2    0.800000
# 2     jusherrerama         HashNick            2            2    0.638298
# 3     jusherrerama       joaortizro            2            2    0.838710
# 4     jusherrerama  juasmartinezbel            2            2    0.652174
# ...            ...              ...          ...          ...         ...
# 2696      oserasoa        xdanielsb            3            3    0.857143
# 2697      oserasoa     jscontrerasp            3            3    0.808511
# 2698      lsfinite        xdanielsb            3            3    0.870370
# 2699      lsfinite     jscontrerasp            3            3    0.759259
# 2700     xdanielsb     jscontrerasp            3            3    0.795918
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase23_bogota1["functions"], df_phase23_bogota1["Student"], df_phase23_bogota1["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df3_bogota1 = pd.DataFrame(result)
df3_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            2            2    0.709677
# 1          gasierram       bdcajicam            2            2    0.709677
# 2          gasierram     dfhincapiem            2            2    0.774194
# 3          gasierram       helmeraac            2            2    0.852941
# 4          gasierram      dasalgadob            2            2    0.709677
# ...              ...             ...          ...          ...         ...
# 2696      daandradec  joahernandezca            3            3    0.924528
# 2697      daandradec    JairVillalba            3            3    0.784314
# 2698        jcrubioa  joahernandezca            3            3    1.000000
# 2699        jcrubioa    JairVillalba            3            3    0.784314
# 2700  joahernandezca    JairVillalba            3            3    0.784314
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase23_bogota0["functions"], df_phase23_bogota0["Student"], df_phase23_bogota0["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df3_bogota0 = pd.DataFrame(result)
df3_bogota0
# Out:
#             user1         user2  user1_phase  user2_phase  similarity
# 0       fffeelipe     mnguzmanc            2            2    0.750000
# 1       fffeelipe    jmcuestasb            2            2    0.629630
# 2       fffeelipe  jjrodriguezn            2            2    0.825000
# 3       fffeelipe         DglyP            2            2    0.775000
# 4       fffeelipe   Judgarciani            2            2    0.733333
# ...           ...           ...          ...          ...         ...
# 1765       gabi04   djsanabriac            3            3    0.686275
# 1766       gabi04    anmmunozme            3            3    0.653061
# 1767   janoguerab   djsanabriac            3            3    0.795455
# 1768   janoguerab    anmmunozme            3            3    0.761905
# 1769  djsanabriac    anmmunozme            3            3    0.825000
#
# [1770 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase12["functions"], df_phase12["Student"], df_phase12["phase"]))


result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df4 = pd.DataFrame(result)
df4
# Out:
#             user1          user2  user1_phase  user2_phase  similarity
# 0       lemartinp      juligarji            1            1    0.500000
# 1       lemartinp      nfmorenog            1            1    0.526316
# 2       lemartinp      AFelipeGA            1            1    0.446809
# 3       lemartinp     mballeng91            1            1    0.388889
# 4       lemartinp       dduartec            1            1    0.486486
# ...           ...            ...          ...          ...         ...
# 2696  afceballosr     NicolasPrr            2            2    0.804878
# 2697  afceballosr  jumcorredorro            2            2    0.904762
# 2698    lizzyt10h     NicolasPrr            2            2    0.764706
# 2699    lizzyt10h  jumcorredorro            2            2    0.692308
# 2700   NicolasPrr  jumcorredorro            2            2    0.800000
#
# [2701 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase12_bogota2["functions"], df_phase12_bogota2["Student"], df_phase12_bogota2["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df4_bogota2 = pd.DataFrame(result)
df4_bogota2
# Out:
#              user1            user2  user1_phase  user2_phase  similarity
# 0     jusherrerama          bdvegat            1            1    0.733333
# 1     jusherrerama       Phoenixest            1            1    0.800000
# 2     jusherrerama         HashNick            1            1    0.638298
# 3     jusherrerama       joaortizro            1            1    0.718750
# 4     jusherrerama  juasmartinezbel            1            1    0.652174
# ...            ...              ...          ...          ...         ...
# 2623      oserasoa        xdanielsb            2            2    0.833333
# 2624      oserasoa     jscontrerasp            2            2    0.804348
# 2625      lsfinite        xdanielsb            2            2    0.833333
# 2626      lsfinite     jscontrerasp            2            2    0.740741
# 2627     xdanielsb     jscontrerasp            2            2    0.808511
#
# [2628 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase12_bogota1["functions"], df_phase12_bogota1["Student"], df_phase12_bogota1["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df4_bogota1 = pd.DataFrame(result)
df4_bogota1
# Out:
#                user1           user2  user1_phase  user2_phase  similarity
# 0          gasierram    adamantwharf            1            1    0.709677
# 1          gasierram       bdcajicam            1            1    0.709677
# 2          gasierram       helmeraac            1            1    0.774194
# 3          gasierram      dasalgadob            1            1    0.709677
# 4          gasierram      falperezgo            1            1    0.682927
# ...              ...             ...          ...          ...         ...
# 2410      daandradec  joahernandezca            2            2    0.905660
# 2411      daandradec    JairVillalba            2            2    0.780000
# 2412        jcrubioa  joahernandezca            2            2    1.000000
# 2413        jcrubioa    JairVillalba            2            2    0.764706
# 2414  joahernandezca    JairVillalba            2            2    0.764706
#
# [2415 rows x 5 columns]

# %%
# create list of tuples like [(wording, user), (wording, user)]
# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df_phase12_bogota0["functions"], df_phase12_bogota0["Student"], df_phase12_bogota0["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

df4_bogota0 = pd.DataFrame(result)
df4_bogota0
# Out:
#             user1        user2  user1_phase  user2_phase  similarity
# 0       fffeelipe    mnguzmanc            1            1    0.676471
# 1       fffeelipe        DglyP            1            1    0.558824
# 2       fffeelipe  Judgarciani            1            1    0.690476
# 3       fffeelipe    sacastroc            1            1    0.617647
# 4       fffeelipe    pcberriop            1            1    0.790698
# ...           ...          ...          ...          ...         ...
# 1535       gabi04  djsanabriac            2            2    0.666667
# 1536       gabi04   anmmunozme            2            2    0.580000
# 1537   janoguerab  djsanabriac            2            2    0.795455
# 1538   janoguerab   anmmunozme            2            2    0.697674
# 1539  djsanabriac   anmmunozme            2            2    0.800000
#
# [1540 rows x 5 columns]

# %%
phase12_bogota3 = df4[df4['user1'] == df4['user2']]
phase12_bogota3
# Out:
#                 user1            user2  user1_phase  user2_phase  similarity
# 36          lemartinp        lemartinp            1            2    0.677419
# 109         juligarji        juligarji            1            2    0.765957
# 181         nfmorenog        nfmorenog            1            2    0.822222
# 252         AFelipeGA        AFelipeGA            1            2    0.870370
# 322        mballeng91       mballeng91            1            2    1.000000
# 391          dduartec         dduartec            1            2    0.809524
# 459         srmedinac        srmedinac            1            2    0.708333
# 527     wapiravaguens    wapiravaguens            1            2    0.925000
# 593          davidh17         davidh17            1            2    0.666667
# 658    DianaNavarrete   DianaNavarrete            1            2    0.920000
# 784         jorge52an        jorge52an            1            2    0.780488
# 846   jscastelblancoh  jscastelblancoh            1            2    0.973684
# 907        juclopezso       juclopezso            1            2    0.604651
# 967         afforeroc        afforeroc            1            2    1.000000
# 1026      dagofonseca      dagofonseca            1            2    0.928571
# 1084      lacardenasv      lacardenasv            1            2    0.866667
# 1141      oacastillol      oacastillol            1            2    0.630435
# 1197       ncampuzano       ncampuzano            1            2    0.805556
# 1252         adriel62         adriel62            1            2    0.700000
# 1306         capinzor         capinzor            1            2    1.000000
# 1359         ofnanezn         ofnanezn            1            2    1.000000
# 1411        macuestap        macuestap            1            2    0.805556
# 1462           spenas           spenas            1            2    0.787879
# 1512      kgbayala528      kgbayala528            1            2    1.000000
# 1561       lgmoralesa       lgmoralesa            1            2    0.750000
# 1609       ronaldsg20       ronaldsg20            1            2    1.000000
# 1656    cccristanchoc    cccristanchoc            1            2    0.906977
# 1702       jmalvarezd       jmalvarezd            1            2    0.880952
# 1747        smarquezo        smarquezo            1            2    0.909091
# 1791          sarizag          sarizag            1            2    0.900000
# 1834         Chranium         Chranium            1            2    1.000000
# 1876          DavidQP          DavidQP            1            2    0.939394
# 1917      afceballosr      afceballosr            1            2    0.951220
# 1957        lizzyt10h        lizzyt10h            1            2    0.529412
# 1996       NicolasPrr       NicolasPrr            1            2    1.000000
# 2034    jumcorredorro    jumcorredorro            1            2    0.974359

# %%
phase45_bogota3 = df1[df1['user1'] == df1['user2']]
phase45_bogota3
# Out:
#                 user1            user2  user1_phase  user2_phase  similarity
# 36          lemartinp        lemartinp            4            5    1.000000
# 110         juligarji        juligarji            4            5    1.000000
# 183         nfmorenog        nfmorenog            4            5    1.000000
# 255         AFelipeGA        AFelipeGA            4            5    1.000000
# 326        mballeng91       mballeng91            4            5    1.000000
# 396          dduartec         dduartec            4            5    0.851852
# 465         srmedinac        srmedinac            4            5    1.000000
# 533      wilson911013     wilson911013            4            5    1.000000
# 600     wapiravaguens    wapiravaguens            4            5    1.000000
# 666          davidh17         davidh17            4            5    1.000000
# 731    DianaNavarrete   DianaNavarrete            4            5    1.000000
# 796         jorge52an        jorge52an            4            5    1.000000
# 859   jscastelblancoh  jscastelblancoh            4            5    0.978723
# 921        juclopezso       juclopezso            4            5    1.000000
# 982         afforeroc        afforeroc            4            5    1.000000
# 1042      dagofonseca      dagofonseca            4            5    0.980392
# 1101      lacardenasv      lacardenasv            4            5    1.000000
# 1159      oacastillol      oacastillol            4            5    1.000000
# 1216       ncampuzano       ncampuzano            4            5    0.916667
# 1272         adriel62         adriel62            4            5    0.814815
# 1327         capinzor         capinzor            4            5    1.000000
# 1381         ofnanezn         ofnanezn            4            5    1.000000
# 1434        macuestap        macuestap            4            5    1.000000
# 1486           spenas           spenas            4            5    1.000000
# 1537      kgbayala528      kgbayala528            4            5    1.000000
# 1587       lgmoralesa       lgmoralesa            4            5    0.976190
# 1636       ronaldsg20       ronaldsg20            4            5    1.000000
# 1684    cccristanchoc    cccristanchoc            4            5    0.957447
# 1731       jmalvarezd       jmalvarezd            4            5    0.954545
# 1777        smarquezo        smarquezo            4            5    0.795455
# 1822          sarizag          sarizag            4            5    0.930233
# 1866         Chranium         Chranium            4            5    1.000000
# 1909          DavidQP          DavidQP            4            5    0.952381
# 1951      afceballosr      afceballosr            4            5    1.000000
# 1992        lizzyt10h        lizzyt10h            4            5    1.000000
# 2032       NicolasPrr       NicolasPrr            4            5    0.944444
# 2071    jumcorredorro    jumcorredorro            4            5    0.979592

# %% [markdown]
# ## Bogota 3 Phase 1 and Phase 5

# %%
phase15_bogota3 = df0[df0['user1'] == df0['user2']]
mean_phase15_bogota3 = phase15_bogota3['similarity'].describe().loc['mean']

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase15_bogota3['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.944, p=0.062
#
# Probably Gaussian

# %% [markdown]
# ## Bogota 2 Phase 1 and Phase 5

# %%
phase15_bogota2 = df0_bogota2[df0_bogota2['user1'] == df0_bogota2['user2']]
mean_phase15_bogota2 = phase15_bogota2['similarity'].describe().loc['mean']

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase15_bogota2['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.911, p=0.007
#
# Probably not Gaussian

# %% [markdown]
# ## Bogota 1 Phase 1 and Phase 5

# %%
phase15_bogota1 = df0_bogota1[df0_bogota1['user1'] == df0_bogota1['user2']]
mean_phase15_bogota1 = phase15_bogota1['similarity'].describe().loc['mean']

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase15_bogota1['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.924, p=0.017
#
# Probably not Gaussian

# %% [markdown]
# ## Bogota 0 Phase 1 and Phase 5

# %%
phase15_bogota0 = df0_bogota0[df0_bogota0['user1'] == df0_bogota0['user2']]
mean_phase15_bogota0 = phase15_bogota0['similarity'].describe().loc['mean']

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase15_bogota0['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.941, p=0.141
#
# Probably Gaussian

# %% [markdown]
# ## Bogota 3 Phase 4 and Phase 5

# %%
phase45_bogota3 = df1[df1['user1'] == df1['user2']]
mean_phase45_bogota3 = phase45_bogota3['similarity'].describe().loc['mean']
min_phase45_bogota3 = phase45_bogota3['similarity'].describe().loc['min']
median_phase45_bogota3 = phase45_bogota3['similarity'].median()

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase45_bogota3['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.581, p=0.000
#
# Probably not Gaussian

# %%
phase45_bogota3_self = df1[df1['user1'] == df1['user2']]
phase45_bogota3_self['similarity'].hist()
# Out:
# <AxesSubplot:>

# %%
from matplotlib import pyplot as plt
phase45_bogota3_self.boxplot(column='similarity')
plt.show()

# %%
import seaborn as sns 
sns.distplot(phase45_bogota3_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase45_bogota3_self = phase45_bogota3_self[['similarity']]
out_array_phase45_bogota3_self = np.log((1-inp_array_phase45_bogota3_self)+1)

# %%
out_array_phase45_bogota3_self.boxplot(column='similarity')
plt.show()

# %%
sns.distplot(out_array_phase45_bogota3_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase45_bogota3_self['similarity'].describe()
# Out:
# count    37.000000
# mean      0.024664
# std       0.047614
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.023530
# max       0.186102
# Name: similarity, dtype: float64

# %%
median_out_array_phase45_bogota3_self = out_array_phase45_bogota3_self['similarity'].describe().loc['50%']
mean_out_array_phase45_bogota3_self = out_array_phase45_bogota3_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 2 Phase 4 and Phase 5

# %%
phase45_bogota2 = df1_bogota2[df1_bogota2['user1'] == df1_bogota2['user2']]
mean_phase45_bogota2 = phase45_bogota2['similarity'].describe().loc['mean']
min_phase45_bogota2 = phase45_bogota2['similarity'].describe().loc['min']
median_phase45_bogota2 = phase45_bogota2['similarity'].median()

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase45_bogota2['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.500, p=0.000
#
# Probably not Gaussian

# %%
phase45_bogota2_self = df1_bogota2[df1_bogota2['user1'] == df1_bogota2['user2']]
sns.distplot(phase45_bogota2_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase45_bogota2_self = phase45_bogota2_self[['similarity']]
out_array_phase45_bogota2_self = np.log((1-inp_array_phase45_bogota2_self)+1)
sns.distplot(out_array_phase45_bogota2_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase45_bogota2_self['similarity'].describe()
# Out:
# count    38.000000
# mean      0.017798
# std       0.040583
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       0.143101
# Name: similarity, dtype: float64

# %%
median_out_array_phase45_bogota2_self = out_array_phase45_bogota2_self['similarity'].describe().loc['50%']
mean_out_array_phase45_bogota2_self = out_array_phase45_bogota2_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 1 Phase 4 and Phase 5

# %%
phase45_bogota1 = df1_bogota1[df1_bogota1['user1'] == df1_bogota1['user2']]
mean_phase45_bogota1 = phase45_bogota1['similarity'].describe().loc['mean']
min_phase45_bogota1 = phase45_bogota1['similarity'].describe().loc['min']
median_phase45_bogota1 = phase45_bogota1['similarity'].median()

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase45_bogota1['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.428, p=0.000
#
# Probably not Gaussian

# %%
phase45_bogota1_self = df1_bogota1[df1_bogota1['user1'] == df1_bogota1['user2']]
sns.distplot(phase45_bogota1_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase45_bogota1_self = phase45_bogota1_self[['similarity']]
out_array_phase45_bogota1_self = np.log((1-inp_array_phase45_bogota1_self)+1)
sns.distplot(out_array_phase45_bogota1_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase45_bogota1_self['similarity'].describe()
# Out:
# count    40.000000
# mean      0.029639
# std       0.078292
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       0.382992
# Name: similarity, dtype: float64

# %%
median_out_array_phase45_bogota1_self = out_array_phase45_bogota1_self['similarity'].describe().loc['50%']
mean_out_array_phase45_bogota1_self = out_array_phase45_bogota1_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 0 Phase 4 and Phase 5

# %%
phase45_bogota0 = df1_bogota0[df1_bogota0['user1'] == df1_bogota0['user2']]
mean_phase45_bogota0 = phase45_bogota0['similarity'].describe().loc['mean']
min_phase45_bogota0 = phase45_bogota0['similarity'].describe().loc['min']
median_phase45_bogota0 = phase45_bogota0['similarity'].median()

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase45_bogota0['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.405, p=0.000
#
# Probably not Gaussian

# %%
phase45_bogota0_self = df1_bogota0[df1_bogota0['user1'] == df1_bogota0['user2']]
sns.distplot(phase45_bogota0_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase45_bogota0_self = phase45_bogota0_self[['similarity']]
out_array_phase45_bogota0_self = np.log((1-inp_array_phase45_bogota0_self)+1)
sns.distplot(out_array_phase45_bogota0_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase45_bogota0_self['similarity'].describe()
# Out:
# count    31.000000
# mean      0.028952
# std       0.077535
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.022473
# max       0.354821
# Name: similarity, dtype: float64

# %%
median_out_array_phase45_bogota0_self = out_array_phase45_bogota0_self['similarity'].describe().loc['50%']
mean_out_array_phase45_bogota0_self = out_array_phase45_bogota0_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 3 Phase 3 and Phase 4

# %%
phase34_bogota3 = df2[df2['user1'] == df2['user2']]
mean_phase34_bogota3 = phase34_bogota3['similarity'].describe().loc['mean']
min_phase34_bogota3 = phase34_bogota3['similarity'].describe().loc['min']
median_phase34_bogota3 = phase34_bogota3['similarity'].median()

# %%
phase34_bogota3_self = df2[df2['user1'] == df2['user2']]
sns.distplot(phase34_bogota3_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase34_bogota3_self = phase34_bogota3_self[['similarity']]
out_array_phase34_bogota3_self = np.log((1-inp_array_phase34_bogota3_self)+1)
sns.distplot(out_array_phase34_bogota3_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase34_bogota3_self['similarity'].describe()
# Out:
# count    37.000000
# mean      0.071131
# std       0.107878
# min       0.000000
# 25%       0.000000
# 50%       0.024098
# 75%       0.087011
# max       0.348307
# Name: similarity, dtype: float64

# %%
median_out_array_phase34_bogota3_self = out_array_phase34_bogota3_self['similarity'].describe().loc['50%']
mean_out_array_phase34_bogota3_self = out_array_phase34_bogota3_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 2 Phase 3 and Phase 4

# %%
phase34_bogota2 = df2_bogota2[df2_bogota2['user1'] == df2_bogota2['user2']]
mean_phase34_bogota2 = phase34_bogota2['similarity'].describe().loc['mean']
min_phase34_bogota2 = phase34_bogota2['similarity'].describe().loc['min']
median_phase34_bogota2 = phase34_bogota2['similarity'].median()

# %%
phase34_bogota2_self = df2_bogota2[df2_bogota2['user1'] == df2_bogota2['user2']]
sns.distplot(phase34_bogota2_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase34_bogota2_self = phase34_bogota2_self[['similarity']]
out_array_phase34_bogota2_self = np.log((1-inp_array_phase34_bogota2_self)+1)
sns.distplot(out_array_phase34_bogota2_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase34_bogota2_self['similarity'].describe()
# Out:
# count    37.000000
# mean      0.041959
# std       0.070422
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.059423
# max       0.326684
# Name: similarity, dtype: float64

# %%
mean_out_array_phase34_bogota2_self = out_array_phase34_bogota2_self['similarity'].describe().loc['mean']
median_out_array_phase34_bogota2_self = out_array_phase34_bogota2_self['similarity'].describe().loc['50%']

# %% [markdown]
# ## Bogota 1 Phase 3 and Phase 4

# %%
phase34_bogota1 = df2_bogota1[df2_bogota1['user1'] == df2_bogota1['user2']]
mean_phase34_bogota1 = phase34_bogota1['similarity'].describe().loc['mean']
min_phase34_bogota1 = phase34_bogota1['similarity'].describe().loc['min']
median_phase34_bogota1 = phase34_bogota1['similarity'].median()

# %%
phase34_bogota1_self = df2_bogota1[df2_bogota1['user1'] == df2_bogota1['user2']]
sns.distplot(phase34_bogota1_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase34_bogota1_self = phase34_bogota1_self[['similarity']]
out_array_phase34_bogota1_self = np.log((1-inp_array_phase34_bogota1_self)+1)
sns.distplot(out_array_phase34_bogota1_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase34_bogota1_self['similarity'].describe()
# Out:
# count    41.000000
# mean      0.038214
# std       0.084528
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.022990
# max       0.380464
# Name: similarity, dtype: float64

# %%
median_out_array_phase34_bogota1_self = out_array_phase34_bogota1_self['similarity'].describe().loc['50%']
mean_out_array_phase34_bogota1_self = out_array_phase34_bogota1_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 0 Phase 3 and Phase 4

# %%
phase34_bogota0 = df2_bogota0[df2_bogota0['user1'] == df2_bogota0['user2']]
mean_phase34_bogota0 = phase34_bogota0['similarity'].describe().loc['mean']
min_phase34_bogota0 = phase34_bogota0['similarity'].describe().loc['min']
median_phase34_bogota0 = phase34_bogota0['similarity'].median()

# %%
phase34_bogota0_self = df2_bogota0[df2_bogota0['user1'] == df2_bogota0['user2']]
sns.distplot(phase34_bogota0_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase34_bogota0_self = phase34_bogota0_self[['similarity']]
out_array_phase34_bogota0_self = np.log((1-inp_array_phase34_bogota0_self)+1)
sns.distplot(out_array_phase34_bogota0_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase34_bogota0_self['similarity'].describe()
# Out:
# count    30.000000
# mean      0.042881
# std       0.074285
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.060340
# max       0.273696
# Name: similarity, dtype: float64

# %%
median_out_array_phase34_bogota0_self = out_array_phase34_bogota0_self['similarity'].describe().loc['50%']
mean_out_array_phase34_bogota0_self = out_array_phase34_bogota0_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 3 Phase 2 and Phase 3

# %%
phase23_bogota3 = df3[df3['user1'] == df3['user2']]
mean_phase23_bogota3 = phase23_bogota3['similarity'].describe().loc['mean']
min_phase23_bogota3 = phase23_bogota3['similarity'].describe().loc['min']
median_phase23_bogota3 = phase23_bogota3['similarity'].median()

# %%
phase23_bogota3_self = df3[df3['user1'] == df3['user2']]
sns.distplot(phase23_bogota3_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase23_bogota3_self = phase23_bogota3_self[['similarity']]
out_array_phase23_bogota3_self = np.log((1-inp_array_phase23_bogota3_self)+1)
sns.distplot(out_array_phase23_bogota3_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase23_bogota3_self['similarity'].describe()
# Out:
# count    37.000000
# mean      0.047967
# std       0.073304
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.087011
# max       0.281851
# Name: similarity, dtype: float64

# %%
median_out_array_phase23_bogota3_self = out_array_phase23_bogota3_self['similarity'].describe().loc['50%']
mean_out_array_phase23_bogota3_self = out_array_phase23_bogota3_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 2 Phase 2 and Phase 3

# %%
phase23_bogota2 = df3_bogota2[df3_bogota2['user1'] == df3_bogota2['user2']]
mean_phase23_bogota2 = phase23_bogota2['similarity'].describe().loc['mean']
min_phase23_bogota2 = phase23_bogota2['similarity'].describe().loc['min']
median_phase23_bogota2 = phase23_bogota2['similarity'].median()

# %%
phase23_bogota2_self = df3_bogota2[df3_bogota2['user1'] == df3_bogota2['user2']]
sns.distplot(phase23_bogota2_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase23_bogota2_self = phase23_bogota2_self[['similarity']]
out_array_phase23_bogota2_self = np.log((1-inp_array_phase23_bogota2_self)+1)
sns.distplot(out_array_phase23_bogota2_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase23_bogota2_self['similarity'].describe()
# Out:
# count    37.000000
# mean      0.049705
# std       0.090007
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.065958
# max       0.367725
# Name: similarity, dtype: float64

# %%
median_out_array_phase23_bogota2_self = out_array_phase23_bogota2_self['similarity'].describe().loc['50%']
mean_out_array_phase23_bogota2_self = out_array_phase23_bogota2_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 1 Phase 2 and Phase 3

# %%
phase23_bogota1 = df3_bogota1[df3_bogota1['user1'] == df3_bogota1['user2']]
mean_phase23_bogota1 = phase23_bogota1['similarity'].describe().loc['mean']
min_phase23_bogota1 = phase23_bogota1['similarity'].describe().loc['min']
median_phase23_bogota1 = phase23_bogota1['similarity'].median()

# %%
phase23_bogota1_self = df3_bogota1[df3_bogota1['user1'] == df3_bogota1['user2']]
sns.distplot(phase23_bogota1_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase23_bogota1_self = phase23_bogota1_self[['similarity']]
out_array_phase23_bogota1_self = np.log((1-inp_array_phase23_bogota1_self)+1)
sns.distplot(out_array_phase23_bogota1_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase23_bogota1_self['similarity'].describe()
# Out:
# count    41.000000
# mean      0.047492
# std       0.106536
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.024693
# max       0.470004
# Name: similarity, dtype: float64

# %%
median_out_array_phase23_bogota1_self = out_array_phase23_bogota1_self['similarity'].describe().loc['50%']
mean_out_array_phase23_bogota1_self = out_array_phase23_bogota1_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 0 Phase 2 and Phase 3

# %%
phase23_bogota0 = df3_bogota0[df3_bogota0['user1'] == df3_bogota0['user2']]
mean_phase23_bogota0 = phase23_bogota0['similarity'].describe().loc['mean']
min_phase23_bogota0 = phase23_bogota0['similarity'].describe().loc['min']
median_phase23_bogota0 = phase23_bogota0['similarity'].median()

# %%
phase23_bogota0_self = df3_bogota0[df3_bogota0['user1'] == df3_bogota0['user2']]
sns.distplot(phase23_bogota0_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase23_bogota0_self = phase23_bogota0_self[['similarity']]
out_array_phase23_bogota0_self = np.log((1-inp_array_phase23_bogota0_self)+1)
sns.distplot(out_array_phase23_bogota0_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase23_bogota0_self['similarity'].describe()
# Out:
# count    30.000000
# mean      0.065906
# std       0.094822
# min       0.000000
# 25%       0.000000
# 50%       0.024708
# 75%       0.098059
# max       0.316670
# Name: similarity, dtype: float64

# %%
median_out_array_phase23_bogota0_self = out_array_phase23_bogota0_self['similarity'].describe().loc['50%']
mean_out_array_phase23_bogota0_self = out_array_phase23_bogota0_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 3 Phase 1 and Phase 2

# %%
phase12_bogota3 = df4[df4['user1'] == df4['user2']]
mean_phase12_bogota3 = phase12_bogota3['similarity'].describe().loc['mean']
min_phase12_bogota3 = phase12_bogota3['similarity'].describe().loc['min']
median_phase12_bogota3 = phase12_bogota3['similarity'].median()

# %%
phase12_bogota3_self = df4[df4['user1'] == df4['user2']]
sns.distplot(phase12_bogota3_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase12_bogota3_self = phase12_bogota3_self[['similarity']]
out_array_phase12_bogota3_self = np.log((1-inp_array_phase12_bogota3_self)+1)
sns.distplot(out_array_phase12_bogota3_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase12_bogota3_self['similarity'].describe()
# Out:
# count    36.000000
# mean      0.128981
# std       0.111665
# min       0.000000
# 25%       0.025811
# 50%       0.103894
# 75%       0.201412
# max       0.385662
# Name: similarity, dtype: float64

# %%
median_out_array_phase12_bogota3_self = out_array_phase12_bogota3_self['similarity'].describe().loc['50%']
mean_out_array_phase12_bogota3_self = out_array_phase12_bogota3_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 2 Phase 1 and Phase 2

# %%
phase12_bogota2 = df4_bogota2[df4_bogota2['user1'] == df4_bogota2['user2']]
mean_phase12_bogota2 = phase12_bogota2['similarity'].describe().loc['mean']
min_phase12_bogota2 = phase12_bogota2['similarity'].describe().loc['min']
median_phase12_bogota2 = phase12_bogota2['similarity'].median()

# %%
phase12_bogota2_self = df4_bogota2[df4_bogota2['user1'] == df4_bogota2['user2']]
sns.distplot(phase12_bogota2_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase12_bogota2_self = phase12_bogota2_self[['similarity']]
out_array_phase12_bogota2_self = np.log((1-inp_array_phase12_bogota2_self)+1)
sns.distplot(out_array_phase12_bogota2_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase12_bogota2_self['similarity'].describe()
# Out:
# count    36.000000
# mean      0.142175
# std       0.140377
# min       0.000000
# 25%       0.000000
# 50%       0.105042
# 75%       0.264953
# max       0.393043
# Name: similarity, dtype: float64

# %%
median_out_array_phase12_bogota2_self = out_array_phase12_bogota2_self['similarity'].describe().loc['50%']
mean_out_array_phase12_bogota2_self = out_array_phase12_bogota2_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 1 Phase 1 and Phase 2

# %%
phase12_bogota1 = df4_bogota1[df4_bogota1['user1'] == df4_bogota1['user2']]
mean_phase12_bogota1 = phase12_bogota1['similarity'].describe().loc['mean']
min_phase12_bogota1 = phase12_bogota1['similarity'].describe().loc['min']
median_phase12_bogota1 = phase12_bogota1['similarity'].median()

# %%
phase12_bogota1_self = df4_bogota1[df4_bogota1['user1'] == df4_bogota1['user2']]
sns.distplot(phase12_bogota1_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase12_bogota1_self = phase12_bogota1_self[['similarity']]
out_array_phase12_bogota1_self = np.log((1-inp_array_phase12_bogota1_self)+1)
sns.distplot(out_array_phase12_bogota1_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase12_bogota1_self['similarity'].describe()
# Out:
# count    37.000000
# mean      0.119450
# std       0.135065
# min       0.000000
# 25%       0.000000
# 50%       0.046520
# 75%       0.215709
# max       0.450201
# Name: similarity, dtype: float64

# %%
median_out_array_phase12_bogota1_self = out_array_phase12_bogota1_self['similarity'].describe().loc['50%']
mean_out_array_phase12_bogota1_self = out_array_phase12_bogota1_self['similarity'].describe().loc['mean']

# %% [markdown]
# ## Bogota 0 Phase 1 and Phase 2

# %%
phase12_bogota0 = df4_bogota0[df4_bogota0['user1'] == df4_bogota0['user2']]
mean_phase12_bogota0 = phase12_bogota0['similarity'].describe().loc['mean']
min_phase12_bogota0 = phase12_bogota0['similarity'].describe().loc['min']
median_phase12_bogota0 = phase12_bogota0['similarity'].median()

# %%
phase12_bogota0_self = df4_bogota0[df4_bogota0['user1'] == df4_bogota0['user2']]
sns.distplot(phase12_bogota0_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
inp_array_phase12_bogota0_self = phase12_bogota0_self[['similarity']]
out_array_phase12_bogota0_self = np.log((1-inp_array_phase12_bogota0_self)+1)
sns.distplot(out_array_phase12_bogota0_self['similarity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='similarity', ylabel='Density'>

# %%
out_array_phase12_bogota0_self['similarity'].describe()
# Out:
# count    26.000000
# mean      0.163959
# std       0.143021
# min       0.000000
# 25%       0.025187
# 50%       0.143236
# 75%       0.293812
# max       0.419854
# Name: similarity, dtype: float64

# %%
mean_out_array_phase12_bogota0_self = out_array_phase12_bogota0_self['similarity'].describe().loc['mean']
median_out_array_phase12_bogota0_self = out_array_phase12_bogota0_self['similarity'].describe().loc['50%']

# %%
out_array_phase12_bogota0_self['similarity'].median()
# Out:
# 0.1432362218301403

# %%
phase12_bogota01 = phase12_bogota0.append(phase12_bogota1, ignore_index=True)
phase12_bogota12 = phase12_bogota01.append(phase12_bogota2, ignore_index=True)
phase12_bogota23 = phase12_bogota12.append(phase12_bogota3, ignore_index=True)
phase12_bogota_overall = phase12_bogota23[(phase12_bogota23['user1_phase'] == 1) & (phase12_bogota23['user2_phase'] == 2) ]
phase12_bogota_overall
# Out:
#              user1          user2  user1_phase  user2_phase  similarity
# 0        fffeelipe      fffeelipe            1            2    0.837838
# 1        mnguzmanc      mnguzmanc            1            2    0.638889
# 2            DglyP          DglyP            1            2    0.513514
# 3      Judgarciani    Judgarciani            1            2    0.840909
# 4        sacastroc      sacastroc            1            2    0.552632
# ..             ...            ...          ...          ...         ...
# 130        DavidQP        DavidQP            1            2    0.939394
# 131    afceballosr    afceballosr            1            2    0.951220
# 132      lizzyt10h      lizzyt10h            1            2    0.529412
# 133     NicolasPrr     NicolasPrr            1            2    1.000000
# 134  jumcorredorro  jumcorredorro            1            2    0.974359
#
# [133 rows x 5 columns]

# %%
phase23_bogota01 = phase23_bogota0.append(phase23_bogota1, ignore_index=True)
phase23_bogota12 = phase23_bogota01.append(phase23_bogota2, ignore_index=True)
phase23_bogota23 = phase23_bogota12.append(phase23_bogota3, ignore_index=True)
phase23_bogota_overall = phase23_bogota23[(phase23_bogota23['user1_phase'] == 2) & (phase23_bogota23['user2_phase'] == 3) ]
phase23_bogota_overall = phase23_bogota_overall[phase23_bogota_overall['user1'] == phase23_bogota_overall['user2']]
phase23_bogota_overall
# Out:
#              user1          user2  user1_phase  user2_phase  similarity
# 0        fffeelipe      fffeelipe            2            3    1.000000
# 1        mnguzmanc      mnguzmanc            2            3    0.666667
# 2       jmcuestasb     jmcuestasb            2            3    1.000000
# 3     jjrodriguezn   jjrodriguezn            2            3    0.809524
# 4            DglyP          DglyP            2            3    1.000000
# ..             ...            ...          ...          ...         ...
# 140        DavidQP        DavidQP            2            3    0.846154
# 141    afceballosr    afceballosr            2            3    1.000000
# 142      lizzyt10h      lizzyt10h            2            3    0.900000
# 143     NicolasPrr     NicolasPrr            2            3    1.000000
# 144  jumcorredorro  jumcorredorro            2            3    0.812500
#
# [143 rows x 5 columns]

# %%
phase34_bogota01 = phase34_bogota0.append(phase34_bogota1, ignore_index=True)
phase34_bogota12 = phase34_bogota01.append(phase34_bogota2, ignore_index=True)
phase34_bogota23 = phase34_bogota12.append(phase34_bogota3, ignore_index=True)
phase34_bogota_overall = phase34_bogota23[phase34_bogota23['user1'] == phase34_bogota23['user2']]
phase34_bogota_overall = phase34_bogota_overall[(phase34_bogota_overall['user1_phase'] == 3) & (phase34_bogota_overall['user2_phase'] == 4) ]
phase34_bogota_overall
# Out:
#              user1          user2  user1_phase  user2_phase  similarity
# 0        fffeelipe      fffeelipe            3            4    0.790698
# 1        mnguzmanc      mnguzmanc            3            4    1.000000
# 2       jmcuestasb     jmcuestasb            3            4    1.000000
# 3     jjrodriguezn   jjrodriguezn            3            4    1.000000
# 4            DglyP          DglyP            3            4    0.685185
# ..             ...            ...          ...          ...         ...
# 140        DavidQP        DavidQP            3            4    0.975000
# 141    afceballosr    afceballosr            3            4    0.909091
# 142      lizzyt10h      lizzyt10h            3            4    0.638298
# 143     NicolasPrr     NicolasPrr            3            4    0.611111
# 144  jumcorredorro  jumcorredorro            3            4    1.000000
#
# [143 rows x 5 columns]

# %%
# Shapiro-Wilk Normality Test

from scipy.stats import shapiro 

stat, p = shapiro(phase34_bogota_overall['similarity'])
print('stat=%.3f, p=%.3f\n' % (stat, p))
if p > 0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.613, p=0.000
#
# Probably not Gaussian

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = [1-mean_phase12_bogota0, 1-mean_phase23_bogota0, 1-mean_phase34_bogota0, 1-mean_phase45_bogota0 ]
y2 = [1-mean_phase12_bogota1, 1-mean_phase23_bogota1, 1-mean_phase34_bogota1, 1-mean_phase45_bogota1 ]
y3 = [1-mean_phase12_bogota2, 1-mean_phase23_bogota2, 1-mean_phase34_bogota2, 1-mean_phase45_bogota2 ]
y4 = [1-mean_phase12_bogota3, 1-mean_phase23_bogota3, 1-mean_phase34_bogota3, 1-mean_phase45_bogota3 ]


x_axis=['Phase 1-2', 'Phase 2-3', 'Phase 3-4', 'Phase 4-5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Mean of Exploration For Each Individual")
plt.ylabel("1-Jaccard Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = [1-median_phase12_bogota0, 1-median_phase23_bogota0, 1-median_phase34_bogota0, 1-median_phase45_bogota0 ]
y2 = [1-median_phase12_bogota1, 1-median_phase23_bogota1, 1-median_phase34_bogota1, 1-median_phase45_bogota1 ]
y3 = [1-median_phase12_bogota2, 1-median_phase23_bogota2, 1-median_phase34_bogota2, 1-median_phase45_bogota2 ]
y4 = [1-median_phase12_bogota3, 1-median_phase23_bogota3, 1-median_phase34_bogota3, 1-median_phase45_bogota3 ]


x_axis=['Phase 1-2', 'Phase 2-3', 'Phase 3-4', 'Phase 4-5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median of Exploration For Each Individual")
plt.ylabel("1-Jaccard Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = [mean_out_array_phase12_bogota0_self, mean_out_array_phase23_bogota0_self, mean_out_array_phase34_bogota0_self, mean_out_array_phase45_bogota0_self ]
y2 = [mean_out_array_phase12_bogota1_self, mean_out_array_phase23_bogota1_self, mean_out_array_phase34_bogota0_self, mean_out_array_phase45_bogota0_self ]
y3 = [mean_out_array_phase12_bogota2_self, mean_out_array_phase23_bogota2_self, mean_out_array_phase34_bogota0_self, mean_out_array_phase45_bogota0_self ]
y4 = [mean_out_array_phase12_bogota3_self, mean_out_array_phase23_bogota3_self, mean_out_array_phase34_bogota0_self, mean_out_array_phase45_bogota0_self ]


x_axis=['Phase 1-2', 'Phase 2-3', 'Phase 3-4', 'Phase 4-5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Mean Log-Transform Exploration")
plt.ylabel("Mean Log-Transform-Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = [median_out_array_phase12_bogota0_self, median_out_array_phase23_bogota0_self, median_out_array_phase34_bogota0_self, median_out_array_phase45_bogota0_self ]
y2 = [median_out_array_phase12_bogota1_self, median_out_array_phase23_bogota1_self, median_out_array_phase34_bogota0_self, median_out_array_phase45_bogota0_self ]
y3 = [median_out_array_phase12_bogota2_self, median_out_array_phase23_bogota2_self, median_out_array_phase34_bogota0_self, median_out_array_phase45_bogota0_self ]
y4 = [median_out_array_phase12_bogota3_self, median_out_array_phase23_bogota3_self, median_out_array_phase34_bogota0_self, median_out_array_phase45_bogota0_self ]


x_axis=['Phase 1-2', 'Phase 2-3', 'Phase 3-4', 'Phase 4-5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Median Log-Transform Similarity For Each Individual")
plt.ylabel("Median Log-Transform-Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

# Mean Scores of All Groups [ Tech Scores ]

y1 = [1-min_phase12_bogota0, 1-min_phase23_bogota0, 1-min_phase34_bogota0, 1-min_phase45_bogota0 ]
y2 = [1-min_phase12_bogota1, 1-min_phase23_bogota1, 1-min_phase34_bogota1, 1-min_phase45_bogota1 ]
y3 = [1-min_phase12_bogota2, 1-min_phase23_bogota2, 1-min_phase34_bogota2, 1-min_phase45_bogota2 ]
y4 = [1-min_phase12_bogota3, 1-min_phase23_bogota3, 1-min_phase34_bogota3, 1-min_phase45_bogota3 ]


x_axis=['Phase 1-2', 'Phase 2-3', 'Phase 3-4', 'Phase 4-5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Max of Individual Exploration in Each Group")
plt.ylabel("1-Jaccard Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %% [markdown]
# ## Test Code Section [ To Be Ignored ]

# %%
import itertools
import pandas as pd

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    return intersection_cardinality/float(union_cardinality)

# set initial data and create dataframe
data = {"wordings": ["apple,banana,orange,pears", "apple, banana", "apple,jackfruit", "banana,jackfruit,berries,apple", "berries,grapes,watermelon"], "users": ["adeline", "adeline", "kenzi", "ericko", "mary"], "phase":[1, 3, 2, 2, 3]}
df = pd.DataFrame(data)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(df["wordings"], df["users"], df["phase"]))
print(wordings_users)

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "phase": item[0][2], "phase2": item[1][2], "similarity": similarity}
    result.append(data)

df1_test = pd.DataFrame(result)
df1_test
# Out:
# [('apple,banana,orange,pears', 'adeline', 1), ('apple, banana', 'adeline', 3), ('apple,jackfruit', 'kenzi', 2), ('banana,jackfruit,berries,apple', 'ericko', 2), ('berries,grapes,watermelon', 'mary', 3)]
#      user1    user2  phase  phase2  similarity
# 0  adeline  adeline      1       3    0.583333
# 1  adeline    kenzi      1       2    0.333333
# 2  adeline   ericko      1       2    0.500000
# 3  adeline     mary      1       3    0.733333
# 4  adeline    kenzi      3       2    0.312500
# 5  adeline   ericko      3       2    0.411765
# 6  adeline     mary      3       3    0.437500
# 7    kenzi   ericko      2       2    0.812500
# 8    kenzi     mary      2       3    0.400000
# 9   ericko     mary      2       3    0.550000

# %%
phase45_bogota3['phase'] = 'phase45'
phase34_bogota3['phase'] = 'phase34'
phase23_bogota3['phase'] = 'phase23'
phase12_bogota3['phase'] = 'phase12'
df = pd.concat([phase45_bogota3, phase34_bogota3, phase23_bogota3, phase12_bogota3], ignore_index=True)
df['exploration'] = 1 - df['similarity']
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/3568056220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase45_bogota3['phase'] = 'phase45'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/3568056220.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase34_bogota3['phase'] = 'phase34'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/3568056220.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase23_bogota3['phase'] = 'phase23'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/3568056220.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase12_bogota3['phase'] = 'phase12'

# %%
import pylab as pl

df.hist(column='exploration', by='phase')
pl.suptitle("Bogota 3")
# Out:
# Text(0.5, 0.98, 'Bogota 3')

# %% [markdown]
# >> Comments: Distribution becomes more skewed over time.

# %%
phase45_bogota2['phase'] = 'phase45'
phase34_bogota2['phase'] = 'phase34'
phase23_bogota2['phase'] = 'phase23'
phase12_bogota2['phase'] = 'phase12'
df_bogota2 = pd.concat([phase45_bogota2, phase34_bogota2, phase23_bogota2, phase12_bogota2], ignore_index=True)
df_bogota2['exploration'] = 1 - df_bogota2['similarity']
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/3247058862.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase45_bogota2['phase'] = 'phase45'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/3247058862.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase34_bogota2['phase'] = 'phase34'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/3247058862.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase23_bogota2['phase'] = 'phase23'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/3247058862.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase12_bogota2['phase'] = 'phase12'

# %%
import pylab as pl

df_bogota2.hist(column='exploration', by='phase')
pl.suptitle("Bogota 2")
# Out:
# Text(0.5, 0.98, 'Bogota 2')

# %%
phase45_bogota1['phase'] = 'phase45'
phase34_bogota1['phase'] = 'phase34'
phase23_bogota1['phase'] = 'phase23'
phase12_bogota1['phase'] = 'phase12'
df_bogota1 = pd.concat([phase45_bogota1, phase34_bogota1, phase23_bogota1, phase12_bogota1], ignore_index=True)
df_bogota1['exploration'] = 1 - df_bogota1['similarity']
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/1378610476.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase45_bogota1['phase'] = 'phase45'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/1378610476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase34_bogota1['phase'] = 'phase34'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/1378610476.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase23_bogota1['phase'] = 'phase23'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/1378610476.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase12_bogota1['phase'] = 'phase12'

# %%
import pylab as pl

df_bogota1.hist(column='exploration', by='phase')
pl.suptitle("Bogota 1")
# Out:
# Text(0.5, 0.98, 'Bogota 1')

# %%
phase45_bogota0['phase'] = 'phase45'
phase34_bogota0['phase'] = 'phase34'
phase23_bogota0['phase'] = 'phase23'
phase12_bogota0['phase'] = 'phase12'
df_bogota0 = pd.concat([phase45_bogota0, phase34_bogota0, phase23_bogota0, phase12_bogota0], ignore_index=True)
df_bogota0['exploration'] = 1 - df_bogota1['similarity']
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/2904350072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase45_bogota0['phase'] = 'phase45'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/2904350072.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase34_bogota0['phase'] = 'phase34'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/2904350072.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase23_bogota0['phase'] = 'phase23'
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_7611/2904350072.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase12_bogota0['phase'] = 'phase12'

# %%
import pylab as pl

df_bogota0.hist(column='exploration', by='phase')
pl.suptitle("Bogota 0")
# Out:
# Text(0.5, 0.98, 'Bogota 0')

# %%
# %store df1
# %store df2
# %store df3
# %store df4

# %store df1_bogota0
# %store df2_bogota0
# %store df3_bogota0
# %store df4_bogota0

# %store df1_bogota1
# %store df2_bogota1
# %store df3_bogota1
# %store df4_bogota1

# %store df1_bogota2
# %store df2_bogota2
# %store df3_bogota2
# %store df4_bogota2

# %store subset_bogota0_phase1
# %store subset_bogota0_phase2
# %store subset_bogota0_phase3
# %store overall_phase4_bogota0
# %store overall_phase5_bogota0
# %store subset_bogota1_phase1
# %store subset_bogota1_phase2
# %store subset_bogota1_phase3
# %store overall_phase4_bogota1
# %store overall_phase5_bogota1
# %store subset_bogota2_phase1
# %store subset_bogota2_phase2
# %store subset_bogota2_phase3
# %store overall_phase4_bogota2
# %store subset_bogota2_phase5
# %store subset_bogota3_phase1
# %store overall_phase1_bogota3
# %store overall_phase2_bogota3
# %store subset_bogota3_phase3
# %store overall_phase4_bogota3
# %store overall_phase5_bogota3

# %store overall_phase1
# %store overall_phase2
# %store overall_phase3
# %store overall_phase4
# %store overall_phase5
# Out:
# Stored 'df1' (DataFrame)
# Stored 'df2' (DataFrame)
# Stored 'df3' (DataFrame)
# Stored 'df4' (DataFrame)
# Stored 'df1_bogota0' (DataFrame)
# Stored 'df2_bogota0' (DataFrame)
# Stored 'df3_bogota0' (DataFrame)
# Stored 'df4_bogota0' (DataFrame)
# Stored 'df1_bogota1' (DataFrame)
# Stored 'df2_bogota1' (DataFrame)
# Stored 'df3_bogota1' (DataFrame)
# Stored 'df4_bogota1' (DataFrame)
# Stored 'df1_bogota2' (DataFrame)
# Stored 'df2_bogota2' (DataFrame)
# Stored 'df3_bogota2' (DataFrame)
# Stored 'df4_bogota2' (DataFrame)
# Stored 'subset_bogota0_phase1' (DataFrame)
# Stored 'subset_bogota0_phase2' (DataFrame)
# Stored 'subset_bogota0_phase3' (DataFrame)
# Stored 'overall_phase4_bogota0' (DataFrame)
# Stored 'overall_phase5_bogota0' (DataFrame)
# Stored 'subset_bogota1_phase1' (DataFrame)
# Stored 'subset_bogota1_phase2' (DataFrame)
# Stored 'subset_bogota1_phase3' (DataFrame)
# Stored 'overall_phase4_bogota1' (DataFrame)
# Stored 'overall_phase5_bogota1' (DataFrame)
# Stored 'subset_bogota2_phase1' (DataFrame)
# Stored 'subset_bogota2_phase2' (DataFrame)
# Stored 'subset_bogota2_phase3' (DataFrame)
# Stored 'overall_phase4_bogota2' (DataFrame)
# Stored 'subset_bogota2_phase5' (DataFrame)
# Stored 'subset_bogota3_phase1' (DataFrame)
# Stored 'overall_phase1_bogota3' (DataFrame)
# Stored 'overall_phase2_bogota3' (DataFrame)
# Stored 'subset_bogota3_phase3' (DataFrame)
# Stored 'overall_phase4_bogota3' (DataFrame)
# Stored 'overall_phase5_bogota3' (DataFrame)
# Stored 'overall_phase1' (DataFrame)
# Stored 'overall_phase2' (DataFrame)
# Stored 'overall_phase3' (DataFrame)
# Stored 'overall_phase4' (DataFrame)
# Stored 'overall_phase5' (DataFrame)
