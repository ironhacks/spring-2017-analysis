# %% [markdown]
# ## Template Similarity
#
# > This metrics look to share some similarities with the approach from Bernstein et. al. (2018). However the metrics remains to be validated.

# %%
# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5
# %store -r df_all
# %store -r overall_loc_scores_final
# %store -r overall_loc_scores
# %store -r template_functions

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ast

# %%
template_functions = pd.read_csv('data-from-ironhub/output_template.txt', header=None, sep='\0', names=['functions'], converters={ 'functions' : ast.literal_eval })
template_functions = template_functions['functions'].iloc[0]
template_functions
# Out:
# ['bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.css',
#  'tutorial.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'RadarChart.js',
#  'tutorial.js',
#  'scripto.js',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  'to.toUpperCase',
#  'this.splice',
#  'google.maps.Map',
#  'z.document.getElementById',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'pxmlhttp.open',
#  'xmlhttp.send',
#  'rentxmlhttp.onreadystatechange',
#  'hxmlhttp.readyState',
#  'xmlhttp.status',
#  'pxmlhttp.responseText',
#  'JSON.parse',
#  'json.data',
#  'km.innerHTML',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListenerOnce',
#  'google.maps.ElevationService',
#  'o.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'bounds.getNorthEast',
#  'northEast.lng',
#  'southWest.lng',
#  'northEast.lat',
#  'southWest.lat',
#  'google.maps.LatLng',
#  '.Math.random',
#  'locations.push',
#  'elevation.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'google.maps.Marker',
#  'okey.toString',
#  '.slices',
#  'infWindow.close',
#  'infowindow.setContent',
#  'infowindowP.open',
#  '.capitalizeFirstLetter',
#  'RadarChart.draw',
#  'arr.length',
#  '.url',
#  'u.display',
#  'str.indexOf',
#  'dt.getDay',
#  'api.openweathermap.org',
#  '.coord.lon',
#  'json.weather',
#  'r.main',
#  't.select',
#  'g.selectAll',
#  'g.append',
#  'Z.attr',
#  'cfg.w',
#  'cfg.h',
#  '.scale.category',
#  'svg.append',
#  'j.text',
#  'title.selectAll',
#  'H.data',
#  'n.enter',
#  'm.style',
#  'g.resize',
#  '.height',
#  '.css',
#  'Math.PI',
#  'cfg.maxValue',
#  'Math.max',
#  '.max',
#  'i.map',
#  'o.value',
#  '.map',
#  'i.axis',
#  'allAxis.length',
#  'cfg.factor',
#  'Math.min',
#  'n.format',
#  'd.remove',
#  'cfg.ExtraWidthY',
#  'cfg.ExtraWidthY',
#  'cfg.TranslateY',
#  'cfg.TranslateY',
#  'cfg.levels',
#  'g.selectAll',
#  'c.levels',
#  'Math.sinh',
#  'cfg.radians',
#  'Math.acos',
#  'cfg.ToRight',
#  'd.axis',
#  'axis.append',
#  'cfg.factortitle',
#  'ids.forEach',
#  'c.nodes',
#  'dataValues.push',
#  'j.value',
#  't.area',
#  'cfg.color',
#  'dx.length',
#  'cfg.opacityArea',
#  '.on',
#  '.transiting',
#  'cfg.radius',
#  'j.axis',
#  'd.values',
#  'g.append']

# %%
overall_phase1 = overall_phase1.loc[(overall_phase1['len_unique'] != 0 )]
overall_phase1 = overall_phase1.dropna()
overall_phase1
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 5            DglyP    0.0                     20.0           25.00
# 8      Judgarciani    0.0                    100.0           58.33
# 9        sacastroc    0.0                     20.0           50.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 5             50.00        195.00        100.0         87.5
# 8             66.67        325.00        100.0         75.0
# 9             68.75        226.25         87.5         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 5                        0.0           25.00  ...               21.5
# 8                       80.0           87.50  ...              -19.5
# 9                       20.0           50.00  ...                0.0
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 5                  0.0              -11.0                3.0
# 8                  4.0               44.0                8.5
# 9                  1.0               13.0                0.5
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 5                -31.0                0.0
# 8                  1.0                1.0
# 9                  0.5                0.5
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...
# 1    [style.css, map.js, document.getElementById, g...
# 5             [bootstrap.min.css, style.css, .JS, .js]
# 8    [jquery.min.js, .js, Rent.js, Crimes.js, googl...
# 9    [js.org, .v, .min.js, bootstrap.min.css, theme...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, jquery.min.js, ...
# 157  [bootstrap.min.css, theme.min.css, jquery.min....
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.js, tutorial.css...
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        21.0
# 1    [style.css, map.js, document.getElementById, g...         5.0
# 5             [bootstrap.min.css, style.css, .JS, .js]         4.0
# 8    [jquery.min.js, .js, Rent.js, Crimes.js, googl...        40.0
# 9    [js.org, .v, .min.js, bootstrap.min.css, theme...         7.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        20.0
# 156  [bootstrap.min.css, style.css, jquery.min.js, ...        27.0
# 157  [bootstrap.min.css, theme.min.css, jquery.min....       122.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...        20.0
# 159  [jquery.min.js, bootstrap.min.js, tutorial.css...        33.0
#
#      len_functions
# 0             21.0
# 1              5.0
# 5              4.0
# 8             40.0
# 9              7.0
# ..             ...
# 155           20.0
# 156           27.0
# 157          122.0
# 158           20.0
# 159           33.0
#
# [127 rows x 90 columns]

# %%
overall_phase2 = overall_phase2.loc[(overall_phase2['len_unique'] != 0 )]
overall_phase2 = overall_phase2.dropna()
overall_phase2
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 4     jjrodriguezn    0.0                     60.0           58.33
# 5            DglyP    0.0                     20.0           25.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 4             87.50        255.83         50.0         37.5
# 5             50.00        195.00        100.0         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 4                       40.0           54.17  ...              104.0
# 5                        0.0           25.00  ...               21.5
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 2                  1.5                9.0               -4.0
# 4                  8.0               60.5                0.5
# 5                  0.0              -11.0                3.0
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 4                  0.0               34.5
# 5                -31.0                0.0
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...
# 1    [house.ico, style.css, map.js, Chicago.jpg, do...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...
# 5    [.ready, .click, .ajax, console.log, result.re...
# ..                                                 ...
# 155  [bootstrap.min.css, implementation.js, google....
# 156  [bootstrap.min.css, style.css, farmermarket.st...
# 157  [.js, jsInitMap.js, document.getElementById, g...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.js, tutorial.css...
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        30.0
# 1    [house.ico, style.css, map.js, Chicago.jpg, do...        25.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        67.0
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...        19.0
# 5    [.ready, .click, .ajax, console.log, result.re...        24.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, implementation.js, google....        31.0
# 156  [bootstrap.min.css, style.css, farmermarket.st...        40.0
# 157  [.js, jsInitMap.js, document.getElementById, g...        13.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...        20.0
# 159  [jquery.min.js, bootstrap.min.js, tutorial.css...        39.0
#
#      len_functions
# 0             30.0
# 1             25.0
# 2             67.0
# 4             19.0
# 5             24.0
# ..             ...
# 155           31.0
# 156           40.0
# 157           13.0
# 158           20.0
# 159           39.0
#
# [135 rows x 90 columns]

# %%
overall_phase3 = overall_phase3.loc[(overall_phase3['len_unique'] != 0 )]
overall_phase3 = overall_phase3.dropna()
overall_phase3
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 4     jjrodriguezn    0.0                     60.0           58.33
# 5            DglyP    0.0                     20.0           25.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 4             87.50        255.83         50.0         37.5
# 5             50.00        195.00        100.0         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 4                       40.0           54.17  ...              104.0
# 5                        0.0           25.00  ...               21.5
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 2                  1.5                9.0               -4.0
# 4                  8.0               60.5                0.5
# 5                  0.0              -11.0                3.0
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 4                  0.0               34.5
# 5                -31.0                0.0
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...
# 1    [house.ico, style.css, .css, main.js, map.js, ...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 4    [google.maps.Map, document.getElementById, goo...
# 5    [.ready, .click, .ajax, console.log, result.re...
# ..                                                 ...
# 155  [bootstrap.min.css, jquery.min.js, implementat...
# 156  [bootstrap.min.css, style.css, farmermarket.st...
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.js, tutorial.css...
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        30.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2273.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        67.0
# 4    [google.maps.Map, document.getElementById, goo...        27.0
# 5    [.ready, .click, .ajax, console.log, result.re...        24.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, jquery.min.js, implementat...        40.0
# 156  [bootstrap.min.css, style.css, farmermarket.st...        44.0
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...        17.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...        20.0
# 159  [jquery.min.js, bootstrap.min.js, tutorial.css...        95.0
#
#      len_functions
# 0             30.0
# 1           2273.0
# 2             67.0
# 4             27.0
# 5             24.0
# ..             ...
# 155           40.0
# 156           44.0
# 157           17.0
# 158           20.0
# 159           95.0
#
# [135 rows x 90 columns]

# %%
overall_phase4 = overall_phase4.loc[(overall_phase4['len_unique'] != 0 )]
overall_phase4 = overall_phase4.dropna()
overall_phase4
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 3       katherinsb    0.0                     20.0           37.50
# 4     jjrodriguezn    0.0                     60.0           58.33
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...              104.0
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 2                  1.5                9.0               -4.0
# 3                  0.0                0.0               73.5
# 4                  8.0               60.5                0.5
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 3                  0.0                0.0
# 4                  0.0               34.5
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, .click, .removeClass, .is, .val, .che...
# 1    [house.ico, style.css, .css, main.js, map.js, ...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3    [reset.css, layout.css, style.css, .js, yui.js...
# 4    [google.maps.Map, document.getElementById, goo...
# ..                                                 ...
# 155  [bootstrap.min.css, creative.min.css, jquery.m...
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.js, .js, script....
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .removeClass, .is, .val, .che...       106.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2290.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        67.0
# 3    [reset.css, layout.css, style.css, .js, yui.js...        21.0
# 4    [google.maps.Map, document.getElementById, goo...        28.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, creative.min.css, jquery.m...        44.0
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...        39.0
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...        66.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...       678.0
# 159  [jquery.min.js, bootstrap.min.js, .js, script....       166.0
#
#      len_functions
# 0            106.0
# 1           2290.0
# 2             67.0
# 3             21.0
# 4             28.0
# ..             ...
# 155           44.0
# 156           39.0
# 157           66.0
# 158          678.0
# 159          166.0
#
# [138 rows x 90 columns]

# %%
overall_phase5 = overall_phase5.loc[(overall_phase5['len_unique'] != 0 )]
overall_phase5 = overall_phase5.dropna()
overall_phase5
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 3       katherinsb    0.0                     20.0           37.50
# 4     jjrodriguezn    0.0                     60.0           58.33
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...              104.0
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 2                  1.5                9.0               -4.0
# 3                  0.0                0.0               73.5
# 4                  8.0               60.5                0.5
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 3                  0.0                0.0
# 4                  0.0               34.5
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...
# 1    [house.ico, style.css, .css, main.js, map.js, ...
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...
# 3    [reset.css, layout.css, style.css, jquery.min....
# 4    [google.maps.Map, document.getElementById, goo...
# ..                                                 ...
# 155  [bootstrap.min.css, creative.min.css, jquery.m...
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 157  [bootstrap.min.css, jquery.min.js, .min.css, t...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.js, .js, script....
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...       116.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2297.0
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...        67.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2290.0
# 4    [google.maps.Map, document.getElementById, goo...        31.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, creative.min.css, jquery.m...        57.0
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...        42.0
# 157  [bootstrap.min.css, jquery.min.js, .min.css, t...        75.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...       133.0
# 159  [jquery.min.js, bootstrap.min.js, .js, script....       181.0
#
#      len_functions
# 0            116.0
# 1           2297.0
# 2             67.0
# 3           2290.0
# 4             31.0
# ..             ...
# 155           57.0
# 156           42.0
# 157           75.0
# 158          133.0
# 159          181.0
#
# [138 rows x 90 columns]

# %%
overall_phase1_group0 = overall_phase1.loc[overall_phase1['Group'] == 0]
overall_phase1_group1 = overall_phase1.loc[overall_phase1['Group'] == 1]
overall_phase1_group2 = overall_phase1.loc[overall_phase1['Group'] == 2]
overall_phase1_group3 = overall_phase1.loc[overall_phase1['Group'] == 3]

# %%
overall_phase2_group0 = overall_phase2.loc[overall_phase2['Group'] == 0]
overall_phase2_group1 = overall_phase2.loc[overall_phase2['Group'] == 1]
overall_phase2_group2 = overall_phase2.loc[overall_phase2['Group'] == 2]
overall_phase2_group3 = overall_phase2.loc[overall_phase2['Group'] == 3]

# %%
overall_phase3_group0 = overall_phase3.loc[overall_phase3['Group'] == 0]
overall_phase3_group1 = overall_phase3.loc[overall_phase3['Group'] == 1]
overall_phase3_group2 = overall_phase3.loc[overall_phase3['Group'] == 2]
overall_phase3_group3 = overall_phase3.loc[overall_phase3['Group'] == 3]

# %%
overall_phase4_group0 = overall_phase4.loc[overall_phase4['Group'] == 0]
overall_phase4_group1 = overall_phase4.loc[overall_phase4['Group'] == 1]
overall_phase4_group2 = overall_phase4.loc[overall_phase4['Group'] == 2]
overall_phase4_group3 = overall_phase4.loc[overall_phase4['Group'] == 3]

# %%
overall_phase5_group0 = overall_phase5.loc[overall_phase5['Group'] == 0]
overall_phase5_group1 = overall_phase5.loc[overall_phase5['Group'] == 1]
overall_phase5_group2 = overall_phase5.loc[overall_phase5['Group'] == 2]
overall_phase5_group3 = overall_phase5.loc[overall_phase5['Group'] == 3]

# %%
df_template = {'Student': ['template'], 'functions': [template_functions], 'phase': [0]}
df_template = pd.DataFrame(data=df_template)
df_template
# Out:
#     Student                                          functions  phase
# 0  template  [bootstrap.min.css, theme.min.css, jquery.min....      0

# %%
overall_phase1_group0['unique'] = [','.join(map(str, l)) for l in overall_phase1_group0['unique']]
overall_phase1_group1['unique'] = [','.join(map(str, l)) for l in overall_phase1_group1['unique']]
overall_phase1_group2['unique'] = [','.join(map(str, l)) for l in overall_phase1_group2['unique']]
overall_phase1_group3['unique'] = [','.join(map(str, l)) for l in overall_phase1_group3['unique']]

overall_phase2_group0['unique'] = [','.join(map(str, l)) for l in overall_phase2_group0['unique']]
overall_phase2_group1['unique'] = [','.join(map(str, l)) for l in overall_phase2_group1['unique']]
overall_phase2_group2['unique'] = [','.join(map(str, l)) for l in overall_phase2_group2['unique']]
overall_phase2_group3['unique'] = [','.join(map(str, l)) for l in overall_phase2_group3['unique']]

overall_phase3_group0['unique'] = [','.join(map(str, l)) for l in overall_phase3_group0['unique']]
overall_phase3_group1['unique'] = [','.join(map(str, l)) for l in overall_phase3_group1['unique']]
overall_phase3_group2['unique'] = [','.join(map(str, l)) for l in overall_phase3_group2['unique']]
overall_phase3_group3['unique'] = [','.join(map(str, l)) for l in overall_phase3_group3['unique']]

overall_phase4_group0['unique'] = [','.join(map(str, l)) for l in overall_phase4_group0['unique']]
overall_phase4_group1['unique'] = [','.join(map(str, l)) for l in overall_phase4_group1['unique']]
overall_phase4_group2['unique'] = [','.join(map(str, l)) for l in overall_phase4_group2['unique']]
overall_phase4_group3['unique'] = [','.join(map(str, l)) for l in overall_phase4_group3['unique']]

overall_phase5_group0['unique'] = [','.join(map(str, l)) for l in overall_phase5_group0['unique']]
overall_phase5_group1['unique'] = [','.join(map(str, l)) for l in overall_phase5_group1['unique']]
overall_phase5_group2['unique'] = [','.join(map(str, l)) for l in overall_phase5_group2['unique']]
overall_phase5_group3['unique'] = [','.join(map(str, l)) for l in overall_phase5_group3['unique']]
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group0['unique'] = [','.join(map(str, l)) for l in overall_phase1_group0['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group1['unique'] = [','.join(map(str, l)) for l in overall_phase1_group1['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group2['unique'] = [','.join(map(str, l)) for l in overall_phase1_group2['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group3['unique'] = [','.join(map(str, l)) for l in overall_phase1_group3['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group0['unique'] = [','.join(map(str, l)) for l in overall_phase2_group0['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group1['unique'] = [','.join(map(str, l)) for l in overall_phase2_group1['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group2['unique'] = [','.join(map(str, l)) for l in overall_phase2_group2['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group3['unique'] = [','.join(map(str, l)) for l in overall_phase2_group3['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group0['unique'] = [','.join(map(str, l)) for l in overall_phase3_group0['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group1['unique'] = [','.join(map(str, l)) for l in overall_phase3_group1['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group2['unique'] = [','.join(map(str, l)) for l in overall_phase3_group2['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group3['unique'] = [','.join(map(str, l)) for l in overall_phase3_group3['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group0['unique'] = [','.join(map(str, l)) for l in overall_phase4_group0['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group1['unique'] = [','.join(map(str, l)) for l in overall_phase4_group1['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group2['unique'] = [','.join(map(str, l)) for l in overall_phase4_group2['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group3['unique'] = [','.join(map(str, l)) for l in overall_phase4_group3['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group0['unique'] = [','.join(map(str, l)) for l in overall_phase5_group0['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group1['unique'] = [','.join(map(str, l)) for l in overall_phase5_group1['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group2['unique'] = [','.join(map(str, l)) for l in overall_phase5_group2['unique']]
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4231300064.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group3['unique'] = [','.join(map(str, l)) for l in overall_phase5_group3['unique']]

# %%
overall_phase1_group0 = overall_phase1_group0.append(df_template, ignore_index=True)
overall_phase1_group1 = overall_phase1_group1.append(df_template, ignore_index=True)
overall_phase1_group2 = overall_phase1_group2.append(df_template, ignore_index=True)
overall_phase1_group3 = overall_phase1_group3.append(df_template, ignore_index=True)

overall_phase2_group0 = overall_phase2_group0.append(df_template, ignore_index=True)
overall_phase2_group1 = overall_phase2_group1.append(df_template, ignore_index=True)
overall_phase2_group2 = overall_phase2_group2.append(df_template, ignore_index=True)
overall_phase2_group3 = overall_phase2_group3.append(df_template, ignore_index=True)

overall_phase3_group0 = overall_phase3_group0.append(df_template, ignore_index=True)
overall_phase3_group1 = overall_phase3_group1.append(df_template, ignore_index=True)
overall_phase3_group2 = overall_phase3_group2.append(df_template, ignore_index=True)
overall_phase3_group3 = overall_phase3_group3.append(df_template, ignore_index=True)

overall_phase4_group0 = overall_phase4_group0.append(df_template, ignore_index=True)
overall_phase4_group1 = overall_phase4_group1.append(df_template, ignore_index=True)
overall_phase4_group2 = overall_phase4_group2.append(df_template, ignore_index=True)
overall_phase4_group3 = overall_phase4_group3.append(df_template, ignore_index=True)

overall_phase5_group0 = overall_phase5_group0.append(df_template, ignore_index=True)
overall_phase5_group1 = overall_phase5_group1.append(df_template, ignore_index=True)
overall_phase5_group2 = overall_phase5_group2.append(df_template, ignore_index=True)
overall_phase5_group3 = overall_phase5_group3.append(df_template, ignore_index=True)
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase1_group0 = overall_phase1_group0.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase1_group1 = overall_phase1_group1.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase1_group2 = overall_phase1_group2.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase1_group3 = overall_phase1_group3.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase2_group0 = overall_phase2_group0.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase2_group1 = overall_phase2_group1.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase2_group2 = overall_phase2_group2.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase2_group3 = overall_phase2_group3.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase3_group0 = overall_phase3_group0.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase3_group1 = overall_phase3_group1.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase3_group2 = overall_phase3_group2.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase3_group3 = overall_phase3_group3.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase4_group0 = overall_phase4_group0.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase4_group1 = overall_phase4_group1.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase4_group2 = overall_phase4_group2.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase4_group3 = overall_phase4_group3.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase5_group0 = overall_phase5_group0.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase5_group1 = overall_phase5_group1.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:23: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase5_group2 = overall_phase5_group2.append(df_template, ignore_index=True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/3402350379.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   overall_phase5_group3 = overall_phase5_group3.append(df_template, ignore_index=True)

# %%
overall_phase5_group3
# Out:
#             Student  Group  user-requirement-phase5  infovis-phase5  \
# 0         lemartinp    3.0                    100.0           54.17
# 1         juligarji    3.0                    100.0           75.00
# 2         nfmorenog    3.0                      0.0           37.50
# 3         AFelipeGA    3.0                     40.0           37.50
# 4        mballeng91    3.0                      0.0           25.00
# 5          dduartec    3.0                     80.0           83.33
# 6         srmedinac    3.0                     20.0           33.33
# 7      wilson911013    3.0                      0.0           25.00
# 8     wapiravaguens    3.0                     80.0           75.00
# 9          davidh17    3.0                     20.0           45.83
# 10   DianaNavarrete    3.0                     20.0           62.50
# 11        jdmonroyg    3.0                      0.0           25.00
# 12        jorge52an    3.0                    100.0           50.00
# 13  jscastelblancoh    3.0                    100.0           83.33
# 14       juclopezso    3.0                     60.0           50.00
# 15        afforeroc    3.0                     20.0           29.17
# 16      dagofonseca    3.0                     40.0           37.50
# 17      lacardenasv    3.0                    100.0           75.00
# 18      oacastillol    3.0                     60.0           62.50
# 19       ncampuzano    3.0                     20.0           45.83
# 20         adriel62    3.0                     80.0           66.67
# 21         capinzor    3.0                     20.0           25.00
# 22         ofnanezn    3.0                     40.0           58.33
# 23        macuestap    3.0                     40.0           50.00
# 24           spenas    3.0                     20.0           33.33
# 25      kgbayala528    3.0                     80.0           50.00
# 26       lgmoralesa    3.0                    100.0           70.83
# 27       ronaldsg20    3.0                     20.0           45.83
# 28    cccristanchoc    3.0                     20.0           33.33
# 29       jmalvarezd    3.0                     80.0           75.00
# 30        smarquezo    3.0                     20.0           33.33
# 31          sarizag    3.0                     20.0           33.33
# 32         Chranium    3.0                     20.0           25.00
# 33          DavidQP    3.0                     80.0           70.83
# 34      afceballosr    3.0                     80.0           45.83
# 35        lizzyt10h    3.0                     20.0           54.17
# 36       NicolasPrr    3.0                    100.0           83.33
# 37    jumcorredorro    3.0                    100.0           62.50
# 38         template    NaN                      NaN             NaN
#
#     novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0            87.50        329.17         87.5         87.5
# 1            92.50        355.00         87.5        100.0
# 2            15.00        127.50         75.0         75.0
# 3            56.25        221.25         87.5         75.0
# 4            25.00        112.50         62.5         62.5
# 5            95.00        345.83         87.5         87.5
# 6             0.00        128.33         75.0         62.5
# 7             0.00         75.00         50.0         37.5
# 8            72.50        327.50        100.0         62.5
# 9            56.25        209.58         87.5         75.0
# 10           25.00        145.00         37.5         37.5
# 11           25.00         75.00         25.0          0.0
# 12           60.00        310.00        100.0         75.0
# 13          100.00        358.33         75.0         75.0
# 14           81.25        278.75         87.5         62.5
# 15           50.00        161.67         62.5         50.0
# 16           66.67        231.67         87.5         87.5
# 17           75.00        350.00        100.0         87.5
# 18           37.50        235.00         75.0         62.5
# 19           50.00        203.33         87.5         62.5
# 20           67.50        301.67         87.5         87.5
# 21           58.33        203.33        100.0         87.5
# 22           25.00        198.33         75.0         50.0
# 23           25.00        177.50         62.5         62.5
# 24            0.00        115.83         62.5         62.5
# 25           81.25        298.75         87.5         62.5
# 26           87.50        345.83         87.5         87.5
# 27           12.50        178.33        100.0        100.0
# 28           56.25        197.08         87.5         62.5
# 29           93.75        348.75        100.0         87.5
# 30           57.50        185.83         75.0         62.5
# 31           56.25        209.58        100.0         75.0
# 32            0.00         95.00         50.0         50.0
# 33           83.33        284.17         50.0         50.0
# 34           57.50        270.83         87.5         87.5
# 35           81.25        255.42        100.0        100.0
# 36           90.00        360.83         87.5         62.5
# 37           75.00        325.00         87.5         87.5
# 38             NaN           NaN          NaN          NaN
#
#     user-requirement-phase4  infovis-phase4  ...  improve-effort-23  \
# 0                      80.0           58.33  ...                0.0
# 1                     100.0           70.83  ...                6.5
# 2                       0.0           33.33  ...                2.5
# 3                      40.0           37.50  ...                0.0
# 4                       0.0           25.00  ...                0.0
# 5                       0.0            0.00  ...                3.5
# 6                      20.0           33.33  ...                1.0
# 7                      20.0           25.00  ...                0.0
# 8                      80.0           75.00  ...                4.0
# 9                       0.0            0.00  ...              -17.0
# 10                     20.0           58.33  ...                0.0
# 11                      0.0            0.00  ...                0.0
# 12                     60.0           33.33  ...                2.5
# 13                    100.0           66.67  ...              -13.5
# 14                     60.0           29.17  ...                0.0
# 15                     20.0           29.17  ...                0.0
# 16                     40.0           37.50  ...               -4.0
# 17                     60.0           37.50  ...              -23.5
# 18                      0.0           33.33  ...               -5.0
# 19                     20.0           37.50  ...              177.5
# 20                     40.0           33.33  ...              -23.0
# 21                     20.0           25.00  ...               60.5
# 22                     20.0           33.33  ...               11.0
# 23                     20.0           41.67  ...                5.0
# 24                     20.0           33.33  ...                0.0
# 25                     60.0           45.83  ...              -36.0
# 26                    100.0           66.67  ...                2.0
# 27                     20.0           33.33  ...              -25.5
# 28                     20.0           33.33  ...                0.0
# 29                     60.0           70.83  ...                0.0
# 30                     20.0           29.17  ...                0.0
# 31                     20.0           33.33  ...                0.0
# 32                     20.0           25.00  ...                0.0
# 33                     80.0           66.67  ...               28.5
# 34                     40.0           50.00  ...               -3.5
# 35                      0.0           29.17  ...                0.0
# 36                      0.0           33.33  ...                0.0
# 37                     80.0           58.33  ...               12.0
# 38                      NaN             NaN  ...                NaN
#
#     improve-effort-34  improve-effort-45  improve-effort-15  \
# 0               -97.0                0.0             -137.5
# 1                10.5               22.0              -91.5
# 2                 1.0                0.0               -3.5
# 3                 0.0                0.0              -76.5
# 4                 2.5                0.0                2.5
# 5                 0.0                0.0                3.5
# 6                 0.5                0.0              -66.0
# 7                 0.0                0.0                0.0
# 8                 4.0               -1.0               -5.5
# 9               127.0               34.0              -57.0
# 10                0.0                0.0               21.5
# 11                0.0                0.0              -41.0
# 12                4.0              -23.0              -37.5
# 13              -20.0              -10.0              -77.0
# 14              -62.5              125.0                0.0
# 15                0.0                0.0                0.0
# 16               -4.5              -25.0              -39.5
# 17              -86.0               11.0              -14.5
# 18              -27.5               -1.0              -48.0
# 19                0.0             -117.5              -93.5
# 20               74.5               90.5               19.5
# 21               56.0              -22.5              -22.5
# 22                0.0                0.0               18.5
# 23               -2.5                0.0                0.0
# 24                0.0                0.0               53.5
# 25                0.0                0.0              -34.5
# 26               -3.0               53.0               51.5
# 27                2.0                3.0               -8.0
# 28                0.0                8.5                8.0
# 29                0.0               -1.0                7.0
# 30              -37.5             -159.5             -278.0
# 31             -423.0              840.0              -27.0
# 32                0.0                0.0                0.0
# 33               -1.0               -4.5                3.0
# 34               58.0                0.5                0.0
# 35                4.5               -4.0               11.5
# 36              -36.5                0.0               16.5
# 37                1.0                1.0               11.5
# 38                NaN                NaN                NaN
#
#     improve-effort-25                                          functions  \
# 0               -98.0  [bootstrap.min.css, style.css, jquery.min.js, ...
# 1                17.0  [bootstrap.min.css, mainPage.css, awesome.min....
# 2                 2.0  [FirstLook.css, bootstrap.min.css, jquery.min....
# 3                 0.0  [materialize.min.css, style.css, awesome.min.c...
# 4                 2.5  [Error.stackTraceLimit, jasmine.DEFAULT, karma...
# 5                 9.5  [.js, style.css, superplaceholder.js, superpla...
# 6                 1.5  [bootstrap.min.css, awesome.min.css, icons.css...
# 7                 0.0                         [.js, jsInitMap.js, .ajax]
# 8                 4.5  [.css, .js, js.org, .v, bootstrap.min.css, the...
# 9                28.0  [bootstrap.min.css, styles.css, jquery.min.js,...
# 10                0.0  [.l, morado.jpg, a.active, .active, google.map...
# 11                0.0  [.mifecha, bootstrap.min.css, theme.min.css, j...
# 12              -26.0  [main.css, material.min.css, angular.min.js, a...
# 13              -62.0  [bootstrap.min.css, theme.min.css, style.css, ...
# 14             -125.0  [bootstrap.min.css, portfolio.css, awesome.min...
# 15              -41.5  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...
# 16                3.0  [campuapi.azurewebsites.net, GetRegionChildren...
# 17              -24.0  [awesome.min.css, bootstrap.min.css, materiali...
# 18              -36.5  [bootstrap.min.css, theme.min.css, awesome.min...
# 19               59.5  [bootstrap.min.css, awesome.min.css, app.css, ...
# 20               46.5  [favicon.ico, .min.js, bootstrap.min.js, appli...
# 21                8.5  [bootstrap.min.css, estilos.css, .min.js, boot...
# 22               11.0  [bootstrap.min.css, awesome.min.css, grayscale...
# 23                2.5  [style.css, favicon.ico, bootstrap.min.css, th...
# 24                0.0  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 25              -36.0  [latest.min.js, jquery.min.js, bootstrap.min.c...
# 26               43.5  [bootstrap.min.css, index.css, jquery.js, boot...
# 27               -8.0  [ownStyle.css, theme.min.css, bootstrap.min.cs...
# 28              -17.0  [unal.edu.co, bootstrap.min.css, template.css,...
# 29               -1.0  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 30             -210.0  [bootstrap.min.css, data.json, jquery.min.js, ...
# 31               -8.5  [js.org, .v, .min.js, style.css, jquery.min.js...
# 32                2.5  [style.css, main.js, document.getElementById, ...
# 33                6.0  [bootstrap.min.css, creative.min.css, jquery.m...
# 34                0.0  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 35                8.0  [bootstrap.min.css, jquery.min.js, .min.css, t...
# 36               16.5  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 37               11.5  [jquery.min.js, bootstrap.min.js, .js, script....
# 38                NaN  [bootstrap.min.css, theme.min.css, jquery.min....
#
#                                                unique  len_unique  \
# 0   bootstrap.min.css,style.css,jquery.min.js,boot...        26.0
# 1   bootstrap.min.css,mainPage.css,awesome.min.css...      2567.0
# 2   FirstLook.css,bootstrap.min.css,jquery.min.js,...        52.0
# 3   materialize.min.css,style.css,awesome.min.css,...      2059.0
# 4   Error.stackTraceLimit,jasmine.DEFAULT,karma.co...       179.0
# 5   .js,style.css,superplaceholder.js,superplaceho...      2338.0
# 6   bootstrap.min.css,awesome.min.css,icons.css,mo...        56.0
# 7                              .js,jsInitMap.js,.ajax         3.0
# 8   .css,.js,js.org,.v,bootstrap.min.css,theme.min...        89.0
# 9   bootstrap.min.css,styles.css,jquery.min.js,boo...        88.0
# 10  .l,morado.jpg,a.active,.active,google.maps.Map...         7.0
# 11  .mifecha,bootstrap.min.css,theme.min.css,jquer...        14.0
# 12  main.css,material.min.css,angular.min.js,angul...       318.0
# 13  bootstrap.min.css,theme.min.css,style.css,hove...       181.0
# 14  bootstrap.min.css,portfolio.css,awesome.min.cs...        30.0
# 15  bootstrap.min.css,uic.edu,.js,bootstrap.min.js...         7.0
# 16  campuapi.azurewebsites.net,GetRegionChildren.h...       271.0
# 17  awesome.min.css,bootstrap.min.css,materialize....      2056.0
# 18  bootstrap.min.css,theme.min.css,awesome.min.cs...       316.0
# 19  bootstrap.min.css,awesome.min.css,app.css,jque...       146.0
# 20  favicon.ico,.min.js,bootstrap.min.js,applicati...       161.0
# 21  bootstrap.min.css,estilos.css,.min.js,bootstra...      1846.0
# 22  bootstrap.min.css,awesome.min.css,grayscale.mi...        58.0
# 23  style.css,favicon.ico,bootstrap.min.css,theme....        17.0
# 24  bootstrap.min.css,mdb.min.css,demos.css,styles...        22.0
# 25  latest.min.js,jquery.min.js,bootstrap.min.css,...       108.0
# 26  bootstrap.min.css,index.css,jquery.js,bootstra...        77.0
# 27  ownStyle.css,theme.min.css,bootstrap.min.css,m...        71.0
# 28  unal.edu.co,bootstrap.min.css,template.css,dat...       100.0
# 29  jmalvarezd.js,bootstrap.min.css,jquery.min.js,...        53.0
# 30  bootstrap.min.css,data.json,jquery.min.js,boot...        64.0
# 31  js.org,.v,.min.js,style.css,jquery.min.js,scri...        40.0
# 32  style.css,main.js,document.getElementById,goog...         5.0
# 33  bootstrap.min.css,creative.min.css,jquery.min....        57.0
# 34  bootstrap.min.css,style.css,bulk.jpg,jquery.mi...        42.0
# 35  bootstrap.min.css,jquery.min.js,.min.css,this....        75.0
# 36  bootstrap.min.css,jquery.min.js,bootstrap.min....       133.0
# 37  jquery.min.js,bootstrap.min.js,.js,script.js,m...       181.0
# 38                                                NaN         NaN
#
#     len_functions  phase
# 0            26.0    NaN
# 1          2567.0    NaN
# 2            52.0    NaN
# 3          2059.0    NaN
# 4           179.0    NaN
# 5          2338.0    NaN
# 6            56.0    NaN
# 7             3.0    NaN
# 8            89.0    NaN
# 9            88.0    NaN
# 10            7.0    NaN
# 11           14.0    NaN
# 12          318.0    NaN
# 13          181.0    NaN
# 14           30.0    NaN
# 15            7.0    NaN
# 16          271.0    NaN
# 17         2056.0    NaN
# 18          316.0    NaN
# 19          146.0    NaN
# 20          161.0    NaN
# 21         1846.0    NaN
# 22           58.0    NaN
# 23           17.0    NaN
# 24           22.0    NaN
# 25          108.0    NaN
# 26           77.0    NaN
# 27           71.0    NaN
# 28          100.0    NaN
# 29           53.0    NaN
# 30           64.0    NaN
# 31           40.0    NaN
# 32            5.0    NaN
# 33           57.0    NaN
# 34           42.0    NaN
# 35           75.0    NaN
# 36          133.0    NaN
# 37          181.0    NaN
# 38            NaN    0.0
#
# [39 rows x 91 columns]

# %% [markdown]
# ## Phase 1 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group0 = overall_phase1_group0[overall_phase1_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group0["functions"], overall_phase1_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group0 = pd.DataFrame(result)
phase1_group0
# Out:
#             user1        user2  similarity
# 0       fffeelipe    mnguzmanc    0.083333
# 1       fffeelipe        DglyP    0.041667
# 2       fffeelipe  Judgarciani    0.051724
# 3       fffeelipe    sacastroc    0.166667
# 4       fffeelipe    pcberriop    0.070175
# ..            ...          ...         ...
# 271    capinillab    bsgarciac    0.121951
# 272    capinillab     template    0.024590
# 273  lfvalderrama    bsgarciac    0.079365
# 274  lfvalderrama     template    0.057554
# 275     bsgarciac     template    0.039735
#
# [276 rows x 3 columns]

# %%
phase1_group0 = phase1_group0.loc[phase1_group0['user2'] == 'template']
phase1_group0
# Out:
#               user1     user2  similarity
# 22        fffeelipe  template    0.037313
# 44        mnguzmanc  template    0.016529
# 65            DglyP  template    0.016667
# 85      Judgarciani  template    0.053333
# 104       sacastroc  template    0.050420
# 122       pcberriop  template    0.170370
# 139     hsmartineza  template    0.093023
# 155        Moimolcp  template    0.039735
# 170      JoseMolano  template    0.016807
# 184   maikellPardoA  template    0.016667
# 197      NicolasZon  template    0.031496
# 209       camilo654  template    0.016667
# 220  CristianLozano  template    0.016807
# 230       jdsuarezj  template    0.038168
# 239       pipemax85  template    0.112000
# 247     juandavidro  template    0.467066
# 254  UNhcrodriguezl  template    0.021429
# 260     camilo13152  template    0.016129
# 265    leavendanoro  template    0.040000
# 269      cdcordobaa  template    0.038168
# 272      capinillab  template    0.024590
# 274    lfvalderrama  template    0.057554
# 275       bsgarciac  template    0.039735

# %% [markdown]
# ## Phase 1 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group1 = overall_phase1_group1[overall_phase1_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group1["functions"], overall_phase1_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group1 = pd.DataFrame(result)
phase1_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.176471
# 1         gasierram     bdcajicam    0.176471
# 2         gasierram     helmeraac    0.150000
# 3         gasierram    dasalgadob    0.444444
# 4         gasierram    falperezgo    0.151515
# ..              ...           ...         ...
# 523        jcrubioa  JairVillalba    0.008902
# 524        jcrubioa      template    0.201058
# 525  joahernandezca  JairVillalba    0.750000
# 526  joahernandezca      template    0.016807
# 527    JairVillalba      template    0.016667
#
# [528 rows x 3 columns]

# %%
phase1_group1 = phase1_group1.loc[phase1_group1['user2'] == 'template']
phase1_group1
# Out:
#               user1     user2  similarity
# 31        gasierram  template    0.080000
# 62     adamantwharf  template    0.016807
# 92        bdcajicam  template    0.016807
# 121       helmeraac  template    0.016393
# 149      dasalgadob  template    0.067227
# 176      falperezgo  template    0.045113
# 202       djguzmanc  template    0.117647
# 227          oeroaq  template    0.068493
# 251         gcantem  template    0.408537
# 274     Semoralesga  template    0.016529
# 296      jonatan360  template    0.081395
# 317  jesusfchavarro  template    0.025316
# 337  jufcontrerasco  template    0.023622
# 356      dsbarrerag  template    0.031250
# 374       wolfstain  template    0.082090
# 391      miaborjaac  template    0.040000
# 407   ivdgonzalezco  template    0.025352
# 422    Christian7sr  template    0.000000
# 436      jsnarvaezb  template    0.084615
# 449   gfalbarracinr  template    0.008065
# 461        aldiazve  template    0.052632
# 472  diegoaguevarar  template    0.443182
# 482      fevargasmo  template    0.024194
# 491      jmhurtadoc  template    0.410526
# 499     nabautistal  template    0.016807
# 506          crigar  template    0.016667
# 512     jiapulidoar  template    0.028571
# 517       jsviveroj  template    0.032000
# 521      daandradec  template    0.032680
# 524        jcrubioa  template    0.201058
# 526  joahernandezca  template    0.016807
# 527    JairVillalba  template    0.016667

# %% [markdown]
# ## Phase 1 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group2 = overall_phase1_group2[overall_phase1_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group2["functions"], overall_phase1_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group2 = pd.DataFrame(result)
phase1_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.176471
# 1    jusherrerama       Phoenixest    0.166667
# 2    jusherrerama         HashNick    0.041667
# 3    jusherrerama  juasmartinezbel    0.038835
# 4    jusherrerama         mdbelloc    0.045455
# ..            ...              ...         ...
# 625      lsfinite     jscontrerasp    0.166667
# 626      lsfinite         template    0.016000
# 627     xdanielsb     jscontrerasp    0.017964
# 628     xdanielsb         template    0.032847
# 629  jscontrerasp         template    0.016529
#
# [630 rows x 3 columns]

# %%
phase1_group2 = phase1_group2.loc[phase1_group2['user2'] == 'template']
phase1_group2
# Out:
#                user1     user2  similarity
# 34      jusherrerama  template    0.022901
# 68           bdvegat  template    0.016667
# 101       Phoenixest  template    0.016529
# 133         HashNick  template    0.273381
# 164  juasmartinezbel  template    0.161111
# 194         mdbelloc  template    0.248175
# 223      diegocruz10  template    0.090909
# 251           sagilm  template    0.016807
# 278         idrojasf  template    0.011348
# 304     raulramirezp  template    0.008264
# 329        fabianr23  template    0.014706
# 353       jhriverasa  template    0.037879
# 376       jhonsd1996  template    0.000000
# 398       JuanitoAli  template    0.045455
# 419       Davsatu313  template    0.031008
# 439   cesarochoa2006  template    0.047244
# 458        jjmuesesq  template    0.016807
# 476           kancas  template    0.100775
# 493          Gantiva  template    0.055556
# 509       Dandarprox  template    0.026490
# 524       debeltranc  template    0.000000
# 538        ykchautai  template    0.008065
# 551        ligibrial  template    0.023077
# 563       davidrh195  template    0.015625
# 574      JulianaNino  template    0.007812
# 584         luegilca  template    0.086331
# 593           Yelis3  template    0.003020
# 601        begarzonf  template    0.048387
# 608       kmendezp96  template    0.141975
# 614         leguzman  template    0.061538
# 619     luealfonsoru  template    0.027397
# 623         oserasoa  template    0.112000
# 626         lsfinite  template    0.016000
# 628        xdanielsb  template    0.032847
# 629     jscontrerasp  template    0.016529

# %% [markdown]
# ## Phase 1 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group3 = overall_phase1_group3[overall_phase1_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group3["functions"], overall_phase1_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group3 = pd.DataFrame(result)
phase1_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.043478
# 1        lemartinp      nfmorenog    0.200000
# 2        lemartinp      AFelipeGA    0.016807
# 3        lemartinp     mballeng91    0.000000
# 4        lemartinp       dduartec    0.038462
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.201550
# 699      lizzyt10h       template    0.472393
# 700     NicolasPrr  jumcorredorro    0.104167
# 701     NicolasPrr       template    0.037594
# 702  jumcorredorro       template    0.135338
#
# [703 rows x 3 columns]

# %%
phase1_group3 = phase1_group3.loc[phase1_group3['user2'] == 'template']
phase1_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.016129
# 72         juligarji  template    0.022901
# 107        nfmorenog  template    0.038760
# 141        AFelipeGA  template    0.022124
# 174       mballeng91  template    0.010714
# 206         dduartec  template    0.062016
# 237        srmedinac  template    0.275362
# 267    wapiravaguens  template    0.086331
# 296         davidh17  template    0.080645
# 324   DianaNavarrete  template    0.008130
# 351        jdmonroyg  template    0.000000
# 377        jorge52an  template    0.023256
# 402  jscastelblancoh  template    0.068702
# 426       juclopezso  template    0.064748
# 449        afforeroc  template    0.033058
# 471      dagofonseca  template    0.069231
# 492      lacardenasv  template    0.058065
# 512      oacastillol  template    0.040984
# 531       ncampuzano  template    0.040000
# 549         adriel62  template    0.040650
# 566         capinzor  template    0.029851
# 582         ofnanezn  template    0.044693
# 597        macuestap  template    0.036496
# 611           spenas  template    0.016000
# 624      kgbayala528  template    0.064677
# 636       lgmoralesa  template    0.035971
# 647       ronaldsg20  template    0.045455
# 657    cccristanchoc  template    0.034014
# 666       jmalvarezd  template    0.063830
# 674        smarquezo  template    0.008403
# 681          sarizag  template    0.046154
# 687         Chranium  template    0.016529
# 692          DavidQP  template    0.022222
# 696      afceballosr  template    0.082090
# 699        lizzyt10h  template    0.472393
# 701       NicolasPrr  template    0.037594
# 702    jumcorredorro  template    0.135338

# %% [markdown]
# ## Phase 2 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group0 = overall_phase2_group0[overall_phase2_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group0["functions"], overall_phase2_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group0 = pd.DataFrame(result)
phase2_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.100000
# 1       fffeelipe    jmcuestasb    0.102273
# 2       fffeelipe  jjrodriguezn    0.195122
# 3       fffeelipe         DglyP    0.255814
# 4       fffeelipe   Judgarciani    0.078431
# ..            ...           ...         ...
# 373  lfvalderrama        gabi04    0.125000
# 374  lfvalderrama      template    0.053333
# 375     bsgarciac        gabi04    0.122222
# 376     bsgarciac      template    0.092025
# 377        gabi04      template    0.032468
#
# [378 rows x 3 columns]

# %%
phase2_group0 = phase2_group0.loc[phase2_group0['user2'] == 'template']
phase2_group0
# Out:
#               user1     user2  similarity
# 26        fffeelipe  template    0.057143
# 52        mnguzmanc  template    0.067164
# 77       jmcuestasb  template    0.051136
# 101    jjrodriguezn  template    0.037879
# 124           DglyP  template    0.059701
# 146     Judgarciani  template    0.070270
# 167       sacastroc  template    0.073826
# 187       pcberriop  template    0.169118
# 206     hsmartineza  template    0.116788
# 224        Moimolcp  template    0.039735
# 241     CamiloRueda  template    0.012270
# 257      JoseMolano  template    0.195652
# 272   maikellPardoA  template    0.016667
# 286      NicolasZon  template    0.031746
# 299       camilo654  template    0.038168
# 311  CristianLozano  template    0.016260
# 322       jdsuarezj  template    0.127660
# 332       pipemax85  template    0.111111
# 341     juandavidro  template    0.467066
# 349  UNhcrodriguezl  template    0.166667
# 356     camilo13152  template    0.023256
# 362    leavendanoro  template    0.037037
# 367      cdcordobaa  template    0.048951
# 371      capinillab  template    0.078125
# 374    lfvalderrama  template    0.053333
# 376       bsgarciac  template    0.092025
# 377          gabi04  template    0.032468

# %% [markdown]
# ## Phase 2 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group1 = overall_phase2_group1[overall_phase2_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group1["functions"], overall_phase2_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group1 = pd.DataFrame(result)
phase2_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.176471
# 1         gasierram     bdcajicam    0.176471
# 2         gasierram   dfhincapiem    0.235294
# 3         gasierram     helmeraac    0.142857
# 4         gasierram    dasalgadob    0.444444
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.054441
# 662        jcrubioa      template    0.196382
# 663  joahernandezca  JairVillalba    0.123077
# 664  joahernandezca      template    0.478528
# 665    JairVillalba      template    0.084615
#
# [666 rows x 3 columns]

# %%
phase2_group1 = phase2_group1.loc[phase2_group1['user2'] == 'template']
phase2_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.080000
# 70     adamantwharf  template    0.016807
# 104       bdcajicam  template    0.016807
# 137     dfhincapiem  template    0.016667
# 169       helmeraac  template    0.031008
# 200      dasalgadob  template    0.067227
# 230      falperezgo  template    0.007328
# 259       djguzmanc  template    0.086667
# 287      gsuarezc04  template    0.032468
# 314          oeroaq  template    0.067460
# 340         gcantem  template    0.408537
# 365     Semoralesga  template    0.005078
# 389      jonatan360  template    0.062176
# 412  jesusfchavarro  template    0.007726
# 434    stevenbustos  template    0.016393
# 455  jufcontrerasco  template    0.023438
# 475      dsbarrerag  template    0.048276
# 494       wolfstain  template    0.105634
# 512      miaborjaac  template    0.045000
# 529   ivdgonzalezco  template    0.025352
# 545    Christian7sr  template    0.000000
# 560      jsnarvaezb  template    0.140000
# 574   gfalbarracinr  template    0.016000
# 587        aldiazve  template    0.009603
# 599  diegoaguevarar  template    0.440678
# 610      fevargasmo  template    0.083333
# 620      jmhurtadoc  template    0.410526
# 629     anfmorenoso  template    0.054264
# 637     nabautistal  template    0.016807
# 644          crigar  template    0.016667
# 650     jiapulidoar  template    0.035398
# 655       jsviveroj  template    0.089655
# 659      daandradec  template    0.060748
# 662        jcrubioa  template    0.196382
# 664  joahernandezca  template    0.478528
# 665    JairVillalba  template    0.084615

# %% [markdown]
# ## Phase 2 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group2 = overall_phase2_group2[overall_phase2_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group2["functions"], overall_phase2_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group2 = pd.DataFrame(result)
phase2_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.176471
# 1    jusherrerama       Phoenixest    0.166667
# 2    jusherrerama         HashNick    0.045455
# 3    jusherrerama  juasmartinezbel    0.035088
# 4    jusherrerama         mdbelloc    0.045455
# ..            ...              ...         ...
# 661      lsfinite     jscontrerasp    0.002060
# 662      lsfinite         template    0.004049
# 663     xdanielsb     jscontrerasp    0.029851
# 664     xdanielsb         template    0.034130
# 665  jscontrerasp         template    0.044776
#
# [666 rows x 3 columns]

# %%
phase2_group2 = phase2_group2.loc[phase2_group2['user2'] == 'template']
phase2_group2
# Out:
#                user1     user2  similarity
# 35      jusherrerama  template    0.022901
# 70           bdvegat  template    0.016667
# 104       Phoenixest  template    0.016529
# 137         HashNick  template    0.239130
# 169  juasmartinezbel  template    0.139896
# 200         mdbelloc  template    0.248175
# 230      diegocruz10  template    0.090226
# 259           sagilm  template    0.025000
# 287         idrojasf  template    0.011348
# 314     raulramirezp  template    0.042308
# 340        fabianr23  template    0.037500
# 365       jhriverasa  template    0.044118
# 389       jhonsd1996  template    0.016529
# 412       JuanitoAli  template    0.007107
# 434       Davsatu313  template    0.190476
# 455   cesarochoa2006  template    0.181818
# 475        jjmuesesq  template    0.016807
# 494     jucjimenezmo  template    0.016000
# 512           kancas  template    0.095890
# 529          Gantiva  template    0.061644
# 545       Dandarprox  template    0.043210
# 560       debeltranc  template    0.000000
# 574        ykchautai  template    0.055556
# 587        ligibrial  template    0.005499
# 599       davidrh195  template    0.015038
# 610      JulianaNino  template    0.028777
# 620         luegilca  template    0.086331
# 629           Yelis3  template    0.004880
# 637        begarzonf  template    0.020873
# 644       kmendezp96  template    0.141975
# 650         leguzman  template    0.210884
# 655     luealfonsoru  template    0.224242
# 659         oserasoa  template    0.150376
# 662         lsfinite  template    0.004049
# 664        xdanielsb  template    0.034130
# 665     jscontrerasp  template    0.044776

# %% [markdown]
# ## Phase 2 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group3 = overall_phase2_group3[overall_phase2_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group3["functions"], overall_phase2_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group3 = pd.DataFrame(result)
phase2_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.034722
# 1        lemartinp      nfmorenog    0.183673
# 2        lemartinp      AFelipeGA    0.002417
# 3        lemartinp     mballeng91    0.000000
# 4        lemartinp       dduartec    0.125000
# ..             ...            ...         ...
# 661      lizzyt10h  jumcorredorro    0.181818
# 662      lizzyt10h       template    0.048000
# 663     NicolasPrr  jumcorredorro    0.092593
# 664     NicolasPrr       template    0.037594
# 665  jumcorredorro       template    0.129496
#
# [666 rows x 3 columns]

# %%
phase2_group3 = phase2_group3.loc[phase2_group3['user2'] == 'template']
phase2_group3
# Out:
#                user1     user2  similarity
# 35         lemartinp  template    0.055556
# 70         juligarji  template    0.020243
# 104        nfmorenog  template    0.059211
# 137        AFelipeGA  template    0.006938
# 169       mballeng91  template    0.010345
# 200         dduartec  template    0.075342
# 230        srmedinac  template    0.047904
# 259    wapiravaguens  template    0.071006
# 287         davidh17  template    0.141844
# 314   DianaNavarrete  template    0.016260
# 340        jorge52an  template    0.029762
# 365  jscastelblancoh  template    0.062937
# 389       juclopezso  template    0.016393
# 412        afforeroc  template    0.033058
# 434      dagofonseca  template    0.070312
# 455      lacardenasv  template    0.056962
# 475      oacastillol  template    0.079439
# 494       ncampuzano  template    0.038217
# 512         adriel62  template    0.170370
# 529         capinzor  template    0.029851
# 545         ofnanezn  template    0.044693
# 560        macuestap  template    0.063492
# 574           spenas  template    0.021898
# 587      kgbayala528  template    0.064677
# 599       lgmoralesa  template    0.087838
# 610       ronaldsg20  template    0.045455
# 620    cccristanchoc  template    0.068750
# 629       jmalvarezd  template    0.096774
# 637        smarquezo  template    0.008264
# 644          sarizag  template    0.072993
# 650         Chranium  template    0.016529
# 655          DavidQP  template    0.049296
# 659      afceballosr  template    0.082192
# 662        lizzyt10h  template    0.048000
# 664       NicolasPrr  template    0.037594
# 665    jumcorredorro  template    0.129496

# %% [markdown]
# ## Phase 3 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group0 = overall_phase3_group0[overall_phase3_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group0["functions"], overall_phase3_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group0 = pd.DataFrame(result)
phase3_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.003923
# 1       fffeelipe    jmcuestasb    0.102273
# 2       fffeelipe  jjrodriguezn    0.096154
# 3       fffeelipe         DglyP    0.255814
# 4       fffeelipe   Judgarciani    0.058442
# ..            ...           ...         ...
# 373  lfvalderrama        gabi04    0.103774
# 374  lfvalderrama      template    0.053571
# 375     bsgarciac        gabi04    0.097222
# 376     bsgarciac      template    0.084577
# 377        gabi04      template    0.047619
#
# [378 rows x 3 columns]

# %%
phase3_group0 = phase3_group0.loc[phase3_group0['user2'] == 'template']
phase3_group0
# Out:
#               user1     user2  similarity
# 26        fffeelipe  template    0.057143
# 52        mnguzmanc  template    0.013136
# 77       jmcuestasb  template    0.051136
# 101    jjrodriguezn  template    0.132812
# 124           DglyP  template    0.059701
# 146     Judgarciani  template    0.054622
# 167       sacastroc  template    0.073446
# 187       pcberriop  template    0.169118
# 206     hsmartineza  template    0.156463
# 224        Moimolcp  template    0.037037
# 241     CamiloRueda  template    0.012270
# 257      JoseMolano  template    0.192857
# 272   maikellPardoA  template    0.016667
# 286      NicolasZon  template    0.031746
# 299       camilo654  template    0.038168
# 311  CristianLozano  template    0.016260
# 322       jdsuarezj  template    0.121951
# 332       pipemax85  template    0.123077
# 341     juandavidro  template    0.047244
# 349  UNhcrodriguezl  template    0.182857
# 356     camilo13152  template    0.189873
# 362    leavendanoro  template    0.034483
# 367      cdcordobaa  template    0.048951
# 371      capinillab  template    0.078125
# 374    lfvalderrama  template    0.053571
# 376       bsgarciac  template    0.084577
# 377          gabi04  template    0.047619

# %% [markdown]
# ## Phase 3 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group1 = overall_phase3_group1[overall_phase3_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group1["functions"], overall_phase3_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group1 = pd.DataFrame(result)
phase3_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.049180
# 1         gasierram     bdcajicam    0.515625
# 2         gasierram   dfhincapiem    0.065574
# 3         gasierram     helmeraac    0.070423
# 4         gasierram    dasalgadob    0.129032
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.070822
# 662        jcrubioa      template    0.196382
# 663  joahernandezca  JairVillalba    0.122302
# 664  joahernandezca      template    0.478528
# 665    JairVillalba      template    0.078571
#
# [666 rows x 3 columns]

# %%
phase3_group1 = phase3_group1.loc[phase3_group1['user2'] == 'template']
phase3_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.251748
# 70     adamantwharf  template    0.016807
# 104       bdcajicam  template    0.175573
# 137     dfhincapiem  template    0.016667
# 169       helmeraac  template    0.031008
# 200      dasalgadob  template    0.067227
# 230      falperezgo  template    0.007328
# 259       djguzmanc  template    0.083871
# 287      gsuarezc04  template    0.032468
# 314          oeroaq  template    0.031017
# 340         gcantem  template    0.408537
# 365     Semoralesga  template    0.005078
# 389      jonatan360  template    0.065657
# 412  jesusfchavarro  template    0.007601
# 434    stevenbustos  template    0.016393
# 455  jufcontrerasco  template    0.023438
# 475      dsbarrerag  template    0.049383
# 494       wolfstain  template    0.055728
# 512      miaborjaac  template    0.052632
# 529   ivdgonzalezco  template    0.025352
# 545    Christian7sr  template    0.016393
# 560      jsnarvaezb  template    0.139073
# 574   gfalbarracinr  template    0.024000
# 587        aldiazve  template    0.009603
# 599  diegoaguevarar  template    0.440678
# 610      fevargasmo  template    0.070513
# 620      jmhurtadoc  template    0.410526
# 629     anfmorenoso  template    0.054264
# 637     nabautistal  template    0.016260
# 644          crigar  template    0.016667
# 650     jiapulidoar  template    0.033613
# 655       jsviveroj  template    0.083333
# 659      daandradec  template    0.060484
# 662        jcrubioa  template    0.196382
# 664  joahernandezca  template    0.478528
# 665    JairVillalba  template    0.078571

# %% [markdown]
# ## Phase 3 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group2 = overall_phase3_group2[overall_phase3_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group2["functions"], overall_phase3_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group2 = pd.DataFrame(result)
phase3_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003091
# 1    jusherrerama       Phoenixest    0.001326
# 2    jusherrerama         HashNick    0.004340
# 3    jusherrerama  juasmartinezbel    0.004601
# 4    jusherrerama         mdbelloc    0.004776
# ..            ...              ...         ...
# 661      lsfinite     jscontrerasp    0.003078
# 662      lsfinite         template    0.004439
# 663     xdanielsb     jscontrerasp    0.032710
# 664     xdanielsb         template    0.036667
# 665  jscontrerasp         template    0.050360
#
# [666 rows x 3 columns]

# %%
phase3_group2 = phase3_group2.loc[phase3_group2['user2'] == 'template']
phase3_group2
# Out:
#                user1     user2  similarity
# 35      jusherrerama  template    0.005920
# 70           bdvegat  template    0.048780
# 104       Phoenixest  template    0.016529
# 137         HashNick  template    0.239130
# 169  juasmartinezbel  template    0.116379
# 200         mdbelloc  template    0.248175
# 230      diegocruz10  template    0.082192
# 259           sagilm  template    0.077519
# 287         idrojasf  template    0.011348
# 314     raulramirezp  template    0.042308
# 340        fabianr23  template    0.036458
# 365       jhriverasa  template    0.043165
# 389       jhonsd1996  template    0.016529
# 412       JuanitoAli  template    0.007022
# 434       Davsatu313  template    0.078014
# 455   cesarochoa2006  template    0.151515
# 475        jjmuesesq  template    0.016807
# 494     jucjimenezmo  template    0.016000
# 512           kancas  template    0.095890
# 529          Gantiva  template    0.065359
# 545       Dandarprox  template    0.042781
# 560       debeltranc  template    0.000000
# 574        ykchautai  template    0.068182
# 587        ligibrial  template    0.007185
# 599       davidrh195  template    0.015038
# 610      JulianaNino  template    0.041096
# 620         luegilca  template    0.086331
# 629           Yelis3  template    0.005232
# 637        begarzonf  template    0.026119
# 644       kmendezp96  template    0.137725
# 650         leguzman  template    0.175141
# 655     luealfonsoru  template    0.226994
# 659         oserasoa  template    0.146853
# 662         lsfinite  template    0.004439
# 664        xdanielsb  template    0.036667
# 665     jscontrerasp  template    0.050360

# %% [markdown]
# ## Phase 3 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group3 = overall_phase3_group3[overall_phase3_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group3["functions"], overall_phase3_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group3 = pd.DataFrame(result)
phase3_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.002394
# 1        lemartinp      nfmorenog    0.155172
# 2        lemartinp      AFelipeGA    0.002417
# 3        lemartinp     mballeng91    0.000000
# 4        lemartinp       dduartec    0.052632
# ..             ...            ...         ...
# 661      lizzyt10h  jumcorredorro    0.098039
# 662      lizzyt10h       template    0.054688
# 663     NicolasPrr  jumcorredorro    0.055046
# 664     NicolasPrr       template    0.037594
# 665  jumcorredorro       template    0.092308
#
# [666 rows x 3 columns]

# %%
phase3_group3 = phase3_group3.loc[phase3_group3['user2'] == 'template']
phase3_group3
# Out:
#                user1     user2  similarity
# 35         lemartinp  template    0.055556
# 70         juligarji  template    0.006156
# 104        nfmorenog  template    0.055901
# 137        AFelipeGA  template    0.006938
# 169       mballeng91  template    0.010345
# 200         dduartec  template    0.051887
# 230        srmedinac  template    0.047904
# 259    wapiravaguens  template    0.063158
# 287         davidh17  template    0.125000
# 314   DianaNavarrete  template    0.016260
# 340        jorge52an  template    0.019920
# 365  jscastelblancoh  template    0.066225
# 389       juclopezso  template    0.016393
# 412        afforeroc  template    0.033058
# 434      dagofonseca  template    0.048433
# 455      lacardenasv  template    0.057325
# 475      oacastillol  template    0.074890
# 494       ncampuzano  template    0.041237
# 512         adriel62  template    0.170370
# 529         capinzor  template    0.176471
# 545         ofnanezn  template    0.041420
# 560        macuestap  template    0.063492
# 574           spenas  template    0.021898
# 587      kgbayala528  template    0.071090
# 599       lgmoralesa  template    0.079268
# 610       ronaldsg20  template    0.052980
# 620    cccristanchoc  template    0.068750
# 629       jmalvarezd  template    0.095541
# 637        smarquezo  template    0.008264
# 644          sarizag  template    0.072993
# 650         Chranium  template    0.016529
# 655          DavidQP  template    0.039474
# 659      afceballosr  template    0.080000
# 662        lizzyt10h  template    0.054688
# 664       NicolasPrr  template    0.037594
# 665    jumcorredorro  template    0.092308

# %% [markdown]
# ## Phase 4 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group0 = overall_phase4_group0[overall_phase4_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group0["functions"], overall_phase4_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group0 = pd.DataFrame(result)
phase4_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.013108
# 1       fffeelipe    jmcuestasb    0.094937
# 2       fffeelipe    katherinsb    0.024194
# 3       fffeelipe  jjrodriguezn    0.038760
# 4       fffeelipe         DglyP    0.010620
# ..            ...           ...         ...
# 401  lfvalderrama        gabi04    0.111111
# 402  lfvalderrama      template    0.058824
# 403     bsgarciac        gabi04    0.086705
# 404     bsgarciac      template    0.087719
# 405        gabi04      template    0.047619
#
# [406 rows x 3 columns]

# %%
phase4_group0 = phase4_group0.loc[phase4_group0['user2'] == 'template']
phase4_group0
# Out:
#               user1     user2  similarity
# 27        fffeelipe  template    0.051643
# 54        mnguzmanc  template    0.013468
# 80       jmcuestasb  template    0.051136
# 105      katherinsb  template    0.022059
# 129    jjrodriguezn  template    0.131783
# 152           DglyP  template    0.011267
# 174     Judgarciani  template    0.053498
# 195       sacastroc  template    0.069892
# 215       pcberriop  template    0.135802
# 234     hsmartineza  template    0.124224
# 252        Moimolcp  template    0.036649
# 269     CamiloRueda  template    0.012270
# 285      JoseMolano  template    0.192857
# 300   maikellPardoA  template    0.016667
# 314      NicolasZon  template    0.031746
# 327       camilo654  template    0.049645
# 339  CristianLozano  template    0.016260
# 350       jdsuarezj  template    0.121951
# 360       pipemax85  template    0.123077
# 369     juandavidro  template    0.047244
# 377  UNhcrodriguezl  template    0.182857
# 384     camilo13152  template    0.164773
# 390    leavendanoro  template    0.044586
# 395      cdcordobaa  template    0.048951
# 399      capinillab  template    0.116788
# 402    lfvalderrama  template    0.058824
# 404       bsgarciac  template    0.087719
# 405          gabi04  template    0.047619

# %% [markdown]
# ## Phase 4 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group1 = overall_phase4_group1[overall_phase4_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group1["functions"], overall_phase4_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group1 = pd.DataFrame(result)
phase4_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.049180
# 1         gasierram     bdcajicam    0.515625
# 2         gasierram   dfhincapiem    0.065574
# 3         gasierram     helmeraac    0.091954
# 4         gasierram    dasalgadob    0.129032
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.076271
# 662        jcrubioa      template    0.196382
# 663  joahernandezca  JairVillalba    0.125874
# 664  joahernandezca      template    0.472727
# 665    JairVillalba      template    0.076923
#
# [666 rows x 3 columns]

# %%
phase4_group1 = phase4_group1.loc[phase4_group1['user2'] == 'template']
phase4_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.251748
# 70     adamantwharf  template    0.016807
# 104       bdcajicam  template    0.175573
# 137     dfhincapiem  template    0.016667
# 169       helmeraac  template    0.034014
# 200      dasalgadob  template    0.067227
# 230      falperezgo  template    0.007123
# 259       djguzmanc  template    0.095808
# 287      gsuarezc04  template    0.032468
# 314          oeroaq  template    0.010329
# 340         gcantem  template    0.078358
# 365     Semoralesga  template    0.046512
# 389      jonatan360  template    0.069869
# 412  jesusfchavarro  template    0.003911
# 434    stevenbustos  template    0.045113
# 455  jufcontrerasco  template    0.157609
# 475      dsbarrerag  template    0.047904
# 494       wolfstain  template    0.059880
# 512      miaborjaac  template    0.048889
# 529   ivdgonzalezco  template    0.025937
# 545    Christian7sr  template    0.016393
# 560      jsnarvaezb  template    0.141104
# 574   gfalbarracinr  template    0.022556
# 587        aldiazve  template    0.004120
# 599  diegoaguevarar  template    0.440678
# 610      fevargasmo  template    0.080745
# 620      jmhurtadoc  template    0.410526
# 629     anfmorenoso  template    0.076923
# 637     nabautistal  template    0.016129
# 644          crigar  template    0.016667
# 650     jiapulidoar  template    0.033613
# 655       jsviveroj  template    0.112500
# 659      daandradec  template    0.054830
# 662        jcrubioa  template    0.196382
# 664  joahernandezca  template    0.472727
# 665    JairVillalba  template    0.076923

# %% [markdown]
# ## Phase 4 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group2 = overall_phase4_group2[overall_phase4_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group2["functions"], overall_phase4_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group2 = pd.DataFrame(result)
phase4_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003091
# 1    jusherrerama       Phoenixest    0.001326
# 2    jusherrerama         HashNick    0.005635
# 3    jusherrerama          ccvacad    0.003871
# 4    jusherrerama  juasmartinezbel    0.013575
# ..            ...              ...         ...
# 698      lsfinite     jscontrerasp    0.002871
# 699      lsfinite         template    0.004437
# 700     xdanielsb     jscontrerasp    0.028000
# 701     xdanielsb         template    0.038922
# 702  jscontrerasp         template    0.050360
#
# [703 rows x 3 columns]

# %%
phase4_group2 = phase4_group2.loc[phase4_group2['user2'] == 'template']
phase4_group2
# Out:
#                user1     user2  similarity
# 36      jusherrerama  template    0.005920
# 72           bdvegat  template    0.048780
# 107       Phoenixest  template    0.016529
# 141         HashNick  template    0.273381
# 174          ccvacad  template    0.085227
# 206  juasmartinezbel  template    0.220532
# 237         mdbelloc  template    0.248175
# 267      diegocruz10  template    0.082192
# 296           sagilm  template    0.077519
# 324         idrojasf  template    0.011331
# 351     raulramirezp  template    0.050562
# 377        fabianr23  template    0.048443
# 402       jhriverasa  template    0.039801
# 426       jhonsd1996  template    0.016529
# 449       JuanitoAli  template    0.006866
# 471       Davsatu313  template    0.136612
# 492   cesarochoa2006  template    0.070922
# 512        jjmuesesq  template    0.031250
# 531     jucjimenezmo  template    0.195946
# 549           kancas  template    0.095890
# 566          Gantiva  template    0.062893
# 582       Dandarprox  template    0.054152
# 597       debeltranc  template    0.000000
# 611        ykchautai  template    0.053030
# 624        ligibrial  template    0.007182
# 636       davidrh195  template    0.014706
# 647      JulianaNino  template    0.043796
# 657         luegilca  template    0.086331
# 666           Yelis3  template    0.009598
# 674        begarzonf  template    0.026119
# 681       kmendezp96  template    0.133690
# 687         leguzman  template    0.165775
# 692     luealfonsoru  template    0.222892
# 696         oserasoa  template    0.146853
# 699         lsfinite  template    0.004437
# 701        xdanielsb  template    0.038922
# 702     jscontrerasp  template    0.050360

# %% [markdown]
# ## Phase 4 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group3 = overall_phase4_group3[overall_phase4_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group3["functions"], overall_phase4_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group3 = pd.DataFrame(result)
phase4_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.005437
# 1        lemartinp      nfmorenog    0.164179
# 2        lemartinp      AFelipeGA    0.006274
# 3        lemartinp     mballeng91    0.004902
# 4        lemartinp       dduartec    0.048000
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.064220
# 699      lizzyt10h       template    0.057471
# 700     NicolasPrr  jumcorredorro    0.048447
# 701     NicolasPrr       template    0.028424
# 702  jumcorredorro       template    0.067669
#
# [703 rows x 3 columns]

# %%
phase4_group3 = phase4_group3.loc[phase4_group3['user2'] == 'template']
phase4_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.058824
# 72         juligarji  template    0.006004
# 107        nfmorenog  template    0.055901
# 141        AFelipeGA  template    0.006938
# 174       mballeng91  template    0.010204
# 206         dduartec  template    0.051887
# 237        srmedinac  template    0.048193
# 267     wilson911013  template    0.008333
# 296    wapiravaguens  template    0.063158
# 324         davidh17  template    0.101064
# 351   DianaNavarrete  template    0.016260
# 377        jorge52an  template    0.072000
# 402  jscastelblancoh  template    0.068841
# 426       juclopezso  template    0.065217
# 449        afforeroc  template    0.033058
# 471      dagofonseca  template    0.047486
# 492      lacardenasv  template    0.008399
# 512      oacastillol  template    0.053269
# 531       ncampuzano  template    0.040816
# 549         adriel62  template    0.004528
# 566         capinzor  template    0.014941
# 582         ofnanezn  template    0.041420
# 597        macuestap  template    0.062992
# 611           spenas  template    0.021898
# 624      kgbayala528  template    0.071090
# 636       lgmoralesa  template    0.090909
# 647       ronaldsg20  template    0.056338
# 657    cccristanchoc  template    0.065934
# 666       jmalvarezd  template    0.095541
# 674        smarquezo  template    0.037313
# 681          sarizag  template    0.071942
# 687         Chranium  template    0.016529
# 692          DavidQP  template    0.045161
# 696      afceballosr  template    0.105634
# 699        lizzyt10h  template    0.057471
# 701       NicolasPrr  template    0.028424
# 702    jumcorredorro  template    0.067669

# %% [markdown]
# ## Phase 5 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group0 = overall_phase5_group0[overall_phase5_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group0["functions"], overall_phase5_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group0 = pd.DataFrame(result)
phase5_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.013866
# 1       fffeelipe    jmcuestasb    0.089286
# 2       fffeelipe    katherinsb    0.009228
# 3       fffeelipe  jjrodriguezn    0.035211
# 4       fffeelipe         DglyP    0.012088
# ..            ...           ...         ...
# 401  lfvalderrama        gabi04    0.119048
# 402  lfvalderrama      template    0.058824
# 403     bsgarciac        gabi04    0.105263
# 404     bsgarciac      template    0.087336
# 405        gabi04      template    0.059140
#
# [406 rows x 3 columns]

# %%
phase5_group0 = phase5_group0.loc[phase5_group0['user2'] == 'template']
phase5_group0
# Out:
#               user1     user2  similarity
# 27        fffeelipe  template    0.054054
# 54        mnguzmanc  template    0.013428
# 80       jmcuestasb  template    0.051136
# 105      katherinsb  template    0.007110
# 129    jjrodriguezn  template    0.128788
# 152           DglyP  template    0.012500
# 174     Judgarciani  template    0.167260
# 195       sacastroc  template    0.076087
# 215       pcberriop  template    0.072165
# 234     hsmartineza  template    0.121951
# 252        Moimolcp  template    0.034826
# 269     CamiloRueda  template    0.012270
# 285      JoseMolano  template    0.192857
# 300   maikellPardoA  template    0.016667
# 314      NicolasZon  template    0.031746
# 327       camilo654  template    0.049645
# 339  CristianLozano  template    0.016260
# 350       jdsuarezj  template    0.121951
# 360       pipemax85  template    0.123077
# 369     juandavidro  template    0.047244
# 377  UNhcrodriguezl  template    0.182857
# 384     camilo13152  template    0.164773
# 390    leavendanoro  template    0.044586
# 395      cdcordobaa  template    0.048951
# 399      capinillab  template    0.101351
# 402    lfvalderrama  template    0.058824
# 404       bsgarciac  template    0.087336
# 405          gabi04  template    0.059140

# %% [markdown]
# ## Phase 5 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group1 = overall_phase5_group1[overall_phase5_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group1["functions"], overall_phase5_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group1 = pd.DataFrame(result)
phase5_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.049180
# 1         gasierram     bdcajicam    0.515625
# 2         gasierram   dfhincapiem    0.065574
# 3         gasierram     helmeraac    0.091954
# 4         gasierram    dasalgadob    0.129032
# ..              ...           ...         ...
# 625        jcrubioa  JairVillalba    0.088710
# 626        jcrubioa      template    0.196382
# 627  joahernandezca  JairVillalba    0.134969
# 628  joahernandezca      template    0.472727
# 629    JairVillalba      template    0.078788
#
# [630 rows x 3 columns]

# %%
phase5_group1 = phase5_group1.loc[phase5_group1['user2'] == 'template']
phase5_group1
# Out:
#               user1     user2  similarity
# 34        gasierram  template    0.251748
# 68     adamantwharf  template    0.016807
# 101       bdcajicam  template    0.175573
# 133     dfhincapiem  template    0.016667
# 164       helmeraac  template    0.034014
# 194      dasalgadob  template    0.067227
# 223      falperezgo  template    0.007102
# 251       djguzmanc  template    0.095808
# 278      gsuarezc04  template    0.032468
# 304          oeroaq  template    0.011948
# 329     Semoralesga  template    0.061069
# 353      jonatan360  template    0.073171
# 376  jesusfchavarro  template    0.001192
# 398    stevenbustos  template    0.049296
# 419  jufcontrerasco  template    0.157609
# 439      dsbarrerag  template    0.044199
# 458       wolfstain  template    0.059880
# 476      miaborjaac  template    0.047826
# 493   ivdgonzalezco  template    0.033520
# 509    Christian7sr  template    0.014184
# 524      jsnarvaezb  template    0.141104
# 538   gfalbarracinr  template    0.040268
# 551        aldiazve  template    0.004119
# 563  diegoaguevarar  template    0.314917
# 574      fevargasmo  template    0.080247
# 584      jmhurtadoc  template    0.410526
# 593     anfmorenoso  template    0.071823
# 601     nabautistal  template    0.207143
# 608          crigar  template    0.016667
# 614     jiapulidoar  template    0.032086
# 619       jsviveroj  template    0.109756
# 623      daandradec  template    0.054830
# 626        jcrubioa  template    0.196382
# 628  joahernandezca  template    0.472727
# 629    JairVillalba  template    0.078788

# %% [markdown]
# ## Phase 5 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group2 = overall_phase5_group2[overall_phase5_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group2["functions"], overall_phase5_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group2 = pd.DataFrame(result)
phase5_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003091
# 1    jusherrerama       Phoenixest    0.001326
# 2    jusherrerama         HashNick    0.005635
# 3    jusherrerama          ccvacad    0.004275
# 4    jusherrerama  juasmartinezbel    0.013575
# ..            ...              ...         ...
# 698      lsfinite     jscontrerasp    0.002871
# 699      lsfinite         template    0.004437
# 700     xdanielsb     jscontrerasp    0.020790
# 701     xdanielsb         template    0.026502
# 702  jscontrerasp         template    0.050360
#
# [703 rows x 3 columns]

# %%
phase5_group2 = phase5_group2.loc[phase5_group2['user2'] == 'template']
phase5_group2
# Out:
#                user1     user2  similarity
# 36      jusherrerama  template    0.005920
# 72           bdvegat  template    0.048780
# 107       Phoenixest  template    0.016529
# 141         HashNick  template    0.273381
# 174          ccvacad  template    0.095745
# 206  juasmartinezbel  template    0.220532
# 237         mdbelloc  template    0.248175
# 267      diegocruz10  template    0.082192
# 296           sagilm  template    0.184615
# 324         idrojasf  template    0.011331
# 351     raulramirezp  template    0.051151
# 377        fabianr23  template    0.050179
# 402       jhriverasa  template    0.040816
# 426       jhonsd1996  template    0.016529
# 449       JuanitoAli  template    0.006866
# 471       Davsatu313  template    0.077778
# 492   cesarochoa2006  template    0.074205
# 512        jjmuesesq  template    0.035714
# 531     jucjimenezmo  template    0.189542
# 549           kancas  template    0.095890
# 566          Gantiva  template    0.062893
# 582       Dandarprox  template    0.054152
# 597       debeltranc  template    0.000000
# 611        ykchautai  template    0.052632
# 624        ligibrial  template    0.006574
# 636       davidrh195  template    0.014706
# 647      JulianaNino  template    0.043796
# 657         luegilca  template    0.086331
# 666           Yelis3  template    0.003122
# 674        begarzonf  template    0.026119
# 681       kmendezp96  template    0.014032
# 687         leguzman  template    0.144860
# 692     luealfonsoru  template    0.222892
# 696         oserasoa  template    0.131579
# 699         lsfinite  template    0.004437
# 701        xdanielsb  template    0.026502
# 702     jscontrerasp  template    0.050360

# %% [markdown]
# ## Phase 5 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group3 = overall_phase5_group3[overall_phase5_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group3["functions"], overall_phase5_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group3 = pd.DataFrame(result)
phase5_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.005428
# 1        lemartinp      nfmorenog    0.164179
# 2        lemartinp      AFelipeGA    0.006274
# 3        lemartinp     mballeng91    0.004902
# 4        lemartinp       dduartec    0.005530
# ..             ...            ...         ...
# 736      lizzyt10h  jumcorredorro    0.066667
# 737      lizzyt10h       template    0.060440
# 738     NicolasPrr  jumcorredorro    0.097902
# 739     NicolasPrr       template    0.054622
# 740  jumcorredorro       template    0.064057
#
# [741 rows x 3 columns]

# %%
phase5_group3 = phase5_group3.loc[phase5_group3['user2'] == 'template']
phase5_group3
# Out:
#                user1     user2  similarity
# 37         lemartinp  template    0.058824
# 74         juligarji  template    0.005995
# 110        nfmorenog  template    0.055901
# 145        AFelipeGA  template    0.006938
# 179       mballeng91  template    0.010204
# 212         dduartec  template    0.011949
# 244        srmedinac  template    0.048193
# 275     wilson911013  template    0.008333
# 305    wapiravaguens  template    0.061538
# 334         davidh17  template    0.095745
# 362   DianaNavarrete  template    0.016260
# 389        jdmonroyg  template    0.047619
# 415        jorge52an  template    0.066015
# 440  jscastelblancoh  template    0.064057
# 464       juclopezso  template    0.064748
# 487        afforeroc  template    0.033058
# 509      dagofonseca  template    0.045699
# 530      lacardenasv  template    0.008349
# 550      oacastillol  template    0.045783
# 569       ncampuzano  template    0.194570
# 587         adriel62  template    0.064885
# 604         capinzor  template    0.011850
# 620         ofnanezn  template    0.041420
# 635        macuestap  template    0.062992
# 649           spenas  template    0.021898
# 662      kgbayala528  template    0.071090
# 674       lgmoralesa  template    0.089385
# 685       ronaldsg20  template    0.067797
# 695    cccristanchoc  template    0.068627
# 704       jmalvarezd  template    0.096154
# 712        smarquezo  template    0.076923
# 719          sarizag  template    0.097222
# 725         Chranium  template    0.016529
# 730          DavidQP  template    0.047904
# 734      afceballosr  template    0.103448
# 737        lizzyt10h  template    0.060440
# 739       NicolasPrr  template    0.054622
# 740    jumcorredorro  template    0.064057

# %% [markdown]
# ## Distribution Plot for Phase 1

# %%
phase1_group0['group'] = 0
phase1_group1['group'] = 1
phase1_group2['group'] = 2
phase1_group3['group'] = 3
phase1 = pd.concat([phase1_group0, phase1_group1, phase1_group2, phase1_group3], ignore_index=True)
phase1['similarity'].hist(by=phase1['group'])
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/2015457414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group0['group'] = 0
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/2015457414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group1['group'] = 1
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/2015457414.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group2['group'] = 2
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/2015457414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 2

# %%
phase2_group0['group'] = 0
phase2_group1['group'] = 1
phase2_group2['group'] = 2
phase2_group3['group'] = 3
phase2 = pd.concat([phase2_group0, phase2_group1, phase2_group2, phase2_group3], ignore_index=True)
phase2['similarity'].hist(by=phase2['group'])
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/124240429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group0['group'] = 0
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/124240429.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group1['group'] = 1
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/124240429.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group2['group'] = 2
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/124240429.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 3

# %%
phase3_group0['group'] = 0
phase3_group1['group'] = 1
phase3_group2['group'] = 2
phase3_group3['group'] = 3
phase3 = pd.concat([phase3_group0, phase3_group1, phase3_group2, phase3_group3], ignore_index=True)
phase3['similarity'].hist(by=phase3['group'])
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4250399680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group0['group'] = 0
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4250399680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group1['group'] = 1
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4250399680.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group2['group'] = 2
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4250399680.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 4

# %%
phase4_group0['group'] = 0
phase4_group1['group'] = 1
phase4_group2['group'] = 2
phase4_group3['group'] = 3
phase4 = pd.concat([phase4_group0, phase4_group1, phase4_group2, phase4_group3], ignore_index=True)
phase4['similarity'].hist(by=phase4['group'])
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4284504232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group0['group'] = 0
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4284504232.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group1['group'] = 1
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4284504232.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group2['group'] = 2
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4284504232.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 5

# %%
phase5_group0['group'] = 0
phase5_group1['group'] = 1
phase5_group2['group'] = 2
phase5_group3['group'] = 3
phase5 = pd.concat([phase5_group0, phase5_group1, phase5_group2, phase5_group3], ignore_index=True)
phase5['similarity'].hist(by=phase5['group'])
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4080999950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group0['group'] = 0
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4080999950.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group1['group'] = 1
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4080999950.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group2['group'] = 2
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_2055/4080999950.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %%
median_log_bogota3 = []
median_log_bogota2 = []
median_log_bogota1 = []
median_log_bogota0 = []

mean_log_bogota3 = []
mean_log_bogota2 = []
mean_log_bogota1 = []
mean_log_bogota0 = []

max_log_bogota3 = []
max_log_bogota2 = []
max_log_bogota1 = []
max_log_bogota0 = []

min_log_bogota3 = []
min_log_bogota2 = []
min_log_bogota1 = []
min_log_bogota0 = []

for df in [phase1_group3, phase2_group3, phase3_group3, phase4_group3, phase5_group3]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    max_value = (np.log(df['similarity']+1)).max()
    max_log_bogota3.append(max_value)
    median_log_bogota3.append(median_value)
    mean_log_bogota3.append(mean_value)
    plt.figure()
    plt.title("Template Similarity Plot Bogota 3")
    sns.distplot((np.log(df['similarity']+1)))

for df in [phase1_group2, phase2_group2, phase3_group2, phase4_group2, phase5_group2]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    max_value = (np.log(df['similarity']+1)).max()
    max_log_bogota2.append(max_value)
    median_log_bogota2.append(median_value)
    mean_log_bogota2.append(mean_value)
    plt.figure()
    plt.title("Template Similarity Plot Bogota 2")
    sns.distplot((np.log(df['similarity']+1)))
    
for df in [phase1_group1, phase2_group1, phase3_group1, phase4_group1, phase5_group1]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    max_value = (np.log(df['similarity']+1)).max()
    max_log_bogota1.append(max_value)
    median_log_bogota1.append(median_value)
    mean_log_bogota1.append(mean_value)
    plt.figure()
    plt.title("Template Similarity Plot Bogota 1")
    sns.distplot((np.log(df['similarity']+1)))

for df in [phase1_group0, phase2_group0, phase3_group0, phase4_group0, phase5_group0]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    max_value = (np.log(df['similarity']+1)).max()
    max_log_bogota0.append(max_value)
    median_log_bogota0.append(median_value)
    mean_log_bogota0.append(mean_value)
    plt.figure()
    plt.title("Template Similarity Plot Bogota 0")
    sns.distplot((np.log(df['similarity']+1)))
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# > Interpretation: Majority of the plots look to be positively skewed, but there are a few plots that are normal.

# %%
import matplotlib.pyplot as plt

y1 = median_log_bogota0
y2 = median_log_bogota1
y3 = median_log_bogota2
y4 = median_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Median Template Similarity")
plt.ylabel("Log-Transform Median Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

y1 = mean_log_bogota0
y2 = mean_log_bogota1
y3 = mean_log_bogota2
y4 = mean_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Mean Template Similarity")
plt.ylabel("Log-Transform Mean Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

y1 = max_log_bogota0
y2 = max_log_bogota1
y3 = max_log_bogota2
y4 = max_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Max Template Similarity")
plt.ylabel("Log-Transform Max Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)
