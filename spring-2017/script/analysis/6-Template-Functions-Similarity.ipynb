# %% [markdown]
# ## Template Similarity
#
# > This metrics look to share some similarities with the approach from Bernstein et. al. (2018). However the metrics remains to be validated.

# %%
# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5
# %store -r df_all
# %store -r overall_loc_scores_final
# %store -r overall_loc_scores
# %store -r template_functions

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ast

# %%
template_functions = pd.read_csv('data-from-ironhub/output_template.txt', header=None, sep='\0', names=['functions'], converters={ 'functions' : ast.literal_eval })
template_functions = template_functions['functions'].iloc[0]
template_functions
# Out:
# ['bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.css',
#  'tutorial.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'RadarChart.js',
#  'tutorial.js',
#  'scripto.js',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  'to.toUpperCase',
#  'this.splice',
#  'google.maps.Map',
#  'z.document.getElementById',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'pxmlhttp.open',
#  'xmlhttp.send',
#  'rentxmlhttp.onreadystatechange',
#  'hxmlhttp.readyState',
#  'xmlhttp.status',
#  'pxmlhttp.responseText',
#  'JSON.parse',
#  'json.data',
#  'km.innerHTML',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListenerOnce',
#  'google.maps.ElevationService',
#  'o.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'bounds.getNorthEast',
#  'northEast.lng',
#  'southWest.lng',
#  'northEast.lat',
#  'southWest.lat',
#  'google.maps.LatLng',
#  '.Math.random',
#  'locations.push',
#  'elevation.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'google.maps.Marker',
#  'okey.toString',
#  '.slices',
#  'infWindow.close',
#  'infowindow.setContent',
#  'infowindowP.open',
#  '.capitalizeFirstLetter',
#  'RadarChart.draw',
#  'arr.length',
#  '.url',
#  'u.display',
#  'str.indexOf',
#  'dt.getDay',
#  'api.openweathermap.org',
#  '.coord.lon',
#  'json.weather',
#  'r.main',
#  't.select',
#  'g.selectAll',
#  'g.append',
#  'Z.attr',
#  'cfg.w',
#  'cfg.h',
#  '.scale.category',
#  'svg.append',
#  'j.text',
#  'title.selectAll',
#  'H.data',
#  'n.enter',
#  'm.style',
#  'g.resize',
#  '.height',
#  '.css',
#  'Math.PI',
#  'cfg.maxValue',
#  'Math.max',
#  '.max',
#  'i.map',
#  'o.value',
#  '.map',
#  'i.axis',
#  'allAxis.length',
#  'cfg.factor',
#  'Math.min',
#  'n.format',
#  'd.remove',
#  'cfg.ExtraWidthY',
#  'cfg.ExtraWidthY',
#  'cfg.TranslateY',
#  'cfg.TranslateY',
#  'cfg.levels',
#  'g.selectAll',
#  'c.levels',
#  'Math.sinh',
#  'cfg.radians',
#  'Math.acos',
#  'cfg.ToRight',
#  'd.axis',
#  'axis.append',
#  'cfg.factortitle',
#  'ids.forEach',
#  'c.nodes',
#  'dataValues.push',
#  'j.value',
#  't.area',
#  'cfg.color',
#  'dx.length',
#  'cfg.opacityArea',
#  '.on',
#  '.transiting',
#  'cfg.radius',
#  'j.axis',
#  'd.values',
#  'g.append']

# %%
overall_phase1 = overall_phase1.loc[(overall_phase1['len_unique'] != 0 )]
overall_phase1 = overall_phase1.dropna()
overall_phase1
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 5            DglyP    0.0                     20.0           25.00
# 8      Judgarciani    0.0                    100.0           58.33
# 9        sacastroc    0.0                     20.0           50.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 5             50.00        195.00        100.0         87.5
# 8             66.67        325.00        100.0         75.0
# 9             68.75        226.25         87.5         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 5                        0.0           25.00  ...               21.5
# 8                       80.0           87.50  ...              -19.5
# 9                       20.0           50.00  ...                0.0
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 5                  0.0              -11.0                3.0
# 8                  4.0               44.0                8.5
# 9                  1.0               13.0                0.5
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 5                -31.0                0.0
# 8                  1.0                1.0
# 9                  0.5                0.5
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, k.click, .mcheck, .on, .closest, p.li...
# 1    [style.css, maps.js, z.document.getElementById...
# 5             [bootstrap.min.css, style.css, .JS, .js]
# 8    [jquery.min.js, .js, Rent.js, Crimes.js, googl...
# 9    [js.org, .v, .min.js, bootstrap.min.css, theme...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, jquery.min.js, ...
# 157  [bootstrap.min.css, theme.min.css, jquery.min....
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [scripto.js, jquery.min.js, bootstrap.min.css,...
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, .mcheck, .on, .closest, p.li...        20.0
# 1    [style.css, maps.js, z.document.getElementById...         5.0
# 5             [bootstrap.min.css, style.css, .JS, .js]         4.0
# 8    [jquery.min.js, .js, Rent.js, Crimes.js, googl...        40.0
# 9    [js.org, .v, .min.js, bootstrap.min.css, theme...         6.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        20.0
# 156  [bootstrap.min.css, style.css, jquery.min.js, ...        25.0
# 157  [bootstrap.min.css, theme.min.css, jquery.min....       117.0
# 158  [bootstrap.min.css, jquery.min.js, stylesLogin...        19.0
# 159  [scripto.js, jquery.min.js, bootstrap.min.css,...        33.0
#
#      len_functions
# 0             21.0
# 1              5.0
# 5              4.0
# 8             40.0
# 9              7.0
# ..             ...
# 155           20.0
# 156           27.0
# 157          122.0
# 158           20.0
# 159           33.0
#
# [127 rows x 90 columns]

# %%
overall_phase2 = overall_phase2.loc[(overall_phase2['len_unique'] != 0 )]
overall_phase2 = overall_phase2.dropna()
overall_phase2
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 4     jjrodriguezn    0.0                     60.0           58.33
# 5            DglyP    0.0                     20.0           25.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 4             87.50        255.83         50.0         37.5
# 5             50.00        195.00        100.0         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 4                       40.0           54.17  ...              104.0
# 5                        0.0           25.00  ...               21.5
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 2                  1.5                9.0               -4.0
# 4                  8.0               60.5                0.5
# 5                  0.0              -11.0                3.0
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 4                  0.0               34.5
# 5                -31.0                0.0
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, k.click, .mcheck, .on, .closest, p.li...
# 1    [house.ico, style.css, maps.js, Chicago.jpg, z...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...
# 5    [google.maps.Map, z.document.getElementById, g...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, farmermarket.st...
# 157  [.js, jsInitMap.js, z.document.getElementById,...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [scripto.js, jquery.min.js, bootstrap.min.css,...
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, .mcheck, .on, .closest, p.li...        29.0
# 1    [house.ico, style.css, maps.js, Chicago.jpg, z...        25.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      6404.0
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...        19.0
# 5    [google.maps.Map, z.document.getElementById, g...        23.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        31.0
# 156  [bootstrap.min.css, style.css, farmermarket.st...        38.0
# 157  [.js, jsInitMap.js, z.document.getElementById,...        13.0
# 158  [bootstrap.min.css, jquery.min.js, stylesLogin...        19.0
# 159  [scripto.js, jquery.min.js, bootstrap.min.css,...        38.0
#
#      len_functions
# 0             30.0
# 1             25.0
# 2           7051.0
# 4             19.0
# 5             24.0
# ..             ...
# 155           31.0
# 156           40.0
# 157           13.0
# 158           20.0
# 159           39.0
#
# [136 rows x 90 columns]

# %%
overall_phase3 = overall_phase3.loc[(overall_phase3['len_unique'] != 0 )]
overall_phase3 = overall_phase3.dropna()
overall_phase3
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 4     jjrodriguezn    0.0                     60.0           58.33
# 5            DglyP    0.0                     20.0           25.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 4             87.50        255.83         50.0         37.5
# 5             50.00        195.00        100.0         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 4                       40.0           54.17  ...              104.0
# 5                        0.0           25.00  ...               21.5
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 2                  1.5                9.0               -4.0
# 4                  8.0               60.5                0.5
# 5                  0.0              -11.0                3.0
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 4                  0.0               34.5
# 5                -31.0                0.0
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, k.click, .mcheck, .on, .closest, p.li...
# 1    [house.ico, style.css, .css, main.js, maps.js,...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 4    [google.maps.Map, z.document.getElementById, g...
# 5    [google.maps.Map, z.document.getElementById, g...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, farmermarket.st...
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.css, tutorial.cs...
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, .mcheck, .on, .closest, p.li...        29.0
# 1    [house.ico, style.css, .css, main.js, maps.js,...      1742.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      6404.0
# 4    [google.maps.Map, z.document.getElementById, g...        27.0
# 5    [google.maps.Map, z.document.getElementById, g...        23.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        40.0
# 156  [bootstrap.min.css, style.css, farmermarket.st...        42.0
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...        16.0
# 158  [bootstrap.min.css, jquery.min.js, stylesLogin...        19.0
# 159  [jquery.min.js, bootstrap.min.css, tutorial.cs...        91.0
#
#      len_functions
# 0             30.0
# 1           2273.0
# 2           7051.0
# 4             27.0
# 5             24.0
# ..             ...
# 155           40.0
# 156           44.0
# 157           17.0
# 158           20.0
# 159           95.0
#
# [136 rows x 90 columns]

# %%
overall_phase4 = overall_phase4.loc[(overall_phase4['len_unique'] != 0 )]
overall_phase4 = overall_phase4.dropna()
overall_phase4
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 3       katherinsb    0.0                     20.0           37.50
# 4     jjrodriguezn    0.0                     60.0           58.33
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...              104.0
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 2                  1.5                9.0               -4.0
# 3                  0.0                0.0               73.5
# 4                  8.0               60.5                0.5
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 3                  0.0                0.0
# 4                  0.0               34.5
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, k.click, w.removeClass, .is, .val, .m...
# 1    [house.ico, style.css, .css, main.js, maps.js,...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3    [reset.css, layout.css, style.css, .js, yui.js...
# 4    [google.maps.Map, z.document.getElementById, g...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.css, .js, script...
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, w.removeClass, .is, .val, .m...       102.0
# 1    [house.ico, style.css, .css, main.js, maps.js,...      1760.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      6404.0
# 3    [reset.css, layout.css, style.css, .js, yui.js...        21.0
# 4    [google.maps.Map, z.document.getElementById, g...        28.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        44.0
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...        36.0
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...        62.0
# 158  [bootstrap.min.css, jquery.min.js, mapControl....       644.0
# 159  [jquery.min.js, bootstrap.min.css, .js, script...       150.0
#
#      len_functions
# 0            106.0
# 1           2290.0
# 2           7051.0
# 3             21.0
# 4             28.0
# ..             ...
# 155           44.0
# 156           39.0
# 157           66.0
# 158          678.0
# 159          166.0
#
# [138 rows x 90 columns]

# %%
overall_phase5 = overall_phase5.loc[(overall_phase5['len_unique'] != 0 )]
overall_phase5 = overall_phase5.dropna()
overall_phase5
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 3       katherinsb    0.0                     20.0           37.50
# 4     jjrodriguezn    0.0                     60.0           58.33
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-12  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...               -1.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...              104.0
# ..                       ...             ...  ...                ...
# 155                     80.0           66.67  ...               16.5
# 156                     40.0           50.00  ...              -76.5
# 157                      0.0           29.17  ...                7.5
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                0.0
#
#      improve-effort-23  improve-effort-34  improve-effort-45  \
# 0                  0.0              -14.0               -6.0
# 1                -16.5               45.5               13.0
# 2                  1.5                9.0               -4.0
# 3                  0.0                0.0               73.5
# 4                  8.0               60.5                0.5
# ..                 ...                ...                ...
# 155               28.5               -1.0               -4.5
# 156               -3.5               58.0                0.5
# 157                0.0                4.5               -4.0
# 158                0.0              -36.5                0.0
# 159               12.0                1.0                1.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 3                  0.0                0.0
# 4                  0.0               34.5
# ..                 ...                ...
# 155                3.0                6.0
# 156                0.0                0.0
# 157               11.5                8.0
# 158               16.5               16.5
# 159               11.5               11.5
#
#                                              functions  \
# 0    [.ready, k.click, .css, w.removeClass, .is, .v...
# 1    [house.ico, style.css, .css, main.js, maps.js,...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3    [reset.css, layout.css, style.css, jquery.min....
# 4    [google.maps.Map, z.document.getElementById, g...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 157  [bootstrap.min.css, jquery.min.js, .min.css, t...
# 158  [jquery.min.js, bootstrap.min.css, stylesLogin...
# 159  [jquery.min.js, bootstrap.min.css, .js, script...
#
#                                                 unique  len_unique  \
# 0    [.ready, k.click, .css, w.removeClass, .is, .v...       112.0
# 1    [house.ico, style.css, .css, main.js, maps.js,...      1766.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      6404.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2043.0
# 4    [google.maps.Map, z.document.getElementById, g...        31.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        56.0
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...        36.0
# 157  [bootstrap.min.css, jquery.min.js, .min.css, t...        71.0
# 158  [jquery.min.js, bootstrap.min.css, stylesLogin...       128.0
# 159  [jquery.min.js, bootstrap.min.css, .js, script...       165.0
#
#      len_functions
# 0            116.0
# 1           2297.0
# 2           7051.0
# 3           2290.0
# 4             31.0
# ..             ...
# 155           57.0
# 156           42.0
# 157           75.0
# 158          133.0
# 159          181.0
#
# [138 rows x 90 columns]

# %%
overall_phase1_group0 = overall_phase1.loc[overall_phase1['Group'] == 0]
overall_phase1_group1 = overall_phase1.loc[overall_phase1['Group'] == 1]
overall_phase1_group2 = overall_phase1.loc[overall_phase1['Group'] == 2]
overall_phase1_group3 = overall_phase1.loc[overall_phase1['Group'] == 3]

# %%
overall_phase2_group0 = overall_phase2.loc[overall_phase2['Group'] == 0]
overall_phase2_group1 = overall_phase2.loc[overall_phase2['Group'] == 1]
overall_phase2_group2 = overall_phase2.loc[overall_phase2['Group'] == 2]
overall_phase2_group3 = overall_phase2.loc[overall_phase2['Group'] == 3]

# %%
overall_phase3_group0 = overall_phase3.loc[overall_phase3['Group'] == 0]
overall_phase3_group1 = overall_phase3.loc[overall_phase3['Group'] == 1]
overall_phase3_group2 = overall_phase3.loc[overall_phase3['Group'] == 2]
overall_phase3_group3 = overall_phase3.loc[overall_phase3['Group'] == 3]

# %%
overall_phase4_group0 = overall_phase4.loc[overall_phase4['Group'] == 0]
overall_phase4_group1 = overall_phase4.loc[overall_phase4['Group'] == 1]
overall_phase4_group2 = overall_phase4.loc[overall_phase4['Group'] == 2]
overall_phase4_group3 = overall_phase4.loc[overall_phase4['Group'] == 3]

# %%
overall_phase5_group0 = overall_phase5.loc[overall_phase5['Group'] == 0]
overall_phase5_group1 = overall_phase5.loc[overall_phase5['Group'] == 1]
overall_phase5_group2 = overall_phase5.loc[overall_phase5['Group'] == 2]
overall_phase5_group3 = overall_phase5.loc[overall_phase5['Group'] == 3]

# %%
df_template = {'Student': ['template'], 'functions': [template_functions], 'phase': [0]}
df_template = pd.DataFrame(data=df_template)
df_template
# Out:
#     Student                                          functions  phase
# 0  template  [bootstrap.min.css, theme.min.css, jquery.min....      0

# %%
overall_phase1_group0['unique'] = [','.join(map(str, l)) for l in overall_phase1_group0['unique']]
overall_phase1_group1['unique'] = [','.join(map(str, l)) for l in overall_phase1_group1['unique']]
overall_phase1_group2['unique'] = [','.join(map(str, l)) for l in overall_phase1_group2['unique']]
overall_phase1_group3['unique'] = [','.join(map(str, l)) for l in overall_phase1_group3['unique']]

overall_phase2_group0['unique'] = [','.join(map(str, l)) for l in overall_phase2_group0['unique']]
overall_phase2_group1['unique'] = [','.join(map(str, l)) for l in overall_phase2_group1['unique']]
overall_phase2_group2['unique'] = [','.join(map(str, l)) for l in overall_phase2_group2['unique']]
overall_phase2_group3['unique'] = [','.join(map(str, l)) for l in overall_phase2_group3['unique']]

overall_phase3_group0['unique'] = [','.join(map(str, l)) for l in overall_phase3_group0['unique']]
overall_phase3_group1['unique'] = [','.join(map(str, l)) for l in overall_phase3_group1['unique']]
overall_phase3_group2['unique'] = [','.join(map(str, l)) for l in overall_phase3_group2['unique']]
overall_phase3_group3['unique'] = [','.join(map(str, l)) for l in overall_phase3_group3['unique']]

overall_phase4_group0['unique'] = [','.join(map(str, l)) for l in overall_phase4_group0['unique']]
overall_phase4_group1['unique'] = [','.join(map(str, l)) for l in overall_phase4_group1['unique']]
overall_phase4_group2['unique'] = [','.join(map(str, l)) for l in overall_phase4_group2['unique']]
overall_phase4_group3['unique'] = [','.join(map(str, l)) for l in overall_phase4_group3['unique']]

overall_phase5_group0['unique'] = [','.join(map(str, l)) for l in overall_phase5_group0['unique']]
overall_phase5_group1['unique'] = [','.join(map(str, l)) for l in overall_phase5_group1['unique']]
overall_phase5_group2['unique'] = [','.join(map(str, l)) for l in overall_phase5_group2['unique']]
overall_phase5_group3['unique'] = [','.join(map(str, l)) for l in overall_phase5_group3['unique']]
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group0['unique'] = [','.join(map(str, l)) for l in overall_phase1_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group1['unique'] = [','.join(map(str, l)) for l in overall_phase1_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group2['unique'] = [','.join(map(str, l)) for l in overall_phase1_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group3['unique'] = [','.join(map(str, l)) for l in overall_phase1_group3['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group0['unique'] = [','.join(map(str, l)) for l in overall_phase2_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group1['unique'] = [','.join(map(str, l)) for l in overall_phase2_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group2['unique'] = [','.join(map(str, l)) for l in overall_phase2_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group3['unique'] = [','.join(map(str, l)) for l in overall_phase2_group3['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group0['unique'] = [','.join(map(str, l)) for l in overall_phase3_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group1['unique'] = [','.join(map(str, l)) for l in overall_phase3_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group2['unique'] = [','.join(map(str, l)) for l in overall_phase3_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group3['unique'] = [','.join(map(str, l)) for l in overall_phase3_group3['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group0['unique'] = [','.join(map(str, l)) for l in overall_phase4_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group1['unique'] = [','.join(map(str, l)) for l in overall_phase4_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group2['unique'] = [','.join(map(str, l)) for l in overall_phase4_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group3['unique'] = [','.join(map(str, l)) for l in overall_phase4_group3['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group0['unique'] = [','.join(map(str, l)) for l in overall_phase5_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group1['unique'] = [','.join(map(str, l)) for l in overall_phase5_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group2['unique'] = [','.join(map(str, l)) for l in overall_phase5_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4231300064.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group3['unique'] = [','.join(map(str, l)) for l in overall_phase5_group3['unique']]

# %%
overall_phase1_group0 = overall_phase1_group0.append(df_template, ignore_index=True)
overall_phase1_group1 = overall_phase1_group1.append(df_template, ignore_index=True)
overall_phase1_group2 = overall_phase1_group2.append(df_template, ignore_index=True)
overall_phase1_group3 = overall_phase1_group3.append(df_template, ignore_index=True)

overall_phase2_group0 = overall_phase2_group0.append(df_template, ignore_index=True)
overall_phase2_group1 = overall_phase2_group1.append(df_template, ignore_index=True)
overall_phase2_group2 = overall_phase2_group2.append(df_template, ignore_index=True)
overall_phase2_group3 = overall_phase2_group3.append(df_template, ignore_index=True)

overall_phase3_group0 = overall_phase3_group0.append(df_template, ignore_index=True)
overall_phase3_group1 = overall_phase3_group1.append(df_template, ignore_index=True)
overall_phase3_group2 = overall_phase3_group2.append(df_template, ignore_index=True)
overall_phase3_group3 = overall_phase3_group3.append(df_template, ignore_index=True)

overall_phase4_group0 = overall_phase4_group0.append(df_template, ignore_index=True)
overall_phase4_group1 = overall_phase4_group1.append(df_template, ignore_index=True)
overall_phase4_group2 = overall_phase4_group2.append(df_template, ignore_index=True)
overall_phase4_group3 = overall_phase4_group3.append(df_template, ignore_index=True)

overall_phase5_group0 = overall_phase5_group0.append(df_template, ignore_index=True)
overall_phase5_group1 = overall_phase5_group1.append(df_template, ignore_index=True)
overall_phase5_group2 = overall_phase5_group2.append(df_template, ignore_index=True)
overall_phase5_group3 = overall_phase5_group3.append(df_template, ignore_index=True)

# %%
overall_phase5_group3
# Out:
#             Student  Group  user-requirement-phase5  infovis-phase5  \
# 0         lemartinp    3.0                    100.0           54.17
# 1         juligarji    3.0                    100.0           75.00
# 2         nfmorenog    3.0                      0.0           37.50
# 3         AFelipeGA    3.0                     40.0           37.50
# 4        mballeng91    3.0                      0.0           25.00
# 5          dduartec    3.0                     80.0           83.33
# 6         srmedinac    3.0                     20.0           33.33
# 7      wilson911013    3.0                      0.0           25.00
# 8     wapiravaguens    3.0                     80.0           75.00
# 9          davidh17    3.0                     20.0           45.83
# 10   DianaNavarrete    3.0                     20.0           62.50
# 11        jdmonroyg    3.0                      0.0           25.00
# 12        jorge52an    3.0                    100.0           50.00
# 13  jscastelblancoh    3.0                    100.0           83.33
# 14       juclopezso    3.0                     60.0           50.00
# 15        afforeroc    3.0                     20.0           29.17
# 16      dagofonseca    3.0                     40.0           37.50
# 17      lacardenasv    3.0                    100.0           75.00
# 18      oacastillol    3.0                     60.0           62.50
# 19       ncampuzano    3.0                     20.0           45.83
# 20         adriel62    3.0                     80.0           66.67
# 21         capinzor    3.0                     20.0           25.00
# 22         ofnanezn    3.0                     40.0           58.33
# 23        macuestap    3.0                     40.0           50.00
# 24           spenas    3.0                     20.0           33.33
# 25      kgbayala528    3.0                     80.0           50.00
# 26       lgmoralesa    3.0                    100.0           70.83
# 27       ronaldsg20    3.0                     20.0           45.83
# 28    cccristanchoc    3.0                     20.0           33.33
# 29       jmalvarezd    3.0                     80.0           75.00
# 30        smarquezo    3.0                     20.0           33.33
# 31          sarizag    3.0                     20.0           33.33
# 32         Chranium    3.0                     20.0           25.00
# 33          DavidQP    3.0                     80.0           70.83
# 34      afceballosr    3.0                     80.0           45.83
# 35        lizzyt10h    3.0                     20.0           54.17
# 36       NicolasPrr    3.0                    100.0           83.33
# 37    jumcorredorro    3.0                    100.0           62.50
# 38         template    NaN                      NaN             NaN
#
#     novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0            87.50        329.17         87.5         87.5
# 1            92.50        355.00         87.5        100.0
# 2            15.00        127.50         75.0         75.0
# 3            56.25        221.25         87.5         75.0
# 4            25.00        112.50         62.5         62.5
# 5            95.00        345.83         87.5         87.5
# 6             0.00        128.33         75.0         62.5
# 7             0.00         75.00         50.0         37.5
# 8            72.50        327.50        100.0         62.5
# 9            56.25        209.58         87.5         75.0
# 10           25.00        145.00         37.5         37.5
# 11           25.00         75.00         25.0          0.0
# 12           60.00        310.00        100.0         75.0
# 13          100.00        358.33         75.0         75.0
# 14           81.25        278.75         87.5         62.5
# 15           50.00        161.67         62.5         50.0
# 16           66.67        231.67         87.5         87.5
# 17           75.00        350.00        100.0         87.5
# 18           37.50        235.00         75.0         62.5
# 19           50.00        203.33         87.5         62.5
# 20           67.50        301.67         87.5         87.5
# 21           58.33        203.33        100.0         87.5
# 22           25.00        198.33         75.0         50.0
# 23           25.00        177.50         62.5         62.5
# 24            0.00        115.83         62.5         62.5
# 25           81.25        298.75         87.5         62.5
# 26           87.50        345.83         87.5         87.5
# 27           12.50        178.33        100.0        100.0
# 28           56.25        197.08         87.5         62.5
# 29           93.75        348.75        100.0         87.5
# 30           57.50        185.83         75.0         62.5
# 31           56.25        209.58        100.0         75.0
# 32            0.00         95.00         50.0         50.0
# 33           83.33        284.17         50.0         50.0
# 34           57.50        270.83         87.5         87.5
# 35           81.25        255.42        100.0        100.0
# 36           90.00        360.83         87.5         62.5
# 37           75.00        325.00         87.5         87.5
# 38             NaN           NaN          NaN          NaN
#
#     user-requirement-phase4  infovis-phase4  ...  improve-effort-23  \
# 0                      80.0           58.33  ...                0.0
# 1                     100.0           70.83  ...                6.5
# 2                       0.0           33.33  ...                2.5
# 3                      40.0           37.50  ...                0.0
# 4                       0.0           25.00  ...                0.0
# 5                       0.0            0.00  ...                3.5
# 6                      20.0           33.33  ...                1.0
# 7                      20.0           25.00  ...                0.0
# 8                      80.0           75.00  ...                4.0
# 9                       0.0            0.00  ...              -17.0
# 10                     20.0           58.33  ...                0.0
# 11                      0.0            0.00  ...                0.0
# 12                     60.0           33.33  ...                2.5
# 13                    100.0           66.67  ...              -13.5
# 14                     60.0           29.17  ...                0.0
# 15                     20.0           29.17  ...                0.0
# 16                     40.0           37.50  ...               -4.0
# 17                     60.0           37.50  ...              -23.5
# 18                      0.0           33.33  ...               -5.0
# 19                     20.0           37.50  ...              177.5
# 20                     40.0           33.33  ...              -23.0
# 21                     20.0           25.00  ...               60.5
# 22                     20.0           33.33  ...               11.0
# 23                     20.0           41.67  ...                5.0
# 24                     20.0           33.33  ...                0.0
# 25                     60.0           45.83  ...              -36.0
# 26                    100.0           66.67  ...                2.0
# 27                     20.0           33.33  ...              -25.5
# 28                     20.0           33.33  ...                0.0
# 29                     60.0           70.83  ...                0.0
# 30                     20.0           29.17  ...                0.0
# 31                     20.0           33.33  ...                0.0
# 32                     20.0           25.00  ...                0.0
# 33                     80.0           66.67  ...               28.5
# 34                     40.0           50.00  ...               -3.5
# 35                      0.0           29.17  ...                0.0
# 36                      0.0           33.33  ...                0.0
# 37                     80.0           58.33  ...               12.0
# 38                      NaN             NaN  ...                NaN
#
#     improve-effort-34  improve-effort-45  improve-effort-15  \
# 0               -97.0                0.0             -137.5
# 1                10.5               22.0              -91.5
# 2                 1.0                0.0               -3.5
# 3                 0.0                0.0              -76.5
# 4                 2.5                0.0                2.5
# 5                 0.0                0.0                3.5
# 6                 0.5                0.0              -66.0
# 7                 0.0                0.0                0.0
# 8                 4.0               -1.0               -5.5
# 9               127.0               34.0              -57.0
# 10                0.0                0.0               21.5
# 11                0.0                0.0              -41.0
# 12                4.0              -23.0              -37.5
# 13              -20.0              -10.0              -77.0
# 14              -62.5              125.0                0.0
# 15                0.0                0.0                0.0
# 16               -4.5              -25.0              -39.5
# 17              -86.0               11.0              -14.5
# 18              -27.5               -1.0              -48.0
# 19                0.0             -117.5              -93.5
# 20               74.5               90.5               19.5
# 21               56.0              -22.5              -22.5
# 22                0.0                0.0               18.5
# 23               -2.5                0.0                0.0
# 24                0.0                0.0               53.5
# 25                0.0                0.0              -34.5
# 26               -3.0               53.0               51.5
# 27                2.0                3.0               -8.0
# 28                0.0                8.5                8.0
# 29                0.0               -1.0                7.0
# 30              -37.5             -159.5             -278.0
# 31             -423.0              840.0              -27.0
# 32                0.0                0.0                0.0
# 33               -1.0               -4.5                3.0
# 34               58.0                0.5                0.0
# 35                4.5               -4.0               11.5
# 36              -36.5                0.0               16.5
# 37                1.0                1.0               11.5
# 38                NaN                NaN                NaN
#
#     improve-effort-25                                          functions  \
# 0               -98.0  [google.maps.Map, z.document.getElementById, g...
# 1                17.0  [jquery.min.js, bootstrap.min.css, awesome.min...
# 2                 2.0  [FirstLook.css, bootstrap.min.css, jquery.min....
# 3                 0.0  [materialize.min.css, style.css, awesome.min.c...
# 4                 2.5  [.bin, e.g, protractor.conf.js, exports.config...
# 5                 9.5  [.js, style.css, superplaceholder.js, superpla...
# 6                 1.5  [.create, package.json, pkg.title, pkg.version...
# 7                 0.0  [.js, jsInitMap.js, .ajax, t.module.exports, o...
# 8                 4.5  [.css, .js, js.org, .v, bootstrap.min.css, the...
# 9                28.0  [bootstrap.min.css, style.css, jquery.min.js, ...
# 10                0.0  [.l, morado.jpg, a.active, a.active, google.ma...
# 11                0.0  [.mifecha, bootstrap.min.css, theme.min.css, j...
# 12              -26.0  [main.css, material.min.js, angular.min.js, an...
# 13              -62.0  [bootstrap.min.css, theme.min.css, style.css, ...
# 14             -125.0  [bootstrap.min.css, portfolio.css, awesome.min...
# 15              -41.5  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...
# 16                3.0  [style.css, jquery.min.js, maps.js, markerclus...
# 17              -24.0  [materialize.css, materialize.min.css, styleSe...
# 18              -36.5  [bootstrap.min.css, theme.min.css, awesome.min...
# 19               59.5  [bootstrap.min.css, awesome.min.css, app.css, ...
# 20               46.5  [favicon.ico, .min.js, bootstrap.min.css, appl...
# 21                8.5  [bootstrap.min.css, estilos.css, .min.js, boot...
# 22               11.0  [.create, package.json, pkg.title, pkg.version...
# 23                2.5  [style.css, favicon.ico, bootstrap.min.css, th...
# 24                0.0  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 25              -36.0  [latest.min.js, jquery.min.js, bootstrap.min.c...
# 26               43.5  [bootstrap.min.css, index.css, criteria.css, j...
# 27               -8.0  [ownStyle.css, theme.min.css, bootstrap.min.cs...
# 28              -17.0  [unal.edu.co, bootstrap.min.css, template.css,...
# 29               -1.0  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 30             -210.0  [bootstrap.min.css, data.json, jquery.min.js, ...
# 31               -8.5  [js.org, .v, .min.js, style.css, jquery.min.js...
# 32                2.5  [style.css, main.js, z.document.getElementById...
# 33                6.0  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 34                0.0  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 35                8.0  [bootstrap.min.css, jquery.min.js, .min.css, t...
# 36               16.5  [jquery.min.js, bootstrap.min.css, stylesLogin...
# 37               11.5  [jquery.min.js, bootstrap.min.css, .js, script...
# 38                NaN  [bootstrap.min.css, theme.min.css, jquery.min....
#
#                                                unique  len_unique  \
# 0   google.maps.Map,z.document.getElementById,goog...        25.0
# 1   jquery.min.js,bootstrap.min.css,awesome.min.cs...      2295.0
# 2   FirstLook.css,bootstrap.min.css,jquery.min.js,...        51.0
# 3   materialize.min.css,style.css,awesome.min.css,...      1907.0
# 4   .bin,e.g,protractor.conf.js,exports.config,spe...     60922.0
# 5   .js,style.css,superplaceholder.js,maps.js,weat...      1806.0
# 6   .create,package.json,pkg.title,pkg.version,pkg...        55.0
# 7   .js,jsInitMap.js,.ajax,t.module.exports,option...       346.0
# 8   .css,.js,js.org,.v,bootstrap.min.css,theme.min...        77.0
# 9   bootstrap.min.css,style.css,jquery.min.js,.js,...        87.0
# 10  .l,morado.jpg,a.active,google.maps.Map,z.docum...         6.0
# 11  .mifecha,bootstrap.min.css,theme.min.css,jquer...        13.0
# 12  main.css,material.min.js,angular.min.js,angula...       298.0
# 13  bootstrap.min.css,theme.min.css,style.css,hove...       178.0
# 14  bootstrap.min.css,portfolio.css,awesome.min.cs...        30.0
# 15  bootstrap.min.css,uic.edu,.js,z.document.getEl...         6.0
# 16  style.css,jquery.min.js,maps.js,markerclustere...       253.0
# 17  materialize.css,materialize.min.css,styleSearc...      9513.0
# 18  bootstrap.min.css,theme.min.css,awesome.min.cs...       293.0
# 19  bootstrap.min.css,awesome.min.css,app.css,jque...       140.0
# 20  favicon.ico,.min.js,bootstrap.min.css,applicat...       149.0
# 21  bootstrap.min.css,estilos.css,.min.js,justgage...      1666.0
# 22  .create,package.json,pkg.title,pkg.version,pkg...        57.0
# 23  style.css,favicon.ico,bootstrap.min.css,theme....        16.0
# 24  bootstrap.min.css,mdb.min.css,demos.css,style....        22.0
# 25  latest.min.js,jquery.min.js,bootstrap.min.css,...       108.0
# 26  bootstrap.min.css,index.css,criteria.css,jquer...        74.0
# 27  ownStyle.css,theme.min.css,bootstrap.min.css,m...     34477.0
# 28  unal.edu.co,bootstrap.min.css,template.css,dat...        97.0
# 29  jmalvarezd.js,bootstrap.min.css,jquery.min.js,...        52.0
# 30  bootstrap.min.css,data.json,jquery.min.js,reso...        61.0
# 31  js.org,.v,.min.js,style.css,jquery.min.js,scri...        39.0
# 32  style.css,main.js,z.document.getElementById,go...         5.0
# 33  bootstrap.min.css,Respond.js,shiv.min.js,respo...        56.0
# 34  bootstrap.min.css,style.css,bulk.jpg,jquery.mi...        36.0
# 35  bootstrap.min.css,jquery.min.js,.min.css,this....        71.0
# 36  jquery.min.js,bootstrap.min.css,stylesLoginf.c...       128.0
# 37  jquery.min.js,bootstrap.min.css,.js,scripto.js...       165.0
# 38                                                NaN         NaN
#
#     len_functions  phase
# 0            26.0    NaN
# 1          2567.0    NaN
# 2            52.0    NaN
# 3          2059.0    NaN
# 4         71871.0    NaN
# 5          2338.0    NaN
# 6            56.0    NaN
# 7           362.0    NaN
# 8            89.0    NaN
# 9            88.0    NaN
# 10            7.0    NaN
# 11           14.0    NaN
# 12          318.0    NaN
# 13          181.0    NaN
# 14           30.0    NaN
# 15            7.0    NaN
# 16          271.0    NaN
# 17        10885.0    NaN
# 18          316.0    NaN
# 19          146.0    NaN
# 20          161.0    NaN
# 21         1846.0    NaN
# 22           58.0    NaN
# 23           17.0    NaN
# 24           22.0    NaN
# 25          108.0    NaN
# 26           77.0    NaN
# 27        39470.0    NaN
# 28          100.0    NaN
# 29           53.0    NaN
# 30           64.0    NaN
# 31           40.0    NaN
# 32            5.0    NaN
# 33           57.0    NaN
# 34           42.0    NaN
# 35           75.0    NaN
# 36          133.0    NaN
# 37          181.0    NaN
# 38            NaN    0.0
#
# [39 rows x 91 columns]

# %% [markdown]
# ## Phase 1 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group0 = overall_phase1_group0[overall_phase1_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group0["functions"], overall_phase1_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group0 = pd.DataFrame(result)
phase1_group0
# Out:
#             user1        user2  similarity
# 0       fffeelipe    mnguzmanc    0.086957
# 1       fffeelipe        DglyP    0.043478
# 2       fffeelipe  Judgarciani    0.052632
# 3       fffeelipe    sacastroc    0.130435
# 4       fffeelipe    pcberriop    0.071429
# ..            ...          ...         ...
# 271    capinillab    bsgarciac    0.125000
# 272    capinillab     template    0.041667
# 273  lfvalderrama    bsgarciac    0.080645
# 274  lfvalderrama     template    0.105263
# 275     bsgarciac     template    0.054054
#
# [276 rows x 3 columns]

# %%
phase1_group0 = phase1_group0.loc[phase1_group0['user2'] == 'template']
phase1_group0
# Out:
#               user1     user2  similarity
# 22        fffeelipe  template    0.045455
# 44        mnguzmanc  template    0.025000
# 65            DglyP  template    0.016667
# 85      Judgarciani  template    0.089655
# 104       sacastroc  template    0.050847
# 122       pcberriop  template    0.316667
# 139     hsmartineza  template    0.155738
# 155        Moimolcp  template    0.075342
# 170      JoseMolano  template    0.025424
# 184   maikellPardoA  template    0.025210
# 197      NicolasZon  template    0.056452
# 209       camilo654  template    0.025210
# 220  CristianLozano  template    0.025424
# 230       jdsuarezj  template    0.062500
# 239       pipemax85  template    0.150000
# 247     juandavidro  template    0.967213
# 254  UNhcrodriguezl  template    0.028986
# 260     camilo13152  template    0.016129
# 265    leavendanoro  template    0.056911
# 269      cdcordobaa  template    0.046154
# 272      capinillab  template    0.041667
# 274    lfvalderrama  template    0.105263
# 275       bsgarciac  template    0.054054

# %% [markdown]
# ## Phase 1 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group1 = overall_phase1_group1[overall_phase1_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group1["functions"], overall_phase1_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group1 = pd.DataFrame(result)
phase1_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.187500
# 1         gasierram     bdcajicam    0.187500
# 2         gasierram     helmeraac    0.222222
# 3         gasierram    dasalgadob    0.411765
# 4         gasierram    falperezgo    0.161290
# ..              ...           ...         ...
# 523        jcrubioa  JairVillalba    0.009174
# 524        jcrubioa      template    0.345455
# 525  joahernandezca  JairVillalba    0.750000
# 526  joahernandezca      template    0.025424
# 527    JairVillalba      template    0.025210
#
# [528 rows x 3 columns]

# %%
phase1_group1 = phase1_group1.loc[phase1_group1['user2'] == 'template']
phase1_group1
# Out:
#               user1     user2  similarity
# 31        gasierram  template    0.089431
# 62     adamantwharf  template    0.025424
# 92        bdcajicam  template    0.025424
# 121       helmeraac  template    0.033333
# 149      dasalgadob  template    0.067797
# 176      falperezgo  template    0.053435
# 202       djguzmanc  template    0.179688
# 227          oeroaq  template    0.112745
# 251         gcantem  template    0.845528
# 274     Semoralesga  template    0.033613
# 296      jonatan360  template    0.135802
# 317  jesusfchavarro  template    0.025316
# 337  jufcontrerasco  template    0.031746
# 356      dsbarrerag  template    0.039370
# 374       wolfstain  template    0.161290
# 391      miaborjaac  template    0.058480
# 407   ivdgonzalezco  template    0.041543
# 422    Christian7sr  template    0.000000
# 436      jsnarvaezb  template    0.128000
# 449   gfalbarracinr  template    0.008065
# 461        aldiazve  template    0.070312
# 472  diegoaguevarar  template    0.886364
# 482      fevargasmo  template    0.032520
# 491      jmhurtadoc  template    0.813793
# 499     nabautistal  template    0.025424
# 506          crigar  template    0.033898
# 512     jiapulidoar  template    0.035971
# 517       jsviveroj  template    0.040984
# 521      daandradec  template    0.039735
# 524        jcrubioa  template    0.345455
# 526  joahernandezca  template    0.025424
# 527    JairVillalba  template    0.025210

# %% [markdown]
# ## Phase 1 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group2 = overall_phase1_group2[overall_phase1_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group2["functions"], overall_phase1_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group2 = pd.DataFrame(result)
phase1_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.187500
# 1    jusherrerama       Phoenixest    0.187500
# 2    jusherrerama         HashNick    0.057143
# 3    jusherrerama  juasmartinezbel    0.039604
# 4    jusherrerama         mdbelloc    0.062500
# ..            ...              ...         ...
# 625      lsfinite     jscontrerasp    0.166667
# 626      lsfinite         template    0.024194
# 627     xdanielsb     jscontrerasp    0.018182
# 628     xdanielsb         template    0.040741
# 629  jscontrerasp         template    0.025000
#
# [630 rows x 3 columns]

# %%
phase1_group2 = phase1_group2.loc[phase1_group2['user2'] == 'template']
phase1_group2
# Out:
#                user1     user2  similarity
# 34      jusherrerama  template    0.031008
# 68           bdvegat  template    0.025210
# 101       Phoenixest  template    0.025210
# 133         HashNick  template    0.500000
# 164  juasmartinezbel  template    0.245509
# 194         mdbelloc  template    0.425000
# 223      diegocruz10  template    0.117188
# 251           sagilm  template    0.025424
# 278         idrojasf  template    0.025602
# 304     raulramirezp  template    0.025210
# 329        fabianr23  template    0.029851
# 353       jhriverasa  template    0.045802
# 376       jhonsd1996  template    0.000000
# 398       JuanitoAli  template    0.053435
# 419       Davsatu313  template    0.047244
# 439   cesarochoa2006  template    0.064000
# 458        jjmuesesq  template    0.025424
# 476           kancas  template    0.146341
# 493          Gantiva  template    0.081301
# 509       Dandarprox  template    0.033333
# 524       debeltranc  template    0.000000
# 538        ykchautai  template    0.008065
# 551        ligibrial  template    0.039062
# 563       davidrh195  template    0.023622
# 574      JulianaNino  template    0.007937
# 584         luegilca  template    0.127820
# 593           Yelis3  template    0.001349
# 601        begarzonf  template    0.101695
# 608       kmendezp96  template    0.284722
# 614         leguzman  template    0.078125
# 619     luealfonsoru  template    0.034965
# 623         oserasoa  template    0.150000
# 626         lsfinite  template    0.024194
# 628        xdanielsb  template    0.040741
# 629     jscontrerasp  template    0.025000

# %% [markdown]
# ## Phase 1 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group3 = overall_phase1_group3[overall_phase1_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group3["functions"], overall_phase1_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group3 = pd.DataFrame(result)
phase1_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.045455
# 1        lemartinp      nfmorenog    0.157895
# 2        lemartinp      AFelipeGA    0.008621
# 3        lemartinp     mballeng91    0.000049
# 4        lemartinp       dduartec    0.040000
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.209677
# 699      lizzyt10h       template    0.991525
# 700     NicolasPrr  jumcorredorro    0.106383
# 701     NicolasPrr       template    0.045802
# 702  jumcorredorro       template    0.217742
#
# [703 rows x 3 columns]

# %%
phase1_group3 = phase1_group3.loc[phase1_group3['user2'] == 'template']
phase1_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.024590
# 72         juligarji  template    0.030769
# 107        nfmorenog  template    0.055556
# 141        AFelipeGA  template    0.022422
# 174       mballeng91  template    0.000689
# 206         dduartec  template    0.122951
# 237        srmedinac  template    0.458333
# 267    wapiravaguens  template    0.111940
# 296         davidh17  template    0.090164
# 324   DianaNavarrete  template    0.016529
# 351        jdmonroyg  template    0.000000
# 377        jorge52an  template    0.031250
# 402  jscastelblancoh  template    0.077519
# 426       juclopezso  template    0.088235
# 449        afforeroc  template    0.042017
# 471      dagofonseca  template    0.130081
# 492      lacardenasv  template    0.086667
# 512      oacastillol  template    0.050000
# 531       ncampuzano  template    0.048387
# 549         adriel62  template    0.049587
# 566         capinzor  template    0.037879
# 582         ofnanezn  template    0.051136
# 597        macuestap  template    0.044118
# 611           spenas  template    0.024194
# 624      kgbayala528  template    0.138298
# 636       lgmoralesa  template    0.043796
# 647       ronaldsg20  template    0.001420
# 657    cccristanchoc  template    0.041379
# 666       jmalvarezd  template    0.102941
# 674        smarquezo  template    0.016949
# 681          sarizag  template    0.054264
# 687         Chranium  template    0.025000
# 692          DavidQP  template    0.029851
# 696      afceballosr  template    0.144000
# 699        lizzyt10h  template    0.991525
# 701       NicolasPrr  template    0.045802
# 702    jumcorredorro  template    0.217742

# %% [markdown]
# ## Phase 2 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group0 = overall_phase2_group0[overall_phase2_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group0["functions"], overall_phase2_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group0 = pd.DataFrame(result)
phase2_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.102041
# 1       fffeelipe    jmcuestasb    0.002337
# 2       fffeelipe  jjrodriguezn    0.200000
# 3       fffeelipe         DglyP    0.238095
# 4       fffeelipe   Judgarciani    0.070000
# ..            ...           ...         ...
# 373  lfvalderrama        gabi04    0.125000
# 374  lfvalderrama      template    0.097222
# 375     bsgarciac        gabi04    0.136364
# 376     bsgarciac      template    0.156863
# 377        gabi04      template    0.081633
#
# [378 rows x 3 columns]

# %%
phase2_group0 = phase2_group0.loc[phase2_group0['user2'] == 'template']
phase2_group0
# Out:
#               user1     user2  similarity
# 26        fffeelipe  template    0.065217
# 52        mnguzmanc  template    0.108527
# 77       jmcuestasb  template    0.006326
# 101    jjrodriguezn  template    0.045802
# 124           DglyP  template    0.076336
# 146     Judgarciani  template    0.139535
# 167       sacastroc  template    0.128571
# 187       pcberriop  template    0.314050
# 206     hsmartineza  template    0.195312
# 224        Moimolcp  template    0.075342
# 241     CamiloRueda  template    0.018634
# 257      JoseMolano  template    0.344262
# 272   maikellPardoA  template    0.025210
# 286      NicolasZon  template    0.056911
# 299       camilo654  template    0.054264
# 311  CristianLozano  template    0.024590
# 322       jdsuarezj  template    0.204545
# 332       pipemax85  template    0.148760
# 341     juandavidro  template    0.967213
# 349  UNhcrodriguezl  template    0.274510
# 356     camilo13152  template    0.031250
# 362    leavendanoro  template    0.052632
# 367      cdcordobaa  template    0.063830
# 371      capinillab  template    0.132231
# 374    lfvalderrama  template    0.097222
# 376       bsgarciac  template    0.156863
# 377          gabi04  template    0.081633

# %% [markdown]
# ## Phase 2 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group1 = overall_phase2_group1[overall_phase2_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group1["functions"], overall_phase2_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group1 = pd.DataFrame(result)
phase2_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.187500
# 1         gasierram     bdcajicam    0.187500
# 2         gasierram   dfhincapiem    0.250000
# 3         gasierram     helmeraac    0.192308
# 4         gasierram    dasalgadob    0.411765
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.056047
# 662        jcrubioa      template    0.336283
# 663  joahernandezca  JairVillalba    0.128000
# 664  joahernandezca      template    1.000000
# 665    JairVillalba      template    0.128000
#
# [666 rows x 3 columns]

# %%
phase2_group1 = phase2_group1.loc[phase2_group1['user2'] == 'template']
phase2_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.089431
# 70     adamantwharf  template    0.025424
# 104       bdcajicam  template    0.025424
# 137     dfhincapiem  template    0.025210
# 169       helmeraac  template    0.047244
# 200      dasalgadob  template    0.067797
# 230      falperezgo  template    0.017516
# 259       djguzmanc  template    0.132867
# 287      gsuarezc04  template    0.081633
# 314          oeroaq  template    0.126087
# 340         gcantem  template    0.845528
# 365     Semoralesga  template    0.015744
# 389      jonatan360  template    0.108696
# 412  jesusfchavarro  template    0.016511
# 434    stevenbustos  template    0.024793
# 455  jufcontrerasco  template    0.031496
# 475      dsbarrerag  template    0.062937
# 494       wolfstain  template    0.172932
# 512      miaborjaac  template    0.066667
# 529   ivdgonzalezco  template    0.041543
# 545    Christian7sr  template    0.000000
# 560      jsnarvaezb  template    0.248175
# 574   gfalbarracinr  template    0.016000
# 587        aldiazve  template    0.001925
# 599  diegoaguevarar  template    0.879699
# 610      fevargasmo  template    0.134921
# 620      jmhurtadoc  template    0.813793
# 629     anfmorenoso  template    0.123967
# 637     nabautistal  template    0.025424
# 644          crigar  template    0.033898
# 650     jiapulidoar  template    0.000783
# 655       jsviveroj  template    0.164179
# 659      daandradec  template    0.107843
# 662        jcrubioa  template    0.336283
# 664  joahernandezca  template    1.000000
# 665    JairVillalba  template    0.128000

# %% [markdown]
# ## Phase 2 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group2 = overall_phase2_group2[overall_phase2_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group2["functions"], overall_phase2_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group2 = pd.DataFrame(result)
phase2_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.187500
# 1    jusherrerama       Phoenixest    0.187500
# 2    jusherrerama         HashNick    0.062500
# 3    jusherrerama  juasmartinezbel    0.037037
# 4    jusherrerama         mdbelloc    0.062500
# ..            ...              ...         ...
# 661      lsfinite     jscontrerasp    0.002207
# 662      lsfinite         template    0.006946
# 663     xdanielsb     jscontrerasp    0.030457
# 664     xdanielsb         template    0.045296
# 665  jscontrerasp         template    0.053030
#
# [666 rows x 3 columns]

# %%
phase2_group2 = phase2_group2.loc[phase2_group2['user2'] == 'template']
phase2_group2
# Out:
#                user1     user2  similarity
# 35      jusherrerama  template    0.031008
# 70           bdvegat  template    0.025210
# 104       Phoenixest  template    0.025210
# 137         HashNick  template    0.449153
# 169  juasmartinezbel  template    0.194444
# 200         mdbelloc  template    0.425000
# 230      diegocruz10  template    0.116279
# 259           sagilm  template    0.033613
# 287         idrojasf  template    0.025602
# 314     raulramirezp  template    0.064000
# 340        fabianr23  template    0.070968
# 365       jhriverasa  template    0.052239
# 389       jhonsd1996  template    0.025000
# 412       JuanitoAli  template    0.017899
# 434       Davsatu313  template    0.335878
# 455   cesarochoa2006  template    0.300000
# 475        jjmuesesq  template    0.025424
# 494     jucjimenezmo  template    0.024194
# 512           kancas  template    0.186567
# 529          Gantiva  template    0.083916
# 545       Dandarprox  template    0.069620
# 560       debeltranc  template    0.000000
# 574        ykchautai  template    0.072581
# 587        ligibrial  template    0.016698
# 599       davidrh195  template    0.022727
# 610      JulianaNino  template    0.036765
# 620         luegilca  template    0.127820
# 629           Yelis3  template    0.001754
# 637        begarzonf  template    0.049505
# 644       kmendezp96  template    0.284722
# 650         leguzman  template    0.351145
# 655     luealfonsoru  template    0.386207
# 659         oserasoa  template    0.245902
# 662         lsfinite  template    0.006946
# 664        xdanielsb  template    0.045296
# 665     jscontrerasp  template    0.053030

# %% [markdown]
# ## Phase 2 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group3 = overall_phase2_group3[overall_phase2_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group3["functions"], overall_phase2_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group3 = pd.DataFrame(result)
phase2_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.028777
# 1        lemartinp      nfmorenog    0.166667
# 2        lemartinp      AFelipeGA    0.003133
# 3        lemartinp     mballeng91    0.000066
# 4        lemartinp       dduartec    0.127660
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.186047
# 699      lizzyt10h       template    0.065041
# 700     NicolasPrr  jumcorredorro    0.096154
# 701     NicolasPrr       template    0.045802
# 702  jumcorredorro       template    0.218750
#
# [703 rows x 3 columns]

# %%
phase2_group3 = phase2_group3.loc[phase2_group3['user2'] == 'template']
phase2_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.081967
# 72         juligarji  template    0.033473
# 107        nfmorenog  template    0.118881
# 141        AFelipeGA  template    0.015547
# 174       mballeng91  template    0.000689
# 206         dduartec  template    0.129496
# 237        srmedinac  template    0.054545
# 267     wilson911013  template    0.010965
# 296    wapiravaguens  template    0.106250
# 324         davidh17  template    0.203008
# 351   DianaNavarrete  template    0.024793
# 377        jorge52an  template    0.036364
# 402  jscastelblancoh  template    0.070922
# 426       juclopezso  template    0.024793
# 449        afforeroc  template    0.042017
# 471      dagofonseca  template    0.113821
# 492      lacardenasv  template    0.084967
# 512      oacastillol  template    0.180412
# 531       ncampuzano  template    0.045161
# 549         adriel62  template    0.266129
# 566         capinzor  template    0.037879
# 582         ofnanezn  template    0.051136
# 597        macuestap  template    0.072581
# 611           spenas  template    0.037037
# 624      kgbayala528  template    0.138298
# 636       lgmoralesa  template    0.142857
# 647       ronaldsg20  template    0.001420
# 657    cccristanchoc  template    0.118421
# 666       jmalvarezd  template    0.173611
# 674        smarquezo  template    0.016667
# 681          sarizag  template    0.089552
# 687         Chranium  template    0.025000
# 692          DavidQP  template    0.087591
# 696      afceballosr  template    0.106383
# 699        lizzyt10h  template    0.065041
# 701       NicolasPrr  template    0.045802
# 702    jumcorredorro  template    0.218750

# %% [markdown]
# ## Phase 3 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group0 = overall_phase3_group0[overall_phase3_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group0["functions"], overall_phase3_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group0 = pd.DataFrame(result)
phase3_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.005108
# 1       fffeelipe    jmcuestasb    0.002337
# 2       fffeelipe  jjrodriguezn    0.098039
# 3       fffeelipe         DglyP    0.238095
# 4       fffeelipe   Judgarciani    0.054422
# ..            ...           ...         ...
# 373  lfvalderrama        gabi04    0.103774
# 374  lfvalderrama      template    0.092593
# 375     bsgarciac        gabi04    0.106383
# 376     bsgarciac      template    0.148936
# 377        gabi04      template    0.100000
#
# [378 rows x 3 columns]

# %%
phase3_group0 = phase3_group0.loc[phase3_group0['user2'] == 'template']
phase3_group0
# Out:
#               user1     user2  similarity
# 26        fffeelipe  template    0.065217
# 52        mnguzmanc  template    0.028761
# 77       jmcuestasb  template    0.006326
# 101    jjrodriguezn  template    0.198347
# 124           DglyP  template    0.076336
# 146     Judgarciani  template    0.114155
# 167       sacastroc  template    0.134146
# 187       pcberriop  template    0.314050
# 206     hsmartineza  template    0.278195
# 224        Moimolcp  template    0.073034
# 241     CamiloRueda  template    0.018634
# 257      JoseMolano  template    0.338710
# 272   maikellPardoA  template    0.025210
# 286      NicolasZon  template    0.056911
# 299       camilo654  template    0.054264
# 311  CristianLozano  template    0.024590
# 322       jdsuarezj  template    0.202614
# 332       pipemax85  template    0.188525
# 341     juandavidro  template    0.099174
# 349  UNhcrodriguezl  template    0.303797
# 356     camilo13152  template    0.345324
# 362    leavendanoro  template    0.049296
# 367      cdcordobaa  template    0.063830
# 371      capinillab  template    0.132231
# 374    lfvalderrama  template    0.092593
# 376       bsgarciac  template    0.148936
# 377          gabi04  template    0.100000

# %% [markdown]
# ## Phase 3 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group1 = overall_phase3_group1[overall_phase3_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group1["functions"], overall_phase3_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group1 = pd.DataFrame(result)
phase3_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.050000
# 1         gasierram     bdcajicam    0.523810
# 2         gasierram   dfhincapiem    0.066667
# 3         gasierram     helmeraac    0.102941
# 4         gasierram    dasalgadob    0.114754
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.072886
# 662        jcrubioa      template    0.336283
# 663  joahernandezca  JairVillalba    0.126866
# 664  joahernandezca      template    1.000000
# 665    JairVillalba      template    0.126866
#
# [666 rows x 3 columns]

# %%
phase3_group1 = phase3_group1.loc[phase3_group1['user2'] == 'template']
phase3_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.447154
# 70     adamantwharf  template    0.025424
# 104       bdcajicam  template    0.272727
# 137     dfhincapiem  template    0.025210
# 169       helmeraac  template    0.047244
# 200      dasalgadob  template    0.067797
# 230      falperezgo  template    0.017516
# 259       djguzmanc  template    0.136054
# 287      gsuarezc04  template    0.081633
# 314          oeroaq  template    0.060403
# 340         gcantem  template    0.845528
# 365     Semoralesga  template    0.015744
# 389      jonatan360  template    0.129032
# 412  jesusfchavarro  template    0.016183
# 434    stevenbustos  template    0.024793
# 455  jufcontrerasco  template    0.031496
# 475      dsbarrerag  template    0.076433
# 494       wolfstain  template    0.094771
# 512      miaborjaac  template    0.073529
# 529   ivdgonzalezco  template    0.041543
# 545    Christian7sr  template    0.024793
# 560      jsnarvaezb  template    0.246377
# 574   gfalbarracinr  template    0.032258
# 587        aldiazve  template    0.001925
# 599  diegoaguevarar  template    0.879699
# 610      fevargasmo  template    0.113333
# 620      jmhurtadoc  template    0.813793
# 629     anfmorenoso  template    0.123967
# 637     nabautistal  template    0.024590
# 644          crigar  template    0.033898
# 650     jiapulidoar  template    0.000783
# 655       jsviveroj  template    0.151724
# 659      daandradec  template    0.105932
# 662        jcrubioa  template    0.336283
# 664  joahernandezca  template    1.000000
# 665    JairVillalba  template    0.126866

# %% [markdown]
# ## Phase 3 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group2 = overall_phase3_group2[overall_phase3_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group2["functions"], overall_phase3_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group2 = pd.DataFrame(result)
phase3_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003471
# 1    jusherrerama       Phoenixest    0.001489
# 2    jusherrerama         HashNick    0.005350
# 3    jusherrerama  juasmartinezbel    0.005615
# 4    jusherrerama         mdbelloc    0.005839
# ..            ...              ...         ...
# 661      lsfinite     jscontrerasp    0.003516
# 662      lsfinite         template    0.008009
# 663     xdanielsb     jscontrerasp    0.033654
# 664     xdanielsb         template    0.055172
# 665  jscontrerasp         template    0.058394
#
# [666 rows x 3 columns]

# %%
phase3_group2 = phase3_group2.loc[phase3_group2['user2'] == 'template']
phase3_group2
# Out:
#                user1     user2  similarity
# 35      jusherrerama  template    0.016691
# 70           bdvegat  template    0.066667
# 104       Phoenixest  template    0.025210
# 137         HashNick  template    0.449153
# 169  juasmartinezbel  template    0.165899
# 200         mdbelloc  template    0.425000
# 230      diegocruz10  template    0.105634
# 259           sagilm  template    0.168067
# 287         idrojasf  template    0.025602
# 314     raulramirezp  template    0.064000
# 340        fabianr23  template    0.058511
# 365       jhriverasa  template    0.051471
# 389       jhonsd1996  template    0.025000
# 412       JuanitoAli  template    0.017658
# 434       Davsatu313  template    0.142857
# 455   cesarochoa2006  template    0.273743
# 475        jjmuesesq  template    0.025424
# 494     jucjimenezmo  template    0.024194
# 512           kancas  template    0.186567
# 529          Gantiva  template    0.093960
# 545       Dandarprox  template    0.071429
# 560       debeltranc  template    0.000000
# 574        ykchautai  template    0.084615
# 587        ligibrial  template    0.018104
# 599       davidrh195  template    0.022727
# 610      JulianaNino  template    0.056338
# 620         luegilca  template    0.127820
# 629           Yelis3  template    0.001774
# 637        begarzonf  template    0.056530
# 644       kmendezp96  template    0.275168
# 650         leguzman  template    0.339869
# 655     luealfonsoru  template    0.372414
# 659         oserasoa  template    0.273438
# 662         lsfinite  template    0.008009
# 664        xdanielsb  template    0.055172
# 665     jscontrerasp  template    0.058394

# %% [markdown]
# ## Phase 3 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group3 = overall_phase3_group3[overall_phase3_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group3["functions"], overall_phase3_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group3 = pd.DataFrame(result)
phase3_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.002667
# 1        lemartinp      nfmorenog    0.140351
# 2        lemartinp      AFelipeGA    0.003133
# 3        lemartinp     mballeng91    0.000066
# 4        lemartinp       dduartec    0.054054
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.103093
# 699      lizzyt10h       template    0.072000
# 700     NicolasPrr  jumcorredorro    0.057692
# 701     NicolasPrr       template    0.045802
# 702  jumcorredorro       template    0.187500
#
# [703 rows x 3 columns]

# %%
phase3_group3 = phase3_group3.loc[phase3_group3['user2'] == 'template']
phase3_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.081967
# 72         juligarji  template    0.015928
# 107        nfmorenog  template    0.111842
# 141        AFelipeGA  template    0.015547
# 174       mballeng91  template    0.000689
# 206         dduartec  template    0.094059
# 237        srmedinac  template    0.054545
# 267     wilson911013  template    0.010965
# 296    wapiravaguens  template    0.094972
# 324         davidh17  template    0.185430
# 351   DianaNavarrete  template    0.024793
# 377        jorge52an  template    0.024490
# 402  jscastelblancoh  template    0.081081
# 426       juclopezso  template    0.024793
# 449        afforeroc  template    0.042017
# 471      dagofonseca  template    0.097179
# 492      lacardenasv  template    0.085526
# 512      oacastillol  template    0.169082
# 531       ncampuzano  template    0.063830
# 549         adriel62  template    0.266129
# 566         capinzor  template    0.316176
# 582         ofnanezn  template    0.047904
# 597        macuestap  template    0.072581
# 611           spenas  template    0.037037
# 624      kgbayala528  template    0.141414
# 636       lgmoralesa  template    0.129870
# 647       ronaldsg20  template    0.001448
# 657    cccristanchoc  template    0.118421
# 666       jmalvarezd  template    0.171233
# 674        smarquezo  template    0.016667
# 681          sarizag  template    0.089552
# 687         Chranium  template    0.025000
# 692          DavidQP  template    0.060403
# 696      afceballosr  template    0.103448
# 699        lizzyt10h  template    0.072000
# 701       NicolasPrr  template    0.045802
# 702    jumcorredorro  template    0.187500

# %% [markdown]
# ## Phase 4 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group0 = overall_phase4_group0[overall_phase4_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group0["functions"], overall_phase4_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group0 = pd.DataFrame(result)
phase4_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.016931
# 1       fffeelipe    jmcuestasb    0.006342
# 2       fffeelipe    katherinsb    0.025000
# 3       fffeelipe  jjrodriguezn    0.040000
# 4       fffeelipe         DglyP    0.012942
# ..            ...           ...         ...
# 401  lfvalderrama        gabi04    0.111111
# 402  lfvalderrama      template    0.097561
# 403     bsgarciac        gabi04    0.101190
# 404     bsgarciac      template    0.189320
# 405        gabi04      template    0.100000
#
# [406 rows x 3 columns]

# %%
phase4_group0 = phase4_group0.loc[phase4_group0['user2'] == 'template']
phase4_group0
# Out:
#               user1     user2  similarity
# 27        fffeelipe  template    0.078431
# 54        mnguzmanc  template    0.030170
# 80       jmcuestasb  template    0.006326
# 105      katherinsb  template    0.037313
# 129    jjrodriguezn  template    0.196721
# 152           DglyP  template    0.023377
# 174     Judgarciani  template    0.112108
# 195       sacastroc  template    0.113636
# 215       pcberriop  template    0.228188
# 234     hsmartineza  template    0.184211
# 252        Moimolcp  template    0.071823
# 269     CamiloRueda  template    0.018634
# 285      JoseMolano  template    0.338710
# 300   maikellPardoA  template    0.025210
# 314      NicolasZon  template    0.056911
# 327       camilo654  template    0.064748
# 339  CristianLozano  template    0.024590
# 350       jdsuarezj  template    0.202614
# 360       pipemax85  template    0.188525
# 369     juandavidro  template    0.099174
# 377  UNhcrodriguezl  template    0.303797
# 384     camilo13152  template    0.305732
# 390    leavendanoro  template    0.072848
# 395      cdcordobaa  template    0.063830
# 399      capinillab  template    0.245902
# 402    lfvalderrama  template    0.097561
# 404       bsgarciac  template    0.189320
# 405          gabi04  template    0.100000

# %% [markdown]
# ## Phase 4 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group1 = overall_phase4_group1[overall_phase4_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group1["functions"], overall_phase4_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group1 = pd.DataFrame(result)
phase4_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.050000
# 1         gasierram     bdcajicam    0.523810
# 2         gasierram   dfhincapiem    0.066667
# 3         gasierram     helmeraac    0.119048
# 4         gasierram    dasalgadob    0.114754
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.078488
# 662        jcrubioa      template    0.336283
# 663  joahernandezca  JairVillalba    0.130435
# 664  joahernandezca      template    0.983333
# 665    JairVillalba      template    0.132353
#
# [666 rows x 3 columns]

# %%
phase4_group1 = phase4_group1.loc[phase4_group1['user2'] == 'template']
phase4_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.447154
# 70     adamantwharf  template    0.025424
# 104       bdcajicam  template    0.272727
# 137     dfhincapiem  template    0.025210
# 169       helmeraac  template    0.062937
# 200      dasalgadob  template    0.067797
# 230      falperezgo  template    0.016975
# 259       djguzmanc  template    0.151899
# 287      gsuarezc04  template    0.081633
# 314          oeroaq  template    0.021756
# 340         gcantem  template    0.150407
# 365     Semoralesga  template    0.062992
# 389      jonatan360  template    0.130233
# 412  jesusfchavarro  template    0.008156
# 434    stevenbustos  template    0.085938
# 455  jufcontrerasco  template    0.258278
# 475      dsbarrerag  template    0.074074
# 494       wolfstain  template    0.101911
# 512      miaborjaac  template    0.104265
# 529   ivdgonzalezco  template    0.042553
# 545    Christian7sr  template    0.024793
# 560      jsnarvaezb  template    0.248322
# 574   gfalbarracinr  template    0.030303
# 587        aldiazve  template    0.001703
# 599  diegoaguevarar  template    0.879699
# 610      fevargasmo  template    0.129870
# 620      jmhurtadoc  template    0.813793
# 629     anfmorenoso  template    0.166667
# 637     nabautistal  template    0.024390
# 644          crigar  template    0.033898
# 650     jiapulidoar  template    0.000783
# 655       jsviveroj  template    0.189189
# 659      daandradec  template    0.099723
# 662        jcrubioa  template    0.336283
# 664  joahernandezca  template    0.983333
# 665    JairVillalba  template    0.132353

# %% [markdown]
# ## Phase 4 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group2 = overall_phase4_group2[overall_phase4_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group2["functions"], overall_phase4_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group2 = pd.DataFrame(result)
phase4_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003471
# 1    jusherrerama       Phoenixest    0.001489
# 2    jusherrerama         HashNick    0.006799
# 3    jusherrerama          ccvacad    0.004819
# 4    jusherrerama  juasmartinezbel    0.016107
# ..            ...              ...         ...
# 698      lsfinite     jscontrerasp    0.003074
# 699      lsfinite         template    0.008005
# 700     xdanielsb     jscontrerasp    0.028689
# 701     xdanielsb         template    0.055556
# 702  jscontrerasp         template    0.058394
#
# [703 rows x 3 columns]

# %%
phase4_group2 = phase4_group2.loc[phase4_group2['user2'] == 'template']
phase4_group2
# Out:
#                user1     user2  similarity
# 36      jusherrerama  template    0.016691
# 72           bdvegat  template    0.066667
# 107       Phoenixest  template    0.025210
# 141         HashNick  template    0.500000
# 174          ccvacad  template    0.145455
# 206  juasmartinezbel  template    0.374449
# 237         mdbelloc  template    0.425000
# 267      diegocruz10  template    0.105634
# 296           sagilm  template    0.168067
# 324         idrojasf  template    0.027108
# 351     raulramirezp  template    0.106061
# 377        fabianr23  template    0.090566
# 402       jhriverasa  template    0.046154
# 426       jhonsd1996  template    0.025000
# 449       JuanitoAli  template    0.017265
# 471       Davsatu313  template    0.276074
# 492   cesarochoa2006  template    0.155039
# 512        jjmuesesq  template    0.039683
# 531     jucjimenezmo  template    0.330827
# 549           kancas  template    0.186567
# 566          Gantiva  template    0.090909
# 582       Dandarprox  template    0.107280
# 597       debeltranc  template    0.000000
# 611        ykchautai  template    0.069231
# 624        ligibrial  template    0.018104
# 636       davidrh195  template    0.022222
# 647      JulianaNino  template    0.060150
# 657         luegilca  template    0.127820
# 666           Yelis3  template    0.002534
# 674        begarzonf  template    0.056530
# 681       kmendezp96  template    0.271084
# 687         leguzman  template    0.319018
# 692     luealfonsoru  template    0.364865
# 696         oserasoa  template    0.273438
# 699         lsfinite  template    0.008005
# 701        xdanielsb  template    0.055556
# 702     jscontrerasp  template    0.058394

# %% [markdown]
# ## Phase 4 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group3 = overall_phase4_group3[overall_phase4_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group3["functions"], overall_phase4_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group3 = pd.DataFrame(result)
phase4_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.006074
# 1        lemartinp      nfmorenog    0.151515
# 2        lemartinp      AFelipeGA    0.007299
# 3        lemartinp     mballeng91    0.000213
# 4        lemartinp       dduartec    0.049180
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.070707
# 699      lizzyt10h       template    0.104294
# 700     NicolasPrr  jumcorredorro    0.054449
# 701     NicolasPrr       template    0.056865
# 702  jumcorredorro       template    0.145299
#
# [703 rows x 3 columns]

# %%
phase4_group3 = phase4_group3.loc[phase4_group3['user2'] == 'template']
phase4_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.117188
# 72         juligarji  template    0.015579
# 107        nfmorenog  template    0.111842
# 141        AFelipeGA  template    0.015547
# 174       mballeng91  template    0.000689
# 206         dduartec  template    0.094059
# 237        srmedinac  template    0.054878
# 267     wilson911013  template    0.013100
# 296    wapiravaguens  template    0.098266
# 324         davidh17  template    0.170455
# 351   DianaNavarrete  template    0.024793
# 377        jorge52an  template    0.124277
# 402  jscastelblancoh  template    0.123077
# 426       juclopezso  template    0.088889
# 449        afforeroc  template    0.042017
# 471      dagofonseca  template    0.095092
# 492      lacardenasv  template    0.005646
# 512      oacastillol  template    0.095745
# 531       ncampuzano  template    0.063158
# 549         adriel62  template    0.007818
# 566         capinzor  template    0.029919
# 582         ofnanezn  template    0.047904
# 597        macuestap  template    0.072000
# 611           spenas  template    0.037037
# 624      kgbayala528  template    0.141414
# 636       lgmoralesa  template    0.138554
# 647       ronaldsg20  template    0.001533
# 657    cccristanchoc  template    0.109195
# 666       jmalvarezd  template    0.171233
# 674        smarquezo  template    0.045455
# 681          sarizag  template    0.088235
# 687         Chranium  template    0.025000
# 692          DavidQP  template    0.065789
# 696      afceballosr  template    0.132353
# 699        lizzyt10h  template    0.104294
# 701       NicolasPrr  template    0.056865
# 702    jumcorredorro  template    0.145299

# %% [markdown]
# ## Phase 5 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group0 = overall_phase5_group0[overall_phase5_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group0["functions"], overall_phase5_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group0 = pd.DataFrame(result)
phase5_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.017886
# 1       fffeelipe    jmcuestasb    0.006799
# 2       fffeelipe    katherinsb    0.010788
# 3       fffeelipe  jjrodriguezn    0.036232
# 4       fffeelipe         DglyP    0.015021
# ..            ...           ...         ...
# 401  lfvalderrama        gabi04    0.119048
# 402  lfvalderrama      template    0.097561
# 403     bsgarciac        gabi04    0.118919
# 404     bsgarciac      template    0.188406
# 405        gabi04      template    0.119318
#
# [406 rows x 3 columns]

# %%
phase5_group0 = phase5_group0.loc[phase5_group0['user2'] == 'template']
phase5_group0
# Out:
#               user1     user2  similarity
# 27        fffeelipe  template    0.079812
# 54        mnguzmanc  template    0.030071
# 80       jmcuestasb  template    0.006326
# 105      katherinsb  template    0.018379
# 129    jjrodriguezn  template    0.192000
# 152           DglyP  template    0.027056
# 174     Judgarciani  template    0.309917
# 195       sacastroc  template    0.126437
# 215       pcberriop  template    0.131148
# 234     hsmartineza  template    0.188312
# 252        Moimolcp  template    0.069149
# 269     CamiloRueda  template    0.018634
# 285      JoseMolano  template    0.338710
# 300   maikellPardoA  template    0.025210
# 314      NicolasZon  template    0.056911
# 327       camilo654  template    0.064748
# 339  CristianLozano  template    0.024590
# 350       jdsuarezj  template    0.202614
# 360       pipemax85  template    0.188525
# 369     juandavidro  template    0.099174
# 377  UNhcrodriguezl  template    0.303797
# 384     camilo13152  template    0.305732
# 390    leavendanoro  template    0.058442
# 395      cdcordobaa  template    0.063830
# 399      capinillab  template    0.165468
# 402    lfvalderrama  template    0.097561
# 404       bsgarciac  template    0.188406
# 405          gabi04  template    0.119318

# %% [markdown]
# ## Phase 5 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group1 = overall_phase5_group1[overall_phase5_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group1["functions"], overall_phase5_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group1 = pd.DataFrame(result)
phase5_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.050000
# 1         gasierram     bdcajicam    0.523810
# 2         gasierram   dfhincapiem    0.066667
# 3         gasierram     helmeraac    0.119048
# 4         gasierram    dasalgadob    0.114754
# ..              ...           ...         ...
# 625        jcrubioa  JairVillalba    0.091160
# 626        jcrubioa      template    0.336283
# 627  joahernandezca  JairVillalba    0.139241
# 628  joahernandezca      template    0.983333
# 629    JairVillalba      template    0.141026
#
# [630 rows x 3 columns]

# %%
phase5_group1 = phase5_group1.loc[phase5_group1['user2'] == 'template']
phase5_group1
# Out:
#               user1     user2  similarity
# 34        gasierram  template    0.447154
# 68     adamantwharf  template    0.025424
# 101       bdcajicam  template    0.272727
# 133     dfhincapiem  template    0.025210
# 164       helmeraac  template    0.062937
# 194      dasalgadob  template    0.067797
# 223      falperezgo  template    0.016923
# 251       djguzmanc  template    0.151899
# 278      gsuarezc04  template    0.081633
# 304          oeroaq  template    0.025416
# 329     Semoralesga  template    0.094488
# 353      jonatan360  template    0.134199
# 376  jesusfchavarro  template    0.002746
# 398    stevenbustos  template    0.087591
# 419  jufcontrerasco  template    0.258278
# 439      dsbarrerag  template    0.068571
# 458       wolfstain  template    0.101911
# 476      miaborjaac  template    0.101852
# 493   ivdgonzalezco  template    0.050000
# 509    Christian7sr  template    0.028777
# 524      jsnarvaezb  template    0.248322
# 538   gfalbarracinr  template    0.061644
# 551        aldiazve  template    0.002101
# 563  diegoaguevarar  template    0.585034
# 574      fevargasmo  template    0.129032
# 584      jmhurtadoc  template    0.813793
# 593     anfmorenoso  template    0.135294
# 601     nabautistal  template    0.341270
# 608          crigar  template    0.033898
# 614     jiapulidoar  template    0.000783
# 619       jsviveroj  template    0.185430
# 623      daandradec  template    0.099723
# 626        jcrubioa  template    0.336283
# 628  joahernandezca  template    0.983333
# 629    JairVillalba  template    0.141026

# %% [markdown]
# ## Phase 5 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group2 = overall_phase5_group2[overall_phase5_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group2["functions"], overall_phase5_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group2 = pd.DataFrame(result)
phase5_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003471
# 1    jusherrerama       Phoenixest    0.001489
# 2    jusherrerama         HashNick    0.006799
# 3    jusherrerama          ccvacad    0.005268
# 4    jusherrerama  juasmartinezbel    0.016107
# ..            ...              ...         ...
# 698      lsfinite     jscontrerasp    0.003074
# 699      lsfinite         template    0.008005
# 700     xdanielsb     jscontrerasp    0.021882
# 701     xdanielsb         template    0.046904
# 702  jscontrerasp         template    0.058394
#
# [703 rows x 3 columns]

# %%
phase5_group2 = phase5_group2.loc[phase5_group2['user2'] == 'template']
phase5_group2
# Out:
#                user1     user2  similarity
# 36      jusherrerama  template    0.016691
# 72           bdvegat  template    0.066667
# 107       Phoenixest  template    0.025210
# 141         HashNick  template    0.500000
# 174          ccvacad  template    0.153409
# 206  juasmartinezbel  template    0.374449
# 237         mdbelloc  template    0.425000
# 267      diegocruz10  template    0.105634
# 296           sagilm  template    0.294118
# 324         idrojasf  template    0.027108
# 351     raulramirezp  template    0.102778
# 377        fabianr23  template    0.098039
# 402       jhriverasa  template    0.057895
# 426       jhonsd1996  template    0.025000
# 449       JuanitoAli  template    0.017265
# 471       Davsatu313  template    0.190184
# 492   cesarochoa2006  template    0.158301
# 512        jjmuesesq  template    0.043478
# 531     jucjimenezmo  template    0.318841
# 549           kancas  template    0.186567
# 566          Gantiva  template    0.090909
# 582       Dandarprox  template    0.107280
# 597       debeltranc  template    0.000000
# 611        ykchautai  template    0.081081
# 624        ligibrial  template    0.014092
# 636       davidrh195  template    0.022222
# 647      JulianaNino  template    0.060150
# 657         luegilca  template    0.127820
# 666           Yelis3  template    0.006060
# 674        begarzonf  template    0.056530
# 681       kmendezp96  template    0.030303
# 687         leguzman  template    0.295699
# 692     luealfonsoru  template    0.364865
# 696         oserasoa  template    0.248175
# 699         lsfinite  template    0.008005
# 701        xdanielsb  template    0.046904
# 702     jscontrerasp  template    0.058394

# %% [markdown]
# ## Phase 5 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group3 = overall_phase5_group3[overall_phase5_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group3["functions"], overall_phase5_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group3 = pd.DataFrame(result)
phase5_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.006071
# 1        lemartinp      nfmorenog    0.151515
# 2        lemartinp      AFelipeGA    0.007299
# 3        lemartinp     mballeng91    0.000213
# 4        lemartinp       dduartec    0.007151
# ..             ...            ...         ...
# 736      lizzyt10h  jumcorredorro    0.072727
# 737      lizzyt10h       template    0.105263
# 738     NicolasPrr  jumcorredorro    0.109848
# 739     NicolasPrr       template    0.108108
# 740  jumcorredorro       template    0.136546
#
# [741 rows x 3 columns]

# %%
phase5_group3 = phase5_group3.loc[phase5_group3['user2'] == 'template']
phase5_group3
# Out:
#                user1     user2  similarity
# 37         lemartinp  template    0.117188
# 74         juligarji  template    0.015572
# 110        nfmorenog  template    0.111842
# 145        AFelipeGA  template    0.015547
# 179       mballeng91  template    0.000689
# 212         dduartec  template    0.027229
# 244        srmedinac  template    0.054878
# 275     wilson911013  template    0.013100
# 305    wapiravaguens  template    0.095506
# 334         davidh17  template    0.164773
# 362   DianaNavarrete  template    0.024793
# 389        jdmonroyg  template    0.065041
# 415        jorge52an  template    0.115282
# 440  jscastelblancoh  template    0.096296
# 464       juclopezso  template    0.088235
# 487        afforeroc  template    0.042017
# 509      dagofonseca  template    0.094395
# 530      lacardenasv  template    0.005744
# 550      oacastillol  template    0.087302
# 569       ncampuzano  template    0.336788
# 587         adriel62  template    0.126582
# 604         capinzor  template    0.024698
# 620         ofnanezn  template    0.047904
# 635        macuestap  template    0.072000
# 649           spenas  template    0.037037
# 662      kgbayala528  template    0.141414
# 674       lgmoralesa  template    0.136095
# 685       ronaldsg20  template    0.001505
# 695    cccristanchoc  template    0.119792
# 704       jmalvarezd  template    0.172414
# 712        smarquezo  template    0.125786
# 719          sarizag  template    0.129496
# 725         Chranium  template    0.025000
# 730          DavidQP  template    0.080745
# 734      afceballosr  template    0.132353
# 737        lizzyt10h  template    0.105263
# 739       NicolasPrr  template    0.108108
# 740    jumcorredorro  template    0.136546

# %% [markdown]
# ## Distribution Plot for Phase 1

# %%
phase1_group0['group'] = 0
phase1_group1['group'] = 1
phase1_group2['group'] = 2
phase1_group3['group'] = 3
phase1 = pd.concat([phase1_group0, phase1_group1, phase1_group2, phase1_group3], ignore_index=True)
phase1['similarity'].hist(by=phase1['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/2015457414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/2015457414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/2015457414.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/2015457414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 2

# %%
phase2_group0['group'] = 0
phase2_group1['group'] = 1
phase2_group2['group'] = 2
phase2_group3['group'] = 3
phase2 = pd.concat([phase2_group0, phase2_group1, phase2_group2, phase2_group3], ignore_index=True)
phase2['similarity'].hist(by=phase2['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/124240429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/124240429.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/124240429.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/124240429.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 3

# %%
phase3_group0['group'] = 0
phase3_group1['group'] = 1
phase3_group2['group'] = 2
phase3_group3['group'] = 3
phase3 = pd.concat([phase3_group0, phase3_group1, phase3_group2, phase3_group3], ignore_index=True)
phase3['similarity'].hist(by=phase3['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4250399680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4250399680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4250399680.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4250399680.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 4

# %%
phase4_group0['group'] = 0
phase4_group1['group'] = 1
phase4_group2['group'] = 2
phase4_group3['group'] = 3
phase4 = pd.concat([phase4_group0, phase4_group1, phase4_group2, phase4_group3], ignore_index=True)
phase4['similarity'].hist(by=phase4['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4284504232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4284504232.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4284504232.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4284504232.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 5

# %%
phase5_group0['group'] = 0
phase5_group1['group'] = 1
phase5_group2['group'] = 2
phase5_group3['group'] = 3
phase5 = pd.concat([phase5_group0, phase5_group1, phase5_group2, phase5_group3], ignore_index=True)
phase5['similarity'].hist(by=phase5['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4080999950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4080999950.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4080999950.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_5022/4080999950.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %%
median_log_bogota3 = []
median_log_bogota2 = []
median_log_bogota1 = []
median_log_bogota0 = []

mean_log_bogota3 = []
mean_log_bogota2 = []
mean_log_bogota1 = []
mean_log_bogota0 = []

max_log_bogota3 = []
max_log_bogota2 = []
max_log_bogota1 = []
max_log_bogota0 = []

min_log_bogota3 = []
min_log_bogota2 = []
min_log_bogota1 = []
min_log_bogota0 = []

for df in [phase1_group3, phase2_group3, phase3_group3, phase4_group3, phase5_group3]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    max_value = (np.log(df['similarity']+1)).max()
    max_log_bogota3.append(max_value)
    median_log_bogota3.append(median_value)
    mean_log_bogota3.append(mean_value)
    plt.figure()
    plt.title("Template Similarity Plot Bogota 3")
    sns.distplot((np.log(df['similarity']+1)))

for df in [phase1_group2, phase2_group2, phase3_group2, phase4_group2, phase5_group2]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    max_value = (np.log(df['similarity']+1)).max()
    max_log_bogota2.append(max_value)
    median_log_bogota2.append(median_value)
    mean_log_bogota2.append(mean_value)
    plt.figure()
    plt.title("Template Similarity Plot Bogota 2")
    sns.distplot((np.log(df['similarity']+1)))
    
for df in [phase1_group1, phase2_group1, phase3_group1, phase4_group1, phase5_group1]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    max_value = (np.log(df['similarity']+1)).max()
    max_log_bogota1.append(max_value)
    median_log_bogota1.append(median_value)
    mean_log_bogota1.append(mean_value)
    plt.figure()
    plt.title("Template Similarity Plot Bogota 1")
    sns.distplot((np.log(df['similarity']+1)))

for df in [phase1_group0, phase2_group0, phase3_group0, phase4_group0, phase5_group0]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    max_value = (np.log(df['similarity']+1)).max()
    max_log_bogota0.append(max_value)
    median_log_bogota0.append(median_value)
    mean_log_bogota0.append(mean_value)
    plt.figure()
    plt.title("Template Similarity Plot Bogota 0")
    sns.distplot((np.log(df['similarity']+1)))
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# > Interpretation: Majority of the plots look to be positively skewed, but there are a few plots that are normal.

# %%
import matplotlib.pyplot as plt

y1 = median_log_bogota0
y2 = median_log_bogota1
y3 = median_log_bogota2
y4 = median_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Median Template Similarity")
plt.ylabel("Log-Transform Median Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

y1 = mean_log_bogota0
y2 = mean_log_bogota1
y3 = mean_log_bogota2
y4 = mean_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Mean Template Similarity")
plt.ylabel("Log-Transform Mean Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

y1 = max_log_bogota0
y2 = max_log_bogota1
y3 = max_log_bogota2
y4 = max_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Max Template Similarity")
plt.ylabel("Log-Transform Max Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

y1 = min_log_bogota0
y2 = min_log_bogota1
y3 = min_log_bogota2
y4 = min_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Max Template Similarity")
plt.ylabel("Log-Transform Max Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)
