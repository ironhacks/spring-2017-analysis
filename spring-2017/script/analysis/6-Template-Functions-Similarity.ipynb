# %%
# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5
# %store -r df_all
# %store -r overall_loc_scores_final
# %store -r overall_loc_scores
# %store -r template_functions

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../../../Library/CloudStorage/Box-Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/processed-data/bogota-functions-output/spring2017-tutorial-template/2017-Purdue-UNAL-IronHack-tutorial.txt', sep=" ", header=None)
template_functions = df[0].tolist()
template_functions
# Out:
# ['bootstrap.min.css',
#  'theme.min.css',
#  'jquery.min.js',
#  'bootstrap.min.js',
#  'tutorial.css',
#  '.js',
#  'js.org',
#  '.v',
#  '.min.js',
#  'RadarChart.js',
#  'tutorial.js',
#  'script.js',
#  'String.prototype.capitalizeFirstLetter',
#  'this.charAt',
#  '.toUpperCase',
#  'this.slice',
#  'google.maps.Map',
#  'document.getElementById',
#  'google.maps.InfoWindow',
#  'data.cityofchicago.org',
#  'rows.json',
#  'xmlhttp.open',
#  'xmlhttp.send',
#  'xmlhttp.onreadystatechange',
#  'xmlhttp.readyState',
#  'xmlhttp.status',
#  'xmlhttp.responseText',
#  'JSON.parse',
#  'json.data',
#  '.innerHTML',
#  'dataLine.push',
#  'washedData.push',
#  'washedData.length',
#  'google.maps.event.addListener',
#  'google.maps.ElevationService',
#  '.each',
#  'value.setMap',
#  'map.getBounds',
#  'boundBox.getSouthWest',
#  'boundBox.getNorthEast',
#  'northEast.lng',
#  'southWest.lng',
#  'northEast.lat',
#  'southWest.lat',
#  'google.maps.LatLng',
#  'Math.random',
#  'locations.push',
#  'elevator.getElevationForLocations',
#  'google.maps.ElevationStatus.OK',
#  'google.maps.Marker',
#  'key.toString',
#  '.slice',
#  'infowindow.close',
#  'infowindow.setContent',
#  'infowindow.open',
#  '.capitalizeFirstLetter',
#  'RadarChart.draw',
#  'arr.length',
#  '.url',
#  '.display',
#  'str.indexOf',
#  'd.getDay',
#  'api.openweathermap.org',
#  '.coord.lon',
#  'json.weather',
#  '.main',
#  '.select',
#  '.selectAll',
#  '.append',
#  '.attr',
#  'cfg.w',
#  'cfg.h',
#  '.scale.category',
#  'svg.append',
#  '.text',
#  'title.selectAll',
#  '.data',
#  '.enter',
#  '.style',
#  '.resize',
#  '.height',
#  '.css',
#  'Math.PI',
#  'cfg.maxValue',
#  'Math.max',
#  '.max',
#  'i.map',
#  'o.value',
#  '.map',
#  'i.axis',
#  'allAxis.length',
#  'cfg.factor',
#  'Math.min',
#  '.format',
#  '.remove',
#  'cfg.ExtraWidthX',
#  'cfg.ExtraWidthY',
#  'cfg.TranslateX',
#  'cfg.TranslateY',
#  'cfg.levels',
#  'g.selectAll',
#  '.levels',
#  'Math.sin',
#  'cfg.radians',
#  'Math.cos',
#  'cfg.ToRight',
#  '.axis',
#  'axis.append',
#  'cfg.factortitle',
#  'd.forEach',
#  '.nodes',
#  'dataValues.push',
#  'j.value',
#  '.area',
#  'cfg.color',
#  'd.length',
#  'cfg.opacityArea',
#  '.on',
#  '.transition',
#  'cfg.radius',
#  'j.axis',
#  'd.value',
#  'g.append']

# %%
overall_phase1 = overall_phase1.loc[(overall_phase1['len_unique'] != 0 )]
overall_phase1 = overall_phase1.dropna()
overall_phase1
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 5            DglyP    0.0                     20.0           25.00
# 8      Judgarciani    0.0                    100.0           58.33
# 9        sacastroc    0.0                     20.0           50.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 5             50.00        195.00        100.0         87.5
# 8             66.67        325.00        100.0         75.0
# 9             68.75        226.25         87.5         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  delete-loc-45  \
# 0                       20.0           29.17  ...          168.0
# 1                       20.0           37.50  ...          136.0
# 5                        0.0           25.00  ...           56.0
# 8                       80.0           87.50  ...           45.0
# 9                       20.0           50.00  ...           11.0
# ..                       ...             ...  ...            ...
# 155                     80.0           66.67  ...           17.0
# 156                     40.0           50.00  ...           11.0
# 157                      0.0           29.17  ...           66.0
# 158                      0.0           33.33  ...            4.0
# 159                     80.0           58.33  ...            2.0
#
#      change-files-45  add-loc-25  delete-loc-25  change-files-25  add-loc-sum  \
# 0                6.0         0.0            0.0              0.0        165.0
# 1                2.0        51.0          144.0              2.0        183.0
# 5                2.0         0.0            0.0              0.0        100.0
# 8                2.0        13.0           24.0              3.0        188.0
# 9                1.0         3.0            5.0              7.0         51.0
# ..               ...         ...            ...              ...          ...
# 155              2.0        28.0           44.0              2.0        204.0
# 156              2.0         0.0            0.0              0.0        109.0
# 157              2.0        17.0           18.0              6.0         73.0
# 158              4.0        41.0           49.0              5.0        108.0
# 159              1.0        29.0           35.0              1.0         32.0
#
#                                              functions  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...
# 1    [style.css, map.js, document.getElementById, g...
# 5             [bootstrap.min.css, style.css, .JS, .js]
# 8    [jquery.min.js, .js, Rent.js, Crimes.js, googl...
# 9    [js.org, .v, .min.js, bootstrap.min.css, theme...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, jquery.min.js, ...
# 157  [bootstrap.min.css, theme.min.css, jquery.min....
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [script.js, jquery.min.js, bootstrap.min.js, t...
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        21.0
# 1    [style.css, map.js, document.getElementById, g...         5.0
# 5             [bootstrap.min.css, style.css, .JS, .js]         4.0
# 8    [jquery.min.js, .js, Rent.js, Crimes.js, googl...        40.0
# 9    [js.org, .v, .min.js, bootstrap.min.css, theme...         7.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        20.0
# 156  [bootstrap.min.css, style.css, jquery.min.js, ...        27.0
# 157  [bootstrap.min.css, theme.min.css, jquery.min....       122.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...        20.0
# 159  [script.js, jquery.min.js, bootstrap.min.js, t...        33.0
#
#      len_functions
# 0             21.0
# 1              5.0
# 5              4.0
# 8             40.0
# 9              7.0
# ..             ...
# 155           20.0
# 156           27.0
# 157          122.0
# 158           20.0
# 159           33.0
#
# [127 rows x 84 columns]

# %%
overall_phase2 = overall_phase2.loc[(overall_phase2['len_unique'] != 0 )]
overall_phase2 = overall_phase2.dropna()
overall_phase2
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 4     jjrodriguezn    0.0                     60.0           58.33
# 5            DglyP    0.0                     20.0           25.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 4             87.50        255.83         50.0         37.5
# 5             50.00        195.00        100.0         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  delete-loc-45  \
# 0                       20.0           29.17  ...          168.0
# 1                       20.0           37.50  ...          136.0
# 2                      100.0           58.33  ...           26.0
# 4                       40.0           54.17  ...            7.0
# 5                        0.0           25.00  ...           56.0
# ..                       ...             ...  ...            ...
# 155                     80.0           66.67  ...           17.0
# 156                     40.0           50.00  ...           11.0
# 157                      0.0           29.17  ...           66.0
# 158                      0.0           33.33  ...            4.0
# 159                     80.0           58.33  ...            2.0
#
#      change-files-45  add-loc-25  delete-loc-25  change-files-25  add-loc-sum  \
# 0                6.0         0.0            0.0              0.0        165.0
# 1                2.0        51.0          144.0              2.0        183.0
# 2                1.0         5.0           34.0              1.0         31.0
# 4                4.0        59.0           49.0              5.0        232.0
# 5                2.0         0.0            0.0              0.0        100.0
# ..               ...         ...            ...              ...          ...
# 155              2.0        28.0           44.0              2.0        204.0
# 156              2.0         0.0            0.0              0.0        109.0
# 157              2.0        17.0           18.0              6.0         73.0
# 158              4.0        41.0           49.0              5.0        108.0
# 159              1.0        29.0           35.0              1.0         32.0
#
#                                              functions  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...
# 1    [house.ico, style.css, map.js, Chicago.jpg, do...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...
# 5    [google.maps.Map, document.getElementById, goo...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, farmermarket.st...
# 157  [.js, jsInitMap.js, document.getElementById, g...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [script.js, jquery.min.js, bootstrap.min.js, t...
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        30.0
# 1    [house.ico, style.css, map.js, Chicago.jpg, do...        25.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      7051.0
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...        19.0
# 5    [google.maps.Map, document.getElementById, goo...        24.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        31.0
# 156  [bootstrap.min.css, style.css, farmermarket.st...        40.0
# 157  [.js, jsInitMap.js, document.getElementById, g...        13.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...        20.0
# 159  [script.js, jquery.min.js, bootstrap.min.js, t...        39.0
#
#      len_functions
# 0             30.0
# 1             25.0
# 2           7051.0
# 4             19.0
# 5             24.0
# ..             ...
# 155           31.0
# 156           40.0
# 157           13.0
# 158           20.0
# 159           39.0
#
# [136 rows x 84 columns]

# %%
overall_phase3 = overall_phase3.loc[(overall_phase3['len_unique'] != 0 )]
overall_phase3 = overall_phase3.dropna()
overall_phase3
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 4     jjrodriguezn    0.0                     60.0           58.33
# 5            DglyP    0.0                     20.0           25.00
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 4             87.50        255.83         50.0         37.5
# 5             50.00        195.00        100.0         87.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  delete-loc-45  \
# 0                       20.0           29.17  ...          168.0
# 1                       20.0           37.50  ...          136.0
# 2                      100.0           58.33  ...           26.0
# 4                       40.0           54.17  ...            7.0
# 5                        0.0           25.00  ...           56.0
# ..                       ...             ...  ...            ...
# 155                     80.0           66.67  ...           17.0
# 156                     40.0           50.00  ...           11.0
# 157                      0.0           29.17  ...           66.0
# 158                      0.0           33.33  ...            4.0
# 159                     80.0           58.33  ...            2.0
#
#      change-files-45  add-loc-25  delete-loc-25  change-files-25  add-loc-sum  \
# 0                6.0         0.0            0.0              0.0        165.0
# 1                2.0        51.0          144.0              2.0        183.0
# 2                1.0         5.0           34.0              1.0         31.0
# 4                4.0        59.0           49.0              5.0        232.0
# 5                2.0         0.0            0.0              0.0        100.0
# ..               ...         ...            ...              ...          ...
# 155              2.0        28.0           44.0              2.0        204.0
# 156              2.0         0.0            0.0              0.0        109.0
# 157              2.0        17.0           18.0              6.0         73.0
# 158              4.0        41.0           49.0              5.0        108.0
# 159              1.0        29.0           35.0              1.0         32.0
#
#                                              functions  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...
# 1    [house.ico, style.css, .css, main.js, map.js, ...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 4    [google.maps.Map, document.getElementById, goo...
# 5    [google.maps.Map, document.getElementById, goo...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, farmermarket.st...
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.js, tutorial.css...
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        30.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2273.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      7051.0
# 4    [google.maps.Map, document.getElementById, goo...        27.0
# 5    [google.maps.Map, document.getElementById, goo...        24.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        40.0
# 156  [bootstrap.min.css, style.css, farmermarket.st...        44.0
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...        17.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...        20.0
# 159  [jquery.min.js, bootstrap.min.js, tutorial.css...        95.0
#
#      len_functions
# 0             30.0
# 1           2273.0
# 2           7051.0
# 4             27.0
# 5             24.0
# ..             ...
# 155           40.0
# 156           44.0
# 157           17.0
# 158           20.0
# 159           95.0
#
# [136 rows x 84 columns]

# %%
overall_phase4 = overall_phase4.loc[(overall_phase4['len_unique'] != 0 )]
overall_phase4 = overall_phase4.dropna()
overall_phase4
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 3       katherinsb    0.0                     20.0           37.50
# 4     jjrodriguezn    0.0                     60.0           58.33
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  delete-loc-45  \
# 0                       20.0           29.17  ...          168.0
# 1                       20.0           37.50  ...          136.0
# 2                      100.0           58.33  ...           26.0
# 3                       20.0           45.83  ...          371.0
# 4                       40.0           54.17  ...            7.0
# ..                       ...             ...  ...            ...
# 155                     80.0           66.67  ...           17.0
# 156                     40.0           50.00  ...           11.0
# 157                      0.0           29.17  ...           66.0
# 158                      0.0           33.33  ...            4.0
# 159                     80.0           58.33  ...            2.0
#
#      change-files-45  add-loc-25  delete-loc-25  change-files-25  add-loc-sum  \
# 0                6.0         0.0            0.0              0.0        165.0
# 1                2.0        51.0          144.0              2.0        183.0
# 2                1.0         5.0           34.0              1.0         31.0
# 3                3.0         0.0            0.0              6.0        259.0
# 4                4.0        59.0           49.0              5.0        232.0
# ..               ...         ...            ...              ...          ...
# 155              2.0        28.0           44.0              2.0        204.0
# 156              2.0         0.0            0.0              0.0        109.0
# 157              2.0        17.0           18.0              6.0         73.0
# 158              4.0        41.0           49.0              5.0        108.0
# 159              1.0        29.0           35.0              1.0         32.0
#
#                                              functions  \
# 0    [.ready, .click, .removeClass, .is, .val, .che...
# 1    [house.ico, style.css, .css, main.js, map.js, ...
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3    [reset.css, layout.css, style.css, .js, yui.js...
# 4    [google.maps.Map, document.getElementById, goo...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.js, .js, script....
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .removeClass, .is, .val, .che...       106.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2290.0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...      7051.0
# 3    [reset.css, layout.css, style.css, .js, yui.js...        21.0
# 4    [google.maps.Map, document.getElementById, goo...        28.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        44.0
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...        39.0
# 157  [bootstrap.min.css, jquery.min.js, index.css, ...        66.0
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...       678.0
# 159  [jquery.min.js, bootstrap.min.js, .js, script....       166.0
#
#      len_functions
# 0            106.0
# 1           2290.0
# 2           7051.0
# 3             21.0
# 4             28.0
# ..             ...
# 155           44.0
# 156           39.0
# 157           66.0
# 158          678.0
# 159          166.0
#
# [138 rows x 84 columns]

# %%
overall_phase5 = overall_phase5.loc[(overall_phase5['len_unique'] != 0 )]
overall_phase5 = overall_phase5.dropna()
overall_phase5
# Out:
#            Student  Group  user-requirement-phase5  infovis-phase5  \
# 0        fffeelipe    0.0                     20.0           29.17
# 1        mnguzmanc    0.0                     60.0           75.00
# 2       jmcuestasb    0.0                    100.0           54.17
# 3       katherinsb    0.0                     20.0           37.50
# 4     jjrodriguezn    0.0                     60.0           58.33
# ..             ...    ...                      ...             ...
# 155        DavidQP    3.0                     80.0           70.83
# 156    afceballosr    3.0                     80.0           45.83
# 157      lizzyt10h    3.0                     20.0           54.17
# 158     NicolasPrr    3.0                    100.0           83.33
# 159  jumcorredorro    3.0                    100.0           62.50
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           83.33        284.17         50.0         50.0
# 156           57.50        270.83         87.5         87.5
# 157           81.25        255.42        100.0        100.0
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  delete-loc-45  \
# 0                       20.0           29.17  ...          168.0
# 1                       20.0           37.50  ...          136.0
# 2                      100.0           58.33  ...           26.0
# 3                       20.0           45.83  ...          371.0
# 4                       40.0           54.17  ...            7.0
# ..                       ...             ...  ...            ...
# 155                     80.0           66.67  ...           17.0
# 156                     40.0           50.00  ...           11.0
# 157                      0.0           29.17  ...           66.0
# 158                      0.0           33.33  ...            4.0
# 159                     80.0           58.33  ...            2.0
#
#      change-files-45  add-loc-25  delete-loc-25  change-files-25  add-loc-sum  \
# 0                6.0         0.0            0.0              0.0        165.0
# 1                2.0        51.0          144.0              2.0        183.0
# 2                1.0         5.0           34.0              1.0         31.0
# 3                3.0         0.0            0.0              6.0        259.0
# 4                4.0        59.0           49.0              5.0        232.0
# ..               ...         ...            ...              ...          ...
# 155              2.0        28.0           44.0              2.0        204.0
# 156              2.0         0.0            0.0              0.0        109.0
# 157              2.0        17.0           18.0              6.0         73.0
# 158              4.0        41.0           49.0              5.0        108.0
# 159              1.0        29.0           35.0              1.0         32.0
#
#                                              functions  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...
# 1    [house.ico, style.css, .css, main.js, map.js, ...
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...
# 3    [reset.css, layout.css, style.css, jquery.min....
# 4    [google.maps.Map, document.getElementById, goo...
# ..                                                 ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 157  [bootstrap.min.css, jquery.min.js, .min.css, t...
# 158  [jquery.min.js, bootstrap.min.css, stylesLogin...
# 159  [jquery.min.js, bootstrap.min.js, .js, script....
#
#                                                 unique  len_unique  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...       116.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2297.0
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...      7051.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2290.0
# 4    [google.maps.Map, document.getElementById, goo...        31.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, Respond.js, shiv.min.js, r...        57.0
# 156  [bootstrap.min.css, style.css, bulk.jpg, jquer...        42.0
# 157  [bootstrap.min.css, jquery.min.js, .min.css, t...        75.0
# 158  [jquery.min.js, bootstrap.min.css, stylesLogin...       133.0
# 159  [jquery.min.js, bootstrap.min.js, .js, script....       181.0
#
#      len_functions
# 0            116.0
# 1           2297.0
# 2           7051.0
# 3           2290.0
# 4             31.0
# ..             ...
# 155           57.0
# 156           42.0
# 157           75.0
# 158          133.0
# 159          181.0
#
# [138 rows x 84 columns]

# %%
overall_phase1_group0 = overall_phase1.loc[overall_phase1['Group'] == 0]
overall_phase1_group1 = overall_phase1.loc[overall_phase1['Group'] == 1]
overall_phase1_group2 = overall_phase1.loc[overall_phase1['Group'] == 2]
overall_phase1_group3 = overall_phase1.loc[overall_phase1['Group'] == 3]

# %%
overall_phase2_group0 = overall_phase2.loc[overall_phase2['Group'] == 0]
overall_phase2_group1 = overall_phase2.loc[overall_phase2['Group'] == 1]
overall_phase2_group2 = overall_phase2.loc[overall_phase2['Group'] == 2]
overall_phase2_group3 = overall_phase2.loc[overall_phase2['Group'] == 3]

# %%
overall_phase3_group0 = overall_phase3.loc[overall_phase3['Group'] == 0]
overall_phase3_group1 = overall_phase3.loc[overall_phase3['Group'] == 1]
overall_phase3_group2 = overall_phase3.loc[overall_phase3['Group'] == 2]
overall_phase3_group3 = overall_phase3.loc[overall_phase3['Group'] == 3]

# %%
overall_phase4_group0 = overall_phase4.loc[overall_phase4['Group'] == 0]
overall_phase4_group1 = overall_phase4.loc[overall_phase4['Group'] == 1]
overall_phase4_group2 = overall_phase4.loc[overall_phase4['Group'] == 2]
overall_phase4_group3 = overall_phase4.loc[overall_phase4['Group'] == 3]

# %%
overall_phase5_group0 = overall_phase5.loc[overall_phase5['Group'] == 0]
overall_phase5_group1 = overall_phase5.loc[overall_phase5['Group'] == 1]
overall_phase5_group2 = overall_phase5.loc[overall_phase5['Group'] == 2]
overall_phase5_group3 = overall_phase5.loc[overall_phase5['Group'] == 3]

# %%
df_template = {'Student': ['template'], 'functions': [template_functions], 'phase': [0]}
df_template = pd.DataFrame(data=df_template)
df_template
# Out:
#     Student                                          functions  phase
# 0  template  [bootstrap.min.css, theme.min.css, jquery.min....      0

# %%
overall_phase1_group0['unique'] = [','.join(map(str, l)) for l in overall_phase1_group0['unique']]
overall_phase1_group1['unique'] = [','.join(map(str, l)) for l in overall_phase1_group1['unique']]
overall_phase1_group2['unique'] = [','.join(map(str, l)) for l in overall_phase1_group2['unique']]
overall_phase1_group3['unique'] = [','.join(map(str, l)) for l in overall_phase1_group3['unique']]

overall_phase2_group0['unique'] = [','.join(map(str, l)) for l in overall_phase2_group0['unique']]
overall_phase2_group1['unique'] = [','.join(map(str, l)) for l in overall_phase2_group1['unique']]
overall_phase2_group2['unique'] = [','.join(map(str, l)) for l in overall_phase2_group2['unique']]
overall_phase2_group3['unique'] = [','.join(map(str, l)) for l in overall_phase2_group3['unique']]

overall_phase3_group0['unique'] = [','.join(map(str, l)) for l in overall_phase3_group0['unique']]
overall_phase3_group1['unique'] = [','.join(map(str, l)) for l in overall_phase3_group1['unique']]
overall_phase3_group2['unique'] = [','.join(map(str, l)) for l in overall_phase3_group2['unique']]
overall_phase3_group3['unique'] = [','.join(map(str, l)) for l in overall_phase3_group3['unique']]

overall_phase4_group0['unique'] = [','.join(map(str, l)) for l in overall_phase4_group0['unique']]
overall_phase4_group1['unique'] = [','.join(map(str, l)) for l in overall_phase4_group1['unique']]
overall_phase4_group2['unique'] = [','.join(map(str, l)) for l in overall_phase4_group2['unique']]
overall_phase4_group3['unique'] = [','.join(map(str, l)) for l in overall_phase4_group3['unique']]

overall_phase5_group0['unique'] = [','.join(map(str, l)) for l in overall_phase5_group0['unique']]
overall_phase5_group1['unique'] = [','.join(map(str, l)) for l in overall_phase5_group1['unique']]
overall_phase5_group2['unique'] = [','.join(map(str, l)) for l in overall_phase5_group2['unique']]
overall_phase5_group3['unique'] = [','.join(map(str, l)) for l in overall_phase5_group3['unique']]
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group0['unique'] = [','.join(map(str, l)) for l in overall_phase1_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group1['unique'] = [','.join(map(str, l)) for l in overall_phase1_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group2['unique'] = [','.join(map(str, l)) for l in overall_phase1_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase1_group3['unique'] = [','.join(map(str, l)) for l in overall_phase1_group3['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group0['unique'] = [','.join(map(str, l)) for l in overall_phase2_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group1['unique'] = [','.join(map(str, l)) for l in overall_phase2_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group2['unique'] = [','.join(map(str, l)) for l in overall_phase2_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase2_group3['unique'] = [','.join(map(str, l)) for l in overall_phase2_group3['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group0['unique'] = [','.join(map(str, l)) for l in overall_phase3_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group1['unique'] = [','.join(map(str, l)) for l in overall_phase3_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group2['unique'] = [','.join(map(str, l)) for l in overall_phase3_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase3_group3['unique'] = [','.join(map(str, l)) for l in overall_phase3_group3['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group0['unique'] = [','.join(map(str, l)) for l in overall_phase4_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group1['unique'] = [','.join(map(str, l)) for l in overall_phase4_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group2['unique'] = [','.join(map(str, l)) for l in overall_phase4_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase4_group3['unique'] = [','.join(map(str, l)) for l in overall_phase4_group3['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group0['unique'] = [','.join(map(str, l)) for l in overall_phase5_group0['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group1['unique'] = [','.join(map(str, l)) for l in overall_phase5_group1['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group2['unique'] = [','.join(map(str, l)) for l in overall_phase5_group2['unique']]
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4231300064.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_phase5_group3['unique'] = [','.join(map(str, l)) for l in overall_phase5_group3['unique']]

# %%
overall_phase1_group0 = overall_phase1_group0.append(df_template, ignore_index=True)
overall_phase1_group1 = overall_phase1_group1.append(df_template, ignore_index=True)
overall_phase1_group2 = overall_phase1_group2.append(df_template, ignore_index=True)
overall_phase1_group3 = overall_phase1_group3.append(df_template, ignore_index=True)

overall_phase2_group0 = overall_phase2_group0.append(df_template, ignore_index=True)
overall_phase2_group1 = overall_phase2_group1.append(df_template, ignore_index=True)
overall_phase2_group2 = overall_phase2_group2.append(df_template, ignore_index=True)
overall_phase2_group3 = overall_phase2_group3.append(df_template, ignore_index=True)

overall_phase3_group0 = overall_phase3_group0.append(df_template, ignore_index=True)
overall_phase3_group1 = overall_phase3_group1.append(df_template, ignore_index=True)
overall_phase3_group2 = overall_phase3_group2.append(df_template, ignore_index=True)
overall_phase3_group3 = overall_phase3_group3.append(df_template, ignore_index=True)

overall_phase4_group0 = overall_phase4_group0.append(df_template, ignore_index=True)
overall_phase4_group1 = overall_phase4_group1.append(df_template, ignore_index=True)
overall_phase4_group2 = overall_phase4_group2.append(df_template, ignore_index=True)
overall_phase4_group3 = overall_phase4_group3.append(df_template, ignore_index=True)

overall_phase5_group0 = overall_phase5_group0.append(df_template, ignore_index=True)
overall_phase5_group1 = overall_phase5_group1.append(df_template, ignore_index=True)
overall_phase5_group2 = overall_phase5_group2.append(df_template, ignore_index=True)
overall_phase5_group3 = overall_phase5_group3.append(df_template, ignore_index=True)

# %%
overall_phase5_group3
# Out:
#             Student  Group  user-requirement-phase5  infovis-phase5  \
# 0         lemartinp    3.0                    100.0           54.17
# 1         juligarji    3.0                    100.0           75.00
# 2         nfmorenog    3.0                      0.0           37.50
# 3         AFelipeGA    3.0                     40.0           37.50
# 4        mballeng91    3.0                      0.0           25.00
# 5          dduartec    3.0                     80.0           83.33
# 6         srmedinac    3.0                     20.0           33.33
# 7      wilson911013    3.0                      0.0           25.00
# 8     wapiravaguens    3.0                     80.0           75.00
# 9          davidh17    3.0                     20.0           45.83
# 10   DianaNavarrete    3.0                     20.0           62.50
# 11        jdmonroyg    3.0                      0.0           25.00
# 12        jorge52an    3.0                    100.0           50.00
# 13  jscastelblancoh    3.0                    100.0           83.33
# 14       juclopezso    3.0                     60.0           50.00
# 15        afforeroc    3.0                     20.0           29.17
# 16      dagofonseca    3.0                     40.0           37.50
# 17      lacardenasv    3.0                    100.0           75.00
# 18      oacastillol    3.0                     60.0           62.50
# 19       ncampuzano    3.0                     20.0           45.83
# 20         adriel62    3.0                     80.0           66.67
# 21         capinzor    3.0                     20.0           25.00
# 22         ofnanezn    3.0                     40.0           58.33
# 23        macuestap    3.0                     40.0           50.00
# 24           spenas    3.0                     20.0           33.33
# 25      kgbayala528    3.0                     80.0           50.00
# 26       lgmoralesa    3.0                    100.0           70.83
# 27       ronaldsg20    3.0                     20.0           45.83
# 28    cccristanchoc    3.0                     20.0           33.33
# 29       jmalvarezd    3.0                     80.0           75.00
# 30        smarquezo    3.0                     20.0           33.33
# 31          sarizag    3.0                     20.0           33.33
# 32         Chranium    3.0                     20.0           25.00
# 33          DavidQP    3.0                     80.0           70.83
# 34      afceballosr    3.0                     80.0           45.83
# 35        lizzyt10h    3.0                     20.0           54.17
# 36       NicolasPrr    3.0                    100.0           83.33
# 37    jumcorredorro    3.0                    100.0           62.50
# 38         template    NaN                      NaN             NaN
#
#     novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0            87.50        329.17         87.5         87.5
# 1            92.50        355.00         87.5        100.0
# 2            15.00        127.50         75.0         75.0
# 3            56.25        221.25         87.5         75.0
# 4            25.00        112.50         62.5         62.5
# 5            95.00        345.83         87.5         87.5
# 6             0.00        128.33         75.0         62.5
# 7             0.00         75.00         50.0         37.5
# 8            72.50        327.50        100.0         62.5
# 9            56.25        209.58         87.5         75.0
# 10           25.00        145.00         37.5         37.5
# 11           25.00         75.00         25.0          0.0
# 12           60.00        310.00        100.0         75.0
# 13          100.00        358.33         75.0         75.0
# 14           81.25        278.75         87.5         62.5
# 15           50.00        161.67         62.5         50.0
# 16           66.67        231.67         87.5         87.5
# 17           75.00        350.00        100.0         87.5
# 18           37.50        235.00         75.0         62.5
# 19           50.00        203.33         87.5         62.5
# 20           67.50        301.67         87.5         87.5
# 21           58.33        203.33        100.0         87.5
# 22           25.00        198.33         75.0         50.0
# 23           25.00        177.50         62.5         62.5
# 24            0.00        115.83         62.5         62.5
# 25           81.25        298.75         87.5         62.5
# 26           87.50        345.83         87.5         87.5
# 27           12.50        178.33        100.0        100.0
# 28           56.25        197.08         87.5         62.5
# 29           93.75        348.75        100.0         87.5
# 30           57.50        185.83         75.0         62.5
# 31           56.25        209.58        100.0         75.0
# 32            0.00         95.00         50.0         50.0
# 33           83.33        284.17         50.0         50.0
# 34           57.50        270.83         87.5         87.5
# 35           81.25        255.42        100.0        100.0
# 36           90.00        360.83         87.5         62.5
# 37           75.00        325.00         87.5         87.5
# 38             NaN           NaN          NaN          NaN
#
#     user-requirement-phase4  infovis-phase4  ...  change-files-45  add-loc-25  \
# 0                      80.0           58.33  ...              1.0        26.0
# 1                     100.0           70.83  ...              1.0       162.0
# 2                       0.0           33.33  ...              0.0         5.0
# 3                      40.0           37.50  ...              0.0         0.0
# 4                       0.0           25.00  ...              0.0         4.0
# 5                       0.0            0.00  ...              1.0        21.0
# 6                      20.0           33.33  ...              0.0         3.0
# 7                      20.0           25.00  ...              0.0         0.0
# 8                      80.0           75.00  ...              2.0        21.0
# 9                       0.0            0.00  ...              5.0        55.0
# 10                     20.0           58.33  ...              0.0         0.0
# 11                      0.0            0.00  ...              4.0         0.0
# 12                     60.0           33.33  ...              1.0        18.0
# 13                    100.0           66.67  ...              2.0        57.0
# 14                     60.0           29.17  ...              1.0        25.0
# 15                     20.0           29.17  ...              0.0        14.0
# 16                     40.0           37.50  ...              6.0        11.0
# 17                     60.0           37.50  ...              2.0        30.0
# 18                      0.0           33.33  ...              1.0         3.0
# 19                     20.0           37.50  ...              2.0       191.0
# 20                     40.0           33.33  ...              4.0        67.0
# 21                     20.0           25.00  ...              4.0        16.0
# 22                     20.0           33.33  ...              0.0        14.0
# 23                     20.0           41.67  ...              0.0         9.0
# 24                     20.0           33.33  ...              0.0         0.0
# 25                     60.0           45.83  ...              0.0         8.0
# 26                    100.0           66.67  ...              2.0        88.0
# 27                     20.0           33.33  ...              2.0        27.0
# 28                     20.0           33.33  ...              2.0         2.0
# 29                     60.0           70.83  ...              2.0        16.0
# 30                     20.0           29.17  ...              1.0        94.0
# 31                     20.0           33.33  ...              3.0        19.0
# 32                     20.0           25.00  ...              0.0         5.0
# 33                     80.0           66.67  ...              2.0        28.0
# 34                     40.0           50.00  ...              2.0         0.0
# 35                      0.0           29.17  ...              2.0        17.0
# 36                      0.0           33.33  ...              4.0        41.0
# 37                     80.0           58.33  ...              1.0        29.0
# 38                      NaN             NaN  ...              NaN         NaN
#
#     delete-loc-25  change-files-25  add-loc-sum  \
# 0           248.0              4.0         37.0
# 1           290.0              4.0        224.0
# 2             6.0              2.0         11.0
# 3             0.0              0.0          0.0
# 4             3.0              4.0          4.0
# 5            23.0              2.0         30.0
# 6             3.0              1.0         51.0
# 7             0.0              2.0          0.0
# 8            33.0              2.0         52.0
# 9            54.0              3.0        598.0
# 10            0.0              9.0          0.0
# 11            0.0              0.0          0.0
# 12           88.0              1.0         34.0
# 13          238.0              2.0        106.0
# 14          300.0              1.0        450.0
# 15          111.0              3.0         10.0
# 16           16.0              1.0         52.0
# 17          108.0              5.0        122.0
# 18           79.0              3.0         23.0
# 19          263.0             15.0        232.0
# 20           41.0              3.0        266.0
# 21           15.0              2.0        313.0
# 22            6.0              2.0         22.0
# 23           13.0              2.0          9.0
# 24            0.0              0.0         83.0
# 25           88.0              2.0         45.0
# 26           89.0              2.0        139.0
# 27           70.0              8.0         60.0
# 28           38.0              5.0         16.0
# 29           34.0              3.0         71.0
# 30          608.0              1.0        125.0
# 31           55.0              3.0        885.0
# 32            5.0              1.0          1.0
# 33           44.0              2.0        204.0
# 34            0.0              0.0        109.0
# 35           18.0              6.0         73.0
# 36           49.0              5.0        108.0
# 37           35.0              1.0         32.0
# 38            NaN              NaN          NaN
#
#                                             functions  \
# 0   [google.maps.Map, document.getElementById, goo...
# 1   [jquery.min.js, bootstrap.min.css, awesome.min...
# 2   [FirstLook.css, bootstrap.min.css, jquery.min....
# 3   [materialize.min.css, style.css, awesome.min.c...
# 4   [.bin, e.g, protractor.config.js, exports.conf...
# 5   [.js, style.css, superplaceholder.js, superpla...
# 6   [.create, package.json, pkg.title, pkg.version...
# 7   [.js, jsInitMap.js, .ajax, module.exports, opt...
# 8   [.css, .js, js.org, .v, bootstrap.min.css, the...
# 9   [bootstrap.min.css, styles.css, jquery.min.js,...
# 10  [.l, morado.jpg, a.active, .active, google.map...
# 11  [.mifecha, bootstrap.min.css, theme.min.css, j...
# 12  [main.css, material.min.css, angular.min.js, a...
# 13  [bootstrap.min.css, theme.min.css, style.css, ...
# 14  [bootstrap.min.css, portfolio.css, awesome.min...
# 15  [bootstrap.min.css, uic.edu, .js, bootstrap.mi...
# 16  [styles.css, jquery.min.js, map.js, markerclus...
# 17  [materialize.css, materialize.min.css, styleSe...
# 18  [bootstrap.min.css, theme.min.css, awesome.min...
# 19  [bootstrap.min.css, awesome.min.css, app.css, ...
# 20  [favicon.ico, .min.js, bootstrap.min.js, appli...
# 21  [bootstrap.min.css, estilos.css, .min.js, boot...
# 22  [.create, package.json, pkg.title, pkg.version...
# 23  [style.css, favicon.ico, bootstrap.min.css, th...
# 24  [bootstrap.min.css, mdb.min.css, demos.css, st...
# 25  [latest.min.js, jquery.min.js, bootstrap.min.c...
# 26  [bootstrap.min.css, index.css, criteria.css, j...
# 27  [ownStyle.css, theme.min.css, bootstrap.min.cs...
# 28  [unal.edu.co, bootstrap.min.css, template.css,...
# 29  [jmalvarezd.js, bootstrap.min.css, jquery.min....
# 30  [bootstrap.min.css, data.json, jquery.min.js, ...
# 31  [js.org, .v, .min.js, style.css, jquery.min.js...
# 32  [style.css, main.js, document.getElementById, ...
# 33  [bootstrap.min.css, Respond.js, shiv.min.js, r...
# 34  [bootstrap.min.css, style.css, bulk.jpg, jquer...
# 35  [bootstrap.min.css, jquery.min.js, .min.css, t...
# 36  [jquery.min.js, bootstrap.min.css, stylesLogin...
# 37  [jquery.min.js, bootstrap.min.js, .js, script....
# 38  [bootstrap.min.css, theme.min.css, jquery.min....
#
#                                                unique  len_unique  \
# 0   google.maps.Map,document.getElementById,google...        26.0
# 1   jquery.min.js,bootstrap.min.css,awesome.min.cs...      2567.0
# 2   FirstLook.css,bootstrap.min.css,jquery.min.js,...        52.0
# 3   materialize.min.css,style.css,awesome.min.css,...      2059.0
# 4   .bin,e.g,protractor.config.js,exports.config,s...     71871.0
# 5   .js,style.css,superplaceholder.js,superplaceho...      2338.0
# 6   .create,package.json,pkg.title,pkg.version,pkg...        56.0
# 7   .js,jsInitMap.js,.ajax,module.exports,options....       362.0
# 8   .css,.js,js.org,.v,bootstrap.min.css,theme.min...        89.0
# 9   bootstrap.min.css,styles.css,jquery.min.js,boo...        88.0
# 10  .l,morado.jpg,a.active,.active,google.maps.Map...         7.0
# 11  .mifecha,bootstrap.min.css,theme.min.css,jquer...        14.0
# 12  main.css,material.min.css,angular.min.js,angul...       318.0
# 13  bootstrap.min.css,theme.min.css,style.css,hove...       181.0
# 14  bootstrap.min.css,portfolio.css,awesome.min.cs...        30.0
# 15  bootstrap.min.css,uic.edu,.js,bootstrap.min.js...         7.0
# 16  styles.css,jquery.min.js,map.js,markerclustere...       271.0
# 17  materialize.css,materialize.min.css,styleSearc...     10885.0
# 18  bootstrap.min.css,theme.min.css,awesome.min.cs...       316.0
# 19  bootstrap.min.css,awesome.min.css,app.css,jque...       146.0
# 20  favicon.ico,.min.js,bootstrap.min.js,applicati...       161.0
# 21  bootstrap.min.css,estilos.css,.min.js,bootstra...      1846.0
# 22  .create,package.json,pkg.title,pkg.version,pkg...        58.0
# 23  style.css,favicon.ico,bootstrap.min.css,theme....        17.0
# 24  bootstrap.min.css,mdb.min.css,demos.css,styles...        22.0
# 25  latest.min.js,jquery.min.js,bootstrap.min.css,...       108.0
# 26  bootstrap.min.css,index.css,criteria.css,jquer...        77.0
# 27  ownStyle.css,theme.min.css,bootstrap.min.css,m...     39470.0
# 28  unal.edu.co,bootstrap.min.css,template.css,dat...       100.0
# 29  jmalvarezd.js,bootstrap.min.css,jquery.min.js,...        53.0
# 30  bootstrap.min.css,data.json,jquery.min.js,boot...        64.0
# 31  js.org,.v,.min.js,style.css,jquery.min.js,scri...        40.0
# 32  style.css,main.js,document.getElementById,goog...         5.0
# 33  bootstrap.min.css,Respond.js,shiv.min.js,respo...        57.0
# 34  bootstrap.min.css,style.css,bulk.jpg,jquery.mi...        42.0
# 35  bootstrap.min.css,jquery.min.js,.min.css,this....        75.0
# 36  jquery.min.js,bootstrap.min.css,stylesLoginf.c...       133.0
# 37  jquery.min.js,bootstrap.min.js,.js,script.js,m...       181.0
# 38                                                NaN         NaN
#
#     len_functions  phase
# 0            26.0    NaN
# 1          2567.0    NaN
# 2            52.0    NaN
# 3          2059.0    NaN
# 4         71871.0    NaN
# 5          2338.0    NaN
# 6            56.0    NaN
# 7           362.0    NaN
# 8            89.0    NaN
# 9            88.0    NaN
# 10            7.0    NaN
# 11           14.0    NaN
# 12          318.0    NaN
# 13          181.0    NaN
# 14           30.0    NaN
# 15            7.0    NaN
# 16          271.0    NaN
# 17        10885.0    NaN
# 18          316.0    NaN
# 19          146.0    NaN
# 20          161.0    NaN
# 21         1846.0    NaN
# 22           58.0    NaN
# 23           17.0    NaN
# 24           22.0    NaN
# 25          108.0    NaN
# 26           77.0    NaN
# 27        39470.0    NaN
# 28          100.0    NaN
# 29           53.0    NaN
# 30           64.0    NaN
# 31           40.0    NaN
# 32            5.0    NaN
# 33           57.0    NaN
# 34           42.0    NaN
# 35           75.0    NaN
# 36          133.0    NaN
# 37          181.0    NaN
# 38            NaN    0.0
#
# [39 rows x 85 columns]

# %% [markdown]
# ## Phase 1 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group0 = overall_phase1_group0[overall_phase1_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group0["functions"], overall_phase1_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group0 = pd.DataFrame(result)
phase1_group0
# Out:
#             user1        user2  similarity
# 0       fffeelipe    mnguzmanc    0.083333
# 1       fffeelipe        DglyP    0.041667
# 2       fffeelipe  Judgarciani    0.051724
# 3       fffeelipe    sacastroc    0.166667
# 4       fffeelipe    pcberriop    0.070175
# ..            ...          ...         ...
# 271    capinillab    bsgarciac    0.121951
# 272    capinillab     template    0.040000
# 273  lfvalderrama    bsgarciac    0.079365
# 274  lfvalderrama     template    0.101449
# 275     bsgarciac     template    0.051948
#
# [276 rows x 3 columns]

# %%
phase1_group0 = phase1_group0.loc[phase1_group0['user2'] == 'template']
phase1_group0
# Out:
#               user1     user2  similarity
# 22        fffeelipe  template    0.051095
# 44        mnguzmanc  template    0.024000
# 65            DglyP  template    0.016000
# 85      Judgarciani  template    0.086667
# 104       sacastroc  template    0.056911
# 122       pcberriop  template    0.304000
# 139     hsmartineza  template    0.149606
# 155        Moimolcp  template    0.072848
# 170      JoseMolano  template    0.024390
# 184   maikellPardoA  template    0.024194
# 197      NicolasZon  template    0.054264
# 209       camilo654  template    0.024194
# 220  CristianLozano  template    0.024390
# 230       jdsuarezj  template    0.060150
# 239       pipemax85  template    0.152000
# 247     juandavidro  template    0.968504
# 254  UNhcrodriguezl  template    0.034965
# 260     camilo13152  template    0.015504
# 265    leavendanoro  template    0.054688
# 269      cdcordobaa  template    0.044444
# 272      capinillab  template    0.040000
# 274    lfvalderrama  template    0.101449
# 275       bsgarciac  template    0.051948

# %% [markdown]
# ## Phase 1 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group1 = overall_phase1_group1[overall_phase1_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group1["functions"], overall_phase1_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group1 = pd.DataFrame(result)
phase1_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.176471
# 1         gasierram     bdcajicam    0.176471
# 2         gasierram     helmeraac    0.150000
# 3         gasierram    dasalgadob    0.444444
# 4         gasierram    falperezgo    0.151515
# ..              ...           ...         ...
# 523        jcrubioa  JairVillalba    0.008902
# 524        jcrubioa      template    0.350000
# 525  joahernandezca  JairVillalba    0.750000
# 526  joahernandezca      template    0.024390
# 527    JairVillalba      template    0.024194
#
# [528 rows x 3 columns]

# %%
phase1_group1 = phase1_group1.loc[phase1_group1['user2'] == 'template']
phase1_group1
# Out:
#               user1     user2  similarity
# 31        gasierram  template    0.093750
# 62     adamantwharf  template    0.024390
# 92        bdcajicam  template    0.024390
# 121       helmeraac  template    0.023810
# 149      dasalgadob  template    0.073171
# 176      falperezgo  template    0.051095
# 202       djguzmanc  template    0.171642
# 227          oeroaq  template    0.096330
# 251         gcantem  template    0.843750
# 274     Semoralesga  template    0.024000
# 296      jonatan360  template    0.136905
# 317  jesusfchavarro  template    0.024540
# 337  jufcontrerasco  template    0.030534
# 356      dsbarrerag  template    0.037879
# 374       wolfstain  template    0.162791
# 391      miaborjaac  template    0.062500
# 407   ivdgonzalezco  template    0.042373
# 422    Christian7sr  template    0.000000
# 436      jsnarvaezb  template    0.123077
# 449   gfalbarracinr  template    0.007752
# 461        aldiazve  template    0.066176
# 472  diegoaguevarar  template    0.890511
# 482      fevargasmo  template    0.031250
# 491      jmhurtadoc  template    0.820000
# 499     nabautistal  template    0.024390
# 506          crigar  template    0.032520
# 512     jiapulidoar  template    0.034722
# 517       jsviveroj  template    0.046875
# 521      daandradec  template    0.044872
# 524        jcrubioa  template    0.350000
# 526  joahernandezca  template    0.024390
# 527    JairVillalba  template    0.024194

# %% [markdown]
# ## Phase 1 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group2 = overall_phase1_group2[overall_phase1_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group2["functions"], overall_phase1_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group2 = pd.DataFrame(result)
phase1_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.176471
# 1    jusherrerama       Phoenixest    0.166667
# 2    jusherrerama         HashNick    0.041667
# 3    jusherrerama  juasmartinezbel    0.038835
# 4    jusherrerama         mdbelloc    0.045455
# ..            ...              ...         ...
# 625      lsfinite     jscontrerasp    0.166667
# 626      lsfinite         template    0.023256
# 627     xdanielsb     jscontrerasp    0.017964
# 628     xdanielsb         template    0.043478
# 629  jscontrerasp         template    0.024000
#
# [630 rows x 3 columns]

# %%
phase1_group2 = phase1_group2.loc[phase1_group2['user2'] == 'template']
phase1_group2
# Out:
#                user1     user2  similarity
# 34      jusherrerama  template    0.029630
# 68           bdvegat  template    0.024194
# 101       Phoenixest  template    0.024000
# 133         HashNick  template    0.479675
# 164  juasmartinezbel  template    0.236994
# 194         mdbelloc  template    0.408000
# 223      diegocruz10  template    0.120301
# 251           sagilm  template    0.024390
# 278         idrojasf  template    0.022792
# 304     raulramirezp  template    0.024194
# 329        fabianr23  template    0.028777
# 353       jhriverasa  template    0.044118
# 376       jhonsd1996  template    0.000000
# 398       JuanitoAli  template    0.051471
# 419       Davsatu313  template    0.045455
# 439   cesarochoa2006  template    0.061538
# 458        jjmuesesq  template    0.024390
# 476           kancas  template    0.148438
# 493          Gantiva  template    0.069767
# 509       Dandarprox  template    0.032258
# 524       debeltranc  template    0.000000
# 538        ykchautai  template    0.007752
# 551        ligibrial  template    0.037594
# 563       davidrh195  template    0.022727
# 574      JulianaNino  template    0.015152
# 584         luegilca  template    0.130435
# 593           Yelis3  template    0.001165
# 601        begarzonf  template    0.097561
# 608       kmendezp96  template    0.275168
# 614         leguzman  template    0.067164
# 619     luealfonsoru  template    0.040268
# 623         oserasoa  template    0.152000
# 626         lsfinite  template    0.023256
# 628        xdanielsb  template    0.043478
# 629     jscontrerasp  template    0.024000

# %% [markdown]
# ## Phase 1 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase1_group3 = overall_phase1_group3[overall_phase1_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase1_group3["functions"], overall_phase1_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase1_group3 = pd.DataFrame(result)
phase1_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.043478
# 1        lemartinp      nfmorenog    0.200000
# 2        lemartinp      AFelipeGA    0.016807
# 3        lemartinp     mballeng91    0.000028
# 4        lemartinp       dduartec    0.038462
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.201550
# 699      lizzyt10h       template    0.991870
# 700     NicolasPrr  jumcorredorro    0.104167
# 701     NicolasPrr       template    0.051471
# 702  jumcorredorro       template    0.209302
#
# [703 rows x 3 columns]

# %%
phase1_group3 = phase1_group3.loc[phase1_group3['user2'] == 'template']
phase1_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.031496
# 72         juligarji  template    0.029630
# 107        nfmorenog  template    0.061069
# 141        AFelipeGA  template    0.026087
# 174       mballeng91  template    0.000570
# 206         dduartec  template    0.118110
# 237        srmedinac  template    0.448000
# 267    wapiravaguens  template    0.114286
# 296         davidh17  template    0.094488
# 324   DianaNavarrete  template    0.015748
# 351        jdmonroyg  template    0.000000
# 377        jorge52an  template    0.030075
# 402  jscastelblancoh  template    0.082090
# 426       juclopezso  template    0.085106
# 449        afforeroc  template    0.048387
# 471      dagofonseca  template    0.125000
# 492      lacardenasv  template    0.083333
# 512      oacastillol  template    0.056000
# 531       ncampuzano  template    0.046512
# 549         adriel62  template    0.055556
# 566         capinzor  template    0.043796
# 582         ofnanezn  template    0.054945
# 597        macuestap  template    0.042553
# 611           spenas  template    0.023256
# 624      kgbayala528  template    0.128866
# 636       lgmoralesa  template    0.049296
# 647       ronaldsg20  template    0.001240
# 657    cccristanchoc  template    0.046667
# 666       jmalvarezd  template    0.099291
# 674        smarquezo  template    0.016260
# 681          sarizag  template    0.052239
# 687         Chranium  template    0.024000
# 692          DavidQP  template    0.028777
# 696      afceballosr  template    0.145038
# 699        lizzyt10h  template    0.991870
# 701       NicolasPrr  template    0.051471
# 702    jumcorredorro  template    0.209302

# %% [markdown]
# ## Phase 2 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group0 = overall_phase2_group0[overall_phase2_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group0["functions"], overall_phase2_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group0 = pd.DataFrame(result)
phase2_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.100000
# 1       fffeelipe    jmcuestasb    0.001839
# 2       fffeelipe  jjrodriguezn    0.195122
# 3       fffeelipe         DglyP    0.255814
# 4       fffeelipe   Judgarciani    0.078431
# ..            ...           ...         ...
# 373  lfvalderrama        gabi04    0.125000
# 374  lfvalderrama      template    0.093960
# 375     bsgarciac        gabi04    0.122222
# 376     bsgarciac      template    0.143750
# 377        gabi04      template    0.071895
#
# [378 rows x 3 columns]

# %%
phase2_group0 = phase2_group0.loc[phase2_group0['user2'] == 'template']
phase2_group0
# Out:
#               user1     user2  similarity
# 26        fffeelipe  template    0.069930
# 52        mnguzmanc  template    0.104478
# 77       jmcuestasb  template    0.005466
# 101    jjrodriguezn  template    0.044118
# 124           DglyP  template    0.080882
# 146     Judgarciani  template    0.140449
# 167       sacastroc  template    0.130137
# 187       pcberriop  template    0.301587
# 206     hsmartineza  template    0.187970
# 224        Moimolcp  template    0.072848
# 241     CamiloRueda  template    0.017964
# 257      JoseMolano  template    0.338583
# 272   maikellPardoA  template    0.024194
# 286      NicolasZon  template    0.054688
# 299       camilo654  template    0.052239
# 311  CristianLozano  template    0.023622
# 322       jdsuarezj  template    0.197080
# 332       pipemax85  template    0.150794
# 341     juandavidro  template    0.968504
# 349  UNhcrodriguezl  template    0.272152
# 356     camilo13152  template    0.030075
# 362    leavendanoro  template    0.050725
# 367      cdcordobaa  template    0.061644
# 371      capinillab  template    0.134921
# 374    lfvalderrama  template    0.093960
# 376       bsgarciac  template    0.143750
# 377          gabi04  template    0.071895

# %% [markdown]
# ## Phase 2 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group1 = overall_phase2_group1[overall_phase2_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group1["functions"], overall_phase2_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group1 = pd.DataFrame(result)
phase2_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.176471
# 1         gasierram     bdcajicam    0.176471
# 2         gasierram   dfhincapiem    0.235294
# 3         gasierram     helmeraac    0.142857
# 4         gasierram    dasalgadob    0.444444
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.054441
# 662        jcrubioa      template    0.340974
# 663  joahernandezca  JairVillalba    0.123077
# 664  joahernandezca      template    1.000000
# 665    JairVillalba      template    0.123077
#
# [666 rows x 3 columns]

# %%
phase2_group1 = phase2_group1.loc[phase2_group1['user2'] == 'template']
phase2_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.093750
# 70     adamantwharf  template    0.024390
# 104       bdcajicam  template    0.024390
# 137     dfhincapiem  template    0.024194
# 169       helmeraac  template    0.037594
# 200      dasalgadob  template    0.073171
# 230      falperezgo  template    0.015226
# 259       djguzmanc  template    0.127517
# 287      gsuarezc04  template    0.071895
# 314          oeroaq  template    0.109312
# 340         gcantem  template    0.843750
# 365     Semoralesga  template    0.013629
# 389      jonatan360  template    0.111111
# 412  jesusfchavarro  template    0.013149
# 434    stevenbustos  template    0.023810
# 455  jufcontrerasco  template    0.030303
# 475      dsbarrerag  template    0.060811
# 494       wolfstain  template    0.173913
# 512      miaborjaac  template    0.064677
# 529   ivdgonzalezco  template    0.042373
# 545    Christian7sr  template    0.000000
# 560      jsnarvaezb  template    0.239437
# 574   gfalbarracinr  template    0.015385
# 587        aldiazve  template    0.001666
# 599  diegoaguevarar  template    0.884058
# 610      fevargasmo  template    0.129771
# 620      jmhurtadoc  template    0.820000
# 629     anfmorenoso  template    0.119048
# 637     nabautistal  template    0.024390
# 644          crigar  template    0.032520
# 650     jiapulidoar  template    0.000649
# 655       jsviveroj  template    0.164286
# 659      daandradec  template    0.110048
# 662        jcrubioa  template    0.340974
# 664  joahernandezca  template    1.000000
# 665    JairVillalba  template    0.123077

# %% [markdown]
# ## Phase 2 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group2 = overall_phase2_group2[overall_phase2_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group2["functions"], overall_phase2_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group2 = pd.DataFrame(result)
phase2_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.176471
# 1    jusherrerama       Phoenixest    0.166667
# 2    jusherrerama         HashNick    0.045455
# 3    jusherrerama  juasmartinezbel    0.035088
# 4    jusherrerama         mdbelloc    0.045455
# ..            ...              ...         ...
# 661      lsfinite     jscontrerasp    0.002060
# 662      lsfinite         template    0.006487
# 663     xdanielsb     jscontrerasp    0.029851
# 664     xdanielsb         template    0.047619
# 665  jscontrerasp         template    0.050725
#
# [666 rows x 3 columns]

# %%
phase2_group2 = phase2_group2.loc[phase2_group2['user2'] == 'template']
phase2_group2
# Out:
#                user1     user2  similarity
# 35      jusherrerama  template    0.029630
# 70           bdvegat  template    0.024194
# 104       Phoenixest  template    0.024000
# 137         HashNick  template    0.430894
# 169  juasmartinezbel  template    0.178010
# 200         mdbelloc  template    0.408000
# 230      diegocruz10  template    0.119403
# 259           sagilm  template    0.032258
# 287         idrojasf  template    0.022792
# 314     raulramirezp  template    0.065637
# 340        fabianr23  template    0.068750
# 365       jhriverasa  template    0.057554
# 389       jhonsd1996  template    0.024000
# 412       JuanitoAli  template    0.016421
# 434       Davsatu313  template    0.323529
# 455   cesarochoa2006  template    0.289655
# 475        jjmuesesq  template    0.024390
# 494     jucjimenezmo  template    0.023256
# 512           kancas  template    0.187050
# 529          Gantiva  template    0.073826
# 545       Dandarprox  template    0.067485
# 560       debeltranc  template    0.000000
# 574        ykchautai  template    0.069767
# 587        ligibrial  template    0.014913
# 599       davidrh195  template    0.021898
# 610      JulianaNino  template    0.042254
# 620         luegilca  template    0.130435
# 629           Yelis3  template    0.001523
# 637        begarzonf  template    0.046243
# 644       kmendezp96  template    0.275168
# 650         leguzman  template    0.345588
# 655     luealfonsoru  template    0.380000
# 659         oserasoa  template    0.244094
# 662         lsfinite  template    0.006487
# 664        xdanielsb  template    0.047619
# 665     jscontrerasp  template    0.050725

# %% [markdown]
# ## Phase 2 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase2_group3 = overall_phase2_group3[overall_phase2_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase2_group3["functions"], overall_phase2_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase2_group3 = pd.DataFrame(result)
phase2_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.034722
# 1        lemartinp      nfmorenog    0.183673
# 2        lemartinp      AFelipeGA    0.002417
# 3        lemartinp     mballeng91    0.000042
# 4        lemartinp       dduartec    0.125000
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.181818
# 699      lizzyt10h       template    0.062500
# 700     NicolasPrr  jumcorredorro    0.092593
# 701     NicolasPrr       template    0.051471
# 702  jumcorredorro       template    0.208955
#
# [703 rows x 3 columns]

# %%
phase2_group3 = phase2_group3.loc[phase2_group3['user2'] == 'template']
phase2_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.086614
# 72         juligarji  template    0.036290
# 107        nfmorenog  template    0.121622
# 141        AFelipeGA  template    0.014412
# 174       mballeng91  template    0.000570
# 206         dduartec  template    0.125000
# 237        srmedinac  template    0.058824
# 267     wilson911013  template    0.010482
# 296    wapiravaguens  template    0.107143
# 324         davidh17  template    0.202899
# 351   DianaNavarrete  template    0.023622
# 377        jorge52an  template    0.028902
# 402  jscastelblancoh  template    0.075342
# 426       juclopezso  template    0.023810
# 449        afforeroc  template    0.048387
# 471      dagofonseca  template    0.109375
# 492      lacardenasv  template    0.075000
# 512      oacastillol  template    0.168317
# 531       ncampuzano  template    0.050000
# 549         adriel62  template    0.263566
# 566         capinzor  template    0.043796
# 582         ofnanezn  template    0.054945
# 597        macuestap  template    0.077519
# 611           spenas  template    0.028369
# 624      kgbayala528  template    0.128866
# 636       lgmoralesa  template    0.144828
# 647       ronaldsg20  template    0.001240
# 657    cccristanchoc  template    0.121019
# 666       jmalvarezd  template    0.174497
# 674        smarquezo  template    0.016000
# 681          sarizag  template    0.093525
# 687         Chranium  template    0.024000
# 692          DavidQP  template    0.084507
# 696      afceballosr  template    0.108844
# 699        lizzyt10h  template    0.062500
# 701       NicolasPrr  template    0.051471
# 702    jumcorredorro  template    0.208955

# %% [markdown]
# ## Phase 3 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group0 = overall_phase3_group0[overall_phase3_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group0["functions"], overall_phase3_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group0 = pd.DataFrame(result)
phase3_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.003923
# 1       fffeelipe    jmcuestasb    0.001839
# 2       fffeelipe  jjrodriguezn    0.096154
# 3       fffeelipe         DglyP    0.255814
# 4       fffeelipe   Judgarciani    0.058442
# ..            ...           ...         ...
# 373  lfvalderrama        gabi04    0.103774
# 374  lfvalderrama      template    0.089820
# 375     bsgarciac        gabi04    0.097222
# 376     bsgarciac      template    0.131980
# 377        gabi04      template    0.090361
#
# [378 rows x 3 columns]

# %%
phase3_group0 = phase3_group0.loc[phase3_group0['user2'] == 'template']
phase3_group0
# Out:
#               user1     user2  similarity
# 26        fffeelipe  template    0.069930
# 52        mnguzmanc  template    0.022184
# 77       jmcuestasb  template    0.005466
# 101    jjrodriguezn  template    0.190476
# 124           DglyP  template    0.080882
# 146     Judgarciani  template    0.113043
# 167       sacastroc  template    0.133721
# 187       pcberriop  template    0.301587
# 206     hsmartineza  template    0.268116
# 224        Moimolcp  template    0.069149
# 241     CamiloRueda  template    0.017964
# 257      JoseMolano  template    0.333333
# 272   maikellPardoA  template    0.024194
# 286      NicolasZon  template    0.054688
# 299       camilo654  template    0.052239
# 311  CristianLozano  template    0.023622
# 322       jdsuarezj  template    0.196203
# 332       pipemax85  template    0.188976
# 341     juandavidro  template    0.095238
# 349  UNhcrodriguezl  template    0.300613
# 356     camilo13152  template    0.331034
# 362    leavendanoro  template    0.047297
# 367      cdcordobaa  template    0.061644
# 371      capinillab  template    0.134921
# 374    lfvalderrama  template    0.089820
# 376       bsgarciac  template    0.131980
# 377          gabi04  template    0.090361

# %% [markdown]
# ## Phase 3 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group1 = overall_phase3_group1[overall_phase3_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group1["functions"], overall_phase3_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group1 = pd.DataFrame(result)
phase3_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.049180
# 1         gasierram     bdcajicam    0.515625
# 2         gasierram   dfhincapiem    0.065574
# 3         gasierram     helmeraac    0.070423
# 4         gasierram    dasalgadob    0.129032
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.070822
# 662        jcrubioa      template    0.340974
# 663  joahernandezca  JairVillalba    0.122302
# 664  joahernandezca      template    1.000000
# 665    JairVillalba      template    0.122302
#
# [666 rows x 3 columns]

# %%
phase3_group1 = phase3_group1.loc[phase3_group1['user2'] == 'template']
phase3_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.437500
# 70     adamantwharf  template    0.024390
# 104       bdcajicam  template    0.261905
# 137     dfhincapiem  template    0.024194
# 169       helmeraac  template    0.037594
# 200      dasalgadob  template    0.073171
# 230      falperezgo  template    0.015226
# 259       djguzmanc  template    0.130719
# 287      gsuarezc04  template    0.071895
# 314          oeroaq  template    0.054224
# 340         gcantem  template    0.843750
# 365     Semoralesga  template    0.013629
# 389      jonatan360  template    0.130890
# 412  jesusfchavarro  template    0.012935
# 434    stevenbustos  template    0.023810
# 455  jufcontrerasco  template    0.030303
# 475      dsbarrerag  template    0.073620
# 494       wolfstain  template    0.088050
# 512      miaborjaac  template    0.071429
# 529   ivdgonzalezco  template    0.042373
# 545    Christian7sr  template    0.023810
# 560      jsnarvaezb  template    0.237762
# 574   gfalbarracinr  template    0.031008
# 587        aldiazve  template    0.001666
# 599  diegoaguevarar  template    0.884058
# 610      fevargasmo  template    0.109677
# 620      jmhurtadoc  template    0.820000
# 629     anfmorenoso  template    0.119048
# 637     nabautistal  template    0.023622
# 644          crigar  template    0.032520
# 650     jiapulidoar  template    0.000649
# 655       jsviveroj  template    0.152318
# 659      daandradec  template    0.107438
# 662        jcrubioa  template    0.340974
# 664  joahernandezca  template    1.000000
# 665    JairVillalba  template    0.122302

# %% [markdown]
# ## Phase 3 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group2 = overall_phase3_group2[overall_phase3_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group2["functions"], overall_phase3_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group2 = pd.DataFrame(result)
phase3_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003091
# 1    jusherrerama       Phoenixest    0.001326
# 2    jusherrerama         HashNick    0.004340
# 3    jusherrerama  juasmartinezbel    0.004601
# 4    jusherrerama         mdbelloc    0.004776
# ..            ...              ...         ...
# 661      lsfinite     jscontrerasp    0.003078
# 662      lsfinite         template    0.007481
# 663     xdanielsb     jscontrerasp    0.032710
# 664     xdanielsb         template    0.056856
# 665  jscontrerasp         template    0.055944
#
# [666 rows x 3 columns]

# %%
phase3_group2 = phase3_group2.loc[phase3_group2['user2'] == 'template']
phase3_group2
# Out:
#                user1     user2  similarity
# 35      jusherrerama  template    0.014900
# 70           bdvegat  template    0.072000
# 104       Phoenixest  template    0.024000
# 137         HashNick  template    0.430894
# 169  juasmartinezbel  template    0.147826
# 200         mdbelloc  template    0.408000
# 230      diegocruz10  template    0.108844
# 259           sagilm  template    0.161290
# 287         idrojasf  template    0.022792
# 314     raulramirezp  template    0.065637
# 340        fabianr23  template    0.056995
# 365       jhriverasa  template    0.056338
# 389       jhonsd1996  template    0.024000
# 412       JuanitoAli  template    0.015800
# 434       Davsatu313  template    0.137681
# 455   cesarochoa2006  template    0.266304
# 475        jjmuesesq  template    0.024390
# 494     jucjimenezmo  template    0.023256
# 512           kancas  template    0.187050
# 529          Gantiva  template    0.083871
# 545       Dandarprox  template    0.069519
# 560       debeltranc  template    0.000000
# 574        ykchautai  template    0.081481
# 587        ligibrial  template    0.016170
# 599       davidrh195  template    0.021898
# 610      JulianaNino  template    0.060811
# 620         luegilca  template    0.130435
# 629           Yelis3  template    0.001539
# 637        begarzonf  template    0.053131
# 644       kmendezp96  template    0.266234
# 650         leguzman  template    0.331250
# 655     luealfonsoru  template    0.366667
# 659         oserasoa  template    0.270677
# 662         lsfinite  template    0.007481
# 664        xdanielsb  template    0.056856
# 665     jscontrerasp  template    0.055944

# %% [markdown]
# ## Phase 3 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase3_group3 = overall_phase3_group3[overall_phase3_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase3_group3["functions"], overall_phase3_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase3_group3 = pd.DataFrame(result)
phase3_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.002394
# 1        lemartinp      nfmorenog    0.155172
# 2        lemartinp      AFelipeGA    0.002417
# 3        lemartinp     mballeng91    0.000042
# 4        lemartinp       dduartec    0.052632
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.098039
# 699      lizzyt10h       template    0.076923
# 700     NicolasPrr  jumcorredorro    0.055046
# 701     NicolasPrr       template    0.051471
# 702  jumcorredorro       template    0.178378
#
# [703 rows x 3 columns]

# %%
phase3_group3 = phase3_group3.loc[phase3_group3['user2'] == 'template']
phase3_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.086614
# 72         juligarji  template    0.014324
# 107        nfmorenog  template    0.114650
# 141        AFelipeGA  template    0.014412
# 174       mballeng91  template    0.000570
# 206         dduartec  template    0.090909
# 237        srmedinac  template    0.058824
# 267     wilson911013  template    0.010482
# 296    wapiravaguens  template    0.095238
# 324         davidh17  template    0.185897
# 351   DianaNavarrete  template    0.023622
# 377        jorge52an  template    0.019531
# 402  jscastelblancoh  template    0.084967
# 426       juclopezso  template    0.023810
# 449        afforeroc  template    0.048387
# 471      dagofonseca  template    0.084302
# 492      lacardenasv  template    0.075472
# 512      oacastillol  template    0.158140
# 531       ncampuzano  template    0.067010
# 549         adriel62  template    0.263566
# 566         capinzor  template    0.312057
# 582         ofnanezn  template    0.052326
# 597        macuestap  template    0.077519
# 611           spenas  template    0.028369
# 624      kgbayala528  template    0.132353
# 636       lgmoralesa  template    0.130435
# 647       ronaldsg20  template    0.001265
# 657    cccristanchoc  template    0.121019
# 666       jmalvarezd  template    0.172185
# 674        smarquezo  template    0.016000
# 681          sarizag  template    0.093525
# 687         Chranium  template    0.024000
# 692          DavidQP  template    0.044872
# 696      afceballosr  template    0.105960
# 699        lizzyt10h  template    0.076923
# 701       NicolasPrr  template    0.051471
# 702    jumcorredorro  template    0.178378

# %% [markdown]
# ## Phase 4 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group0 = overall_phase4_group0[overall_phase4_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group0["functions"], overall_phase4_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group0 = pd.DataFrame(result)
phase4_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.013108
# 1       fffeelipe    jmcuestasb    0.004914
# 2       fffeelipe    katherinsb    0.024194
# 3       fffeelipe  jjrodriguezn    0.038760
# 4       fffeelipe         DglyP    0.010620
# ..            ...           ...         ...
# 401  lfvalderrama        gabi04    0.111111
# 402  lfvalderrama      template    0.094675
# 403     bsgarciac        gabi04    0.086705
# 404     bsgarciac      template    0.171296
# 405        gabi04      template    0.090361
#
# [406 rows x 3 columns]

# %%
phase4_group0 = phase4_group0.loc[phase4_group0['user2'] == 'template']
phase4_group0
# Out:
#               user1     user2  similarity
# 27        fffeelipe  template    0.080189
# 54        mnguzmanc  template    0.023325
# 80       jmcuestasb  template    0.005466
# 105      katherinsb  template    0.035971
# 129    jjrodriguezn  template    0.188976
# 152           DglyP  template    0.018887
# 174     Judgarciani  template    0.110638
# 195       sacastroc  template    0.114754
# 215       pcberriop  template    0.219355
# 234     hsmartineza  template    0.177215
# 252        Moimolcp  template    0.068421
# 269     CamiloRueda  template    0.017964
# 285      JoseMolano  template    0.333333
# 300   maikellPardoA  template    0.024194
# 314      NicolasZon  template    0.054688
# 327       camilo654  template    0.062500
# 339  CristianLozano  template    0.023622
# 350       jdsuarezj  template    0.196203
# 360       pipemax85  template    0.188976
# 369     juandavidro  template    0.095238
# 377  UNhcrodriguezl  template    0.300613
# 384     camilo13152  template    0.288344
# 390    leavendanoro  template    0.069620
# 395      cdcordobaa  template    0.061644
# 399      capinillab  template    0.244094
# 402    lfvalderrama  template    0.094675
# 404       bsgarciac  template    0.171296
# 405          gabi04  template    0.090361

# %% [markdown]
# ## Phase 4 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group1 = overall_phase4_group1[overall_phase4_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group1["functions"], overall_phase4_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group1 = pd.DataFrame(result)
phase4_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.049180
# 1         gasierram     bdcajicam    0.515625
# 2         gasierram   dfhincapiem    0.065574
# 3         gasierram     helmeraac    0.091954
# 4         gasierram    dasalgadob    0.129032
# ..              ...           ...         ...
# 661        jcrubioa  JairVillalba    0.076271
# 662        jcrubioa      template    0.340974
# 663  joahernandezca  JairVillalba    0.125874
# 664  joahernandezca      template    0.984000
# 665    JairVillalba      template    0.127660
#
# [666 rows x 3 columns]

# %%
phase4_group1 = phase4_group1.loc[phase4_group1['user2'] == 'template']
phase4_group1
# Out:
#               user1     user2  similarity
# 35        gasierram  template    0.437500
# 70     adamantwharf  template    0.024390
# 104       bdcajicam  template    0.261905
# 137     dfhincapiem  template    0.024194
# 169       helmeraac  template    0.053691
# 200      dasalgadob  template    0.073171
# 230      falperezgo  template    0.014797
# 259       djguzmanc  template    0.146341
# 287      gsuarezc04  template    0.071895
# 314          oeroaq  template    0.016986
# 340         gcantem  template    0.148438
# 365     Semoralesga  template    0.052632
# 389      jonatan360  template    0.131222
# 412  jesusfchavarro  template    0.006935
# 434    stevenbustos  template    0.082707
# 455  jufcontrerasco  template    0.211111
# 475      dsbarrerag  template    0.071429
# 494       wolfstain  template    0.094512
# 512      miaborjaac  template    0.100457
# 529   ivdgonzalezco  template    0.043353
# 545    Christian7sr  template    0.023810
# 560      jsnarvaezb  template    0.240260
# 574   gfalbarracinr  template    0.029197
# 587        aldiazve  template    0.001497
# 599  diegoaguevarar  template    0.884058
# 610      fevargasmo  template    0.125786
# 620      jmhurtadoc  template    0.820000
# 629     anfmorenoso  template    0.160584
# 637     nabautistal  template    0.023438
# 644          crigar  template    0.032520
# 650     jiapulidoar  template    0.000649
# 655       jsviveroj  template    0.188312
# 659      daandradec  template    0.099462
# 662        jcrubioa  template    0.340974
# 664  joahernandezca  template    0.984000
# 665    JairVillalba  template    0.127660

# %% [markdown]
# ## Phase 4 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group2 = overall_phase4_group2[overall_phase4_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group2["functions"], overall_phase4_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group2 = pd.DataFrame(result)
phase4_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003091
# 1    jusherrerama       Phoenixest    0.001326
# 2    jusherrerama         HashNick    0.005635
# 3    jusherrerama          ccvacad    0.003871
# 4    jusherrerama  juasmartinezbel    0.013575
# ..            ...              ...         ...
# 698      lsfinite     jscontrerasp    0.002871
# 699      lsfinite         template    0.007478
# 700     xdanielsb     jscontrerasp    0.028000
# 701     xdanielsb         template    0.057057
# 702  jscontrerasp         template    0.055944
#
# [703 rows x 3 columns]

# %%
phase4_group2 = phase4_group2.loc[phase4_group2['user2'] == 'template']
phase4_group2
# Out:
#                user1     user2  similarity
# 36      jusherrerama  template    0.014900
# 72           bdvegat  template    0.072000
# 107       Phoenixest  template    0.024000
# 141         HashNick  template    0.479675
# 174          ccvacad  template    0.132948
# 206  juasmartinezbel  template    0.358333
# 237         mdbelloc  template    0.408000
# 267      diegocruz10  template    0.108844
# 296           sagilm  template    0.161290
# 324         idrojasf  template    0.024217
# 351     raulramirezp  template    0.101744
# 377        fabianr23  template    0.084507
# 402       jhriverasa  template    0.049020
# 426       jhonsd1996  template    0.024000
# 449       JuanitoAli  template    0.015447
# 471       Davsatu313  template    0.260355
# 492   cesarochoa2006  template    0.149813
# 512        jjmuesesq  template    0.045802
# 531     jucjimenezmo  template    0.318841
# 549           kancas  template    0.187050
# 566          Gantiva  template    0.080745
# 582       Dandarprox  template    0.104089
# 597       debeltranc  template    0.000000
# 611        ykchautai  template    0.066667
# 624        ligibrial  template    0.016596
# 636       davidrh195  template    0.021429
# 647      JulianaNino  template    0.064748
# 657         luegilca  template    0.130435
# 666           Yelis3  template    0.002236
# 674        begarzonf  template    0.053131
# 681       kmendezp96  template    0.261628
# 687         leguzman  template    0.311765
# 692     luealfonsoru  template    0.359477
# 696         oserasoa  template    0.270677
# 699         lsfinite  template    0.007478
# 701        xdanielsb  template    0.057057
# 702     jscontrerasp  template    0.055944

# %% [markdown]
# ## Phase 4 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase4_group3 = overall_phase4_group3[overall_phase4_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase4_group3["functions"], overall_phase4_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase4_group3 = pd.DataFrame(result)
phase4_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.005437
# 1        lemartinp      nfmorenog    0.164179
# 2        lemartinp      AFelipeGA    0.006274
# 3        lemartinp     mballeng91    0.000167
# 4        lemartinp       dduartec    0.048000
# ..             ...            ...         ...
# 698      lizzyt10h  jumcorredorro    0.064220
# 699      lizzyt10h       template    0.092486
# 700     NicolasPrr  jumcorredorro    0.048447
# 701     NicolasPrr       template    0.051181
# 702  jumcorredorro       template    0.133333
#
# [703 rows x 3 columns]

# %%
phase4_group3 = phase4_group3.loc[phase4_group3['user2'] == 'template']
phase4_group3
# Out:
#                user1     user2  similarity
# 36         lemartinp  template    0.120301
# 72         juligarji  template    0.013968
# 107        nfmorenog  template    0.114650
# 141        AFelipeGA  template    0.014412
# 174       mballeng91  template    0.000570
# 206         dduartec  template    0.090909
# 237        srmedinac  template    0.059172
# 267     wilson911013  template    0.012526
# 296    wapiravaguens  template    0.095238
# 324         davidh17  template    0.171271
# 351   DianaNavarrete  template    0.023622
# 377        jorge52an  template    0.118132
# 402  jscastelblancoh  template    0.123596
# 426       juclopezso  template    0.085714
# 449        afforeroc  template    0.048387
# 471      dagofonseca  template    0.082621
# 492      lacardenasv  template    0.004935
# 512      oacastillol  template    0.086420
# 531       ncampuzano  template    0.066327
# 549         adriel62  template    0.006701
# 566         capinzor  template    0.025974
# 582         ofnanezn  template    0.052326
# 597        macuestap  template    0.076923
# 611           spenas  template    0.028369
# 624      kgbayala528  template    0.132353
# 636       lgmoralesa  template    0.138728
# 647       ronaldsg20  template    0.001339
# 657    cccristanchoc  template    0.111732
# 666       jmalvarezd  template    0.172185
# 674        smarquezo  template    0.051095
# 681          sarizag  template    0.092199
# 687         Chranium  template    0.024000
# 692          DavidQP  template    0.050314
# 696      afceballosr  template    0.132867
# 699        lizzyt10h  template    0.092486
# 701       NicolasPrr  template    0.051181
# 702    jumcorredorro  template    0.133333

# %% [markdown]
# ## Phase 5 Group 0 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group0 = overall_phase5_group0[overall_phase5_group0.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group0["functions"], overall_phase5_group0["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group0 = pd.DataFrame(result)
phase5_group0
# Out:
#             user1         user2  similarity
# 0       fffeelipe     mnguzmanc    0.013866
# 1       fffeelipe    jmcuestasb    0.005189
# 2       fffeelipe    katherinsb    0.009228
# 3       fffeelipe  jjrodriguezn    0.035211
# 4       fffeelipe         DglyP    0.012088
# ..            ...           ...         ...
# 401  lfvalderrama        gabi04    0.119048
# 402  lfvalderrama      template    0.094675
# 403     bsgarciac        gabi04    0.105263
# 404     bsgarciac      template    0.170507
# 405        gabi04      template    0.109890
#
# [406 rows x 3 columns]

# %%
phase5_group0 = phase5_group0.loc[phase5_group0['user2'] == 'template']
phase5_group0
# Out:
#               user1     user2  similarity
# 27        fffeelipe  template    0.081448
# 54        mnguzmanc  template    0.023256
# 80       jmcuestasb  template    0.005466
# 105      katherinsb  template    0.016428
# 129    jjrodriguezn  template    0.184615
# 152           DglyP  template    0.021393
# 174     Judgarciani  template    0.316206
# 195       sacastroc  template    0.127778
# 215       pcberriop  template    0.126984
# 234     hsmartineza  template    0.181250
# 252        Moimolcp  template    0.065000
# 269     CamiloRueda  template    0.017964
# 285      JoseMolano  template    0.333333
# 300   maikellPardoA  template    0.024194
# 314      NicolasZon  template    0.054688
# 327       camilo654  template    0.062500
# 339  CristianLozano  template    0.023622
# 350       jdsuarezj  template    0.196203
# 360       pipemax85  template    0.188976
# 369     juandavidro  template    0.095238
# 377  UNhcrodriguezl  template    0.300613
# 384     camilo13152  template    0.288344
# 390    leavendanoro  template    0.056250
# 395      cdcordobaa  template    0.061644
# 399      capinillab  template    0.166667
# 402    lfvalderrama  template    0.094675
# 404       bsgarciac  template    0.170507
# 405          gabi04  template    0.109890

# %% [markdown]
# ## Phase 5 Group 1 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group1 = overall_phase5_group1[overall_phase5_group1.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group1["functions"], overall_phase5_group1["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group1 = pd.DataFrame(result)
phase5_group1
# Out:
#               user1         user2  similarity
# 0         gasierram  adamantwharf    0.049180
# 1         gasierram     bdcajicam    0.515625
# 2         gasierram   dfhincapiem    0.065574
# 3         gasierram     helmeraac    0.091954
# 4         gasierram    dasalgadob    0.129032
# ..              ...           ...         ...
# 625        jcrubioa  JairVillalba    0.088710
# 626        jcrubioa      template    0.340974
# 627  joahernandezca  JairVillalba    0.134969
# 628  joahernandezca      template    0.984000
# 629    JairVillalba      template    0.136646
#
# [630 rows x 3 columns]

# %%
phase5_group1 = phase5_group1.loc[phase5_group1['user2'] == 'template']
phase5_group1
# Out:
#               user1     user2  similarity
# 34        gasierram  template    0.437500
# 68     adamantwharf  template    0.024390
# 101       bdcajicam  template    0.261905
# 133     dfhincapiem  template    0.024194
# 164       helmeraac  template    0.053691
# 194      dasalgadob  template    0.073171
# 223      falperezgo  template    0.014755
# 251       djguzmanc  template    0.146341
# 278      gsuarezc04  template    0.071895
# 304          oeroaq  template    0.019294
# 329     Semoralesga  template    0.082707
# 353      jonatan360  template    0.135021
# 376  jesusfchavarro  template    0.001718
# 398    stevenbustos  template    0.076923
# 419  jufcontrerasco  template    0.211111
# 439      dsbarrerag  template    0.065934
# 458       wolfstain  template    0.094512
# 476      miaborjaac  template    0.098214
# 493   ivdgonzalezco  template    0.050420
# 509    Christian7sr  template    0.027778
# 524      jsnarvaezb  template    0.240260
# 538   gfalbarracinr  template    0.059603
# 551        aldiazve  template    0.001843
# 563  diegoaguevarar  template    0.598684
# 574      fevargasmo  template    0.125000
# 584      jmhurtadoc  template    0.820000
# 593     anfmorenoso  template    0.130682
# 601     nabautistal  template    0.328244
# 608          crigar  template    0.032520
# 614     jiapulidoar  template    0.000649
# 619       jsviveroj  template    0.183544
# 623      daandradec  template    0.099462
# 626        jcrubioa  template    0.340974
# 628  joahernandezca  template    0.984000
# 629    JairVillalba  template    0.136646

# %% [markdown]
# ## Phase 5 Group 2 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group2 = overall_phase5_group2[overall_phase5_group2.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group2["functions"], overall_phase5_group2["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group2 = pd.DataFrame(result)
phase5_group2
# Out:
#             user1            user2  similarity
# 0    jusherrerama          bdvegat    0.003091
# 1    jusherrerama       Phoenixest    0.001326
# 2    jusherrerama         HashNick    0.005635
# 3    jusherrerama          ccvacad    0.004275
# 4    jusherrerama  juasmartinezbel    0.013575
# ..            ...              ...         ...
# 698      lsfinite     jscontrerasp    0.002871
# 699      lsfinite         template    0.007478
# 700     xdanielsb     jscontrerasp    0.020790
# 701     xdanielsb         template    0.042705
# 702  jscontrerasp         template    0.055944
#
# [703 rows x 3 columns]

# %%
phase5_group2 = phase5_group2.loc[phase5_group2['user2'] == 'template']
phase5_group2
# Out:
#                user1     user2  similarity
# 36      jusherrerama  template    0.014900
# 72           bdvegat  template    0.072000
# 107       Phoenixest  template    0.024000
# 141         HashNick  template    0.479675
# 174          ccvacad  template    0.140541
# 206  juasmartinezbel  template    0.358333
# 237         mdbelloc  template    0.408000
# 267      diegocruz10  template    0.108844
# 296           sagilm  template    0.282258
# 324         idrojasf  template    0.024217
# 351     raulramirezp  template    0.097625
# 377        fabianr23  template    0.091575
# 402       jhriverasa  template    0.060914
# 426       jhonsd1996  template    0.024000
# 449       JuanitoAli  template    0.015447
# 471       Davsatu313  template    0.177515
# 492   cesarochoa2006  template    0.152985
# 512        jjmuesesq  template    0.048951
# 531     jucjimenezmo  template    0.307692
# 549           kancas  template    0.187050
# 566          Gantiva  template    0.080745
# 582       Dandarprox  template    0.104089
# 597       debeltranc  template    0.000000
# 611        ykchautai  template    0.078431
# 624        ligibrial  template    0.012025
# 636       davidrh195  template    0.021429
# 647      JulianaNino  template    0.064748
# 657         luegilca  template    0.130435
# 666           Yelis3  template    0.005325
# 674        begarzonf  template    0.053131
# 681       kmendezp96  template    0.027117
# 687         leguzman  template    0.288660
# 692     luealfonsoru  template    0.359477
# 696         oserasoa  template    0.246479
# 699         lsfinite  template    0.007478
# 701        xdanielsb  template    0.042705
# 702     jscontrerasp  template    0.055944

# %% [markdown]
# ## Phase 5 Group 3 Comparison with Template

# %%
import itertools
import pandas as pd

overall_phase5_group3 = overall_phase5_group3[overall_phase5_group3.unique != '']

# copied from OP above
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

# create list of tuples like [(wording, user), (wording, user)]
wordings_users = list(zip(overall_phase5_group3["functions"], overall_phase5_group3["Student"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "similarity": similarity}
    result.append(data)

phase5_group3 = pd.DataFrame(result)
phase5_group3
# Out:
#              user1          user2  similarity
# 0        lemartinp      juligarji    0.005428
# 1        lemartinp      nfmorenog    0.164179
# 2        lemartinp      AFelipeGA    0.006274
# 3        lemartinp     mballeng91    0.000167
# 4        lemartinp       dduartec    0.005530
# ..             ...            ...         ...
# 736      lizzyt10h  jumcorredorro    0.066667
# 737      lizzyt10h       template    0.093923
# 738     NicolasPrr  jumcorredorro    0.097902
# 739     NicolasPrr       template    0.103448
# 740  jumcorredorro       template    0.125926
#
# [741 rows x 3 columns]

# %%
phase5_group3 = phase5_group3.loc[phase5_group3['user2'] == 'template']
phase5_group3
# Out:
#                user1     user2  similarity
# 37         lemartinp  template    0.120301
# 74         juligarji  template    0.013946
# 110        nfmorenog  template    0.114650
# 145        AFelipeGA  template    0.014412
# 179       mballeng91  template    0.000570
# 212         dduartec  template    0.021162
# 244        srmedinac  template    0.059172
# 275     wilson911013  template    0.012526
# 305    wapiravaguens  template    0.092784
# 334         davidh17  template    0.165746
# 362   DianaNavarrete  template    0.023622
# 389        jdmonroyg  template    0.070312
# 415        jorge52an  template    0.108040
# 440  jscastelblancoh  template    0.097473
# 464       juclopezso  template    0.085106
# 487        afforeroc  template    0.048387
# 509      dagofonseca  template    0.079452
# 530      lacardenasv  template    0.005021
# 550      oacastillol  template    0.078624
# 569       ncampuzano  template    0.351759
# 587         adriel62  template    0.122530
# 604         capinzor  template    0.021266
# 620         ofnanezn  template    0.052326
# 635        macuestap  template    0.076923
# 649           spenas  template    0.028369
# 662      kgbayala528  template    0.132353
# 674       lgmoralesa  template    0.136364
# 685       ronaldsg20  template    0.001315
# 695    cccristanchoc  template    0.120603
# 704       jmalvarezd  template    0.173333
# 712        smarquezo  template    0.126506
# 719          sarizag  template    0.124138
# 725         Chranium  template    0.024000
# 730          DavidQP  template    0.071429
# 734      afceballosr  template    0.130137
# 737        lizzyt10h  template    0.093923
# 739       NicolasPrr  template    0.103448
# 740    jumcorredorro  template    0.125926

# %% [markdown]
# ## Distribution Plot for Phase 1

# %%
phase1_group0['group'] = 0
phase1_group1['group'] = 1
phase1_group2['group'] = 2
phase1_group3['group'] = 3
phase1 = pd.concat([phase1_group0, phase1_group1, phase1_group2, phase1_group3], ignore_index=True)
phase1['similarity'].hist(by=phase1['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/2015457414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/2015457414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/2015457414.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/2015457414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase1_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 2

# %%
phase2_group0['group'] = 0
phase2_group1['group'] = 1
phase2_group2['group'] = 2
phase2_group3['group'] = 3
phase2 = pd.concat([phase2_group0, phase2_group1, phase2_group2, phase2_group3], ignore_index=True)
phase2['similarity'].hist(by=phase2['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/124240429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/124240429.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/124240429.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/124240429.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase2_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 3

# %%
phase3_group0['group'] = 0
phase3_group1['group'] = 1
phase3_group2['group'] = 2
phase3_group3['group'] = 3
phase3 = pd.concat([phase3_group0, phase3_group1, phase3_group2, phase3_group3], ignore_index=True)
phase3['similarity'].hist(by=phase3['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4250399680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4250399680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4250399680.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4250399680.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase3_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 4

# %%
phase4_group0['group'] = 0
phase4_group1['group'] = 1
phase4_group2['group'] = 2
phase4_group3['group'] = 3
phase4 = pd.concat([phase4_group0, phase4_group1, phase4_group2, phase4_group3], ignore_index=True)
phase4['similarity'].hist(by=phase4['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4284504232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4284504232.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4284504232.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4284504232.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase4_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %% [markdown]
# ## Distribution Plot for Phase 5

# %%
phase5_group0['group'] = 0
phase5_group1['group'] = 1
phase5_group2['group'] = 2
phase5_group3['group'] = 3
phase5 = pd.concat([phase5_group0, phase5_group1, phase5_group2, phase5_group3], ignore_index=True)
phase5['similarity'].hist(by=phase5['group'])
# Out:
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4080999950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group0['group'] = 0
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4080999950.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group1['group'] = 1
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4080999950.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group2['group'] = 2
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_4926/4080999950.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phase5_group3['group'] = 3
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>],
#        [<AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>]], dtype=object)

# %%
median_log_bogota3 = []
median_log_bogota2 = []
median_log_bogota1 = []
median_log_bogota0 = []

mean_log_bogota3 = []
mean_log_bogota2 = []
mean_log_bogota1 = []
mean_log_bogota0 = []

for df in [phase1_group3, phase2_group3, phase3_group3, phase4_group3, phase5_group3]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    median_log_bogota3.append(median_value)
    mean_log_bogota3.append(mean_value)
    plt.figure()
    plt.title("Global Similarity Plot Bogota 3")
    sns.distplot((np.log(df['similarity']+1)))

for df in [phase1_group2, phase2_group2, phase3_group2, phase4_group2, phase5_group2]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    median_log_bogota2.append(median_value)
    mean_log_bogota2.append(mean_value)
    plt.figure()
    plt.title("Global Similarity Plot Bogota 2")
    sns.distplot((np.log(df['similarity']+1)))
    
for df in [phase1_group1, phase2_group1, phase3_group1, phase4_group1, phase5_group1]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    median_log_bogota1.append(median_value)
    mean_log_bogota1.append(mean_value)
    plt.figure()
    plt.title("Global Similarity Plot Bogota 1")
    sns.distplot((np.log(df['similarity']+1)))

for df in [phase1_group0, phase2_group0, phase3_group0, phase4_group0, phase5_group0]:
    median_value = (np.log(df['similarity']+1)).median()
    mean_value = (np.log(df['similarity']+1)).mean()
    median_log_bogota0.append(median_value)
    mean_log_bogota0.append(mean_value)
    plt.figure()
    plt.title("Global Similarity Plot Bogota 0")
    sns.distplot((np.log(df['similarity']+1)))
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt

y1 = median_log_bogota0
y2 = median_log_bogota1
y3 = median_log_bogota2
y4 = median_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Median Template Similarity")
plt.ylabel("Log-Transform Median Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)

# %%
import matplotlib.pyplot as plt

y1 = mean_log_bogota0
y2 = mean_log_bogota1
y3 = mean_log_bogota2
y4 = mean_log_bogota3

x_axis=['Phase 1', 'Phase 2', 'Phase 3', 'Phase 4', 'Phase 5']

line1 = plt.plot(x_axis, y1,'bo-',label='Bogota 0 ( No Transparency )') 
line2 = plt.plot(x_axis, y2,'go-',label='Bogota 1 ( Performance Transparency )') 
line3 = plt.plot(x_axis, y3,'ko-',label='Bogota 2 ( Solution Transparency )')
line4 = plt.plot(x_axis, y4,'ro-',label='Bogota 3 ( Full Transparency )') 

plt.title("Log-Transform Mean Template Similarity")
plt.ylabel("Log-Transform Mean Template Similarity")

plt.legend(bbox_to_anchor=(1.5, 1),
           bbox_transform=plt.gcf().transFigure)
