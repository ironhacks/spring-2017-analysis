# %%
# %store -r bogota_final
# %store -r survey

# %store -r bogota0_phase4_high_compare
# %store -r bogota0_phase3_high_compare
# %store -r bogota0_phase2_high_compare
# %store -r bogota0_phase1_high_compare

# %store -r bogota1_phase4_high_compare
# %store -r bogota1_phase3_high_compare
# %store -r bogota1_phase2_high_compare
# %store -r bogota1_phase1_high_compare

# %store -r bogota2_phase4_high_compare
# %store -r bogota2_phase3_high_compare
# %store -r bogota2_phase2_high_compare
# %store -r bogota2_phase1_high_compare

# %store -r bogota3_phase4_high_compare
# %store -r bogota3_phase3_high_compare
# %store -r bogota3_phase2_high_compare
# %store -r bogota3_phase1_high_compare

# %store -r stage1_bogota0_high_similarity
# %store -r stage1_bogota1_high_similarity
# %store -r stage1_bogota2_high_similarity
# %store -r stage1_bogota3_high_similarity

# %store -r stage2_bogota0_high_similarity
# %store -r stage2_bogota1_high_similarity
# %store -r stage2_bogota2_high_similarity
# %store -r stage2_bogota3_high_similarity

# %store -r stage3_bogota0_high_similarity
# %store -r stage3_bogota1_high_similarity
# %store -r stage3_bogota2_high_similarity
# %store -r stage3_bogota3_high_similarity

# %store -r stage4_bogota0_high_similarity
# %store -r stage4_bogota1_high_similarity
# %store -r stage4_bogota2_high_similarity
# %store -r stage4_bogota3_high_similarity


import pandas as pd

# %%
stage1_bogota3_high_similarity['novelty'] = 1 - stage1_bogota3_high_similarity['similarity']
stage2_bogota3_high_similarity['novelty'] = 1 - stage2_bogota3_high_similarity['similarity']
stage3_bogota3_high_similarity['novelty'] = 1 - stage3_bogota3_high_similarity['similarity']
stage4_bogota3_high_similarity['novelty'] = 1 - stage4_bogota3_high_similarity['similarity']

stage1_bogota2_high_similarity['novelty'] = 1 - stage1_bogota2_high_similarity['similarity']
stage2_bogota2_high_similarity['novelty'] = 1 - stage2_bogota2_high_similarity['similarity']
stage3_bogota2_high_similarity['novelty'] = 1 - stage3_bogota2_high_similarity['similarity']
stage4_bogota2_high_similarity['novelty'] = 1 - stage4_bogota2_high_similarity['similarity']

stage1_bogota1_high_similarity['novelty'] = 1 - stage1_bogota1_high_similarity['similarity']
stage2_bogota1_high_similarity['novelty'] = 1 - stage2_bogota1_high_similarity['similarity']
stage3_bogota1_high_similarity['novelty'] = 1 - stage3_bogota1_high_similarity['similarity']
stage4_bogota1_high_similarity['novelty'] = 1 - stage4_bogota1_high_similarity['similarity']

stage1_bogota0_high_similarity['novelty'] = 1 - stage1_bogota0_high_similarity['similarity']
stage2_bogota0_high_similarity['novelty'] = 1 - stage2_bogota0_high_similarity['similarity']
stage3_bogota0_high_similarity['novelty'] = 1 - stage3_bogota0_high_similarity['similarity']
stage4_bogota0_high_similarity['novelty'] = 1 - stage4_bogota0_high_similarity['similarity']

# %%
stage1_bogota2_high_similarity
# Out:
#               user1         user2  user1_phase  user2_phase  similarity  \
# 0        crarojasca   jhcardenasa            1            2    1.000000
# 1      jucjimenezmo       ccvacad            1            2    1.000000
# 2       jhcardenasa    crarojasca            1            2    1.000000
# 3            sagilm     jjmuesesq            1            2    1.000000
# 4          HashNick      mdbelloc            1            2    0.696970
# 5          mdbelloc      HashNick            1            2    0.656250
# 6         jjmuesesq        sagilm            1            2    0.600000
# 7        JuanitoAli   JulianaNino            1            2    0.500000
# 8            kancas      luegilca            1            2    0.390244
# 9       diegocruz10    joaortizro            1            2    0.370370
# 10         luegilca    kmendezp96            1            2    0.351351
# 11          Gantiva     ykchautai            1            2    0.304348
# ...

# %%
bogota3_phase4_high_compare['phase'] = 4
bogota3_phase4_high_compare['group'] = 3

bogota3_phase3_high_compare['phase'] = 3
bogota3_phase3_high_compare['group'] = 3

bogota3_phase2_high_compare['phase'] = 2
bogota3_phase2_high_compare['group'] = 3

bogota3_phase1_high_compare['phase'] = 1
bogota3_phase1_high_compare['group'] = 3

bogota2_phase4_high_compare['phase'] = 4
bogota2_phase4_high_compare['group'] = 2

bogota2_phase3_high_compare['phase'] = 3
bogota2_phase3_high_compare['group'] = 2

bogota2_phase2_high_compare['phase'] = 2
bogota2_phase2_high_compare['group'] = 2

bogota2_phase1_high_compare['phase'] = 1
bogota2_phase1_high_compare['group'] = 2

bogota1_phase4_high_compare['phase'] = 4
bogota1_phase4_high_compare['group'] = 1

bogota1_phase3_high_compare['phase'] = 3
bogota1_phase3_high_compare['group'] = 1

bogota1_phase2_high_compare['phase'] = 2
bogota1_phase2_high_compare['group'] = 1

bogota1_phase1_high_compare['phase'] = 1
bogota1_phase1_high_compare['group'] = 1

bogota0_phase4_high_compare['phase'] = 4
bogota0_phase4_high_compare['group'] = 0

bogota0_phase3_high_compare['phase'] = 3
bogota0_phase3_high_compare['group'] = 0

bogota0_phase2_high_compare['phase'] = 2
bogota0_phase2_high_compare['group'] = 0

bogota0_phase1_high_compare['phase'] = 1
bogota0_phase1_high_compare['group'] = 0

# %%
p1 = bogota_final[['Student', 'group', 'abs_perform_diff_best_phase1']]
p1.rename(columns = {'abs_perform_diff_best_phase1':'abs_perform_diff_best'}, inplace = True)
p1['phase'] = 1
p2 = bogota_final[['Student', 'group', 'abs_perform_diff_best_phase2']]
p2.rename(columns = {'abs_perform_diff_best_phase2':'abs_perform_diff_best'}, inplace = True)
p2['phase'] = 2
p3 = bogota_final[['Student', 'group', 'abs_perform_diff_best_phase3']]
p3.rename(columns = {'abs_perform_diff_best_phase3':'abs_perform_diff_best'}, inplace = True)
p3['phase'] = 3
p4 = bogota_final[['Student', 'group', 'abs_perform_diff_best_phase4']]
p4.rename(columns = {'abs_perform_diff_best_phase4':'abs_perform_diff_best'}, inplace = True)
p4['phase'] = 4
p5 = bogota_final[['Student', 'group', 'abs_perform_diff_best_phase5']]
p5.rename(columns = {'abs_perform_diff_best_phase5':'abs_perform_diff_best'}, inplace = True)
p5['phase'] = 5
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1881/305279030.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p1.rename(columns = {'abs_perform_diff_best_phase1':'abs_perform_diff_best'}, inplace = True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1881/305279030.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p1['phase'] = 1
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1881/305279030.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
high_compare_overall = pd.concat([bogota0_phase1_high_compare, bogota0_phase2_high_compare, bogota0_phase3_high_compare, bogota0_phase4_high_compare, bogota1_phase1_high_compare, bogota1_phase2_high_compare, bogota1_phase3_high_compare, bogota1_phase4_high_compare, bogota2_phase1_high_compare, bogota2_phase2_high_compare, bogota2_phase3_high_compare, bogota2_phase4_high_compare, bogota3_phase1_high_compare, bogota3_phase2_high_compare, bogota3_phase3_high_compare, bogota3_phase4_high_compare], ignore_index = True)
high_compare_overall
# Out:
#            user1               user2  user1_phase  user2_phase  similarity  \
# 0    juandavidro           fffeelipe            1            2    0.068027
# 1    juandavidro           mnguzmanc            1            2    0.101449
# 2    juandavidro          jmcuestasb            1            2    0.077778
# 3    juandavidro          katherinsb            1            2    0.000000
# 4    juandavidro        jjrodriguezn            1            2    0.042857
# ..           ...                 ...          ...          ...         ...
# 619    juligarji          NicolasPrr            4            5    0.009360
# 620    juligarji       jumcorredorro            4            5    0.013294
# 621    juligarji          feartheGru            4            5    0.000000
# 622    juligarji        Danielsv9207            4            5    0.000000
# 623    juligarji  JhonEmmanuelTorres            4            5    0.000000
#
#      phase  group
# 0        1      0
# 1        1      0
# ...

# %%
high_compare_b3 = pd.concat([bogota3_phase1_high_compare, bogota3_phase2_high_compare, bogota3_phase3_high_compare, bogota3_phase4_high_compare], ignore_index = True)
high_compare_b3.reset_index()
# Out:
#      index       user1               user2  user1_phase  user2_phase  \
# 0        0  jmalvarezd           lemartinp            1            2
# 1        1  jmalvarezd           juligarji            1            2
# 2        2  jmalvarezd           nfmorenog            1            2
# 3        3  jmalvarezd           AFelipeGA            1            2
# 4        4  jmalvarezd          mballeng91            1            2
# ..     ...         ...                 ...          ...          ...
# 155    155   juligarji          NicolasPrr            4            5
# 156    156   juligarji       jumcorredorro            4            5
# 157    157   juligarji          feartheGru            4            5
# 158    158   juligarji        Danielsv9207            4            5
# 159    159   juligarji  JhonEmmanuelTorres            4            5
#
#      similarity  phase  group
# 0      0.146341      1      3
# 1      0.057325      1      3
# 2      0.190476      1      3
# ...

# %%
high_compare_b2 = pd.concat([bogota2_phase1_high_compare, bogota2_phase2_high_compare, bogota2_phase3_high_compare, bogota2_phase4_high_compare], ignore_index = True)
high_compare_b2.reset_index()
# Out:
#      index      user1         user2  user1_phase  user2_phase  similarity  \
# 0        0  xdanielsb  jusherrerama            1            2    0.022599
# 1        1  xdanielsb       bdvegat            1            2    0.018072
# 2        2  xdanielsb    Phoenixest            1            2    0.017964
# 3        3  xdanielsb      HashNick            1            2    0.028302
# 4        4  xdanielsb       ccvacad            1            2    0.000000
# ..     ...        ...           ...          ...          ...         ...
# 155    155  fabianr23      lsfinite            4            5    0.008392
# 156    156  fabianr23     xdanielsb            4            5    0.040128
# 157    157  fabianr23   CSebasGomez            4            5    0.000000
# 158    158  fabianr23   jhcardenasa            4            5    0.000000
# 159    159  fabianr23  jscontrerasp            4            5    0.054455
#
#      phase  group
# 0        1      2
# 1        1      2
# 2        1      2
# ...

# %%
high_compare_b1 = pd.concat([bogota1_phase1_high_compare, bogota1_phase2_high_compare, bogota1_phase3_high_compare, bogota1_phase4_high_compare], ignore_index = True)
high_compare_b1.reset_index()
# Out:
#      index    user1           user2  user1_phase  user2_phase  similarity  \
# 0        0  gcantem       gasierram            1            2    0.111111
# 1        1  gcantem    adamantwharf            1            2    0.026549
# 2        2  gcantem       bdcajicam            1            2    0.026549
# 3        3  gcantem  andfsanchezlem            1            2    0.000000
# 4        4  gcantem     dfhincapiem            1            2    0.026316
# ..     ...      ...             ...          ...          ...         ...
# 151    151   oeroaq        jcrubioa            4            5    0.025527
# 152    152   oeroaq  joahernandezca            4            5    0.016976
# 153    153   oeroaq         ItsNavi            4            5    0.000000
# 154    154   oeroaq         Zeugmax            4            5    0.000000
# 155    155   oeroaq    JairVillalba            4            5    0.010520
#
#      phase  group
# 0        1      1
# 1        1      1
# 2        1      1
# ...

# %%
high_compare_b0 = pd.concat([bogota0_phase1_high_compare, bogota0_phase2_high_compare, bogota0_phase3_high_compare, bogota0_phase4_high_compare], ignore_index = True)
high_compare_b0.reset_index()
# Out:
#      index        user1         user2  user1_phase  user2_phase  similarity  \
# 0        0  juandavidro     fffeelipe            1            2    0.068027
# 1        1  juandavidro     mnguzmanc            1            2    0.101449
# 2        2  juandavidro    jmcuestasb            1            2    0.077778
# 3        3  juandavidro    katherinsb            1            2    0.000000
# 4        4  juandavidro  jjrodriguezn            1            2    0.042857
# ..     ...          ...           ...          ...          ...         ...
# 143    143    bsgarciac      jcneivaa            4            5    0.000000
# 144    144    bsgarciac     fmbernalb            4            5    0.000000
# 145    145    bsgarciac       MogGy94            4            5    0.000000
# 146    146    bsgarciac     yocuervoc            4            5    0.000000
# 147    147    bsgarciac     odprietoh            4            5    0.000000
#
#      phase  group
# 0        1      0
# ...

# %%
## Concat dataframe for relational novelty

pd.set_option('display.max_rows', None)
novelty = pd.concat([stage1_bogota3_high_similarity, stage2_bogota3_high_similarity, stage3_bogota3_high_similarity, stage4_bogota3_high_similarity, 
             stage1_bogota2_high_similarity, stage2_bogota2_high_similarity, stage3_bogota2_high_similarity, stage4_bogota2_high_similarity, 
             stage1_bogota1_high_similarity, stage2_bogota1_high_similarity, stage3_bogota1_high_similarity, stage4_bogota1_high_similarity, 
             stage1_bogota0_high_similarity, stage2_bogota0_high_similarity, stage3_bogota0_high_similarity, stage4_bogota0_high_similarity], ignore_index = True)
novelty = novelty.reset_index()
novelty = novelty.rename({'user2': 'Student', 'user1_phase': 'phase'}, axis=1) 
novelty
# Out:
#      index               user1             Student  phase  user2_phase  \
# 0        0  JhonEmmanuelTorres        Danielsv9207      1            2
# 1        1  JhonEmmanuelTorres          feartheGru      1            2
# 2        2  JhonEmmanuelTorres           jdmonroyg      1            2
# 3        3  JhonEmmanuelTorres        wilson911013      1            2
# 4        4        Danielsv9207  JhonEmmanuelTorres      1            2
# 5        5             DavidQP            capinzor      1            2
# 6        6            ofnanezn           srmedinac      1            2
# 7        7            capinzor              spenas      1            2
# 8        8           srmedinac            adriel62      1            2
# 9        9            davidh17           macuestap      1            2
# 10      10         oacastillol           afforeroc      1            2
# 11      11            capinzor             DavidQP      1            2
# ...

# %%
## Concat dataframe for similarity with best
similarity_with_best = pd.concat([high_compare_b0,high_compare_b1, high_compare_b2, high_compare_b3], ignore_index = True)
similarity_with_best = similarity_with_best.reset_index()
similarity_with_best = similarity_with_best.rename({'user2': 'Student'}, axis=1)

# %%
## Concat dataframe for performance distance with best
perform_dist = pd.concat([p1, p2, p3, p4, p5], ignore_index = True)
perform_dist.reset_index()
# Out:
#      index             Student  group  abs_perform_diff_best  phase
# 0        0           fffeelipe      0                 201.66      1
# 1        1           mnguzmanc      0                 213.33      1
# 2        2          jmcuestasb      0                 250.83      1
# 3        3          katherinsb      0                 300.83      1
# 4        4        jjrodriguezn      0                 300.83      1
# 5        5               DglyP      0                 300.83      1
# 6        6              cap182      0                 152.50      1
# 7        7         annumumozme      0                 263.33      1
# 8        8         Judgarciani      0                 300.83      1
# 9        9           sacastroc      0                 225.83      1
# 10      10           pcberriop      0                 223.33      1
# 11      11         hsmartineza      0                 300.83      1
# 12      12            Moimolcp      0                 275.83      1
# ...

# %%
pd.set_option('display.max_rows', None)
perform_dist = pd.merge(perform_dist, survey, how='left', left_on='Student', right_on ='user2')
perform_dist = perform_dist[perform_dist['phase'] != 5]
perform_dist
# Out:
#                 Student  group  abs_perform_diff_best  phase  \
# 0             fffeelipe      0                 201.66      1
# 1             mnguzmanc      0                 213.33      1
# 2            jmcuestasb      0                 250.83      1
# 3            katherinsb      0                 300.83      1
# 4          jjrodriguezn      0                 300.83      1
# 5                 DglyP      0                 300.83      1
# 6                cap182      0                 152.50      1
# 7           annumumozme      0                 263.33      1
# 8           Judgarciani      0                 300.83      1
# 9             sacastroc      0                 225.83      1
# 10            pcberriop      0                 223.33      1
# 11          hsmartineza      0                 300.83      1
# 12             Moimolcp      0                 275.83      1
# 13          CamiloRueda      0                 300.83      1
# ...

# %%
df_merged = pd.merge(novelty[['Student', 'phase', 'novelty']], perform_dist, on=['Student', 'phase'], how='outer')
df_merged['novelty'] = df_merged['novelty'].fillna(0)

# %%
df_merged.to_csv('novelty_complete.csv')

# %%
perform_dist_b3 = perform_dist[perform_dist['group'] == 3]
perform_dist_b3.drop('user2', inplace=True, axis=1)
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1881/3795420823.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perform_dist_b3.drop('user2', inplace=True, axis=1)

# %%
perform_dist_b2 = perform_dist[perform_dist['group'] == 2]
perform_dist_b2.drop('user2', inplace=True, axis=1)
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_1881/2361742440.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   perform_dist_b2.drop('user2', inplace=True, axis=1)

# %%
perform_dist_high_compare_b3 = pd.merge(perform_dist_b3, high_compare_b3[['user2', 'similarity', 'group','phase']], how='left', left_on=['Student', 'phase', 'group'], right_on =['user2', 'phase', 'group'])
perform_dist_high_compare_b3 = perform_dist_high_compare_b3[perform_dist_high_compare_b3.phase != 5]
perform_dist_high_compare_b3.drop('user2', axis = 1, inplace=True)

# %%
high_compare_b2.rename(columns={'user2': 'Student'}, inplace=True)
pd.set_option('display.max_rows', None)
high_compare_b2
# Out:
#          user1          Student  user1_phase  user2_phase  similarity  phase  \
# 0    xdanielsb     jusherrerama            1            2    0.022599      1
# 1    xdanielsb          bdvegat            1            2    0.018072      1
# 2    xdanielsb       Phoenixest            1            2    0.017964      1
# 3    xdanielsb         HashNick            1            2    0.028302      1
# 4    xdanielsb          ccvacad            1            2    0.000000      1
# 5    xdanielsb       joaortizro            1            2    0.041420      1
# 6    xdanielsb  juasmartinezbel            1            2    0.034884      1
# 7    xdanielsb         mdbelloc            1            2    0.028302      1
# 8    xdanielsb      diegocruz10            1            2    0.037838      1
# 9    xdanielsb       crarojasca            1            2    0.000000      1
# 10   xdanielsb           sagilm            1            2    0.017964      1
# ...

# %%
perform_dist_b2 = perform_dist_b2[perform_dist_b2['phase'] != 5]
pd.set_option('display.max_rows', None)
perform_dist_b2
# Out:
#              Student  group  abs_perform_diff_best  phase  Q7_Q7_1  Q7_Q7_2  \
# 81      jusherrerama      2                 177.50      1      NaN      NaN
# 82           bdvegat      2                 260.00      1      1.0      2.0
# 83        Phoenixest      2                 185.83      1      0.0      1.0
# 84          HashNick      2                 260.00      1      1.0      3.0
# 85           ccvacad      2                 260.00      1      1.0      0.0
# 86        joaortizro      2                 152.50      1      0.0      2.0
# 87   juasmartinezbel      2                   8.33      1      0.0      5.0
# 88          mdbelloc      2                 168.33      1      1.0      3.0
# 89       diegocruz10      2                 169.17      1      3.0      3.0
# 90        crarojasca      2                 215.00      1      1.0      3.0
# 91            sagilm      2                 210.00      1      0.0      0.0
# ...

# %%
perform_dist_high_compare_b2 = pd.merge(perform_dist_b2, high_compare_b2[['Student', 'similarity', 'group','phase']], how='left', left_on=['Student', 'phase', 'group'], right_on =['Student', 'phase', 'group'])
#perform_dist_high_compare_b2 = perform_dist_high_compare_b2[perform_dist_high_compare_b2.phase != 5]
pd.set_option('display.max_rows', None)
perform_dist_high_compare_b2
# Out:
#              Student  group  abs_perform_diff_best  phase  Q7_Q7_1  Q7_Q7_2  \
# 0       jusherrerama      2                 177.50      1      NaN      NaN
# 1            bdvegat      2                 260.00      1      1.0      2.0
# 2         Phoenixest      2                 185.83      1      0.0      1.0
# 3           HashNick      2                 260.00      1      1.0      3.0
# 4            ccvacad      2                 260.00      1      1.0      0.0
# 5         joaortizro      2                 152.50      1      0.0      2.0
# 6    juasmartinezbel      2                   8.33      1      0.0      5.0
# 7           mdbelloc      2                 168.33      1      1.0      3.0
# 8        diegocruz10      2                 169.17      1      3.0      3.0
# 9         crarojasca      2                 215.00      1      1.0      3.0
# 10            sagilm      2                 210.00      1      0.0      0.0
# ...

# %%
perform_dist_high_compare_b2.to_csv('perform_dist_high_compare_b2.csv')
perform_dist_high_compare_b3.to_csv('perform_dist_high_compare_b3.csv')

# %%
# store performance distance dataframe to be used in individual exploration 

# %store perform_dist
# %store perform_dist_high_compare_b3
# Out:
# Stored 'perform_dist' (DataFrame)
# Stored 'perform_dist_high_compare_b3' (DataFrame)

# %%
novelty_b2_p1 = pd.merge(perform_dist_high_compare_b2, stage1_bogota2_high_similarity[['user2', 'novelty']], how='left', left_on=['Student'], right_on =['user2'])
novelty_b2_p1 = novelty_b2_p1[novelty_b2_p1['phase'] == 1]
novelty_b2_p1
# Out:
#             Student  group  abs_perform_diff_best  phase  Q7_Q7_1  Q7_Q7_2  \
# 0      jusherrerama      2                 177.50      1      NaN      NaN
# 1           bdvegat      2                 260.00      1      1.0      2.0
# 2        Phoenixest      2                 185.83      1      0.0      1.0
# 3          HashNick      2                 260.00      1      1.0      3.0
# 4           ccvacad      2                 260.00      1      1.0      0.0
# 5        joaortizro      2                 152.50      1      0.0      2.0
# 6   juasmartinezbel      2                   8.33      1      0.0      5.0
# 7          mdbelloc      2                 168.33      1      1.0      3.0
# 8       diegocruz10      2                 169.17      1      3.0      3.0
# 9        crarojasca      2                 215.00      1      1.0      3.0
# 10           sagilm      2                 210.00      1      0.0      0.0
# ...

# %%
import seaborn as sns
sns.regplot(novelty_b2_p1['abs_perform_diff_best'], novelty_b2_p1['novelty']).set(title='Phase 1 Performance Distance vs Relational Novelty - Solution Transparency')
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Phase 1 Performance Distance vs Relational Novelty - Solution Transparency')]

# %%
novelty_b2_p2 = pd.merge(perform_dist_high_compare_b2, stage2_bogota2_high_similarity[['user2', 'novelty']], how='left', left_on=['Student'], right_on =['user2'])
novelty_b2_p2 = novelty_b2_p2[novelty_b2_p2['phase'] == 2]
novelty_b2_p2
# Out:
#             Student  group  abs_perform_diff_best  phase  Q7_Q7_1  Q7_Q7_2  \
# 42     jusherrerama      2                 168.33      2      NaN      NaN
# 43          bdvegat      2                 235.00      2      1.0      2.0
# 44       Phoenixest      2                 218.33      2      0.0      1.0
# 45         HashNick      2                 221.67      2      1.0      3.0
# 46          ccvacad      2                 317.50      2      1.0      0.0
# 47       joaortizro      2                  61.67      2      0.0      2.0
# 48  juasmartinezbel      2                  33.33      2      0.0      5.0
# 49         mdbelloc      2                 205.00      2      1.0      3.0
# 50      diegocruz10      2                 201.67      2      3.0      3.0
# 51       crarojasca      2                 272.50      2      1.0      3.0
# 52           sagilm      2                 259.17      2      0.0      0.0
# ...

# %%
sns.regplot(novelty_b2_p2['abs_perform_diff_best'], novelty_b2_p2['novelty']).set(title='Phase 2 Performance Distance vs Relational Novelty - Solution Transparency')
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Phase 2 Performance Distance vs Relational Novelty - Solution Transparency')]

# %%
novelty_b2_p3 = pd.merge(perform_dist_high_compare_b2, stage3_bogota2_high_similarity[['user2', 'novelty']], how='left', left_on=['Student'], right_on =['user2'])
novelty_b2_p3 = novelty_b2_p3[novelty_b2_p3['phase'] == 3]
novelty_b2_p3
# Out:
#              Student  group  abs_perform_diff_best  phase  Q7_Q7_1  Q7_Q7_2  \
# 84      jusherrerama      2                 238.33      3      NaN      NaN
# 85           bdvegat      2                 263.33      3      1.0      2.0
# 86        Phoenixest      2                 263.33      3      0.0      1.0
# 87          HashNick      2                 255.00      3      1.0      3.0
# 88           ccvacad      2                 358.33      3      1.0      0.0
# 89        joaortizro      2                  53.33      3      0.0      2.0
# 90   juasmartinezbel      2                  65.00      3      0.0      5.0
# 91          mdbelloc      2                 225.00      3      1.0      3.0
# 92       diegocruz10      2                 246.66      3      3.0      3.0
# 93        crarojasca      2                 313.33      3      1.0      3.0
# 94            sagilm      2                 212.50      3      0.0      0.0
# ...

# %%
sns.regplot(novelty_b2_p3['abs_perform_diff_best'], novelty_b2_p3['novelty']).set(title='Phase 3 Performance Distance vs Relational Novelty - Solution Transparency')
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Phase 3 Performance Distance vs Relational Novelty - Solution Transparency')]

# %%
novelty_b2_p4 = pd.merge(perform_dist_high_compare_b2, stage4_bogota2_high_similarity[['user2', 'novelty']], how='left', left_on=['Student'], right_on =['user2'])
novelty_b2_p4 = novelty_b2_p4[novelty_b2_p4['phase'] == 4]
novelty_b2_p4
# Out:
#              Student  group  abs_perform_diff_best  phase  Q7_Q7_1  Q7_Q7_2  \
# 126     jusherrerama      2                 250.83      4      NaN      NaN
# 127          bdvegat      2                 263.33      4      1.0      2.0
# 128       Phoenixest      2                 263.33      4      0.0      1.0
# 129         HashNick      2                 226.66      4      1.0      3.0
# 130          ccvacad      2                 358.33      4      1.0      0.0
# 131       joaortizro      2                  78.33      4      0.0      2.0
# 132  juasmartinezbel      2                  37.50      4      0.0      5.0
# 133         mdbelloc      2                 229.16      4      1.0      3.0
# 134      diegocruz10      2                 251.66      4      3.0      3.0
# 135       crarojasca      2                 313.33      4      1.0      3.0
# 136           sagilm      2                 208.33      4      0.0      0.0
# ...

# %%
sns.regplot(novelty_b2_p4['abs_perform_diff_best'], novelty_b2_p4['novelty']).set(title='Phase 4 Performance Distance vs Relational Novelty - Solution Transparency')
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Phase 4 Performance Distance vs Relational Novelty - Solution Transparency')]

# %%
novelty_b3_p1 = pd.merge(perform_dist_high_compare_b3, stage1_bogota3_high_similarity[['user2', 'novelty']], how='left', left_on=['Student'], right_on =['user2'])
novelty_b3_p1 = novelty_b3_p1[novelty_b3_p1['phase'] == 1]
novelty_b3_p1
# Out:
#                Student  group  abs_perform_diff_best  phase  Q7_Q7_1  Q7_Q7_2  \
# 0            lemartinp      3                 270.84      1      0.0      0.0
# 1            juligarji      3                 167.50      1      4.0      4.0
# 2            nfmorenog      3                 225.00      1      0.0      2.0
# 3            AFelipeGA      3                 291.67      1      4.0      3.0
# 4           mballeng91      3                 329.17      1      2.0      6.0
# 5             dduartec      3                 287.50      1      1.0      5.0
# 6            srmedinac      3                 304.17      1      1.0      2.0
# 7         wilson911013      3                 250.84      1      0.0      1.0
# 8        wapiravaguens      3                  90.00      1      0.0      1.0
# 9             davidh17      3                 173.34      1      3.0      3.0
# 10      DianaNavarrete      3                 229.17      1      0.0      1.0
# ...

# %%
import seaborn as sns
sns.regplot(novelty_b3_p1['abs_perform_diff_best'], novelty_b3_p1['novelty']).set(title='Phase 1 Performance Distance vs Relational Novelty - Full Transparency')
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Phase 1 Performance Distance vs Relational Novelty - Full Transparency')]

# %%
novelty_b3_p2 = pd.merge(perform_dist_high_compare_b3, stage2_bogota3_high_similarity[['user2', 'novelty']], how='left', left_on=['Student'], right_on =['user2'])
novelty_b3_p2 = novelty_b3_p2[novelty_b3_p2['phase'] == 2]
novelty_b3_p2
# Out:
#                Student  group  abs_perform_diff_best  phase  Q7_Q7_1  Q7_Q7_2  \
# 41           lemartinp      3                 201.66      2      0.0      0.0
# 42           juligarji      3                  91.25      2      4.0      4.0
# 43           nfmorenog      3                 200.00      2      0.0      2.0
# 44           AFelipeGA      3                 180.83      2      4.0      3.0
# 45          mballeng91      3                 233.33      2      2.0      6.0
# 46            dduartec      3                   0.00      2      1.0      5.0
# 47           srmedinac      3                 217.50      2      1.0      2.0
# 48        wilson911013      3                 242.50      2      0.0      1.0
# 49       wapiravaguens      3                 140.83      2      0.0      1.0
# 50            davidh17      3                  87.50      2      3.0      3.0
# 51      DianaNavarrete      3                 205.00      2      0.0      1.0
# ...

# %%
sns.regplot(novelty_b3_p2['abs_perform_diff_best'], novelty_b3_p2['novelty']).set(title='Phase 2 Performance Distance vs Relational Novelty - Full Transparency')
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Phase 2 Performance Distance vs Relational Novelty - Full Transparency')]

# %%
novelty_b3_p3 = pd.merge(perform_dist_high_compare_b3, stage3_bogota3_high_similarity[['user2', 'novelty']], how='left', left_on=['Student'], right_on =['user2'])
novelty_b3_p3 = novelty_b3_p3[novelty_b3_p3['phase'] == 3]
novelty_b3_p3
# Out:
#                 Student  group  abs_perform_diff_best  phase  Q7_Q7_1  \
# 82            lemartinp      3                 193.33      3      0.0
# 83            juligarji      3                 126.67      3      4.0
# 84            nfmorenog      3                 196.67      3      0.0
# 85            AFelipeGA      3                 177.50      3      4.0
# 86           mballeng91      3                 230.00      3      2.0
# 87             dduartec      3                  25.00      3      1.0
# 88            srmedinac      3                 214.17      3      1.0
# 89         wilson911013      3                 239.17      3      0.0
# 90        wapiravaguens      3                 137.50      3      0.0
# 91             davidh17      3                 109.17      3      3.0
# 92       DianaNavarrete      3                 182.50      3      0.0
# 93            jdmonroyg      3                 330.00      3      0.0
# ...

# %%
sns.regplot(novelty_b3_p3['abs_perform_diff_best'], novelty_b3_p3['novelty']).set(title='Phase 3 Performance Distance vs Relational Novelty - Full Transparency')
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Phase 3 Performance Distance vs Relational Novelty - Full Transparency')]

# %%
novelty_b3_p4 = pd.merge(perform_dist_high_compare_b3, stage4_bogota3_high_similarity[['user2', 'novelty']], how='left', left_on=['Student'], right_on =['user2'])
novelty_b3_p4 = novelty_b3_p4[novelty_b3_p4['phase'] == 4]
novelty_b3_p4
# Out:
#                 Student  group  abs_perform_diff_best  phase  Q7_Q7_1  \
# 123           lemartinp      3                  57.50      4      0.0
# 124           juligarji      3                   0.00      4      4.0
# 125           nfmorenog      3                 237.50      4      0.0
# 126           AFelipeGA      3                 205.83      4      4.0
# 127          mballeng91      3                 245.83      4      2.0
# 128            dduartec      3                 270.83      4      1.0
# 129           srmedinac      3                 242.50      4      1.0
# 130        wilson911013      3                 275.83      4      0.0
# 131       wapiravaguens      3                 140.83      4      0.0
# 132            davidh17      3                 283.33      4      3.0
# 133      DianaNavarrete      3                 242.50      4      0.0
# 134           jdmonroyg      3                 358.33      4      0.0
# ...

# %%
sns.regplot(novelty_b3_p4['abs_perform_diff_best'], novelty_b3_p4['novelty']).set(title='Phase 4 Performance Distance vs Relational Novelty - Full Transparency')
# Out:
# /Users/jialincheoh/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Phase 4 Performance Distance vs Relational Novelty - Full Transparency')]

# %%
# %store novelty_b3_p1
# %store novelty_b3_p2
# %store novelty_b3_p3
# %store novelty_b3_p4

# %store novelty_b2_p1
# %store novelty_b2_p2
# %store novelty_b2_p3
# %store novelty_b2_p4

# %store high_compare_overall
# Out:
# Stored 'novelty_b3_p1' (DataFrame)
# Stored 'novelty_b3_p2' (DataFrame)
# Stored 'novelty_b3_p3' (DataFrame)
# Stored 'novelty_b3_p4' (DataFrame)
# Stored 'novelty_b2_p1' (DataFrame)
# Stored 'novelty_b2_p2' (DataFrame)
# Stored 'novelty_b2_p3' (DataFrame)
# Stored 'novelty_b2_p4' (DataFrame)
# Stored 'high_compare_overall' (DataFrame)
