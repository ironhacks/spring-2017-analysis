# %%
# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5
# %store -r df_template
# %store -r bogota_final

# %%
bogota_final['total-max-phase5'] = bogota_final.groupby(["Group"])['total-phase5'].transform(np.max)
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 159       jumcorredorro    3.0                    100.0           62.50
# 160          feartheGru    3.0                      0.0            0.00
# 161        Danielsv9207    3.0                      0.0            0.00
# 162  JhonEmmanuelTorres    3.0                      0.0            0.00
# 163          Januguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
bogota_best = bogota_final[bogota_final['total-max-phase1'] == bogota_final['total-phase1']]
bogota_best
# Out:
#          Student  Group  user-requirement-phase5  infovis-phase5  \
# 22   juandavidro    0.0                     20.0           58.33
# 50       gcantem    1.0                    100.0           70.83
# 117    xdanielsb    2.0                    100.0           87.50
# 151   jmalvarezd    3.0                     80.0           75.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 22            25.00        153.33         50.0         37.5
# 50            87.50        283.33         25.0        100.0
# 117           70.00        357.50        100.0         50.0
# 151           93.75        348.75        100.0         87.5
#
#      user-requirement-phase4  infovis-phase4  ...  perform_diff_best_phase1  \
# 22                      20.0           54.17  ...                       0.0
# 50                      60.0           29.17  ...                       0.0
# 117                      0.0           25.00  ...                       0.0
# ...

# %%
bogota_best = bogota_best.append(df_template, ignore_index=True)
bogota_best
# Out:
#        Student  Group  user-requirement-phase5  infovis-phase5  \
# 0  juandavidro    0.0                     20.0           58.33
# 1      gcantem    1.0                    100.0           70.83
# 2    xdanielsb    2.0                    100.0           87.50
# 3   jmalvarezd    3.0                     80.0           75.00
# 4     template    NaN                      NaN             NaN
#
#    novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0           25.00        153.33         50.0         37.5
# 1           87.50        283.33         25.0        100.0
# 2           70.00        357.50        100.0         50.0
# 3           93.75        348.75        100.0         87.5
# 4             NaN           NaN          NaN          NaN
#
#    user-requirement-phase4  infovis-phase4  ...  perform_diff_best_phase3  \
# 0                     20.0           54.17  ...                   -117.50
# 1                     60.0           29.17  ...                   -119.16
# ...
