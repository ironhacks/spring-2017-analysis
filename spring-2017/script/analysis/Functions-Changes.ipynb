# %%
# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn3_circles
from matplotlib_venn import venn2, venn2_circles

# %%
overall_phase5.rename(columns = {'unique':'uniquephase5'}, inplace = True)
overall_phase4.rename(columns = {'unique':'uniquephase4'}, inplace = True)
overall_phase3.rename(columns = {'unique':'uniquephase3'}, inplace = True)
overall_phase2.rename(columns = {'unique':'uniquephase2'}, inplace = True)
overall_phase1.rename(columns = {'unique':'uniquephase1'}, inplace = True)

# %%
df45 = pd.merge(overall_phase5, overall_phase4[['Student', 'Group', 'uniquephase4']], how='left', left_on=['Student', 'Group'], right_on =['Student', 'Group'] )
df45
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 159       jumcorredorro    3.0                    100.0           62.50
# 160          feartheGru    3.0                      0.0            0.00
# 161        Danielsv9207    3.0                      0.0            0.00
# 162  JhonEmmanuelTorres    3.0                      0.0            0.00
# 163          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df45 = df45[df45['uniquephase5'].notna()]
df45
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 159       jumcorredorro    3.0                    100.0           62.50
# 160          feartheGru    3.0                      0.0            0.00
# 161        Danielsv9207    3.0                      0.0            0.00
# 162  JhonEmmanuelTorres    3.0                      0.0            0.00
# 163          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df45["added45"] = df45.apply(lambda row: len(set(row.uniquephase5) - set(row.uniquephase4)), axis=1)
df45["deleted45"] = df45.apply(lambda row: len(set(row.uniquephase4) - set(row.uniquephase5)), axis=1)
df45
# Out:
# <ipython-input-5-f86bea143a11>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df45["added45"] = df45.apply(lambda row: len(set(row.uniquephase5) - set(row.uniquephase4)), axis=1)
# <ipython-input-5-f86bea143a11>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df45["deleted45"] = df45.apply(lambda row: len(set(row.uniquephase4) - set(row.uniquephase5)), axis=1)
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# ...

# %%
df45["func_add_45"] = df45.apply(lambda row: list(set(row.uniquephase5) - set(row.uniquephase4)), axis=1)
df45["func_delete_45"] = df45.apply(lambda row: list(set(row.uniquephase4) - set(row.uniquephase5)), axis=1)
df45
# Out:
# <ipython-input-6-078aebe69c9c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df45["func_add_45"] = df45.apply(lambda row: list(set(row.uniquephase5) - set(row.uniquephase4)), axis=1)
# <ipython-input-6-078aebe69c9c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df45["func_delete_45"] = df45.apply(lambda row: list(set(row.uniquephase4) - set(row.uniquephase5)), axis=1)
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# ...

# %%
df345 = pd.merge(df45, overall_phase3[['Student', 'Group', 'uniquephase3']], how='left', left_on=['Student', 'Group'], right_on =['Student', 'Group'] )
df345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df345["added34"] = df345.apply(lambda row: len(set(row.uniquephase4) - set(row.uniquephase3)), axis=1)
df345["deleted34"] = df345.apply(lambda row: len(set(row.uniquephase3) - set(row.uniquephase4)), axis=1)
df345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df345["func_add_34"] = df345.apply(lambda row: list(set(row.uniquephase4) - set(row.uniquephase3)), axis=1)
df345["func_delete_34"] = df345.apply(lambda row: list(set(row.uniquephase3) - set(row.uniquephase4)), axis=1)
df345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df2345 = pd.merge(df345, overall_phase2[['Student', 'Group', 'uniquephase2']], how='left', left_on=['Student', 'Group'], right_on =['Student', 'Group'] )
df2345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df2345["added23"] = df2345.apply(lambda row: len(set(row.uniquephase3) - set(row.uniquephase2)), axis=1)
df2345["deleted23"] = df2345.apply(lambda row: len(set(row.uniquephase2) - set(row.uniquephase3)), axis=1)
df2345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df2345["func_add_23"] = df2345.apply(lambda row: list(set(row.uniquephase3) - set(row.uniquephase2)), axis=1)
df2345["func_delete_23"] = df2345.apply(lambda row: list(set(row.uniquephase2) - set(row.uniquephase3)), axis=1)
df2345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df12345 = pd.merge(df2345, overall_phase1[['Student', 'Group', 'uniquephase1']], how='left', left_on=['Student', 'Group'], right_on =['Student', 'Group'] )
df12345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df12345["added12"] = df12345.apply(lambda row: len(set(row.uniquephase2) - set(row.uniquephase1)), axis=1)
df12345["deleted12"] = df12345.apply(lambda row: len(set(row.uniquephase1) - set(row.uniquephase2)), axis=1)
df12345 = df12345.fillna(0)
df12345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    0.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %%
df12345["func_add_12"] = df12345.apply(lambda row: list(set(row.uniquephase2) - set(row.uniquephase1)), axis=1)
df12345["func_delete_12"] = df12345.apply(lambda row: list(set(row.uniquephase1) - set(row.uniquephase2)), axis=1)
df12345 = df12345.fillna(0)
df12345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155       jumcorredorro    3.0                    100.0           62.50
# 156          feartheGru    3.0                      0.0            0.00
# 157        Danielsv9207    3.0                      0.0            0.00
# 158  JhonEmmanuelTorres    3.0                      0.0            0.00
# 159          janoguerab    0.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# ...

# %% [markdown]
# ## Group 0 Stage 1

# %%
df12345_group0 = df12345[df12345['Group'] == 0]
df12345_group0_list = df12345_group0['func_add_12'].explode().to_list()
len(df12345_group0_list)
# Out:
# 8125

# %% [markdown]
# ## Group 1 Stage 1

# %%
df12345_group1 = df12345[df12345['Group'] == 1]
df12345_group1_list = df12345_group1['func_add_12'].explode().to_list()
len(df12345_group1_list)
# Out:
# 5087

# %% [markdown]
# ## Group 2 Stage 1

# %%
df12345_group2 = df12345[df12345['Group'] == 2]
df12345_group2_list = df12345_group2['func_add_12'].explode().to_list()
len(df12345_group2_list)
# Out:
# 4740

# %% [markdown]
# ## Group 3 Stage 1

# %%
df12345_group3 = df12345[df12345['Group'] == 3]
df12345_group3_list = df12345_group3['func_add_12'].explode().to_list()
len(df12345_group3_list)
# Out:
# 2667

# %%
df12345 = df12345['func_add_12'].explode().to_list()
len(df12345)
# Out:
# 20619

# %%
venn3([set(df12345_group1_list), set(df12345_group2_list), set(df12345_group3_list)],
      set_colors=('#3E64AF', '#3EAF5D', '#D74E3B'), 
      set_labels = ('Performance Transparency', 'Solution Transparency',
                    'Full Transparency'), alpha=0.75)
venn3_circles([set(df12345_group1_list), set(df12345_group2_list), set(df12345_group3_list)], lw=0.7)
 
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/matplotlib_venn/_venn3.py:117: UserWarning: Bad circle positioning
#   warnings.warn("Bad circle positioning")

# %%
labels = ['No Transparency',
          'Performance Transparency', 
          'Solution Transparency',
          'Full Transparency']

# %%
from venn import venn
sets = {
    labels[0]: set(df12345_group0_list),
    labels[1]: set(df12345_group1_list),
    labels[2]: set(df12345_group2_list),
    labels[3]: set(df12345_group3_list)
}
fig, ax = plt.subplots(1, figsize=(16,12))
venn(sets, ax=ax)
plt.legend(labels[:], ncol=6)

# %% [markdown]
# ## Group 0 Stage 2

# %%
df2345_group0 = df2345[df2345['Group'] == 0]
df2345_group0_list = df2345_group0['func_add_23'].explode().to_list()
len(df2345_group0_list)
# Out:
# 583

# %% [markdown]
# ## Group 1 Stage 2

# %%
df2345_group1 = df2345[df2345['Group'] == 1]
df2345_group1_list = df2345_group1['func_add_23'].explode().to_list()
len(df2345_group1_list)
# Out:
# 940

# %% [markdown]
# ## Group 2 Stage 2

# %%
df2345_group2 = df2345[df2345['Group'] == 2]
df2345_group2_list = df2345_group2['func_add_23'].explode().to_list()
len(df2345_group2_list)
# Out:
# 2598

# %% [markdown]
# ## Group 3 Stage 2

# %%
df2345_group3 = df2345[df2345['Group'] == 3]
df2345_group3_list = df2345_group3['func_add_23'].explode().to_list()
len(df2345_group3_list)
# Out:
# 3185

# %%
df2345 = df2345['func_add_23'].explode().to_list()
df2345
# Out:
# [nan,
#  nan,
#  'coma.length',
#  'xmlDoc.getElementsByTagName',
#  'rzestimate.childNodes',
#  'amount.childNodes',
#  '.serializeToString',
#  'currentdate.getFullYear',
#  '.firstChild.nodeValue',
#  'currentdate.getDate',
#  'xmlhttp.responseXML',
#  'currentdate.getMonth',
#  'rows.rdf',
#  '.setMap',
#  'google.maps.event.addListener',
#  'data.date',
#  'marker.get',
#  'x.className.replace',
#  'showCrimes.js',
#  'crimeMarker.push',
#  'infowindow.open',
#  'xi.json',
#  'data.description',
#  'x.className.indexOf',
#  '.primary',
#  'data.primary',
#  'google.maps.InfoWindow',
#  'infowindow.setContent',
#  'data.year',
#  'crimeMarker.length',
#  'infowindow.close',
#  nan,
#  nan,
#  nan,
#  nan,
#  'site.js',
#  'profile.css',
#  'google.maps.Map',
#  'rid.css',
#  'google.maps.Marker',
#  'document.getElementById',
#  nan,
#  nan,
#  '.click',
#  'location.hash.substr',
#  'x.hide',
#  'controlUI.innerHTML',
#  '.scrollTop',
#  'config.target.removeClass',
# ...

# %%
from venn import venn
sets = {
    labels[0]: set(df2345_group0_list),
    labels[1]: set(df2345_group1_list),
    labels[2]: set(df2345_group2_list),
    labels[3]: set(df2345_group3_list)
}
fig, ax = plt.subplots(1, figsize=(16,12))
venn(sets, ax=ax)
plt.legend(labels[:], ncol=6)

# %% [markdown]
# ## Group 0 Stage 3

# %%
df345_group0 = df345[df345['Group'] == 0]
df345_group0_list = df345_group0['func_add_34'].explode().to_list()
len(df345_group0_list)
# Out:
# 3450

# %% [markdown]
# ## Group 1 Stage 3

# %%
df345_group1 = df345[df345['Group'] == 1]
df345_group1_list = df345_group1['func_add_34'].explode().to_list()
len(df345_group1_list)
# Out:
# 3118

# %% [markdown]
# ## Group 2 Stage 3

# %%
df345_group2 = df345[df345['Group'] == 2]
df345_group2_list = df345_group2['func_add_34'].explode().to_list()
len(df345_group2_list)
# Out:
# 4492

# %% [markdown]
# ## Group 3 Stage 3

# %%
df345_group3 = df345[df345['Group'] == 3]
df345_group3_list = df345_group3['func_add_34'].explode().to_list()
len(df345_group3_list)
# Out:
# 2725

# %%
from venn import venn
sets = {
    labels[0]: set(df345_group0_list),
    labels[1]: set(df345_group1_list),
    labels[2]: set(df345_group2_list),
    labels[3]: set(df345_group3_list)
}
fig, ax = plt.subplots(1, figsize=(16,12))
venn(sets, ax=ax)
plt.legend(labels[:], ncol=6)

# %% [markdown]
# ## Group 0 Stage 4

# %%
df45_group0 = df45[df45['Group'] == 0]
df45_group0_list = df45_group0['func_add_45'].explode().to_list()
len(df45_group0_list)
# Out:
# 4346

# %% [markdown]
# ## Group 1 Stage 4

# %%
df45_group1 = df45[df45['Group'] == 1]
df45_group1_list = df45_group1['func_add_45'].explode().to_list()
len(df45_group1_list)
# Out:
# 4671

# %% [markdown]
# ## Group 2 Stage 4

# %%
df45_group2 = df45[df45['Group'] == 2]
df45_group2_list = df45_group2['func_add_45'].explode().to_list()
len(df45_group2_list)
# Out:
# 339

# %% [markdown]
# ## Group 3 Stage 4

# %%
df45_group3 = df45[df45['Group'] == 3]
df45_group3_list = df45_group3['func_add_45'].explode().to_list()
len(df45_group3_list)
# Out:
# 2883

# %%
df345 = df345['func_add_34'].explode().to_list()
df345
# Out:
# [nan,
#  nan,
#  '.v',
#  'infowindow.open',
#  '.generate',
#  'rows.xml',
#  'json.data.length',
#  '.min.js',
#  '.css',
#  'google.maps.InfoWindow',
#  'js.org',
#  'x.json',
#  'RestaurantMarker.push',
#  'data.dba',
#  'showRestaurants.js',
#  'roomMarker.push',
#  '.each',
#  'console.log',
#  'Math.atan',
#  '.append',
#  'Math.cos',
#  '.getJSON',
#  'result.data',
#  '.classList.toggle',
#  'Math.sin',
#  'Math.sqrt',
#  'Math.PI',
#  nan,
#  nan,
#  'google.maps.LatLng',
#  'bootstrap.min.js',
#  '.jumbotron',
#  '.panel',
#  'marker.setMap',
#  'unal.edu.co',
#  '.navbar',
#  '.logo',
#  'google.maps.MapTypeId.ROADMAP',
#  '.jpg',
#  '.item',
#  'jquery.min.js',
#  'bootstrap.min.css',
#  'google.maps.Marker',
#  '.container',
#  'li.active',
#  'resolution.jpg',
#  '.thumbnail',
#  '.sidenav',
#  nan,
#  'in.css',
#  'host.css',
#  'document.getElementsByClassName',
#  'event.target',
#  'modal.style.display',
#  'window.onclick',
#  'span.onclick',
#  'profile.js',
# ...

# %%
df45 = df45['func_add_45'].explode().to_list()
df45
# Out:
# [nan,
#  nan,
#  'markers.length',
#  'markersp.length',
#  '.checked',
#  '.setMap',
#  nan,
#  nan,
#  nan,
#  nan,
#  'this.type',
#  'fire.push',
#  'coordinates.push',
#  'xmlhttp.send',
#  'JSON.parse',
#  'stations.length',
#  'google.maps.InfoWindow',
#  'fire.length',
#  'this.tel',
#  'this.location',
#  'libraries.length',
#  'json.data',
#  'this.zip',
#  'infoWindow.open',
#  'data.json',
#  '.glyphicon',
#  'stations.push',
#  'xmlhttp.onreadystatechange',
#  'google.maps.Size',
#  'xmlhttp.status',
#  'hospitals.push',
#  'this.date',
#  'xmlhttp.readyState',
#  'data.cityofchicago.org',
#  'hospitals.length',
#  'google.maps.event.addListener',
#  'this.hours',
#  'crime.length',
#  'casa.jpg',
#  'xmlhttp.open',
#  'infowindow.setContent',
#  'this.title',
#  'archivo.jpg',
#  'this.url',
#  'ladron.jpg',
#  'this.address',
#  'infowindow.open',
#  'libraries.push',
#  'infoWindow.setContent',
#  'rows.json',
#  'coordinates.length',
#  'crime.push',
# ...

# %%
from venn import venn
sets = {
    labels[0]: set(df45_group0_list),
    labels[1]: set(df45_group1_list),
    labels[2]: set(df45_group2_list),
    labels[3]: set(df45_group3_list)
}
fig, ax = plt.subplots(1, figsize=(16,12))
venn(sets, ax=ax)
plt.legend(labels[:], ncol=6)

# %%
df_12 = df12345[['Student', 'Group','added12']]
df_23 = df2345[['Student', 'Group','added23']]
df_34 = df345[['Student', 'Group','added34']]
df_45 = df45[['Student', 'Group','added45']]

df_12.rename(columns = {'added12':'added_sum'}, inplace = True)
df_23.rename(columns = {'added23':'added_sum'}, inplace = True)
df_34.rename(columns = {'added34':'added_sum'}, inplace = True)
df_45.rename(columns = {'added45':'added_sum'}, inplace = True)

df_12['phase'] = 1
df_23['phase'] = 2
df_34['phase'] = 3
df_45['phase'] = 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-2e35286df789> in <module>
# ----> 1 df_12 = df12345[['Student', 'Group','added12']]
#       2 df_23 = df2345[['Student', 'Group','added23']]
#       3 df_34 = df345[['Student', 'Group','added34']]
#       4 df_45 = df45[['Student', 'Group','added45']]
#       5
#
# TypeError: list indices must be integers or slices, not list

# %%
df12345[['added12']]

# %%
df = df_12.append([df_23, df_34, df_45], ignore_index = True)
df

# %%
df.to_csv('functions_added.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_rows', None)
#df = df.fillna(0)
#df

# %%
df_g0 = df[df['Group'] == 0]
df_g0['added_sum'].mean()

# %%
df_g0 = df[df['Group'] == 0]
df_g0['added_sum'].sum()

# %%
df_g1 = df[df['Group'] == 1]
df_g1['added_sum'].mean()

# %%
df_g1 = df[df['Group'] == 1]
df_g1['added_sum'].sum()

# %%
df_g2 = df[df['Group'] == 2]
df_g2['added_sum'].mean()

# %%
df_g3 = df[df['Group'] == 2]
df_g3['added_sum'].sum()

# %%
df_g3 = df[df['Group'] == 3]
df_g3['added_sum'].mean()

# %%
df_g3 = df[df['Group'] == 3]
df_g3['added_sum'].sum()

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.api import add_constant
from statsmodels.sandbox.regression.gmm import IV2SLS

df['ln_added_sum'] = np.log(df['added_sum'] + 1)

reg_expr = 'ln_added_sum ~ Group'
olsr_model = smf.ols(formula=reg_expr, data=df)
olsr_model_results = olsr_model.fit()
print(olsr_model_results.summary())

# %%
ln_len_added = df

# %store ln_len_added
