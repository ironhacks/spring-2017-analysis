# %%
# %store -r overall_phase1
# %store -r overall_phase2
# %store -r overall_phase3
# %store -r overall_phase4
# %store -r overall_phase5

import pandas as pd

# %%
overall_phase5.rename(columns = {'unique':'uniquephase5'}, inplace = True)
overall_phase4.rename(columns = {'unique':'uniquephase4'}, inplace = True)
overall_phase3.rename(columns = {'unique':'uniquephase3'}, inplace = True)
overall_phase2.rename(columns = {'unique':'uniquephase2'}, inplace = True)
overall_phase1.rename(columns = {'unique':'uniquephase1'}, inplace = True)

# %%
df45 = pd.merge(overall_phase5, overall_phase4[['Student', 'Group', 'uniquephase4']], how='left', left_on=['Student', 'Group'], right_on =['Student', 'Group'] )
df45
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 159       jumcorredorro    3.0                    100.0           62.50
# 160          feartheGru    3.0                      0.0            0.00
# 161        Danielsv9207    3.0                      0.0            0.00
# 162  JhonEmmanuelTorres    3.0                      0.0            0.00
# 163          Januguerab    NaN                      NaN             NaN
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 159           75.00        325.00         87.5         87.5
# 160            0.00          0.00          0.0          0.0
# 161            0.00          0.00          0.0          0.0
# 162            0.00          0.00          0.0          0.0
# 163             NaN           NaN          NaN          NaN
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-23  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...              -16.5
# 2                      100.0           58.33  ...                1.5
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...                8.0
# ..                       ...             ...  ...                ...
# 159                     80.0           58.33  ...               12.0
# 160                      0.0            0.00  ...                0.0
# 161                      0.0            0.00  ...                0.0
# 162                      0.0            0.00  ...                0.0
# 163                      NaN             NaN  ...                0.0
#
#      improve-effort-34  improve-effort-45  improve-effort-15  \
# 0                -14.0               -6.0              -32.5
# 1                 45.5               13.0              -29.0
# 2                  9.0               -4.0                7.0
# 3                  0.0               73.5                0.0
# 4                 60.5                0.5                0.0
# ..                 ...                ...                ...
# 159                1.0                1.0               11.5
# 160                0.0                0.0                0.0
# 161                0.0                0.0                0.0
# 162                0.0                0.0                0.0
# 163                0.0                0.0                0.0
#
#      improve-effort-25                                          functions  \
# 0                  0.0  [.ready, .click, .css, .removeClass, .is, .val...
# 1                -21.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2                -12.0  [js.org, .v, .min.js, weather.js, myss.css, bo...
# 3                  0.0  [reset.css, layout.css, style.css, jquery.min....
# 4                 34.5  [google.maps.Map, document.getElementById, goo...
# ..                 ...                                                ...
# 159               11.5  [jquery.min.js, bootstrap.min.js, .js, script....
# 160             -111.0                                                 []
# 161                0.0                                                 []
# 162                0.0                                                 []
# 163                NaN                                                NaN
#
#                                           uniquephase5  len_unique  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...       116.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2297.0
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...        67.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2290.0
# 4    [google.maps.Map, document.getElementById, goo...        31.0
# ..                                                 ...         ...
# 159  [jquery.min.js, bootstrap.min.js, .js, script....       181.0
# 160                                                 []         0.0
# 161                                                 []         0.0
# 162                                                 []         0.0
# 163                                                NaN         NaN
#
#      len_functions                                       uniquephase4
# 0            116.0  [.ready, .click, .removeClass, .is, .val, .che...
# 1           2297.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2             67.0  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3           2290.0  [reset.css, layout.css, style.css, .js, yui.js...
# 4             31.0  [google.maps.Map, document.getElementById, goo...
# ..             ...                                                ...
# 159          181.0  [jquery.min.js, bootstrap.min.js, .js, script....
# 160            0.0                                                 []
# 161            0.0                                                 []
# 162            0.0                                                 []
# 163            NaN                                                NaN
#
# [164 rows x 91 columns]

# %%
df45 = df45[df45['uniquephase5'].notna()]
df45
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 158          NicolasPrr    3.0                    100.0           83.33
# 159       jumcorredorro    3.0                    100.0           62.50
# 160          feartheGru    3.0                      0.0            0.00
# 161        Danielsv9207    3.0                      0.0            0.00
# 162  JhonEmmanuelTorres    3.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
# 160            0.00          0.00          0.0          0.0
# 161            0.00          0.00          0.0          0.0
# 162            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-23  \
# 0                       20.0           29.17  ...                0.0
# 1                       20.0           37.50  ...              -16.5
# 2                      100.0           58.33  ...                1.5
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...                8.0
# ..                       ...             ...  ...                ...
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...               12.0
# 160                      0.0            0.00  ...                0.0
# 161                      0.0            0.00  ...                0.0
# 162                      0.0            0.00  ...                0.0
#
#      improve-effort-34  improve-effort-45  improve-effort-15  \
# 0                -14.0               -6.0              -32.5
# 1                 45.5               13.0              -29.0
# 2                  9.0               -4.0                7.0
# 3                  0.0               73.5                0.0
# 4                 60.5                0.5                0.0
# ..                 ...                ...                ...
# 158              -36.5                0.0               16.5
# 159                1.0                1.0               11.5
# 160                0.0                0.0                0.0
# 161                0.0                0.0                0.0
# 162                0.0                0.0                0.0
#
#      improve-effort-25                                          functions  \
# 0                  0.0  [.ready, .click, .css, .removeClass, .is, .val...
# 1                -21.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2                -12.0  [js.org, .v, .min.js, weather.js, myss.css, bo...
# 3                  0.0  [reset.css, layout.css, style.css, jquery.min....
# 4                 34.5  [google.maps.Map, document.getElementById, goo...
# ..                 ...                                                ...
# 158               16.5  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159               11.5  [jquery.min.js, bootstrap.min.js, .js, script....
# 160             -111.0                                                 []
# 161                0.0                                                 []
# 162                0.0                                                 []
#
#                                           uniquephase5  len_unique  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...       116.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2297.0
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...        67.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2290.0
# 4    [google.maps.Map, document.getElementById, goo...        31.0
# ..                                                 ...         ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...       133.0
# 159  [jquery.min.js, bootstrap.min.js, .js, script....       181.0
# 160                                                 []         0.0
# 161                                                 []         0.0
# 162                                                 []         0.0
#
#      len_functions                                       uniquephase4
# 0            116.0  [.ready, .click, .removeClass, .is, .val, .che...
# 1           2297.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2             67.0  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3           2290.0  [reset.css, layout.css, style.css, .js, yui.js...
# 4             31.0  [google.maps.Map, document.getElementById, goo...
# ..             ...                                                ...
# 158          133.0  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159          181.0  [jquery.min.js, bootstrap.min.js, .js, script....
# 160            0.0                                                 []
# 161            0.0                                                 []
# 162            0.0                                                 []
#
# [160 rows x 91 columns]

# %%
df45["added45"] = df45.apply(lambda row: len(set(row.uniquephase5) - set(row.uniquephase4)), axis=1)
df45["deleted45"] = df45.apply(lambda row: len(set(row.uniquephase4) - set(row.uniquephase5)), axis=1)
df45
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_3155/3829132610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df45["added45"] = df45.apply(lambda row: len(set(row.uniquephase5) - set(row.uniquephase4)), axis=1)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_3155/3829132610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df45["deleted45"] = df45.apply(lambda row: len(set(row.uniquephase4) - set(row.uniquephase5)), axis=1)
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 158          NicolasPrr    3.0                    100.0           83.33
# 159       jumcorredorro    3.0                    100.0           62.50
# 160          feartheGru    3.0                      0.0            0.00
# 161        Danielsv9207    3.0                      0.0            0.00
# 162  JhonEmmanuelTorres    3.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 158           90.00        360.83         87.5         62.5
# 159           75.00        325.00         87.5         87.5
# 160            0.00          0.00          0.0          0.0
# 161            0.00          0.00          0.0          0.0
# 162            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-45  \
# 0                       20.0           29.17  ...               -6.0
# 1                       20.0           37.50  ...               13.0
# 2                      100.0           58.33  ...               -4.0
# 3                       20.0           45.83  ...               73.5
# 4                       40.0           54.17  ...                0.5
# ..                       ...             ...  ...                ...
# 158                      0.0           33.33  ...                0.0
# 159                     80.0           58.33  ...                1.0
# 160                      0.0            0.00  ...                0.0
# 161                      0.0            0.00  ...                0.0
# 162                      0.0            0.00  ...                0.0
#
#      improve-effort-15  improve-effort-25  \
# 0                -32.5                0.0
# 1                -29.0              -21.0
# 2                  7.0              -12.0
# 3                  0.0                0.0
# 4                  0.0               34.5
# ..                 ...                ...
# 158               16.5               16.5
# 159               11.5               11.5
# 160                0.0             -111.0
# 161                0.0                0.0
# 162                0.0                0.0
#
#                                              functions  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...
# 1    [house.ico, style.css, .css, main.js, map.js, ...
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...
# 3    [reset.css, layout.css, style.css, jquery.min....
# 4    [google.maps.Map, document.getElementById, goo...
# ..                                                 ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159  [jquery.min.js, bootstrap.min.js, .js, script....
# 160                                                 []
# 161                                                 []
# 162                                                 []
#
#                                           uniquephase5  len_unique  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...       116.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2297.0
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...        67.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2290.0
# 4    [google.maps.Map, document.getElementById, goo...        31.0
# ..                                                 ...         ...
# 158  [bootstrap.min.css, jquery.min.js, bootstrap.m...       133.0
# 159  [jquery.min.js, bootstrap.min.js, .js, script....       181.0
# 160                                                 []         0.0
# 161                                                 []         0.0
# 162                                                 []         0.0
#
#      len_functions                                       uniquephase4  \
# 0            116.0  [.ready, .click, .removeClass, .is, .val, .che...
# 1           2297.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2             67.0  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3           2290.0  [reset.css, layout.css, style.css, .js, yui.js...
# 4             31.0  [google.maps.Map, document.getElementById, goo...
# ..             ...                                                ...
# 158          133.0  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 159          181.0  [jquery.min.js, bootstrap.min.js, .js, script....
# 160            0.0                                                 []
# 161            0.0                                                 []
# 162            0.0                                                 []
#
#      added45  deleted45
# 0         11          1
# 1          9          2
# 2          1          1
# 3       2281         12
# 4          3          0
# ..       ...        ...
# 158        6        551
# 159       15          0
# 160        0          0
# 161        0          0
# 162        0          0
#
# [160 rows x 93 columns]

# %%
df345 = pd.merge(df45, overall_phase3[['Student', 'Group', 'uniquephase3']], how='left', left_on=['Student', 'Group'], right_on =['Student', 'Group'] )
df345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155          NicolasPrr    3.0                    100.0           83.33
# 156       jumcorredorro    3.0                    100.0           62.50
# 157          feartheGru    3.0                      0.0            0.00
# 158        Danielsv9207    3.0                      0.0            0.00
# 159  JhonEmmanuelTorres    3.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           90.00        360.83         87.5         62.5
# 156           75.00        325.00         87.5         87.5
# 157            0.00          0.00          0.0          0.0
# 158            0.00          0.00          0.0          0.0
# 159            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  infovis-phase4  ...  improve-effort-15  \
# 0                       20.0           29.17  ...              -32.5
# 1                       20.0           37.50  ...              -29.0
# 2                      100.0           58.33  ...                7.0
# 3                       20.0           45.83  ...                0.0
# 4                       40.0           54.17  ...                0.0
# ..                       ...             ...  ...                ...
# 155                      0.0           33.33  ...               16.5
# 156                     80.0           58.33  ...               11.5
# 157                      0.0            0.00  ...                0.0
# 158                      0.0            0.00  ...                0.0
# 159                      0.0            0.00  ...                0.0
#
#      improve-effort-25                                          functions  \
# 0                  0.0  [.ready, .click, .css, .removeClass, .is, .val...
# 1                -21.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2                -12.0  [js.org, .v, .min.js, weather.js, myss.css, bo...
# 3                  0.0  [reset.css, layout.css, style.css, jquery.min....
# 4                 34.5  [google.maps.Map, document.getElementById, goo...
# ..                 ...                                                ...
# 155               16.5  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156               11.5  [jquery.min.js, bootstrap.min.js, .js, script....
# 157             -111.0                                                 []
# 158                0.0                                                 []
# 159                0.0                                                 []
#
#                                           uniquephase5  len_unique  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...       116.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2297.0
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...        67.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2290.0
# 4    [google.maps.Map, document.getElementById, goo...        31.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...       133.0
# 156  [jquery.min.js, bootstrap.min.js, .js, script....       181.0
# 157                                                 []         0.0
# 158                                                 []         0.0
# 159                                                 []         0.0
#
#      len_functions                                       uniquephase4  \
# 0            116.0  [.ready, .click, .removeClass, .is, .val, .che...
# 1           2297.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2             67.0  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3           2290.0  [reset.css, layout.css, style.css, .js, yui.js...
# 4             31.0  [google.maps.Map, document.getElementById, goo...
# ..             ...                                                ...
# 155          133.0  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156          181.0  [jquery.min.js, bootstrap.min.js, .js, script....
# 157            0.0                                                 []
# 158            0.0                                                 []
# 159            0.0                                                 []
#
#      added45  deleted45                                       uniquephase3
# 0         11          1  [.ready, .click, .mcheck, .on, .closest, .list...
# 1          9          2  [house.ico, style.css, .css, main.js, map.js, ...
# 2          1          1  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3       2281         12                                                 []
# 4          3          0  [google.maps.Map, document.getElementById, goo...
# ..       ...        ...                                                ...
# 155        6        551  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156       15          0  [jquery.min.js, bootstrap.min.js, tutorial.css...
# 157        0          0                                                 []
# 158        0          0                                                 []
# 159        0          0                                                 []
#
# [160 rows x 94 columns]

# %%
df345["added34"] = df345.apply(lambda row: len(set(row.uniquephase4) - set(row.uniquephase3)), axis=1)
df345["deleted34"] = df345.apply(lambda row: len(set(row.uniquephase3) - set(row.uniquephase4)), axis=1)
df345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155          NicolasPrr    3.0                    100.0           83.33
# 156       jumcorredorro    3.0                    100.0           62.50
# 157          feartheGru    3.0                      0.0            0.00
# 158        Danielsv9207    3.0                      0.0            0.00
# 159  JhonEmmanuelTorres    3.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           90.00        360.83         87.5         62.5
# 156           75.00        325.00         87.5         87.5
# 157            0.00          0.00          0.0          0.0
# 158            0.00          0.00          0.0          0.0
# 159            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  infovis-phase4  ...  \
# 0                       20.0           29.17  ...
# 1                       20.0           37.50  ...
# 2                      100.0           58.33  ...
# 3                       20.0           45.83  ...
# 4                       40.0           54.17  ...
# ..                       ...             ...  ...
# 155                      0.0           33.33  ...
# 156                     80.0           58.33  ...
# 157                      0.0            0.00  ...
# 158                      0.0            0.00  ...
# 159                      0.0            0.00  ...
#
#                                              functions  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...
# 1    [house.ico, style.css, .css, main.js, map.js, ...
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...
# 3    [reset.css, layout.css, style.css, jquery.min....
# 4    [google.maps.Map, document.getElementById, goo...
# ..                                                 ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156  [jquery.min.js, bootstrap.min.js, .js, script....
# 157                                                 []
# 158                                                 []
# 159                                                 []
#
#                                           uniquephase5  len_unique  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...       116.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2297.0
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...        67.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2290.0
# 4    [google.maps.Map, document.getElementById, goo...        31.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...       133.0
# 156  [jquery.min.js, bootstrap.min.js, .js, script....       181.0
# 157                                                 []         0.0
# 158                                                 []         0.0
# 159                                                 []         0.0
#
#      len_functions                                       uniquephase4  \
# 0            116.0  [.ready, .click, .removeClass, .is, .val, .che...
# 1           2297.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2             67.0  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3           2290.0  [reset.css, layout.css, style.css, .js, yui.js...
# 4             31.0  [google.maps.Map, document.getElementById, goo...
# ..             ...                                                ...
# 155          133.0  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156          181.0  [jquery.min.js, bootstrap.min.js, .js, script....
# 157            0.0                                                 []
# 158            0.0                                                 []
# 159            0.0                                                 []
#
#      added45  deleted45                                       uniquephase3  \
# 0         11          1  [.ready, .click, .mcheck, .on, .closest, .list...
# 1          9          2  [house.ico, style.css, .css, main.js, map.js, ...
# 2          1          1  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3       2281         12                                                 []
# 4          3          0  [google.maps.Map, document.getElementById, goo...
# ..       ...        ...                                                ...
# 155        6        551  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156       15          0  [jquery.min.js, bootstrap.min.js, tutorial.css...
# 157        0          0                                                 []
# 158        0          0                                                 []
# 159        0          0                                                 []
#
#      added34  deleted34
# 0         81          5
# 1         24          7
# 2          0          0
# 3         21          0
# 4          1          0
# ..       ...        ...
# 155      658          0
# 156       74          3
# 157        0          0
# 158        0          0
# 159        0          0
#
# [160 rows x 96 columns]

# %%
df2345 = pd.merge(df345, overall_phase2[['Student', 'Group', 'uniquephase2']], how='left', left_on=['Student', 'Group'], right_on =['Student', 'Group'] )
df2345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155          NicolasPrr    3.0                    100.0           83.33
# 156       jumcorredorro    3.0                    100.0           62.50
# 157          feartheGru    3.0                      0.0            0.00
# 158        Danielsv9207    3.0                      0.0            0.00
# 159  JhonEmmanuelTorres    3.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           90.00        360.83         87.5         62.5
# 156           75.00        325.00         87.5         87.5
# 157            0.00          0.00          0.0          0.0
# 158            0.00          0.00          0.0          0.0
# 159            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  infovis-phase4  ...  \
# 0                       20.0           29.17  ...
# 1                       20.0           37.50  ...
# 2                      100.0           58.33  ...
# 3                       20.0           45.83  ...
# 4                       40.0           54.17  ...
# ..                       ...             ...  ...
# 155                      0.0           33.33  ...
# 156                     80.0           58.33  ...
# 157                      0.0            0.00  ...
# 158                      0.0            0.00  ...
# 159                      0.0            0.00  ...
#
#                                           uniquephase5  len_unique  \
# 0    [.ready, .click, .css, .removeClass, .is, .val...       116.0
# 1    [house.ico, style.css, .css, main.js, map.js, ...      2297.0
# 2    [js.org, .v, .min.js, weather.js, myss.css, bo...        67.0
# 3    [reset.css, layout.css, style.css, jquery.min....      2290.0
# 4    [google.maps.Map, document.getElementById, goo...        31.0
# ..                                                 ...         ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...       133.0
# 156  [jquery.min.js, bootstrap.min.js, .js, script....       181.0
# 157                                                 []         0.0
# 158                                                 []         0.0
# 159                                                 []         0.0
#
#      len_functions                                       uniquephase4  \
# 0            116.0  [.ready, .click, .removeClass, .is, .val, .che...
# 1           2297.0  [house.ico, style.css, .css, main.js, map.js, ...
# 2             67.0  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3           2290.0  [reset.css, layout.css, style.css, .js, yui.js...
# 4             31.0  [google.maps.Map, document.getElementById, goo...
# ..             ...                                                ...
# 155          133.0  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156          181.0  [jquery.min.js, bootstrap.min.js, .js, script....
# 157            0.0                                                 []
# 158            0.0                                                 []
# 159            0.0                                                 []
#
#      added45  deleted45                                       uniquephase3  \
# 0         11          1  [.ready, .click, .mcheck, .on, .closest, .list...
# 1          9          2  [house.ico, style.css, .css, main.js, map.js, ...
# 2          1          1  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3       2281         12                                                 []
# 4          3          0  [google.maps.Map, document.getElementById, goo...
# ..       ...        ...                                                ...
# 155        6        551  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156       15          0  [jquery.min.js, bootstrap.min.js, tutorial.css...
# 157        0          0                                                 []
# 158        0          0                                                 []
# 159        0          0                                                 []
#
#      added34  deleted34                                       uniquephase2
# 0         81          5  [.ready, .click, .mcheck, .on, .closest, .list...
# 1         24          7  [house.ico, style.css, map.js, Chicago.jpg, do...
# 2          0          0  [js.org, .v, .min.js, weather.js, mycss.css, b...
# 3         21          0                                                 []
# 4          1          0  [data.cityofchicago.org, rows.json, .ajax, goo...
# ..       ...        ...                                                ...
# 155      658          0  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156       74          3  [jquery.min.js, bootstrap.min.js, tutorial.css...
# 157        0          0                                                 []
# 158        0          0                                                 []
# 159        0          0                                                 []
#
# [160 rows x 97 columns]

# %%
df2345["added23"] = df2345.apply(lambda row: len(set(row.uniquephase3) - set(row.uniquephase2)), axis=1)
df2345["deleted23"] = df2345.apply(lambda row: len(set(row.uniquephase2) - set(row.uniquephase3)), axis=1)
df2345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155          NicolasPrr    3.0                    100.0           83.33
# 156       jumcorredorro    3.0                    100.0           62.50
# 157          feartheGru    3.0                      0.0            0.00
# 158        Danielsv9207    3.0                      0.0            0.00
# 159  JhonEmmanuelTorres    3.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           90.00        360.83         87.5         62.5
# 156           75.00        325.00         87.5         87.5
# 157            0.00          0.00          0.0          0.0
# 158            0.00          0.00          0.0          0.0
# 159            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  infovis-phase4  ...  len_functions  \
# 0                       20.0           29.17  ...          116.0
# 1                       20.0           37.50  ...         2297.0
# 2                      100.0           58.33  ...           67.0
# 3                       20.0           45.83  ...         2290.0
# 4                       40.0           54.17  ...           31.0
# ..                       ...             ...  ...            ...
# 155                      0.0           33.33  ...          133.0
# 156                     80.0           58.33  ...          181.0
# 157                      0.0            0.00  ...            0.0
# 158                      0.0            0.00  ...            0.0
# 159                      0.0            0.00  ...            0.0
#
#                                           uniquephase4  added45  deleted45  \
# 0    [.ready, .click, .removeClass, .is, .val, .che...       11          1
# 1    [house.ico, style.css, .css, main.js, map.js, ...        9          2
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        1          1
# 3    [reset.css, layout.css, style.css, .js, yui.js...     2281         12
# 4    [google.maps.Map, document.getElementById, goo...        3          0
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...        6        551
# 156  [jquery.min.js, bootstrap.min.js, .js, script....       15          0
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
#                                           uniquephase3  added34  deleted34  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...       81          5
# 1    [house.ico, style.css, .css, main.js, map.js, ...       24          7
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        0          0
# 3                                                   []       21          0
# 4    [google.maps.Map, document.getElementById, goo...        1          0
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...      658          0
# 156  [jquery.min.js, bootstrap.min.js, tutorial.css...       74          3
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
#                                           uniquephase2  added23  deleted23
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        0          0
# 1    [house.ico, style.css, map.js, Chicago.jpg, do...     2248          0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        0          0
# 3                                                   []        0          0
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...       20         12
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...        0          0
# 156  [jquery.min.js, bootstrap.min.js, tutorial.css...       60          4
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
# [160 rows x 99 columns]

# %%
df12345 = pd.merge(df2345, overall_phase1[['Student', 'Group', 'uniquephase1']], how='left', left_on=['Student', 'Group'], right_on =['Student', 'Group'] )
df12345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155          NicolasPrr    3.0                    100.0           83.33
# 156       jumcorredorro    3.0                    100.0           62.50
# 157          feartheGru    3.0                      0.0            0.00
# 158        Danielsv9207    3.0                      0.0            0.00
# 159  JhonEmmanuelTorres    3.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           90.00        360.83         87.5         62.5
# 156           75.00        325.00         87.5         87.5
# 157            0.00          0.00          0.0          0.0
# 158            0.00          0.00          0.0          0.0
# 159            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  infovis-phase4  ...  \
# 0                       20.0           29.17  ...
# 1                       20.0           37.50  ...
# 2                      100.0           58.33  ...
# 3                       20.0           45.83  ...
# 4                       40.0           54.17  ...
# ..                       ...             ...  ...
# 155                      0.0           33.33  ...
# 156                     80.0           58.33  ...
# 157                      0.0            0.00  ...
# 158                      0.0            0.00  ...
# 159                      0.0            0.00  ...
#
#                                           uniquephase4  added45  deleted45  \
# 0    [.ready, .click, .removeClass, .is, .val, .che...       11          1
# 1    [house.ico, style.css, .css, main.js, map.js, ...        9          2
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        1          1
# 3    [reset.css, layout.css, style.css, .js, yui.js...     2281         12
# 4    [google.maps.Map, document.getElementById, goo...        3          0
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...        6        551
# 156  [jquery.min.js, bootstrap.min.js, .js, script....       15          0
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
#                                           uniquephase3  added34  deleted34  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...       81          5
# 1    [house.ico, style.css, .css, main.js, map.js, ...       24          7
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        0          0
# 3                                                   []       21          0
# 4    [google.maps.Map, document.getElementById, goo...        1          0
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...      658          0
# 156  [jquery.min.js, bootstrap.min.js, tutorial.css...       74          3
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
#                                           uniquephase2  added23  deleted23  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        0          0
# 1    [house.ico, style.css, map.js, Chicago.jpg, do...     2248          0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        0          0
# 3                                                   []        0          0
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...       20         12
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...        0          0
# 156  [jquery.min.js, bootstrap.min.js, tutorial.css...       60          4
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
#                                           uniquephase1
# 0    [.ready, .click, .mcheck, .on, .closest, .list...
# 1    [style.css, map.js, document.getElementById, g...
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...
# 156  [jquery.min.js, bootstrap.min.js, tutorial.css...
# 157                                                 []
# 158                                                 []
# 159                                                 []
#
# [160 rows x 100 columns]

# %%
df12345["added12"] = df12345.apply(lambda row: len(set(row.uniquephase2) - set(row.uniquephase1)), axis=1)
df12345["deleted12"] = df12345.apply(lambda row: len(set(row.uniquephase1) - set(row.uniquephase2)), axis=1)
df12345 = df12345.fillna(0)
df12345
# Out:
#                 Student  Group  user-requirement-phase5  infovis-phase5  \
# 0             fffeelipe    0.0                     20.0           29.17
# 1             mnguzmanc    0.0                     60.0           75.00
# 2            jmcuestasb    0.0                    100.0           54.17
# 3            katherinsb    0.0                     20.0           37.50
# 4          jjrodriguezn    0.0                     60.0           58.33
# ..                  ...    ...                      ...             ...
# 155          NicolasPrr    3.0                    100.0           83.33
# 156       jumcorredorro    3.0                    100.0           62.50
# 157          feartheGru    3.0                      0.0            0.00
# 158        Danielsv9207    3.0                      0.0            0.00
# 159  JhonEmmanuelTorres    3.0                      0.0            0.00
#
#      novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             50.00        199.17        100.0        100.0
# 1             67.50        290.00         87.5         87.5
# 2             25.00        254.17         75.0         62.5
# 3             16.67        136.67         62.5         37.5
# 4             87.50        255.83         50.0         37.5
# ..              ...           ...          ...          ...
# 155           90.00        360.83         87.5         62.5
# 156           75.00        325.00         87.5         87.5
# 157            0.00          0.00          0.0          0.0
# 158            0.00          0.00          0.0          0.0
# 159            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  infovis-phase4  ...  deleted45  \
# 0                       20.0           29.17  ...          1
# 1                       20.0           37.50  ...          2
# 2                      100.0           58.33  ...          1
# 3                       20.0           45.83  ...         12
# 4                       40.0           54.17  ...          0
# ..                       ...             ...  ...        ...
# 155                      0.0           33.33  ...        551
# 156                     80.0           58.33  ...          0
# 157                      0.0            0.00  ...          0
# 158                      0.0            0.00  ...          0
# 159                      0.0            0.00  ...          0
#
#                                           uniquephase3  added34  deleted34  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...       81          5
# 1    [house.ico, style.css, .css, main.js, map.js, ...       24          7
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        0          0
# 3                                                   []       21          0
# 4    [google.maps.Map, document.getElementById, goo...        1          0
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...      658          0
# 156  [jquery.min.js, bootstrap.min.js, tutorial.css...       74          3
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
#                                           uniquephase2  added23  deleted23  \
# 0    [.ready, .click, .mcheck, .on, .closest, .list...        0          0
# 1    [house.ico, style.css, map.js, Chicago.jpg, do...     2248          0
# 2    [js.org, .v, .min.js, weather.js, mycss.css, b...        0          0
# 3                                                   []        0          0
# 4    [data.cityofchicago.org, rows.json, .ajax, goo...       20         12
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...        0          0
# 156  [jquery.min.js, bootstrap.min.js, tutorial.css...       60          4
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
#                                           uniquephase1  added12  deleted12
# 0    [.ready, .click, .mcheck, .on, .closest, .list...       11          2
# 1    [style.css, map.js, document.getElementById, g...       20          0
# 2                                                   []       67          0
# 3                                                   []        0          0
# 4                                                   []       19          0
# ..                                                 ...      ...        ...
# 155  [bootstrap.min.css, jquery.min.js, bootstrap.m...        0          0
# 156  [jquery.min.js, bootstrap.min.js, tutorial.css...        6          0
# 157                                                 []        0          0
# 158                                                 []        0          0
# 159                                                 []        0          0
#
# [160 rows x 102 columns]

# %%
df_12 = df12345[['Student', 'Group','added12']]
df_23 = df12345[['Student', 'Group','added23']]
df_34 = df12345[['Student', 'Group','added34']]
df_45 = df12345[['Student', 'Group','added45']]

df_12.rename(columns = {'added12':'added_sum'}, inplace = True)
df_23.rename(columns = {'added23':'added_sum'}, inplace = True)
df_34.rename(columns = {'added34':'added_sum'}, inplace = True)
df_45.rename(columns = {'added45':'added_sum'}, inplace = True)
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_3155/3419450139.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_12.rename(columns = {'added12':'added_sum'}, inplace = True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_3155/3419450139.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_23.rename(columns = {'added23':'added_sum'}, inplace = True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_3155/3419450139.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_34.rename(columns = {'added34':'added_sum'}, inplace = True)
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_3155/3419450139.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_45.rename(columns = {'added45':'added_sum'}, inplace = True)

# %%
df = df_12.append([df_23, df_34, df_45], ignore_index = True)
df
# Out:
# /var/folders/nr/2yp640v56_x34zrd2n5jvfqc0000gn/T/ipykernel_3155/4014926930.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_12.append([df_23, df_34, df_45], ignore_index = True)
#                 Student  Group  added_sum
# 0             fffeelipe    0.0         11
# 1             mnguzmanc    0.0         20
# 2            jmcuestasb    0.0         67
# 3            katherinsb    0.0          0
# 4          jjrodriguezn    0.0         19
# ..                  ...    ...        ...
# 635          NicolasPrr    3.0          6
# 636       jumcorredorro    3.0         15
# 637          feartheGru    3.0          0
# 638        Danielsv9207    3.0          0
# 639  JhonEmmanuelTorres    3.0          0
#
# [640 rows x 3 columns]

# %%
df.to_csv('functions_added.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_rows', None)
df = df.fillna(0)
df
# Out:
#                 Student  Group  added_sum
# 0             fffeelipe    0.0         11
# 1             mnguzmanc    0.0         20
# 2            jmcuestasb    0.0         67
# 3            katherinsb    0.0          0
# 4          jjrodriguezn    0.0         19
# 5                 DglyP    0.0         20
# 6                cap182    0.0          0
# 7           Judgarciani    0.0         41
# 8             sacastroc    0.0         35
# 9             pcberriop    0.0          2
# 10          hsmartineza    0.0         12
# 11             Moimolcp    0.0          0
# 12          CamiloRueda    0.0         47
# 13            juanescai    0.0          0
# 14           JoseMolano    0.0         44
# 15        maikellPardoA    0.0          0
# 16           NicolasZon    0.0          0
# 17            camilo654    0.0         14
# 18       CristianLozano    0.0          4
# 19            jdsuarezj    0.0         26
# 20            pipemax85    0.0          1
# 21          juandavidro    0.0          0
# 22       UNhcrodriguezl    0.0         53
# 23          camilo13152    0.0         14
# 24         leavendanoro    0.0         11
# 25           cdcordobaa    0.0         14
# 26           capinillab    0.0         13
# 27           janoguerab    0.0         33
# 28         lfvalderrama    0.0         11
# 29            bsgarciac    0.0         21
# 30               gabi04    0.0         41
# 31               annipi    0.0          0
# 32            jdsolanos    0.0          0
# 33             jcneivaa    0.0          0
# 34            fmbernalb    0.0          0
# 35              MogGy94    0.0          0
# 36            yocuervoc    0.0          0
# 37            odprietoh    0.0          0
# 38            gasierram    1.0          0
# 39         adamantwharf    1.0          0
# 40            bdcajicam    1.0          0
# 41       andfsanchezlem    1.0          0
# 42          dfhincapiem    1.0          4
# 43            helmeraac    1.0          9
# 44           dasalgadob    1.0          0
# 45           falperezgo    1.0       1923
# 46            djguzmanc    1.0         17
# 47           gsuarezc04    1.0         41
# 48               oeroaq    1.0         40
# 49              gcantem    1.0          0
# 50          Semoralesga    1.0       2252
# 51           jonatan360    1.0         26
# 52       jesusfchavarro    1.0       2838
# 53         stevenbustos    1.0          6
# 54       jufcontrerasco    1.0          1
# 55           dsbarrerag    1.0         20
# 56            wolfstain    1.0         14
# 57           miaborjaac    1.0         38
# 58        ivdgonzalezco    1.0          0
# 59         maikellPardo    1.0          0
# 60         Christian7sr    1.0          1
# 61           jsnarvaezb    1.0         38
# 62        gfalbarracinr    1.0          2
# 63             aldiazve    1.0       1443
# 64       diegoaguevarar    1.0          1
# 65           fevargasmo    1.0         17
# 66           jmhurtadoc    1.0          0
# 67          anfmorenoso    1.0         18
# 68          nabautistal    1.0          0
# 69               crigar    1.0          0
# 70          jiapulidoar    1.0        207
# 71            jsviveroj    1.0         29
# 72           daandradec    1.0         71
# 73             jcrubioa    1.0          9
# 74       joahernandezca    1.0        120
# 75              ItsNavi    1.0          0
# 76              Zeugmax    1.0          0
# 77         JairVillalba    1.0         19
# 78         jusherrerama    2.0          0
# 79              bdvegat    2.0          0
# 80           Phoenixest    2.0          0
# 81             HashNick    2.0          0
# 82              ccvacad    2.0          0
# 83           joaortizro    2.0          4
# 84      juasmartinezbel    2.0         25
# 85             mdbelloc    2.0          0
# 86          diegocruz10    2.0          1
# 87           crarojasca    2.0          0
# 88               sagilm    2.0          2
# 89             idrojasf    2.0          0
# 90         raulramirezp    2.0        151
# 91            fabianr23    2.0         28
# 92           jhriverasa    2.0          5
# 93           jhonsd1996    2.0          3
# 94           JuanitoAli    2.0       2275
# 95           Davsatu313    2.0         43
# 96       cesarochoa2006    2.0         49
# 97            jjmuesesq    2.0          0
# 98         jucjimenezmo    2.0          9
# 99               kancas    2.0         18
# 100             Gantiva    2.0         23
# 101          Dandarprox    2.0         14
# 102          debeltranc    2.0          0
# 103           ykchautai    2.0          9
# 104           ligibrial    2.0          4
# 105          davidrh195    2.0          5
# 106         JulianaNino    2.0         14
# 107            luegilca    2.0          0
# 108              Yelis3    2.0         32
# 109           begarzonf    2.0        408
# 110          kmendezp96    2.0          0
# 111            leguzman    2.0         47
# 112        luealfonsoru    2.0         55
# 113            oserasoa    2.0         14
# 114            lsfinite    2.0       4835
# 115           xdanielsb    2.0         23
# 116         CSebasGomez    2.0          0
# 117         jhcardenasa    2.0          0
# 118        jscontrerasp    2.0         17
# 119           lemartinp    3.0          7
# 120           juligarji    3.0        121
# 121           nfmorenog    3.0         28
# 122           AFelipeGA    3.0       2049
# 123          mballeng91    3.0         11
# 124            dduartec    3.0         20
# 125           srmedinac    3.0         50
# 126        wilson911013    3.0          0
# 127       wapiravaguens    3.0         34
# 128            davidh17    3.0         27
# 129      DianaNavarrete    3.0          3
# 130           jdmonroyg    3.0          0
# 131           jorge52an    3.0         44
# 132     jscastelblancoh    3.0         12
# 133          juclopezso    3.0          1
# 134           afforeroc    3.0          0
# 135         dagofonseca    3.0          2
# 136         lacardenasv    3.0         26
# 137         oacastillol    3.0        104
# 138          ncampuzano    3.0         34
# 139            adriel62    3.0         30
# 140            capinzor    3.0          0
# 141            ofnanezn    3.0          0
# 142           macuestap    3.0          8
# 143              spenas    3.0         18
# 144         kgbayala528    3.0          0
# 145          lgmoralesa    3.0         19
# 146          ronaldsg20    3.0          0
# 147       cccristanchoc    3.0         19
# 148          jmalvarezd    3.0         21
# 149           smarquezo    3.0          2
# 150             sarizag    3.0         12
# 151            Chranium    3.0          0
# 152             DavidQP    3.0         11
# 153         afceballosr    3.0         21
# 154           lizzyt10h    3.0          6
# 155          NicolasPrr    3.0          0
# 156       jumcorredorro    3.0          6
# 157          feartheGru    3.0          0
# 158        Danielsv9207    3.0          0
# 159  JhonEmmanuelTorres    3.0          0
# 160           fffeelipe    0.0          0
# 161           mnguzmanc    0.0       2248
# 162          jmcuestasb    0.0          0
# 163          katherinsb    0.0          0
# 164        jjrodriguezn    0.0         20
# 165               DglyP    0.0          0
# 166              cap182    0.0          0
# 167         Judgarciani    0.0         60
# 168           sacastroc    0.0         34
# 169           pcberriop    0.0          0
# 170         hsmartineza    0.0         20
# 171            Moimolcp    0.0         41
# 172         CamiloRueda    0.0          0
# 173           juanescai    0.0          0
# 174          JoseMolano    0.0          2
# 175       maikellPardoA    0.0          0
# 176          NicolasZon    0.0          0
# 177           camilo654    0.0          0
# 178      CristianLozano    0.0          0
# 179           jdsuarezj    0.0         25
# 180           pipemax85    0.0          6
# 181         juandavidro    0.0          1
# 182      UNhcrodriguezl    0.0         16
# 183         camilo13152    0.0         57
# 184        leavendanoro    0.0         13
# 185          cdcordobaa    0.0          0
# 186          capinillab    0.0          0
# 187          janoguerab    0.0          0
# 188        lfvalderrama    0.0         22
# 189           bsgarciac    0.0         40
# 190              gabi04    0.0         17
# 191              annipi    0.0          0
# 192           jdsolanos    0.0          0
# 193            jcneivaa    0.0          0
# 194           fmbernalb    0.0          0
# 195             MogGy94    0.0          0
# 196           yocuervoc    0.0          0
# 197           odprietoh    0.0          0
# 198           gasierram    1.0         44
# 199        adamantwharf    1.0          0
# 200           bdcajicam    1.0         33
# 201      andfsanchezlem    1.0          0
# 202         dfhincapiem    1.0          0
# 203           helmeraac    1.0          0
# 204          dasalgadob    1.0          0
# 205          falperezgo    1.0          0
# 206           djguzmanc    1.0          7
# 207          gsuarezc04    1.0          0
# 208              oeroaq    1.0        565
# 209             gcantem    1.0          0
# 210         Semoralesga    1.0          0
# 211          jonatan360    1.0         21
# 212      jesusfchavarro    1.0         62
# 213        stevenbustos    1.0          0
# 214      jufcontrerasco    1.0          0
# 215          dsbarrerag    1.0         19
# 216           wolfstain    1.0        186
# 217          miaborjaac    1.0         11
# 218       ivdgonzalezco    1.0          0
# 219        maikellPardo    1.0          0
# 220        Christian7sr    1.0          4
# 221          jsnarvaezb    1.0          1
# 222       gfalbarracinr    1.0          5
# 223            aldiazve    1.0          0
# 224      diegoaguevarar    1.0          0
# 225          fevargasmo    1.0         24
# 226          jmhurtadoc    1.0          0
# 227         anfmorenoso    1.0          0
# 228         nabautistal    1.0          4
# 229              crigar    1.0          0
# 230         jiapulidoar    1.0         19
# 231           jsviveroj    1.0         11
# 232          daandradec    1.0         38
# 233            jcrubioa    1.0          0
# 234      joahernandezca    1.0          0
# 235             ItsNavi    1.0          0
# 236             Zeugmax    1.0          0
# 237        JairVillalba    1.0         11
# 238        jusherrerama    2.0          6
# 239             bdvegat    2.0          7
# 240          Phoenixest    2.0          0
# 241            HashNick    2.0          0
# 242             ccvacad    2.0          0
# 243          joaortizro    2.0          8
# 244     juasmartinezbel    2.0         39
# 245            mdbelloc    2.0          0
# 246         diegocruz10    2.0         16
# 247          crarojasca    2.0          0
# 248              sagilm    2.0         16
# 249            idrojasf    2.0          0
# 250        raulramirezp    2.0          0
# 251           fabianr23    2.0         34
# 252          jhriverasa    2.0          3
# 253          jhonsd1996    2.0          0
# 254          JuanitoAli    2.0         39
# 255          Davsatu313    2.0          2
# 256      cesarochoa2006    2.0         46
# 257           jjmuesesq    2.0          0
# 258        jucjimenezmo    2.0          0
# 259              kancas    2.0          0
# 260             Gantiva    2.0         10
# 261          Dandarprox    2.0         27
# 262          debeltranc    2.0          0
# 263           ykchautai    2.0          8
# 264           ligibrial    2.0          8
# 265          davidrh195    2.0          0
# 266         JulianaNino    2.0          9
# 267            luegilca    2.0          0
# 268              Yelis3    2.0        111
# 269           begarzonf    2.0         12
# 270          kmendezp96    2.0          5
# 271            leguzman    2.0         32
# 272        luealfonsoru    2.0          0
# 273            oserasoa    2.0         12
# 274            lsfinite    2.0         18
# 275           xdanielsb    2.0         30
# 276         CSebasGomez    2.0          0
# 277         jhcardenasa    2.0          0
# 278        jscontrerasp    2.0         11
# 279           lemartinp    3.0          0
# 280           juligarji    3.0       2390
# 281           nfmorenog    3.0          9
# 282           AFelipeGA    3.0          0
# 283          mballeng91    3.0          0
# 284            dduartec    3.0         66
# 285           srmedinac    3.0          0
# 286        wilson911013    3.0          0
# 287       wapiravaguens    3.0         23
# 288            davidh17    3.0         21
# 289      DianaNavarrete    3.0          0
# 290           jdmonroyg    3.0          0
# 291           jorge52an    3.0         91
# 292     jscastelblancoh    3.0         19
# 293          juclopezso    3.0          0
# 294           afforeroc    3.0          0
# 295         dagofonseca    3.0        232
# 296         lacardenasv    3.0          0
# 297         oacastillol    3.0         13
# 298          ncampuzano    3.0         39
# 299            adriel62    3.0          0
# 300            capinzor    3.0         42
# 301            ofnanezn    3.0          1
# 302           macuestap    3.0          0
# 303              spenas    3.0          0
# 304         kgbayala528    3.0         12
# 305          lgmoralesa    3.0         16
# 306          ronaldsg20    3.0         21
# 307       cccristanchoc    3.0          0
# 308          jmalvarezd    3.0          2
# 309           smarquezo    3.0          0
# 310             sarizag    3.0          0
# 311            Chranium    3.0          0
# 312             DavidQP    3.0         19
# 313         afceballosr    3.0          4
# 314           lizzyt10h    3.0          5
# 315          NicolasPrr    3.0          0
# 316       jumcorredorro    3.0         60
# 317          feartheGru    3.0          0
# 318        Danielsv9207    3.0          0
# 319  JhonEmmanuelTorres    3.0          0
# 320           fffeelipe    0.0         81
# 321           mnguzmanc    0.0         24
# 322          jmcuestasb    0.0          0
# 323          katherinsb    0.0         21
# 324        jjrodriguezn    0.0          1
# 325               DglyP    0.0       2820
# 326              cap182    0.0          0
# 327         Judgarciani    0.0          5
# 328           sacastroc    0.0         24
# 329           pcberriop    0.0         30
# 330         hsmartineza    0.0         22
# 331            Moimolcp    0.0          4
# 332         CamiloRueda    0.0          0
# 333           juanescai    0.0          0
# 334          JoseMolano    0.0          0
# 335       maikellPardoA    0.0          0
# 336          NicolasZon    0.0          0
# 337           camilo654    0.0         17
# 338      CristianLozano    0.0          0
# 339           jdsuarezj    0.0          0
# 340           pipemax85    0.0          0
# 341         juandavidro    0.0          0
# 342      UNhcrodriguezl    0.0          0
# 343         camilo13152    0.0         18
# 344        leavendanoro    0.0         15
# 345          cdcordobaa    0.0          0
# 346          capinillab    0.0         15
# 347          janoguerab    0.0          0
# 348        lfvalderrama    0.0          4
# 349           bsgarciac    0.0         30
# 350              gabi04    0.0          0
# 351              annipi    0.0          0
# 352           jdsolanos    0.0          0
# 353            jcneivaa    0.0          0
# 354           fmbernalb    0.0          0
# 355             MogGy94    0.0          0
# 356           yocuervoc    0.0          0
# 357           odprietoh    0.0          0
# 358           gasierram    1.0          0
# 359        adamantwharf    1.0          0
# 360           bdcajicam    1.0          0
# 361      andfsanchezlem    1.0          0
# 362         dfhincapiem    1.0          0
# 363           helmeraac    1.0         20
# 364          dasalgadob    1.0          0
# 365          falperezgo    1.0         64
# 366           djguzmanc    1.0         16
# 367          gsuarezc04    1.0          0
# 368              oeroaq    1.0       2423
# 369             gcantem    1.0        132
# 370         Semoralesga    1.0          8
# 371          jonatan360    1.0         35
# 372      jesusfchavarro    1.0         49
# 373        stevenbustos    1.0         15
# 374      jufcontrerasco    1.0         87
# 375          dsbarrerag    1.0          5
# 376           wolfstain    1.0         14
# 377          miaborjaac    1.0         21
# 378       ivdgonzalezco    1.0          0
# 379        maikellPardo    1.0          0
# 380        Christian7sr    1.0          0
# 381          jsnarvaezb    1.0         15
# 382       gfalbarracinr    1.0          9
# 383            aldiazve    1.0       3063
# 384      diegoaguevarar    1.0          0
# 385          fevargasmo    1.0          7
# 386          jmhurtadoc    1.0          0
# 387         anfmorenoso    1.0         19
# 388         nabautistal    1.0          1
# 389              crigar    1.0          0
# 390         jiapulidoar    1.0          0
# 391           jsviveroj    1.0          9
# 392          daandradec    1.0        145
# 393            jcrubioa    1.0          0
# 394      joahernandezca    1.0          2
# 395             ItsNavi    1.0          0
# 396             Zeugmax    1.0          0
# 397        JairVillalba    1.0          5
# 398        jusherrerama    2.0          0
# 399             bdvegat    2.0          0
# 400          Phoenixest    2.0          0
# 401            HashNick    2.0          6
# 402             ccvacad    2.0         73
# 403          joaortizro    2.0          0
# 404     juasmartinezbel    2.0         62
# 405            mdbelloc    2.0          0
# 406         diegocruz10    2.0          0
# 407          crarojasca    2.0          0
# 408              sagilm    2.0          0
# 409            idrojasf    2.0          3
# 410        raulramirezp    2.0        105
# 411           fabianr23    2.0        106
# 412          jhriverasa    2.0         64
# 413          jhonsd1996    2.0          0
# 414          JuanitoAli    2.0        104
# 415          Davsatu313    2.0         58
# 416      cesarochoa2006    2.0         92
# 417           jjmuesesq    2.0         11
# 418        jucjimenezmo    2.0         50
# 419              kancas    2.0          0
# 420             Gantiva    2.0          6
# 421          Dandarprox    2.0        100
# 422          debeltranc    2.0          0
# 423           ykchautai    2.0          0
# 424           ligibrial    2.0          1
# 425          davidrh195    2.0          5
# 426         JulianaNino    2.0          1
# 427            luegilca    2.0          0
# 428              Yelis3    2.0        127
# 429           begarzonf    2.0          0
# 430          kmendezp96    2.0         22
# 431            leguzman    2.0         19
# 432        luealfonsoru    2.0          3
# 433            oserasoa    2.0          0
# 434            lsfinite    2.0          5
# 435           xdanielsb    2.0         44
# 436         CSebasGomez    2.0          0
# 437         jhcardenasa    2.0          0
# 438        jscontrerasp    2.0          3
# 439           lemartinp    3.0         11
# 440           juligarji    3.0         78
# 441           nfmorenog    3.0          0
# 442           AFelipeGA    3.0          0
# 443          mballeng91    3.0          5
# 444            dduartec    3.0          0
# 445           srmedinac    3.0          0
# 446        wilson911013    3.0          3
# 447       wapiravaguens    3.0         15
# 448            davidh17    3.0         32
# 449      DianaNavarrete    3.0          0
# 450           jdmonroyg    3.0          0
# 451           jorge52an    3.0        153
# 452     jscastelblancoh    3.0        136
# 453          juclopezso    3.0         24
# 454           afforeroc    3.0          0
# 455         dagofonseca    3.0          7
# 456         lacardenasv    3.0       2002
# 457         oacastillol    3.0        254
# 458          ncampuzano    3.0         15
# 459            adriel62    3.0       4967
# 460            capinzor    3.0       1792
# 461            ofnanezn    3.0          0
# 462           macuestap    3.0          1
# 463              spenas    3.0          0
# 464         kgbayala528    3.0          0
# 465          lgmoralesa    3.0         15
# 466          ronaldsg20    3.0         66
# 467       cccristanchoc    3.0         24
# 468          jmalvarezd    3.0          0
# 469           smarquezo    3.0         19
# 470             sarizag    3.0          2
# 471            Chranium    3.0          0
# 472             DavidQP    3.0          4
# 473         afceballosr    3.0         13
# 474           lizzyt10h    3.0         50
# 475          NicolasPrr    3.0        658
# 476       jumcorredorro    3.0         74
# 477          feartheGru    3.0          0
# 478        Danielsv9207    3.0          0
# 479  JhonEmmanuelTorres    3.0          0
# 480           fffeelipe    0.0         11
# 481           mnguzmanc    0.0          9
# 482          jmcuestasb    0.0          1
# 483          katherinsb    0.0       2281
# 484        jjrodriguezn    0.0          3
# 485               DglyP    0.0         29
# 486              cap182    0.0          0
# 487         Judgarciani    0.0         79
# 488           sacastroc    0.0          7
# 489           pcberriop    0.0         37
# 490         hsmartineza    0.0          4
# 491            Moimolcp    0.0         12
# 492         CamiloRueda    0.0          0
# 493           juanescai    0.0          0
# 494          JoseMolano    0.0          0
# 495       maikellPardoA    0.0          0
# 496          NicolasZon    0.0          0
# 497           camilo654    0.0          0
# 498      CristianLozano    0.0          0
# 499           jdsuarezj    0.0          0
# 500           pipemax85    0.0          0
# 501         juandavidro    0.0          0
# 502      UNhcrodriguezl    0.0          0
# 503         camilo13152    0.0          0
# 504        leavendanoro    0.0          8
# 505          cdcordobaa    0.0          0
# 506          capinillab    0.0         19
# 507          janoguerab    0.0          0
# 508        lfvalderrama    0.0          4
# 509           bsgarciac    0.0          1
# 510              gabi04    0.0         21
# 511              annipi    0.0          0
# 512           jdsolanos    0.0          0
# 513            jcneivaa    0.0          0
# 514           fmbernalb    0.0          0
# 515             MogGy94    0.0          0
# 516           yocuervoc    0.0          0
# 517           odprietoh    0.0          0
# 518           gasierram    1.0          0
# 519        adamantwharf    1.0          0
# 520           bdcajicam    1.0          0
# 521      andfsanchezlem    1.0          0
# 522         dfhincapiem    1.0          0
# 523           helmeraac    1.0          0
# 524          dasalgadob    1.0          0
# 525          falperezgo    1.0          6
# 526           djguzmanc    1.0          0
# 527          gsuarezc04    1.0          0
# 528              oeroaq    1.0         23
# 529             gcantem    1.0          0
# 530         Semoralesga    1.0          4
# 531          jonatan360    1.0         20
# 532      jesusfchavarro    1.0         21
# 533        stevenbustos    1.0         13
# 534      jufcontrerasco    1.0          0
# 535          dsbarrerag    1.0         15
# 536           wolfstain    1.0          0
# 537          miaborjaac    1.0          5
# 538       ivdgonzalezco    1.0         14
# 539        maikellPardo    1.0          0
# 540        Christian7sr    1.0         19
# 541          jsnarvaezb    1.0          0
# 542       gfalbarracinr    1.0         19
# 543            aldiazve    1.0          2
# 544      diegoaguevarar    1.0         21
# 545          fevargasmo    1.0          2
# 546          jmhurtadoc    1.0          0
# 547         anfmorenoso    1.0         46
# 548         nabautistal    1.0         43
# 549              crigar    1.0          0
# 550         jiapulidoar    1.0         17
# 551           jsviveroj    1.0          4
# 552          daandradec    1.0          0
# 553            jcrubioa    1.0          0
# 554      joahernandezca    1.0          0
# 555             ItsNavi    1.0          0
# 556             Zeugmax    1.0          0
# 557        JairVillalba    1.0         24
# 558        jusherrerama    2.0          0
# 559             bdvegat    2.0          0
# 560          Phoenixest    2.0          0
# 561            HashNick    2.0          0
# 562             ccvacad    2.0         15
# 563          joaortizro    2.0          0
# 564     juasmartinezbel    2.0          0
# 565            mdbelloc    2.0          0
# 566         diegocruz10    2.0          0
# 567          crarojasca    2.0          0
# 568              sagilm    2.0         16
# 569            idrojasf    2.0          0
# 570        raulramirezp    2.0         40
# 571           fabianr23    2.0          4
# 572          jhriverasa    2.0          6
# 573          jhonsd1996    2.0          0
# 574          JuanitoAli    2.0          0
# 575          Davsatu313    2.0          0
# 576      cesarochoa2006    2.0          2
# 577           jjmuesesq    2.0         13
# 578        jucjimenezmo    2.0          5
# 579              kancas    2.0          0
# 580             Gantiva    2.0          0
# 581          Dandarprox    2.0          0
# 582          debeltranc    2.0         25
# 583           ykchautai    2.0         21
# 584           ligibrial    2.0         27
# 585          davidrh195    2.0          0
# 586         JulianaNino    2.0          1
# 587            luegilca    2.0          0
# 588              Yelis3    2.0       4060
# 589           begarzonf    2.0          0
# 590          kmendezp96    2.0       2249
# 591            leguzman    2.0         27
# 592        luealfonsoru    2.0          0
# 593            oserasoa    2.0          9
# 594            lsfinite    2.0          0
# 595           xdanielsb    2.0        236
# 596         CSebasGomez    2.0          0
# 597         jhcardenasa    2.0          0
# 598        jscontrerasp    2.0          0
# 599           lemartinp    3.0          0
# 600           juligarji    3.0         11
# 601           nfmorenog    3.0          0
# 602           AFelipeGA    3.0          0
# 603          mballeng91    3.0          0
# 604            dduartec    3.0       2233
# 605           srmedinac    3.0          0
# 606        wilson911013    3.0          0
# 607       wapiravaguens    3.0          5
# 608            davidh17    3.0          0
# 609      DianaNavarrete    3.0          0
# 610           jdmonroyg    3.0         14
# 611           jorge52an    3.0         40
# 612     jscastelblancoh    3.0         12
# 613          juclopezso    3.0          1
# 614           afforeroc    3.0          0
# 615         dagofonseca    3.0         14
# 616         lacardenasv    3.0         14
# 617         oacastillol    3.0          2
# 618          ncampuzano    3.0         82
# 619            adriel62    3.0         59
# 620            capinzor    3.0         10
# 621            ofnanezn    3.0          0
# 622           macuestap    3.0          0
# 623              spenas    3.0          0
# 624         kgbayala528    3.0          0
# 625          lgmoralesa    3.0          3
# 626          ronaldsg20    3.0         14
# 627       cccristanchoc    3.0         24
# 628          jmalvarezd    3.0          1
# 629           smarquezo    3.0         43
# 630             sarizag    3.0          9
# 631            Chranium    3.0          0
# 632             DavidQP    3.0         14
# 633         afceballosr    3.0          3
# 634           lizzyt10h    3.0         11
# 635          NicolasPrr    3.0          6
# 636       jumcorredorro    3.0         15
# 637          feartheGru    3.0          0
# 638        Danielsv9207    3.0          0
# 639  JhonEmmanuelTorres    3.0          0

# %%
df_g0 = df[df['Group'] == 0]
df_g0['added_sum'].mean()
# Out:
# 58.24342105263158

# %%
df_g0 = df[df['Group'] == 0]
df_g0['added_sum'].sum()
# Out:
# 8853

# %%
df_g1 = df[df['Group'] == 1]
df_g1['added_sum'].mean()
# Out:
# 104.69375

# %%
df_g1 = df[df['Group'] == 1]
df_g1['added_sum'].sum()
# Out:
# 16751

# %%
df_g2 = df[df['Group'] == 2]
df_g2['added_sum'].mean()
# Out:
# 100.29268292682927

# %%
df_g3 = df[df['Group'] == 2]
df_g3['added_sum'].sum()
# Out:
# 16448

# %%
df_g3 = df[df['Group'] == 3]
df_g3['added_sum'].mean()
# Out:
# 115.1890243902439

# %%
df_g3 = df[df['Group'] == 3]
df_g3['added_sum'].sum()
# Out:
# 18891

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.api import add_constant
from statsmodels.sandbox.regression.gmm import IV2SLS

df['ln_added_sum'] = np.log(df['added_sum'] + 1)

reg_expr = 'ln_added_sum ~ Group'
olsr_model = smf.ols(formula=reg_expr, data=df)
olsr_model_results = olsr_model.fit()
print(olsr_model_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           ln_added_sum   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     4.776
# Date:                Mon, 26 Dec 2022   Prob (F-statistic):             0.0292
# Time:                        00:01:10   Log-Likelihood:                -1328.1
# No. Observations:                 640   AIC:                             2660.
# Df Residuals:                     638   BIC:                             2669.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4648      0.130     11.280      0.000       1.210       1.720
# Group          0.1500      0.069      2.186      0.029       0.015       0.285
# ==============================================================================
# Omnibus:                      100.076   Durbin-Watson:                   1.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.418
# Skew:                           1.073   Prob(JB):                     9.74e-33
# Kurtosis:                       3.961   Cond. No.                         3.86
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
