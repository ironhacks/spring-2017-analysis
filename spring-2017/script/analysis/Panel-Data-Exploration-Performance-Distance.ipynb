# %%
import pandas as pd 
import seaborn as sns
df = pd.read_csv("merged-variety.csv")
df
# Out:
#      Unnamed: 0.1  Unnamed: 0        Student  phase   novelty  group  \
# 0               0           1   wilson911013      1  0.000000      3
# 1               2           5      lizzyt10h      1  0.400000      3
# 2               3           6      AFelipeGA      1  0.400000      3
# 3               4           7  wapiravaguens      1  0.400000      3
# 4               5           8       capinzor      1  0.413793      3
# ..            ...         ...            ...    ...       ...    ...
# 631           647         651    kastellanos      3  0.000000      1
# 632           648         652      tres-iqus      3  0.000000      2
# 633           649         653    annumumozme      4  0.000000      0
# 634           650         654    kastellanos      4  0.000000      1
# 635           651         655      tres-iqus      4  0.000000      2
#
#      abs_perform_diff_best          user2  Q7_Q7_1  Q7_Q7_2  Q8_Q8_1  Q10  \
# ...

# %% [markdown]
# ## Group 3

# %%
df_g3 = df[df['group'] == 3]
df_g3_p1 = df_g3[df_g3['phase'] == 1]
df_g3_p2 = df_g3[df_g3['phase'] == 2]
df_g3_p3 = df_g3[df_g3['phase'] == 3]
df_g3_p4 = df_g3[df_g3['phase'] == 4]

# %%
sns.regplot(df_g3['abs_perform_diff_best'], df_g3['exploration']).set(title='Performance Distance vs Individual Exploration')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration')]

# %%
sns.regplot(df_g3_p1['abs_perform_diff_best'], df_g3_p1['exploration']).set(title='Performance Distance vs Individual Exploration Full Transparency Stage 1')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Full Transparency Stage 1')]

# %%
sns.regplot(df_g3_p2['abs_perform_diff_best'], df_g3_p2['exploration']).set(title='Performance Distance vs Individual Exploration Full Transparency Stage 2')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Full Transparency Stage 2')]

# %%
sns.regplot(df_g3_p3['abs_perform_diff_best'], df_g3_p3['exploration']).set(title='Performance Distance vs Individual Exploration Full Transparency Stage 3')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Full Transparency Stage 3')]

# %%
sns.regplot(df_g3_p4['abs_perform_diff_best'], df_g3_p4['exploration']).set(title='Performance Distance vs Individual Exploration Full Transparency Stage 4')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Full Transparency Stage 4')]

# %% [markdown]
# ## Group 2

# %%
df_g2 = df[df['group'] == 2]
df_g2_p1 = df_g2[df_g2['phase'] == 1]
df_g2_p2 = df_g2[df_g2['phase'] == 2]
df_g2_p3 = df_g2[df_g2['phase'] == 3]
df_g2_p4 = df_g2[df_g2['phase'] == 4]

# %%
sns.regplot(df_g2['abs_perform_diff_best'], df_g2['exploration']).set(title='Performance Distance vs Individual Exploration Solution Transparency')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Solution Transparency')]

# %%
sns.regplot(df_g2_p1['abs_perform_diff_best'], df_g2_p1['exploration']).set(title='Performance Distance vs Individual Exploration Solution Transparency Stage 1')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Solution Transparency Stage 1')]

# %%
sns.regplot(df_g2_p2['abs_perform_diff_best'], df_g2_p2['exploration']).set(title='Performance Distance vs Individual Exploration Solution Transparency Stage 2')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Solution Transparency Stage 2')]

# %%
sns.regplot(df_g2_p3['abs_perform_diff_best'], df_g2_p3['exploration']).set(title='Performance Distance vs Individual Exploration Solution Transparency Stage 3')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Solution Transparency Stage 3')]

# %%
sns.regplot(df_g2_p4['abs_perform_diff_best'], df_g2_p4['exploration']).set(title='Performance Distance vs Individual Exploration Solution Transparency Stage 4')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Solution Transparency Stage 4')]

# %% [markdown]
# ## Group 1

# %%
df_g1 = df[df['group'] == 1]
df_g1_p1 = df_g1[df_g1['phase'] == 1]
df_g1_p2 = df_g1[df_g1['phase'] == 2]
df_g1_p3 = df_g1[df_g1['phase'] == 3]
df_g1_p4 = df_g1[df_g1['phase'] == 4]

# %%
sns.regplot(df_g1['abs_perform_diff_best'], df_g1['exploration']).set(title='Performance Distance vs Individual Exploration Performance Transparency Stage 1')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Performance Transparency Stage 1')]

# %%
sns.regplot(df_g1_p1['abs_perform_diff_best'], df_g1_p1['exploration']).set(title='Performance Distance vs Individual Exploration Performance Transparency Stage 1')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Performance Transparency Stage 1')]

# %%
sns.regplot(df_g1_p2['abs_perform_diff_best'], df_g1_p2['exploration']).set(title='Performance Distance vs Individual Exploration Performance Transparency Stage 2')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Performance Transparency Stage 2')]

# %%
sns.regplot(df_g1_p3['abs_perform_diff_best'], df_g1_p3['exploration']).set(title='Performance Distance vs Individual Exploration Performance Transparency Stage 3')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Performance Transparency Stage 3')]

# %%
sns.regplot(df_g1_p4['abs_perform_diff_best'], df_g1_p4['exploration']).set(title='Performance Distance vs Individual Exploration Performance Transparency Stage 4')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration Performance Transparency Stage 4')]

# %% [markdown]
# ## Group 0

# %%
df_g0 = df[df['group'] == 0]
df_g0_p1 = df_g0[df_g0['phase'] == 1]
df_g0_p2 = df_g0[df_g0['phase'] == 2]
df_g0_p3 = df_g0[df_g0['phase'] == 3]
df_g0_p4 = df_g0[df_g0['phase'] == 4]

# %%
sns.regplot(df_g0['abs_perform_diff_best'], df_g0['exploration']).set(title='Performance Distance vs Individual Exploration')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration')]

# %%
sns.regplot(df_g0_p1['abs_perform_diff_best'], df_g0_p1['exploration']).set(title='Performance Distance vs Individual Exploration No Transparency Stage 1')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration No Transparency Stage 1')]

# %%
sns.regplot(df_g0_p2['abs_perform_diff_best'], df_g0_p2['exploration']).set(title='Performance Distance vs Individual Exploration No Transparency Stage 2')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration No Transparency Stage 2')]

# %%
sns.regplot(df_g0_p3['abs_perform_diff_best'], df_g0_p3['exploration']).set(title='Performance Distance vs Individual Exploration No Transparency Stage 3')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration No Transparency Stage 3')]

# %%
sns.regplot(df_g0_p4['abs_perform_diff_best'], df_g0_p4['exploration']).set(title='Performance Distance vs Individual Exploration No Transparency Stage 4')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [Text(0.5, 1.0, 'Performance Distance vs Individual Exploration No Transparency Stage 4')]
