# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from statsmodels.api import add_constant
from statsmodels.sandbox.regression.gmm import IV2SLS


df = pd.read_csv("../../../../Library/CloudStorage/Box-Box/NSF IronHacks App 2016 - 2019/05 Experiments 2017/01 Hack Spring 2017/01 Summary Spring 2017/02 Data/processed-data/overall_score_click_result.csv")
df
# Out:
#      Unnamed: 0             Student  Group  user-requirement-phase5  \
# 0             0           fffeelipe    0.0                     20.0
# 1             1           mnguzmanc    0.0                     60.0
# 2             2          jmcuestasb    0.0                    100.0
# 3             3          katherinsb    0.0                     20.0
# 4             4        jjrodriguezn    0.0                     60.0
# ..          ...                 ...    ...                      ...
# 159         159       jumcorredorro    3.0                    100.0
# 160         160          feartheGru    3.0                      0.0
# 161         161        Danielsv9207    3.0                      0.0
# 162         162  JhonEmmanuelTorres    3.0                      0.0
# 163         163          janoguerab    0.0                      0.0
#
#      infovis-phase5  novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 0             29.17           50.00        199.17        100.0        100.0
# 1             75.00           67.50        290.00         87.5         87.5
# 2             54.17           25.00        254.17         75.0         62.5
# 3             37.50           16.67        136.67         62.5         37.5
# 4             58.33           87.50        255.83         50.0         37.5
# ..              ...             ...           ...          ...          ...
# 159           62.50           75.00        325.00         87.5         87.5
# 160            0.00            0.00          0.00          0.0          0.0
# 161            0.00            0.00          0.00          0.0          0.0
# 162            0.00            0.00          0.00          0.0          0.0
# 163            0.00            0.00          0.00          0.0          0.0
#
#      user-requirement-phase4  ...  phase1-clicks-count  phase2-clicks-count  \
# 0                       20.0  ...                  0.0                  0.0
# 1                       20.0  ...                  4.0                  0.0
# 2                      100.0  ...                  4.0                  0.0
# 3                       20.0  ...                  0.0                  0.0
# 4                       40.0  ...                  1.0                  0.0
# ..                       ...  ...                  ...                  ...
# 159                     80.0  ...                178.0                  9.0
# 160                      0.0  ...                  0.0                  0.0
# 161                      0.0  ...                  2.0                  0.0
# 162                      0.0  ...                  0.0                  0.0
# 163                      0.0  ...                  0.0                  2.0
#
#      phase3-clicks-count  phase4-clicks-count  sum-clicks-count  \
# 0                    0.0                  5.0               5.0
# 1                    0.0                 22.0              26.0
# 2                    0.0                  0.0               4.0
# 3                    0.0                  0.0               0.0
# 4                    0.0                  0.0               1.0
# ..                   ...                  ...               ...
# 159                  0.0                  3.0             190.0
# 160                  0.0                  0.0               0.0
# 161                  0.0                  0.0               2.0
# 162                  0.0                  0.0               0.0
# 163                  0.0                  0.0               2.0
#
#      project-clicks-count  score-clicks-count  sum-add-loc  \
# 0                     5.0                 NaN        165.0
# 1                    23.0                 NaN        183.0
# 2                     2.0                 NaN         31.0
# 3                     NaN                 NaN        259.0
# 4                     1.0                 NaN        232.0
# ..                    ...                 ...          ...
# 159                  48.0               140.0         32.0
# 160                   NaN                 NaN          6.0
# 161                   NaN                 2.0          0.0
# 162                   NaN                 NaN          0.0
# 163                   2.0                 NaN          0.0
#
#      project-clicks-hacker  unique_apps
# 0                      9.0          5.0
# 1                     11.0         15.0
# 2                      7.0          1.0
# 3                     10.0          NaN
# 4                      8.0          1.0
# ..                     ...          ...
# 159                  205.0         21.0
# 160                    NaN          NaN
# 161                    NaN          NaN
# 162                   65.0          NaN
# 163                   10.0          2.0
#
# [164 rows x 91 columns]

# %%
df = df[(df['Group'] == 2) | (df['Group'] == 3)]
df
# Out:
#      Unnamed: 0             Student  Group  user-requirement-phase5  \
# 80           80        jusherrerama    2.0                     20.0
# 81           81             bdvegat    2.0                     20.0
# 82           82          Phoenixest    2.0                      0.0
# 83           83            HashNick    2.0                     40.0
# 84           84             ccvacad    2.0                     80.0
# ..          ...                 ...    ...                      ...
# 158         158          NicolasPrr    3.0                    100.0
# 159         159       jumcorredorro    3.0                    100.0
# 160         160          feartheGru    3.0                      0.0
# 161         161        Danielsv9207    3.0                      0.0
# 162         162  JhonEmmanuelTorres    3.0                      0.0
#
#      infovis-phase5  novelty-phase5  total-phase5  tech-phase5  tech-phase4  \
# 80            25.00             0.0        120.00         75.0         62.5
# 81            25.00             0.0        107.50         62.5         50.0
# 82            25.00            25.0         75.00         25.0         25.0
# 83            50.00            25.0        152.50         37.5         37.5
# 84            66.67            80.0        314.17         87.5          0.0
# ..              ...             ...           ...          ...          ...
# 158           83.33            90.0        360.83         87.5         62.5
# 159           62.50            75.0        325.00         87.5         87.5
# 160            0.00             0.0          0.00          0.0          0.0
# 161            0.00             0.0          0.00          0.0          0.0
# 162            0.00             0.0          0.00          0.0          0.0
#
#      user-requirement-phase4  ...  phase1-clicks-count  phase2-clicks-count  \
# 80                      20.0  ...                  0.0                  0.0
# 81                      20.0  ...                  0.0                 18.0
# 82                      20.0  ...                  4.0                  0.0
# 83                      40.0  ...                 21.0                  0.0
# 84                       0.0  ...                  4.0                 42.0
# ..                       ...  ...                  ...                  ...
# 158                      0.0  ...                499.0                447.0
# 159                     80.0  ...                178.0                  9.0
# 160                      0.0  ...                  0.0                  0.0
# 161                      0.0  ...                  2.0                  0.0
# 162                      0.0  ...                  0.0                  0.0
#
#      phase3-clicks-count  phase4-clicks-count  sum-clicks-count  \
# 80                   0.0                  0.0               0.0
# 81                   0.0                  0.0              18.0
# 82                   1.0                  0.0               5.0
# 83                   0.0                  0.0              21.0
# 84                   8.0                 38.0              92.0
# ..                   ...                  ...               ...
# 158                442.0                438.0            1826.0
# 159                  0.0                  3.0             190.0
# 160                  0.0                  0.0               0.0
# 161                  0.0                  0.0               2.0
# 162                  0.0                  0.0               0.0
#
#      project-clicks-count  score-clicks-count  sum-add-loc  \
# 80                    NaN                 NaN          0.0
# 81                   14.0                 NaN         25.0
# 82                    2.0                 NaN          0.0
# 83                    8.0                 NaN         21.0
# 84                   84.0                 NaN         24.0
# ..                    ...                 ...          ...
# 158                 821.0               978.0        108.0
# 159                  48.0               140.0         32.0
# 160                   NaN                 NaN          6.0
# 161                   NaN                 2.0          0.0
# 162                   NaN                 NaN          0.0
#
#      project-clicks-hacker  unique_apps
# 80                   103.0          NaN
# 81                    44.0          8.0
# 82                    93.0          2.0
# 83                    33.0          7.0
# 84                     NaN         37.0
# ..                     ...          ...
# 158                  119.0         38.0
# 159                  205.0         21.0
# 160                    NaN          NaN
# 161                    NaN          NaN
# 162                   65.0          NaN
#
# [83 rows x 91 columns]

# %%
#Compare the performance of 2SLS with OLS of ln(wage) on performance distance to the best
df['sum_add_loc'] =  np.log(df['sum-add-loc'] + 1)

reg_expr = 'sum_add_loc ~ Group'
olsr_model = smf.ols(formula=reg_expr, data=df)
olsr_model_results = olsr_model.fit()
print(olsr_model_results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            sum_add_loc   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     3.859
# Date:                Fri, 30 Sep 2022   Prob (F-statistic):             0.0529
# Time:                        13:49:29   Log-Likelihood:                -169.67
# No. Observations:                  83   AIC:                             343.3
# Df Residuals:                      81   BIC:                             348.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0408      1.056      0.985      0.327      -1.061       3.143
# Group          0.8158      0.415      1.964      0.053      -0.010       1.642
# ==============================================================================
# Omnibus:                        5.695   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                3.820
# Skew:                          -0.367   Prob(JB):                        0.148
# Kurtosis:                       2.248   Cond. No.                         14.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/gf/pvtbdsj96cz1tv7vmn1gq7j40000gn/T/ipykernel_1816/4188428212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sum_add_loc'] =  np.log(df['sum-add-loc'] + 1)
