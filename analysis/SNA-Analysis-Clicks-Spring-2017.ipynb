# %%
import pandas as pd
import numpy as np

df = pd.read_csv('2017-spring-clicks.csv')
df.head(5)

## Exclude rows wh
# Out:
#    click_date click_time         event_type                  url   phase  \
# 0  2017-03-12   10:02 am        score-click                  NaN  phase3
# 1  2017-03-12   10:02 am        score-click                  NaN  phase3
# 2  2017-03-12   10:02 am        score-click                  NaN  phase3
# 3  2017-03-12   10:02 am  click-project-url  https://github.com/  phase3
# 4  2017-03-12   10:03 am  click-project-url  https://purdue.edu/  phase3
#
#   hacker_username             hacker_email clicker_username  \
# 0           RCODI   opendigital@purdue.edu            RCODI
# 1      hackpurdue  ironhacktech1@gmail.com            RCODI
# 2        uxjudges       uxjudges@gmail.com            RCODI
# 3           RCODI   opendigital@purdue.edu            RCODI
# 4        uxjudges       uxjudges@gmail.com            RCODI
#
#             clicker_email
# 0  opendigital@purdue.edu
# 1  opendigital@purdue.edu
# 2  opendigital@purdue.edu
# 3  opendigital@purdue.edu
# 4  opendigital@purdue.edu
