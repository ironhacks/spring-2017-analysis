# %% [markdown]
# # Fall 2017

# %%
import pandas as pd
import os

# %%
import csv

# %%
os.getcwd()
# Out:
# '/Users/aldana/Dropbox (RCODI)/09 NSF open data/05 Experiments 2017/02 Hack Fall 2017/01 repo Hack Fall 2017/02 Data/2-4 scripts/01 components'

# %%
# Here goes the automatic API downloading

all_functions = set()
classes_dict = dict()
with open("./node_modules/d3/API.md") as f: 
    #required_api_list.append(str_api.strip())
    readme_reader = csv.reader(f)
    readme_reader_iter = iter(readme_reader)
    current_class = 'init'
    next(readme_reader_iter) #skipping header
    for i,row in enumerate(readme_reader_iter):
        if row:
            if  row[0].startswith('## ['):
                current_class = row[0].split(']')[0].split('[')[-1].split('(')[-1].split(')')[0].strip()
                classes_dict[row[0].split(']')[0].split('[')[-1].split('(')[-1].split(')')[0].strip()] = dict()
                current_subclass = '_'
                classes_dict[current_class][current_subclass] = set()
            if row[0].startswith('### ['): 
                current_subclass = row[0].split(']')[0].split('[')[-1].split(' ')[0]
                classes_dict[current_class][current_subclass] = set()
            if '[d3.' in row[0]:
                all_functions.add('.'+row[0].split(']')[0].split('[')[-1].split('.')[-1])
                classes_dict[current_class][current_subclass].add('.'+row[0].split(']')[0].split('[')[-1].split('.')[-1])

package_component_list = list([['package','component']])
for package, semantic_class in classes_dict.items():
    for semantic_class, components in semantic_class.items():
        for component in components:
            package_component_list.append([package,component])

if 'results' not in os.listdir('.'):
    os.mkdir('results')

pd.DataFrame(package_component_list).to_csv('./results/packages_components.csv',index=False,header=False)

# %%
d3_components_all =[components for val in classes_dict.values() for v in val.values() for components in list(v)]

# %%
df = pd.DataFrame()

participants_code_path = '../../2-1 Raw/05 Participants code/'
for phase_folder in [repo for repo in os.listdir(participants_code_path) if repo.startswith('PHASE')]:
    phase = phase_folder.split('-')[-1].split('_')[-1]
    for repo_folder in [ repo for repo in os.listdir(participants_code_path+phase_folder) if not repo.startswith('.')]:
        for root, folders, files in os.walk(participants_code_path+phase_folder+'/'+repo_folder):
            for file_name in files:
                if file_name.endswith(".js"):
                    with open(os.path.join( root,  file_name)) as  file_object:
                        file_content = file_object.read()
                        d3_components = set()
                        #for d3 libraries
                        for d3_component in d3_components_all:
                            if d3_component in file_content:
                                class_d3 = [ '_'.join([d3class,subclass,d3_component]) for d3class, val in classes_dict.items() for subclass,components in val.items() if d3_component in components ]
                                if  class_d3:
                                    d3_components.add(class_d3[0])
                                    #libraries.append(d3_component)
                        num_components = len(list(d3_components))
                        df = df.append(pd.DataFrame({'components':list(d3_components),"username_folder_name":num_components*[repo_folder],"phase":num_components*[phase],"js_loc_in_each_js":num_components*[len(file_content)]}))

# %%
df
# Out:
#                            components  js_loc_in_each_js    phase  \
# 0             d3-collection_Maps_.map              927.0  PHASE 1
# 0             d3-collection_Maps_.map              609.0  PHASE 1
# 0                    d3-fetch___.text             7858.0  PHASE 1
# 1         d3-transition___.transition             7858.0  PHASE 1
# 2                 d3-format___.format             7858.0  PHASE 1
# 3            d3-array_Statistics_.max             7858.0  PHASE 1
# 4            d3-array_Statistics_.min             7858.0  PHASE 1
# 5                   d3-color___.color             7858.0  PHASE 1
# 6                d3-shape_Areas_.area             7858.0  PHASE 1
# 7   d3-selection_Selecting_.selectAll             7858.0  PHASE 1
# 8      d3-selection_Selecting_.select             7858.0  PHASE 1
# 9       d3-selection_Selecting_.style             7858.0  PHASE 1
# 10            d3-collection_Maps_.map             7858.0  PHASE 1
# 0                    d3-fetch___.text             2789.0  PHASE 1
# 1   d3-selection_Selecting_.selectAll             2789.0  PHASE 1
# 2       d3-selection_Selecting_.style             2789.0  PHASE 1
# 3      d3-selection_Selecting_.select             2789.0  PHASE 1
# 0        d3-selection_Handling_.event             9439.0  PHASE 1
# 1             d3-collection_Sets_.set             9439.0  PHASE 1
# 2             d3-collection_Maps_.map             9439.0  PHASE 1
# 3                    d3-fetch___.json             9439.0  PHASE 1
# 0            d3-array_Statistics_.min             3132.0  PHASE 1
# 1      d3-selection_Modifying_.create             3132.0  PHASE 1
# 2             d3-collection_Maps_.map             3132.0  PHASE 1
# 3                    d3-fetch___.json             3132.0  PHASE 1
# 0         d3-transition___.transition            69707.0  PHASE 1
# 1      d3-selection_Selecting_.select            69707.0  PHASE 1
# 2            d3-array_Statistics_.max            69707.0  PHASE 1
# 3                 d3-timer___.timeout            69707.0  PHASE 1
# 4    d3-selection_Selecting_.selector            69707.0  PHASE 1
# ..                                ...                ...      ...
# 1      d3-selection_Selecting_.select             2024.0  PHASE 2
# 2    d3-selection_Selecting_.selector             2024.0  PHASE 2
# 0     d3-array_Transformations_.merge             3142.0  PHASE 2
# 0     d3-array_Transformations_.merge             2793.0  PHASE 2
# 1      d3-selection_Selecting_.select             2793.0  PHASE 2
# 2    d3-selection_Selecting_.selector             2793.0  PHASE 2
# 0     d3-array_Transformations_.merge             3574.0  PHASE 2
# 0     d3-array_Transformations_.merge             5152.0  PHASE 2
# 1      d3-selection_Selecting_.select             5152.0  PHASE 2
# 2    d3-selection_Selecting_.selector             5152.0  PHASE 2
# 0     d3-array_Transformations_.merge            12443.0  PHASE 2
# 1      d3-selection_Selecting_.select            12443.0  PHASE 2
# 2    d3-selection_Selecting_.selector            12443.0  PHASE 2
# 0            d3-array_Statistics_.min              780.0  PHASE 2
# 1            d3-array_Statistics_.max              780.0  PHASE 2
# 0         d3-collection_Objects_.keys             4047.0  PHASE 2
# 0     d3-array_Transformations_.merge             1455.0  PHASE 2
# 0           d3-selection_Local_.local             7956.0  PHASE 2
# 0                d3-shape_Lines_.line             1299.0  PHASE 2
# 0         d3-collection_Objects_.keys             3857.0  PHASE 2
# 1           d3-selection_Local_.local             3857.0  PHASE 2
# 0                     d3-path___.path             1867.0  PHASE 2
# 1             d3-collection_Sets_.set             1867.0  PHASE 2
# 0       d3-selection_Selecting_.style            12933.0  PHASE 2
# 1           d3-selection_Local_.local            12933.0  PHASE 2
# 0             d3-collection_Maps_.map              446.0  PHASE 2
# 0             d3-collection_Maps_.map              330.0  PHASE 2
# 0                d3-shape_Lines_.line            20777.0  PHASE 2
# 0            d3-array_Statistics_.min              772.0  PHASE 2
# 1             d3-collection_Maps_.map              772.0  PHASE 2
#
#                        username_folder_name
# 0     2017-Purdue-IronHack-aesmaeili_phase1
# 0   2017-Purdue-IronHack-bchongolnee_phase1
# 0   2017-Purdue-IronHack-collin11117_phase1
# 1   2017-Purdue-IronHack-collin11117_phase1
# 2   2017-Purdue-IronHack-collin11117_phase1
# 3   2017-Purdue-IronHack-collin11117_phase1
# 4   2017-Purdue-IronHack-collin11117_phase1
# 5   2017-Purdue-IronHack-collin11117_phase1
# 6   2017-Purdue-IronHack-collin11117_phase1
# 7   2017-Purdue-IronHack-collin11117_phase1
# 8   2017-Purdue-IronHack-collin11117_phase1
# 9   2017-Purdue-IronHack-collin11117_phase1
# 10  2017-Purdue-IronHack-collin11117_phase1
# 0   2017-Purdue-IronHack-collin11117_phase1
# 1   2017-Purdue-IronHack-collin11117_phase1
# 2   2017-Purdue-IronHack-collin11117_phase1
# 3   2017-Purdue-IronHack-collin11117_phase1
# 0   2017-Purdue-IronHack-collin11117_phase1
# 1   2017-Purdue-IronHack-collin11117_phase1
# 2   2017-Purdue-IronHack-collin11117_phase1
# 3   2017-Purdue-IronHack-collin11117_phase1
# 0     2017-Purdue-IronHack-NTAbraham_phase1
# 1     2017-Purdue-IronHack-NTAbraham_phase1
# 2     2017-Purdue-IronHack-NTAbraham_phase1
# 3     2017-Purdue-IronHack-NTAbraham_phase1
# 0     2017-Purdue-IronHack-NTAbraham_phase1
# 1     2017-Purdue-IronHack-NTAbraham_phase1
# 2     2017-Purdue-IronHack-NTAbraham_phase1
# 3     2017-Purdue-IronHack-NTAbraham_phase1
# 4     2017-Purdue-IronHack-NTAbraham_phase1
# ..                                      ...
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 2   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 2   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 2   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 2   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 0   2017-Purdue-UNAL-IronHack-Yelis3_phase2
# 1   2017-Purdue-UNAL-IronHack-Yelis3_phase2
#
# [23689 rows x 4 columns]

# %%
df['username'] = df['username_folder_name'].apply(lambda row: row.split('-')[-1])

# %%
df.to_csv('../../2-3 processed data/03 software metrics/component.csv',index=False)
